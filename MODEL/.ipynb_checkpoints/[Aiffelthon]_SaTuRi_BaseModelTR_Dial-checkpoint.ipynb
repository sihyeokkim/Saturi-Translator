# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Step-1.-데이터-다운로드" data-toc-modified-id="Step-1.-데이터-다운로드-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Step 1. 데이터 다운로드</a></span></li><li><span><a href="#Step-2.-데이터-정제-및-토큰화" data-toc-modified-id="Step-2.-데이터-정제-및-토큰화-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Step 2. 데이터 정제 및 토큰화</a></span></li><li><span><a href="#Step-3.-모델설계" data-toc-modified-id="Step-3.-모델설계-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Step 3. 모델설계</a></span><ul class="toc-item"><li><span><a href="#Positional-Encoding" data-toc-modified-id="Positional-Encoding-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Positional Encoding</a></span></li><li><span><a href="#Multi-Head-Attention" data-toc-modified-id="Multi-Head-Attention-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Multi-Head Attention</a></span></li><li><span><a href="#Position-wise-Feed-Forward-Network" data-toc-modified-id="Position-wise-Feed-Forward-Network-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Position-wise Feed-Forward Network</a></span></li><li><span><a href="#Encoder-레이어-구현하기" data-toc-modified-id="Encoder-레이어-구현하기-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Encoder 레이어 구현하기</a></span></li><li><span><a href="#Decoder-레이어-구현하기" data-toc-modified-id="Decoder-레이어-구현하기-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Decoder 레이어 구현하기</a></span></li><li><span><a href="#Encoder와-Decoder-클래스를-정의" data-toc-modified-id="Encoder와-Decoder-클래스를-정의-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Encoder와 Decoder 클래스를 정의</a></span></li><li><span><a href="#Transformer-완성하기" data-toc-modified-id="Transformer-완성하기-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Transformer 완성하기</a></span></li><li><span><a href="#Mask" data-toc-modified-id="Mask-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Mask</a></span></li></ul></li><li><span><a href="#Step-4.-훈련하기" data-toc-modified-id="Step-4.-훈련하기-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Step 4. 훈련하기</a></span><ul class="toc-item"><li><span><a href="#Learning-Rate-Scheduler를-선언하고,-이를-포함하는-Adam-Optimizer를-선언" data-toc-modified-id="Learning-Rate-Scheduler를-선언하고,-이를-포함하는-Adam-Optimizer를-선언-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Learning Rate Scheduler를 선언하고, 이를 포함하는 Adam Optimizer를 선언</a></span></li><li><span><a href="#Loss-함수를-정의" data-toc-modified-id="Loss-함수를-정의-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Loss 함수를 정의</a></span></li><li><span><a href="#train_step-함수를-정의" data-toc-modified-id="train_step-함수를-정의-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>train_step 함수를 정의</a></span></li><li><span><a href="#Attention-시각화-함수" data-toc-modified-id="Attention-시각화-함수-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Attention 시각화 함수</a></span></li><li><span><a href="#번역생성함수" data-toc-modified-id="번역생성함수-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>번역생성함수</a></span></li><li><span><a href="#학습" data-toc-modified-id="학습-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>학습</a></span></li></ul></li><li><span><a href="#Step-5.-평가" data-toc-modified-id="Step-5.-평가-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Step 5. 평가</a></span></li></ul></div>

# %%
import tensorflow as tf
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

import matplotlib as mpl
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt

import time
import re
import os
import io


# from tqdm import tqdm_notebook 
from tqdm.notebook import tqdm 
import random

import sentencepiece as spm
from konlpy.tag import Mecab

# %% [markdown]
# # Step 1. 데이터 다운로드

# %%
# train data load
data_dir = os.getenv('HOME')+'/aiffel/aiffelthon/data'
data_train_path = data_dir+"/Train_set_data.csv"
data_test_path = data_dir+"/Test_set_data_sampling(0223).csv"
full_data = pd.read_csv(data_train_path)
full_data_test = pd.read_csv(data_test_path)

# %%
full_data
# Out:
#                                                       text  \
# 0                                            생각이 쪼금씩 바뀌더라고
# 1                                  어 알겠는가 외국인들이 그래도 잘 적응하고
# 2                                 아으 갑자기 예전에 맹장 뜯은 게 생각난다.
# 3                    보면은 조금 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.
# 4                             약간 조금 약간 맛이 쪼끔 거시기 하긴 한데 그래도
# ...                                                    ...
# 1065913  뭐~ 맨날 집에서 인제 음식도 그냥 가까운 데 나가서 먹는 게 아니라 되게 시켜먹는...
# 1065914                  너는 만약에 그런 시대가 오면 네가 어떻게 활동할 것 같애?
# 1065915      하이브도 있고 #조석 작가 이제 조의 영역이라는 웹툰도 있고 마음의 소리도 있는데
# 1065916        추석도 친척들도 사촌까지만 모이긴 했는데 이~ 다 모이니까 할 말도 많고 이~
# 1065917             커피숍 가서 이렇게 먹고 하는 거가 훨씬 맛있거든 기분상으로도 그렇고
#
#                                                       dial reg  \
# 0                                            생각이 쪼금씩 바뀌드라고  jd
# 1                                  어 알겄는가 외국인들이 그래도 잘 적응하고  jd
# 2                                아으 갑자기 예전에 맹장 뜯은 게 생각난디야.  jd
# 3                     보면은 쫌 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.  jd
# 4                              약간 쫌 약간 맛이 쪼끔 거시기 하긴 한데 그래도  jd
# ...                                                    ...  ..
# 1065913  뭐~ 맨날 집에서 인제 음식도 그냥 가까운 데 나가서 먹는 게 아니라 되게 시켜먹는...  jd
# 1065914                  너는 만약에 그런 시대가 오면 니가 어떻게 활동할 것 같애?  gs
# 1065915       하이브도 있고 조석 작가 이제 조의 영역이라는 웹툰도 있고 마음의 소리도 있는디  jd
# 1065916        추석도 친척들도 사촌까지만 모이긴 했는데 이~ 다 모이난이 할 말도 많고 이~  jj
# 1065917              커피숍 가서 이케 먹고 하는 거가 훨씬 맛있거든 기분상으로도 그렇고  cc
#
#                                                        eng
# 0                       I've changed my mind a little bit.
# 1          You know what? Foreigners still get used to it.
# 2        All of a sudden, I think I've ripped off my ap...
# 3        I have a lot of ideas about getting older in a...
# 4              It's a little bit of a tastey, but still...
# ...                                                    ...
# 1065913  I suppose I dont just go out to the nearest pl...
# 1065914  How do you think you will be active when that ...
# 1065915  There is a hive a webtoon called the area of J...
# 1065916  On Chuseok relatives and cousins only gathered...
# 1065917  Its much better to eat at a coffee shop and it...
#
# [1065918 rows x 4 columns]

# %%
full_data_test
# Out:
#                                                   text  \
# 0                            그니까 거기 그 사진 찍는아니야 주상절리 마냥
# 1                                               집에 있으면
# 2                      먹고 취하잖아 그러면 취하면 한이 있잖아 사람이 왜 이게
# 3                                           그렇지 그렇게하겠지
# 4                나 아는사람이라고 해서 십만 원 더 지원해서 이십만 원 지원해 줬어
# ..                                                 ...
# 495  뭐~ 두 분 쓰시는 게 없어서 뭐~ 안정적인 건지 살 잘 얘기를 안 하시더라고요 그...
# 496                   잘 치거나 이렇게 했을 때 다 그냥 이렇게 손 한 번씩 다
# 497                                        아니 잘 안 맞지 넌
# 498                   진짜 너무 이거 조금 조금 미안하기도 하고 다른 사람들한테
# 499  바퀴벌레가 방역을 해도 기어나와 가지고 이제는 쪼끔 마음이 조금 나아지긴 했는데 처...
#
#                                                   dial reg  \
# 0                             그니까 거기 그 사진 찍는아니 주상절리 마냥  jj
# 1                                               집에 이시믄  jj
# 2                   먹어지믄 취하잖아 겅하*믄이 취하면 한이 있네 사람이 왜 이게  jj
# 3                                            그렇지 겅하겠주게  jj
# 4                 나 아는사람이라고 해서 십만 원 더 지원해서 이십만 원 지원해 줜  jj
# ..                                                 ...  ..
# 495  뭐~ 두 분 쓰시는 게 없어서 뭐~ 안정적인 건지 살 잘 얘기를 안 하시더라고요 그...  gs
# 496                    잘 치거나 이렇게 했을 때 다 그냥 이케 손 한 번씩 다  gs
# 497                                        아니 잘 안 맞지 닌  gs
# 498                   진짜 너무 이거 쪼끔 쪼끔 미안하기도 하고 다른 사람들한테  gs
# 499  바퀴벌레가 방역을 해도 기어나와 가지고 이제는 쪼끔 마음이 쫌 나아지긴 했는데 처음...  gs
#
#                                                    eng
# 0    So youre not taking that picture there are you...
# 1                                   If you are at home
# 2    You're eating and getting drunk, and if you're...
# 3                              Thats right Ill do that
# 4    I ot it as I know so I applied for another 100...
# ..                                                 ...
# 495  Im worried about whether its stable or not bec...
# 496  When you hit well or did this, you're all just...
# 497                          No it doesnt fit well you
# 498                           I'm so sorry about this.
# 499  I fot it out even if the cockroaches crawled o...
#
# [500 rows x 4 columns]

# %%
full_data=pd.concat([full_data, full_data_test], axis=0)

# %%
full_data.info() #full_data: 1065918 full_data_test: 500
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1066418 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   text    1066418 non-null  object
#  1   dial    1066418 non-null  object
#  2   reg     1066418 non-null  object
#  3   eng     1066418 non-null  object
# dtypes: object(4)
# memory usage: 40.7+ MB

# %%
full_data.isnull().sum()
# Out:
# text    0
# dial    0
# reg     0
# eng     0
# dtype: int64

# %%
def del_null_dupl(data):
    data=data.dropna(axis=0)
    data=data[~data.duplicated(subset=['text','dial','reg','eng'], keep= 'first')]
    data=data.reset_index(drop=True)# index reset하기 - 기존 index 제거 O
    return data

# %%
full_data=del_null_dupl(full_data) # ['text', 'dial', 'reg', 'eng'])

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1066418 entries, 0 to 1066417
# Data columns (total 4 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   text    1066418 non-null  object
#  1   dial    1066418 non-null  object
#  2   reg     1066418 non-null  object
#  3   eng     1066418 non-null  object
# dtypes: object(4)
# memory usage: 32.5+ MB

# %%
full_data['eng_length'] = full_data['eng'].apply(lambda x : len(str(x).split()))
full_data['dial_length'] = full_data['dial'].apply(lambda x : len(str(x).split()))
full_data['eng_c_length'] = full_data['eng'].apply(lambda x : len(str(x)))
full_data['dial_c_length'] = full_data['dial'].apply(lambda x : len(str(x)))

# %%
regs = ['jj', 'jd', 'gs', 'cc', 'kw']

for reg in regs:
    count = full_data['dial'][full_data['reg']==reg].count()
    print(f'Dial_{reg} :', count)
# Out:
# Dial_jj : 259305
# Dial_jd : 191123
# Dial_gs : 121367
# Dial_cc : 119055
# Dial_kw : 375568

# %%
full_data.groupby(full_data['reg'])['eng_length'].mean()
# Out:
# reg
# cc    14.617244
# gs    13.541300
# jd    14.028306
# jj    11.169943
# kw     9.538350
# Name: eng_length, dtype: float64

# %%
full_data.groupby(full_data['reg'])['dial_length'].mean()
# Out:
# reg
# cc    10.569275
# gs     9.857605
# jd     8.982775
# jj     6.484364
# kw     6.014850
# Name: dial_length, dtype: float64

# %%
eng_data = full_data[['eng', 'eng_length']]
eng_data
# Out:
#                                                        eng  eng_length
# 0                       I've changed my mind a little bit.           7
# 1          You know what? Foreigners still get used to it.           9
# 2        All of a sudden, I think I've ripped off my ap...          12
# 3        I have a lot of ideas about getting older in a...          14
# 4              It's a little bit of a tastey, but still...           9
# ...                                                    ...         ...
# 1066413  Im worried about whether its stable or not bec...          26
# 1066414  When you hit well or did this, you're all just...          17
# 1066415                          No it doesnt fit well you           6
# 1066416                           I'm so sorry about this.           5
# 1066417  I fot it out even if the cockroaches crawled o...          33
#
# [1066418 rows x 2 columns]

# %%
dial_data = full_data[['reg', 'dial', 'dial_length']]
dial_data
# Out:
#         reg                                               dial  dial_length
# 0        jd                                      생각이 쪼금씩 바뀌드라고            3
# 1        jd                            어 알겄는가 외국인들이 그래도 잘 적응하고            6
# 2        jd                          아으 갑자기 예전에 맹장 뜯은 게 생각난디야.            7
# 3        jd               보면은 쫌 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.           11
# 4        jd                        약간 쫌 약간 맛이 쪼끔 거시기 하긴 한데 그래도            9
# ...      ..                                                ...          ...
# 1066413  gs  뭐~ 두 분 쓰시는 게 없어서 뭐~ 안정적인 건지 살 잘 얘기를 안 하시더라고요 그...           23
# 1066414  gs                    잘 치거나 이렇게 했을 때 다 그냥 이케 손 한 번씩 다           12
# 1066415  gs                                        아니 잘 안 맞지 닌            5
# 1066416  gs                   진짜 너무 이거 쪼끔 쪼끔 미안하기도 하고 다른 사람들한테            9
# 1066417  gs  바퀴벌레가 방역을 해도 기어나와 가지고 이제는 쪼끔 마음이 쫌 나아지긴 했는데 처음...           20
#
# [1066418 rows x 3 columns]

# %%
full_data["reg_dial"] = "<" + full_data["reg"] +"> "+full_data["dial"]
full_data["reg_dial"]
# Out:
# 0                                         <jd> 생각이 쪼금씩 바뀌드라고
# 1                               <jd> 어 알겄는가 외국인들이 그래도 잘 적응하고
# 2                             <jd> 아으 갑자기 예전에 맹장 뜯은 게 생각난디야.
# 3                  <jd> 보면은 쫌 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.
# 4                           <jd> 약간 쫌 약간 맛이 쪼끔 거시기 하긴 한데 그래도
#                                  ...
# 1066413    <gs> 뭐~ 두 분 쓰시는 게 없어서 뭐~ 안정적인 건지 살 잘 얘기를 안 하시더...
# 1066414                 <gs> 잘 치거나 이렇게 했을 때 다 그냥 이케 손 한 번씩 다
# 1066415                                     <gs> 아니 잘 안 맞지 닌
# 1066416                <gs> 진짜 너무 이거 쪼끔 쪼끔 미안하기도 하고 다른 사람들한테
# 1066417    <gs> 바퀴벌레가 방역을 해도 기어나와 가지고 이제는 쪼끔 마음이 쫌 나아지긴 했...
# Name: reg_dial, Length: 1066418, dtype: object

# %%
full_data
# Out:
#                                                       text  \
# 0                                            생각이 쪼금씩 바뀌더라고
# 1                                  어 알겠는가 외국인들이 그래도 잘 적응하고
# 2                                 아으 갑자기 예전에 맹장 뜯은 게 생각난다.
# 3                    보면은 조금 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.
# 4                             약간 조금 약간 맛이 쪼끔 거시기 하긴 한데 그래도
# ...                                                    ...
# 1066413  뭐~ 두 분 쓰시는 게 없어서 뭐~ 안정적인 건지 살 잘 얘기를 안 하시더라고요 그...
# 1066414                   잘 치거나 이렇게 했을 때 다 그냥 이렇게 손 한 번씩 다
# 1066415                                        아니 잘 안 맞지 넌
# 1066416                   진짜 너무 이거 조금 조금 미안하기도 하고 다른 사람들한테
# 1066417  바퀴벌레가 방역을 해도 기어나와 가지고 이제는 쪼끔 마음이 조금 나아지긴 했는데 처...
#
#                                                       dial reg  \
# 0                                            생각이 쪼금씩 바뀌드라고  jd
# 1                                  어 알겄는가 외국인들이 그래도 잘 적응하고  jd
# 2                                아으 갑자기 예전에 맹장 뜯은 게 생각난디야.  jd
# 3                     보면은 쫌 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.  jd
# 4                              약간 쫌 약간 맛이 쪼끔 거시기 하긴 한데 그래도  jd
# ...                                                    ...  ..
# 1066413  뭐~ 두 분 쓰시는 게 없어서 뭐~ 안정적인 건지 살 잘 얘기를 안 하시더라고요 그...  gs
# 1066414                    잘 치거나 이렇게 했을 때 다 그냥 이케 손 한 번씩 다  gs
# 1066415                                        아니 잘 안 맞지 닌  gs
# 1066416                   진짜 너무 이거 쪼끔 쪼끔 미안하기도 하고 다른 사람들한테  gs
# 1066417  바퀴벌레가 방역을 해도 기어나와 가지고 이제는 쪼끔 마음이 쫌 나아지긴 했는데 처음...  gs
#
#                                                        eng  eng_length  \
# 0                       I've changed my mind a little bit.           7
# 1          You know what? Foreigners still get used to it.           9
# 2        All of a sudden, I think I've ripped off my ap...          12
# 3        I have a lot of ideas about getting older in a...          14
# 4              It's a little bit of a tastey, but still...           9
# ...                                                    ...         ...
# 1066413  Im worried about whether its stable or not bec...          26
# 1066414  When you hit well or did this, you're all just...          17
# 1066415                          No it doesnt fit well you           6
# 1066416                           I'm so sorry about this.           5
# 1066417  I fot it out even if the cockroaches crawled o...          33
#
#          dial_length  eng_c_length  dial_c_length  \
# 0                  3            34             13
# 1                  6            47             23
# 2                  7            60             25
# 3                 11            66             36
# 4                  9            43             27
# ...              ...           ...            ...
# 1066413           23           144             80
# 1066414           12            76             31
# 1066415            5            25             11
# 1066416            9            24             32
# 1066417           20           158             71
#
#                                                   reg_dial
# 0                                       <jd> 생각이 쪼금씩 바뀌드라고
# 1                             <jd> 어 알겄는가 외국인들이 그래도 잘 적응하고
# 2                           <jd> 아으 갑자기 예전에 맹장 뜯은 게 생각난디야.
# 3                <jd> 보면은 쫌 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.
# 4                         <jd> 약간 쫌 약간 맛이 쪼끔 거시기 하긴 한데 그래도
# ...                                                    ...
# 1066413  <gs> 뭐~ 두 분 쓰시는 게 없어서 뭐~ 안정적인 건지 살 잘 얘기를 안 하시더...
# 1066414               <gs> 잘 치거나 이렇게 했을 때 다 그냥 이케 손 한 번씩 다
# 1066415                                   <gs> 아니 잘 안 맞지 닌
# 1066416              <gs> 진짜 너무 이거 쪼끔 쪼끔 미안하기도 하고 다른 사람들한테
# 1066417  <gs> 바퀴벌레가 방역을 해도 기어나와 가지고 이제는 쪼끔 마음이 쫌 나아지긴 했...
#
# [1066418 rows x 9 columns]

# %%
type(full_data['dial'][0])
# Out:
# str

# %%
# # 1. 모든 입력을 소문자로 변환합니다.
# # 2. 알파벳, 문장부호, 한글만 남기고 모두 제거합니다.
# # 3. 문장부호 양옆에 공백을 추가합니다.
# # 4. 문장 앞뒤의 불필요한 공백을 제거합니다.

def preprocess_sentence(sentence):

    length = len(sentence)
    match = re.search(r'(.+)\1{3,}', sentence) 
    if match or length == 0:
        return None

    sentence = sentence.lower()
    sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
    sentence = re.sub(r'[" "]+', " ", sentence)
    sentence = re.sub(r"[^a-zA-Z?.!<>가-힣ㄱ-ㅎㅏ-ㅣ]+", " ", sentence)
    sentence = sentence.strip()

    return sentence

# %%
# encoder corpus
enc_corpus = full_data['eng'].apply(lambda x : preprocess_sentence(x)).sort_index()

# %%
enc_corpus
# Out:
# 0                        i ve changed my mind a little bit .
# 1          you know what ? foreigners still get used to it .
# 2          all of a sudden i think i ve ripped off my app...
# 3          i have a lot of ideas about getting older in a...
# 4              it s a little bit of a tastey but still . . .
#                                  ...
# 1066413    im worried about whether its stable or not bec...
# 1066414    when you hit well or did this you re all just ...
# 1066415                            no it doesnt fit well you
# 1066416                            i m so sorry about this .
# 1066417    i fot it out even if the cockroaches crawled o...
# Name: eng, Length: 1066418, dtype: object

# %%
len(enc_corpus[1])
# Out:
# 49

# %%
# enc_corpus 통계

min_len = 999
max_len = 0
sum_len = 0


for sen in enc_corpus:
    length = len(str(sen))
    if min_len > length: min_len = length
    if max_len < length: max_len = length
    sum_len += length

print("문장의 최단 길이:", min_len)
print("문장의 최장 길이:", max_len)
print("문장의 평균 길이:", sum_len // len(enc_corpus))

sentence_length = np.zeros((max_len), dtype=int)

#총 max_len의 배열을 만든 후, raw 문장을 돌면서 각 문장별 길이를 sentence_length의 len(sen) 인덱스마다  계속 더해가면서 counting
for sen in enc_corpus:
    sentence_length[len(str(sen))-1] += 1

plt.bar(range(max_len), sentence_length, width=1.0)
plt.title("Sentence Length Distribution")
plt.show()
# Out:
# 문장의 최단 길이: 0
# 문장의 최장 길이: 713
# 문장의 평균 길이: 50

# %%
dec_corpus = full_data['reg_dial'].apply(lambda x : preprocess_sentence(x)).sort_index()

# %%
dec_corpus
# Out:
# 0                                         <jd> 생각이 쪼금씩 바뀌드라고
# 1                               <jd> 어 알겄는가 외국인들이 그래도 잘 적응하고
# 2                            <jd> 아으 갑자기 예전에 맹장 뜯은 게 생각난디야 .
# 3                 <jd> 보면은 쫌 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요 .
# 4                           <jd> 약간 쫌 약간 맛이 쪼끔 거시기 하긴 한데 그래도
#                                  ...
# 1066413    <gs> 뭐 두 분 쓰시는 게 없어서 뭐 안정적인 건지 살 잘 얘기를 안 하시더라고...
# 1066414                 <gs> 잘 치거나 이렇게 했을 때 다 그냥 이케 손 한 번씩 다
# 1066415                                     <gs> 아니 잘 안 맞지 닌
# 1066416                <gs> 진짜 너무 이거 쪼끔 쪼끔 미안하기도 하고 다른 사람들한테
# 1066417    <gs> 바퀴벌레가 방역을 해도 기어나와 가지고 이제는 쪼끔 마음이 쫌 나아지긴 했...
# Name: reg_dial, Length: 1066418, dtype: object

# %%
# dec_corpus 통계

min_len = 999
max_len = 0
sum_len = 0


for sen in dec_corpus:
    length = len(str(sen))
    if min_len > length: min_len = length
    if max_len < length: max_len = length
    sum_len += length

print("문장의 최단 길이:", min_len)
print("문장의 최장 길이:", max_len)
print("문장의 평균 길이:", sum_len // len(dec_corpus))

sentence_length = np.zeros((max_len), dtype=int)

#총 max_len의 배열을 만든 후, raw 문장을 돌면서 각 문장별 길이를 sentence_length의 len(sen) 인덱스마다  계속 더해가면서 counting
for sen in dec_corpus:
    sentence_length[len(str(sen))-1] += 1

plt.bar(range(max_len), sentence_length, width=1.0)
plt.title("Sentence Length Distribution")
plt.show()
# Out:
# 문장의 최단 길이: 4
# 문장의 최장 길이: 221
# 문장의 평균 길이: 31

# %%
len(enc_corpus)
# Out:
# 1066418

# %%
len(dec_corpus)
# Out:
# 1066418

# %%
#훈련 및 테스트셋 분리
enc_corpus=enc_corpus[:-500]
enc_corpus_test = enc_corpus[-500:]
dec_corpus=dec_corpus[:-500]
dec_corpus_test = dec_corpus[-500:]

# %%
print(enc_corpus.shape)
print(enc_corpus_test.shape)
print(dec_corpus.shape)
print(dec_corpus_test.shape)
# Out:
# (1065918,)
# (500,)
# (1065918,)
# (500,)

# %% [markdown]
# # Step 2. 데이터 정제 및 토큰화

# %%
# Train 데이터 정제 및 토큰화
def clean_corpus(enc_corpus, dec_corpus):

    assert len(enc_corpus) == len(dec_corpus) # enc_corpus, dec_corpus가 같은 갯수라는 것을 검증받기 위해 적용

    cleaned_corpus = list(set(zip(enc_corpus, dec_corpus)))  # 중복된 데이터 제거
    
    return cleaned_corpus

cleaned_corpus = clean_corpus(enc_corpus, dec_corpus)
len(cleaned_corpus)
# Out:
# 1065270

# %%
cleaned_corpus
# Out:
# [('it s not too much .', '<kw> 너머 그러는거 아니어라 .'),
#  ('i mean when i m in elementary school if i m done in fifth',
#   '<jj> 고등학교에 다니는 시간이 점점점 그니까 뭐 초등학교 때는 뭐 이제 뭐냐 다섯째 안에 마친다 하믄'),
#  ('its very implicit so something', '<jd> 어 엄청 약간 시사적인 거 근까 뭔가 어떤'),
#  ('he s a handsome guy so . . .', '<jj> 얼굴이 잘생겼지 게난'),
#  ('so it s kind of a little bit of a everyday', '<jj> 그난 좀 약간이 가끔 보믄 일상'),
#  ('she s working on the branches .', '<kw> 여자가 나뭇가지를 손질하고 있사 .'),
#  ('no matter how angry i am how can i say that ?',
#   '<kw> 아무리 화가 나도 어떻게 그른 소릴해 ?'),
#  ('i ve been bringing my husband here lately .', '<jj> 난 요새 우리 서방 잡아오는 이'),
#  ('the door is always open in the house of my student jeju grandmother',
#   '<gs> 제자 제주 할매 집에는 문은 항상 열리가 있잖아 대문이'),
#  ('its a bit disappointing that i can come by looking at the trip only there',
#   '<cc> 나는 여행을 이제 그 거기만 보고 오기는 쫌 아쉽잖아 .'),
#  ('his friend came down and decided to rent a truck in gwangju then',
#   '<jj> 그 오빠 친구가 내려와 광주에서 그때 빌리기로 핸 트럭을'),
#  ('i want you to do two pieces of omlinkle two pieces of bolconos like this .',
#   '<jj> 뿌링클 두 조각 볼케이노 두 조각 이렇게 하고 와시면 좋겠다 웃음'),
#  ('i didnt know before marriage', '<kw> 겨론 전엔 몰랐는데'),
#  ('these are songs that you can humme so i think you like them a little',
#   '<cc> 이제 흥얼거릴 수 있는 노래들이니까 그래서 그런 노래들을 쫌 좋아하는 거 같고'),
#  ('i don t know so if you think about what you re doing that would be a good idea .',
#   '<jd> 몰라 긍게 할라고 생각을 하면은 그렇게 하면은 좋을 것 같더라'),
#  ('there s a lot of people in the long run .', '<kw> 오래 있다 보면 벨사람 다 있어 .'),
#  ('oh why did you write a colored one or did you reflect the one that was too thick and fall down',
#   '<jj> 아 왜 색깔 있는 것 썬 아님 너무 두꺼운 거 쓴 거 반사해서 밑으로 떨어진 건가'),
#  ('ive never seen him late before', '<kw> 이제까지 그 사람이 한 번도 지각한 걸 본 적이 음싸 .'),
#  ('i put it in a pot there and i ate it and i finished it .',
#   '<jj> 거기 가마솥에 올려놩 거기서 밥해 먹고 다 했주 . 게'),
#  ('imashing it so when did you wash it i got water and scratched it',
#   '<jd> 씻고 있는거야 야 그래가꼬 언제 씻냐 이래가지고 물 받아가지고 쓱쓱스'),
#  ('but hye jin came out with a tube just like this .',
#   '<cc> 근데 내가 그 깊은 데로 확 딱 빠진 거야 근데 혜진이는 여차저차 해가지고 튜브를 짚고서 이케 나왔어 .'),
#  (None, '<kw> 이름 야 휘지'),
#  ('so your friends didnt play so im sure ill be at home',
#   '<jd> 그래서 니 친구들은 안 놀아 그랬더니 집에 있을 걸요'),
#  ('i can tell you about my personality but when i talk about other peoples personalities i especially have to fix the personality of that person',
#   '<gs> 저의 성격에 대해서 말씀을 드릴 수 있는데 따른 사람의 성격에 대해서 얘기할 때는 특히 뭐 그 사람의 뭐 고쳐야 될 성격 그'),
#  ('we still don t know the th of what nature has shown us .',
#   '<kw> 우리는 당아 자연이 우리에게 보여준 모습의 만분의 일도 모르고 있어 .'),
#  ('it may be because its just compared to you but if i ordered it to me i would',
#   '<gs> 걍 오빠랑 비교돼서 그런지 몰라도 저한테는 저는 만약에 제가 시켰는데 저거 만약에'),
#  ('so this is kind of similar to other things',
#   '<gs> 그니까 약간 이것도 좀 여타 다른 일이랑 비슷한 게'),
#  ('the garlic smells really bad', '<jj> 마늘 냄새 막 심하잖아'),
#  ('dont you have a ring', '<gs> 반지 그거는 있다 아이가'),
#  ('oh i asked her to send someone to me because i had something to do with ari .',
#   '<kw> 아 내가 아리랑 보낼게 있어서 사램 좀 보내 달라고 부택했는데'),
#  ('you re my boss but in this case it s a team thing .',
#   '<kw> 아무리 헝이가 제 상사지만 이번 일 같은 경우엔 팀으로 움직여야하는 일이잖아요 .'),
#  ('it s good if you make money .', '<kw> 엄마가 돈이라도 잘 불리문 좋은데 .'),
#  ('since i have only one sister im a little unusual about her relationship',
#   '<jd> 어 저도 언니 한 명만 있다 보니까 언니랑 쫌 사이가 유별나게 쫌'),
#  ('i told you not to come home and now i m telling you it s over .',
#   '<jj> 집에 오지 말랜 허멍이 이젠 해그네 허난 이젠 끝'),
#  ('are you sure you don t want to see us ?', '<kw> 즈네 안 보고 싶을 자신 있으세요 ?'),
#  ('because chinese cant come', '<jj> 중국인들 못 오난'),
#  ('its a little bit like that i help you a little bit',
#   '<jd> 쫌 약간 그런 거 막 약간 도와주지'),
#  ('thats how you did it sharp', '<jj> 영 했구나이 .'),
#  ('they shot an arrow with the enemy and pulled the boat back on the wall',
#   '<jd> 적군이다하고 화살을 엄청나게 쐈대 그 담에 그 배를 다시 떙겼대 .'),
#  ('when i was in high school time really didnt go by and i was wondering when i would graduate and enjoy freedom',
#   '<jj> 고등학교 땐 시간이 진짜 안 가는거라 가는 거야 언제면 이걸 졸업해서 자유를 누리나 해신디'),
#  ('what he means to me .', '<kw> 저 사램이 나한테 워뜬 의미인지 .'),
#  ('it seemed to be of no use at all .', '<kw> 그것은 아모 데도 쓸모가 없을 듯 싶었어 .'),
#  ('give me anything .', '<kw> 워느 것이든 하나기 주시오 .'),
#  ('then my brother pushed me before i came to the sacrifice .',
#   '<jd> 했드니 우리 형님은 긍까 내가 제사 때 오기 전에 밀렸어 .'),
#  ('city hall', '<jj> 시청에이'),
#  ('so there s something you re talking about .',
#   '<jd> 그니까 주변에 응 어르신들이 하는 말씀 있자뉴 응'),
#  ('i don t think there s yet a site that s so organized like albamon .',
#   '<gs> 있는데 그게 뭐 알바몬처럼 이케 쫙 정리돼 있는 사이트는 아직 없는 거 같애요 그래서'),
#  ('hey but if its name you wont be able to wear it in a few years does he need to buy such expensive ones',
#   '<jj> 야 근디 name이면은 거 몇 년 강 못 입을 거 아니 가이 경 비싼거 살 필요 있서 ?'),
#  ('so wow really but really', '<jj> 그래가지고 와 진짜 근데 약간'),
#  ('isnt weight training right now so its all called weight training in foreign countries right',
#   '<gs> 웨이트 트레이닝이라고 하는 게 이제 맞지 않나 외국에서도 다 웨이트 트레이닝이라고 하는 거지 .'),
#  ('movie stars are good at movies and doesnt they are good at dramas',
#   '<gs> 영화 배우들이 영화를 잘 아 그 드라마를 잘 한다 아이가 ?'),
#  ('the man who had never loved a woman who was apathetic .',
#   '<kw> 단 한 번도 예자를 사랑해본 적이 없는 냉담한 자였던 그 남자가 .'),
#  ('dont you put a little more water in the dough like that',
#   '<gs> 반죽 쫌 더 이렇게 물 같으 물 같은 그렇게 넣는 거 아이가 ?'),
#  ('it s a long term emergency . i can t do a hundred copies of the print .',
#   '<kw> 비상긴축 기간이라 프린트 백 장은 증말 안돼요 .'),
#  ('but if you don t get this early', '<jj> 근데 이거 조생은 빨리 안 따믄'),
#  ('are you still eating ?', '<kw> 상구도도 먹어 ?'),
#  ('my personality is to endure this even if i want to i sleep well and im going to be comfortable',
#   '<cc> 성격은 이게 하고 싶어도 참는 거야 내가 내가 잠 잘 자고 내가 편할라고'),
#  ('if you want to make him send him to the name three .',
#   '<kw> 자 사램 만들려면 이름 한테 보내 .'),
#  ('i couldn t take a shower this morning .', '<kw> 아직에 샤워를 못해서요 지금 퉁퉁 부었어요 .'),
#  ('maybe a little foreign but i didn t fit in a little bit with the rest of the world .',
#   '<jd> 아무래도 쫌 외국 저는 외국이랑 쫌 안 맞더라고요 .'),
#  ('they see it as a competition and make extreme choices .',
#   '<jd> 그 대상을 경쟁상대로 보고 극단적인 선택을 하기도 한댜 .'),
#  ('i cant even pack it anymore', '<jj> 꾸레도 못가 이젠'),
#  ('you re a bitch . now you re a bitch .', '<kw> 지집아야 지금은 니 차여라 .'),
#  ('i ve just got a t shirt . it s just a horse . it s just like this .',
#   '<jj> 막 티를 낸 말뿐인 거잖아 막 이런 식으로'),
#  ('i dont do much acidity and i dont do much acidity',
#   '<jj> 산디는 많이 안 허고 산디는 잘 안돼'),
#  ('i can t give up on you until now .',
#   '<cc> 배우게 될려나 어쩔려나 아직까지는 아유 포기를 포기가 안 되네 .'),
#  ('i m not sure .', '<kw> 나는 자신 읎어 .'),
#  ('if you go to the dock below it it was very big if you go a little bit toward my house at this time',
#   '<jj> 그 밑에도 부두 쪽으로 가면은 이제 우리집 이시간 쪽으로 조금 가면은 굉장히 커났어'),
#  ('you have to eat evenly and eat meat well and this is what you have to do',
#   '<gs> 골고루 묵고 고기도 잘 먹고 막 이래야 되는데'),
#  ('but you re the second since he told me he s got that label .',
#   '<kw> 근데 갸가 그 주소 가 됐다는 말 이후로 두 번째가 니야 .'),
#  ('but i can t use all the data because it s a white flag in a month .',
#   '<jj> 그런데 데이터를 다 쓸 일이 어서 한 달에 백기가 라부난 .'),
#  ('and if you keep giving it to me if i keep giving it to you',
#   '<kw> 그걸 꼐속 만약에 주다 보면 내가 계속하면은'),
#  ('don t worry about that because if you need to hire a temporary employee you ll be able to finish it in the deadline .',
#   '<kw> 그근 극정 말아요 . 필요하면 임시 직원을 채용하면 되니까 마감일 안에 끝낼 수 있을 거예요 .'),
#  ('you don t need to know that .', '<kw> 그건 할머이가 알 거 없사요 .'),
#  ('i don t think it s a fall these days .', '<kw> 요중간 가을 자체가 없는 거 같아요 .'),
#  ('for selfsatisfaction i kept wearing it and i wore it and i asked you to do this',
#   '<gs> 자기 만족을 위해서 계속 입히고 다니고 이거 입히고 저거 입히고 나는 니한테 이거 해줬는데 하고 요구하고'),
#  ('it s amazing how you feel .', '<kw> 마옴 쓰는 게 기특하구먼 .'),
#  ('i m too busy today .', '<kw> 내가 오놀 너머 너머 바빠가지고 말이다 .'),
#  ('i just kind of bought a lot of what i wanted to do because i ve bought or of them .',
#   '<gs> 그냥 종류별로 제가 하고 싶었던 거 다양하게 마이 샀던 거 같습니다 그렇게 산 저 스무 개에서 서른 개 정도 되니까'),
#  ('it s actually two fundamental mistakes .',
#   '<kw> 사실 이것은 두 나무가쟁이 근본적인 실수들을 저지르는 거야 .'),
#  ('if you get that kind of apology for your kid you let him go .',
#   '<kw> 자석을 위해서 그 정도 사개 받았으문 풀어주는 거지 뭐 은주야 .'),
#  ('when you have menstruation your body is all swollen', '<jj> 생리하믄 몸 다 붇'),
#  ('didn t you forget about dinner ?', '<kw> 저냑 당번 깜빡 한거 아니나 ?'),
#  ('puta and then for the customer wait a minute', '<jj> 거난 그다음에 손님한텐 손님 잠시만예'),
#  ('the performance has fallen a lot', '<jj> 성능이 하영 떨어져부런'),
#  ('isn t that a story we haven t talked about for a while ?',
#   '<kw> 그건 당분간 없던 이애기로 하지 않았니 ?'),
#  ('i just don t know how to get past it so i think it s been a month .',
#   '<kw> 그냥 기냥 어트게 지나가는지도 모르겠어서 한 달 지났다고 생각한 거 같은데 ?'),
#  ('when i looked at it i said that professor too',
#   '<jj> 붕 떠보니깐 이 그니까 그 교수님도 내가 말했잖아 그때이'),
#  ('itis good to be with friends but its not that i think they tend to do it a little bit',
#   '<gs> 친구들이랑 같이 할 수 있으면 좋은데 그렇지 않으니까 쫌 하다 말다 하는 편인 거 같아요 .'),
#  ('then dont tell me let me put it on the plate', '<jj> 개믄 곧지마라 게'),
#  ('i don t know .', '<kw> 글쎄 그른 것 같기두 하구 .'),
#  ('im going to the mountains today', '<jj> 오늘도 나 산에 가멍'),
#  ('what bitch ?', '<kw> 어뜬 년 ?'),
#  ('yeah you know if i catch you this way i think it s gonna be okay .',
#   '<kw> 응 진로도 그니까 이쪽으로 잡으면은 어 괜찮을 거 같단 생각이 들어 .'),
#  (None, '<kw> 마음이 아프대고 몸이 아팠대 몸또'),
#  ('i think i ve had a lot of fun in my life .',
#   '<kw> 내가 그동안 너머 멋대가리 없게 산거 같애 .'),
#  ('my little girl lives with my little girl in her mouth for a day .',
#   '<kw> 우리새아가 우리새아가 할로쥉일 아주 입에 다시고 사신다 아주 아이고 .'),
#  ('if you eat that taste open', '<gs> 그 맛이 이 뜯어 무먼'),
#  ('that s how i got married .', '<jd> 그렇게 해가꼬 결혼하게 된 거예요 .'),
#  ('oh what if you get addicted so i dont think you can get addicted its okay what do you say',
#   '<cc> 아고 중독되면 어떡하지 허니까 에 중독 안 돼요 괜찮아요 아 이러는데 뭐라 그려요 .'),
#  ('yeah and then again and then again .', '<kw> 그치 또 그러면 또 그땐'),
#  ('i can also sympathize with him a lot', '<cc> 되게 많이 공감을 하게 되기도 하고 쫌 뭔가'),
#  ('he s lost and he s still having a hard time with it .',
#   '<jd> 사별로 이제 잃어가지고 그걸 아직도 힘들어 하는 그런 친구여 .'),
#  ('yes i saw yesterday and the high school student was confirmed oh my',
#   '<jj> 네 어제도 보난 그 고등학생이 확진 됐는데 아이구'),
#  ('i ve never used an x ray before but i ve been studying to learn how to write computer notes so i don t know anything .',
#   '<jd> 너 엑세스 쓴 적 있어 나 엑세스 한번도 안썼는데 컴활 필기 딸려고 공부하니까 뭐 아무것도 모르겠던데 .'),
#  ('i m just gonna make money .', '<kw> 아부지 인제 막 돈 막 벌 거다 .'),
#  ('if you save a lot of money a month for a date bankbook you can use it with that money and you may feel a little awkward when paying',
#   '<cc> 데이트 통장으루 한번에 한 달에 얼마씩 모으자 하면 그 돈으로 여행 가서도 쓸 수 있고 계산할 때 되게 쫌 뻘쭘해지는 상황이 생길 수도 있잖아 .'),
#  ('dad s note is real not a threat to my family .',
#   '<kw> 아부지 유서가 우리 가족들 협박용이 아니라 진이라구 .'),
#  ('that photo razor blades look similar to electronics',
#   '<jj> 그 이 면도날도 전자제품 이랑 좀 비슷한 거 닮아'),
#  ('do you have any seafood allergies', '<jd> 너는 뭐 해산물 알러지 같은 거 없나 ?'),
#  ('i dont like watching dramas a little bit and like listening to them like this right name',
#   '<cc> 드라마에 쫌 드라마도 별로 보는 거 안 좋아하고 이케 듣는 걸 좋아하거든요 이름님 저는'),
#  ('do you live at home ?', '<kw> 시직 보구 살어 ?'),
#  ('and then we re going to have a little bit of that vitamin .',
#   '<kw> 그러 그다음에 이제 그런 비타민 같은 것도 쫌'),
#  ('i think ive hidden something inside and did a gift that could be a little surprising',
#   '<cc> 뭔가 안에 숨겨놔서 약간 깜짝 놀랄 수 있는 선물 그런 거를 했던 적은 있는 거 같애요 .'),
#  ('if you hit him he ll be gentle .', '<jd> 막 치대믄잉 고것이 인자 그 부드럽게 인자 그'),
#  ('i don t want to get paid so if you get paid pay it back at once .',
#   '<kw> 월수 받는 것도 귀찮으이까 돈 모아지면 한끄번에 갚아라 .'),
#  ('so among stocks these days a little', '<gs> 그래서 혹시 머 요새 주식 중에서 쫌'),
#  ('that was my first play i saw it eight years ago',
#   '<gs> 내 첫 연극이 그거였거든 진짜 한 팔 년 됐다 팔 년 팔 년 전에 본 건데'),
#  ('is this really silver ?', '<kw> 이건 진뗑이 은입니까 ?'),
#  ('rather than spending time drinking and drinking having a good meal',
#   '<jd> 술을 마시면서 이르케 시간 자리를 보내는 거보다는 밥을 이제 맛있게 먹고'),
#  ('it s a little bit like running at home .', '<jd> 인제 쫌 집에서라도 가볍게 뛰거나'),
#  ('i m sure you re going to have a medical checkup now but i m sure you re going to have to take a full medical exam .',
#   '<jd> 갖 근디 건 인자 건강검진을 받았겄잖아 목포 한양댄가 와서 건강검진을 전체적으로'),
#  ('i want you to be able to put something in there like this .',
#   '<cc> 뭔가 좀 이케 담아줄 수 있는 분이셨으면 합니다 .'),
#  ('i think i ve never seen you so angry .', '<jj> 쌤이 그렇게 화내는 거 진짜 처음 봤던 거 닮'),
#  ('the sabula kept on angling these days', '<gs> 쭐임말도 요새 자꾸 각을 잡으시더라고요 .'),
#  ('you re such an idiot . you did this .',
#   '<kw> 니 참 바보 같다 막 이켔잖아 이렇게 했잖아 그리구 뭐 사람들이 뭐 물어보니까는'),
#  ('is that your mother ?', '<kw> 어머이야 ?'),
#  ('do you know this guy ?', '<kw> 이 자석이 이그 사램을 거렁뱅이루 아나 ?'),
#  ('i think i had a hard time because the food didnt suit my taste when i went to china',
#   '<gs> 저는 중국 갔을 때 음식이 되게 입에 안 맞아가지고 쫌 고생을 했던 것 같애요 .'),
#  ('it s only from your point of view that you can go to her house .',
#   '<kw> 이모 입장에서야 그 예자 집에 찾아갈 수 있는 거지 .'),
#  ('i still do a small ball exercise', '<jd> 나는 그래도 짝은 공으로 하는 운동은'),
#  ('you need to come to our office and put it in our application .',
#   '<kw> 우리 사무실로 오세사 신청서에 기재하셔야 돼요 .'),
#  ('even if you re not married can you do it that way ?',
#   '<kw> 아무리 겔혼을 안 하셨다지만 그른 식으로 하셔도 돼요 ?'),
#  ('they ve dealt a lot with the pollution in the course of three years .',
#   '<kw> 석간에서는 공해 문제를 거하게 다루었어 .'),
#  ('grandmother plum sellers and grandmothers who sell garlic in the countryside',
#   '<jj> 할망 매실파는 할망들이영 시골에 무신 마농 파는 할망들이영'),
#  ('what do you say to your sister ?',
#   '<kw> 어머 어머 아무리 화가 나도 그렇지 너 언니한테 무신 말이 그래 ?'),
#  ('what are you doing', '<jj> 너 뭐하멍 지내맨 ?'),
#  ('of course the name of the title is like that so i think it has outstanding advantages and again',
#   '<jd> 이름이도 당연히 그런 부분이 있어서 출중한 장점이 있다고 생각을 하고 그리고 그리고 또'),
#  ('you don t have children to beat .', '<kw> 자석 이기는 부모 없다잖아요 .'),
#  ('imaturely eat snacks', '<kw> 과자를 덥석덥석 먹어조지다 .'),
#  ('he said that so hes singing all the stars',
#   '<jd> 참 그 소릴 허드라고 그래서는 에잇 별 소릴 다 하시네 참말로'),
#  ('until the end of the covid situation i was definitely a little reluctant to go to the pc room',
#   '<jd> 혹시 코로나 시국 끝나기 전까지는 확실히 피씨방 가기도 쫌 꺼려지더라구요 .'),
#  ('so the people of broadcasting companies are amazing',
#   '<jd> 그니까 방송사 사람들 참 대단한 거야 보면은'),
#  ('thats right so if you think about it now its really bad',
#   '<jd> 그러제 긍께 지금 생가가믄 진짜 못됐어 .'),
#  ('how many times do i have to change the train to get there ?',
#   '<kw> 그곳에 가려면 기차를 몇 번이나 갈아타야 하다와 ?'),
#  ('i ve seen it in one eye .', '<kw> 난 한 눈에 알아봤싸요 .'),
#  ('i do . i feel the vibrations in my bed .',
#   '<kw> 내가 그래 가주구 침대에 진동이 느껴 가주구 너무'),
#  ('born and raised in jeju island and learned from parents is a really good thing',
#   '<jj> 제주도에서 나고 자라고 부모한테 배운 것도 행 이런 건 참 장점으로'),
#  ('so im a little worried', '<cc> 그래서 쫌 걱정이 돼요 .'),
#  ('oh but that was a little bit like that if we bought three we gave about five dumplings',
#   '<jj> 아 근데이 그게 그 약간 그렇긴 핸 원래 만두를 우리가 세 개 샀으면 다섯 개 정도 줜'),
#  ('i thught i like a gorangang character actually a friendly person is more',
#   '<gs> 내 약간 고런 캐릭터가 좋나 봐 사실 다정한 사람이 더'),
#  ('tell your son to do it .', '<jd> 아들한테 시켜요 그래갖고'),
#  ('sometimes there was a time when the car came by and the car just came by .',
#   '<jj> 가끔씩 차가 옆 차가 막 빵 하고 지나갈 때가 있었댄'),
#  ('everyone is like that they all live the same thing who am i or who am i',
#   '<jj> 다 거난 사는 거는 다 똑같아 나 사는 거나 누구 사는 거나 .'),
#  ('no i said i said you should unite all at once because you have deposits at the end of the year',
#   '<cc> 아니 나는 연말에 너 예금 나오니까 한꺼번에 뭉칠라 그랬지 그랬드니'),
#  ('in a way the military so one that turned the game upside down in the history of war',
#   '<gs> 되게 어떻게 보면은 군 그니까 전쟁사에서 크게 판을 뒤집어놓은 하나의 어떻게 보면'),
#  ('so now i m going to connect with itunes and then i m going to put in a song and sometimes i m going to say',
#   '<jd> 그래서 이제 아이튠즈로 이르케 연결을 해서 노래를 넣고 하면은 가끔씩 이제 아이튠즈가'),
#  ('be a good boy .', '<kw> 효자 노릇을 하다와 .'),
#  ('i want you to call me the name . that s my name .',
#   '<kw> 이름 라고 불러 주세요 그기 제 이름이에요 .'),
#  ('that s what he wrote .', '<kw> 고 사람이 쓴 시집이었다 .'),
#  ('this is so i', '<cc> 까 말하자면 그니까 제가 이게'),
#  ('if you win a fight you get a smile .', '<kw> 화투하는데 이기면 희쭉 웃음이 나오지 .'),
#  ('she gave birth to a baby last year', '<jj> 지금 애기 작년에 낳그냉'),
#  ('then what about the parttime job i throw it away thats right thats not it so',
#   '<gs> 저는 그면 하던 알바는 어떡하나요 버리고 가잖아요 맞잖아요 그건 아니잖아요 그니깐'),
#  ('i have to eat dinner .', '<kw> 저 저냑 먹어야 해요 .'),
#  ('because the windows are big the sun shines through the room .',
#   '<kw> 창문이 크니까 햇빛으로 방 안이 다 비치킨다 .'),
#  ('come with me . come with me . i ll assist you . come with me .',
#   '<jd> 같이 해야 쓰겄어 와갖고 내가 보조할 것인께 와 가지고 좀'),
#  ('of course i m the first one .', '<kw> 무 물론 내가 먼전'),
#  ('what are you saying', '<jj> 뭐라 뭐라고 햄수가'),
#  ('the bride is dressed up nicely .', '<kw> 신비가 한복을 곱게 차려입었다 .'),
#  ('it s cheaper than baseball than a screen .', '<gs> 그 스크린보다 야구보다 싸다 쫌'),
#  ('on the right hand side there s a rock .', '<kw> 오른펜짜에 보면 바위가 있다 .'),
#  ('your father couldn t raise his face .', '<kw> 느이 아부지가 얼구리를 들을 수가 없드랜다 .'),
#  ('he said you were a student . you re a student .',
#   '<kw> 그래가주고 학상이라고 말을 했어 학상은 학상입니다'),
#  ('but this is what i just did a little bit of exercise when i was a kid .',
#   '<kw> 근데 이게 나는 그냥 단순히 어릴 때 운동을 쫌 많이 했는데'),
#  (None, '<jd> 그래서 이케 병원이나 이런 거 그 이런 거를 세 개'),
#  ('i think it s right that you don t really have one .',
#   '<jj> 진짜 안 키우는 게이 안 낳는 게 맞다고 생각해 .'),
#  ('so i can t stop and i m just trying to keep looking for new songs and i m just trying to hear that song .',
#   '<kw> 그래서 끊을 수가 없는 거 같애 계속 새로운 거 좋은 노래 찾을라고 막 이 노래 저 노래 들어보고 막 그러는 거 같애 .'),
#  ('i think that scene is the most cool scene',
#   '<jd> 그 저는 그 장면이 가장 머 가장 이케 멋있는 장면이다라고 생각이 드는 것 같아요 .'),
#  ('you re just putting a lot of stuff on youtube . have you seen that ?',
#   '<jj> 몇 가지 해 가지고 막 유투브에 막 많이 올리잖아 그런 거 안 봐 봔 ?'),
#  ('if you can t even take care of your mother you can t do that .',
#   '<kw> 혼재 계신 어마이 모시지도 못하면 서 그 정도도 안 해요 ?'),
#  ('ive never met a true customer', '<jj> 진상손님은 만난 적 어신디 그냥'),
#  ('no leaves .', '<kw> 잎사구도 있지 않고'),
#  ('so so the more you go to school and go outside',
#   '<jd> 근 그니까 그니까 이제 학교를 다니고 밖으로 나다닐수록'),
#  ('oh my god . why are you here already ?', '<kw> 어머 이름 아 왜서 발싸 와 ?'),
#  ('about three years ago i moved to an expansion and i want to raise a little student',
#   '<gs> 한 삼 년쯤 됐을 때 확장 이전을 해서 나도 쫌 제자도 키우고 싶고'),
#  ('feel like you re left alone in this dark cold classroom .',
#   '<kw> 이 어둡고 차가운 교실에 혼재 버려진 기분 한 번 느껴보라고 .'),
#  ('mr . fisher are you listening ?',
#   '<kw> 그의 제안에 동의하십니까 ? 피셔 씨 저기요 피셔 씨 듣고 기서요 ?'),
#  ('oh like my grandfather .', '<jj> 어 하르방처럼 나와부난'),
#  ('if you do that thing over there you ll do it again and then you ll do it again .',
#   '<jd> 물건 저기 하면은 또 인제 하고 그랬으면서'),
#  ('so wow but it was a little amazing that i had no choice but to do well when i did something like that in the military',
#   '<gs> 그래서 와 그래도 군대에서 그런 거 하면은 당연히 잘할 수밖에 없다 하는 게 쫌 신기하기도 했고'),
#  ('why are you so scared ?', '<kw> 내 자취방 이을대 뇌쇄적인 거 보여줘야죠 왜요 겁나요 ?'),
#  ('i did that but im particularly', '<jj> 거 해신디 나는 유독'),
#  ('anyway while i was lying there sick', '<jd> 암튼 나는 아파가지고 누워 있다가도'),
#  ('well they re coming with us now aren t they ?',
#   '<jd> 뭐 직원들이 인자 같이 갔을 거 아니여'),
#  ('i mean i ve heard it really hard but . . .', '<jj> 진짜 열심히 들언 근데'),
#  ('i was going to take care of it but i couldnt but it was because of the kid',
#   '<jd> 챙길라고 했는데 못 챙겨가지고 했는데 애가'),
#  ('i don t know what s wrong with you but i ll call him .',
#   '<kw> 뭐야 마음이 심란한데 해팔 내가 불러내'),
#  ('you even had your eyes in it right', '<jj> 그 속에 눈 다 들어가 불었을 거 아니 ?'),
#  ('so i hum at home but i cant go there', '<jd> 그래서 난 집에서 흥얼흥얼 하는데 워낙에 못 가니까'),
#  ('i was so scared of the snow .', '<jd> 눈 오는 날이 너무 무서워 근데'),
#  ('i think im having a little fun', '<gs> 또 재밌게 쫌 하게 되는 거 같애요 .'),
#  ('so are you hurt', '<kw> 그래서 다쳤나 ?'),
#  ('there are a lot of people who are similar to the actors there',
#   '<gs> 거기에 나오는 배우들도 쫌 비슷한 똑같은 사람이 많이 나오고'),
#  ('i hope i find a new hobby like resin art like you',
#   '<cc> 나도 너처럼 쫌 레진 아트처럼 새로운 취미를 찾았으면 좋겠다 .'),
#  ('maybe time has passed a little bit .', '<jd> 아마 시간이 또 지나가지고 내용이 쫌'),
#  ('honey stop it .', '<kw> 여보 고마해 .'),
#  ('aren t we actually a little far from that ?',
#   '<jd> 우리는 사실 그런 거 쪼끔 멀지 않니 ?'),
#  ('manizer was korean .', '<kw> 이름매니저가 한국 사램인지 몰랐습니다 .'),
#  ('when we were young what kind of people live in such a house',
#   '<jj> 우리 두린 때 그거 보멍 어떤 사람은 저런 집에 사는고'),
#  ('the lights don t turn on the lights light up which is why they re so beautiful but they re so beautiful .',
#   '<jd> 불이 안 켜도 불이 환해 그리가꼬 진짜 아름답더만 멋있더만'),
#  ('its one of the three world festivals',
#   '<gs> 그기 그기 막 삼 대 세계 삼 대 축제 중의 하나라는데'),
#  ('if i can study again its okay to work hard again',
#   '<jd> 다시 공부를 할 수 있으면은 또 열심히 하는 것도 나는 괜찮다고 생가가는 게'),
#  ('we are using this two rooms and a kitchen', '<jj> 이것 방 두 개랑 부엌 행 우리 쓰고 있지'),
#  ('i don t drink very well these days because of the arrhythmias but i m older .',
#   '<jj> 요즘에는 부정맥 때문에 잘 안 마시긴 하는디 나이가 있어가지고'),
#  ('some people accept it like this because i think its because of your personality problems',
#   '<gs> 되게 니 성격 문제 있어서 그런 거 같애 이러 이렇게 받아들여지는 경우도 있더라고요 .'),
#  ('i think my mom bought a lot of things like that',
#   '<jj> 우리 엄마 뭐 그런 거 많이 샀던 거 닮아 .'),
#  ('i was surprised by the feast xx i saw it in the morning and saw it let me know',
#   '<jj> 잔치 xx 놀래 자빠져부런 나 아니 아침에 보당보난 보다가 보니까 이'),
#  ('it s a wild rabbit isn t it ?', '<kw> 암퇴끼가 사납네 ?'),
#  ('wow youve been there a lot', '<jj> 와 많이 하영 갔구나'),
#  ('but i hope there was a veranda like that that shines well in the apartment',
#   '<jj> 아파트 근데 아파트에 막 쫌 햇빛 잘 드는 그런 베란다 같은 거 있었음 좋겐 .'),
#  ('wheres a little bit of pork and won',
#   '<gs> 세상에 돼지고기 한 쫌 한 덩거리 오천 원짜리가 어딨노'),
#  ('i only thought i should save a little money and get married now',
#   '<gs> 뭐 돈을 쫌 모아서 이제 결혼을 해야 되겠다 이런 생각밖에 없었기 때문에'),
#  ('i feel like i m looking all over the place without my eyes in one place .',
#   '<jd> 이케 눈을 한곳에 안 두고 막 사방 군데를 다 보는 거 같애 .'),
#  ('god listens to our title over there and the rest are all of that office worker',
#   '<jd> 하나님이 우리 이름 만 저그 들어주시고 나머지기는 다 저 그 회사원인디'),
#  ('i received it in cash when i was working', '<jj> 나는 일할 때 현금으로받아난예'),
#  ('he d say what did i do to give you a little something like this ?',
#   '<cc> 뭔 이렇게 쬐끔한 거를 하나씩 주냐고 했을 거요 다 내가 오빠들 왔을 때 그'),
#  ('the doctor called me later .', '<jj> 게 나중에 의사가 불렁게'),
#  ('the streets were snowed centimeters .', '<kw> 거리에 누이 오십 센티미터 쌔여 있었어 .'),
#  ('stop talking shit .', '<kw> 쥐뿔같은 소래기 그만둬라 .'),
#  ('so everything is luxury goods makers or brands',
#   '<jd> 긍께 다 뭐 명품이든 메이커든 뭐 브랜드든'),
#  ('i remember playing really hard when i was in middle school .',
#   '<jd> 쫌 중학교 때는 엄청 열심히 놀았던 그런 기억이 있네요 .'),
#  ('yeah ill stop coming', '<jj> 어 오지말랑 난'),
#  (None, '<jj> 야 좀을 그추룩 잘 자불어'),
#  ('the project is going well .', '<kw> 그 프로젝트는 잘되어 가고 있사 .'),
#  ('it s gonna be harder to go to extreme diets .',
#   '<jd> 다이어트를 극단적으로 하면은 더 힘들 것 같어 .'),
#  ('there should be a seat or something like that but my husband has a seat in it so im like this person',
#   '<jd> 그런 어 좌수나 뭐가 있어야 되는데 제 남편은 그게 좌수가 들어있는 거예요 그니까 나는 이 사람이'),
#  ('do you like spicy stirfried chicken or spicy buckwheat noodles a little bit',
#   '<kw> 너도 혹시 그러면은 닭갈비나 막 막국수 같은 그런 음식들을 쫌 좋아하는 편이야 ?'),
#  ('is it still a good idea that he left the baby ?',
#   '<kw> 그자석은 성아 떠났다고 그렇게 진상을 떨어놓고 여전히 좋은건가 ?'),
#  ('then i used to like rice i really liked carbohydrates i ate well just by eating rice and kimchi',
#   '<jd> 그면 예전에 내가 엄청 밥을 좋아했잖아 탄수화물 엄청 좋아했잖아 밥하고 김치만 있어도 내가 잘 먹었는데'),
#  ('just hurry up and hurry up and do it', '<jd> 그냥 얼른 성격이 막 글잖아 얼른얼른 해블고 막'),
#  ('it s called the central aru beach . it s a very famous beach .',
#   '<jd> 거기에 탄중아루 비치라고 그 뭐지 그 해변 겁나 유명한'),
#  ('dont call me because ill go in before work',
#   '<kw> 퇴근시간 전에 들어갈 테이까 하고 즌화하지 마 .'),
#  ('but i had something like that im going to ride a sports car later',
#   '<cc> 근데 나는 그런 게 좀 있었어 나는 나중에 스포츠카를 탈 거여 .'),
#  ('why don t you do something stupid and do something right and laugh ?',
#   '<kw> 왜 그런 거 짜질구리한 거 하지 말고 제대로 하나 해라 근데 뭐래 웃지 ?'),
#  ('if you go on a trip you have to eat food you die if you dont eat korean food for a week',
#   '<jj> 여행 가면 놈이나라 음식을 먹어서사지 우리나라 음식을 한 일주일 안먹으면 죽어져이 그나라 음식 먹엉 배탈도 나고'),
#  ('its a really good hobby', '<gs> 정말 좋은 치미 생활이죠 .'),
#  ('since then you ve been living in hong kong with a little a little bit of force and a little distance .',
#   '<jd> 그때 이후로 으 그 쫌 야 약간 강동원이랑 거리를 두면서 홍콩에서 지내게 돼 .'),
#  ('i asked one more time but i didnt answer', '<jj> 한 번 더 물어봤는데 대답안핸 .'),
#  ('also i think there will be a lot of changes in the good aspects and disadvantages',
#   '<gs> 또 좋은 면이나 단점이나 하는 게 쫌 많이 앞으로도 바뀔 거 같애요 .'),
#  ('oh i think its weird so i just do it and habitually put the padded jacket in my outerwear',
#   '<cc> 아 그러니까 저 이상한 거 같애요 아 긍까 그냥 하고서 습관적으로 그냥 저는 패딩 그냥 겉옷에 넣거든요 .'),
#  ('if you treat it that way i don t think i m going to get married either .',
#   '<kw> 이름 그렁이 식으로 다루시면 저도 겔혼 생각 안할 겁니다 .'),
#  ('she said she got it so once you got it on your phone you got it .',
#   '<gs> 징계 아 그 받았다 하니 긍까 니가 휴대폰 관련돼서 한 번 징계 같은 거 받은 적 있는데'),
#  ('a small guy eats a lot', '<jd> 쪼꼬만 한 놈이 엄청나게 먹어 대 .'),
#  ('you look weird .', '<jj> 이상해봬다 해네'),
#  ('itll be absolutely necessary so i have one person with yangjae i have two persons with yangjae',
#   '<jj> 꼭 있어야 되는 뭐라 그럼 양재를 한 명돌안 두명돌안'),
#  ('perhaps something like that', '<jd> 혹시 너는 뭐 그런 어떤'),
#  ('long term conflict barely ended .', '<kw> 오랫동안의 분쟁이 제우 그쳤어 .'),
#  ('you get a little cold you get a lot of colds you get a lot of cold pills .',
#   '<jd> 쫌 먹고 감기 워낙 많이 걸리니까 감기약 자주 먹고'),
#  ('get out of the way .', '<kw> 돌 뿌리를 잘 비케 가세요 .'),
#  ('there were people who came over at night just to get drunk .',
#   '<jj> 경 하난이 야간에 막 술 퍼먹엉 왕으네 진상 부리는 사람들도 이서나서'),
#  ('honey can i not leave the department store tomorrow ?',
#   '<kw> 여보 나 내리부터 백화점 안 나가면 안되겠나 ?'),
#  ('my face is so big that i look a little fleshy on my face and everything looks fleshy on my face from then on',
#   '<jd> 얼굴이 빵빵하 하니까 그때부터 약간 내 얼굴에 살집 있고 내 모든 게 다 살집있어 보이는 거여 그래가 내가'),
#  ('theres a time when i have time to spare thats only a few days all day',
#   '<gs> 정말 쫌 내가 여유가 됐을 때 있잖아 시간적 여유 지금은 그거만 하루 종일 며칠 안 되거든 .'),
#  ('i ll be back .', '<kw> 댕겨 오겠습니다 .'),
#  ('it s what it is isn t it ?', '<kw> 그대로지 그제 ?'),
#  ('they re hanging around like pigeons .', '<kw> 비덜기마냥 둘이 꾸꾸거리구 있다가 .'),
#  ('there are so many things like time stirring or not to knead a lot',
#   '<cc> 딱 시간이라던지 뭐 젓는 쎄기라던지 많이 반죽하면 또 안 되고 이런 것들이 너무 많아서'),
#  ('if she calls you', '<jj> 가이가 이녁 불러지민'),
#  ('i went there because i had a sex education class',
#   '<jj> 저기 성교육 수업이 이성으네 가신디양'),
#  ('theres a player named anteto kumbo so this person is now',
#   '<cc> 안테토 쿰보라는 선수가 있거든 그니까 이 사람이 지금'),
#  ('no i went around like this', '<kw> 아니 내가 다니민서 요렁이'),
#  ('it s not often but i think i ve done it a little bit .',
#   '<jd> 자주는 아니지만 그래도 좀 했던 것 같기는 해 .'),
#  ('i understand what they re doing but they ll think differently .',
#   '<jj> 이해한다 뭐한다 해신디 걔네들 생각도 다를 거라 기지'),
#  ('oh its a little different i thought thats not right',
#   '<cc> 아 쫌 다르구나 약간 그거는 뭐 안 맞구나라고 생각을 했었었고'),
#  ('the gums and tongue to touch the teeth like this',
#   '<cc> 이 잇몸이 그리고 이케 혀로 이를 이케 이케 만져주래 .'),
#  ('hey i went to the company name and now it s it s famous .',
#   '<jj> 야야 나 company name 가봐신디 이 거기는 이제 유명해져 부런 ?'),
#  ('theres nothing to be devastated but youre not working right now so if you work later youre busy and can afford it',
#   '<jd> 피폐하지 하는 거 없고 아니 근데 지금은 니가 뭐 일 안 하고 있으니까 나중에 일하면은 바빠가꼬 또 여유가 있을'),
#  ('my mom ironed me out and i gave birth to a child',
#   '<gs> 우리 엄마가 다리줘갖고 불임된 거 애도 놓고'),
#  ('i thought it was a fries of colpop', '<jd> 콜팝 그 감자 튀김인 주 알았어 그'),
#  ('don t use a brush . write it as a pen .', '<kw> 붓으로 쓰지 마고 볼펜으로 쓰시오 .'),
#  ('i understand .', '<kw> 마음이 통하다 .'),
#  ('there were many cultural differences in those cultures',
#   '<gs> 쫌 그런 문화들이 문화 차이가 많았는데'),
#  ('that s what i m talking about .', '<gs> 그거라 카더라고 에이아이'),
#  ('i know . i know . i know what it is .', '<jj> 알아 알아 뭔지 알지게'),
#  ('anyway i cant walk back and forth from the warehouse',
#   '<jj> 어찌됐건 저찌됐던 간에 나는 저기 걸어서는 여기 창고랑 왔다 갔다 못하크라 .'),
#  ('after that there are several people following them secretly',
#   '<jd> 그 뒤에는 암암리에 식솔들도 멫 명씩 따라오잖아요 .'),
#  ('you don t have to study harder .', '<kw> 좀 더 불나게 공부하지 않으면 안될거야 .'),
#  ('okay i ll call you .', '<kw> 그래 즌화할게 .'),
#  ('i wope you changed the logo of chevrolet a little bit and its kind of like this',
#   '<gs> 그 쉐보레 로고 진짜 쫌 바깠음 좋겠고 뭐 약간 아 너무 쫌 이케'),
#  ('and they said', '<jj> 겐디 그 똘들이'),
#  ('iveathed others but im somewhat materially comfortable',
#   '<cc> 남한테 피해를 줬지만 내가 뭔가 물질적으로 편안하잖여 .'),
#  ('i cant see well when i just do it so if i boil it i can see it better',
#   '<jd> 기냥 했을 땐 잘 안 보여 긍까 삶으믄 오히려 더 잘 보여 삶으면은'),
#  ('so green onions are a little okay these days', '<gs> 이렇게 해서 요즘은 파래가 쫌 괜찮고'),
#  ('dude i m suddenly in a state of need .', '<kw> 형 나 갑자키 승부욕이 발동하는데 .'),
#  ('what s wrong with you girl ?', '<kw> 왜 그래 기집애야 증말 .'),
#  ('i didn t do it today . i did it last night and i ve been doing it for a couple of days .',
#   '<jj> 오늘은 또 어떵 안해 어제 저녁에 좀 경하고 한 요 며칠'),
#  ('but it was good to use', '<jj> 근데 쓰난 좋긴 하더라 .'),
#  ('now i ve heard a lot of it .', '<kw> 이제 마이 들었고'),
#  ('hey but did you have a cell phone then', '<jj> 야 근데 그때 너 핸드폰이라는 게 있언 ?'),
#  ('it s not that bad .', '<jj> 경 궂지 않애여 .'),
#  ('theres that too dance academy is a bit pricey',
#   '<gs> 또 그것도 있어 댄스학원은 좀 가격이 또 쎄니까'),
#  (None, '<kw> 됐고 이 옷은 뭐고 갑자키 왜 피부관리를 하는건데 ?'),
#  ('but then you said you weren t pretty .', '<gs> 근데 니가 그때 안 이쁘다 그랬었어 .'),
#  ('my husband is a little more delicate than the seed and so on and so forth .',
#   '<jd> 아 아쉽게도 아 제 남편은 씨처럼 약간 섬세하고 그런 이케'),
#  ('i middlemade her to say no', '<jj> 안고르게 했수다'),
#  ('that s why i m able to live in unity so to be honest i m going to live in unity .',
#   '<jd> 그래서 나는 컴활은 딸 수 있응게 솔직히 바로 컴활은 딸 거고'),
#  ('i have to keep going . is it gonna be okay if i keep going ?',
#   '<jj> 자꾸 가 봐사 되는데이 자꾸 가믄 잘 될 건가 ?'),
#  ('you ve never done this before .', '<kw> 생즌에 이딴 적이 없잖어 이름애미'),
#  ('other rappers used to like swings a long time ago',
#   '<gs> 따른 래퍼들도 진짜 아주 옛날에는 그 스윙스 좋아했었고'),
#  ('thats how he did it', '<jj> 겅 허드라고 .'),
#  ('i thasked if there was almost nothing if i had eaten or if there was nothing if i didnt fall off',
#   '<gs> 밥 먹었나 거의 묵음이 있다 아이가 했나 했나 떨어진다 아이가 이게'),
#  ('five four three two one zero .', '<kw> 다섯 넷 셋 둘 하네기 제로 발사'),
#  ('okay i ll see you later .', '<kw> 알았어 그럼 냉중에 봐요 .'),
#  ('didn t she just like you ?', '<kw> 처레미 어니 혼재 좋아했던 거 아니에요 ?'),
#  ('if you go there there are people who catch the meat on the ice',
#   '<jj> 행강보민 해서 가보면 그듸 얼음에 그 고기 낚으는 사람도 있곡'),
#  ('that s right . she s totally sad when she s three .',
#   '<kw> 그렇지 세 살이면 완저이 애안데 .'),
#  ('so this is just', '<gs> 그니까 이게 그냥'),
#  ('unlike the essence of the webtoon its a little bit',
#   '<cc> 웹툰에 뭐 본질과는 다르게 약간 쫌'),
#  ('is it supposed to be for the purpose or is there something like that',
#   '<gs> 뭐 목적이라 그래야 되나 그런 게 쫌 있으신가요 ?'),
#  ('wakat up what i should do now and then quickly this covid',
#   '<cc> 내가 지금 어떻게 해야 할 것인가를 얼렁들 깨어나서 그러고 또 얼른 이 코로나가'),
#  ('if he s a pastor right now he s worse than him .',
#   '<jd> 그놈이 지금 목사 생활하고 있으면 그 이만희보다 더 나쁜놈이여 그놈은'),
#  ('are you okay ?', '<kw> 어데 아프시다면서요 괜찮으세요 ?'),
#  ('but the one you mentioned earlier is the university club',
#   '<gs> 근데 아까 니가 말했던 그 엔대 동아리'),
#  ('i havent decided yet please wait a moment',
#   '<kw> 상구 결정을 못 했어 장깐 기다려 주세요 .'),
#  ('just a little bit and if you don t get caught just close your eyes and pretend you don t .',
#   '<jd> 약간 이제 한 만약에 걸리게 되면 안 걸린 애들은 그냥 그냥 눈 감고 모른척을 해불자'),
#  ('i mean i talk about money every day and it s a little rough .',
#   '<gs> 매일 돈 얘기만 해서 쫌 팍팍하긴 한데'),
#  ('why do you ask for a gift ?', '<kw> 왜 선물받은것을 미루니 ?'),
#  ('just a little bit .', '<cc> 그때 쫌 막 약간'),
#  ('im going around to take care of the elderly',
#   '<cc> 내가 이렇게 어르신들 지금 다섯 명 이렇게 이케 케어하러 대니려면서'),
#  ('they re just gonna have to open up the hospital later .',
#   '<kw> 냉중에 벵원 개업만 시켜주면 된대 그짝에서 .'),
#  ('with a smile on the site have you tried yoga', '<jj> 웃음 넌 요가해 봔 ?'),
#  ('i hid the daughterinlaw and hated the daughterinlaw',
#   '<jj> 막 허멍 며느리도 며느리는 막 미워 가지고'),
#  ('it s very very very depressing these days .', '<jd> 요즘에 정말 우울증이 아주'),
#  ('i couldnt tell you about my employment with that document',
#   '<kw> 제가 그 서류로 취직 했다곤 도제 말씀 드릴 수가 없었습니다 .'),
#  ('and why are you only asking for one of them with a yearold title',
#   '<kw> 그래구 왜 이름 씨 한테만 존댈하고 그래 ?'),
#  ('but my sister s too big for a cat .',
#   '<kw> 근데 우리 동상이 인자 커가지고는 고양이가 너무 예쁜가봐'),
#  ('the arm is naturally put down under the knee .',
#   '<kw> 팔은 자연스럽게 내려저 무릎고벵이 밑에 둔다 .'),
#  ('i ll take care of it .', '<kw> 내가 알아서 할 테이까 이름 씬 가마니 있어요 .'),
#  ('it s like you re a squeamish mom again .', '<jd> 또 엄마가 까탈스럽자네 . 웃음'),
#  ('so i have conditions for this too', '<cc> 그래서 이렇게 나도 지금 이게 조건도 있단 말이여 .'),
#  ('i don t think it s going to grow any more cause i m saying it s eating a little less and it s going to grow a little less .',
#   '<gs> 쫌 적게 먹을라고 늘어간다고 하기 때문에 뭐 더 이상 안 늘 거 같아'),
#  ('i m going to study in windows today . quiet man .',
#   '<kw> 오놀은 윈도우에서 대해서 공부하겠다 조용해 임마 .'),
#  ('well that s too much . is there any more to it ?',
#   '<kw> 그건 너머 야하군요 언원이 수수한 것은 없어요 ?'),
#  ('oh the old grandmothers said that the world is done the world is done it seems like the world is done by doing it',
#   '<jj> 아니 옛날 할망들 말론 시상 다 됨져 시상 다 됨져 해 해난에 시상 다 되는 거 닮댄'),
#  ('why did you ask me to pay like that so i just said yes yes',
#   '<jd> 뭐 이르케 뭐 그렇게 해서 지불해달라길래 아 네 그냥 네 그러니까'),
#  ('i assess it but it was also when i was very young so i wasnt in my s',
#   '<jj> 검침을 허는데 그때도 역시 그때 한참 젊을 때니까 뭐 삼십 대도 안 할 때지'),
#  ('should we do this many these days kids', '<kw> 이르케 많다 해야 되나 요즘 애들은 그리구'),
#  ('i ve never seen anyone who can t be like my brother .',
#   '<kw> 내 우리 성님같이 못하는 사람은 보다가 츰이네요 .'),
#  ('its from samsung so', '<jd> 그 그것이 삼성에서 나왔드 나왔더구만 그래 가지고'),
#  ('uh it s a little rough it s got a lot of new designs .',
#   '<jd> 어 디자인이 좀 꾸지고 새로운 디자인도 많고'),
#  ('it s all winter so i m wearing a coat .', '<kw> 죄다 겨울이라고 코트를 입었어 .'),
#  ('its a combination of the military', '<jj> 군이 다 합쳐져븐 거쥬게 .'),
#  ('you re the one who says it s gonna be a little better if we change this part too .',
#   '<jd> 잘 바꼈다 이런 부분도 쫌 바꾸면은 쫌 더 괜찮을 거 같애라고 이렇게 말해 주시는 형님이거든 .'),
#  ('sit down .', '<kw> 거게 앉아 봐 .'),
#  ('let s do it on days .', '<jj> 어 십 이 일 날은 회 먹게 .'),
#  ('what does the cold brew feel like', '<jj> 콜드브루가 어떤 느낌이냐면이'),
#  ('yeah you must be tired . i m just driving a cab .',
#   '<kw> 예 피고하겠어요 그냥 택시 타구 와두 되는데'),
#  ('its energy to spring up while eating the food at home the two of me and my name father',
#   '<cc> 기운이 샘솟는 거야 그 음식을 그릏게 그냥 집에 있는 음식을 먹으면서 이름아빠랑 둘이'),
#  ('you have to put the card in here so you dont know if you have to put it over there',
#   '<jd> 카드를 여따 꽂아야 돼 저따 꽂아야 되는 지 모르시고'),
#  ('i wrote too well .', '<kw> 너머 잘 썼어 .'),
#  ('you daehyeop is over or so but he is so tall',
#   '<jd> 한 팔 정도 되는데 윤대협은 백구십이 넘는 그런 장신이자네 ? 그래가지구'),
#  ('but im still fortunate this for no reason', '<jj> 근데 그래도 천만다행이라 . 괜히 이것도'),
#  ('you re watching . if you suddenly find something like that it ll cool off immediately .',
#   '<gs> 잘 보고 있다 갑자기 그런 거 나오면 몰입감 바로 식어버림 .'),
#  ('then i ll be noticed by people a little later and i ll be frustrated .',
#   '<cc> 그러면은 나는 나두 쫌 뒤에 사람한테 눈치 보이고 답답하고 그려 .'),
#  ('that s what s next when you tell me you re coming with you all at once .',
#   '<jj> 그게 나중에 또 한꺼번에 한번에 같이 온다매 그다음꺼'),
#  ('you were totally cutie', '<jj> 완전 앵겻인디 .'),
#  ('maybe the average high school in seoul went down because of us .',
#   '<kw> 아매 서울시내 중고등학고 전체 펭군 성적이 우리 때미에 떨어졌을걸요 .'),
#  ('it s a good day to get out of here .', '<kw> 할로라도 빨리그 빨라당 가는 게 좋단 말이야'),
#  ('yeah well i went to the anus and then i stopped by the house and said',
#   '<kw> 그래 가주고 내가 뭐 항문내과다 이빈후과다 갔다가 뭐 집에 잠깐 들려서'),
#  ('this vibration comes right away and in the case of drawing text messages or kakaotalk it contacts you right away',
#   '<cc> 이케 진동이 바로 오고 그리구 문자나 뭐 카카오톡 같은 경우도 오면은 바로 연락이 오기 때문에'),
#  ('so i thought it was a pig i saw it a long time ago',
#   '<jj> 경허난 도새기겠지 옛날에 한번 봐신디 .'),
#  ('yeah i m here and this is a credit card receipt .',
#   '<kw> 네 여그 있어요 . 고라고 이건 신용 카드 영수증이에요 .'),
#  ('either way we don t have any money .', '<jj> 어느거 하나가 되면은 돈이 없어 .'),
#  ('i think its a little bit seasoned because you drink prickly',
#   '<jd> 술을 쪼끔 드시는 편이셔서 간이 쫌 그런 것 같애요 .'),
#  ('he would have slept on the bus then', '<jj> 야이 그때 뻐스에서 잠자실꺼라 야이는'),
#  ('teach me how to go to the tourist center .',
#   '<kw> 관광안내소에 가는 길을 가르체 주시오야 .'),
#  ('now ill do it because i helped you with the right performance',
#   '<jj> 이제 곹이행 도와줭 해사주'),
#  ('i think its okay ill look for a lot of laughter and take it out',
#   '<gs> 괜찮은 거 같애요 저도 웃음 함 찾아봐 가주고 들고 나가야겠네요'),
#  ('there is nothing i really got from it nothing i lost',
#   '<jj> 거기서 진짜 얻은 것도 없고 잃은 것도 언'),
#  ('i think its good to just match it right so i dont have to have it i might have been born without it but i dont think its good',
#   '<gs> 걍 적당히 두루두루 맞춰주면 좋다고 생각하기 때문에 굳이 내가 그거를 가지고 있을 필요는 없다 아이가 내가 안 가지고 태어났을 수도 있는데 그 성격을'),
#  ('it s better to eat less salty soup .', '<jd> 짠 국물은 적게 먹는 것이 좋은디'),
#  ('go ahead and sit here', '<kw> 어서 요기 앉어요 .'),
#  ('who s gonna buy it ?', '<kw> 살 사램 ?'),
#  ('i was going to try and make sure i didn t but they gave me a little bit of money .',
#   '<jj> 어 그런 것 닮기도 하고 아닌 것 닮기도 하고 해보카 했는데 약간 돈을 준다고 하니까 웃음'),
#  ('and then he says it s ridiculous and he just says it s too expensive for million dollars .',
#   '<jd> 그랬더니 아빠가 말도 안 된 소리 한다고 글고 이십 평이 오천만 원이면 너무 비싸다고 막 그러는 거야 .'),
#  ('what s your next week s schedule ?', '<kw> 다음 주 일정이 어타 되십니까 ?'),
#  ('so you re bigger than that .', '<jj> 그니까 너 그것보다 더 굽언 .'),
#  ('i explained it for a long time and youre hungry is there anyone who wants lunch today',
#   '<kw> 한참 설명을 했더니 배가 고프 네 오놀 점슴 쏠 사램 없나 ?'),
#  ('you put two legal laws together and your granddaughter is in the middle of an international country where it s hard .',
#   '<kw> 법무법인 두 개나 합병 하시구 손녀는 또 그 어렵다는 국제중에 들어가구'),
#  ('don t you think it s really good when you put that in and you do this stuff ?',
#   '<gs> 그 정구지 넣어가지고 막 부추전 이런 것도 해먹으면 진짜 맛있다 아이가'),
#  ('when i dont think about how good it would be if i come',
#   '<jd> 오면 얼마나 좋을까 그런 생각이 쫌 잠 안 올때는'),
#  ('and on the bucket list .', '<kw> 그래고 버킷 리스트로'),
#  ('did you know what the korean teacher said', '<gs> 그 국어 선생님이 뭐라 했는지 아나 ?'),
#  ('where do you check ?', '<kw> 어데서 체크인 합니까 ?'),
#  ('i ate the meat and the kids gathered together to play card games and it was really fun then',
#   '<jd> 그 고기 꾸어 먹고 애들이랑 막 다같이 모여가지고 카드 게임하고 진짜 재밌었어 그때는'),
#  ('then we have to engage a lot now so were going to the growing jungle and the ap jungle',
#   '<jd> 그믄 이제 교전을 많이 해야 되는데 성장형 정글 에이피형 정글로 간다 ?'),
#  ('now im reflecting on myself', '<jj> 게이제 완전 죽게 반성햄쭈게'),
#  ('oh thats right then ill too', '<jj> 아 기꽈마씸 ? 그럼 나도'),
#  ('once upon a time there was a pig bank .', '<jj> 옛날엔이 그 전화 돼지 저금통도 이서나신디'),
#  ('im not standing up if the kid pulls the queue to go i wont look at me',
#   '<jd> 딱 서는 거야 안 가고 그 꼬맹이가 가자고 막 줄을 잡아댕겨도 안 가 나만 쳐다보고'),
#  ('i dont like things like that', '<kw> 그런 거는 벨로 안 좋아하는 편이고'),
#  ('you just have to wrap it up a little bit .', '<kw> 걸충 마무리만 하면 됩니다 .'),
#  ('like youre doing things like that you know what to do now do you have things like this',
#   '<jd> 막 하는 것처럼 막 그런 막 니가 지금 뭘 하면 되는 줄 알아 이런 거 있지 ?'),
#  ('we re not going far .', '<jj> 우린 막 멀리도 안 가곡게에'),
#  ('but after i made it i dried it out but yours is okay',
#   '<cc> 근데 막상 다 만들고 나서 이거를 말련 말려 놨는디 언니꺼는 괜찮은디'),
#  ('i should ve known where i was going to be a maid .',
#   '<kw> 나도 어데 가정부 짜리나 알아볼 걸 그랬나 ?'),
#  ('i thought about the looking child while watching it',
#   '<jj> 뜬 아이구나 막 생각 들었수다 그거 보멍 .'),
#  ('the boss called me in person .', '<kw> 사장님께서 제게 직접 즌화 주셨는데'),
#  ('since i did that for about a month or two this loses a lot of weight',
#   '<cc> 그렇게 해가지고 한 한두 달 정도 하다 보니까 이것도 은근히 쫌 되게 살이 많이 빠지고'),
#  ('and when i saw a movie on the night of the night', '<kw> 그래고 심야영화를 보고 오는'),
#  ('then again physical education class and physical education class',
#   '<jj> 겅허연 또 체육시간 행 체육시간 해서'),
#  ('if you learn how to do your own knowhow to be honest its too natural to say its knowhow',
#   '<cc> 일 터득하는데 본인만의 노하우라 하면은 솔직히 말하면은 노하우라고 하기도 뭐한 디 너무 당연한 거라서 .'),
#  ('it s delicious mom .', '<kw> 깍디기가 익어야 맛나잖아요 엄마 .'),
#  ('im tired and thirsty to speak', '<jj> 말 곧당 보니까 지치고 목도 마르고'),
#  ('i wanted to try it so i looked for it a little bit',
#   '<gs> 어 나도 그게 쫌 근데 해 보고 싶어서 쫌 생 많이 쫌 찾아보고 했거든'),
#  ('ac so i tried writing my brotherinlaw', '<jj> 에이씨 그래가지고 형부도 써보난'),
#  ('but now i had a gene that was handsome tall and kind of good but my legs were cut off because of an accident',
#   '<jd> 근데 인제 잘생기고 키도 크고 약간 좀 좋은 그런 유전자를 가지고 있었는데 사고 때문에 다리가 짤렸어요 두 다리가'),
#  ('what do you say ?', '<kw> 엉이 하실래요 ? 어떠세요 ?'),
#  ('what should i say there are foods that crave when youre on a diet',
#   '<gs> 약간 뭐라 해야 돼 다이어트할 때 그런 거 막 땡기는 음식들 있거든 .'),
#  ('youre not just saying as you say your mouth is bursting do you pay for your age',
#   '<jj> 그예 터진 입이랜 골아진양 막 곧는거 아니 언니 나이값 헙써'),
#  ('the mulberry is popping out its pretty right', '<jj> 뽕 튀어나와 인 . 예쁜 거지 .'),
#  ('what do you want to eat ?', '<kw> 자게는 무얼 먹고 싶어 ?'),
#  ('and now i m pretty good at it .', '<jj> 이제 막 해신디 그래갖고'),
#  ('but i remember enjoying it a little bit because i liked everything',
#   '<cc> 근데 다 좋아해가지고 쫌 재밌게 봤던 기억이 있습니다 .'),
#  ('you know when people saw this they were just like',
#   '<jd> 이것도 남들이 봤을 때는 한 인제 와서 막 이러던데'),
#  ('anyway i was stuck so i thought i blocked it and kicked him out of my life but im still',
#   '<gs> 어쨌든 그 쫑 났다 그래서 차단하고 내 인생에서 쪼까냈다 싶은데 아직도 지금'),
#  ('or was there anything difficult or something like that you were so old or something',
#   '<gs> 아님 뭐 어려웠던 거나 그런 거 없었나 니 뭐 나이 많아서 어려웠다든지 뭐'),
#  ('so if you bring that kind of fussages', '<jd> 그러니까 그런 푸징가리를 가지고 오면'),
#  ('when i caught him like this or whatever he seemed so nice .',
#   '<kw> 이랬던 저랬던 무조근 잡아 보이까 사램 참 착해 보이더라 .'),
#  ('oh but they say its hard to fit my aptitude',
#   '<kw> 아유 근데 뭐 그것도 언니 지 적성에 맞아야 된데이 야들 힘들대'),
#  ('blew shirts and the ballpointen debris on blouses are removed by rubbing them with waterfare .',
#   '<kw> 와이셔츠나 블라우스에 묻은 볼펜 찌끄레기는 물파스로 슥슥 문질러주면 없어진다 .'),
#  ('imired that i wont even wear a coat in winter because of my lover who is in a cold place',
#   '<kw> 추운 데 있는 연인 때미에 겨실에 코트조차 안 입겠다고 우기민서 살고 있는'),
#  ('what the hell was that eye ?', '<kw> 허 망금 그 눈 뭐야 ?'),
#  (None, '<jj> 내려가는데 요새는 중앙에 이게 뭐라 그러지 중앙 분리하는 거 이렇게 말뚝 박아 놓은 거 너무 많이 해 가지고이'),
#  ('so i dont like shopping a little', '<cc> 그래 가주구 제가 쪼꼼 쇼핑을 좋아하진 않는데'),
#  ('in the end he tentatively dropped out and he communicated with him but is it still coming out',
#   '<jd> 결국에는 잠정 하차 그 의사 전달을 했다고는 하는디 아직도 나오나 ?'),
#  ('so i dont have anything special', '<jd> 그서 나는 특별히 뭘 하다기보다는'),
#  ('there was a book that i wanted to read a little bit',
#   '<gs> 내가 쫌 평소에 읽고 싶었던 책이 있었는데'),
#  ('i can t speak right now .', '<jd> 지금 말은 입으로 못 밴디'),
#  ('because in jejudo you have to have one of those shirts .',
#   '<kw> 제주도에선 그른 셔츠 하내기는 있어줘야거든요 .'),
#  ('i hate you .', '<kw> 니가 싫어서 .'),
#  ('where are you going ?', '<kw> 에이 어데가와 ?'),
#  ('and then the baby gets brighter and then you have your little time and just like you have time so i m over time and then they burst apart .',
#   '<cc> 그러면서 애도 밝아지니까 그 네 쪼금 시간이 남죠 언니도 이케 시간이 남듯이 저도 시간이 넘는 거예요 근데 그때 터진 거예요 서로'),
#  ('and that michael jordan you mentioned earlier you re not doing it at netflix .',
#   '<jd> 그리고 아까 니가 말한 그 마이클 조던 있자너 거 넷플릭스에서 하는 거 아니여 .'),
#  ('no i always did it without saying it', '<jj> 아니더라 맨날 지멋대로 하던디 ?'),
#  ('don t get upset about her . we can just go . let s go .',
#   '<kw> 누우 속상해 하지 마 그냥 가면 되잖아 가자구 .'),
#  ('grandma i m sorry .', '<kw> 할어머이 죄송해요 .'),
#  ('don t you think that s the only way to buy a lottery ticket ?',
#   '<jj> 야 이정도면 복권을 사야되는거 아니 ? 수상한데 꿈내용이'),
#  ('then if i get a statue i dont have to serve in the military anymore',
#   '<jj> 그럼 동상 걸리면 이제 군 생활 안해도 되는거 ?'),
#  ('i think its a little exaggerated', '<cc> 쫌 과장되게 표현된 거라고 생각을 하는데'),
#  ('yeah i actually like it yeo movies especially art so like you said',
#   '<cc> 아 나는 사실 좋아하는 여 영화 특히 예술은 그까 너가 말한 것처럼'),
#  ('oh my god i didn t just broadcast today .', '<kw> 아아아 아 저 오놀 마침 안 방송은 제가'),
#  ('you can say that gian palsa who seems to be a little often on tv is a little like that',
#   '<cc> 이제 뭐 티비로도 쫌 자주 보이시는 그 기안 팔사 님이 약간 그런 그림체라고 해야 되죠 ?'),
#  ('if you re going to ride a car you don t know how to write it and if you re going to ride a few times you re going to count the character .',
#   '<jj> 차 타그네 허젠 허믄 글 몰라그네게 몇 번 타면은 그 글자 그림 세봐그네'),
#  ('you got any snacks ?', '<jj> 먹을 간식은 챙견 ?'),
#  ('and what else did you say there was ?', '<jd> 글고 자네 뭐 또 또 뭐 있다 그랬제 ?'),
#  ('your family raised it really well but your mom said that your mom is like that and other peoples attention is also very important',
#   '<cc> 진짜 엄청 잘 키운 거야 니네 집안은 근데 니네 엄마는 그렇다매 남의 이목도 되게 중요시 한다매'),
#  ('its getting shorter so you have to go and go quickly',
#   '<jj> 해 짧아져 불고 하니까 얼른 가가지고 가그냉 해야 되잖아 .'),
#  ('look i want you to live here .', '<kw> 나보구 여개서 살라구'),
#  ('i awaited a lot of things like that so if i went to a whole thousand won but i really liked the teacher here',
#   '<cc> 그런 걸 쫌 많이 보고 가요 그래서 만약에 만사천 원짜리를 갔는데 여기 선생님 너무 마음에 들어 .'),
#  ('i ll be back sometime with your chef .', '<kw> 운제 올꺼야 니 쉐프랑 .'),
#  ('if i pick my mother ill just be the head of the table',
#   '<jj> 저 우리 어멍 빼어오믄 그거 그냥 한 대 주주게 .'),
#  ('iveathe ive arranged a special', '<jd> 특집을 마련해 봤당께 .'),
#  ('for example skirt knee exercise and thigh exercise',
#   '<jd> 예를 들면 인제 스커트 무릎 운동 허벅지 운동은'),
#  ('oh then thats enough', '<jj> 아 그러면 게믄 됐수다 .'),
#  (None, '<jj> 희한하다 그 나와있는데 언니 잠깐만 내가 예 그 색깔을 보여줄게 .'),
#  ('i ve had enough of it when i m writing . just get the table out of my mouth .',
#   '<kw> 내가 써빙 할 땐 다 감당했어 잔말 말고 게신 테이블이나 치워 .'),
#  ('there s a lot of kids out there who got hit .', '<jd> 타격대가 짬 찬 애들이 많이 가가꼬'),
#  ('are you gonna say that ?', '<kw> 그 따우 소리기 할 거야 ?'),
#  ('i ve had a very pleasant lunch today since you came out .',
#   '<kw> 자네가 나와서 그런지 오늘 정심은 아주 유쾌했어 .'),
#  ('its been a while since i started in the early stages',
#   '<jd> 인자 초창기에는 초 초기에는 시작한지 얼마 되지 않아 가지고'),
#  ('are you worried i m gonna lose ?', '<kw> 제가 질까봐 극정되나 ?'),
#  ('in the case of damage assessment work of personal insurance the intensity is high',
#   '<jd> 인보험의 손해 사정 업무의 경우 강도가 높은디'),
#  ('it rained during the day and at night it turned snow .',
#   '<kw> 낮에는 비가 오다가이 저녁때에는 눈으로 변했어 .'),
#  ('but what happened to yours ?', '<kw> 갠데 자네의 그근 어떠 됐지 .'),
#  ('i think that s the right thing to do because i m a little timid .',
#   '<jd> 쪼끔 이렇게 소심하다 그래야 되나 그런 부분이 맞는 거 같고 에이형은 쫌'),
#  ('that s why you re telling me everything .', '<jj> 그러니까 나한테 모든 걸 다 말하는 거'),
#  ('who are these people ?', '<kw> 이 사램들 뭐예요 ?'),
#  ('in front of him he s an extrovert and he s doing this .',
#   '<jd> 막 앞에서는 신나는 척 막 외향적인 척 이릏게 하면서도 .'),
#  ('if you win the first place you will get the best excellent and encouragement awards',
#   '<jj> 일등하면 장원급제 최우수 우수 장려상 영 행 줌신디'),
#  ('i think she s coming too slowly .', '<kw> 누우 너머 씩씩하게 오는 거 같애 .'),
#  ('so i just went into my moms room and was shocked',
#   '<gs> 그래가 엄마 방에 그냥 쏙 들어가 버렸어 충격을 먹었는지 .'),
#  ('i gave you half a million dollars .', '<jd> 돈 오십만원줬네'),
#  ('i thought i was gonna die lying .', '<kw> 나 거지뿔하느라 죽는 줄 알았다 .'),
#  ('i can t pretend i didn t know she was in our blood .',
#   '<kw> 인제는 그 애가 우리 핏줄 핏줄이라는 거 알았으이까 모른 척 할 수는 없다 .'),
#  ('that s what we re talking about .', '<jj> 우리도 막 동창들 만나고 겅 하주 그런 얘기를 제일'),
#  ('isnt it natural', '<jd> 당연한 거 아냐 ?'),
#  ('why are you doing that ?', '<kw> 왜서 그러고 있어 이름 가 갖다 주래서 .'),
#  ('so you know what ?', '<jj> 게난 저기 아까 어멍이'),
#  ('i ve been going to the hospital lately because of the stomach but i m busy and i don t have time to go .',
#   '<cc> 저번에 내가 위 때문에 요즘에 계속 병원을 가야 되는데 바뻐서 갈 시간이 없는 거야'),
#  ('i ve been in a general unit and i ve got an audition and i ve been discharged .',
#   '<kw> 요즘 연예병사라는게 없어졌어요 일반부대에 있다가 오디션을 보구 차출되는 거에요 .'),
#  ('i think i can heal a little bit while watching it',
#   '<gs> 보면서 쫌 힐링을 할 수 있는 것 같습니다 .'),
#  ('i should have been suspicious and wary from the beginning .',
#   '<kw> 츰부터 의심하고 경계했어야 했어요 .'),
#  ('the seasoning was a little bit', '<cc> 그 간이 쫌 그때'),
#  ('i don t think it s because of the burial .', '<kw> 뭐 꼭 매장일 때민이 아니래두'),
#  ('good so i barely go and see it even when i dont have time',
#   '<cc> 좋아 가지고 가서 인제 뭐 이르케 시간이 없는 데도 갠신히 가서 보고 오고'),
#  ('im actually a blunt stranger', '<jj> 저도 어정쩡한 세대라예 사실은'),
#  ('i heard you talking to your father and your father .',
#   '<kw> 어버이랑 아버이니랑 아버이니랑 얘기하는 거 들었어 .'),
#  ('i m gonna sell it here and i m gonna bite it all up like this and i m gonna look like it s cotton inside .',
#   '<gs> 막 쇼 쇼파 여기 팔 거는데 이케 다 물어뜯어 가지고 안에 솜 보이고'),
#  ('clean the rooms in the room quickly again', '<jj> 금방금방 객실 청소 또 해여'),
#  (None, '<jd> 우리가 또 굴러도 크게 굴른다고 약간 휴식도 십만원대 정도 주식을 사서 굴린 것이 나을 것 같고요 .'),
# ...
#   '<cc> 내가 집에 있는 어떤 긍까 그거 내가 아침에 먹은 거 뭐 점심에 먹은 거 저녁에 먹은 거를'),
#  ('you re my brother now to be honest .', '<kw> 지굼 오빠한텔 솔직히'),
#  ('i ve just got this many clips on youtube lately .',
#   '<cc> 요즘 막 유튜브에 되게 이케 클립으로 많이 올라오는데'),
#  ('i used to ride along with the guy with whom i was going to come .',
#   '<jj> 이제 같이 서귀포 가시는 분 차 타서 같이 다녔언'),
#  ('what s wrong with you ?', '<kw> 당신 증말 왜서이러나'),
#  ('there s lots of shells on the beach .', '<kw> 불에 가면 조갑지가 많아 .'),
#  ('i ve been patient for a while .', '<kw> 그 동안 무다이도 참았다 .'),
#  ('but theres another kalguksu restaurant called hwangbuja and that place called hwangbuja',
#   '<cc> 근데 그 옆에 황부자라고 또 칼국수집이 있는디 그 황부자라는 데가'),
#  ('im only delivering information unilaterally so i have to reply what is this',
#   '<gs> 내 혼자만 일방적으로 정보전달 하고 있으니까 이 뭐라 답장이 와야 되는데'),
#  ('you said you were getting married again .', '<kw> 니 또 시집간다매 ?'),
#  ('now when youre holding the egg your doppel gang appears and just comes to me',
#   '<gs> 인제 그 알을 들고 있으면 자기 도플갱어가 나타나 가지고 내한테 막'),
#  ('i think i saw it a little differently', '<gs> 막 그거는 쫌 다르게 봤던 것 같애요 그리고'),
#  ('take off your socks', '<kw> 낭말 벗어요 .'),
#  ('oh theres no grace no grace', '<jj> 아이구 여한이 어수다 원 여한이 어서'),
#  ('is he the biggest of the three ?', '<jj> 가이가 세 명중에 제일 커 ?'),
#  ('please continue next time .', '<kw> 어여 그다음을 계속해 주시오 .'),
#  ('i live near a desk again and i don t know what i m talking about .',
#   '<gs> 또 사직구장 근처에 살아가주고 인제'),
#  ('its good to go there in the morning but if its not that its equipment but its a little tight a day',
#   '<jd> 오전에 갔다 오면 좋은데 그게 아니잖아 하면 장비인데 보니까 하루는 좀 빠듯하긴 하드라 ?'),
#  ('i just wanted to give you the album your wife used to love .',
#   '<kw> 그짝 와이프가 잇날에 좋아했던 앨범이라 주고 싶어서요 그 .'),
#  ('i would have built it alone when everyone is there but i do that rather than building it alone',
#   '<jj> 다 있을 때면 나 혼자 지어불껄 겅 허긴 허는디 혼자 짓는 것보다'),
#  ('the men in the drama have a slightly different face',
#   '<gs> 그 일단 드라마 속에 있는 남자들은 얼굴이 쫌 다르기도 하고'),
#  ('it didnt make sense for people to do it for a day before then and its just a vote yes no',
#   '<jd> 그전부터 사 일 동안 이십 명 하는 것도 쫌 말이 안 됐고 그냥 예 아니요 투표인데'),
#  ('can you come to my dads place and tell him to do something for a while and he can take care of my daily wages',
#   '<jd> 아빠 있는 데 와서 잠깐 해라고 일 좀 하라고 일당을 자기가 챙겨줄 수 있으니깐'),
#  ('i haven t been sick in years .', '<jj> 그동안엔 안 아파란만은이'),
#  ('she fell asleep and went to the hospital .', '<kw> 그 어머이 졸도해서 벵원 실려갔대요 .'),
#  ('unusable tools were put together in one place .',
#   '<kw> 쓰지 않는 도구는 껄끼지 않도록 한 군데에 마 놓았다 .'),
#  ('there s nothing to see .', '<jd> 뭐 볼 수 있는 게 없 없어 . 글고'),
#  ('i don t know what a ghost is .', '<kw> 구신은 뭐하내기 모르겠다 .'),
#  ('theres no probability at all', '<kw> 공산이 전예 없다 .'),
#  ('i couldn t help but think about it .', '<kw> 그른 생각 지울 수가 없더라 .'),
#  ('oh that s because it s also saving trees .',
#   '<kw> 아 이게 또 낭구 구하는 일이 있으니까 그럴 수 있겠네요 .'),
#  ('i don t know if it s ilencia .', '<jd> 혹시 일렌시아라고 알랑가 모르겄어 .'),
#  ('i don t feel comfortable getting dressed .', '<kw> 자꾸 옷이 찡구키니 불편하네 .'),
#  ('well it s really hard to keep the house under control .',
#   '<kw> 뭐 정말 집에서 억압을 해가주구'),
#  ('so i think ive changed a lot too', '<cc> 그니까 아 나도 진짜 많이 달라졌구나 나도 지금'),
#  ('when you take a picture you say what is it but other people come out very pretty and brightly youre just going to pick up',
#   '<gs> 사진 찍어주면 또 어 뭐야 이러는데 이제 막 따른 사람들 엄청 예쁘게 화사하게 나오 니 혼자 막 추리닝'),
#  ('i like that too i like that the most side dish i really like',
#   '<cc> 그것도 게 좋아 좋아하고 그거 내가 진짜 반찬 중에 쩨일 좋아하는 거는'),
#  ('i m sorry i m just thinking about something else .',
#   '<kw> 미안해요 . 딴 생각 좀 하느라고 .'),
#  ('if you ask the officials to investigate a little bit correctly they did it correctly',
#   '<gs> 사관보 사관보인들한테 쫌 조사 좀 똑바로 해봐라 시키면은 아 똑바로 했다 이케 해놓고'),
#  ('yeah i don t think young people today know the dross .',
#   '<kw> 맞아 요즘 언나들은 딱종이를 모를거 같은데 .'),
#  ('she has a girlfriend .', '<kw> 그 예자는 애인이 있는데요 .'),
#  ('how many boys ?', '<kw> 아니 사내 녀석들이 뭘 얼매나 ?'),
#  ('once my foot was broken but the side of the foot the backbone of the foot was broken',
#   '<jd> 한 번은 발이 뿌러졌는데 발꼬락 쪽 발 등뼈 뭐 그쪽이 부러졌는데'),
#  ('so there s a lot of good things to know but some people don t get bad things when they do something .',
#   '<jd> 긍게 알바라는 게 좋은 것도 많은데 어떻게 하다가 보면 나쁜 것도 빠지는 사람도 있고 긍게'),
#  ('imaturely eat it together so im eating it together',
#   '<jj> 나 밥 행 먹어 가난 이녁도 고치 밥 행 먹켄 저'),
#  ('you have everything right ?', '<kw> 다 가주구 계신거죠 ? ?'),
#  ('so bangkok and pata . i only know this much .',
#   '<kw> 그까 뭐 방콕이랑 파타야 뭐 이 정도만 알지'),
#  ('its called the best satirical literature', '<jd> 극한한 최고의 풍자 문학이라고 하는 거여 .'),
#  ('and when you go and eat it it tastes good one day another day it doesn t and a lot of times it does .',
#   '<jd> 또 가서 먹으면 어느 날은 또 맛있고 어느 날은 또 아니고 그럴 때가 많이 있드라 .'),
#  ('these days women are left and office workers are also going to pick stars in the sky',
#   '<kw> 요중간은 예자들 남아 돌아서 회사원도 하날에 별따기래 .'),
#  ('this summer i ve been down the line .', '<jd> 나 이번 여름에는 말이여 제주도를 갔다 왔는디 .'),
#  ('i see a little less television these days .', '<jj> 요새 는 테레비 호끔 덜 봠주기'),
#  ('he told me to do that', '<cc> 그르케 하게 돼 하라구 얘기를 하더라고'),
#  ('i used to do that', '<jj> 원래 겅 했져'),
#  ('cant i eat it the next day', '<jj> 다음날 먹으면 안돼어 ?'),
#  ('so to stretch your muscles you keep bending your legs forward like this',
#   '<cc> 긍까는 근육을 늘리려면 다리를 이렇게 자꾸 앞으로 숙였잖아요 .'),
#  ('but the wrong way the delivery fee was krw',
#   '<cc> 근데 엉뚱하게 어 일케 그 어 택배비가 육천 원이 막 이케 나온 거예요 .'),
#  ('you threw all of this and said you were in the swamp jungle',
#   '<jj> 이거 다 대껴부러시 니 늪 정글 댔댄 하멍 막'),
#  ('its like that i must have been so willing to do that so you too',
#   '<jd> 그런 거지 뭐 내가 얼마나 의지가 강해서 그러고 그러것냐 긍께 너도'),
#  ('it s almost like eating like this . it s worth a lot of money .',
#   '<jj> 거의 그럼 가치 영 먹는것 두루치기 같은 거 있잖아'),
#  ('tell me quickly . who hit you ?', '<kw> 빨라당 말해 누그한테 맞은거야 ?'),
#  ('if you look at the neber webtoon the webtoons are put together and the masks are in the ratings .',
#   '<gs> 아니 네이버 웹툰 보면은 웹툰 모아놓은 데 가면은 순위권에 있그든 .'),
#  ('when are you gonna stop acting like a martyr ?',
#   '<kw> 도대처 언제쯤 순교자 행세를 그만둘 거야 ?'),
#  ('try new ones .', '<kw> 새루 해보아라 .'),
#  ('it s useless to do that .', '<kw> 그렁이 짓을 해보았자 무익하다 .'),
#  ('you know when my dad told me he was gonna open an account for you you know like a minor or something .',
#   '<jd> 아부지가 인제 뭐 계좌를 터주신다고 핫 때 이제 그때 뭐 미성년자나'),
#  ('mom does it .', '<kw> 어머이가 해'),
#  ('theres something like that like these days', '<jj> 요즘 처럼 그런 거 있대매'),
#  ('is there a nice restaurant around here ?', '<kw> 여 근처에 좋은 레스토랑이 있습니까 ?'),
#  ('theres everything i think there are a lot of parttime jobs that we didnt even think of',
#   '<jd> 별 것이 다 있드만 뭐 우리가 생각지도 못한 그런 아르바이트가 많이 있는 거 같애 .'),
#  ('your name is uh uh oh oh oh you said it but you like it a little bit more rationally',
#   '<gs> 이름님은 혹시 어 좋아 아 스타일 말씀하셨지만 구체적인 쫌 좋아하시는 스타일 이성적으로'),
#  ('i tried the conch this time but my teeth almost got out i laughed at it',
#   '<jj> 소라 요번에 먹어봤거든 근데 이빨 나갈 뻔 웃음 핸'),
#  ('i ve seen you before .', '<kw> 오전 에 뵌 저으기 있어 .'),
#  ('he wouldn t have survived without me .', '<kw> 오빠가 내 옆에 없으문 견뎌내지 못했을 기야 .'),
#  ('so when i go to the beach a lot i always try to eat some seafood',
#   '<cc> 그래서 바닷가 많이 놀러 가면은 항상 쫌 그래도 해산물을 좀 먹으려고 하고'),
#  ('start talking is that right', '<jj> 곧 기 시작 이 ?'),
#  ('it s been a while .', '<kw> 야 얼매 만에 보는 파인애플이냐 .'),
#  ('i can t even find it .', '<jj> 찾지도 못하주 .'),
#  ('iveisted a lot from the beginning',
#   '<jd> 초반부터 내가 이러케 들어 논 게 많이 있어 가지고 그래 갖고'),
#  ('press the calculator and say ill buy it so please give me a little more discount and buy a cute pouch',
#   '<jd> 계산기 누리면서 뭐 내가 살 테니까 쫌 더 할인해 달라 이러면서 기여운 파우치 같은 것도 사고'),
#  ('don t you think i m kidding you ?', '<kw> 내가 지굼 너하고 장난하는 줄 아나 ?'),
#  ('someone else', '<gs> 뭔가 따른 사람 제'),
#  ('is that all men ?', '<jj> 그거 달렸댄 다 남자꽈 ?'),
#  ('grind it like a powder made of mushrooms and sprinkle it on the food',
#   '<jj> 버섯으로 만든 파우더처럼 빻아갖고 그걸 음식의 뿌리민'),
#  ('i think i had a wise doctors life', '<jd> 슬기로운 의사 생활이 있던 거 같여 .'),
#  ('theres a tripod in my house so i take it',
#   '<cc> 우리 집에 놀고 있는 삼각대가 있거든 그니까 그거를 가져가서'),
#  ('i was going to go on a backpacking trip too',
#   '<jj> 배낭 여행도 어떵 가 보젠 가 보려고 나도 막 그'),
#  ('oh shit . and then i hit him with my bare fist .',
#   '<jj> 어 시발 한 다음에 맨 주먹으로 그냥 내려쳔 .'),
#  ('it s gonna take a while to get this to the car .',
#   '<kw> 이그 견인차 불러서 가려면 꽤 시간이 걸릴 거 같은데 .'),
#  ('the land is called kimchi so i just put a jar on the ground and store kimchi',
#   '<jj> 육지는 이제 김장이라고 해서 막 땅에 항아리 묻엉 김치를 막 저장하는데'),
#  ('i don t know if i ll ever make it back to kang neung .',
#   '<kw> 강릉을 다시 못 올까 봐 저번에 한 번 그래 가주구'),
#  ('someone bought something and the guardians bought it and eat it you got it',
#   '<cc> 누가 뭐 뭐 사와서 인자 보호자들 사와서 먹잖아 얻어 먹었잖아 .'),
#  ('i think i just went to haeundae market after experiencing helicopter helicopters',
#   '<jd> 내가 이제 헬기 헬게이트 경험을 하고 시장이 뭐 시장이겠지 하고 그냥 해운대 시장만 갔던 거 같혀 .'),
#  ('in fact if they taught them universities they had to do everything',
#   '<cc> 실은 뭐 대학교까지 가르쳤으면 지들이 다 하고 해야 되는데'),
#  ('i like the details and i don t know if this guy s out there and i don t know what he s up to .',
#   '<jd> 디테일한 것도 좋아하고 의외로 이 인물이 나고 그런 게 있드라고'),
#  ('you know it s just so annoying and so annoying .',
#   '<kw> 하다 보니까 너무 째증나고 번거롭더라고'),
#  ('that s why he supported one side of me to do the right thing .',
#   '<kw> 기래서 일을 제대로 해보라고 한쪽을 지지 해주신거죠 .'),
#  ('is it his own fashion', '<gs> 그 지 때만의 자기 때만의 그른 어떤 패션인가'),
#  ('didnt you give christmas to me i thought you would give it to me in the new year',
#   '<gs> 크리스마스 챙겨줬다 아이가 그게 또 뭐 새해 때도 막 아 그 누나가 뭐 줄 거 같거든 ?'),
#  ('after my death it s so sad and it s so regretful and then what do you do ?',
#   '<kw> 돌아가시고 나이까 참 아쉽고 후회되고 그런데 그래문 뭐 하니 ?'),
#  ('i m a little good at credit .', '<jd> 신용 같은 거 쫌 잘'),
#  ('i ook the test a long time ago', '<jj> 나는 나도 옛날에 그 저 검사해신디'),
#  ('there s a lot of wrinkles around your eyes .', '<kw> 웃어서 눈주위에 쭈구럭살이 많네 .'),
#  ('look at what to give as a gift to everyone to dad or mom',
#   '<cc> 누구한테나 아빠나 엄마한테나 이릏게 뭐 선물할 거 막 구경하고'),
#  ('i ve just had a hard time going around .', '<jj> 나 막 다니멍 폭삭 속았주게'),
#  ('a bouncy year became a mother so im sorry but my name is',
#   '<kw> 복없는 년이 어머이가 돼어서 이름 야 미안하다 .'),
#  ('i m back alive .', '<kw> 살아 돌아왔싸 됐다 .'),
#  ('yesh thats right there are more people in seoul right now',
#   '<gs> 응 하긴 건 하긴 거기 보다야 지금 서울이 더 많지 그냥 저거들은'),
#  ('if you re her i m her .', '<kw> 니가 여보야면 나도 여보야고'),
#  ('she s a student and she s like um she s smoking in the middle .',
#   '<jd> 학생인데 뭔가 음 막 중간중간에 담배 피는 거 나오고 그러잖아 .'),
#  ('the title is to talk about childhood stories .',
#   '<jj> 제목은 어린시절 이야기에 대해서 얘기해 보쿠다 예'),
#  ('don t you have your grandfather s father ?', '<kw> 왕 할아바이 아빠 없어요 ?'),
#  ('what should i say like this should i say it to help',
#   '<jd> 이케 뭐라 해야 되지 보듬어준다 해야 되나'),
#  ('so there are hammers but in a way the market is too narrow',
#   '<cc> 그니까 이 해머라든가 있긴 있는데 약간 어떻게 보면은 너무 시장이 협소하다 보니까 그니까'),
#  ('its purple right ill play rock paper scissors with that ripped off',
#   '<jd> 자주색 펴있단 말이지 금 그거 뜯어갖고 가위바위보 함씨롱 응 니'),
#  ('so now he s got a bad knee on his own and he s been doing knee smoothing for a while .',
#   '<kw> 그래서 이제 혼자서 이제 무릎도 안 좋으셔 가주구 얼마 전에 무릎 수슬도 하고 이래 가주구'),
#  ('i m going to roast some bean sprouts .', '<kw> 콩질금볶음 해먹지 .'),
#  ('i want to see the major league competition .', '<kw> 메이저리그 시합을 보구 싶어 .'),
#  ('then is it better not to raise a pet dog',
#   '<jd> 지금 그라면 애완견은 안 키우는 것이 좋겠네 ?'),
#  ('i heard that korean webtoons are the best in japan',
#   '<gs> 일본에서 우리나라 웹툰이 최고라 카대 캐서'),
#  ('when you receive it you can use a motorcycle to go to hoengcheon stream or hwangcheongil street',
#   '<jd> 받으면은 진짜 인제 횡천 긍까 황천길이거든 이게 오토바이가'),
#  ('when the rain stops let s go .', '<kw> 야중에 비 그치면 가자 .'),
#  ('are you telling me you re good in front of me ?',
#   '<kw> 지굼 내 앞에서 잘났다고 자랑하는 거야 ?'),
#  ('where do you go with the meat bar ?', '<kw> 고기 보탱이를 이고서 어디로 가나요 ?'),
#  ('you don t look fat at all .', '<jd> 살이 하나도 안 쪄보여 거시기 뭐야'),
#  ('it s a chicken ribs but i have a really good memory .',
#   '<kw> 닭갈비 근데 되게 맛있었던 기억이 있어 가주구'),
#  ('but shouldnt you do sports like sports steadily',
#   '<jj> 근데 운동 같은 그런 스포츠는 꾸준히 해야 되는거 아니 ?'),
#  ('because i was in the sixty six years i was in the sixty one seven years .',
#   '<jj> 육십육 년도에 입사를 해시난 육 십 한 칠 년도에'),
#  ('yeah . name is just busy .', '<jj> 게난 name 막 바빠게 바빤 바빤'),
#  ('it s all day .', '<jj> 날이 다 이서 무슨 .'),
#  ('one of the reasons why i like makgeolli bread because its not sweet',
#   '<jj> 달거나 막 이런거 허난 상예떡 좋아하는 이유 중의 하나가 달지 안해부난'),
#  ('one or two they re just doing that so they re not exercising they re not stretching .',
#   '<jd> 하나 둘 하나 둘 그냥 그 정도만 하고 말아븐게 운동도 아니고 스트레칭도 아니고'),
#  ('it s going to be useful if you give some sort of map of the type of question you re asking the seller .',
#   '<kw> 판매자에게 물어볼 질문의 유형에 대해 어는 정도 지도를 해 줄 경우 유익할 거예요 .'),
#  ('dont mind it too much because its a matter of organizing one or two affiliates',
#   '<kw> 계열사 한두 개 정리하면 될 문제니까 너머 마옴 쓰지 마라 .'),
#  ('i think i used to look up a lot of beauty programs and makeuprelated videos when i didnt wear makeup',
#   '<cc> 나는 오히려 옛날에 화장을 안 했을 때는 그런 뷰티 프로그램이나 화장 관련된 영상들을 많이 찾아봤던거 같은디'),
#  ('and now that i m talking in middle school it s kind of a little bit of a concern for me .',
#   '<gs> 이게 이렇게 이제 중학교 때 말을 하니까 제가 쫌 고민이 많이 되더라고요 이게'),
#  ('ims talking and finding a very perfect ideal type',
#   '<jj> 말하고 너무나도 완벽한 이상형을 한 번 찾는거수다'),
#  ('now everyone is upset but why didnt you send your daughter to marriage when my friend was sitting and playing',
#   '<jd> 인자 큰 다 이제 흉을 봤어요 근데 내 친구가 앉아 놀던 왜 딸을 안 시집을 안 보내냬'),
#  ('how long do you think you re gonna eat like a dog ?',
#   '<kw> 운제까지 개 부려먹듯이 부려먹을려고 그러세요 ?'),
#  ('i think winter is better than summer but i think its a little bit',
#   '<jd> 여름보다는 겨울이 나은 거 같기도 하고 쫌 그러네 .'),
#  ('since i keep saying this im giving them single single strokes separately',
#   '<jd> 이 말을 자꾸 인제 하니까 이 사람들도 단타 단타 종목 따로 주고'),
#  ('it s hard because i don t have enough money .', '<kw> 자금이 부족하니 심든가 보더라 .'),
#  ('is my child and the woman who gave birth to him ?',
#   '<kw> 이름 도 내 자석인데 자석 낳아 준 예나 허투루 대해요 ?'),
#  ('how many times do i need your help ?', '<kw> 몇 번이나 도와 달라구 매달리구 싶구 지굼두'),
#  ('so about that kind of thing in reality', '<cc> 그래서 그런 거에 대해서 좀 이케 현실적으로'),
#  ('well if everyone in the world had to be beaten up it would be cheap in the country because without them that s a lot of money .',
#   '<jj> 뭐 전 세계적으로 국민들이 다 맞아야 될 거면 나라에서 싸게 하겠지 . 왜냐하면 없이 사는 사람 그것도 큰 돈이주게 .'),
#  ('i m not gonna ignore it you guys .', '<jj> 무시 못 할거여 너네'),
#  ('so now i come to my house once a month and i go to sleep and she has that kind of thing .',
#   '<jd> 그래서 지금도 한 달에 한 번씩이나 저희 집에 오나 그래 가지구 자고 가 걔는 그니까 좀 그런 게 있죠 .'),
#  ('maybe i can visualize it that way and i ll prepare for it and i ll be a little bit more alert all the time .',
#   '<jd> 아무래도 그렇게 시각화시켜 놓으면 내가 그걸 위해서 준비 하고 쫌 어 항상 각성이 있지 않을까 그래서'),
#  ('you re gonna be a little weak in your body and in your health .',
#   '<jd> 인제 몸도 건강도 많이 인자 쫌 약해질텐데'),
#  ('you really decided to come out on the news',
#   '<jd> 너 이거 진짜 이거 뉴스 나올라고 작정 했구나 니가'),
#  ('i dont really want to go with you', '<jj> 별로 오빠랑 가고 싶지 않은 게'),
#  ('i m sorry .', '<kw> 안 됐 니가'),
#  ('so thats why', '<jd> 되야 그래서'),
#  ('twenty seven .', '<kw> 쉬물 일굽 입니다 .'),
#  ('so the smart palm is only for this cabbage and the other vegetables aren t ?',
#   '<kw> 그러면은 그 스마트팜이 이 양배추에만 해당돼 다른 야채는 해당이 안 되나 ?'),
#  ('i m not as strong as i am .', '<jj> 만큼 막 술 세진 않애 .'),
#  ('i called her and said hey i was also', '<gs> 걔한테 전화해서 야 나도 됐다 카면서'),
#  ('i can t see a man of love riding on a horse .',
#   '<kw> 목마를 탄 사랑의 사램은 보이지 않는다 .'),
#  ('it s small but it doesn t make any sense .', '<kw> 자잘하기는 해도 매굽기는 말도 못해 .'),
#  ('when we grow up we have our own families so we dont know',
#   '<gs> 뭐 커서 뭐 즈그들끼리 뭐 각자의 뭐 가정이 있으니까 뭐 몰라라 이렇게 한다 하지만'),
#  ('your father s the only one who s gonna be virtuous .',
#   '<kw> 앞으루 느희 아부지만 덕 보게 생겼다 아들덕에'),
#  ('i know but i couldn t see it because i had to work at night .',
#   '<kw> 알아요 근데 저는 밤에 일을 해야 되기 때민에 볼 수가 없었어요 .'),
#  ('in gyeongsangdo its called daseulgi soup because theres daseulgi soup',
#   '<gs> 경상도에서는 꼴부리국이라고 하는데 다슬기국이 있거든요 .'),
#  ('why would you do that ?', '<jd> 아 니 근데 배그 사양으로 왜 맞추 왜 맞추겠다는 거야 ?'),
#  ...]

# %%
# <PAD> : 0 / <BOS> : 1 / <EOS> : 2 / <UNK> : 3
# <jj> : 4 / <jd> : 5 / <gs> : 6 / <cc> : 7 / <kw> : 8

# Sentencepiece를 활용하여 학습한 tokenizer를 생성
def generate_tokenizer(corpus, vocab_size, lang="en", pad_id=0, bos_id=1, eos_id=2, unk_id=3):

    temp_file = os.getenv('HOME') + f'/aiffel/aiffelthon/corpus_{lang}.txt'     # corpus를 받아 txt파일로 저장
    
    with open(temp_file, 'w') as f:
        for row in corpus:
            f.write(str(row) + '\n')
    
    # Sentencepiece를 이용해 
    spm.SentencePieceTrainer.Train(
        f'--input={temp_file} --model_type=bpe --pad_id={pad_id} --bos_id={bos_id} --eos_id={eos_id} \
        --unk_id={unk_id} --model_prefix=spm{lang}_r0 --vocab_size={vocab_size} \
        --user_defined_symbols=<jj>,<jd>,<gs>,<cc>,<kw> --remove_extra_whitespaces=false'   # model_r0
    )
    tokenizer = spm.SentencePieceProcessor()
    tokenizer.Load(f'spm{lang}_r0.model') # model_r1

    return tokenizer

# %%
SRC_VOCAB_SIZE = TGT_VOCAB_SIZE = 4000

enc_corpus = []
dec_corpus = []

for pair in cleaned_corpus:
    e, d = pair[0], pair[1]
    # enc, dec 분리
    enc_corpus.append(e)
    dec_corpus.append(d)

#     enc_corpus.append(preprocess_sentence(e))
#     dec_corpus.append(preprocess_sentence(d))

enc_tokenizer = generate_tokenizer(enc_corpus, SRC_VOCAB_SIZE, "enc")
dec_tokenizer = generate_tokenizer(dec_corpus, TGT_VOCAB_SIZE, "dec")
dec_tokenizer.set_encode_extra_options("bos:eos")
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=/aiffel/aiffel/aiffelthon/corpus_enc.txt --model_type=bpe --pad_id=0 --bos_id=1 --eos_id=2         --unk_id=3 --model_prefix=spmenc_r0 --vocab_size=4000         --user_defined_symbols=<jj>,<jd>,<gs>,<cc>,<kw> --remove_extra_whitespaces=false
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /aiffel/aiffel/aiffelthon/corpus_enc.txt
#   input_format:
#   model_prefix: spmenc_r0
#   model_type: BPE
#   vocab_size: 4000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: <jj>
#   user_defined_symbols: <jd>
#   user_defined_symbols: <gs>
#   user_defined_symbols: <cc>
#   user_defined_symbols: <kw>
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 3
#   bos_id: 1
#   eos_id: 2
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 0
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(329) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(178) LOG(INFO) Loading corpus: /aiffel/aiffel/aiffelthon/corpus_enc.txt
# trainer_interface.cc(140) LOG(INFO) Loaded 1000000 lines
# trainer_interface.cc(117) LOG(WARNING) Too many sentences are loaded! (1065266), which may slow down training.
# trainer_interface.cc(119) LOG(WARNING) Consider using --input_sentence_size=<size> and --shuffle_input_sentence=true.
# trainer_interface.cc(122) LOG(WARNING) They allow to randomly sample <size> sentences from the entire corpus.
# trainer_interface.cc(385) LOG(INFO) Loaded all 1065266 sentences
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <jj>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <jd>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <gs>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <cc>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <kw>
# trainer_interface.cc(405) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(466) LOG(INFO) all chars count=54572696
# trainer_interface.cc(477) LOG(INFO) Done: 99.9739% characters are covered.
# trainer_interface.cc(487) LOG(INFO) Alphabet size=29
# trainer_interface.cc(488) LOG(INFO) Final character coverage=0.999739
# trainer_interface.cc(520) LOG(INFO) Done! preprocessed 1065266 sentences.
# trainer_interface.cc(526) LOG(INFO) Tokenizing input sentences with whitespace: 1065266
# trainer_interface.cc(537) LOG(INFO) Done! 59094
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1717115 min_freq=1
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=455878 size=20 all=1207 active=1177 piece=at
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=209471 size=40 all=2125 active=2095 piece=▁that
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=143156 size=60 all=3372 active=3342 piece=as
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=99075 size=80 all=4179 active=4149 piece=▁k
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=78106 size=100 all=5193 active=5163 piece=▁think
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=77311 min_freq=2369
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=62205 size=120 all=6131 active=1934 piece=ent
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=48945 size=140 all=6960 active=2763 piece=ame
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=39637 size=160 all=7899 active=3702 piece=▁want
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=33256 size=180 all=8851 active=4654 piece=▁eat
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=29823 size=200 all=9469 active=5272 piece=▁she
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=29580 min_freq=2555
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=25967 size=220 all=10140 active=1648 piece=king
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=23311 size=240 all=10828 active=2336 piece=ur
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=20158 size=260 all=11807 active=3315 piece=are
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=17552 size=280 all=12848 active=4355 piece=▁them
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=15597 size=300 all=13434 active=4941 piece=oney
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=15556 min_freq=2292
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=14834 size=320 all=14098 active=1646 piece=▁sch
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=13930 size=340 all=14381 active=1929 piece=▁his
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=12780 size=360 all=14989 active=2537 piece=▁buy
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=11738 size=380 all=15394 active=2942 piece=ure
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=10661 size=400 all=16017 active=3565 piece=so
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=10618 min_freq=2015
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=10009 size=420 all=16412 active=1313 piece=▁has
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=9251 size=440 all=17471 active=2372 piece=▁yes
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=8696 size=460 all=18233 active=3134 piece=▁came
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=8189 size=480 all=18607 active=3508 piece=aw
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=7574 size=500 all=19195 active=4096 piece=▁fam
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=7528 min_freq=1771
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=7094 size=520 all=19714 active=1514 piece=▁pr
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=6795 size=540 all=19992 active=1791 piece=wn
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=6471 size=560 all=20593 active=2392 piece=ful
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=6031 size=580 all=21195 active=2994 piece=ts
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=5767 size=600 all=21745 active=3544 piece=▁doesn
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=5764 min_freq=1424
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=5503 size=620 all=22065 active=1407 piece=▁rest
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=5267 size=640 all=22595 active=1937 piece=▁wom
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4945 size=660 all=22993 active=2335 piece=nder
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4798 size=680 all=23380 active=2722 piece=▁pay
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4588 size=700 all=23936 active=3278 piece=▁asked
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=4586 min_freq=1159
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4414 size=720 all=24212 active=1473 piece=▁cle
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4295 size=740 all=24718 active=1979 piece=▁clothes
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4152 size=760 all=25001 active=2262 piece=▁turn
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4028 size=780 all=25465 active=2725 piece=▁front
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3865 size=800 all=25844 active=3104 piece=▁head
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=3860 min_freq=972
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3655 size=820 all=26166 active=1596 piece=ny
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3496 size=840 all=26436 active=1866 piece=▁having
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3411 size=860 all=26945 active=2375 piece=▁five
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3308 size=880 all=27474 active=2904 piece=▁expensive
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3196 size=900 all=27634 active=3064 piece=▁bel
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=3193 min_freq=825
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3089 size=920 all=27886 active=1613 piece=▁read
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2992 size=940 all=28169 active=1896 piece=▁att
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2894 size=960 all=28582 active=2309 piece=▁felt
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2817 size=980 all=28864 active=2591 piece=▁pop
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2749 size=1000 all=29185 active=2912 piece=▁hund
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=2745 min_freq=725
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2692 size=1020 all=29497 active=1768 piece=uickly
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2612 size=1040 all=29847 active=2118 piece=▁age
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2536 size=1060 all=29960 active=2231 piece=aurant
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2478 size=1080 all=30157 active=2428 piece=▁student
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2379 size=1100 all=30535 active=2806 piece=ced
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=2378 min_freq=637
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2321 size=1120 all=30767 active=1726 piece=ok
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2257 size=1140 all=31165 active=2124 piece=▁somewhere
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2200 size=1160 all=31425 active=2384 piece=▁light
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2115 size=1180 all=31624 active=2583 piece=▁chea
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2061 size=1200 all=31998 active=2957 piece=▁spend
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=2057 min_freq=559
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2013 size=1220 all=32345 active=1945 piece=wer
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1979 size=1240 all=32811 active=2411 piece=▁completely
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1923 size=1260 all=33173 active=2773 piece=▁trouble
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1875 size=1280 all=33390 active=2990 piece=gs
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1810 size=1300 all=33774 active=3374 piece=▁blood
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1808 min_freq=488
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1776 size=1320 all=34036 active=1942 piece=cks
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1753 size=1340 all=34271 active=2177 piece=▁neigh
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1710 size=1360 all=34578 active=2484 piece=ship
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1652 size=1380 all=34952 active=2858 piece=▁neighbor
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1606 size=1400 all=35253 active=3159 piece=iting
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1604 min_freq=442
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1579 size=1420 all=35610 active=2092 piece=▁mess
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1548 size=1440 all=35837 active=2319 piece=ised
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1502 size=1460 all=35930 active=2412 piece=▁dry
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1474 size=1480 all=36202 active=2684 piece=ins
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1440 size=1500 all=36622 active=3104 piece=▁medicine
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1438 min_freq=401
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1404 size=1520 all=37015 active=2225 piece=ese
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1382 size=1540 all=37160 active=2370 piece=▁dead
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1361 size=1560 all=37408 active=2618 piece=▁sol
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1328 size=1580 all=37702 active=2912 piece=▁team
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1309 size=1600 all=38162 active=3372 piece=▁birthday
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1308 min_freq=362
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1290 size=1620 all=38266 active=2012 piece=▁girls
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1264 size=1640 all=38404 active=2150 piece=▁ste
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1239 size=1660 all=38525 active=2271 piece=▁ah
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1211 size=1680 all=38706 active=2452 piece=▁fig
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1193 size=1700 all=39032 active=2778 piece=▁pie
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1193 min_freq=337
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1172 size=1720 all=39319 active=2235 piece=▁sleeping
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1145 size=1740 all=39567 active=2483 piece=▁box
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1122 size=1760 all=39945 active=2861 piece=▁eff
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1099 size=1780 all=40217 active=3133 piece=erg
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1082 size=1800 all=40464 active=3380 piece=▁strength
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1080 min_freq=310
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1063 size=1820 all=40806 active=2361 piece=▁contact
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1034 size=1840 all=41077 active=2632 piece=▁paper
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1008 size=1860 all=41471 active=3026 piece=mbers
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=997 size=1880 all=41613 active=3168 piece=▁contro
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=975 size=1900 all=41760 active=3315 piece=fast
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=975 min_freq=286
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=964 size=1920 all=41930 active=2256 piece=▁leaving
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=949 size=1940 all=42108 active=2434 piece=line
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=929 size=1960 all=42444 active=2770 piece=▁mine
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=915 size=1980 all=42631 active=2957 piece=oud
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=899 size=2000 all=42912 active=3238 piece=sel
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=899 min_freq=264
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=881 size=2020 all=43267 active=2469 piece=▁lady
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=866 size=2040 all=43475 active=2677 piece=▁ret
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=851 size=2060 all=43661 active=2863 piece=▁insurance
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=835 size=2080 all=43755 active=2957 piece=▁tax
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=819 size=2100 all=43927 active=3129 piece=▁regret
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=818 min_freq=247
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=807 size=2120 all=44011 active=2276 piece=▁singing
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=790 size=2140 all=44122 active=2387 piece=cious
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=780 size=2160 all=44192 active=2457 piece=ef
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=769 size=2180 all=44436 active=2701 piece=▁choose
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=760 size=2200 all=44550 active=2815 piece=▁professor
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=759 min_freq=231
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=744 size=2220 all=44616 active=2294 piece=▁ground
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=733 size=2240 all=44788 active=2466 piece=▁phys
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=722 size=2260 all=45036 active=2714 piece=ged
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=709 size=2280 all=45333 active=3011 piece=▁inform
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=698 size=2300 all=45502 active=3180 piece=loy
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=697 min_freq=216
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=689 size=2320 all=45614 active=2376 piece=▁allow
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=679 size=2340 all=45875 active=2637 piece=ict
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=665 size=2360 all=46123 active=2885 piece=▁flat
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=658 size=2380 all=46223 active=2985 piece=▁bean
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=642 size=2400 all=46463 active=3225 piece=cket
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=642 min_freq=202
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=633 size=2420 all=46552 active=2401 piece=▁broad
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=624 size=2440 all=46763 active=2612 piece=▁rough
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=613 size=2460 all=46951 active=2800 piece=▁trans
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=605 size=2480 all=47103 active=2952 piece=▁snacks
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=596 size=2500 all=47251 active=3100 piece=onment
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=596 min_freq=190
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=586 size=2520 all=47374 active=2480 piece=▁ridiculous
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=575 size=2540 all=47518 active=2624 piece=▁pet
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=567 size=2560 all=47796 active=2902 piece=▁activ
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=560 size=2580 all=47895 active=3001 piece=▁shes
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=552 size=2600 all=48056 active=3162 piece=▁cheaper
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=552 min_freq=180
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=543 size=2620 all=48306 active=2653 piece=▁bright
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=535 size=2640 all=48528 active=2875 piece=▁shut
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=528 size=2660 all=48731 active=3078 piece=▁dying
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=519 size=2680 all=48903 active=3250 piece=uar
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=513 size=2700 all=49046 active=3393 piece=▁electric
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=512 min_freq=169
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=505 size=2720 all=49175 active=2578 piece=lect
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=499 size=2740 all=49405 active=2808 piece=▁salary
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=492 size=2760 all=49522 active=2925 piece=ugg
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=488 size=2780 all=49723 active=3126 piece=▁fishing
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=480 size=2800 all=49890 active=3293 piece=antage
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=480 min_freq=160
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=472 size=2820 all=50013 active=2613 piece=▁master
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=468 size=2840 all=50082 active=2682 piece=▁knowing
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=461 size=2860 all=50252 active=2852 piece=▁moder
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=453 size=2880 all=50333 active=2933 piece=edu
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=447 size=2900 all=50523 active=3123 piece=▁pal
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=447 min_freq=152
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=444 size=2920 all=50737 active=2702 piece=▁stea
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=439 size=2940 all=50917 active=2882 piece=▁tourist
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=434 size=2960 all=51123 active=3088 piece=▁invol
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=430 size=2980 all=51388 active=3353 piece=▁ticket
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=425 size=3000 all=51472 active=3437 piece=▁divorce
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=424 min_freq=144
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=421 size=3020 all=51666 active=2767 piece=▁extent
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=416 size=3040 all=51750 active=2851 piece=▁pian
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=412 size=3060 all=51834 active=2935 piece=▁ep
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=409 size=3080 all=52032 active=3133 piece=▁american
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=402 size=3100 all=52188 active=3289 piece=▁inje
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=402 min_freq=138
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=396 size=3120 all=52305 active=2720 piece=▁awk
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=392 size=3140 all=52521 active=2936 piece=▁sounds
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=387 size=3160 all=52662 active=3077 piece=▁cos
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=383 size=3180 all=52770 active=3185 piece=▁results
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=377 size=3200 all=52866 active=3281 piece=ective
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=377 min_freq=131
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=375 size=3220 all=53011 active=2781 piece=▁ingredients
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=370 size=3240 all=53130 active=2900 piece=▁rainy
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=366 size=3260 all=53265 active=3035 piece=▁gotten
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=362 size=3280 all=53361 active=3131 piece=▁lay
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=358 size=3300 all=53486 active=3256 piece=▁spir
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=358 min_freq=125
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=354 size=3320 all=53517 active=2697 piece=ague
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=352 size=3340 all=53742 active=2922 piece=rible
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=348 size=3360 all=53877 active=3057 piece=▁cru
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=345 size=3380 all=53950 active=3130 piece=▁besides
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=341 size=3400 all=54043 active=3223 piece=▁touching
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=340 min_freq=120
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=336 size=3420 all=54131 active=2790 piece=▁mir
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=334 size=3440 all=54198 active=2857 piece=▁discount
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=331 size=3460 all=54360 active=3019 piece=▁schedule
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=327 size=3480 all=54577 active=3236 piece=ration
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=324 size=3500 all=54659 active=3318 piece=▁exch
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=324 min_freq=114
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=319 size=3520 all=54717 active=2790 piece=▁camping
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=315 size=3540 all=54814 active=2887 piece=▁trad
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=311 size=3560 all=54872 active=2945 piece=ister
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=309 size=3580 all=54965 active=3038 piece=▁current
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=306 size=3600 all=55057 active=3130 piece=▁beaten
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=306 min_freq=110
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=303 size=3620 all=55176 active=2871 piece=▁surv
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=300 size=3640 all=55244 active=2939 piece=▁upper
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=297 size=3660 all=55338 active=3033 piece=▁indep
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=294 size=3680 all=55414 active=3109 piece=▁lecture
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=292 size=3700 all=55481 active=3176 piece=▁finger
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=292 min_freq=106
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=290 size=3720 all=55557 active=2847 piece=▁reservation
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=286 size=3740 all=55608 active=2898 piece=▁crush
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=283 size=3760 all=55717 active=3007 piece=nel
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=281 size=3780 all=55867 active=3157 piece=ians
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=277 size=3800 all=55949 active=3239 piece=iety
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=277 min_freq=103
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=276 size=3820 all=56012 active=2855 piece=▁relatives
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=274 size=3840 all=56156 active=2999 piece=▁divided
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=271 size=3860 all=56313 active=3156 piece=▁entered
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=269 size=3880 all=56449 active=3292 piece=▁stood
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=266 size=3900 all=56573 active=3416 piece=▁ordinary
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=266 min_freq=98
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=263 size=3920 all=56652 active=2908 piece=▁toe
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=261 size=3940 all=56724 active=2980 piece=▁thri
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=258 size=3960 all=56825 active=3081 piece=▁prose
# trainer_interface.cc(615) LOG(INFO) Saving model: spmenc_r0.model
# trainer_interface.cc(626) LOG(INFO) Saving vocabs: spmenc_r0.vocab
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=/aiffel/aiffel/aiffelthon/corpus_dec.txt --model_type=bpe --pad_id=0 --bos_id=1 --eos_id=2         --unk_id=3 --model_prefix=spmdec_r0 --vocab_size=4000         --user_defined_symbols=<jj>,<jd>,<gs>,<cc>,<kw> --remove_extra_whitespaces=false
# True
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /aiffel/aiffel/aiffelthon/corpus_dec.txt
#   input_format:
#   model_prefix: spmdec_r0
#   model_type: BPE
#   vocab_size: 4000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: <jj>
#   user_defined_symbols: <jd>
#   user_defined_symbols: <gs>
#   user_defined_symbols: <cc>
#   user_defined_symbols: <kw>
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 3
#   bos_id: 1
#   eos_id: 2
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 0
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(329) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(178) LOG(INFO) Loading corpus: /aiffel/aiffel/aiffelthon/corpus_dec.txt
# trainer_interface.cc(140) LOG(INFO) Loaded 1000000 lines
# trainer_interface.cc(117) LOG(WARNING) Too many sentences are loaded! (1065270), which may slow down training.
# trainer_interface.cc(119) LOG(WARNING) Consider using --input_sentence_size=<size> and --shuffle_input_sentence=true.
# trainer_interface.cc(122) LOG(WARNING) They allow to randomly sample <size> sentences from the entire corpus.
# trainer_interface.cc(385) LOG(INFO) Loaded all 1065270 sentences
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <jj>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <jd>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <gs>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <cc>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <kw>
# trainer_interface.cc(405) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(466) LOG(INFO) all chars count=31560670
# trainer_interface.cc(477) LOG(INFO) Done: 99.9502% characters are covered.
# trainer_interface.cc(487) LOG(INFO) Alphabet size=1488
# trainer_interface.cc(488) LOG(INFO) Final character coverage=0.999502
# trainer_interface.cc(520) LOG(INFO) Done! preprocessed 1065270 sentences.
# trainer_interface.cc(526) LOG(INFO) Tokenizing input sentences with whitespace: 1065270
# trainer_interface.cc(537) LOG(INFO) Done! 716525
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=571271 min_freq=240
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=82540 size=20 all=150007 active=13416 piece=▁보
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=54391 size=40 all=154664 active=18073 piece=▁게
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=41432 size=60 all=158216 active=21625 piece=▁이름
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=32150 size=80 all=164871 active=28280 piece=▁니
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=26735 size=100 all=169101 active=32510 piece=▁요
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=26543 min_freq=204
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=23443 size=120 all=172612 active=11767 piece=▁있는
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=18839 size=140 all=175429 active=14584 piece=▁비
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=16255 size=160 all=180580 active=19735 piece=▁재
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=14556 size=180 all=184188 active=23343 piece=더라고
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=13523 size=200 all=188441 active=27596 piece=▁도
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=13443 min_freq=179
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=12430 size=220 all=191457 active=12192 piece=▁불
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=11250 size=240 all=194975 active=15710 piece=이야
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=10375 size=260 all=198986 active=19721 piece=▁어떻게
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=9576 size=280 all=202556 active=23291 piece=▁몰
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=8911 size=300 all=205370 active=26105 piece=▁사람이
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=8904 min_freq=158
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=8382 size=320 all=208460 active=13273 piece=▁관
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=7943 size=340 all=211189 active=16002 piece=▁보면
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=7411 size=360 all=214524 active=19337 piece=▁맨
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=7093 size=380 all=217559 active=22372 piece=▁갖고
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=6839 size=400 all=221336 active=26149 piece=▁따른
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=6831 min_freq=143
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=6566 size=420 all=223389 active=13103 piece=▁명
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=6173 size=440 all=225969 active=15683 piece=▁둘
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=5880 size=460 all=228566 active=18280 piece=▁외
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=5612 size=480 all=231306 active=21020 piece=▁혹시
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=5395 size=500 all=233750 active=23464 piece=▁그러면
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=5390 min_freq=133
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=5148 size=520 all=236108 active=14037 piece=부난
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=5014 size=540 all=238081 active=16010 piece=▁결혼
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4854 size=560 all=240345 active=18274 piece=▁여행
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4693 size=580 all=242909 active=20838 piece=▁별로
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4528 size=600 all=245487 active=23416 piece=▁워
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=4523 min_freq=124
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4295 size=620 all=247224 active=13933 piece=▁후
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4168 size=640 all=248653 active=15362 piece=▁문제
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4026 size=660 all=249708 active=16417 piece=▁보는
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3817 size=680 all=251356 active=18065 piece=▁그서
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3655 size=700 all=253785 active=20494 piece=했어
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=3651 min_freq=117
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3526 size=720 all=256026 active=14504 piece=▁있지
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3442 size=740 all=258319 active=16797 piece=▁건강
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3333 size=760 all=259881 active=18359 piece=▁누가
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3202 size=780 all=261489 active=19967 piece=이지
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3076 size=800 all=263429 active=21907 piece=▁생각하
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=3054 min_freq=111
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2981 size=820 all=265423 active=15055 piece=▁왜냐면
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2888 size=840 all=267742 active=17374 piece=▁지나
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2825 size=860 all=270643 active=20275 piece=▁때도
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2765 size=880 all=272507 active=22139 piece=▁스타일
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2704 size=900 all=273901 active=23533 piece=그네
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=2702 min_freq=105
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2630 size=920 all=276176 active=15747 piece=▁안되
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2536 size=940 all=279135 active=18706 piece=▁채
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2483 size=960 all=281312 active=20883 piece=▁칠
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2429 size=980 all=282967 active=22538 piece=▁이름씨
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2348 size=1000 all=284520 active=24091 piece=▁한국
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=2346 min_freq=99
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2291 size=1020 all=286598 active=16209 piece=▁운전
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2235 size=1040 all=288662 active=18273 piece=▁베
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2191 size=1060 all=290995 active=20606 piece=▁트
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2137 size=1080 all=292158 active=21769 piece=▁쳐
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2072 size=1100 all=293992 active=23603 piece=레스
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=2065 min_freq=95
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2013 size=1120 all=295827 active=16441 piece=한데
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1970 size=1140 all=298201 active=18815 piece=▁늘
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1938 size=1160 all=300244 active=20858 piece=▁말씀
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1882 size=1180 all=301539 active=22153 piece=▁보면서
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1859 size=1200 all=302631 active=23245 piece=간에
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1857 min_freq=91
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1830 size=1220 all=304104 active=16489 piece=스럽
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1806 size=1240 all=306024 active=18409 piece=마씸
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1776 size=1260 all=307597 active=19982 piece=▁자신
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1742 size=1280 all=308852 active=21237 piece=하는데
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1716 size=1300 all=310303 active=22688 piece=▁괜찮은
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1714 min_freq=87
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1691 size=1320 all=311963 active=17159 piece=▁집이
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1658 size=1340 all=313606 active=18802 piece=▁컴
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1626 size=1360 all=314672 active=19868 piece=▁안에
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1582 size=1380 all=316563 active=21759 piece=▁나라
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1563 size=1400 all=317916 active=23112 piece=▁브
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1560 min_freq=84
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1532 size=1420 all=319032 active=16976 piece=까지는
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1509 size=1440 all=320836 active=18780 piece=▁고기
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1483 size=1460 all=322421 active=20365 piece=▁내용
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1462 size=1480 all=323781 active=21725 piece=▁니네
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1441 size=1500 all=325491 active=23435 piece=▁어렵
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1440 min_freq=81
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1423 size=1520 all=326641 active=17348 piece=▁행복
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1401 size=1540 all=327814 active=18521 piece=▁뭐라고
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1387 size=1560 all=329837 active=20544 piece=▁좋지
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1368 size=1580 all=332159 active=22866 piece=▁우린
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1345 size=1600 all=333443 active=24150 piece=▁어뜬
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1344 min_freq=78
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1324 size=1620 all=334484 active=17691 piece=도록
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1307 size=1640 all=335975 active=19182 piece=▁유튜
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1291 size=1660 all=336989 active=20196 piece=치가
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1274 size=1680 all=338713 active=21920 piece=던지
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1256 size=1700 all=339983 active=23190 piece=물이
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1256 min_freq=76
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1242 size=1720 all=341674 active=18484 piece=▁상태
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1223 size=1740 all=343969 active=20779 piece=▁도움
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1214 size=1760 all=345473 active=22283 piece=▁택
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1196 size=1780 all=347293 active=24103 piece=▁생긴
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1181 size=1800 all=348622 active=25432 piece=▁약속
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1181 min_freq=73
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1171 size=1820 all=349714 active=18458 piece=▁오빠가
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1150 size=1840 all=350880 active=19624 piece=▁구만
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1140 size=1860 all=351797 active=20541 piece=에다
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1126 size=1880 all=352949 active=21693 piece=그램
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1112 size=1900 all=354301 active=23045 piece=었거든
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1112 min_freq=71
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1100 size=1920 all=355653 active=18916 piece=▁다니는
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1083 size=1940 all=356670 active=19933 piece=▁싹
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1071 size=1960 all=357486 active=20749 piece=▁뒤에
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1058 size=1980 all=358533 active=21796 piece=▁나으
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1044 size=2000 all=360132 active=23395 piece=▁으제
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1044 min_freq=69
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1036 size=2020 all=361610 active=19470 piece=▁최고
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1022 size=2040 all=362863 active=20723 piece=▁그걸로
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1007 size=2060 all=363687 active=21547 piece=▁자연
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=997 size=2080 all=365351 active=23211 piece=▁셋
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=988 size=2100 all=366970 active=24830 piece=하신
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=987 min_freq=67
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=976 size=2120 all=368373 active=19495 piece=▁고맙
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=964 size=2140 all=369700 active=20822 piece=▁쪼매이
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=955 size=2160 all=370783 active=21905 piece=▁당장
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=946 size=2180 all=371828 active=22950 piece=수과
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=938 size=2200 all=372865 active=23987 piece=사는
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=937 min_freq=65
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=927 size=2220 all=374333 active=19917 piece=▁재기
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=916 size=2240 all=375490 active=21074 piece=▁지난
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=903 size=2260 all=376836 active=22420 piece=▁꽤
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=895 size=2280 all=377578 active=23162 piece=▁특별
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=881 size=2300 all=378859 active=24443 piece=▁보자
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=881 min_freq=64
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=874 size=2320 all=379989 active=20039 piece=▁염
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=865 size=2340 all=381255 active=21305 piece=▁데는
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=853 size=2360 all=382539 active=22589 piece=▁거죠
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=847 size=2380 all=383807 active=23857 piece=▁발싸
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=839 size=2400 all=384745 active=24795 piece=▁데서
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=839 min_freq=62
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=832 size=2420 all=385706 active=20186 piece=▁사실은
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=820 size=2440 all=386708 active=21188 piece=▁기다려
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=813 size=2460 all=387603 active=22083 piece=두고
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=805 size=2480 all=388906 active=23386 piece=▁만드는
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=799 size=2500 all=389910 active=24390 piece=▁야이
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=795 min_freq=61
# trainer_interface.cc(615) LOG(INFO) Saving model: spmdec_r0.model
# trainer_interface.cc(626) LOG(INFO) Saving vocabs: spmdec_r0.vocab

# %%
enc_corpus
# Out:
# ['it s not too much .',
#  'i mean when i m in elementary school if i m done in fifth',
#  'its very implicit so something',
#  'he s a handsome guy so . . .',
#  'so it s kind of a little bit of a everyday',
#  'she s working on the branches .',
#  'no matter how angry i am how can i say that ?',
#  'i ve been bringing my husband here lately .',
#  'the door is always open in the house of my student jeju grandmother',
#  'its a bit disappointing that i can come by looking at the trip only there',
#  'his friend came down and decided to rent a truck in gwangju then',
#  'i want you to do two pieces of omlinkle two pieces of bolconos like this .',
#  'i didnt know before marriage',
#  'these are songs that you can humme so i think you like them a little',
#  'i don t know so if you think about what you re doing that would be a good idea .',
#  'there s a lot of people in the long run .',
#  'oh why did you write a colored one or did you reflect the one that was too thick and fall down',
#  'ive never seen him late before',
#  'i put it in a pot there and i ate it and i finished it .',
#  'imashing it so when did you wash it i got water and scratched it',
#  'but hye jin came out with a tube just like this .',
#  None,
#  'so your friends didnt play so im sure ill be at home',
#  'i can tell you about my personality but when i talk about other peoples personalities i especially have to fix the personality of that person',
#  'we still don t know the th of what nature has shown us .',
#  'it may be because its just compared to you but if i ordered it to me i would',
#  'so this is kind of similar to other things',
#  'the garlic smells really bad',
#  'dont you have a ring',
#  'oh i asked her to send someone to me because i had something to do with ari .',
#  'you re my boss but in this case it s a team thing .',
#  'it s good if you make money .',
#  'since i have only one sister im a little unusual about her relationship',
#  'i told you not to come home and now i m telling you it s over .',
#  'are you sure you don t want to see us ?',
#  'because chinese cant come',
#  'its a little bit like that i help you a little bit',
#  'thats how you did it sharp',
#  'they shot an arrow with the enemy and pulled the boat back on the wall',
#  'when i was in high school time really didnt go by and i was wondering when i would graduate and enjoy freedom',
#  'what he means to me .',
#  'it seemed to be of no use at all .',
#  'give me anything .',
#  'then my brother pushed me before i came to the sacrifice .',
#  'city hall',
#  'so there s something you re talking about .',
#  'i don t think there s yet a site that s so organized like albamon .',
#  'hey but if its name you wont be able to wear it in a few years does he need to buy such expensive ones',
#  'so wow really but really',
#  'isnt weight training right now so its all called weight training in foreign countries right',
#  'movie stars are good at movies and doesnt they are good at dramas',
#  'the man who had never loved a woman who was apathetic .',
#  'dont you put a little more water in the dough like that',
#  'it s a long term emergency . i can t do a hundred copies of the print .',
#  'but if you don t get this early',
#  'are you still eating ?',
#  'my personality is to endure this even if i want to i sleep well and im going to be comfortable',
#  'if you want to make him send him to the name three .',
#  'i couldn t take a shower this morning .',
#  'maybe a little foreign but i didn t fit in a little bit with the rest of the world .',
#  'they see it as a competition and make extreme choices .',
#  'i cant even pack it anymore',
#  'you re a bitch . now you re a bitch .',
#  'i ve just got a t shirt . it s just a horse . it s just like this .',
#  'i dont do much acidity and i dont do much acidity',
#  'i can t give up on you until now .',
#  'i m not sure .',
#  'if you go to the dock below it it was very big if you go a little bit toward my house at this time',
#  'you have to eat evenly and eat meat well and this is what you have to do',
#  'but you re the second since he told me he s got that label .',
#  'but i can t use all the data because it s a white flag in a month .',
#  'and if you keep giving it to me if i keep giving it to you',
#  'don t worry about that because if you need to hire a temporary employee you ll be able to finish it in the deadline .',
#  'you don t need to know that .',
#  'i don t think it s a fall these days .',
#  'for selfsatisfaction i kept wearing it and i wore it and i asked you to do this',
#  'it s amazing how you feel .',
#  'i m too busy today .',
#  'i just kind of bought a lot of what i wanted to do because i ve bought or of them .',
#  'it s actually two fundamental mistakes .',
#  'if you get that kind of apology for your kid you let him go .',
#  'when you have menstruation your body is all swollen',
#  'didn t you forget about dinner ?',
#  'puta and then for the customer wait a minute',
#  'the performance has fallen a lot',
#  'isn t that a story we haven t talked about for a while ?',
#  'i just don t know how to get past it so i think it s been a month .',
#  'when i looked at it i said that professor too',
#  'itis good to be with friends but its not that i think they tend to do it a little bit',
#  'then dont tell me let me put it on the plate',
#  'i don t know .',
#  'im going to the mountains today',
#  'what bitch ?',
#  'yeah you know if i catch you this way i think it s gonna be okay .',
#  None,
#  'i think i ve had a lot of fun in my life .',
#  'my little girl lives with my little girl in her mouth for a day .',
#  'if you eat that taste open',
#  'that s how i got married .',
#  'oh what if you get addicted so i dont think you can get addicted its okay what do you say',
#  'yeah and then again and then again .',
#  'i can also sympathize with him a lot',
#  'he s lost and he s still having a hard time with it .',
#  'yes i saw yesterday and the high school student was confirmed oh my',
#  'i ve never used an x ray before but i ve been studying to learn how to write computer notes so i don t know anything .',
#  'i m just gonna make money .',
#  'if you save a lot of money a month for a date bankbook you can use it with that money and you may feel a little awkward when paying',
#  'dad s note is real not a threat to my family .',
#  'that photo razor blades look similar to electronics',
#  'do you have any seafood allergies',
#  'i dont like watching dramas a little bit and like listening to them like this right name',
#  'do you live at home ?',
#  'and then we re going to have a little bit of that vitamin .',
#  'i think ive hidden something inside and did a gift that could be a little surprising',
#  'if you hit him he ll be gentle .',
#  'i don t want to get paid so if you get paid pay it back at once .',
#  'so among stocks these days a little',
#  'that was my first play i saw it eight years ago',
#  'is this really silver ?',
#  'rather than spending time drinking and drinking having a good meal',
#  'it s a little bit like running at home .',
#  'i m sure you re going to have a medical checkup now but i m sure you re going to have to take a full medical exam .',
#  'i want you to be able to put something in there like this .',
#  'i think i ve never seen you so angry .',
#  'the sabula kept on angling these days',
#  'you re such an idiot . you did this .',
#  'is that your mother ?',
#  'do you know this guy ?',
#  'i think i had a hard time because the food didnt suit my taste when i went to china',
#  'it s only from your point of view that you can go to her house .',
#  'i still do a small ball exercise',
#  'you need to come to our office and put it in our application .',
#  'even if you re not married can you do it that way ?',
#  'they ve dealt a lot with the pollution in the course of three years .',
#  'grandmother plum sellers and grandmothers who sell garlic in the countryside',
#  'what do you say to your sister ?',
#  'what are you doing',
#  'of course the name of the title is like that so i think it has outstanding advantages and again',
#  'you don t have children to beat .',
#  'imaturely eat snacks',
#  'he said that so hes singing all the stars',
#  'until the end of the covid situation i was definitely a little reluctant to go to the pc room',
#  'so the people of broadcasting companies are amazing',
#  'thats right so if you think about it now its really bad',
#  'how many times do i have to change the train to get there ?',
#  'i ve seen it in one eye .',
#  'i do . i feel the vibrations in my bed .',
#  'born and raised in jeju island and learned from parents is a really good thing',
#  'so im a little worried',
#  'oh but that was a little bit like that if we bought three we gave about five dumplings',
#  'i thught i like a gorangang character actually a friendly person is more',
#  'tell your son to do it .',
#  'sometimes there was a time when the car came by and the car just came by .',
#  'everyone is like that they all live the same thing who am i or who am i',
#  'no i said i said you should unite all at once because you have deposits at the end of the year',
#  'in a way the military so one that turned the game upside down in the history of war',
#  'so now i m going to connect with itunes and then i m going to put in a song and sometimes i m going to say',
#  'be a good boy .',
#  'i want you to call me the name . that s my name .',
#  'that s what he wrote .',
#  'this is so i',
#  'if you win a fight you get a smile .',
#  'she gave birth to a baby last year',
#  'then what about the parttime job i throw it away thats right thats not it so',
#  'i have to eat dinner .',
#  'because the windows are big the sun shines through the room .',
#  'come with me . come with me . i ll assist you . come with me .',
#  'of course i m the first one .',
#  'what are you saying',
#  'the bride is dressed up nicely .',
#  'it s cheaper than baseball than a screen .',
#  'on the right hand side there s a rock .',
#  'your father couldn t raise his face .',
#  'he said you were a student . you re a student .',
#  'but this is what i just did a little bit of exercise when i was a kid .',
#  None,
#  'i think it s right that you don t really have one .',
#  'so i can t stop and i m just trying to keep looking for new songs and i m just trying to hear that song .',
#  'i think that scene is the most cool scene',
#  'you re just putting a lot of stuff on youtube . have you seen that ?',
#  'if you can t even take care of your mother you can t do that .',
#  'ive never met a true customer',
#  'no leaves .',
#  'so so the more you go to school and go outside',
#  'oh my god . why are you here already ?',
#  'about three years ago i moved to an expansion and i want to raise a little student',
#  'feel like you re left alone in this dark cold classroom .',
#  'mr . fisher are you listening ?',
#  'oh like my grandfather .',
#  'if you do that thing over there you ll do it again and then you ll do it again .',
#  'so wow but it was a little amazing that i had no choice but to do well when i did something like that in the military',
#  'why are you so scared ?',
#  'i did that but im particularly',
#  'anyway while i was lying there sick',
#  'well they re coming with us now aren t they ?',
#  'i mean i ve heard it really hard but . . .',
#  'i was going to take care of it but i couldnt but it was because of the kid',
#  'i don t know what s wrong with you but i ll call him .',
#  'you even had your eyes in it right',
#  'so i hum at home but i cant go there',
#  'i was so scared of the snow .',
#  'i think im having a little fun',
#  'so are you hurt',
#  'there are a lot of people who are similar to the actors there',
#  'i hope i find a new hobby like resin art like you',
#  'maybe time has passed a little bit .',
#  'honey stop it .',
#  'aren t we actually a little far from that ?',
#  'manizer was korean .',
#  'when we were young what kind of people live in such a house',
#  'the lights don t turn on the lights light up which is why they re so beautiful but they re so beautiful .',
#  'its one of the three world festivals',
#  'if i can study again its okay to work hard again',
#  'we are using this two rooms and a kitchen',
#  'i don t drink very well these days because of the arrhythmias but i m older .',
#  'some people accept it like this because i think its because of your personality problems',
#  'i think my mom bought a lot of things like that',
#  'i was surprised by the feast xx i saw it in the morning and saw it let me know',
#  'it s a wild rabbit isn t it ?',
#  'wow youve been there a lot',
#  'but i hope there was a veranda like that that shines well in the apartment',
#  'wheres a little bit of pork and won',
#  'i only thought i should save a little money and get married now',
#  'i feel like i m looking all over the place without my eyes in one place .',
#  'god listens to our title over there and the rest are all of that office worker',
#  'i received it in cash when i was working',
#  'he d say what did i do to give you a little something like this ?',
#  'the doctor called me later .',
#  'the streets were snowed centimeters .',
#  'stop talking shit .',
#  'so everything is luxury goods makers or brands',
#  'i remember playing really hard when i was in middle school .',
#  'yeah ill stop coming',
#  None,
#  'the project is going well .',
#  'it s gonna be harder to go to extreme diets .',
#  'there should be a seat or something like that but my husband has a seat in it so im like this person',
#  'do you like spicy stirfried chicken or spicy buckwheat noodles a little bit',
#  'is it still a good idea that he left the baby ?',
#  'then i used to like rice i really liked carbohydrates i ate well just by eating rice and kimchi',
#  'just hurry up and hurry up and do it',
#  'it s called the central aru beach . it s a very famous beach .',
#  'dont call me because ill go in before work',
#  'but i had something like that im going to ride a sports car later',
#  'why don t you do something stupid and do something right and laugh ?',
#  'if you go on a trip you have to eat food you die if you dont eat korean food for a week',
#  'its a really good hobby',
#  'since then you ve been living in hong kong with a little a little bit of force and a little distance .',
#  'i asked one more time but i didnt answer',
#  'also i think there will be a lot of changes in the good aspects and disadvantages',
#  'oh i think its weird so i just do it and habitually put the padded jacket in my outerwear',
#  'if you treat it that way i don t think i m going to get married either .',
#  'she said she got it so once you got it on your phone you got it .',
#  'a small guy eats a lot',
#  'you look weird .',
#  'itll be absolutely necessary so i have one person with yangjae i have two persons with yangjae',
#  'perhaps something like that',
#  'long term conflict barely ended .',
#  'you get a little cold you get a lot of colds you get a lot of cold pills .',
#  'get out of the way .',
#  'there were people who came over at night just to get drunk .',
#  'honey can i not leave the department store tomorrow ?',
#  'my face is so big that i look a little fleshy on my face and everything looks fleshy on my face from then on',
#  'theres a time when i have time to spare thats only a few days all day',
#  'i ll be back .',
#  'it s what it is isn t it ?',
#  'they re hanging around like pigeons .',
#  'there are so many things like time stirring or not to knead a lot',
#  'if she calls you',
#  'i went there because i had a sex education class',
#  'theres a player named anteto kumbo so this person is now',
#  'no i went around like this',
#  'it s not often but i think i ve done it a little bit .',
#  'i understand what they re doing but they ll think differently .',
#  'oh its a little different i thought thats not right',
#  'the gums and tongue to touch the teeth like this',
#  'hey i went to the company name and now it s it s famous .',
#  'theres nothing to be devastated but youre not working right now so if you work later youre busy and can afford it',
#  'my mom ironed me out and i gave birth to a child',
#  'i thought it was a fries of colpop',
#  'don t use a brush . write it as a pen .',
#  'i understand .',
#  'there were many cultural differences in those cultures',
#  'that s what i m talking about .',
#  'i know . i know . i know what it is .',
#  'anyway i cant walk back and forth from the warehouse',
#  'after that there are several people following them secretly',
#  'you don t have to study harder .',
#  'okay i ll call you .',
#  'i wope you changed the logo of chevrolet a little bit and its kind of like this',
#  'and they said',
#  'iveathed others but im somewhat materially comfortable',
#  'i cant see well when i just do it so if i boil it i can see it better',
#  'so green onions are a little okay these days',
#  'dude i m suddenly in a state of need .',
#  'what s wrong with you girl ?',
#  'i didn t do it today . i did it last night and i ve been doing it for a couple of days .',
#  'but it was good to use',
#  'now i ve heard a lot of it .',
#  'hey but did you have a cell phone then',
#  'it s not that bad .',
#  'theres that too dance academy is a bit pricey',
#  None,
#  'but then you said you weren t pretty .',
#  'my husband is a little more delicate than the seed and so on and so forth .',
#  'i middlemade her to say no',
#  'that s why i m able to live in unity so to be honest i m going to live in unity .',
#  'i have to keep going . is it gonna be okay if i keep going ?',
#  'you ve never done this before .',
#  'other rappers used to like swings a long time ago',
#  'thats how he did it',
#  'i thasked if there was almost nothing if i had eaten or if there was nothing if i didnt fall off',
#  'five four three two one zero .',
#  'okay i ll see you later .',
#  'didn t she just like you ?',
#  'if you go there there are people who catch the meat on the ice',
#  'that s right . she s totally sad when she s three .',
#  'so this is just',
#  'unlike the essence of the webtoon its a little bit',
#  'is it supposed to be for the purpose or is there something like that',
#  'wakat up what i should do now and then quickly this covid',
#  'if he s a pastor right now he s worse than him .',
#  'are you okay ?',
#  'but the one you mentioned earlier is the university club',
#  'i havent decided yet please wait a moment',
#  'just a little bit and if you don t get caught just close your eyes and pretend you don t .',
#  'i mean i talk about money every day and it s a little rough .',
#  'why do you ask for a gift ?',
#  'just a little bit .',
#  'im going around to take care of the elderly',
#  'they re just gonna have to open up the hospital later .',
#  'with a smile on the site have you tried yoga',
#  'i hid the daughterinlaw and hated the daughterinlaw',
#  'it s very very very depressing these days .',
#  'i couldnt tell you about my employment with that document',
#  'and why are you only asking for one of them with a yearold title',
#  'but my sister s too big for a cat .',
#  'the arm is naturally put down under the knee .',
#  'i ll take care of it .',
#  'it s like you re a squeamish mom again .',
#  'so i have conditions for this too',
#  'i don t think it s going to grow any more cause i m saying it s eating a little less and it s going to grow a little less .',
#  'i m going to study in windows today . quiet man .',
#  'well that s too much . is there any more to it ?',
#  'oh the old grandmothers said that the world is done the world is done it seems like the world is done by doing it',
#  'why did you ask me to pay like that so i just said yes yes',
#  'i assess it but it was also when i was very young so i wasnt in my s',
#  'should we do this many these days kids',
#  'i ve never seen anyone who can t be like my brother .',
#  'its from samsung so',
#  'uh it s a little rough it s got a lot of new designs .',
#  'it s all winter so i m wearing a coat .',
#  'its a combination of the military',
#  'you re the one who says it s gonna be a little better if we change this part too .',
#  'sit down .',
#  'let s do it on days .',
#  'what does the cold brew feel like',
#  'yeah you must be tired . i m just driving a cab .',
#  'its energy to spring up while eating the food at home the two of me and my name father',
#  'you have to put the card in here so you dont know if you have to put it over there',
#  'i wrote too well .',
#  'you daehyeop is over or so but he is so tall',
#  'but im still fortunate this for no reason',
#  'you re watching . if you suddenly find something like that it ll cool off immediately .',
#  'then i ll be noticed by people a little later and i ll be frustrated .',
#  'that s what s next when you tell me you re coming with you all at once .',
#  'you were totally cutie',
#  'maybe the average high school in seoul went down because of us .',
#  'it s a good day to get out of here .',
#  'yeah well i went to the anus and then i stopped by the house and said',
#  'this vibration comes right away and in the case of drawing text messages or kakaotalk it contacts you right away',
#  'so i thought it was a pig i saw it a long time ago',
#  'yeah i m here and this is a credit card receipt .',
#  'either way we don t have any money .',
#  'i think its a little bit seasoned because you drink prickly',
#  'he would have slept on the bus then',
#  'teach me how to go to the tourist center .',
#  'now ill do it because i helped you with the right performance',
#  'i think its okay ill look for a lot of laughter and take it out',
#  'there is nothing i really got from it nothing i lost',
#  'i think its good to just match it right so i dont have to have it i might have been born without it but i dont think its good',
#  'it s better to eat less salty soup .',
#  'go ahead and sit here',
#  'who s gonna buy it ?',
#  'i was going to try and make sure i didn t but they gave me a little bit of money .',
#  'and then he says it s ridiculous and he just says it s too expensive for million dollars .',
#  'what s your next week s schedule ?',
#  'so you re bigger than that .',
#  'i explained it for a long time and youre hungry is there anyone who wants lunch today',
#  'you put two legal laws together and your granddaughter is in the middle of an international country where it s hard .',
#  'don t you think it s really good when you put that in and you do this stuff ?',
#  'when i dont think about how good it would be if i come',
#  'and on the bucket list .',
#  'did you know what the korean teacher said',
#  'where do you check ?',
#  'i ate the meat and the kids gathered together to play card games and it was really fun then',
#  'then we have to engage a lot now so were going to the growing jungle and the ap jungle',
#  'now im reflecting on myself',
#  'oh thats right then ill too',
#  'once upon a time there was a pig bank .',
#  'im not standing up if the kid pulls the queue to go i wont look at me',
#  'i dont like things like that',
#  'you just have to wrap it up a little bit .',
#  'like youre doing things like that you know what to do now do you have things like this',
#  'we re not going far .',
#  'but after i made it i dried it out but yours is okay',
#  'i should ve known where i was going to be a maid .',
#  'i thought about the looking child while watching it',
#  'the boss called me in person .',
#  'since i did that for about a month or two this loses a lot of weight',
#  'and when i saw a movie on the night of the night',
#  'then again physical education class and physical education class',
#  'if you learn how to do your own knowhow to be honest its too natural to say its knowhow',
#  'it s delicious mom .',
#  'im tired and thirsty to speak',
#  'i wanted to try it so i looked for it a little bit',
#  'ac so i tried writing my brotherinlaw',
#  'but now i had a gene that was handsome tall and kind of good but my legs were cut off because of an accident',
#  'what do you say ?',
#  'what should i say there are foods that crave when youre on a diet',
#  'youre not just saying as you say your mouth is bursting do you pay for your age',
#  'the mulberry is popping out its pretty right',
#  'what do you want to eat ?',
#  'and now i m pretty good at it .',
#  'but i remember enjoying it a little bit because i liked everything',
#  'you know when people saw this they were just like',
#  'anyway i was stuck so i thought i blocked it and kicked him out of my life but im still',
#  'or was there anything difficult or something like that you were so old or something',
#  'so if you bring that kind of fussages',
#  'when i caught him like this or whatever he seemed so nice .',
#  'oh but they say its hard to fit my aptitude',
#  'blew shirts and the ballpointen debris on blouses are removed by rubbing them with waterfare .',
#  'imired that i wont even wear a coat in winter because of my lover who is in a cold place',
#  'what the hell was that eye ?',
#  None,
#  'so i dont like shopping a little',
#  'in the end he tentatively dropped out and he communicated with him but is it still coming out',
#  'so i dont have anything special',
#  'there was a book that i wanted to read a little bit',
#  'i can t speak right now .',
#  'because in jejudo you have to have one of those shirts .',
#  'i hate you .',
#  'where are you going ?',
#  'and then the baby gets brighter and then you have your little time and just like you have time so i m over time and then they burst apart .',
#  'and that michael jordan you mentioned earlier you re not doing it at netflix .',
#  'no i always did it without saying it',
#  'don t get upset about her . we can just go . let s go .',
#  'grandma i m sorry .',
#  'don t you think that s the only way to buy a lottery ticket ?',
#  'then if i get a statue i dont have to serve in the military anymore',
#  'i think its a little exaggerated',
#  'yeah i actually like it yeo movies especially art so like you said',
#  'oh my god i didn t just broadcast today .',
#  'you can say that gian palsa who seems to be a little often on tv is a little like that',
#  'if you re going to ride a car you don t know how to write it and if you re going to ride a few times you re going to count the character .',
#  'you got any snacks ?',
#  'and what else did you say there was ?',
#  'your family raised it really well but your mom said that your mom is like that and other peoples attention is also very important',
#  'its getting shorter so you have to go and go quickly',
#  'look i want you to live here .',
#  'i awaited a lot of things like that so if i went to a whole thousand won but i really liked the teacher here',
#  'i ll be back sometime with your chef .',
#  'if i pick my mother ill just be the head of the table',
#  'iveathe ive arranged a special',
#  'for example skirt knee exercise and thigh exercise',
#  'oh then thats enough',
#  None,
#  'i ve had enough of it when i m writing . just get the table out of my mouth .',
#  'there s a lot of kids out there who got hit .',
#  'are you gonna say that ?',
#  'i ve had a very pleasant lunch today since you came out .',
#  'its been a while since i started in the early stages',
#  'are you worried i m gonna lose ?',
#  'in the case of damage assessment work of personal insurance the intensity is high',
#  'it rained during the day and at night it turned snow .',
#  'but what happened to yours ?',
#  'i think that s the right thing to do because i m a little timid .',
#  'that s why you re telling me everything .',
#  'who are these people ?',
#  'in front of him he s an extrovert and he s doing this .',
#  'if you win the first place you will get the best excellent and encouragement awards',
#  'i think she s coming too slowly .',
#  'so i just went into my moms room and was shocked',
#  'i gave you half a million dollars .',
#  'i thought i was gonna die lying .',
#  'i can t pretend i didn t know she was in our blood .',
#  'that s what we re talking about .',
#  'isnt it natural',
#  'why are you doing that ?',
#  'so you know what ?',
#  'i ve been going to the hospital lately because of the stomach but i m busy and i don t have time to go .',
#  'i ve been in a general unit and i ve got an audition and i ve been discharged .',
#  'i think i can heal a little bit while watching it',
#  'i should have been suspicious and wary from the beginning .',
#  'the seasoning was a little bit',
#  'i don t think it s because of the burial .',
#  'good so i barely go and see it even when i dont have time',
#  'im actually a blunt stranger',
#  'i heard you talking to your father and your father .',
#  'i m gonna sell it here and i m gonna bite it all up like this and i m gonna look like it s cotton inside .',
#  'clean the rooms in the room quickly again',
#  None,
#  'i dont think ive heard of it through word of mouth and bought it because its good',
#  'i realized i could be meaningless .',
#  'so i m like uh eating like this and dieting like this .',
#  'what did you just say ?',
#  'why my father ?',
#  'it ll be very stressful for you to do this when your spouse s shaking a little bit by the side of the street .',
#  'oh is that really too much for me to remember ?',
#  None,
#  'im going to do parasailing now',
#  'i did that oh my god right marriage and marriage',
#  'there was a place in the middle of the mountain where i raised a black pig in about three thousand acres .',
#  'werent you going to the bank over there',
#  'there are about to minutes left',
#  'well do you uh you know do you think you re gonna need some of the idols ?',
#  'she s staring at her shirt .',
#  'dont you intend to change it',
#  'the stars are bright and warm but i think they re right .',
#  'yesh i mean i gave birth a little late i gave birth at the age of so i laughed',
#  'there s a computer and a body attached to one .',
#  'eurachacha waikiki too which was taken a long time ago and delivered to there',
#  'she s good at memorizing .',
#  'she thinks we re on the same age as the but she s like a daughter .',
#  'where did this come from ?',
#  'yes its in the top four or five people including the teacher so i expired for a period in front of it and cut it off every three months',
#  'what its because the boy went and said i was wondering if he would turn on the lights so i was there at first and said yes',
#  'your mother .',
#  'they say they make a lot of money a day',
#  'she had an extraordinary talent for painting',
#  'you told me last time i heard that you would file a complaint with kim chang so i thought about it too',
#  'the story of the race is equally bold .',
#  'there s been a lot of crazy going on this trip .',
#  'since youre not old how did you pay at home',
#  'it was clogged so i cut both rims with scissors and made air holes and used them',
#  'the cargo is stuck',
#  'how about this ?',
#  'the paint was peeled off at the part where the table touched the wall',
#  'you re gonna have to be very careful . you re gonna have to be really serious .',
#  'other than that it may be a hobby that is the same but it doesnt help anymore',
#  'theres a procedure and since im a manager i know more than i do but',
#  'don t be late until eight o clock in the evening .',
#  'i cant even sell alcohol now and its turned into a clean festival right',
#  'i attempt to cook ramen but kimchi',
#  None,
#  'i cant say good things',
#  'it s not good when you re in the water .',
#  'yeah it won t be long .',
#  'what should i say if i explain that shape',
#  'i was really surprised at that time i wouldnt have been arguing about my situation at that time it was so serious',
#  'its really not as good as it used to be',
#  'there s a lot of things that get a little bad .',
#  'even then',
#  'i don t know what the name is .',
#  'i ll tell you later .',
#  'we used to pull beef ribs and burn them',
#  'who takes a picture and love love love is written in front of the coffee',
#  'i think the big toe is genetic .',
#  'so even if you put it in your ears you dont listen to it and even if you sing a song you smile at me so you rarely listen to it',
#  'you can do it for dogs and when youre a little stressed or depressed',
#  'the main content is about college life which is a little fresh anyway its because ive been in college now',
#  'what s going on ?',
#  'where are we ?',
#  'can i talk to you ?',
#  'the person next to me was from gyeongsangdo so i came here after having a glass of soju together',
#  'is going to the hospital later so you re sneaking in between .',
#  'it feels like i m a little bit distracted and i feel like i m getting tired a little bit faster .',
#  'that s why you re doing something that you haven t done a little bit and you re trying to do something to me a little bit .',
#  'but it s hard to get a lot of people together and it s hard to show .',
#  'but the longer i rode the more tires wore out so i changed the tires a little bit .',
#  'yes i played the fps game with this mindset and now im going to play the sudden untack because many kids did it',
#  'and then the second one i don t know a little bit .',
#  'well it turns out we re going to have to do an artificial suit a little faster .',
#  'i m a little late . i got a call .',
#  'that s . in the area .',
#  'well that s what i learned .',
#  'hundful of practical skills',
#  'i bought her for a month and instead of eating her i gave her away .',
#  'i booked a seat and i barely booked a seat in a row',
#  'dont overdo it today',
#  'that s why the waves hit the road .',
#  'so for me it s . . .',
#  'how long did it take you to finish this ?',
#  'yeah dad ?',
#  'so thats what i said about the atmosphere that cant be helped and as i said earlier',
#  'you ve changed already .',
#  'what pizza did you eat ?',
#  'and its also a season so its a season',
#  'i f a little proud of pursuing it but its not that dream right now',
#  'the days you dont go are the happiest',
#  'she s lying down .',
#  'it s good to have a demo like this .',
#  'i jassed out in the middle of the world because i was practicing a little bit and lost the world again',
#  'and what kind of mother did she take her son for that ?',
#  'so i know that its a toner pad i get a few of those',
#  'it s beautiful but it s only fair to have a job with people like you .',
#  'we re going to go right here .',
#  'isnt it good',
#  'you left the house alone .',
#  'it s your birthday isn t it ?',
#  'im hesitant but as my dad said i just went to a quiet place without insurance',
#  'what did choi sungsoon do you go',
#  'i m talking about your mental health .',
#  'you re gonna get that this year ?',
#  'samaner i didn t even eat dinner .',
#  'it s not gonna be so easy . just think about it .',
#  'if theres something uncomfortable you should live together',
#  'so you re gonna sell it for me ?',
#  'after doing the laundry overwhelmed with the name',
#  'yeah i m telling you i ve got guests like this but she s got hair and she doesn t run again .',
#  'now i thought about it and now im shocked and lets grow something else for my mom but she now',
#  'i mean i was lucky enough to do something and i didn t go to the army so i got a little curt .',
#  'i have to show how i do it and do this but i dont think i can laugh a little bit at my personality',
#  'look even if the daughter lives with room the soninlaw leaves everything to name',
#  'just go',
#  'i got to enter the room',
#  'dont say something that doesnt even say when you say youre not going to do it',
#  'if you look close to the tv your eyesight can get worse .',
#  'if there s a line i don t know just hang on .',
#  'my snow is a little bad',
#  'i was so surprised',
#  'but then i took a picture and then i took it just down on my chin .',
#  'it was snowing up then',
#  'my dad didn t write this down a little bit he just lived one day .',
#  'all right i ll see you there . you have to come on time .',
#  'then one day he suddenly asked me to go to juwangsan mountain and i said lets go',
#  'you don t remember any of my stories ?',
#  'what are you talking about ?',
#  'is that how you re gonna die ?',
#  'i really wanted to give him the best of my strength if you weren t .',
#  'yesh sister at work',
#  'anyway you know how im in my physical condition and how my straw corruption is',
#  'dont make any sounds and put it on the plate',
#  'week people are passing by so please catch them and conduct them like this',
#  'then since the ramen is about what is your favorite ramen',
#  'we started from the beginning we started from the middle .',
#  'but what do you think ?',
#  'i suddenly swore and did it while watching my moms terrapism are there only grandfathers who are going to be presidents in the united states today and tomorrow laughing',
#  'i too jillio .',
#  'he cut a lot',
#  'you want won ?',
#  'dont be happy i think this is what you think now',
#  'the plan is being reviewed .',
#  'it all starts with your sister .',
#  'i didnt have much ideal type but i wish i was handsome',
#  'no bamboo fields bamboo fields',
#  'its okay ill sleep a little bit more on my own when im tired mother',
#  'so you know when i heard that you said you were an audition .',
#  'its a little coercive but these days its so nowadays',
#  'theyre going to live themselves but were going to live with them',
#  'you want to say that to me now ?',
#  'there s food debris in there .',
#  'it s a little bit of a top pro but anyway you know in your professional field',
#  'but it was natural at the end',
#  'i only had one nose',
#  'it was like stepping on a tiger s tail .',
#  'i can walk right to the event .',
#  'i dont lose weight because i eat it but i think i need to lose weight a little slower',
#  'isnt it better to smoke based on the womans standards isnt it more comfortable',
#  'but that s just the religion .',
#  'i put charcoal in the room like this',
#  'i was going to take a break again',
#  'i ccould catch something like that and i cooked fish noodles',
#  'the snow and the main world has become the world .',
#  'so in the past i used to do that',
#  'im thinking a lot about it ill use a laptop a monitor and a very big monitor',
#  'should i do more',
#  'you just need to tell your brotherinlaw the address of the website',
#  'so i was a little interested but frankly',
#  'you cant quit it if you leave it again',
#  'you know samchun deul right',
#  'when i was a kid i used to play with the dirt .',
#  'i m hungry for anything while i m playing .',
#  'there are a lot of mentally ill people',
#  'very father .',
#  'i m lonely . i lost my bob s friend .',
#  'i feel bad about not going home and being with my girlfriend after all i ve done .',
#  'when you listen to it you say it sticky and sticky',
#  'you didn t use kial .',
#  'and now it s on fire and now it s on paper and there s no toilet in the old days .',
#  'you re gonna have to keep the sky shut down .',
#  'we re gonna have to do it on purpose but we re gonna have to do it on the farm .',
#  'you know when you re older maybe you ve changed your personality or something .',
#  'it feels like a long future',
#  'well you should say that you wont lose money later',
#  'wheres the car mr',
#  'i didnt do everything even if i was tempted',
#  'you know i ve seen a lot of things before .',
#  'i m gonna be a little late for a group of friends .',
#  'you say that family members are also earning this much',
#  'if you cut the train school and train youll get a discount so youll drag it there',
#  'i dinner think i wont go because ive been around for about a decade',
#  'the snow is a little bit norsy to us .',
#  'if you re not worried about one of them you re missing one of them .',
#  'she s a friend of mine . she s like oh my dad s looking for you .',
#  'i don t remember her name .',
#  'she does everything .',
#  'don t be silly .',
#  'i got close to these guys but i was a little disappointed because i was going to break up the next day',
#  'i think he s having a lot of trouble with the input problem .',
#  'are you so tired ?',
#  None,
#  'if you listen to it a little like a house open card',
#  'uh i ll put a little bit more value on something and i ll be a little bit more interested in something .',
#  'i was going to apply for this school year because the recruitment was over but i couldnt apply because i couldnt go to school because covid broke out',
#  'i m sorry i m sorry but i don t think i m gonna make it .',
#  'if youre good it would be better not to appear in this alley',
#  'if you look downtown from here',
#  'what were you fighting about ?',
#  'and we shall bring the latan to the water .',
#  'you live like this and you carry things like this and you boast that youre going around',
#  'then i brought it after comparative analysis i brought it and looked at it',
#  'whose daughter am i ?',
#  'why are you putting on your earphones when youre throwing away the trash',
#  'so people who are not highly obese keep on eating diet pills and rely on them',
#  'pes eight thousand won eight thousand won and other places',
#  'he wrote that once when he was a kid he was like',
#  'so go like this and then put it back again',
#  'mom this is what happened to me and i m shocked that i m leaving home .',
#  'was worried about .',
#  'they asked me and told me to bring him if he knew how to eat eggs but if he couldnt eat eggs he only told him to be friends',
#  'where should i go where should i go get some air',
#  'the next day you ll go there too .',
#  'so i m not gonna come back so i m just gonna make some money and get some sleep .',
#  'turn on the lights .',
#  'a gansterlike person came out and said it was like that i dont know if he saw this',
#  'sang hoon sent it to me . it s a very popular drug in china .',
#  'why are you going to a karaoke bar',
#  'oh honey why ?',
#  'since youre gentle and dont say anything i think the two of you are doing so well',
#  'i think itll be a daughter when you have to pick it',
#  'oh i dont have any',
#  'i m gonna get married and do my best until i m done .',
#  'thats worse completely',
#  'it s better to get a little more comfortable .',
#  'should i say that they listen to others well',
#  'is there any other way to contact him ?',
#  'there s something you need to do here .',
#  'and lets go to the bus bar and go drive',
#  'you ll live a long life too .',
#  'jejudo has the most orange fields to do in this town .',
#  'this is how i remember it a little bit intensely in my head .',
#  'my parents died early .',
#  'anyway i tried it like that',
#  'i think i scolded him a little bit badly or honestly i would have kicked him out before that',
#  'it s not good it s sweet it s sweet and no matter where you go no matter where you go you re still in training .',
#  'i m seeing you alone with my dad .',
#  'but bitcoin could plunge again like then i was in or years',
#  'i think there are a lot of eyebrows that young people draw',
#  'i remembered that my mom kept going there so i only went',
#  'they said that she wouldnt be able to do it',
#  'ims saying its not going out so im jealous of that',
#  'i fixed this one once . you gave me .',
#  'are you okay ?',
#  'i don t spend a lot of money .',
#  'what are you thinking forgetting ice cream ?',
#  'but we didn t do that . we just allowed her to do this .',
#  'so youre so sweet to us so youre so sweet to us',
#  'when and when',
#  'those parts so you should have had a talent as a boxer',
#  'mature and grownup luxury goods',
#  'now that yoyo came and gained some weight again',
#  'so forgive me for a few days of hating you .',
#  'yeah my brother is here',
#  'can you tell me the contents of the shopping bag ?',
#  'is there a lot of hives on the thighs',
#  'he said he was raising a racehorse .',
#  'i learned about the preciousness of life because of covid and travel',
#  'oh a little round ?',
#  'then why do you act nervous to me',
#  'everyone said its good either',
#  'yeah thats why i always come out with you',
#  'id like to ask you a little bit about whether youve watched the game in person or what youve seen',
#  'you were gonna get married and talk to me slowly .',
#  'if we re gonna get it right',
#  'its not that good of a character',
#  'if you want to look around slowly you have to catch about a dozen days',
#  'but kim sungsoo said that spicy chicken is the best taste in tteokbokki',
#  None,
#  'and through the love between parents the society is also like this',
#  'who is a celebrity theres a name on the site i should buy another one',
#  'i m going to make a little bit of a self replicating club about programming .',
#  'yes i also think a lot about what i should do',
#  'its a drama that grows a little so its a drama that makes my heart flutter',
#  'oh my god i m so scared .',
#  'before that we had several classes and there was only a half of the classes so laughing at the school children',
#  'dad just pretend you didn t see it .',
#  None,
#  'the war crime act condemned germany .',
#  'now we re checking each other in the morning aren t we ?',
#  'he s got good qualities .',
#  'no there s only one man in my mother s life .',
#  'what d he say to the guy with the checkout .',
#  'in the morning there s a lot of traffic .',
#  'where did you hear that ? national geographic ?',
#  'are you going to be on a trip team this year',
#  'what are you going to do with the club and will you keep doing it',
#  'i scored it',
#  'oh okay',
#  'i ve always been so frustrated i ve always been so upset and i ve always been in a play .',
#  'so if it s a double u . s . process i think it s comfortable to think of it as the most recognized and highly authorized certificate of wine .',
#  'i would have died in the alps without mr aldeson who helped me when i went to europe',
#  'the hardware store looks good',
#  'is this your newest movie ?',
#  'every morning go to the ceremony .',
#  'don t give her a drink because she doesn t have any money .',
#  'thank you very much sir but if it s okay with you',
#  'why do you have to bear that burden ?',
#  'mother first .',
#  'did you hang up ?',
#  'while watching minister kang kyungwha i sometimes think about my future and minister kang kyungwha is over years old',
#  'still theres some left',
#  'ive been here these days and you and i',
#  'i ll take ten and then i ll have ten and i ll do it again .',
#  'i think you look like decorating and any temperament like that',
#  None,
#  'yeah well let s get the kids in the class to compete instead of doing this .',
#  'all the people who made it together were out and he worked hard to pay billion won',
#  'he said he could try . he said he could . he asked for his own pistol .',
#  'a stable life is guaranteed .',
#  'yeah it s like the wind is blowing and it s like it s getting cold .',
#  'i ve been using an iphone for years and the iphone says it likes a little bit of security .',
#  'you know i don t know what i m doing here .',
#  'i think i like it that much',
#  'we cant give you a gift again when you give it to me every day',
#  'it s dede today .',
#  None,
#  'i think that s important once .',
#  'it was turned upside down a little bit around',
#  'it was a certificate that was still easy to get if i studied',
#  'open ive always been in charge of opening so im going to open a pc room',
#  'you re going to sing joy in your heart .',
#  'i went to the fence and now i m in there .',
#  'you don t think you can get a girl like anywhere ?',
#  'suddenly he asked me if i didnt believe him and he gave me a cheer for an hour and a half',
#  'i mean that s what i ate in the morning that s what i ate in the lunch that s what i ate in the evening .',
#  'you re my brother now to be honest .',
#  'i ve just got this many clips on youtube lately .',
#  'i used to ride along with the guy with whom i was going to come .',
#  'what s wrong with you ?',
#  'there s lots of shells on the beach .',
#  'i ve been patient for a while .',
#  'but theres another kalguksu restaurant called hwangbuja and that place called hwangbuja',
#  'im only delivering information unilaterally so i have to reply what is this',
#  'you said you were getting married again .',
#  'now when youre holding the egg your doppel gang appears and just comes to me',
#  'i think i saw it a little differently',
#  'take off your socks',
#  'oh theres no grace no grace',
#  'is he the biggest of the three ?',
#  'please continue next time .',
#  'i live near a desk again and i don t know what i m talking about .',
#  'its good to go there in the morning but if its not that its equipment but its a little tight a day',
#  'i just wanted to give you the album your wife used to love .',
#  'i would have built it alone when everyone is there but i do that rather than building it alone',
#  'the men in the drama have a slightly different face',
#  'it didnt make sense for people to do it for a day before then and its just a vote yes no',
#  'can you come to my dads place and tell him to do something for a while and he can take care of my daily wages',
#  'i haven t been sick in years .',
#  'she fell asleep and went to the hospital .',
#  'unusable tools were put together in one place .',
#  'there s nothing to see .',
#  'i don t know what a ghost is .',
#  'theres no probability at all',
#  'i couldn t help but think about it .',
#  'oh that s because it s also saving trees .',
#  'i don t know if it s ilencia .',
#  'i don t feel comfortable getting dressed .',
#  'well it s really hard to keep the house under control .',
#  'so i think ive changed a lot too',
#  'when you take a picture you say what is it but other people come out very pretty and brightly youre just going to pick up',
#  'i like that too i like that the most side dish i really like',
#  'i m sorry i m just thinking about something else .',
#  'if you ask the officials to investigate a little bit correctly they did it correctly',
#  'yeah i don t think young people today know the dross .',
#  'she has a girlfriend .',
#  'how many boys ?',
#  'once my foot was broken but the side of the foot the backbone of the foot was broken',
#  'so there s a lot of good things to know but some people don t get bad things when they do something .',
#  'imaturely eat it together so im eating it together',
#  'you have everything right ?',
#  'so bangkok and pata . i only know this much .',
#  'its called the best satirical literature',
#  'and when you go and eat it it tastes good one day another day it doesn t and a lot of times it does .',
#  'these days women are left and office workers are also going to pick stars in the sky',
#  'this summer i ve been down the line .',
#  'i see a little less television these days .',
#  'he told me to do that',
#  'i used to do that',
#  'cant i eat it the next day',
#  'so to stretch your muscles you keep bending your legs forward like this',
#  'but the wrong way the delivery fee was krw',
#  'you threw all of this and said you were in the swamp jungle',
#  'its like that i must have been so willing to do that so you too',
#  'it s almost like eating like this . it s worth a lot of money .',
#  'tell me quickly . who hit you ?',
#  'if you look at the neber webtoon the webtoons are put together and the masks are in the ratings .',
#  'when are you gonna stop acting like a martyr ?',
#  'try new ones .',
#  'it s useless to do that .',
#  'you know when my dad told me he was gonna open an account for you you know like a minor or something .',
#  'mom does it .',
#  'theres something like that like these days',
#  'is there a nice restaurant around here ?',
#  'theres everything i think there are a lot of parttime jobs that we didnt even think of',
#  'your name is uh uh oh oh oh you said it but you like it a little bit more rationally',
#  'i tried the conch this time but my teeth almost got out i laughed at it',
#  'i ve seen you before .',
#  'he wouldn t have survived without me .',
#  'so when i go to the beach a lot i always try to eat some seafood',
#  'start talking is that right',
#  'it s been a while .',
#  'i can t even find it .',
#  'iveisted a lot from the beginning',
#  'press the calculator and say ill buy it so please give me a little more discount and buy a cute pouch',
#  'don t you think i m kidding you ?',
#  'someone else',
#  'is that all men ?',
#  'grind it like a powder made of mushrooms and sprinkle it on the food',
#  'i think i had a wise doctors life',
#  'theres a tripod in my house so i take it',
#  'i was going to go on a backpacking trip too',
#  'oh shit . and then i hit him with my bare fist .',
#  'it s gonna take a while to get this to the car .',
#  'the land is called kimchi so i just put a jar on the ground and store kimchi',
#  'i don t know if i ll ever make it back to kang neung .',
#  'someone bought something and the guardians bought it and eat it you got it',
#  'i think i just went to haeundae market after experiencing helicopter helicopters',
#  'in fact if they taught them universities they had to do everything',
#  'i like the details and i don t know if this guy s out there and i don t know what he s up to .',
#  'you know it s just so annoying and so annoying .',
#  'that s why he supported one side of me to do the right thing .',
#  'is it his own fashion',
#  'didnt you give christmas to me i thought you would give it to me in the new year',
#  'after my death it s so sad and it s so regretful and then what do you do ?',
#  'i m a little good at credit .',
#  'i ook the test a long time ago',
#  'there s a lot of wrinkles around your eyes .',
#  'look at what to give as a gift to everyone to dad or mom',
#  'i ve just had a hard time going around .',
#  'a bouncy year became a mother so im sorry but my name is',
#  'i m back alive .',
#  'yesh thats right there are more people in seoul right now',
#  'if you re her i m her .',
#  'she s a student and she s like um she s smoking in the middle .',
#  'the title is to talk about childhood stories .',
#  'don t you have your grandfather s father ?',
#  'what should i say like this should i say it to help',
#  'so there are hammers but in a way the market is too narrow',
#  'its purple right ill play rock paper scissors with that ripped off',
#  'so now he s got a bad knee on his own and he s been doing knee smoothing for a while .',
#  'i m going to roast some bean sprouts .',
#  'i want to see the major league competition .',
#  'then is it better not to raise a pet dog',
#  'i heard that korean webtoons are the best in japan',
#  'when you receive it you can use a motorcycle to go to hoengcheon stream or hwangcheongil street',
#  'when the rain stops let s go .',
#  'are you telling me you re good in front of me ?',
#  'where do you go with the meat bar ?',
#  'you don t look fat at all .',
#  'it s a chicken ribs but i have a really good memory .',
#  'but shouldnt you do sports like sports steadily',
#  'because i was in the sixty six years i was in the sixty one seven years .',
#  'yeah . name is just busy .',
#  'it s all day .',
#  'one of the reasons why i like makgeolli bread because its not sweet',
#  'one or two they re just doing that so they re not exercising they re not stretching .',
#  'it s going to be useful if you give some sort of map of the type of question you re asking the seller .',
#  'dont mind it too much because its a matter of organizing one or two affiliates',
#  'i think i used to look up a lot of beauty programs and makeuprelated videos when i didnt wear makeup',
#  'and now that i m talking in middle school it s kind of a little bit of a concern for me .',
#  'ims talking and finding a very perfect ideal type',
#  'now everyone is upset but why didnt you send your daughter to marriage when my friend was sitting and playing',
#  'how long do you think you re gonna eat like a dog ?',
#  'i think winter is better than summer but i think its a little bit',
#  'since i keep saying this im giving them single single strokes separately',
#  'it s hard because i don t have enough money .',
#  'is my child and the woman who gave birth to him ?',
#  'how many times do i need your help ?',
#  'so about that kind of thing in reality',
#  'well if everyone in the world had to be beaten up it would be cheap in the country because without them that s a lot of money .',
#  'i m not gonna ignore it you guys .',
#  'so now i come to my house once a month and i go to sleep and she has that kind of thing .',
#  'maybe i can visualize it that way and i ll prepare for it and i ll be a little bit more alert all the time .',
#  'you re gonna be a little weak in your body and in your health .',
#  'you really decided to come out on the news',
#  'i dont really want to go with you',
#  'i m sorry .',
#  'so thats why',
#  'twenty seven .',
#  'so the smart palm is only for this cabbage and the other vegetables aren t ?',
#  'i m not as strong as i am .',
#  'i called her and said hey i was also',
#  'i can t see a man of love riding on a horse .',
#  'it s small but it doesn t make any sense .',
#  'when we grow up we have our own families so we dont know',
#  'your father s the only one who s gonna be virtuous .',
#  'i know but i couldn t see it because i had to work at night .',
#  'in gyeongsangdo its called daseulgi soup because theres daseulgi soup',
#  'why would you do that ?',
#  ...]

# %%
dec_corpus
# Out:
# ['<kw> 너머 그러는거 아니어라 .',
#  '<jj> 고등학교에 다니는 시간이 점점점 그니까 뭐 초등학교 때는 뭐 이제 뭐냐 다섯째 안에 마친다 하믄',
#  '<jd> 어 엄청 약간 시사적인 거 근까 뭔가 어떤',
#  '<jj> 얼굴이 잘생겼지 게난',
#  '<jj> 그난 좀 약간이 가끔 보믄 일상',
#  '<kw> 여자가 나뭇가지를 손질하고 있사 .',
#  '<kw> 아무리 화가 나도 어떻게 그른 소릴해 ?',
#  '<jj> 난 요새 우리 서방 잡아오는 이',
#  '<gs> 제자 제주 할매 집에는 문은 항상 열리가 있잖아 대문이',
#  '<cc> 나는 여행을 이제 그 거기만 보고 오기는 쫌 아쉽잖아 .',
#  '<jj> 그 오빠 친구가 내려와 광주에서 그때 빌리기로 핸 트럭을',
#  '<jj> 뿌링클 두 조각 볼케이노 두 조각 이렇게 하고 와시면 좋겠다 웃음',
#  '<kw> 겨론 전엔 몰랐는데',
#  '<cc> 이제 흥얼거릴 수 있는 노래들이니까 그래서 그런 노래들을 쫌 좋아하는 거 같고',
#  '<jd> 몰라 긍게 할라고 생각을 하면은 그렇게 하면은 좋을 것 같더라',
#  '<kw> 오래 있다 보면 벨사람 다 있어 .',
#  '<jj> 아 왜 색깔 있는 것 썬 아님 너무 두꺼운 거 쓴 거 반사해서 밑으로 떨어진 건가',
#  '<kw> 이제까지 그 사람이 한 번도 지각한 걸 본 적이 음싸 .',
#  '<jj> 거기 가마솥에 올려놩 거기서 밥해 먹고 다 했주 . 게',
#  '<jd> 씻고 있는거야 야 그래가꼬 언제 씻냐 이래가지고 물 받아가지고 쓱쓱스',
#  '<cc> 근데 내가 그 깊은 데로 확 딱 빠진 거야 근데 혜진이는 여차저차 해가지고 튜브를 짚고서 이케 나왔어 .',
#  '<kw> 이름 야 휘지',
#  '<jd> 그래서 니 친구들은 안 놀아 그랬더니 집에 있을 걸요',
#  '<gs> 저의 성격에 대해서 말씀을 드릴 수 있는데 따른 사람의 성격에 대해서 얘기할 때는 특히 뭐 그 사람의 뭐 고쳐야 될 성격 그',
#  '<kw> 우리는 당아 자연이 우리에게 보여준 모습의 만분의 일도 모르고 있어 .',
#  '<gs> 걍 오빠랑 비교돼서 그런지 몰라도 저한테는 저는 만약에 제가 시켰는데 저거 만약에',
#  '<gs> 그니까 약간 이것도 좀 여타 다른 일이랑 비슷한 게',
#  '<jj> 마늘 냄새 막 심하잖아',
#  '<gs> 반지 그거는 있다 아이가',
#  '<kw> 아 내가 아리랑 보낼게 있어서 사램 좀 보내 달라고 부택했는데',
#  '<kw> 아무리 헝이가 제 상사지만 이번 일 같은 경우엔 팀으로 움직여야하는 일이잖아요 .',
#  '<kw> 엄마가 돈이라도 잘 불리문 좋은데 .',
#  '<jd> 어 저도 언니 한 명만 있다 보니까 언니랑 쫌 사이가 유별나게 쫌',
#  '<jj> 집에 오지 말랜 허멍이 이젠 해그네 허난 이젠 끝',
#  '<kw> 즈네 안 보고 싶을 자신 있으세요 ?',
#  '<jj> 중국인들 못 오난',
#  '<jd> 쫌 약간 그런 거 막 약간 도와주지',
#  '<jj> 영 했구나이 .',
#  '<jd> 적군이다하고 화살을 엄청나게 쐈대 그 담에 그 배를 다시 떙겼대 .',
#  '<jj> 고등학교 땐 시간이 진짜 안 가는거라 가는 거야 언제면 이걸 졸업해서 자유를 누리나 해신디',
#  '<kw> 저 사램이 나한테 워뜬 의미인지 .',
#  '<kw> 그것은 아모 데도 쓸모가 없을 듯 싶었어 .',
#  '<kw> 워느 것이든 하나기 주시오 .',
#  '<jd> 했드니 우리 형님은 긍까 내가 제사 때 오기 전에 밀렸어 .',
#  '<jj> 시청에이',
#  '<jd> 그니까 주변에 응 어르신들이 하는 말씀 있자뉴 응',
#  '<gs> 있는데 그게 뭐 알바몬처럼 이케 쫙 정리돼 있는 사이트는 아직 없는 거 같애요 그래서',
#  '<jj> 야 근디 name이면은 거 몇 년 강 못 입을 거 아니 가이 경 비싼거 살 필요 있서 ?',
#  '<jj> 그래가지고 와 진짜 근데 약간',
#  '<gs> 웨이트 트레이닝이라고 하는 게 이제 맞지 않나 외국에서도 다 웨이트 트레이닝이라고 하는 거지 .',
#  '<gs> 영화 배우들이 영화를 잘 아 그 드라마를 잘 한다 아이가 ?',
#  '<kw> 단 한 번도 예자를 사랑해본 적이 없는 냉담한 자였던 그 남자가 .',
#  '<gs> 반죽 쫌 더 이렇게 물 같으 물 같은 그렇게 넣는 거 아이가 ?',
#  '<kw> 비상긴축 기간이라 프린트 백 장은 증말 안돼요 .',
#  '<jj> 근데 이거 조생은 빨리 안 따믄',
#  '<kw> 상구도도 먹어 ?',
#  '<cc> 성격은 이게 하고 싶어도 참는 거야 내가 내가 잠 잘 자고 내가 편할라고',
#  '<kw> 자 사램 만들려면 이름 한테 보내 .',
#  '<kw> 아직에 샤워를 못해서요 지금 퉁퉁 부었어요 .',
#  '<jd> 아무래도 쫌 외국 저는 외국이랑 쫌 안 맞더라고요 .',
#  '<jd> 그 대상을 경쟁상대로 보고 극단적인 선택을 하기도 한댜 .',
#  '<jj> 꾸레도 못가 이젠',
#  '<kw> 지집아야 지금은 니 차여라 .',
#  '<jj> 막 티를 낸 말뿐인 거잖아 막 이런 식으로',
#  '<jj> 산디는 많이 안 허고 산디는 잘 안돼',
#  '<cc> 배우게 될려나 어쩔려나 아직까지는 아유 포기를 포기가 안 되네 .',
#  '<kw> 나는 자신 읎어 .',
#  '<jj> 그 밑에도 부두 쪽으로 가면은 이제 우리집 이시간 쪽으로 조금 가면은 굉장히 커났어',
#  '<gs> 골고루 묵고 고기도 잘 먹고 막 이래야 되는데',
#  '<kw> 근데 갸가 그 주소 가 됐다는 말 이후로 두 번째가 니야 .',
#  '<jj> 그런데 데이터를 다 쓸 일이 어서 한 달에 백기가 라부난 .',
#  '<kw> 그걸 꼐속 만약에 주다 보면 내가 계속하면은',
#  '<kw> 그근 극정 말아요 . 필요하면 임시 직원을 채용하면 되니까 마감일 안에 끝낼 수 있을 거예요 .',
#  '<kw> 그건 할머이가 알 거 없사요 .',
#  '<kw> 요중간 가을 자체가 없는 거 같아요 .',
#  '<gs> 자기 만족을 위해서 계속 입히고 다니고 이거 입히고 저거 입히고 나는 니한테 이거 해줬는데 하고 요구하고',
#  '<kw> 마옴 쓰는 게 기특하구먼 .',
#  '<kw> 내가 오놀 너머 너머 바빠가지고 말이다 .',
#  '<gs> 그냥 종류별로 제가 하고 싶었던 거 다양하게 마이 샀던 거 같습니다 그렇게 산 저 스무 개에서 서른 개 정도 되니까',
#  '<kw> 사실 이것은 두 나무가쟁이 근본적인 실수들을 저지르는 거야 .',
#  '<kw> 자석을 위해서 그 정도 사개 받았으문 풀어주는 거지 뭐 은주야 .',
#  '<jj> 생리하믄 몸 다 붇',
#  '<kw> 저냑 당번 깜빡 한거 아니나 ?',
#  '<jj> 거난 그다음에 손님한텐 손님 잠시만예',
#  '<jj> 성능이 하영 떨어져부런',
#  '<kw> 그건 당분간 없던 이애기로 하지 않았니 ?',
#  '<kw> 그냥 기냥 어트게 지나가는지도 모르겠어서 한 달 지났다고 생각한 거 같은데 ?',
#  '<jj> 붕 떠보니깐 이 그니까 그 교수님도 내가 말했잖아 그때이',
#  '<gs> 친구들이랑 같이 할 수 있으면 좋은데 그렇지 않으니까 쫌 하다 말다 하는 편인 거 같아요 .',
#  '<jj> 개믄 곧지마라 게',
#  '<kw> 글쎄 그른 것 같기두 하구 .',
#  '<jj> 오늘도 나 산에 가멍',
#  '<kw> 어뜬 년 ?',
#  '<kw> 응 진로도 그니까 이쪽으로 잡으면은 어 괜찮을 거 같단 생각이 들어 .',
#  '<kw> 마음이 아프대고 몸이 아팠대 몸또',
#  '<kw> 내가 그동안 너머 멋대가리 없게 산거 같애 .',
#  '<kw> 우리새아가 우리새아가 할로쥉일 아주 입에 다시고 사신다 아주 아이고 .',
#  '<gs> 그 맛이 이 뜯어 무먼',
#  '<jd> 그렇게 해가꼬 결혼하게 된 거예요 .',
#  '<cc> 아고 중독되면 어떡하지 허니까 에 중독 안 돼요 괜찮아요 아 이러는데 뭐라 그려요 .',
#  '<kw> 그치 또 그러면 또 그땐',
#  '<cc> 되게 많이 공감을 하게 되기도 하고 쫌 뭔가',
#  '<jd> 사별로 이제 잃어가지고 그걸 아직도 힘들어 하는 그런 친구여 .',
#  '<jj> 네 어제도 보난 그 고등학생이 확진 됐는데 아이구',
#  '<jd> 너 엑세스 쓴 적 있어 나 엑세스 한번도 안썼는데 컴활 필기 딸려고 공부하니까 뭐 아무것도 모르겠던데 .',
#  '<kw> 아부지 인제 막 돈 막 벌 거다 .',
#  '<cc> 데이트 통장으루 한번에 한 달에 얼마씩 모으자 하면 그 돈으로 여행 가서도 쓸 수 있고 계산할 때 되게 쫌 뻘쭘해지는 상황이 생길 수도 있잖아 .',
#  '<kw> 아부지 유서가 우리 가족들 협박용이 아니라 진이라구 .',
#  '<jj> 그 이 면도날도 전자제품 이랑 좀 비슷한 거 닮아',
#  '<jd> 너는 뭐 해산물 알러지 같은 거 없나 ?',
#  '<cc> 드라마에 쫌 드라마도 별로 보는 거 안 좋아하고 이케 듣는 걸 좋아하거든요 이름님 저는',
#  '<kw> 시직 보구 살어 ?',
#  '<kw> 그러 그다음에 이제 그런 비타민 같은 것도 쫌',
#  '<cc> 뭔가 안에 숨겨놔서 약간 깜짝 놀랄 수 있는 선물 그런 거를 했던 적은 있는 거 같애요 .',
#  '<jd> 막 치대믄잉 고것이 인자 그 부드럽게 인자 그',
#  '<kw> 월수 받는 것도 귀찮으이까 돈 모아지면 한끄번에 갚아라 .',
#  '<gs> 그래서 혹시 머 요새 주식 중에서 쫌',
#  '<gs> 내 첫 연극이 그거였거든 진짜 한 팔 년 됐다 팔 년 팔 년 전에 본 건데',
#  '<kw> 이건 진뗑이 은입니까 ?',
#  '<jd> 술을 마시면서 이르케 시간 자리를 보내는 거보다는 밥을 이제 맛있게 먹고',
#  '<jd> 인제 쫌 집에서라도 가볍게 뛰거나',
#  '<jd> 갖 근디 건 인자 건강검진을 받았겄잖아 목포 한양댄가 와서 건강검진을 전체적으로',
#  '<cc> 뭔가 좀 이케 담아줄 수 있는 분이셨으면 합니다 .',
#  '<jj> 쌤이 그렇게 화내는 거 진짜 처음 봤던 거 닮',
#  '<gs> 쭐임말도 요새 자꾸 각을 잡으시더라고요 .',
#  '<kw> 니 참 바보 같다 막 이켔잖아 이렇게 했잖아 그리구 뭐 사람들이 뭐 물어보니까는',
#  '<kw> 어머이야 ?',
#  '<kw> 이 자석이 이그 사램을 거렁뱅이루 아나 ?',
#  '<gs> 저는 중국 갔을 때 음식이 되게 입에 안 맞아가지고 쫌 고생을 했던 것 같애요 .',
#  '<kw> 이모 입장에서야 그 예자 집에 찾아갈 수 있는 거지 .',
#  '<jd> 나는 그래도 짝은 공으로 하는 운동은',
#  '<kw> 우리 사무실로 오세사 신청서에 기재하셔야 돼요 .',
#  '<kw> 아무리 겔혼을 안 하셨다지만 그른 식으로 하셔도 돼요 ?',
#  '<kw> 석간에서는 공해 문제를 거하게 다루었어 .',
#  '<jj> 할망 매실파는 할망들이영 시골에 무신 마농 파는 할망들이영',
#  '<kw> 어머 어머 아무리 화가 나도 그렇지 너 언니한테 무신 말이 그래 ?',
#  '<jj> 너 뭐하멍 지내맨 ?',
#  '<jd> 이름이도 당연히 그런 부분이 있어서 출중한 장점이 있다고 생각을 하고 그리고 그리고 또',
#  '<kw> 자석 이기는 부모 없다잖아요 .',
#  '<kw> 과자를 덥석덥석 먹어조지다 .',
#  '<jd> 참 그 소릴 허드라고 그래서는 에잇 별 소릴 다 하시네 참말로',
#  '<jd> 혹시 코로나 시국 끝나기 전까지는 확실히 피씨방 가기도 쫌 꺼려지더라구요 .',
#  '<jd> 그니까 방송사 사람들 참 대단한 거야 보면은',
#  '<jd> 그러제 긍께 지금 생가가믄 진짜 못됐어 .',
#  '<kw> 그곳에 가려면 기차를 몇 번이나 갈아타야 하다와 ?',
#  '<kw> 난 한 눈에 알아봤싸요 .',
#  '<kw> 내가 그래 가주구 침대에 진동이 느껴 가주구 너무',
#  '<jj> 제주도에서 나고 자라고 부모한테 배운 것도 행 이런 건 참 장점으로',
#  '<cc> 그래서 쫌 걱정이 돼요 .',
#  '<jj> 아 근데이 그게 그 약간 그렇긴 핸 원래 만두를 우리가 세 개 샀으면 다섯 개 정도 줜',
#  '<gs> 내 약간 고런 캐릭터가 좋나 봐 사실 다정한 사람이 더',
#  '<jd> 아들한테 시켜요 그래갖고',
#  '<jj> 가끔씩 차가 옆 차가 막 빵 하고 지나갈 때가 있었댄',
#  '<jj> 다 거난 사는 거는 다 똑같아 나 사는 거나 누구 사는 거나 .',
#  '<cc> 아니 나는 연말에 너 예금 나오니까 한꺼번에 뭉칠라 그랬지 그랬드니',
#  '<gs> 되게 어떻게 보면은 군 그니까 전쟁사에서 크게 판을 뒤집어놓은 하나의 어떻게 보면',
#  '<jd> 그래서 이제 아이튠즈로 이르케 연결을 해서 노래를 넣고 하면은 가끔씩 이제 아이튠즈가',
#  '<kw> 효자 노릇을 하다와 .',
#  '<kw> 이름 라고 불러 주세요 그기 제 이름이에요 .',
#  '<kw> 고 사람이 쓴 시집이었다 .',
#  '<cc> 까 말하자면 그니까 제가 이게',
#  '<kw> 화투하는데 이기면 희쭉 웃음이 나오지 .',
#  '<jj> 지금 애기 작년에 낳그냉',
#  '<gs> 저는 그면 하던 알바는 어떡하나요 버리고 가잖아요 맞잖아요 그건 아니잖아요 그니깐',
#  '<kw> 저 저냑 먹어야 해요 .',
#  '<kw> 창문이 크니까 햇빛으로 방 안이 다 비치킨다 .',
#  '<jd> 같이 해야 쓰겄어 와갖고 내가 보조할 것인께 와 가지고 좀',
#  '<kw> 무 물론 내가 먼전',
#  '<jj> 뭐라 뭐라고 햄수가',
#  '<kw> 신비가 한복을 곱게 차려입었다 .',
#  '<gs> 그 스크린보다 야구보다 싸다 쫌',
#  '<kw> 오른펜짜에 보면 바위가 있다 .',
#  '<kw> 느이 아부지가 얼구리를 들을 수가 없드랜다 .',
#  '<kw> 그래가주고 학상이라고 말을 했어 학상은 학상입니다',
#  '<kw> 근데 이게 나는 그냥 단순히 어릴 때 운동을 쫌 많이 했는데',
#  '<jd> 그래서 이케 병원이나 이런 거 그 이런 거를 세 개',
#  '<jj> 진짜 안 키우는 게이 안 낳는 게 맞다고 생각해 .',
#  '<kw> 그래서 끊을 수가 없는 거 같애 계속 새로운 거 좋은 노래 찾을라고 막 이 노래 저 노래 들어보고 막 그러는 거 같애 .',
#  '<jd> 그 저는 그 장면이 가장 머 가장 이케 멋있는 장면이다라고 생각이 드는 것 같아요 .',
#  '<jj> 몇 가지 해 가지고 막 유투브에 막 많이 올리잖아 그런 거 안 봐 봔 ?',
#  '<kw> 혼재 계신 어마이 모시지도 못하면 서 그 정도도 안 해요 ?',
#  '<jj> 진상손님은 만난 적 어신디 그냥',
#  '<kw> 잎사구도 있지 않고',
#  '<jd> 근 그니까 그니까 이제 학교를 다니고 밖으로 나다닐수록',
#  '<kw> 어머 이름 아 왜서 발싸 와 ?',
#  '<gs> 한 삼 년쯤 됐을 때 확장 이전을 해서 나도 쫌 제자도 키우고 싶고',
#  '<kw> 이 어둡고 차가운 교실에 혼재 버려진 기분 한 번 느껴보라고 .',
#  '<kw> 그의 제안에 동의하십니까 ? 피셔 씨 저기요 피셔 씨 듣고 기서요 ?',
#  '<jj> 어 하르방처럼 나와부난',
#  '<jd> 물건 저기 하면은 또 인제 하고 그랬으면서',
#  '<gs> 그래서 와 그래도 군대에서 그런 거 하면은 당연히 잘할 수밖에 없다 하는 게 쫌 신기하기도 했고',
#  '<kw> 내 자취방 이을대 뇌쇄적인 거 보여줘야죠 왜요 겁나요 ?',
#  '<jj> 거 해신디 나는 유독',
#  '<jd> 암튼 나는 아파가지고 누워 있다가도',
#  '<jd> 뭐 직원들이 인자 같이 갔을 거 아니여',
#  '<jj> 진짜 열심히 들언 근데',
#  '<jd> 챙길라고 했는데 못 챙겨가지고 했는데 애가',
#  '<kw> 뭐야 마음이 심란한데 해팔 내가 불러내',
#  '<jj> 그 속에 눈 다 들어가 불었을 거 아니 ?',
#  '<jd> 그래서 난 집에서 흥얼흥얼 하는데 워낙에 못 가니까',
#  '<jd> 눈 오는 날이 너무 무서워 근데',
#  '<gs> 또 재밌게 쫌 하게 되는 거 같애요 .',
#  '<kw> 그래서 다쳤나 ?',
#  '<gs> 거기에 나오는 배우들도 쫌 비슷한 똑같은 사람이 많이 나오고',
#  '<cc> 나도 너처럼 쫌 레진 아트처럼 새로운 취미를 찾았으면 좋겠다 .',
#  '<jd> 아마 시간이 또 지나가지고 내용이 쫌',
#  '<kw> 여보 고마해 .',
#  '<jd> 우리는 사실 그런 거 쪼끔 멀지 않니 ?',
#  '<kw> 이름매니저가 한국 사램인지 몰랐습니다 .',
#  '<jj> 우리 두린 때 그거 보멍 어떤 사람은 저런 집에 사는고',
#  '<jd> 불이 안 켜도 불이 환해 그리가꼬 진짜 아름답더만 멋있더만',
#  '<gs> 그기 그기 막 삼 대 세계 삼 대 축제 중의 하나라는데',
#  '<jd> 다시 공부를 할 수 있으면은 또 열심히 하는 것도 나는 괜찮다고 생가가는 게',
#  '<jj> 이것 방 두 개랑 부엌 행 우리 쓰고 있지',
#  '<jj> 요즘에는 부정맥 때문에 잘 안 마시긴 하는디 나이가 있어가지고',
#  '<gs> 되게 니 성격 문제 있어서 그런 거 같애 이러 이렇게 받아들여지는 경우도 있더라고요 .',
#  '<jj> 우리 엄마 뭐 그런 거 많이 샀던 거 닮아 .',
#  '<jj> 잔치 xx 놀래 자빠져부런 나 아니 아침에 보당보난 보다가 보니까 이',
#  '<kw> 암퇴끼가 사납네 ?',
#  '<jj> 와 많이 하영 갔구나',
#  '<jj> 아파트 근데 아파트에 막 쫌 햇빛 잘 드는 그런 베란다 같은 거 있었음 좋겐 .',
#  '<gs> 세상에 돼지고기 한 쫌 한 덩거리 오천 원짜리가 어딨노',
#  '<gs> 뭐 돈을 쫌 모아서 이제 결혼을 해야 되겠다 이런 생각밖에 없었기 때문에',
#  '<jd> 이케 눈을 한곳에 안 두고 막 사방 군데를 다 보는 거 같애 .',
#  '<jd> 하나님이 우리 이름 만 저그 들어주시고 나머지기는 다 저 그 회사원인디',
#  '<jj> 나는 일할 때 현금으로받아난예',
#  '<cc> 뭔 이렇게 쬐끔한 거를 하나씩 주냐고 했을 거요 다 내가 오빠들 왔을 때 그',
#  '<jj> 게 나중에 의사가 불렁게',
#  '<kw> 거리에 누이 오십 센티미터 쌔여 있었어 .',
#  '<kw> 쥐뿔같은 소래기 그만둬라 .',
#  '<jd> 긍께 다 뭐 명품이든 메이커든 뭐 브랜드든',
#  '<jd> 쫌 중학교 때는 엄청 열심히 놀았던 그런 기억이 있네요 .',
#  '<jj> 어 오지말랑 난',
#  '<jj> 야 좀을 그추룩 잘 자불어',
#  '<kw> 그 프로젝트는 잘되어 가고 있사 .',
#  '<jd> 다이어트를 극단적으로 하면은 더 힘들 것 같어 .',
#  '<jd> 그런 어 좌수나 뭐가 있어야 되는데 제 남편은 그게 좌수가 들어있는 거예요 그니까 나는 이 사람이',
#  '<kw> 너도 혹시 그러면은 닭갈비나 막 막국수 같은 그런 음식들을 쫌 좋아하는 편이야 ?',
#  '<kw> 그자석은 성아 떠났다고 그렇게 진상을 떨어놓고 여전히 좋은건가 ?',
#  '<jd> 그면 예전에 내가 엄청 밥을 좋아했잖아 탄수화물 엄청 좋아했잖아 밥하고 김치만 있어도 내가 잘 먹었는데',
#  '<jd> 그냥 얼른 성격이 막 글잖아 얼른얼른 해블고 막',
#  '<jd> 거기에 탄중아루 비치라고 그 뭐지 그 해변 겁나 유명한',
#  '<kw> 퇴근시간 전에 들어갈 테이까 하고 즌화하지 마 .',
#  '<cc> 근데 나는 그런 게 좀 있었어 나는 나중에 스포츠카를 탈 거여 .',
#  '<kw> 왜 그런 거 짜질구리한 거 하지 말고 제대로 하나 해라 근데 뭐래 웃지 ?',
#  '<jj> 여행 가면 놈이나라 음식을 먹어서사지 우리나라 음식을 한 일주일 안먹으면 죽어져이 그나라 음식 먹엉 배탈도 나고',
#  '<gs> 정말 좋은 치미 생활이죠 .',
#  '<jd> 그때 이후로 으 그 쫌 야 약간 강동원이랑 거리를 두면서 홍콩에서 지내게 돼 .',
#  '<jj> 한 번 더 물어봤는데 대답안핸 .',
#  '<gs> 또 좋은 면이나 단점이나 하는 게 쫌 많이 앞으로도 바뀔 거 같애요 .',
#  '<cc> 아 그러니까 저 이상한 거 같애요 아 긍까 그냥 하고서 습관적으로 그냥 저는 패딩 그냥 겉옷에 넣거든요 .',
#  '<kw> 이름 그렁이 식으로 다루시면 저도 겔혼 생각 안할 겁니다 .',
#  '<gs> 징계 아 그 받았다 하니 긍까 니가 휴대폰 관련돼서 한 번 징계 같은 거 받은 적 있는데',
#  '<jd> 쪼꼬만 한 놈이 엄청나게 먹어 대 .',
#  '<jj> 이상해봬다 해네',
#  '<jj> 꼭 있어야 되는 뭐라 그럼 양재를 한 명돌안 두명돌안',
#  '<jd> 혹시 너는 뭐 그런 어떤',
#  '<kw> 오랫동안의 분쟁이 제우 그쳤어 .',
#  '<jd> 쫌 먹고 감기 워낙 많이 걸리니까 감기약 자주 먹고',
#  '<kw> 돌 뿌리를 잘 비케 가세요 .',
#  '<jj> 경 하난이 야간에 막 술 퍼먹엉 왕으네 진상 부리는 사람들도 이서나서',
#  '<kw> 여보 나 내리부터 백화점 안 나가면 안되겠나 ?',
#  '<jd> 얼굴이 빵빵하 하니까 그때부터 약간 내 얼굴에 살집 있고 내 모든 게 다 살집있어 보이는 거여 그래가 내가',
#  '<gs> 정말 쫌 내가 여유가 됐을 때 있잖아 시간적 여유 지금은 그거만 하루 종일 며칠 안 되거든 .',
#  '<kw> 댕겨 오겠습니다 .',
#  '<kw> 그대로지 그제 ?',
#  '<kw> 비덜기마냥 둘이 꾸꾸거리구 있다가 .',
#  '<cc> 딱 시간이라던지 뭐 젓는 쎄기라던지 많이 반죽하면 또 안 되고 이런 것들이 너무 많아서',
#  '<jj> 가이가 이녁 불러지민',
#  '<jj> 저기 성교육 수업이 이성으네 가신디양',
#  '<cc> 안테토 쿰보라는 선수가 있거든 그니까 이 사람이 지금',
#  '<kw> 아니 내가 다니민서 요렁이',
#  '<jd> 자주는 아니지만 그래도 좀 했던 것 같기는 해 .',
#  '<jj> 이해한다 뭐한다 해신디 걔네들 생각도 다를 거라 기지',
#  '<cc> 아 쫌 다르구나 약간 그거는 뭐 안 맞구나라고 생각을 했었었고',
#  '<cc> 이 잇몸이 그리고 이케 혀로 이를 이케 이케 만져주래 .',
#  '<jj> 야야 나 company name 가봐신디 이 거기는 이제 유명해져 부런 ?',
#  '<jd> 피폐하지 하는 거 없고 아니 근데 지금은 니가 뭐 일 안 하고 있으니까 나중에 일하면은 바빠가꼬 또 여유가 있을',
#  '<gs> 우리 엄마가 다리줘갖고 불임된 거 애도 놓고',
#  '<jd> 콜팝 그 감자 튀김인 주 알았어 그',
#  '<kw> 붓으로 쓰지 마고 볼펜으로 쓰시오 .',
#  '<kw> 마음이 통하다 .',
#  '<gs> 쫌 그런 문화들이 문화 차이가 많았는데',
#  '<gs> 그거라 카더라고 에이아이',
#  '<jj> 알아 알아 뭔지 알지게',
#  '<jj> 어찌됐건 저찌됐던 간에 나는 저기 걸어서는 여기 창고랑 왔다 갔다 못하크라 .',
#  '<jd> 그 뒤에는 암암리에 식솔들도 멫 명씩 따라오잖아요 .',
#  '<kw> 좀 더 불나게 공부하지 않으면 안될거야 .',
#  '<kw> 그래 즌화할게 .',
#  '<gs> 그 쉐보레 로고 진짜 쫌 바깠음 좋겠고 뭐 약간 아 너무 쫌 이케',
#  '<jj> 겐디 그 똘들이',
#  '<cc> 남한테 피해를 줬지만 내가 뭔가 물질적으로 편안하잖여 .',
#  '<jd> 기냥 했을 땐 잘 안 보여 긍까 삶으믄 오히려 더 잘 보여 삶으면은',
#  '<gs> 이렇게 해서 요즘은 파래가 쫌 괜찮고',
#  '<kw> 형 나 갑자키 승부욕이 발동하는데 .',
#  '<kw> 왜 그래 기집애야 증말 .',
#  '<jj> 오늘은 또 어떵 안해 어제 저녁에 좀 경하고 한 요 며칠',
#  '<jj> 근데 쓰난 좋긴 하더라 .',
#  '<kw> 이제 마이 들었고',
#  '<jj> 야 근데 그때 너 핸드폰이라는 게 있언 ?',
#  '<jj> 경 궂지 않애여 .',
#  '<gs> 또 그것도 있어 댄스학원은 좀 가격이 또 쎄니까',
#  '<kw> 됐고 이 옷은 뭐고 갑자키 왜 피부관리를 하는건데 ?',
#  '<gs> 근데 니가 그때 안 이쁘다 그랬었어 .',
#  '<jd> 아 아쉽게도 아 제 남편은 씨처럼 약간 섬세하고 그런 이케',
#  '<jj> 안고르게 했수다',
#  '<jd> 그래서 나는 컴활은 딸 수 있응게 솔직히 바로 컴활은 딸 거고',
#  '<jj> 자꾸 가 봐사 되는데이 자꾸 가믄 잘 될 건가 ?',
#  '<kw> 생즌에 이딴 적이 없잖어 이름애미',
#  '<gs> 따른 래퍼들도 진짜 아주 옛날에는 그 스윙스 좋아했었고',
#  '<jj> 겅 허드라고 .',
#  '<gs> 밥 먹었나 거의 묵음이 있다 아이가 했나 했나 떨어진다 아이가 이게',
#  '<kw> 다섯 넷 셋 둘 하네기 제로 발사',
#  '<kw> 알았어 그럼 냉중에 봐요 .',
#  '<kw> 처레미 어니 혼재 좋아했던 거 아니에요 ?',
#  '<jj> 행강보민 해서 가보면 그듸 얼음에 그 고기 낚으는 사람도 있곡',
#  '<kw> 그렇지 세 살이면 완저이 애안데 .',
#  '<gs> 그니까 이게 그냥',
#  '<cc> 웹툰에 뭐 본질과는 다르게 약간 쫌',
#  '<gs> 뭐 목적이라 그래야 되나 그런 게 쫌 있으신가요 ?',
#  '<cc> 내가 지금 어떻게 해야 할 것인가를 얼렁들 깨어나서 그러고 또 얼른 이 코로나가',
#  '<jd> 그놈이 지금 목사 생활하고 있으면 그 이만희보다 더 나쁜놈이여 그놈은',
#  '<kw> 어데 아프시다면서요 괜찮으세요 ?',
#  '<gs> 근데 아까 니가 말했던 그 엔대 동아리',
#  '<kw> 상구 결정을 못 했어 장깐 기다려 주세요 .',
#  '<jd> 약간 이제 한 만약에 걸리게 되면 안 걸린 애들은 그냥 그냥 눈 감고 모른척을 해불자',
#  '<gs> 매일 돈 얘기만 해서 쫌 팍팍하긴 한데',
#  '<kw> 왜 선물받은것을 미루니 ?',
#  '<cc> 그때 쫌 막 약간',
#  '<cc> 내가 이렇게 어르신들 지금 다섯 명 이렇게 이케 케어하러 대니려면서',
#  '<kw> 냉중에 벵원 개업만 시켜주면 된대 그짝에서 .',
#  '<jj> 웃음 넌 요가해 봔 ?',
#  '<jj> 막 허멍 며느리도 며느리는 막 미워 가지고',
#  '<jd> 요즘에 정말 우울증이 아주',
#  '<kw> 제가 그 서류로 취직 했다곤 도제 말씀 드릴 수가 없었습니다 .',
#  '<kw> 그래구 왜 이름 씨 한테만 존댈하고 그래 ?',
#  '<kw> 근데 우리 동상이 인자 커가지고는 고양이가 너무 예쁜가봐',
#  '<kw> 팔은 자연스럽게 내려저 무릎고벵이 밑에 둔다 .',
#  '<kw> 내가 알아서 할 테이까 이름 씬 가마니 있어요 .',
#  '<jd> 또 엄마가 까탈스럽자네 . 웃음',
#  '<cc> 그래서 이렇게 나도 지금 이게 조건도 있단 말이여 .',
#  '<gs> 쫌 적게 먹을라고 늘어간다고 하기 때문에 뭐 더 이상 안 늘 거 같아',
#  '<kw> 오놀은 윈도우에서 대해서 공부하겠다 조용해 임마 .',
#  '<kw> 그건 너머 야하군요 언원이 수수한 것은 없어요 ?',
#  '<jj> 아니 옛날 할망들 말론 시상 다 됨져 시상 다 됨져 해 해난에 시상 다 되는 거 닮댄',
#  '<jd> 뭐 이르케 뭐 그렇게 해서 지불해달라길래 아 네 그냥 네 그러니까',
#  '<jj> 검침을 허는데 그때도 역시 그때 한참 젊을 때니까 뭐 삼십 대도 안 할 때지',
#  '<kw> 이르케 많다 해야 되나 요즘 애들은 그리구',
#  '<kw> 내 우리 성님같이 못하는 사람은 보다가 츰이네요 .',
#  '<jd> 그 그것이 삼성에서 나왔드 나왔더구만 그래 가지고',
#  '<jd> 어 디자인이 좀 꾸지고 새로운 디자인도 많고',
#  '<kw> 죄다 겨울이라고 코트를 입었어 .',
#  '<jj> 군이 다 합쳐져븐 거쥬게 .',
#  '<jd> 잘 바꼈다 이런 부분도 쫌 바꾸면은 쫌 더 괜찮을 거 같애라고 이렇게 말해 주시는 형님이거든 .',
#  '<kw> 거게 앉아 봐 .',
#  '<jj> 어 십 이 일 날은 회 먹게 .',
#  '<jj> 콜드브루가 어떤 느낌이냐면이',
#  '<kw> 예 피고하겠어요 그냥 택시 타구 와두 되는데',
#  '<cc> 기운이 샘솟는 거야 그 음식을 그릏게 그냥 집에 있는 음식을 먹으면서 이름아빠랑 둘이',
#  '<jd> 카드를 여따 꽂아야 돼 저따 꽂아야 되는 지 모르시고',
#  '<kw> 너머 잘 썼어 .',
#  '<jd> 한 팔 정도 되는데 윤대협은 백구십이 넘는 그런 장신이자네 ? 그래가지구',
#  '<jj> 근데 그래도 천만다행이라 . 괜히 이것도',
#  '<gs> 잘 보고 있다 갑자기 그런 거 나오면 몰입감 바로 식어버림 .',
#  '<cc> 그러면은 나는 나두 쫌 뒤에 사람한테 눈치 보이고 답답하고 그려 .',
#  '<jj> 그게 나중에 또 한꺼번에 한번에 같이 온다매 그다음꺼',
#  '<jj> 완전 앵겻인디 .',
#  '<kw> 아매 서울시내 중고등학고 전체 펭군 성적이 우리 때미에 떨어졌을걸요 .',
#  '<kw> 할로라도 빨리그 빨라당 가는 게 좋단 말이야',
#  '<kw> 그래 가주고 내가 뭐 항문내과다 이빈후과다 갔다가 뭐 집에 잠깐 들려서',
#  '<cc> 이케 진동이 바로 오고 그리구 문자나 뭐 카카오톡 같은 경우도 오면은 바로 연락이 오기 때문에',
#  '<jj> 경허난 도새기겠지 옛날에 한번 봐신디 .',
#  '<kw> 네 여그 있어요 . 고라고 이건 신용 카드 영수증이에요 .',
#  '<jj> 어느거 하나가 되면은 돈이 없어 .',
#  '<jd> 술을 쪼끔 드시는 편이셔서 간이 쫌 그런 것 같애요 .',
#  '<jj> 야이 그때 뻐스에서 잠자실꺼라 야이는',
#  '<kw> 관광안내소에 가는 길을 가르체 주시오야 .',
#  '<jj> 이제 곹이행 도와줭 해사주',
#  '<gs> 괜찮은 거 같애요 저도 웃음 함 찾아봐 가주고 들고 나가야겠네요',
#  '<jj> 거기서 진짜 얻은 것도 없고 잃은 것도 언',
#  '<gs> 걍 적당히 두루두루 맞춰주면 좋다고 생각하기 때문에 굳이 내가 그거를 가지고 있을 필요는 없다 아이가 내가 안 가지고 태어났을 수도 있는데 그 성격을',
#  '<jd> 짠 국물은 적게 먹는 것이 좋은디',
#  '<kw> 어서 요기 앉어요 .',
#  '<kw> 살 사램 ?',
#  '<jj> 어 그런 것 닮기도 하고 아닌 것 닮기도 하고 해보카 했는데 약간 돈을 준다고 하니까 웃음',
#  '<jd> 그랬더니 아빠가 말도 안 된 소리 한다고 글고 이십 평이 오천만 원이면 너무 비싸다고 막 그러는 거야 .',
#  '<kw> 다음 주 일정이 어타 되십니까 ?',
#  '<jj> 그니까 너 그것보다 더 굽언 .',
#  '<kw> 한참 설명을 했더니 배가 고프 네 오놀 점슴 쏠 사램 없나 ?',
#  '<kw> 법무법인 두 개나 합병 하시구 손녀는 또 그 어렵다는 국제중에 들어가구',
#  '<gs> 그 정구지 넣어가지고 막 부추전 이런 것도 해먹으면 진짜 맛있다 아이가',
#  '<jd> 오면 얼마나 좋을까 그런 생각이 쫌 잠 안 올때는',
#  '<kw> 그래고 버킷 리스트로',
#  '<gs> 그 국어 선생님이 뭐라 했는지 아나 ?',
#  '<kw> 어데서 체크인 합니까 ?',
#  '<jd> 그 고기 꾸어 먹고 애들이랑 막 다같이 모여가지고 카드 게임하고 진짜 재밌었어 그때는',
#  '<jd> 그믄 이제 교전을 많이 해야 되는데 성장형 정글 에이피형 정글로 간다 ?',
#  '<jj> 게이제 완전 죽게 반성햄쭈게',
#  '<jj> 아 기꽈마씸 ? 그럼 나도',
#  '<jj> 옛날엔이 그 전화 돼지 저금통도 이서나신디',
#  '<jd> 딱 서는 거야 안 가고 그 꼬맹이가 가자고 막 줄을 잡아댕겨도 안 가 나만 쳐다보고',
#  '<kw> 그런 거는 벨로 안 좋아하는 편이고',
#  '<kw> 걸충 마무리만 하면 됩니다 .',
#  '<jd> 막 하는 것처럼 막 그런 막 니가 지금 뭘 하면 되는 줄 알아 이런 거 있지 ?',
#  '<jj> 우린 막 멀리도 안 가곡게에',
#  '<cc> 근데 막상 다 만들고 나서 이거를 말련 말려 놨는디 언니꺼는 괜찮은디',
#  '<kw> 나도 어데 가정부 짜리나 알아볼 걸 그랬나 ?',
#  '<jj> 뜬 아이구나 막 생각 들었수다 그거 보멍 .',
#  '<kw> 사장님께서 제게 직접 즌화 주셨는데',
#  '<cc> 그렇게 해가지고 한 한두 달 정도 하다 보니까 이것도 은근히 쫌 되게 살이 많이 빠지고',
#  '<kw> 그래고 심야영화를 보고 오는',
#  '<jj> 겅허연 또 체육시간 행 체육시간 해서',
#  '<cc> 일 터득하는데 본인만의 노하우라 하면은 솔직히 말하면은 노하우라고 하기도 뭐한 디 너무 당연한 거라서 .',
#  '<kw> 깍디기가 익어야 맛나잖아요 엄마 .',
#  '<jj> 말 곧당 보니까 지치고 목도 마르고',
#  '<gs> 어 나도 그게 쫌 근데 해 보고 싶어서 쫌 생 많이 쫌 찾아보고 했거든',
#  '<jj> 에이씨 그래가지고 형부도 써보난',
#  '<jd> 근데 인제 잘생기고 키도 크고 약간 좀 좋은 그런 유전자를 가지고 있었는데 사고 때문에 다리가 짤렸어요 두 다리가',
#  '<kw> 엉이 하실래요 ? 어떠세요 ?',
#  '<gs> 약간 뭐라 해야 돼 다이어트할 때 그런 거 막 땡기는 음식들 있거든 .',
#  '<jj> 그예 터진 입이랜 골아진양 막 곧는거 아니 언니 나이값 헙써',
#  '<jj> 뽕 튀어나와 인 . 예쁜 거지 .',
#  '<kw> 자게는 무얼 먹고 싶어 ?',
#  '<jj> 이제 막 해신디 그래갖고',
#  '<cc> 근데 다 좋아해가지고 쫌 재밌게 봤던 기억이 있습니다 .',
#  '<jd> 이것도 남들이 봤을 때는 한 인제 와서 막 이러던데',
#  '<gs> 어쨌든 그 쫑 났다 그래서 차단하고 내 인생에서 쪼까냈다 싶은데 아직도 지금',
#  '<gs> 아님 뭐 어려웠던 거나 그런 거 없었나 니 뭐 나이 많아서 어려웠다든지 뭐',
#  '<jd> 그러니까 그런 푸징가리를 가지고 오면',
#  '<kw> 이랬던 저랬던 무조근 잡아 보이까 사램 참 착해 보이더라 .',
#  '<kw> 아유 근데 뭐 그것도 언니 지 적성에 맞아야 된데이 야들 힘들대',
#  '<kw> 와이셔츠나 블라우스에 묻은 볼펜 찌끄레기는 물파스로 슥슥 문질러주면 없어진다 .',
#  '<kw> 추운 데 있는 연인 때미에 겨실에 코트조차 안 입겠다고 우기민서 살고 있는',
#  '<kw> 허 망금 그 눈 뭐야 ?',
#  '<jj> 내려가는데 요새는 중앙에 이게 뭐라 그러지 중앙 분리하는 거 이렇게 말뚝 박아 놓은 거 너무 많이 해 가지고이',
#  '<cc> 그래 가주구 제가 쪼꼼 쇼핑을 좋아하진 않는데',
#  '<jd> 결국에는 잠정 하차 그 의사 전달을 했다고는 하는디 아직도 나오나 ?',
#  '<jd> 그서 나는 특별히 뭘 하다기보다는',
#  '<gs> 내가 쫌 평소에 읽고 싶었던 책이 있었는데',
#  '<jd> 지금 말은 입으로 못 밴디',
#  '<kw> 제주도에선 그른 셔츠 하내기는 있어줘야거든요 .',
#  '<kw> 니가 싫어서 .',
#  '<kw> 에이 어데가와 ?',
#  '<cc> 그러면서 애도 밝아지니까 그 네 쪼금 시간이 남죠 언니도 이케 시간이 남듯이 저도 시간이 넘는 거예요 근데 그때 터진 거예요 서로',
#  '<jd> 그리고 아까 니가 말한 그 마이클 조던 있자너 거 넷플릭스에서 하는 거 아니여 .',
#  '<jj> 아니더라 맨날 지멋대로 하던디 ?',
#  '<kw> 누우 속상해 하지 마 그냥 가면 되잖아 가자구 .',
#  '<kw> 할어머이 죄송해요 .',
#  '<jj> 야 이정도면 복권을 사야되는거 아니 ? 수상한데 꿈내용이',
#  '<jj> 그럼 동상 걸리면 이제 군 생활 안해도 되는거 ?',
#  '<cc> 쫌 과장되게 표현된 거라고 생각을 하는데',
#  '<cc> 아 나는 사실 좋아하는 여 영화 특히 예술은 그까 너가 말한 것처럼',
#  '<kw> 아아아 아 저 오놀 마침 안 방송은 제가',
#  '<cc> 이제 뭐 티비로도 쫌 자주 보이시는 그 기안 팔사 님이 약간 그런 그림체라고 해야 되죠 ?',
#  '<jj> 차 타그네 허젠 허믄 글 몰라그네게 몇 번 타면은 그 글자 그림 세봐그네',
#  '<jj> 먹을 간식은 챙견 ?',
#  '<jd> 글고 자네 뭐 또 또 뭐 있다 그랬제 ?',
#  '<cc> 진짜 엄청 잘 키운 거야 니네 집안은 근데 니네 엄마는 그렇다매 남의 이목도 되게 중요시 한다매',
#  '<jj> 해 짧아져 불고 하니까 얼른 가가지고 가그냉 해야 되잖아 .',
#  '<kw> 나보구 여개서 살라구',
#  '<cc> 그런 걸 쫌 많이 보고 가요 그래서 만약에 만사천 원짜리를 갔는데 여기 선생님 너무 마음에 들어 .',
#  '<kw> 운제 올꺼야 니 쉐프랑 .',
#  '<jj> 저 우리 어멍 빼어오믄 그거 그냥 한 대 주주게 .',
#  '<jd> 특집을 마련해 봤당께 .',
#  '<jd> 예를 들면 인제 스커트 무릎 운동 허벅지 운동은',
#  '<jj> 아 그러면 게믄 됐수다 .',
#  '<jj> 희한하다 그 나와있는데 언니 잠깐만 내가 예 그 색깔을 보여줄게 .',
#  '<kw> 내가 써빙 할 땐 다 감당했어 잔말 말고 게신 테이블이나 치워 .',
#  '<jd> 타격대가 짬 찬 애들이 많이 가가꼬',
#  '<kw> 그 따우 소리기 할 거야 ?',
#  '<kw> 자네가 나와서 그런지 오늘 정심은 아주 유쾌했어 .',
#  '<jd> 인자 초창기에는 초 초기에는 시작한지 얼마 되지 않아 가지고',
#  '<kw> 제가 질까봐 극정되나 ?',
#  '<jd> 인보험의 손해 사정 업무의 경우 강도가 높은디',
#  '<kw> 낮에는 비가 오다가이 저녁때에는 눈으로 변했어 .',
#  '<kw> 갠데 자네의 그근 어떠 됐지 .',
#  '<jd> 쪼끔 이렇게 소심하다 그래야 되나 그런 부분이 맞는 거 같고 에이형은 쫌',
#  '<jj> 그러니까 나한테 모든 걸 다 말하는 거',
#  '<kw> 이 사램들 뭐예요 ?',
#  '<jd> 막 앞에서는 신나는 척 막 외향적인 척 이릏게 하면서도 .',
#  '<jj> 일등하면 장원급제 최우수 우수 장려상 영 행 줌신디',
#  '<kw> 누우 너머 씩씩하게 오는 거 같애 .',
#  '<gs> 그래가 엄마 방에 그냥 쏙 들어가 버렸어 충격을 먹었는지 .',
#  '<jd> 돈 오십만원줬네',
#  '<kw> 나 거지뿔하느라 죽는 줄 알았다 .',
#  '<kw> 인제는 그 애가 우리 핏줄 핏줄이라는 거 알았으이까 모른 척 할 수는 없다 .',
#  '<jj> 우리도 막 동창들 만나고 겅 하주 그런 얘기를 제일',
#  '<jd> 당연한 거 아냐 ?',
#  '<kw> 왜서 그러고 있어 이름 가 갖다 주래서 .',
#  '<jj> 게난 저기 아까 어멍이',
#  '<cc> 저번에 내가 위 때문에 요즘에 계속 병원을 가야 되는데 바뻐서 갈 시간이 없는 거야',
#  '<kw> 요즘 연예병사라는게 없어졌어요 일반부대에 있다가 오디션을 보구 차출되는 거에요 .',
#  '<gs> 보면서 쫌 힐링을 할 수 있는 것 같습니다 .',
#  '<kw> 츰부터 의심하고 경계했어야 했어요 .',
#  '<cc> 그 간이 쫌 그때',
#  '<kw> 뭐 꼭 매장일 때민이 아니래두',
#  '<cc> 좋아 가지고 가서 인제 뭐 이르케 시간이 없는 데도 갠신히 가서 보고 오고',
#  '<jj> 저도 어정쩡한 세대라예 사실은',
#  '<kw> 어버이랑 아버이니랑 아버이니랑 얘기하는 거 들었어 .',
#  '<gs> 막 쇼 쇼파 여기 팔 거는데 이케 다 물어뜯어 가지고 안에 솜 보이고',
#  '<jj> 금방금방 객실 청소 또 해여',
#  '<jd> 우리가 또 굴러도 크게 굴른다고 약간 휴식도 십만원대 정도 주식을 사서 굴린 것이 나을 것 같고요 .',
#  '<gs> 아 저는 물건을 사람들이 입소문을 통해 가주고 어 이게 좋다 해서 들어서 사 본 건 없는 거 같애요 아',
#  '<kw> 무이미할 수두 있다는 걸 알아버렸거든 .',
#  '<jd> 그래서 나는 어 이르케 먹는걸로 식단으로 다이어트를 하는게',
#  '<kw> 너 지굼 뭐라고 했나 ?',
#  '<kw> 우리 통장을 왜요 아부지 ?',
#  '<gs> 도 옆에 배우자가 쫌 흔들린다 이러면은 스트레스 굉장히 받을 텐데',
#  '<jj> 어 그때가 나 진짜 너무 기억에 남는 거라 ?',
#  '<cc> 그렁게 만 원어치 담았어 그렁게스물두 개더라고 스물네 개 그거면 왠지 뭐',
#  '<cc> 인제 패러세일링을 이제 할려고',
#  '<jj> 경허군데 그렇게 했는데 아이구 기여게 시집가고 시집이나',
#  '<jj> 그 중산간에 예 한 삼천 평에 흑돼지를 방사행 키워난 디가 이서났어 . 예',
#  '<kw> 저게 은앵에 가는 거 아니었어 ?',
#  '<jj> 지금 한 삼 이십오분 남았져게 .',
#  '<cc> 그럼 혹시 선생 그까 선생님 혹시 아이돌 중에서 아 좀',
#  '<kw> 여자가 지 셔츠를 쳐다보고 있사 .',
#  '<jd> 바까 볼 생각은 없어 ?',
#  '<kw> 별은 채고 밝고 따듯하다는데 그 말이 맞나 봐 .',
#  '<jj> 응 아니 저 아기 저 호끔 늦게 났주게 마흔 마흔 살에 나 가지고 웃음',
#  '<jd> 몸통 하나에 컴퓨터하고 본체가 붙어분 것도 있더라고 .',
#  '<cc> 막 따른 거 옛날에 찍은 으라차차 와이키키 투 거기에도 인도를 하고 이래가지구',
#  '<kw> 그 애는 에우는 것을 잘한다 .',
#  '<kw> 아가씨가 우리 이름 랑 나아도 나으도 같고 딸 같아서 하는 말인데 .',
#  '<kw> 이게 어데서 ?',
#  '<jd> 응 선생 포함해서 한 여 넷 다섯 명 안에 드는 거야 그래서 이 앞전에 한 기간 만료돼갖고 삼 개월 단위로 끊어 끊었었는데',
#  '<jj> 뭐냐 그 남자애가 가가지고 불 켜 줄까 영하니까 아니다 처음에 거기 있어 이렇게 하니까 네 이렇게 했댄',
#  '<kw> 즈 엄마',
#  '<jj> 허루에 잘도 돈하영번댄 돈 많이 번다고 헙디다 .',
#  '<kw> 그녀는 그림에 대해 비범한 재능을 가꼬 있었어 .',
#  '<cc> 너가 쩌번에 얘기해줬잖아 뭐 김앤장까지 껴서 고소하겠다고 공지문 띄웠다고 그래서 나도 쫌 생각을 해봤는데',
#  '<kw> 맞재비로 달리기의 이야기가 동등히 대담해 .',
#  '<kw> 이번 여행에서는 어엽는일이 많았어 .',
#  '<cc> 나이가 안 돼 갖고 인제 그래서 어띃게 뭐 집에서 이제 돈 내고 봤었지 .',
#  '<cc> 꽉 막혀가지고 그래서 가위로 양 테두리를 짤라가지고 공기 구멍도 막 만들어가지고 사용하고 그랬었는데',
#  '<kw> 화물이 정체해 있사 .',
#  '<kw> 오빠 이그 어때요 ?',
#  '<kw> 테이블이 벽에 닿은 부분에 페인트가 삐끼지싸 .',
#  '<jj> 완전 신중해야 될 거 닮 진짜 완전 .',
#  '<jd> 그런 거 말고두 또 겁나게 많은 취미나 이제 같 취미지만 이제 도움이 안 되는 거일 수도 있는데 그런 것도 이제',
#  '<jd> 좀 절차도 있고 쫌 관리직이다 보니까는 아무래도 저보다 많이 알겠죠 근데',
#  '<kw> 저냑 여덟시까지야 늦지말고 와 .',
#  '<cc> 지금은 약간 막 술도 못 팔고 그 약간 클린한 약간 그런 축제로 바꼈잖아요 ?',
#  '<jd> 라면 끓여 먹고 그러는디 아으 김치가',
#  '<gs> 아니 그니까 무슨 스타일인지 알겠제 어 그래서',
#  '<jj> 좋은 말도 못 해라는',
#  '<jj> 물에 타 먹으면 맛있지 안',
#  '<jj> 게 오래가지 않을 테주 게',
#  '<jj> 그 저 모양을 좀 설명을 하면 무시경 해질건고 ?',
#  '<jd> 나 진짜 그때 너무 놀랬어 나도 딱 그때 내 그 상황이었으면 따지고 난리도 아니었지 너무 심각하더라 그때 진짜 그 분은',
#  '<jj> 진짜 아멩헤도 옛날 예전만이 맛이 안핸 예',
#  '<jd> 쫌 안 좋아지는게 많잖아 .',
#  '<jj> 겅해도',
#  '<kw> 이름 이가 뭣 땜에',
#  '<jj> 낸중에 보난게 무신',
#  '<kw> 옛날 소갈비도 끌어 가지고 막 태우고 그랬잖가 우리',
#  '<jj> 누가 사진 찍는데 사 랑 사 랑 햄수다 . 적어진 커피 앞에',
#  '<kw> 엄지발꼬락이 큰 건 유전인 거 같아 .',
#  '<jd> 뭔가 긍까 귀에 꽂아 놔도 안 들어 노래가 나와도 웃음 그래서 거의 그냥 안 듣는 편 ?',
#  '<cc> 강아지들한테도 할 수 있고 쫌 스트레스받거나 우울할 때',
#  '<jj> 주된 내용인디 어쨌든 좀 약간 풋풋한 그런 대학 생활 얘기 ? 지금 내가 대학 다닌지 좀 되부난',
#  '<kw> 근데 무신 일인데 ?',
#  '<jj> 여기가 어디냐게 여기가 오만 놈이 다 들락거리난이',
#  '<kw> 어머이가 얘기 좀 해 볼까 ?',
#  '<gs> 마침 옆자리에 있는 사람이 경상도 사람인 거야 그래가 합석해가 소주 한잔 먹고 그래 왔는데',
#  '<kw> 게따 이름 이 벵원에 간다니까 그 상간에 몰래 들어와 .',
#  '<jd> 약간 쫌 잘 집중이 안되는 것 같은 그리고 약간 쫌 빨리 피로한 것 같은 느낌',
#  '<jd> 그래서 그런지 자꾸 약간 안 하던 짓도 하고 나한테 쫌 이렇게 할퀼려고도 하고',
#  '<jj> 근데 요샌 이추룩 시대가 사람들 많이 모이는 것도 힘들고 전시하기도 힘든 상황이난 그런데',
#  '<kw> 안 그래도 오래 타면 탈수록 타이어가 많이 닳기 때문에 타이어도 쫌 자주 갈았었고',
#  '<gs> 네 전 게임이 꼭 실력이 쫌 좋아야 된다 이렇게 이런 마인드를 가지고 그렇게 에프피에스 게임을 하게 됐고 이제 뭐 서든 언택도 애들이 많이 해 가지고 서든 언택을 하게 됐는데',
#  '<jd> 그리고 두 번째는 어째 쫌',
#  '<jd> 음 그러고 보니 우리도 인제 김장을 쫌 빨리해야 되는디',
#  '<kw> 좀 늦는다구 즌화 왔어요 .',
#  '<jd> 지역 늫 게 만오천 원이고',
#  '<kw> 뭐 내 배운기지 .',
#  '<jj> 실기 백 프로 행',
#  '<jd> 한 달 분 사서 부쳐줬어 언니 먹다 말고 우리 딸 줘 부러써',
#  '<gs> 자리를 예매해가주고 그나마 쫌 연속으로 자리가 겨우겨우 예매를 했었고',
#  '<kw> 오놀 무리하지 마 .',
#  '<jj> 경허면 그 파도가 길가레 덮치니깐',
#  '<jd> 그래서 저한테는 그니까 인제 우리',
#  '<kw> 이것을 끝내려면 울매나 걸리더냐 ?',
#  '<kw> 응 아부지 ?',
#  '<cc> 근까 그건 이제 어쩔 수 없는 분위기를 얘기한 거고 아까 얘기한 것처럼',
#  '<kw> 발싸 변했그나',
#  '<jj> 그런데 무심 피자 먹언 ?',
#  '<jj> 그리고 또 시즌 투도 하니깐이',
#  '<gs> 추구했다는 게 약간 쫌 자부심 느껴지지만 지금은 그 꿈이 아니지만',
#  '<jj> 원래 안 간 날이 제일 행복하지 .',
#  '<kw> 어마이 누우세요 .',
#  '<jj> 이렇게 데모하면 효과가 있긴 이서',
#  '<jd> 쫌만 연습하니까 막 세계 막 재패해버리고 그래가지고 나도 중간에 걍 나왔어',
#  '<kw> 그리구 아들이 그렇다고 데리고 자는 어마이는 또 뭐이야 ?',
#  '<gs> 그래서 그거 토너 패드라고 아나 그거 몇 개 받고',
#  '<cc> 이쁜 거야 근데 직장을 고만둔다는 데는 인저 같이 인저 있던 사람들하고 인저',
#  '<kw> 여개서 오른쪽으로 가야지 .',
#  '<jj> 맛조추',
#  '<kw> 둔 채 니가 집을 나갔어 .',
#  '<kw> 오날 귀빠진날 이시죠 ?',
#  '<gs> 쪼끔 망설여지긴 해 그래 진짜 아빠말마따나 고마 보험 안 넣고 저기 한적한 데 가 갖고 고마',
#  '<jd> 최성순가 뭐 했던디 자네 갔었는가 ?',
#  '<kw> 이무 이무 정신 근강을 위해서 말씀드리는 건데요 .',
#  '<jj> 거 올해 받을 거 ?',
#  '<kw> 이름너 저냑도 안 먹었을 거 아냐 .',
#  '<gs> 진짜 쉽지만은 않겠다라는 그때 생각을 쫌 해 가지구',
#  '<jd> 영 찝찝한 게 있으면은 동거 해봐야지 그니까',
#  '<kw> 그럼 니가 대신 팔거야 ?',
#  '<jj> 저 빨래를 다해뒁 이름 엎고 와랑와랑',
#  '<jj> 그치 ? 그렇지 이런 손님이 있단 말이야 근데 가이는 털도 날리는데 또 관리를 안 해',
#  '<jd> 이제 생각이 들고 이제 충격을 먹고 이제 엄마한테 따른 거를 키우자 인데 엄마는 이제',
#  '<jd> 그니까 운 좋게 어떻게 하다가 군대를 안 갔어 그니까 약간 커트라인에 걸렸는데',
#  '<gs> 하는 걸 보여주고 이래야 되는데 성격이 웃음 쫌 안 되는 것 같애요 .',
#  '<jd> 우리는 봐바 딸이 여유가 이씨 살아도 사위가 모든 것을 딱 이름 한테 매깨부러 . 맡겨 버려 .',
#  '<kw> 처레미 가라 .',
#  '<jd> 입소를 허게 됐는데',
#  '<jj> 안 한다고 하니까 엄마가 말 같지도 않은 소리 하지 말랜',
#  '<kw> tv를 개차이서 보면 시력이 안 좋아질 수 있어요 .',
#  '<jj> 갑자기 줄 생기면이 나도 모르게이 그냥 걸려 .',
#  '<gs> 눈이 쫌 많이 안 좋아져요 .',
#  '<kw> 너무 놀랬어 증말',
#  '<jd> 근데 그 다음에는 사진 찍은다 그러면은 턱에 딱 내려가지고 찍었는디',
#  '<jj> 그때 눈이 펑펑 와부난',
#  '<jd> 아버지는 보 그 이걸 쫌 허물하게 써진 않고 그냥 하루는 그냥 살아 보고',
#  '<kw> 좋아 거개서 보자 제시간에 와야 해 .',
#  '<gs> 이랬는데 어느 날 얘가 갑자기 난데없이 제의를 하는 거야 주왕산에 가자꼬 그랬는데 어 그래 가자 이케 했는데',
#  '<kw> 나랑 한 얘기들은 하내기도 기억하지 못한단 말이나 ?',
#  '<kw> 무신 소릴 하는 거야 ?',
#  '<jj> 아니 경해가성 죽어 죽어졈샤 ?',
#  '<kw> 니말이 아니었어도 사실 나 그 친구랑 진짜 한번 온힘을 다해 승부해 보고 싶었어 .',
#  '<jj> 기 회사에서도 언니',
#  '<jd> 어차피 내 몸 상태가 어떤지 알고 내 꼬라지가 어떤지 안께',
#  '<jj> 찍 소리도안행 게',
#  '<cc> 우리 이제 므 사람들을 그까 지나가는 데 막 잡아서 막 전도 이케 해달라 .',
#  '<gs> 그러면 라면 얘기가 나왔으니까 니는 라면 중에 제일 좋아하는 라면이 뭐야 ?',
#  '<jd> 처음부터 시작해서 우리는 중간에 시작해갖고 .',
#  '<jd> 근디 형은 어떻게 생각 혀 ?',
#  '<jj> 막 욕 하면서 막 했네 우리 엄마 테레비젼 보당 미국은 대통령 할 사람이 오늘 내일 하는 하르방들 밖에 어시냐 . 웃음',
#  '<kw> 나두 질리우 .',
#  '<jj> 가이 막커서라이 .',
#  '<kw> 한 만 원 하내기 ?',
#  '<jd> 행복하겠다 마 이제 이른 생각',
#  '<kw> 그 계획은 검토중에 있사 .',
#  '<kw> 첨엔 다 누님 동상하민서 시작하는 거에요 .',
#  '<jd> 난 머 이상형 별로 없었는데 일단 잘생기면 좋겠다 생각했지 .',
#  '<jj> 아니지 . 대왓은 대나무 밭 .',
#  '<kw> 괜찮아요 제가 피곤한 날이 날은 알아서 쪼매이 더 잘게요 어머님',
#  '<jd> 긍게 너 아 근데 내가 얼핏 들었을 때 너가 그러면 오디션도 보고 그랬다고 하는데',
#  '<gs> 되게 쫌 강압적으로 하기도하고 하는데 요즘에는 또 이제 워낙',
#  '<gs> 자기들이 살 건데 뭐 우리가 데꼬 살 것 아이고',
#  '<kw> 넌 지금 나한테 그런 말이 하고 싶나 ?',
#  '<kw> 이에 음석 찌꺼기가 끼어 있어 .',
#  '<gs> 그 뭐 상위 몇 프로라 하기는 쫌 그렇지만 어쨌든 그쪽 전문가들 분야 안에서',
#  '<jj> 그런데 마지막에 어나택되서 있네 .',
#  '<jj> 코나 한 개만 났네 .',
#  '<kw> 늑대마니 꼬리를 밟는 기분 이었어 .',
#  '<jd> 바로 행사장까지 쫌 걸어갈 수 있스 있는 거리라서',
#  '<kw> 먹고 해서 살이 안 빠지는데 아 나는 쫌 찬차히 빼야 될 거 같',
#  '<gs> 그 여자 기준에선 담배 피는 게 더 좋은 것 아이가 더 편하다 아이가 일단',
#  '<jd> 근데 인제 막 그 종교도 다 글잖아 .',
#  '<cc> 이렇게 숯을 너가꼬서 거따 인자 방에',
#  '<jj> 이제 또 쉬멍 하잰 해신디',
#  '<cc> 그런 거 뭐 뭐 뭐 그런 거 잡아가지고 뭐 생선국시도 해먹고',
#  '<kw> 눈이 와 가주 세상이 은세계가 됐당께',
#  '<jj> 거난 옛날에는 그추룩도 하고 겅해난',
#  '<gs> 그까 쫌 생각은 많이 하고 있어 노트북 그니까 그 모니터 모니터도 되게 큰 걸로 해 가지구',
#  '<jj> 좀 더 해살건가 .',
#  '<kw> 서이가 헹부한테 홈페이지 주소만 가르쳐 드리면 돼 .',
#  '<gs> 그래서 쫌 관심 있었는데 아 솔직히',
#  '<gs> 그 그것을 뚜다가 어 그만둘 수는 없고 또 뜨다 보면은',
#  '<jj> 삼춘들 알아지겠지예',
#  '<kw> 어릴 때 흘기로 장난을 많이 쳤었어 .',
#  '<jj> 운동하멍 뭐 먹을까 배고프다 뭐 먹지 ?',
#  '<jj> 정신병자들 많아 이',
#  '<kw> 아주버니 .',
#  '<jj> 외롭다 밥친구 잃언',
#  '<kw> 해졌는데도 집에 안 들어가고 애인이랑 있는 거 저절로 발이 저려서 .',
#  '<gs> 말을 들어보면은 찰떡 겉이 착착 달라붙게 말을 하거든요 ?',
#  '<jj> 케이 알 안 썼구나게',
#  '<kw> 그리고 또 인제 불에다가 인제 막 지금은 휴지가 있는데 옛날엔 휴지도 없었자나 웃음',
#  '<kw> 천서방이나 입단속 단디이 시키래이 .',
#  '<kw> 일부러래도 그래도 농촌 변하는 거는 해야지 .',
#  '<kw> 엉 니 뭐 나이 먹으면서 뭐 성격이 바꼈다거나 아니면은 뭐',
#  '<gs> 쫌 머나먼 미래처럼 느껴진단 말이죠 그래 가지고',
#  '<gs> 음 그래야지 머 나중에 손해도 안 볼 거고',
#  '<jj> 차가 어디 있냐게 씨',
#  '<jd> 그렇게 유혹이 있어도 나가 다 안 했었는데',
#  '<kw> 아깨 보이까 어깨쭉지가 좀 높더라 .',
#  '<kw> 친구들 모임 있어서 쪼매이 늦을 거야 .',
#  '<jd> 가족 사이도 이케 막 벌어 놓는다 그러잖아요 .',
#  '<jd> 기차 통학 기차를 끊으면 할인이 돼 그니까 그걸 끌어가지고 하는데 거기서',
#  '<jd> 한 십오 년 다니다 봉게 안 갈 거 같여 .',
#  '<jj> 우리 보믄 눈들이 호끔 노르스름하주게',
#  '<kw> 한 놈이 극정 없으문 한 놈이 코빠뜨리고 있고 .',
#  '<kw> 친구 고모인데 아주 뭐 아버지가 엄청 오빠가 보자니까네',
#  '<jj> 겅 행 월산 근처 쪽에 무슨 스시 집이 스시 집인가 거기 간예 스시 무슨 이름은 기억 안 남수다게',
#  '<jj> 딸 이 다 해여',
#  '<kw> 유치한 소리기 작작해라 .',
#  '<jd> 이 얘들하고 잠 친해졌는데 다음날 헤이질려고 하니까쫌 섭섭하기도 하더라구요 .',
#  '<kw> 아무래도 입적 문제 때메 고민이 많은가봐요 .',
#  '<kw> 그러 피곤해 ?',
#  '<jj> 십오만 원 돌안 ?',
#  '<gs> 그것도 쫌 말로만 들어보면 하우스 오브 카드처럼',
#  '<kw> 어 제가 좀 뭐에 조금 더 가치를 두고 무엇을 쫌 더',
#  '<cc> 어 모집이 마감됐다 해서 이 학년 때 신청을 할려 했는디 그때 코로나가 하필 터지게 돼서 학교를 못 가게 돼서 신청을 못 했던 게 있어 .',
#  '<kw> 그 띨빵한 남자배우가 자꼬 엔지를 내는 바람에',
#  '<kw> 좋게 말할 때 이 골목탱이에 안 나타나는 게 좋을 거요 .',
#  '<jj> 요쪽에 우리 요기서 시에서 보믄',
#  '<kw> 머시기 때민에 싸웠어 ?',
#  '<kw> 라탄을 물에 뿔리고',
#  '<cc> 막 이릏게 산다 나 이런 거 메고 다닌다 막 자랑하고 다니잖아요',
#  '<jd> 그랬더니사 비교분석하고 갖고 왔드라구 갖고 와서 싹 봤어',
#  '<kw> 내가 누그 딸이유 ?',
#  '<jj> 쓰레기 버리는디 무사 이어폰을 꼉',
#  '<cc> 그래서 다이어트 약을 그렇게 어 그까 고도 비만 아닌 사람들이 계속 먹으면서 의지하고 이러는 건',
#  '<jd> 팔천 원 구천 원 이렇게 주고 그리고 따른 데는',
#  '<jj> 가이가 써서 한 번은 자기는 어린 시절에 너무 이',
#  '<jj> 그래 가지고 이케 가다가 다시 빠꾸',
#  '<kw> 어마이 저 때미네 이렇게 되셨고 지가 집을 나간다고 해서 충격을 받으시고 .',
#  '<kw> 이름 씨도 이름 가 극정이 돼서 있었어 .',
#  '<cc> 물어 보고 수란 할 줄 알으면 데려와도 되고 수란 몬하면 친구만 하라 그랬대',
#  '<kw> 어머님 어데로 갈까 ? 어데 가서 바람 좀 쐬고 올까요 ?',
#  '<jj> 다음날은 그기도 강으네',
#  '<jj> 그러니까 촞아 오지 않을거야 게난 돈만 벌엉 잘 놨다그넹',
#  '<kw> 전깃불을 키다 .',
#  '<jd> 조폭 같은 사람이 나와가지고 인제 그런다고 하더라고 이거 봤는지 모르겠는디',
#  '<kw> 상훈이가 보내준 건데 중국에서 뒤게 유멩한 약이래 .',
#  '<jj> 이와중에 도대체 단란주점을 왜 가는 거 ?',
#  '<kw> 어 여보 왜서 ?',
#  '<jd> 언니가 또 순해서 아무 말도 안 하니까 둘이 그렇게 인제 잘 지내는 거 같애요 .',
#  '<jj> 꼭 따야될 때 그럴때 딸거닮아',
#  '<jj> 아 없수가 ?',
#  '<kw> 나 등단할때까지 겨론 접어두구 최선 다할거니까 .',
#  '<jj> 그게 더 심하덴마씨 . 완전히',
#  '<kw> 뻐꾸기눈물 더 편하게 지내는 기 좋아요 .',
#  '<gs> 듣는 얘기가 쫌 남들 이야기를 잘 들어준다고 해야 되나 ?',
#  '<kw> 그에게 연락할 딴 방법은 없을까요 ?',
#  '<jj> 무사 파트가 정해졍 있지 않아서 느 할 일은 느 있구 요기 할 일은 여기 있구게 .',
#  '<jj> 그리고 버스 탈 바에 드라이브나 가게',
#  '<kw> 이름씨도 오래오래 살아줘이 .',
#  '<jj> 제주도는 이 동네 저 동네 할 것이 귤 밭이 제일 많주게 . 무슨 .',
#  '<jd> 이렇게 돼가지고 쫌 내 머리 속에 강렬하게 기억이 된 것 같아 .',
#  '<jd> 부모가 인제 엄마가 일찍 돌아가셨어',
#  '<gs> 여튼 그렇게 해서 먹어봤는데',
#  '<gs> 쫌 크게 혼냈을 거 같긴 하거든 엄청 아니면 솔직히 그 전에 내쫓았을 거 같다 내가 내 성격에',
#  '<jd> 착한 게 아니라 다정한 거지 잘 챙겨준 거고 어딜 가도 너가 이제 훈련을 간다해도',
#  '<jd> 테레비 테레비 이어폰 우리 아빠랑 같이 둘이 본디야',
#  '<cc> 아니 근데 비트코인이 또 폭락할 수 있잖아 이천십팔 년 고때처럼',
#  '<cc> 내가 생각하는 그런 쫌 젊은 사람들이 많이 그리는 눈썹이 있는데',
#  '<jj> 생각낭으네 우리 저기 엄마도 저기 절물 자꾸 가난 갈 때만',
#  '<jj> 그 가지 못하게 여자가 밤중에 댕깁덴 하멍',
#  '<gs> 안 나간다고 보는 거니까 되게 쫌 그런 부분은 부럽더라고요 .',
#  '<jj> 나 한번 이거 고쳤수게게 팔십 만 원 줭',
#  '<kw> 니는 좀 괜찮나 ?',
#  '<cc> 쫌 목돈은 많이 안 쓰는데',
#  '<kw> 아이스크림이나 까묵고 뭔 생각이에요 지굼 ?',
#  '<kw> 근데 우리는 아 그렇게까지는 안 하고 그냥 이케 내복까지는 허용을 해 주드라고',
#  '<jj> 양 언니는 게난 그추륵 언니네 한테 언니가 그추륵 발랑발랑발랑 해버리난 어머니가 우리한테',
#  '<jd> 은제야 ?',
#  '<gs> 그런 부분들 그니까 그 복서로서 가졌어야 될 재능 같은 걸 되게',
#  '<jd> 성수가면서 어른스러운 명품 .',
#  '<jd> 이제 요요가 와갖고 다시 살이 쫌 붙었더라고 ?',
#  '<kw> 그니까 메칠만 미워하다가 용서해 주라 .',
#  '<kw> 그래 나 동상은 걔가 지금',
#  '<kw> 쇼핑백의 내용물을 말쌈 해 주실 수 있겠습니까 ?',
#  '<jj> 두드러기가 엄청 올라와 있는 거 ? 허벅지 같은 데',
#  '<jj> 경주마 사육한댄 하더라고',
#  '<gs> 삶의 뭔가 소중함을 코로나와 여행 때문에 알게 되네 이카면서',
#  '<jd> 아 그 약간 쫌 전체 도는 것 ?',
#  '<kw> 그러구선 왜서 부에는 나한테 부려 ?',
#  '<jd> 다 우리 오빠도 맛있다고 걍 다 맛있대 .',
#  '<jd> 그래 있어 그래가꼬 항상 같이 나와',
#  '<cc> 경기 관람을 직접 가서 보신 적이 있으신지 어떤 걸 보셨는지 쫌 질문드리고 싶네요 ?',
#  '<kw> 너 겨론이나 하고 시느매 얘기할라 했는데 .',
#  '<kw> 지대로 잡으려면',
#  '<cc> 그릏게 좋은 승질은 아니여 .',
#  '<jd> 천천히 군데군데 보고 돌아다니고 헐러면은 한 십일은 잡아야돼 .',
#  '<cc> 근데 이제 김성수가 표현하기를 닭볶 그니깐 약간 그냥 떡볶이에서는 최상의 뭔가 이제 그 있는 맛이고',
#  '<jj> 어떵헤 어떻게 해 그런데 가는데 뭐 길도 아무것도 모르두고 게 헤노난 게',
#  '<cc> 애기가 이제 정서적으로나 뭐 이케 부모 간의 사랑을 통해서 이제 어쨌든 사회 이런 것도',
#  '<cc> 연예인 누구 이름 가 있디야 그걸 또 하나 사봐야 되것어 .',
#  '<jd> 프로그래밍 관련해서 쫌 자율 동아리를 하나 만들어서',
#  '<jd> 응 나도 그래 볼까 라는 생각도 많이 들고잉',
#  '<jd> 그런 쫌 성장하는 그런 드라마라 드라마여서 쫌 가슴이 벅차오르는',
#  '<jj> 깜짝 놀래서 이',
#  '<jj> 잘도 그 전에 학교 애들한테 우리는 반이 여러 개라고 촌은 일 반 밖에 어서부난 . 웃음',
#  '<kw> 아부지 그냥 못 본 척 해주세요 .',
#  '<jd> 그 사람들이 더 많애 버리니까는 우리는 꼼짝 못 하고 그럴 수밖에 없는 거고',
#  '<kw> 즌쟁 범죄 조항은 독일을 비난했어 .',
#  '<kw> 이젠 아직부터 서루를 확인하는 거지 우리 ?',
#  '<kw> 좋은 소질을 지니고 있사 .',
#  '<kw> 아뇨 어머이한테 남자는 우리 아부지 한사램뿐이예요 .',
#  '<jj> 뭐랜 했댄 가이한테 계산병한테 .',
#  '<kw> 아칙에는 차가 많이 밀려 .',
#  '<jj> 어디 . 어디서 들언 ? 내셔널지오그래픽 ?',
#  '<jj> 너넨 올 올해 답사팀 하맨 ?',
#  '<gs> 동아리하고 그런 거는 어떻게 할 건데 계속할 거가 ?',
#  '<jj> 보영게 .',
#  '<jj> 어어 알암지켜 .',
#  '<kw> 연극을 하민서 늘 답답하고 확 났어요 .',
#  '<jd> 그래서 더블유에스이티 과정이라고 하면 와인 자격증 중 가장 인지도와 권위가 높은 자격증 이렇게 생각하면 편할 거 같어 .',
#  '<kw> 나도 유럽 갔을 때 나 도와준 미스터 알데슨 없었으문 알프스에서 얼어 죽었을 거야 .',
#  '<jj> 그 철물점 잘 되는 생이라예',
#  '<kw> 니네 신파 영화 찍냐 ?',
#  '<kw> 만날 아칙 조례에 나가요 .',
#  '<kw> 저 예나 돈 없으이까 술 절대 주지 마세요',
#  '<kw> 말씸은 감사합니다만 전 관장님만 괜찮으시다면',
#  '<kw> 그 짐을 왜 조캐가 져야 해요 ?',
#  '<kw> 어멍이 먼처가 우선입니다 .',
#  '<jj> 끊견 ?',
#  '<jd> 강경화 장관을 보면서 나의 미래를 가끔씩 또 생각을 하제 강경화 장관이 육십이 넘었잖아 육십이',
#  '<jd> 어 그래도 조금 남아 갖고 있다는 거 시',
#  '<gs> 나도 요즘에 와가지고 니하고 내하고',
#  '<jj> 열 명만 뽑아 겨믄 열 명 열 명이서 다시 한 번 허여',
#  '<jj> 꾸미는 거 좋아하는 거 그런 그런 너의 어떤 기질도 닮은 것 같은디',
#  '<jj> 막 주물럭 주물럭도 하지 마랑 그 국물 넣고 간장 놓고 갖은 양념 낭 뚜껑을 똑 덮엉 가스레인지에',
#  '<jd> 그치 학급의 애들끼리 경쟁시키고 이런 거보다는',
#  '<jj> 겅행 같이 해먹은 놈은 다 빠져 나가고 혼자 덤탱이썬 칠억 을 물어냈',
#  '<jj> 해볼 수 있냐고 하니깐 해볼 수 있다고 했는데 자기권총을 달라고 했댄',
#  '<kw> 안정된 삶이 보장되기 때미네',
#  '<kw> 그래 바람이 불면서 깔껭이인 걸보니 추워지려나 보네 .',
#  '<jd> 몇 년 동안 그래도 아이폰 썼다고 아이폰이 약간 보안 같은 것도 좋다고 하니까 쫌 그런 것 때문에',
#  '<kw> 선생님 아시다시피 제가 이 동니 와가지구',
#  '<cc> 뭐 고로케 고로케 내가 좋아하는 것 같다 .',
#  '<jd> 또 선물을 막 줄 수는 없죠 걍 막 매일매일 주다 보면',
#  '<kw> 오놀이 디데이잖아요 .',
#  '<gs> 다이어트할 때 굉장히 이케 힘들어하고 또 어떨 때는 다이어트를 질질끌면서 막',
#  '<jj> 그거 한번이 중요한 거 닮아 . 그러면 이제 프랜차이즈 수요가 생기고',
#  '<gs> 갖고 쫌 주변에서 막 뒤집어지고 그랬었는데',
#  '<cc> 그냥 이제 공부하면 그래도 쫌 쉽게 딸 수 있는 그런 자격증이었었어서',
#  '<jd> 오픈 오픈을 항상 담당했어 근까 피시방도 오픈할 .',
#  '<kw> 너 지굼 속으로 쾌재를 부르겠구나 ?',
#  '<jj> 펜션을 가신디 이제 거기에서',
#  '<kw> 니 어데 가 이름 이 만한 예자 잡을 자신 없지 ?',
#  '<cc> 갑자기 자기 못 믿는 거냐고 하더니 기합 주드라 한 시간 반 동안 그 쌩 여름에',
#  '<cc> 내가 집에 있는 어떤 긍까 그거 내가 아침에 먹은 거 뭐 점심에 먹은 거 저녁에 먹은 거를',
#  '<kw> 지굼 오빠한텔 솔직히',
#  '<cc> 요즘 막 유튜브에 되게 이케 클립으로 많이 올라오는데',
#  '<jj> 이제 같이 서귀포 가시는 분 차 타서 같이 다녔언',
#  '<kw> 당신 증말 왜서이러나',
#  '<kw> 불에 가면 조갑지가 많아 .',
#  '<kw> 그 동안 무다이도 참았다 .',
#  '<cc> 근데 그 옆에 황부자라고 또 칼국수집이 있는디 그 황부자라는 데가',
#  '<gs> 내 혼자만 일방적으로 정보전달 하고 있으니까 이 뭐라 답장이 와야 되는데',
#  '<kw> 니 또 시집간다매 ?',
#  '<gs> 인제 그 알을 들고 있으면 자기 도플갱어가 나타나 가지고 내한테 막',
#  '<gs> 막 그거는 쫌 다르게 봤던 것 같애요 그리고',
#  '<kw> 낭말 벗어요 .',
#  '<jj> 아이구 여한이 어수다 원 여한이 어서',
#  '<jj> 가이가 세 명중에 제일 커 ?',
#  '<kw> 어여 그다음을 계속해 주시오 .',
#  '<gs> 또 사직구장 근처에 살아가주고 인제',
#  '<jd> 오전에 갔다 오면 좋은데 그게 아니잖아 하면 장비인데 보니까 하루는 좀 빠듯하긴 하드라 ?',
#  '<kw> 그짝 와이프가 잇날에 좋아했던 앨범이라 주고 싶어서요 그 .',
#  '<jj> 다 있을 때면 나 혼자 지어불껄 겅 허긴 허는디 혼자 짓는 것보다',
#  '<gs> 그 일단 드라마 속에 있는 남자들은 얼굴이 쫌 다르기도 하고',
#  '<jd> 그전부터 사 일 동안 이십 명 하는 것도 쫌 말이 안 됐고 그냥 예 아니요 투표인데',
#  '<jd> 아빠 있는 데 와서 잠깐 해라고 일 좀 하라고 일당을 자기가 챙겨줄 수 있으니깐',
#  '<jj> 그동안엔 안 아파란만은이',
#  '<kw> 그 어머이 졸도해서 벵원 실려갔대요 .',
#  '<kw> 쓰지 않는 도구는 껄끼지 않도록 한 군데에 마 놓았다 .',
#  '<jd> 뭐 볼 수 있는 게 없 없어 . 글고',
#  '<kw> 구신은 뭐하내기 모르겠다 .',
#  '<kw> 공산이 전예 없다 .',
#  '<kw> 그른 생각 지울 수가 없더라 .',
#  '<kw> 아 이게 또 낭구 구하는 일이 있으니까 그럴 수 있겠네요 .',
#  '<jd> 혹시 일렌시아라고 알랑가 모르겄어 .',
#  '<kw> 자꾸 옷이 찡구키니 불편하네 .',
#  '<kw> 뭐 정말 집에서 억압을 해가주구',
#  '<cc> 그니까 아 나도 진짜 많이 달라졌구나 나도 지금',
#  '<gs> 사진 찍어주면 또 어 뭐야 이러는데 이제 막 따른 사람들 엄청 예쁘게 화사하게 나오 니 혼자 막 추리닝',
#  '<cc> 그것도 게 좋아 좋아하고 그거 내가 진짜 반찬 중에 쩨일 좋아하는 거는',
#  '<kw> 미안해요 . 딴 생각 좀 하느라고 .',
#  '<gs> 사관보 사관보인들한테 쫌 조사 좀 똑바로 해봐라 시키면은 아 똑바로 했다 이케 해놓고',
#  '<kw> 맞아 요즘 언나들은 딱종이를 모를거 같은데 .',
#  '<kw> 그 예자는 애인이 있는데요 .',
#  '<kw> 아니 사내 녀석들이 뭘 얼매나 ?',
#  '<jd> 한 번은 발이 뿌러졌는데 발꼬락 쪽 발 등뼈 뭐 그쪽이 부러졌는데',
#  '<jd> 긍게 알바라는 게 좋은 것도 많은데 어떻게 하다가 보면 나쁜 것도 빠지는 사람도 있고 긍게',
#  '<jj> 나 밥 행 먹어 가난 이녁도 고치 밥 행 먹켄 저',
#  '<kw> 다 가주구 계신거죠 ? ?',
#  '<kw> 그까 뭐 방콕이랑 파타야 뭐 이 정도만 알지',
#  '<jd> 극한한 최고의 풍자 문학이라고 하는 거여 .',
#  '<jd> 또 가서 먹으면 어느 날은 또 맛있고 어느 날은 또 아니고 그럴 때가 많이 있드라 .',
#  '<kw> 요중간은 예자들 남아 돌아서 회사원도 하날에 별따기래 .',
#  '<jd> 나 이번 여름에는 말이여 제주도를 갔다 왔는디 .',
#  '<jj> 요새 는 테레비 호끔 덜 봠주기',
#  '<cc> 그르케 하게 돼 하라구 얘기를 하더라고',
#  '<jj> 원래 겅 했져',
#  '<jj> 다음날 먹으면 안돼어 ?',
#  '<cc> 긍까는 근육을 늘리려면 다리를 이렇게 자꾸 앞으로 숙였잖아요 .',
#  '<cc> 근데 엉뚱하게 어 일케 그 어 택배비가 육천 원이 막 이케 나온 거예요 .',
#  '<jj> 이거 다 대껴부러시 니 늪 정글 댔댄 하멍 막',
#  '<jd> 그런 거지 뭐 내가 얼마나 의지가 강해서 그러고 그러것냐 긍께 너도',
#  '<jj> 거의 그럼 가치 영 먹는것 두루치기 같은 거 있잖아',
#  '<kw> 빨라당 말해 누그한테 맞은거야 ?',
#  '<gs> 아니 네이버 웹툰 보면은 웹툰 모아놓은 데 가면은 순위권에 있그든 .',
#  '<kw> 도대처 언제쯤 순교자 행세를 그만둘 거야 ?',
#  '<kw> 새루 해보아라 .',
#  '<kw> 그렁이 짓을 해보았자 무익하다 .',
#  '<jd> 아부지가 인제 뭐 계좌를 터주신다고 핫 때 이제 그때 뭐 미성년자나',
#  '<kw> 어머이가 해',
#  '<jj> 요즘 처럼 그런 거 있대매',
#  '<kw> 여 근처에 좋은 레스토랑이 있습니까 ?',
#  '<jd> 별 것이 다 있드만 뭐 우리가 생각지도 못한 그런 아르바이트가 많이 있는 거 같애 .',
#  '<gs> 이름님은 혹시 어 좋아 아 스타일 말씀하셨지만 구체적인 쫌 좋아하시는 스타일 이성적으로',
#  '<jj> 소라 요번에 먹어봤거든 근데 이빨 나갈 뻔 웃음 핸',
#  '<kw> 오전 에 뵌 저으기 있어 .',
#  '<kw> 오빠가 내 옆에 없으문 견뎌내지 못했을 기야 .',
#  '<cc> 그래서 바닷가 많이 놀러 가면은 항상 쫌 그래도 해산물을 좀 먹으려고 하고',
#  '<jj> 곧 기 시작 이 ?',
#  '<kw> 야 얼매 만에 보는 파인애플이냐 .',
#  '<jj> 찾지도 못하주 .',
#  '<jd> 초반부터 내가 이러케 들어 논 게 많이 있어 가지고 그래 갖고',
#  '<jd> 계산기 누리면서 뭐 내가 살 테니까 쫌 더 할인해 달라 이러면서 기여운 파우치 같은 것도 사고',
#  '<kw> 내가 지굼 너하고 장난하는 줄 아나 ?',
#  '<gs> 뭔가 따른 사람 제',
#  '<jj> 그거 달렸댄 다 남자꽈 ?',
#  '<jj> 버섯으로 만든 파우더처럼 빻아갖고 그걸 음식의 뿌리민',
#  '<jd> 슬기로운 의사 생활이 있던 거 같여 .',
#  '<cc> 우리 집에 놀고 있는 삼각대가 있거든 그니까 그거를 가져가서',
#  '<jj> 배낭 여행도 어떵 가 보젠 가 보려고 나도 막 그',
#  '<jj> 어 시발 한 다음에 맨 주먹으로 그냥 내려쳔 .',
#  '<kw> 이그 견인차 불러서 가려면 꽤 시간이 걸릴 거 같은데 .',
#  '<jj> 육지는 이제 김장이라고 해서 막 땅에 항아리 묻엉 김치를 막 저장하는데',
#  '<kw> 강릉을 다시 못 올까 봐 저번에 한 번 그래 가주구',
#  '<cc> 누가 뭐 뭐 사와서 인자 보호자들 사와서 먹잖아 얻어 먹었잖아 .',
#  '<jd> 내가 이제 헬기 헬게이트 경험을 하고 시장이 뭐 시장이겠지 하고 그냥 해운대 시장만 갔던 거 같혀 .',
#  '<cc> 실은 뭐 대학교까지 가르쳤으면 지들이 다 하고 해야 되는데',
#  '<jd> 디테일한 것도 좋아하고 의외로 이 인물이 나고 그런 게 있드라고',
#  '<kw> 하다 보니까 너무 째증나고 번거롭더라고',
#  '<kw> 기래서 일을 제대로 해보라고 한쪽을 지지 해주신거죠 .',
#  '<gs> 그 지 때만의 자기 때만의 그른 어떤 패션인가',
#  '<gs> 크리스마스 챙겨줬다 아이가 그게 또 뭐 새해 때도 막 아 그 누나가 뭐 줄 거 같거든 ?',
#  '<kw> 돌아가시고 나이까 참 아쉽고 후회되고 그런데 그래문 뭐 하니 ?',
#  '<jd> 신용 같은 거 쫌 잘',
#  '<jj> 나는 나도 옛날에 그 저 검사해신디',
#  '<kw> 웃어서 눈주위에 쭈구럭살이 많네 .',
#  '<cc> 누구한테나 아빠나 엄마한테나 이릏게 뭐 선물할 거 막 구경하고',
#  '<jj> 나 막 다니멍 폭삭 속았주게',
#  '<kw> 복없는 년이 어머이가 돼어서 이름 야 미안하다 .',
#  '<kw> 살아 돌아왔싸 됐다 .',
#  '<gs> 응 하긴 건 하긴 거기 보다야 지금 서울이 더 많지 그냥 저거들은',
#  '<kw> 니가 여보야면 나도 여보야고',
#  '<jd> 학생인데 뭔가 음 막 중간중간에 담배 피는 거 나오고 그러잖아 .',
#  '<jj> 제목은 어린시절 이야기에 대해서 얘기해 보쿠다 예',
#  '<kw> 왕 할아바이 아빠 없어요 ?',
#  '<jd> 이케 뭐라 해야 되지 보듬어준다 해야 되나',
#  '<cc> 그니까 이 해머라든가 있긴 있는데 약간 어떻게 보면은 너무 시장이 협소하다 보니까 그니까',
#  '<jd> 자주색 펴있단 말이지 금 그거 뜯어갖고 가위바위보 함씨롱 응 니',
#  '<kw> 그래서 이제 혼자서 이제 무릎도 안 좋으셔 가주구 얼마 전에 무릎 수슬도 하고 이래 가주구',
#  '<kw> 콩질금볶음 해먹지 .',
#  '<kw> 메이저리그 시합을 보구 싶어 .',
#  '<jd> 지금 그라면 애완견은 안 키우는 것이 좋겠네 ?',
#  '<gs> 일본에서 우리나라 웹툰이 최고라 카대 캐서',
#  '<jd> 받으면은 진짜 인제 횡천 긍까 황천길이거든 이게 오토바이가',
#  '<kw> 야중에 비 그치면 가자 .',
#  '<kw> 지굼 내 앞에서 잘났다고 자랑하는 거야 ?',
#  '<kw> 고기 보탱이를 이고서 어디로 가나요 ?',
#  '<jd> 살이 하나도 안 쪄보여 거시기 뭐야',
#  '<kw> 닭갈비 근데 되게 맛있었던 기억이 있어 가주구',
#  '<jj> 근데 운동 같은 그런 스포츠는 꾸준히 해야 되는거 아니 ?',
#  '<jj> 육십육 년도에 입사를 해시난 육 십 한 칠 년도에',
#  '<jj> 게난 name 막 바빠게 바빤 바빤',
#  '<jj> 날이 다 이서 무슨 .',
#  '<jj> 달거나 막 이런거 허난 상예떡 좋아하는 이유 중의 하나가 달지 안해부난',
#  '<jd> 하나 둘 하나 둘 그냥 그 정도만 하고 말아븐게 운동도 아니고 스트레칭도 아니고',
#  '<kw> 판매자에게 물어볼 질문의 유형에 대해 어는 정도 지도를 해 줄 경우 유익할 거예요 .',
#  '<kw> 계열사 한두 개 정리하면 될 문제니까 너머 마옴 쓰지 마라 .',
#  '<cc> 나는 오히려 옛날에 화장을 안 했을 때는 그런 뷰티 프로그램이나 화장 관련된 영상들을 많이 찾아봤던거 같은디',
#  '<gs> 이게 이렇게 이제 중학교 때 말을 하니까 제가 쫌 고민이 많이 되더라고요 이게',
#  '<jj> 말하고 너무나도 완벽한 이상형을 한 번 찾는거수다',
#  '<jd> 인자 큰 다 이제 흉을 봤어요 근데 내 친구가 앉아 놀던 왜 딸을 안 시집을 안 보내냬',
#  '<kw> 운제까지 개 부려먹듯이 부려먹을려고 그러세요 ?',
#  '<jd> 여름보다는 겨울이 나은 거 같기도 하고 쫌 그러네 .',
#  '<jd> 이 말을 자꾸 인제 하니까 이 사람들도 단타 단타 종목 따로 주고',
#  '<kw> 자금이 부족하니 심든가 보더라 .',
#  '<kw> 이름 도 내 자석인데 자석 낳아 준 예나 허투루 대해요 ?',
#  '<kw> 몇 번이나 도와 달라구 매달리구 싶구 지굼두',
#  '<cc> 그래서 그런 거에 대해서 좀 이케 현실적으로',
#  '<jj> 뭐 전 세계적으로 국민들이 다 맞아야 될 거면 나라에서 싸게 하겠지 . 왜냐하면 없이 사는 사람 그것도 큰 돈이주게 .',
#  '<jj> 무시 못 할거여 너네',
#  '<jd> 그래서 지금도 한 달에 한 번씩이나 저희 집에 오나 그래 가지구 자고 가 걔는 그니까 좀 그런 게 있죠 .',
#  '<jd> 아무래도 그렇게 시각화시켜 놓으면 내가 그걸 위해서 준비 하고 쫌 어 항상 각성이 있지 않을까 그래서',
#  '<jd> 인제 몸도 건강도 많이 인자 쫌 약해질텐데',
#  '<jd> 너 이거 진짜 이거 뉴스 나올라고 작정 했구나 니가',
#  '<jj> 별로 오빠랑 가고 싶지 않은 게',
#  '<kw> 안 됐 니가',
#  '<jd> 되야 그래서',
#  '<kw> 쉬물 일굽 입니다 .',
#  '<kw> 그러면은 그 스마트팜이 이 양배추에만 해당돼 다른 야채는 해당이 안 되나 ?',
#  '<jj> 만큼 막 술 세진 않애 .',
#  '<gs> 걔한테 전화해서 야 나도 됐다 카면서',
#  '<kw> 목마를 탄 사랑의 사램은 보이지 않는다 .',
#  '<kw> 자잘하기는 해도 매굽기는 말도 못해 .',
#  '<gs> 뭐 커서 뭐 즈그들끼리 뭐 각자의 뭐 가정이 있으니까 뭐 몰라라 이렇게 한다 하지만',
#  '<kw> 앞으루 느희 아부지만 덕 보게 생겼다 아들덕에',
#  '<kw> 알아요 근데 저는 밤에 일을 해야 되기 때민에 볼 수가 없었어요 .',
#  '<gs> 경상도에서는 꼴부리국이라고 하는데 다슬기국이 있거든요 .',
#  '<jd> 아 니 근데 배그 사양으로 왜 맞추 왜 맞추겠다는 거야 ?',
#  ...]

# %%
len(enc_corpus)
# Out:
# 1065270

# %%
len(dec_corpus)
# Out:
# 1065270

# %%
print(enc_tokenizer.EncodeAsPieces(enc_corpus[5000]))
# Out:
# ['▁theres', '▁a', '▁', 'q', 'uar', 'rel', '▁after', '▁the', '▁', 'q', 'uar', 'rel']

# %%
print(dec_tokenizer.EncodeAsPieces(dec_corpus[5000]))
# Out:
# ['<s>', '▁', '<jd>', '▁다', '툼', '이', '▁있', '드라구', '▁이제', '▁다', '투', '고', '▁나', '면은', '</s>']

# %%
print(enc_tokenizer.EncodeAsIds(enc_corpus[1000]))
# Out:
# [71, 519, 3978, 75, 90, 82, 18, 1627]

# %%
print(dec_tokenizer.EncodeAsIds(dec_corpus[1000]))
# Out:
# [1, 2512, 7, 117, 3092, 2535, 143, 2512, 3052, 3052, 353, 2516, 2227, 2535, 1015, 10, 2]

# %%
# 토크나이저를 활용해 토큰의 길이가 >5 이상인 데이터를 선별하여 src_corpus 와 tgt_corpus 를 각각 구축하고, 텐서 enc_train 과 dec_train 으로 변환
src_corpus = [] #영어
tgt_corpus = [] #사투리

assert len(enc_corpus) == len(dec_corpus)

# 토큰의 길이가 xxx 이하인 문장만 남깁니다. 
for idx in tqdm(range(len(enc_corpus))):
    src = enc_tokenizer.EncodeAsIds(str(enc_corpus[idx]))
    tgt = dec_tokenizer.EncodeAsIds(str(dec_corpus[idx]))
    
    if len(src) >= 5 : 
        src_corpus.append(src)
        tgt_corpus.append(tgt)

# 패딩처리를 완료하여 학습용 데이터를 완성합니다. 
enc_train = tf.keras.preprocessing.sequence.pad_sequences(src_corpus, padding='post')
dec_train = tf.keras.preprocessing.sequence.pad_sequences(tgt_corpus, padding='post')
# Out:
#   0%|          | 0/1065270 [00:00<?, ?it/s]

# %%
# # 훈련 데이터와 검증 데이터로 분리하기
# enc_train, enc_val, dec_train, dec_val = train_test_split(enc_data, dec_data, test_size=0.05)

# %%
# enc, dec 의 seq_length는 달라도 상관없음.
print(enc_train.shape)
print(dec_train.shape)
# print(enc_val.shape)
# print(dec_val.shape)
# Out:
# (999693, 168)
# (999693, 117)

# %%
dec_tokenizer.encode('사랑해')
# Out:
# [1, 852, 2536, 2]

# %%
dec_tokenizer.encode('<jd>')
# Out:
# [1, 2512, 5, 2]

# %% [markdown]
# # Step 3. 모델설계

# %% [markdown]
# ## Positional Encoding

# %%
# pos - 단어가 위치한 Time-step(각각의 토큰의 위치정보값이며 정수값을 의미)
# d_model - 모델의 Embedding 차원 수
# i - Encoding차원의 index

def positional_encoding(pos, d_model):
    def cal_angle(position, i):
        return position / np.power(10000, int(i)/d_model)  # np.power(a,b) > a^b(제곱)
    
    def get_posi_angle_vec(position):
        return [cal_angle(position, i) for i in range(d_model)]
    
    sinusoid_table = np.array([get_posi_angle_vec(pos_i) for pos_i in range(pos)])
    
    # 배열의 짝수 인덱스(2i)에는 사인 함수 적용
    sinusoid_table[:, 0::2] = np.sin(sinusoid_table[:, 0::2])
    # 배열의 홀수 인덱스(2i+1)에는 코사인 함수 적용
    sinusoid_table[:, 1::2] = np.cos(sinusoid_table[:, 1::2])
    
    return sinusoid_table

# %% [markdown]
# ## Multi-Head Attention

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model
        
        self.depth = d_model // self.num_heads
        
        self.W_q = tf.keras.layers.Dense(d_model)  # Linear Layer
        self.W_k = tf.keras.layers.Dense(d_model)
        self.W_v = tf.keras.layers.Dense(d_model)
        
        self.linear = tf.keras.layers.Dense(d_model)
        
    def scaled_dot_product_attention(self, Q, K, V, mask):
        d_k = tf.cast(K.shape[-1], tf.float32)
        
        # Scaled QK 값 구하기
        QK = tf.matmul(Q, K, transpose_b=True)
        scaled_qk = QK / tf.math.sqrt(d_k)
        
        if mask is not None:
            scaled_qk += (mask * -1e9)
        
        # 1. Attention Weights 값 구하기 -> attentions
        attentions = tf.nn.softmax(scaled_qk, axis=-1)
        # 2. Attention 값을 V에 곱하기 -> out
        out = tf.matmul(attentions, V)
        return out, attentions
    
    def split_heads(self, x):
        """
        Embedding된 입력을 head의 수로 분할하는 함수
        
        x: [ batch x length x emb ]
        return: [ batch x length x heads x self.depth ]
        """
        bsz = x.shape[0]
        split_x = tf.reshape(x, (bsz, -1, self.num_heads, self.depth))
        split_x = tf.transpose(split_x, perm=[0, 2, 1, 3])
        return split_x
    
    def combine_heads(self, x):
        """
        분할된 Embedding을 하나로 결합하는 함수
        
        x: [ batch x length x heads x self.depth ]
        return: [ batch x length x emb ]
        """
        bsz = x.shape[0]
        combined_x = tf.transpose(x, perm=[0, 2, 1, 3])
        combined_x = tf.reshape(combined_x, (bsz, -1, self.d_model))
        return combined_x
    
    def call(self, Q, K, V, mask):
        """
        Step 1: Linear_in(Q, K, V) -> WQ, WK, WV
        Step 2: Split Heads(WQ, WK, WV) -> WQ_split, WK_split, WV_split
        Step 3: Scaled Dot Product Attention(WQ_split, WK_split, WV_split)
                 -> out, attention_weights
        Step 4: Combine Heads(out) -> out
        Step 5: Linear_out(out) -> out
        """
        WQ = self.W_q(Q)
        WK = self.W_k(K)
        WV = self.W_v(V)
        
        WQ_splits = self.split_heads(WQ)
        WK_splits = self.split_heads(WK)
        WV_splits = self.split_heads(WV)
        
        out, attention_weights = self.scaled_dot_product_attention(
            WQ_splits, WK_splits, WV_splits, mask
        )
        
        out = self.combine_heads(out)
        out = self.linear(out)
        
        return out, attention_weights

# %% [markdown]
# ## Position-wise Feed-Forward Network

# %%
class PoswiseFeedForwardNet(tf.keras.layers.Layer):
    def __init__(self, d_model, d_ff):
        super(PoswiseFeedForwardNet, self).__init__()
        self.w_1 = tf.keras.layers.Dense(d_ff, activation='relu')
        self.w_2 = tf.keras.layers.Dense(d_model)

    def call(self, x):
        out = self.w_1(x)
        out = self.w_2(out)
            
        return out

print("슝=3")
# Out:
# 슝=3

# %% [markdown]
# ## Encoder 레이어 구현하기

# %%
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, n_heads, d_ff, dropout):
        super(EncoderLayer, self).__init__()
        self.enc_self_attn = MultiHeadAttention(d_model, n_heads)
        self.ffn = PoswiseFeedForwardNet(d_model, d_ff)
        
        self.norm_1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.norm_2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        
        self.do = tf.keras.layers.Dropout(dropout)
        
    def call(self, x, mask):
        # Multi-Head Attention
        residual = x
        out = self.norm_1(x)
        out, enc_attn = self.enc_self_attn(out, out, out, mask)
        out = self.do(out)
        out += residual*1 
        
        # Position-Wise Feed Forward Network
        residual = out
        out = self.norm_2(out)
        out = self.ffn(out)
        out = self.do(out)
        out += residual*1 
        
        return out, enc_attn

# %% [markdown]
# ## Decoder 레이어 구현하기

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(DecoderLayer, self).__init__()

        self.dec_self_attn = MultiHeadAttention(d_model, num_heads)
        self.enc_dec_attn = MultiHeadAttention(d_model, num_heads)

        self.ffn = PoswiseFeedForwardNet(d_model, d_ff)

        self.norm_1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.norm_2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.norm_3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.do = tf.keras.layers.Dropout(dropout)
        
    def call(self, x, enc_out, causality_mask, padding_mask):
        # Masked Multi-Head Attention
        residual = x
        out = self.norm_1(x)
        #out, dec_attn = self.dec_self_attn(out, out, out, causality_mask)
        out, dec_attn = self.dec_self_attn(out, out, out, padding_mask)
        out = self.do(out)
        out += residual
        
        # Multi-Head Attention
        residual = out
        out = self.norm_2(out)
        #out, dec_enc_attn = self.enc_dec_attn(out, enc_out, enc_out, padding_mask)
        out, dec_enc_attn = self.enc_dec_attn(out, enc_out, enc_out, causality_mask)
        out = self.do(out)
        out += residual

        # Position-Wise Feed Forward Network
        residual = out
        out = self.norm_3(out)
        out = self.ffn(out)
        out = self.do(out)
        out += residual

        return out, dec_attn, dec_enc_attn

# %% [markdown]
# ## Encoder와 Decoder 클래스를 정의
# EncodeLayer 와 DecoderLayer 를 모두 정의했으니 이를 조립하는 것은 어렵지 않겠죠? 이를 이용해 Encoder와 Decoder 클래스를 정의합니다.

# %%
class Encoder(tf.keras.Model):
    def __init__(self, n_layers, d_model, n_heads, d_ff, dropout):
        super(Encoder, self).__init__()
        self.n_layers = n_layers
        self.enc_layers = [EncoderLayer(d_model, n_heads, d_ff, dropout) for _ in range(n_layers)]
        self.do = tf.keras.layers.Dropout(dropout)
        
    def call(self, x, mask):
        out = x
        enc_attns = list()
        for i in range(self.n_layers):
            out, enc_attn = self.enc_layers[i](out, mask)
            enc_attns.append(enc_attn)
            
        return out, enc_attns

# %%
class Decoder(tf.keras.Model):
    def __init__(self, n_layers, d_model, n_heads, d_ff, dropout):
        super(Decoder, self).__init__()
        self.n_layers = n_layers
        self.dec_layers = [DecoderLayer(d_model, n_heads, d_ff, dropout) for _ in range(n_layers)]
        
    def call(self, x, enc_out, causality_mask, padding_mask):
        out = x
        dec_attns = list()
        dec_enc_attns = list()
        for i in range(self.n_layers):
            out, dec_attn, dec_enc_attn = self.dec_layers[i](out, enc_out, causality_mask, padding_mask)
            dec_attns.append(dec_attn)
            dec_enc_attns.append(dec_enc_attn)
        
        return out, dec_attns, dec_enc_attns

# %% [markdown]
# ## Transformer 완성하기

# %%
class Transformer(tf.keras.Model):
    def __init__(self, n_layers, d_model, n_heads, d_ff, src_vocab_size, tgt_vocab_size,
                 pos_len, dropout=0.2, shared=True):
        super(Transformer, self).__init__()
        self.d_model = tf.cast(d_model, tf.float32)
        
        # 1. Embedding Layer 정의
        self.enc_emb = tf.keras.layers.Embedding(src_vocab_size, d_model)
        self.dec_emb = tf.keras.layers.Embedding(tgt_vocab_size, d_model)
        
        # 2. Positional Encoding 정의
        self.pos_encoding = positional_encoding(pos_len, d_model)
        # 6. Dropout 정의
        self.do = tf.keras.layers.Dropout(dropout)
        
        # 3. Encoder / Decoder 정의
        self.encoder = Encoder(n_layers, d_model, n_heads, d_ff, dropout)
        self.decoder = Decoder(n_layers, d_model, n_heads, d_ff, dropout)
        
        # 4. Output Linear 정의
        self.fc = tf.keras.layers.Dense(tgt_vocab_size)
        
        # 5. Shared Weights
        self.shared = shared
        
        if shared:
            self.fc.set_weights(tf.transpose(self.dec_emb.weights))
        
        
    def embedding(self, emb, x):
        """
        입력된 정수 배열을 Embedding + Pos Encoding
        + Shared일 경우 Scaling 작업 포함

        x: [ batch x length ]
        return: [ batch x length x emb ]
        """
        seq_len = x.shape[1]
        out = emb(x)
        
        if self.shared:
            out *= tf.math.sqrt(self.d_model)
        
        out += self.pos_encoding[np.newaxis, ...][:, :seq_len, :]
        out = self.do(out)
        
        return out
    
    def call(self, enc_in, dec_in, enc_mask, causality_mask, dec_mask):
        # Step 1: Embedding(enc_in, dec_in) -> enc_in, dec_in
        enc_in = self.embedding(self.enc_emb, enc_in)
        dec_in = self.embedding(self.dec_emb, dec_in)
        
        # Step 2: Encoder(enc_in, enc_mask) -> enc_out, enc_attns
        enc_out, enc_attns = self.encoder(enc_in, enc_mask)

        # Step 3: Decoder(dec_in, enc_out, mask) -> dec_out, dec_attns, dec_enc_attns
        dec_out, dec_attns, dec_enc_attns = self.decoder(dec_in, enc_out, causality_mask, dec_mask)
        
        # Step 4: Out Linear(dec_out) -> logits
        logits = self.fc(dec_out)
        
        return logits, enc_attns, dec_attns, dec_enc_attns

# %% [markdown]
# ## Mask

# %%
# Attention을 할 때에 <PAD> 토큰에도 Attention을 주는 것을 방지해 주는 역할
def generate_padding_mask(seq):
    seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
    return seq[:, tf.newaxis, tf.newaxis, :]

def generate_causality_mask(src_len, tgt_len):
    mask = 1 - np.cumsum(np.eye(src_len, tgt_len), 0)
    return tf.cast(mask, tf.float32)

def generate_masks(src, tgt):
    enc_mask = generate_padding_mask(src)
    dec_mask = generate_padding_mask(tgt)

    dec_enc_causality_mask = generate_causality_mask(tgt.shape[1], src.shape[1])
    dec_enc_mask = tf.maximum(enc_mask, dec_enc_causality_mask)

    dec_causality_mask = generate_causality_mask(tgt.shape[1], tgt.shape[1])
    dec_mask = tf.maximum(dec_mask, dec_causality_mask)

    return enc_mask, dec_enc_mask, dec_mask

# %% [markdown]
# # Step 4. 훈련하기

# %%
transformer = Transformer(
    n_layers=2,
    d_model=512,
    n_heads=8,
    d_ff=2048,
    src_vocab_size=SRC_VOCAB_SIZE,
    tgt_vocab_size=TGT_VOCAB_SIZE,
    pos_len=200,
    dropout=0.2,
    shared=True
)

# %% [markdown]
# ##  Learning Rate Scheduler를 선언하고, 이를 포함하는 Adam Optimizer를 선언

# %%
class LearningRateScheduler(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(LearningRateScheduler, self).__init__()
        self.d_model = d_model
        self.warmup_steps = warmup_steps
    
    def __call__(self, step):
        arg1 = step ** -0.5
        arg2 = step * (self.warmup_steps ** -1.5)
        
        return (self.d_model ** -0.5) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = LearningRateScheduler(512)
optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

# %% [markdown]
# ## Loss 함수를 정의

# %%
# Loss 함수 정의
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    # Masking 되지 않은 입력의 개수로 Scaling하는 과정
    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

# %% [markdown]
# ## train_step 함수를 정의

# %%
@tf.function()
def train_step(src, tgt, model, optimizer):
    gold = tgt[:, 1:]
        
    enc_mask, dec_enc_mask, dec_mask = generate_masks(src, tgt)

    # 계산된 loss에 tf.GradientTape()를 적용해 학습을 진행합니다.
    with tf.GradientTape() as tape:
        predictions, enc_attns, dec_attns, dec_enc_attns = model(src, tgt, enc_mask, dec_enc_mask, dec_mask)
        loss = loss_function(gold, predictions[:, :-1])

    # 최종적으로 optimizer.apply_gradients()가 사용됩니다. 
    gradients = tape.gradient(loss, model.trainable_variables)    
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    
    return loss, enc_attns, dec_attns, dec_enc_attns

# %%
ckpt = tf.train.Checkpoint(step = tf.Variable(1), optimizer = optimizer , transformer = transformer)
manager = tf.train.CheckpointManager(ckpt, './tf_ckpts_gd12_r1',max_to_keep=2)

# %% [markdown]
# ## Attention 시각화 함수

# %%
# Attention 시각화 함수
def visualize_attention(src, tgt, enc_attns, dec_attns, dec_enc_attns):
    def draw(data, ax, x="auto", y="auto"):
        import seaborn
        seaborn.heatmap(data, 
                        square=True,
                        vmin=0.0, vmax=1.0, 
                        cbar=False, ax=ax,
                        xticklabels=x,
                        yticklabels=y)
        
    for layer in range(0, 2, 1):
        fig, axs = plt.subplots(1, 4, figsize=(20, 10))
        print("Encoder Layer", layer + 1)
        for h in range(4):
            draw(enc_attns[layer][0, h, :len(src), :len(src)], axs[h], src, src)
        plt.show()
        
    for layer in range(0, 2, 1):
        fig, axs = plt.subplots(1, 4, figsize=(20, 10))
        print("Decoder Self Layer", layer+1)
        for h in range(4):
            draw(dec_attns[layer][0, h, :len(tgt), :len(tgt)], axs[h], tgt, tgt)
        plt.show()

        print("Decoder Src Layer", layer+1)
        fig, axs = plt.subplots(1, 4, figsize=(20, 10))
        for h in range(4):
            draw(dec_enc_attns[layer][0, h, :len(tgt), :len(src)], axs[h], src, tgt)
        plt.show()

# %% [markdown]
# ## 번역생성함수

# %%
# 번역 생성 함수
def evaluate(sentence, model, reg, src_tokenizer, tgt_tokenizer):
    sentence = preprocess_sentence(sentence)
    pieces = src_tokenizer.encode_as_pieces(sentence)
    tokens = src_tokenizer.encode_as_ids(sentence)

    _input = tf.keras.preprocessing.sequence.pad_sequences([tokens], maxlen=enc_train.shape[-1], padding='post')

    ids = []

    #     output = tf.expand_dims([tgt_tokenizer.bos_id()], 0)    
    # jj > 4, jd > 5, gs > 6 , cc > 7 , kw > 8
    output = tf.expand_dims([tgt_tokenizer.bos_id(), reg], 0) # reg포함
    for i in range(dec_train.shape[-1]):
        enc_padding_mask, combined_mask, dec_padding_mask = generate_masks(_input, output)
        

        predictions, enc_attns, dec_attns, dec_enc_attns = model(_input, output, enc_padding_mask, combined_mask, dec_padding_mask)
        
        predicted_id = tf.argmax(tf.math.softmax(predictions, axis=-1)[0, -1]).numpy().item()
        if tgt_tokenizer.eos_id() == predicted_id:
            result = tgt_tokenizer.decode_ids(ids)
            return pieces, result, enc_attns, dec_attns, dec_enc_attns

        ids.append(predicted_id)
        output = tf.concat([output, tf.expand_dims([predicted_id], 0)], axis=-1)
    result = tgt_tokenizer.decode_ids(ids)
    return pieces, result, enc_attns, dec_attns, dec_enc_attns

# %%
# 번역 생성 및 Attention 시각화 결합
def translate(sentence, model, reg, src_tokenizer, tgt_tokenizer, plot_attention=False):
    pieces, result, enc_attns, dec_attns, dec_enc_attns = evaluate(sentence, model, reg, src_tokenizer, tgt_tokenizer)
    
    print('Input: %s' % (sentence))
    print('Predicted translation: {}'.format(result))

    if plot_attention:
        visualize_attention(pieces, result.split(), enc_attns, dec_attns, dec_enc_attns)
  
    return result

# %%
examples = [
    "How was your day? I was the best.",
    "Take your time, please.",
    "I’m about to leave. Please hold for a moment.",
    "Have you heard of it?"
]

# %% [markdown]
# ## 학습

# %%
# 학습
EPOCHS = 2
BATCH_SIZE = 64

def train_and_checkpoint(transformer, manager, EPOCHS):
    ckpt.restore(manager.latest_checkpoint)
    if manager.latest_checkpoint:
        print("Restored from {}".format(manager.latest_checkpoint))
    
    else:
        print("Initializing from scratch.")


    for epoch in range(EPOCHS):
        total_loss = 0

        idx_list = list(range(0, enc_train.shape[0], BATCH_SIZE))
        random.shuffle(idx_list)
        t = tqdm(idx_list)

        for (batch, idx) in enumerate(t):
            batch_loss, enc_attns, dec_attns, dec_enc_attns = train_step(enc_train[idx:idx+BATCH_SIZE],
                                                                         dec_train[idx:idx+BATCH_SIZE],
                                                                         transformer,
                                                                         optimizer)

            total_loss += batch_loss

            t.set_description_str('Epoch %2d' % (epoch + 1))
            t.set_postfix_str('Loss %.4f' % (total_loss.numpy() / (batch + 1)))
      
      
#         # 매 Epoch 마다 제시된 예문에 대한 번역 생성
#         for example in examples:
#             translate(example, transformer, 4, enc_tokenizer, dec_tokenizer)
            
 
        if int(ckpt.step) % 2 == 0:
            save_path = manager.save()
            print("Saved checkpoint for step {}: {}".format(int(ckpt.step), save_path))

# %%
train_and_checkpoint(transformer, manager, EPOCHS )
# Out:
# Initializing from scratch.
#   0%|          | 0/15621 [00:00<?, ?it/s]
#   0%|          | 0/15621 [00:00<?, ?it/s]

# %%
enc_corpus_test=list(enc_corpus_test)
enc_corpus_test
# Out:
# ['you have to wake up and eat on time and clean up but its so neat',
#  'hey he is the person who left the dry but he is the lawyers office who is smiling on the site',
#  'i the nami sings like this and she has a short hair',
#  'so if youre stressed out and do this',
#  'theyribs are not recommended to go on a diet when they see it around them',
#  'i think its a little bit like that right now',
#  'yes he was like this with his name',
#  'but our ceos name is so serious',
#  'since its a comic id like to tell you tom jerry and dooly a baby dinosaur as a representative',
#  'so ill eat until im drunk but anyway its only for me',
#  'get the old age lets go lets go',
#  'there were three of us',
#  'so i liked a lot of friends who were a little bit long and mother seedlings',
#  'ita is a name and i have to go to my sister',
#  'how can we go abroad if we go there because we said we would go abroad',
#  'i wonder if you like this kind of performance a little bit',
#  'our title name is like that to me',
#  'imly call the school because im abusive so im going to do this so i wont come from next time',
#  'the taste is really good',
#  'i think he quit in the year of ten',
#  'before that it went up once a year',
#  'lets eat for about two days focusing on a small amount of rice and inje vegetables',
#  'but the rules are simple too',
#  'everything is doing like this now its completely well',
#  'do you want to ruin my hair then',
#  'do germs crawl like this',
#  'so replace it at the right time',
#  'it doesnt suit me so',
#  'some working women suffer from habitual miscarriage',
#  'so in korea really all over the world',
#  'i know he was in his early and mid s but he must have lived like that in changwon so he wasnt even a drama writer',
#  'and if i become a little dead alone i remember again',
#  'i dont know all the details in detail',
#  'when i was young my parents said they didnt want to go to my mother',
#  'no there are a lot of small children and pretty children but its particularly',
#  'so its not just about blocking it from being fixed',
#  'oh i didnt know',
#  'so if theres a more seoul concert im going to hang out in seoul',
#  'its better to have a pet in a house with a little yard',
#  'no stocks are done these days or anything',
#  'its times hot with gel so theres no air conditioner and no fan at home',
#  'youre thinking about something so you can do it later',
#  'after growing up i traveled a lot with my boyfriend but thats what the two go around',
#  'recognize you well is there a philosopher who is good at seogwipo',
#  'then my dad at my house',
#  'its a pity in a way and i think its a selfemployed profit and i just dont know',
#  'isnt there a time when youre really puzzled',
#  'ithe was built by the year but now it changed oh i think it changed to beginner and intermediate since last year',
#  'it does worth doing',
#  'oh my the hair dye is strong',
#  'well the insurance company sold everything and fed them to me really bars long time ago',
#  'should i not post the sashtag to just look at the people around me',
#  'since youve been working in a bank for a long time how neatly would you like to serve customers or manage your finances',
#  'its a dry pig that just soaks it and its splashing out',
#  'you use a lot of filters in the photo album like an album have you used that filter before',
#  'and among your diet diets',
#  'usually there are not many places like this so its early in the morning so its a tunnel',
#  'did you sign up',
#  'i thought i could last a long time',
#  'then you just have to not make physical contact',
#  'i dont think theres any advertisement that really doesnt do it',
#  'oh my is this like this for exercise',
#  'i dont see you burying it at least well im a daughter who has two different things so im not sure about my mother',
#  'lets go lets go',
#  'ohay right why did you learn programming',
#  'and i tried that today i gave it to the nurse the flavor of the chips the injeon and the injeolmi',
#  'ill know only when i grow it up but so is it guilty',
#  'but our title name overslept so they always said that they should go to the academy and take it out so its late on the ledger',
#  'there are a lot of accidents like that',
#  'there is a major announcement the manager doesnt even connect i think i called the reporter in person',
#  'how does the electromagnetic wave come out',
#  'ifont you do that it will rot',
#  'its refreshing to sleep but sometimes this is',
#  'ive learned so far but i still want to try something new',
#  'oh you remember when you were young and you steam ham well totally baby',
#  'did you see it',
#  'obviously they know the absurdity when they go through it',
#  'but shouldnt we live over in this yearold age',
#  'but there are two months left',
#  None,
#  'the performance is just canceled',
#  'i think samsung is the most used country because it is a country that uses a lot',
#  'so i think its just',
#  'also because of her husbands character its more comfortable to get along with me',
#  'it the person who keeps my promise even if i dont touch my fingers',
#  'the pcis caf has a black screen',
#  'because of covid if its your first time coming here you have to quarantine again',
#  'your high personality is sometimes tough so sometimes people say this',
#  'no but are you yang minji these days',
#  'some people went to just play yut',
#  'i was an atheist at that time to pull me to their church once in a while',
#  'so im a little sad but i have one or so when i go somewhere',
#  'it acts as a shield to defend on its own thats how you do it',
#  'what was the most expensive item you bought',
#  'thinking about the war thinking about the movie battle of bongodong which my aunt talked about in the past is it straight',
#  'its not bad either',
#  'answering or sadness',
#  'it was amazing because you seemed to read a lot of books',
#  'when you do it a little you use some scenes',
#  'ive been doing that a lot like a craze for a while',
#  'the actors were actually a little bit bad and the set and the whole',
#  'is it pumpkin porridge again',
#  'just go to a nice place and see the scenery',
#  'i heard that you went to seoul without it',
#  'i think hes not feeling well',
#  'thats not helpful so its big',
#  'yesh but its just positive and positive about everything',
#  'oh he doesnt have a bug or a child when he enters the daycare center he stuck something outside',
#  'hey punk stand there',
#  'im going to kill meat i left meat',
#  'i think i listen to that but in karaoke rooms the latest songs are from show me the money',
#  'these days it seems that many people watch a lot of different types of mci',
#  'daddy thinking is wrong this time',
#  'i didnt know baek jiyoung was that small',
#  'so then i cant study even if im in there that day i did it and i just came out too',
#  'because the chestnuts are falling a lot',
#  'i also thought a lot about the cost',
#  'if you look at each of their actions their tone and theyre a little',
#  'conservation so its the scariest',
#  'they dont accept it a lot',
#  'so i dont always wear clothes like this on my body and even though im slim i wear them like this looks like this rather than stuffing them',
#  'dont you think of dream high dream high right',
#  'i remember that so music purely turns human emotions around',
#  'is it the last meeting it shows the reality like this',
#  'have a meal im korean',
#  'it wasnt as spicy as i thought but',
#  'masks are important so in winter',
#  'but even i keep on doing surgery every morning',
#  'so now my father went to iraq now',
#  'ah then if the children want to choose strawberry milk or strawberry milk',
#  None,
#  'then based on your standards',
#  'its a year of living regretfully without anyone who lives without anyone',
#  'i think ive seen a lot of people overcome complexes while doing that',
#  'i studied the writing by myself but the interview is a little cheaper than that so im taking an interview lecture',
#  'do you like a grasshopper',
#  'i was going to do this there',
#  'but i was sad about the words i said to stop',
#  'there are so many vacant markets and im a little more like this',
#  'so i think its a little hard for newbie to do it',
#  'i put it in the freezer so i have to blow away the cold air',
#  'yes i only have a heart but always i have to do a little bit of it',
#  'they did it with a mess',
#  'and now you have to wear a uniform you have to use your hair and a cardigan',
#  'do you kill me by hitting me with a toy hammer',
#  'my father filled up his keys',
#  'i think it was famous because it was waited there',
#  'if theres a distance between wireless earphones',
#  'at this time no one wants to see my mom only',
#  'looking at it like this',
#  'yeah i thought it was a very serious situation because of that i cried at that time',
#  'oh if i had done something wrong i would have gotten a real cold because it was so cold',
#  'there are times when i think it was a little too much',
#  'but now to determine whether or not there is this license to determine who is eligible for overseas business trips',
#  'first start with farts',
#  'a long listening book',
#  'i bent a motorcycle so',
#  'and then the computer engineering department is divided into electronic information colleges',
#  'sitting together i saw her next to her and at the convenience store',
#  'ive been passing by a few times and kept looking at it closely',
#  'first of all i think ill be around a little bit from the current situation',
#  None,
#  'its because i said that ai rodo robot industry and selfdriving cars are coming out',
#  'what is this female drink i saw in front of the house yesterday',
#  'is there all the equipment there',
#  'my friends are older than us so the three are similar in age and one in hanam is younger than us',
#  'at that time when my father said i was going to import tea milk and something like that',
#  'i ran away and hide like that',
#  'in the military that was where our country was divided into north and south',
#  'but since i was in elementary school it was a little fun',
#  'i wide take a walk',
#  'usually i tend to exclude a little bit',
#  'since this years covid the cold has never caught like this i dont know if its because i wash my hands clean but i dont know if its because i wash my hands clean',
#  'so i just did that this time',
#  'how much i had pulled it like this',
#  'hey can i walk with that then',
#  'so windbreakers were very fun or watching other things',
#  'but since she is not good at driving she cant turn right or left',
#  'i have it but its a relationship',
#  'so there are many things that the name of the dad doesnt know me',
#  'yesh i met someone at school and i dont think i washed up',
#  'but cats dont touch each other very often',
#  'if you mix and cook the soup its really icing on the gold',
#  'if you look at it doesnt it say that its a name picture',
#  'portting portraits photos of portraits and so on',
#  'i heard that you dont have a handsome ear i thought youd live a very good life but it wasnt that',
#  'ive always said the same thing for a long time',
#  'theres a place where people are just luxurious',
#  'thats why there must have been a mess in your house because you touched the girl',
#  'i thought they were doing lip service but what did you say about naije',
#  'i dont know how to sing it so as soon as i saw it',
#  'it was a little hard for me to wear it like this and wear it like that',
#  'but after meeting the faith i think the hot temperament is subsiding a little',
#  'but now let me tell them not to do that',
#  'when the ingredients are exhausted they sell only grams every day and pop up after that they close',
#  'i tried golf after cutting off the class',
#  'you must have been disappointed',
#  'hey stop them at times when you look at them',
#  'there are many ways to become famous',
#  'i think i forgot all my face',
#  'youre talking about the talent award youre asking for',
#  'its bad for you so the man',
#  'the main character or the main character in there',
#  'weve been to things like that and the kids are very',
#  'theyre kids but they all got together so i loved the feeling of doing something',
#  'and i think they took care of each other a little without knowing it and held out a lot because of their classmates',
#  'so its common to do this',
#  'and then when i ate something i learned a lot about steaming it until then',
#  'i think a little differently because of the consumers benefits of course thats really good',
#  'its been less than a week so im saying what is this and im not using apple pencil puttery younger at all',
#  'if you claim and take it whats wrong',
#  'so i',
#  'i was looking forward to that a little bit',
#  'yes then since i dont have a husband anyway',
#  'is it going to gain a little confidence while living outside',
#  'i solicited you to take him to go with you',
#  'so my friend just needs money for a moment',
#  'i was on my side and i was revered',
#  'what do you want to share with me i think youre going to take some off',
#  'he claims to be a woman anywhere',
#  'thats why i started',
#  'its like a car or a phone',
#  'itapped as a little bit of my stuff then',
#  'uh if you go in through this like this or if you like it you just buy it right away',
#  'everyone has the same thoughts and its fine',
#  'you have to go out and think that youre just trying your hands and go out',
#  'the person with a high status said ill drink it when i give it to him',
#  None,
#  'so im satisfied with watching it on tv but you go there and stay like women',
#  'what do you do to the kid if youre ugly',
#  'i cant walk because im scared like that at dawn',
#  'its a ningning herb that doesnt taste like you or mine',
#  'i had to eat not say anything',
#  'like the name of the title im also looking for a little bit of recent status of acquaintances around me',
#  'i think mom just thinks that her daughters are good at living a little bit',
#  'depending on whether you are trained or not',
#  'were inviting guests',
#  'or he is really poor at home so he is really poor',
#  'actually i only saw the good side so are you blind or not',
#  'squeeze it there and apply strawberry jam on top of the bread',
#  'thats a little uncomfortable when i look at it',
#  'i creditly cant go on any other trips so i barely took time',
#  'i went to the national agricultural cooperative federation and i got a transfer and i got a late fee of sixty thousand won',
#  'make such things more specific and things like that about future preparations',
#  'so no one said no one would eat it and everything was in the refrigerator',
#  'they know him himself hes nice',
#  'is it that vitalityful to do that yoga',
#  'itinally its really fun to talk about the seasons two of us for so long',
#  'if youve done sparring a little bit',
#  'grandma was sick but grandma i didnt think of doing it over there so i told her so she laughed',
#  'ive never seen you order that before so it was the last time we ordered that and watched it',
#  'how about you on the title',
#  'when i asked to go to the field i would like to sit only in billiards and only say i wish it rained',
#  'we can put in a little bit if we have some extra money and we have some money',
#  'i think ive been a little stressed out because of my stubbornness',
#  'the ntime name is to my mom that the intermittent fasting is about one three or five days but i think its about a week',
#  'later he came next to me and walked so just come to the room with his name',
#  'wow i can feel that you really like rap',
#  'the laundry is also dried',
#  'put all the cosmetics in the bag and throw it outside',
#  'even after becoming an adult its like this',
#  'so if i have a hope these days',
#  'so if you dont set up rules like that and dont set up rules like that',
#  'didnt this end last spring',
#  'my dad spent a little bit of money on computer engineering at university and bought me a computer for eight or six',
#  'if you exercise separately and steadily you can meet and do that together',
#  'today again two names of the food come out and he started again with an unwantedly bad meat',
#  'so when i first said i would meet you again you said to you oh i told you',
#  'asternally it was moved and moved it spread as a natural disaster',
#  None,
#  'i have to do everything little by little',
#  'no i went to the airport really early',
#  None,
#  'didnt he put a lot of your pictures on the computer',
#  'so that father talks about that',
#  'and as mom fell out of it',
#  'as i focused on this i got a little distracted so i was like pifi and bag',
#  'its a little funny when others listen to it but its really nice while watching the dress',
#  'but if you really want to change you have to take it how can you get something without risk or compensation',
#  'itu was a beautiful car in the past but these days',
#  'and the sea is a little bit more like dollars',
#  'its a special episode that i remember when i was in the military',
#  'so they said they had to repair the car quickly to maintain their customer base',
#  'itinting to be far away',
#  'she said whats this so then',
#  'we used to do this but now my mother seems to be controlling me like this',
#  'canly this be called metech too',
#  'things like this are too much to touch the face',
#  'the tip of the tongue that looks slightly between them',
#  'im going to go to homework on sunday',
#  'born in donumi as the eldest daughter of seven siblings miso yang and mom and dad',
#  'whats that because of the flower syrup where did they go',
#  'there was a tradition in gangneung or something like this',
#  None,
#  'i drowned it in the water but its still alive',
#  'i heard it a lot when i was young',
#  'i dream that anything is not allowed',
#  'so he name is graded',
#  'i have no idea what happened',
#  'hey you fixed your cell phone please give me my cell phone',
#  'i dont know anything but im on my wifes side',
#  'my brotherinlaw is a star',
#  'what should i say if you buy a gift or something like that',
#  'then we shouldnt tell you we believed in it and said it',
#  'its okay because he is a little big but if i call him in three grades like this',
#  'imont good at sad movies in the midst of that',
#  'people who get vulnerable groups well should give them vaccines first',
#  'and toe head is sore',
#  'should we go and buy it together',
#  'my life just didnt get well at the beginning because i married a weird man',
#  'and my mother is old and food',
#  'and there are interns oblivians and six or so',
#  'so because youre just heavyduty',
#  'everyone looked really good',
#  'then you cant miss mr chung',
#  'i saw it',
#  'how could it be because he is so itchy',
#  'he was a very talkative employee so that employee',
#  'originally pokemon came out as a game first',
#  'wasent they a little known couple at work a little known news',
#  'there are a few things that happened after drinking do you want to hear that',
#  'ifout he had a skirt he did it',
#  'but its okay its sophisticated and good it overlaps with me a lot',
#  'well i bought some clothes for you',
#  'so it cant always be successful and it cant always be bad',
#  'so it was the first holiday one day according to that atmosphere',
#  'he used the stairs and now he was greedy with the water',
#  'hey is there a name for the star',
#  'is there anything like this that i impressed with the olympic games',
#  'if you learn techniques and do something you can open a beauty shop',
#  'i took that picture and it was but new ones come in every day',
#  'but still i would never use feature phones while using smartphones',
#  'i think ill use a little more robots too',
#  'but since i know how much i live i understand everything but in high school i dont even take him to my house',
#  'but theres really little soup and it just felt like it was a little bit dead with the ingredients',
#  'thats a trauma thats a complex',
#  'so its nothing to buy',
#  'its okay for me to see something but its a little bit like a ranch',
#  'how are there only people who live well in the eastern town',
#  'was there any more and more changes when it was small',
#  'so i walked around there',
#  'no i cant do it with this person i cant eat it i can smile at him or separate him when theres no major risk',
#  'without hesitation without any hesitation',
#  'but because im so stuck in reality',
#  'awesome youre good style',
#  'imscared that i already have a career path i studied a little more',
#  'it was a little comfortable to live on the fivestory',
#  'i wanted to go to hokkaido japan at least once but my friend in middle school',
#  'but im listening to kim hojungs song on youtube a little bit because',
#  'if you did something wrong you would have just died if you were linked to the akali palace',
#  'imasleep and eat again i downgraded it to the bottom with work and then i ate something more',
#  'yeah theyre very thorough at managing the house so we still have a land area right',
#  'what season do you hate the most',
#  'give me a slightly soft new one with a completely changed one',
#  'if the customers go over and fall out of the box',
#  'you sold a little bit lets talk to your husband',
#  'ims currently a little bit about me like this',
#  'hey dont you let this go',
#  'thats right because i had names right tell me what the situation changed a little from then',
#  'it was slippery so it flowed well so i played a lot of bottle cap soccer',
#  'if you think you ate a little more you should eat a small one',
#  'is that so really',
#  'i dont think ive ever refused firmly',
#  'astern graduation will also lead to a lot of work to use your phone',
#  'lets make your eyes look dark and make it peary together',
#  'i thought i should watch the k league a little often now',
#  'if you dont change your clothes you cant do anything',
#  'then its a big trouble',
#  'im becoming a little interested in clothes and wear them a little often so if you look at the mixing rate roughly it feels a little like',
#  'how do i go alone i decided to go there together asking if no one was going to go there and he asked me how to betray and hit everyone so i was really upset',
#  'thats scary so i dont want to be scared',
#  'so if you want to save meals with a talent and money',
#  'i ired all the movies so i could enjoy them',
#  'theres corn right',
#  'i didnt know because i didnt get that treatment',
#  'with that as an excuse i went too',
#  'its going to be a shame hurry up',
#  'the secret is first you trust yourself and this is the most important thing',
#  'i was going to study more so i was going to take the civil service exam somewhere else and somewhere else i got a job',
#  'my mom is sick now',
#  'youre going to do well',
#  'oh so i look at the flowers and the dog owners always bring their dogs there',
#  'hey this is delicious',
#  'i think its rather using that kind of mind from the people around me',
#  'i answered courtesy and i could learn it then so i also learned it',
#  'its okay i dont like it i dont like it ive never tried this before its their choice',
#  'so the hormones are certain',
#  'i really cant understand the person named kim taenyeon',
#  'so why do you get so weighty for the first time',
#  'i think it was the biggest lack of sleep because i cant sleep',
#  'didnt you say wonnable before',
#  'its decorated a little luxuriously i dont know if you cut your hair and did all the waves like this',
#  'theres nothing else so you can really enjoy meeting them',
#  'yes but there are times when they always buy me delicious rice and beef',
#  'im looking forward to what itll take',
#  'but i couldnt drive my car and you called me to take a taxi and told me to go back and forth',
#  'because the water flowed',
#  'even if someone says that i look a little blunt im a little drowsy',
#  'because im done with the work after plowing the field',
#  'imas so stressed out',
#  'but its a bit big for a jindo dog so if you see it you might have been a little surprised',
#  'oh my i know',
#  'multiple multiple multiple',
#  'the first thing i want to say is my daughters name',
#  'i want to open it up but lets go with many people',
#  'its just a mix of things that need to use the brain',
#  'he doesnt sit like this and says it',
#  'my grandfather hated his older uncle very much',
#  'since years ago ive been doing saxophone',
#  'so when i asked what my dream was when i was young i said that the person who wrote arongsae was my dream',
#  'i just want you to build up your body so whats the purpose of your exercise now',
#  'theres a break like this and we also said then when you are on a break you guys too when you are on a break',
#  'so you laugh at the time you cancel it omansang',
#  'the construction is just started',
#  'but its really clean',
#  'soam oil is slightly covered and seaweed powder is mixed and mixed',
#  'slice the green onions diagonally and slightly',
#  'i cant read it this well even when i see it its very hard for me to start',
#  'enength even when i went to japan i really didnt say a word but i laughed at japan',
#  'theyre digging up on the mountains because its called an air defense shelter',
#  'i liked it when there was a yoky scandal but if i talk about it now',
#  'theres something we cant do when were older',
#  'i went to hwaseong suwon',
#  'so i was scolded by my mom then',
#  'when you come to get a confucian cauldron you come here and come here',
#  'i thasked about about to about a dozen people but its not about to about a dozen people i think about to about a dozen people came',
#  'its night and the sign that they said they were doing business is tangerine trees',
#  'im baemin vip',
#  'i was trying not to do it but i was a little cool and a little disappointed',
#  'i told you to run once and i ran once but i won the last place',
#  'i didnt want to see horrors',
#  'its a pity to see you evaluate your backwardness',
#  'wellthough i think it would be easier to work so youre also in the department of civil engineering and civil engineering',
#  'i couldnt even deliver it when i met him because i had dementia',
#  'i dont know what you say edu edu',
#  'i remembered a little bit when i went to high school',
#  'as a result of the traceback several evidence about the process of acquiring stolen goods has been secured',
#  'ive been in touch a few times like this',
#  'if you look there in a groundless place there are houses that are all grounded',
#  'anyway its strange so its slightly similar',
#  'now that i think about it i dont think theres a parttime job that was so good',
#  'i did i didnt know if i remember you when i was using the',
#  'no have you ever written it',
#  'he didnt say hello even though he went',
#  'you know that if your organs are uncomfortable you have a backache right',
#  'but as it was after that it was like before that it was like before',
#  'but even if you apply here and its like e its much less than this so its more than using cnb',
#  'i did everything i asked for',
#  'its just that my friend gets angry because i was disappointed',
#  'so the doctor said im a big woman with a liver and if im going to have surgery i wont have surgery',
#  'what do you mean you punk',
#  'it was very annoying so i was',
#  'are you watching cntv right now or jeju island',
#  'oh you know i told you i was migrant so theres nothing to do',
#  'if its half and its a fish that freezes and its a shell that freezes its like that',
#  'so they too',
#  'in mour field there was a field in your grandmothers house',
#  'hey do you really have any thoughts on exchange math for next semester',
#  'today my name is suddenly letting me see',
#  'are you eating jajangmyeon what are you eating',
#  'a little bit of a situation',
#  'is this the only thing i did by calling and cheating',
#  'well it cant be practiced so quickly',
#  'i only focused and if there was a seat he always took him out',
#  'i think people like that kind of thing that they can pay attention to me',
#  'itually its just collected in one room so its very wide and theres a lot to eat',
#  'i think its said there is',
#  'what does she say when she goes to me',
#  'but i think my legs will scare',
#  'i jassed at night and i thought it wasnt covid even if i coughed and i think thats a little scarier',
#  'the alumni would have done it with more',
#  'i called my son and he told him to come here and there',
#  'the creaking sound is crazy for me',
#  'i tend to be a little bit attacked as a joke',
#  'money money i only know money i cant do it because of money',
#  'is it a matchmaking lover',
#  'he said he was jealous of his hair because he dried it',
#  'itas right',
#  'itory was ten thousand thousand won when i was working but it was like that',
#  'changing it as you personally like this',
#  'when men go out with each other its a little fun',
#  'you apply it to your tongue and it comes out thick then youre chilling because youre getting sick',
#  'when you say it you stutter a little bit',
#  'i dont think you need to worry because many people passed online lectures',
#  'sting was like that and there were smaller cars than the cars you said',
#  'no johnna goes around but i dont like it',
#  'theres an orchestra like this',
#  'my and my child and dad are making such a happy family',
#  'oh thats the problem',
#  'dont come because you keep trying to say useless things with your name',
#  'asdamping',
#  'imam afraid that ill lament the situation by talking about the title name amount in front of me so is that',
#  'so honestly the price is still stronger than the mid to lowpriced one',
#  'didnt there be many people who liked it in elementary school',
#  'they said they didnt want to do it anymore after reading the street there',
#  'i suppose i dont just go out to the nearest place to eat at home but ive always ordered a little more',
#  'how do you think you will be active when that kind of time comes',
#  'there is a hive a webtoon called the area of jo a writer of tidal stones and a sound of heart',
#  'on chuseok relatives and cousins only gathered together but since they all gathered there were a lot to say',
#  'its much better to eat at a coffee shop and its more delicious']

# %%
dec_corpus_test=list(dec_corpus_test)
dec_corpus_test
# Out:
# ['<cc> 일어나서 제시간에 밥을 먹어야 되구 청소를 해야 되는데 워낙 깔끔은 허셔 아주',
#  '<jj> 야 드라이 맡긴 사람인디 변호사 사무장이라이 그 사람은이 웃음',
#  '<cc> 아 나는 그 나미 씨 노래 이케 막 단발머리하구',
#  '<gs> 그래서 스트레스받고 인자 이라면',
#  '<cc> 그 친구두 막 케 주변에서 봤을 때 다이어트를 해야 한다라고 권하지 않는 친구인데',
#  '<gs> 어 지금 살짝 쫌 그런 거 같기는 해 .',
#  '<gs> 어 어 이름님하고 같이 또 이르케',
#  '<cc> 아니 근데 우리 사장은 진짜 씅질이 너무 진짜 심각해 가지고 진짜',
#  '<gs> 이 또 만화하니까 이 톰과 제리랑 아기 공룡 둘리를 쫌 대표적으로 얘기 드리고 싶은데요 .',
#  '<jj> 거난 취할 때까지 먹음니가만은게 어쨌든 한 모금 배끼 나 직신 어신디',
#  '<jj> 노각 얻어당 예 올래',
#  '<jj> 우리 세 명이연',
#  '<gs> 그래서 그렇게 약간 쫌 장모종인 친구들을 많이 좋아했는데',
#  '<kw> 이름데리고 헝이한테 가봐야 돼요 .',
#  '<jj> 이제 또 어디 우리 해외라도 갔다 오켄 핸 갔다 오믄 어떵',
#  '<gs> 이런 공연 자체를 쫌 좋아하시는지도 저는 쫌 궁금해요 .',
#  '<jd> 우리 이름 가 나한테 글던데',
#  '<jj> 막 욕지거리 행 학교에 전화해불켄 전화해 버리겠다 막 영 행 가부니까 그 다음부턴 안 와 .',
#  '<gs> 그 맛은 또 거 맛있데 겁나',
#  '<jj> 십육 년도에 그만둔 거 닮거든 ?',
#  '<jj> 그 전에는 일 년에 한 번씩은 올라가시난',
#  '<jd> 소량의 밥과 인제 야채 중심으로 인자 식사를 그 하죠 한 이틀정도',
#  '<jj> 근데 그런 거는이 룰도 단순하고이',
#  '<jj> 다 삶이 또 이제 영 햄구나 완전 잘살아',
#  '<jj> 너 그 때도 내 머리 망쳐놓고 또 망치고싶 ?',
#  '<jj> 세균이 이렇게 기어서 기어댕기나',
#  '<gs> 그니까 적정 시기에 교체를 할',
#  '<jd> 마땅하지가 않어 그래서',
#  '<kw> 직장 여성들 중에는 습관성 유산으루 고통받고 있는 분들이 두루 있습니다',
#  '<cc> 그래서 아 우리나라에도 이르케 정말 전 세계적으로',
#  '<gs> 이제 삼십 대 초중반으로 알고 있는데 가가 창원에서 약간 그렇게 생활했었나 봐 그래 가지고 자기 그 원래 그리고 얘가 드라마 작가도 아니었디 .',
#  '<cc> 또 혼자 이케 쫌 사색이 되어 지면 또 생각나구 .',
#  '<jd> 다 세세히 자세히 알지는 못하긴 한디',
#  '<gs> 내 어릴 때 부모님은 그니까 어머님한테 가기 싫다고 했던 논리 중 그거였어 .',
#  '<jj> 아니 아이돌도 쪼골락한 아이들 막 이쁜 아이들 많으매 근디 딱히',
#  '<cc> 그래서 막 그거를 다시 고치려고 막고 그냥 이릏게 단순히 막아서 되는 일이 아니야 .',
#  '<jj> 헐 몰란 .',
#  '<gs> 그래서 쫌 더 서울 콘서트가 있으면 서울에서 더 놀려고 하는 편이구요 .',
#  '<gs> 쫌 마당이 있는 집에 애완동물을 키우는 게 더 좋을 거 같으니까',
#  '<gs> 아니 뭐 주식 같은 것도 요즘 하잖아 아이면 뭐',
#  '<jd> 이십구 도 나가더만 젤로 더울 때가 긍께 거기는 에어컨도 없고 선풍기도 없어 집에가 다',
#  '<gs> 뭔가 고민하고 있다 해서 니가 나중에도',
#  '<cc> 크고 나서는 뭐 남자친구 하구야 뭐 여행을 좀 자주 다녔지만 그건 둘이 다니는 거고',
#  '<jj> 너가 잘 알아봐 서귀포 쪽에 잘하는 철학관 이신가',
#  '<jj> 게민 우리집 아방',
#  '<jj> 어떻게 보면 안타깝고 어떻게 보면 자업자득인가 싶기도 하고 이 그냥 차라리 모르크라 나는 .',
#  '<jj> 한 번씩 진짜 두룽청 하지 할 때 있지 않읍니까 ?',
#  '<gs> 해 쌓는데 이제는 또 그게 바꼈다 하더라구요 오 아 작년부터 한국사 이 자격증이 초급 중급 이렇게로 바꼈다고 하는 거 같드라구요 그래서',
#  '<jj> 할만하켜게',
#  '<jj> 어머 염색약 쎄난',
#  '<jd> 모 보험회사에서 다 팔아줬제 맥여 살렸제 진짜 술집들 옛날에',
#  '<cc> 제가 걍 주변 사람만 막 봐라고 해시태그를 굳이 안 올린다 해야 되나 ?',
#  '<kw> 은애이에서 오래 일하셨으니 고객 응대나 재무 관리나 얼매나 깔끔하게 하시겠습니까 ?',
#  '<jj> 거 훌레몰른 도새기 그냥 담이고 뭐고 정신 못차령 튀어 나간덴 헌 말입주',
#  '<gs> 약간 앨범같이 사진첩에 들어간 필터 마이 쓰던데 니는 그 필터 안 써 봤나 ?',
#  '<gs> 그리고 니는 그러면 다이어트 식단 중에서 혹시 쫌',
#  '<cc> 보통 이런 데에서는 이백 잘 안 나와 그니까 새벽이니까 어 터널에서',
#  '<jj> 가입 핸 ?',
#  '<gs> 그나마 내가 쫌 오래 다닐 수 있지 않을까 싶어서',
#  '<gs> 그러면은 오빠는 신체적 접촉만 안 하면 된다는 거가 ?',
#  '<cc> 진짜 안 하는 광고가 없는 거 같어 .',
#  '<jj> 아이구 이거 운동 땜에 영햄신가',
#  '<kw> 겹사둔 꼴은 안 봐 글쎄 어뜬일이 있어두 딸이 돼서 에밀 몰 라 ?',
#  '<jj> 글라 가게 해여그네',
#  '<jj> 아 기 ? 프로그래밍 배워 ?',
#  '<gs> 그리고 오늘 그거 먹어 봤다 꼬북칩 인전 인절미 맛 그 간호사 쌤 줬거든 그래서',
#  '<cc> 더 키워 봐야 알겠지만 그서 약간에 죄책감이랄까 ?',
#  '<jd> 그런데 우리 이름 가 늦잠 자서 학원도 맨날 빼먹지 가라 가라 해서 긍게 지각 대장에',
#  '<cc> 이런저런 쫌 사고가 많은데 어 그런',
#  '<kw> 중대 발표가 있다구 매니저도 안 통하구 직접 기자한테 즌화를 한 것 같습니다',
#  '<cc> 전자파는 어뜨게 나오긴 나오는 겨 ?',
#  '<jj> 안그러면 썩을 거 닮아',
#  '<cc> 잠 잘라고 하믄 개운하긴 한데 어떤 때는 이',
#  '<jj> 지금까지도 물론 좀 배워봤지만 배워봐신디 그래도 쫌 그냥 새로운 것도 도전해보고 싶고',
#  '<jj> 아고 잘도 어릴 적 기억도 잘도 햄쪄이 잘 하네 완전 아기 아기',
#  '<jj> 봐안 ?',
#  '<gs> 분명히 자기들도 겪었을 때 그 부조리함을 알낀데',
#  '<cc> 그래도 요새 백세 시대에 팔십 은 넘게 살아야 되지 않겄어',
#  '<jd> 그래도 두 달 남었으니까',
#  '<jj> 이십만 탔으면은 오백 맞는거 닮아 .',
#  '<cc> 그양 공연이 이제 다 취소되고',
#  '<gs> 대표적으로 많이 쫌 쓰는 나라니까 삼성을 아무래도 제일 많이 쓰는 거 같고',
#  '<gs> 그서 그양 이게 내 생각은',
#  '<cc> 또 그런 남편의 성품이기 때문에 나한테 쫌 맞춰주기가 쫌 더 편하고',
#  '<kw> 손고락 안 걸어도 나 약속은 지키는 사램이에요 .',
#  '<gs> 피시방은 약간 쫌 검은색 화면으로 돼 있으니까',
#  '<jj> 코로나 때문에 아이고 이거 처음 오믄 또 격리해야되잖아예',
#  '<cc> 너 상 성격이 너 가끔가다가 까칠해서 사람이 쫌 할 때도 있어 이릏게 말은 하지만',
#  '<jd> 아니 근디 또 요즘 양민지 ?',
#  '<jj> 윷놀이만 하러 간 사람도 있댄',
#  '<gs> 한 번씩 가다가 자기들 교회로 나를 땡길려고 나는 그때 무신론자였거든 .',
#  '<cc> 그래서 쫌 많이 아쉽긴 한디 또 어디 막 가면은 하나쯤은 있어가주고',
#  '<gs> 스스로 방어를 할 수 있는 방패 역할을 해요 그기 쉴드라 그래가',
#  '<gs> 니가 샀던 것 중에 제일 비싼 아이템이 뭐였어 ?',
#  '<jj> 그 전쟁 생각하니까 옛날 그 어 이모가 얘기했던 봉오동전투 영화 생각 남쪄',
#  '<jj> 나쁘지 안 것도',
#  '<cc> 또 슬픔을 아니믄 기쁨을',
#  '<jd> 되게 너가 책을 읽는 많이 읽는 것 같아서 되게 신기했어 .',
#  '<gs> 쫌 할 때 어 그럴 때 신을 삼는 거지',
#  '<cc> 한동안 봤을 때 열풍처럼 그렇게 많이 했었잖아요 그니까',
#  '<gs> 어 그 배우들도 난 사실 쫌 별로였고 그 세트장이나 전체적인 그런',
#  '<kw> 또 호박죽이가 ?',
#  '<kw> 그냥 쫌 좋은 데 한 곳 가서 경치 보고',
#  '<jj> 뺑으네 가네 서울 강 와쪄 허난에',
#  '<jd> 본인 몸이 어디가 쪼금 안 좋은 것 같다',
#  '<gs> 그게 도움이 안 돼 크게 그러리께',
#  '<cc> 음 그릏죠 근데 인제 그냥 매사에 긍정적이고',
#  '<jj> 아이고 가이는이 벌레에 만xx 한 아이 어서 어린이집 들어갈 때도 뱉끼이서 이디 무신거 붙은거',
#  '<kw> 이 자석아 거게 서 .',
#  '<jj> 내 내가 고기 킬런디 고기 내가 남견 .',
#  '<cc> 그런 거를 듣는 거 같고 근데 노래방에서는 어 쫌 최신 노래들 쇼미더머니에서 나오는 노래들 ?',
#  '<cc> 요즘에는 되게 다양하게 엠비티아이 같은 거를 좀 사람들이 많이 보는 것 같여 .',
#  '<kw> 아버니 생각 이번엔 틀렸습니다 .',
#  '<gs> 난 백지영이 그래 짝은 사람인지 몰랐거든 ?',
#  '<cc> 그래서 아 그러면은 거기 안에 있어도 공부가 안 되겠다 그날은 해가주구 그냥 나도 나왔지 .',
#  '<cc> 밤송이도 많이 떨어지고 해 가주구',
#  '<gs> 비용도 생각이 마이 들더라고요 .',
#  '<gs> 어 그냥 그 사람들 행동 하나하나 말투 하나하나 그런 것들을 보면 쫌',
#  '<cc> 컨저링이나 그니까 가장 무서운게',
#  '<jj> 안 받아주는데 많댄',
#  '<cc> 그래가지고 꼭 옷도 몸에 이렇게 안 붙게 입고 날씬한데도 그렇게 꼭 박시한 거보다 이렇게 터벙하게 입어서',
#  '<jj> 드림하이 생각나지 안 ? 드림하이 맞지 .',
#  '<jd> 그런 기억이 나요 긍게 음악은 인간의 감정을 순수하게 돌려놓잖아요',
#  '<jj> 칠찬 모임 맞나 ? 그 현실을 이렇게 딱 보여주고이',
#  '<jj> 밥 먹읍써 한국인인디 .',
#  '<jj> 생각보다 안 매원 . 아니 근데',
#  '<jd> 마스크가 중요하네 그니까 겨울에',
#  '<jd> 근디 나보고도 자꾸 수술을 하라고 아침마다',
#  '<jj> 행 이젠 아방이 이젠 이라크를 간거라 게난',
#  '<jd> 아 인제 그러면 아이들이 다 뭐 이케 딸기 우유 시 선택하고 싶은 사람은 딸기 우유 선택해 가지고',
#  '<jd> 얼마냐니까 칠 만원이래 그래서 비싸다는 말도 못하고 그냥 시세가 그런갑다 허고',
#  '<gs> 그럼 니 기준에서 이제',
#  '<kw> 읎이 살아두 남한테 일영원 한장 손 안 벌리구 열씸히 사는 년이야 내딸년이 .',
#  '<gs> 그런 거 하면서 쫌 컴플렉스 극복하는 사람들도 마이 본 거 같애요 .',
#  '<cc> 필기는 일단 혼자 공부를 했는데 면접은 그거에 비해서 쫌 가격이 싸가지구 면접 강의 하나 듣고 있고',
#  '<cc> 베짱이처럼 해유 ?',
#  '<jd> 거기서 이렇게 할라 했는데 .',
#  '<jd> 근데 내가 그 그만 두라는 그 말 한 마디가 인자 서러워서 지 그냥',
#  '<cc> 빈틈 시장도 너무너무 많고 내가 쫌 더 이렇게',
#  '<gs> 그래서 뉴비가 하기가 쫌 힘든 거 같애 .',
#  '<gs> 이제 냉동실에 너 놨으니까 좀 냉기를 날려야 돼서',
#  '<cc> 에 마음만 있어요 항시 항시 인제 해도 쫌 해야 된다는 거는',
#  '<jd> 난장판을 피어놓고 하드만',
#  '<cc> 그리고 또 이제 유니폼 무조건 입어야 되고 머리 망 꼭 써야 되고 가디건도 꼭 입어야 된단 말이여 .',
#  '<jj> 뿅망치로 때령 죽이는거 ?',
#  '<jj> 우리 아버지는 열쇠 채워나서마씨 .',
#  '<jj> 유명한데 였던거 닮 왜냐하면 거기서도 좀 막 웨이팅 해가지고 그래가지고',
#  '<cc> 되게 쫌 이게 무선이어폰이 거리가 있으면은',
#  '<kw> 이럴 땐 엄마밖에 보고 싶은 사램 없어 .',
#  '<jj> 영 딱 보난이',
#  '<jj> 그래가지구 난 그것 때문에 되게 심각한 상황인 줄 알아가지고 그때 막 울고 그랜 .',
#  '<cc> 아흐 그때 내가 긍까 잘못 잘못 했으면은 진짜 감기 몸살 걸릴 뻔했어 너무 추워서',
#  '<gs> 쫌 과했구나라는 생각을 할 때가 있어요 .',
#  '<cc> 근디 이제 해외출장 자격이 있는 사람들을 가리기 위해서 이 자격증이 있는지 없는지를 판단을 했다고 해 .',
#  '<jd> 일단은 방구부터 시작 .',
#  '<gs> 그 리스닝 책 중에서 쫌',
#  '<jd> 오토바이를 빌렸자녀 음 그래갖고는',
#  '<cc> 그다음에 무슨 뭐 컴퓨터공학과가 하면은 전자정보대학 머 이런식으로 나뉘어져 있잖아 .',
#  '<jj> 고치 앉앙 이제 여 여피드레 보난 편의점에 강 보난',
#  '<cc> 제가 이렇게 몇 번 지나치 치면서 이렇게 계속 그거를 이케 유심히 봤는데',
#  '<cc> 일단은 지금 상황으로 보면은 쫌 다닐 거 같은데',
#  '<jj> 그럼 가만히해서 이 그냥 이',
#  '<gs> 에이아이랑 로도 로봇 산업 또 자율주행 차 나온다고 이케 얘기하니까',
#  '<kw> 뭐야 이 여잔 으제 집 앞에서 봤던',
#  '<jj> 거기 뭐 기구들 다 이서 ?',
#  '<cc> 우리 친구들이 그 인제 그이까 인제 세 명은 나이가 비슷하고 하남 한 명은 인제 우리보다 쫌 어려 어리는데',
#  '<gs> 그때 아버지가 인자 차 그 뭐이고 우유 같은 거 이런 거 이제 수입하러 대니고 이랄 때 인자',
#  '<cc> 그런 도망가고 이케 숨다 보 숨다가',
#  '<jd> 그 군대에 그니까 저 저 우리나라가 남북으로 갈려 있었는데',
#  '<gs> 근데 그거 아무래도 초등학생 때다 보니까 쫌 치 재미로',
#  '<jj> 산책핸 .',
#  '<gs> 보통 웬만하면 쫌 배제하는 편인데',
#  '<gs> 올 코로나 이후부터는 그 감기가 이래 걸린 일이 없습니다 감기가 걸린 일이 없이 몰라 손을 깨끗하게 씨꺼서 그런가 그거는 잘 모르겠다마는',
#  '<jj> 그래서 이번에 막 그거겠네',
#  '<cc> 제가 얼마나 이르케 끌어 잡아 댕겼으면은',
#  '<jj> 야 그럼 그걸로 걸을 수는 인 ?',
#  '<cc> 그래서 윈드 윈드브레이커도 되게 재미있었고 아니면 또 따른 거 보는 게',
#  '<cc> 근디 아줌마가 운전을 잘 못하니까 우회전이나 좌회전을 못햐 .',
#  '<jj> 저 우리 이신디 그것이 인연이 되어',
#  '<jd> 긍께 이름아빠가 나를 모른 점도 많이 있제',
#  '<jj> 맞아 학교에서 사람 만나신디 뭔가 안 씻은 거 같고',
#  '<gs> 그래도 고양이는 스킨십을 잘 안 하잖아예 근데',
#  '<jd> 섞어 가지고 국을 끓이면은 그게 진짜 금상첨화여 .',
#  '<gs> 니꺼는 보면 딱 아 이름그림이다 나온다 아이가 .',
#  '<jj> 영정 영정사진 그런거 놩해',
#  '<gs> 뭐 귀 잘생긴 거지는 없다더라 내 그 말 듣고 내 억수로 엄청 잘 살 줄 알았거든 근데 그것도 아니더라고 보니까 그냥',
#  '<jj> 나는 항상 예전부터 맨날 똑같은 소리 했긴 햄신디',
#  '<cc> 사람이 이렇게 그냥 고급 딘 디도 있고',
#  '<cc> 그라니까 그쪽 집에서 난리가 났을 거 아녀 처녀를 건들였으니까',
#  '<jj> 립서비스를 허는중 알켜이 나이제 겅허멍 무시거 햄신데이',
#  '<jj> 그걸 부를 줄 모르난 나 보자마자 그거 호끔',
#  '<gs> 이렇게 입어 저렇게 입어 하는 게 난 쫌 엄청 힘들더라고 .',
#  '<gs> 그런데 어 신앙 만나고 나니까 다혈질적인 기질도 쪼꼼 가라앉는 거 같고요 .',
#  '<jj> 그러나 이제 강남어멍들이 아이들 그거 하지 말랜',
#  '<jj> 재료 소진하면 매일 삼십그램만 팔고 이 그거 끝나면 문 닫아',
#  '<gs> 골프를 그 쫌 수강을 끊어놓고 해 봤는데',
#  '<jj> 섭섭했주게 .',
#  '<kw> 야 이름 아 쟤들 좀 말래 .',
#  '<jj> 유명해지는 방법도 여러 가지라 이',
#  '<jj> 나 얼굴 다 까먹어진거닮아',
#  '<gs> 요구하는 머 인재상 머 이런 얘기 하잖아',
#  '<jd> 새끼야 나뻐 긍게 그 남자가 .',
#  '<cc> 그 나 거기 나오는 인자 주인공이라든지 주인공하고 인자 이렇게 인자',
#  '<gs> 저희 고런 것들을 가봤는데 어 굉장히 아 애들이 어',
#  '<jj> 애들인데 걔네가 다 같이 똘똘 뭉쳐서이 뭔가 그 해내는 느낌이 난 너무 좋안 .',
#  '<gs> 그리고 이제 뭐 알게 모르게 서로 쫌 챙겨주고 어 동기애로 쫌 많이 버텼던 거 같애 .',
#  '<gs> 그래서 어 흔히 이케 뭐 또',
#  '<gs> 그다음에 뭘 먹었을 때 찌고 이런 거를 쫌 많이 배웠어요 그 그전까지는',
#  '<cc> 나는 쫌 다르게 생각하는 게 소비자쪽 이득만 생각하면 물론 그게 정말 좋은데',
#  '<gs> 일주일도 안 돼서 저 뭐야 이러면서 짐 애플펜슬 빼터리 영퍼고 전혀 안 쓰고',
#  '<cc> 청구를 해서 가지가 뭐가 잘못되믄',
#  '<jj> 경핸 나는',
#  '<gs> 그런 게 쫌 많이 기대가 되더라고 .',
#  '<jj> 예 경허면은 어쨌든 남편이 없으니까',
#  '<gs> 이제 쫌 바깥 생활하면서 자신감이 쫌 붙을 려나',
#  '<jj> 게난 같 이 가젠 데려감댄 해여 .',
#  '<kw> 그래니까네 제 친구가 기양 잠깐 돈이 필요해서',
#  '<kw> 편을 들다 역성을 드다라 .',
#  '<cc> 나눠 줄 게 뭐 있어 뭐 조금 떼어주기로 했겄지 .',
#  '<kw> 뭐 아무데나 간나라고 우겨대요 .',
#  '<jj> 그래서 한 거네 .',
#  '<gs> 자동차라던지 아이면 휴대전화',
#  '<gs> 쫌 짐으로 다가와서 그때',
#  '<cc> 어 그런 거 이케 통해서 이렇게 들어가면은 그게 쫌 마음에 들거나 이러면 그냥 바로 사는데',
#  '<cc> 생각은 다 똑같 멀쩡햐 .',
#  '<gs> 그냥 나가갖고 걍 손맛본다라고 생각을 하고 나가야 되거등',
#  '<gs> 쫌 지위가 높은 분이 이거 그래도 내가 주는 건데 마셔야지 이라면서 이제',
#  '<cc> 누가 쏜겨 초 총을 쏠라고 했는데 그 오 만 불로 산 흑인 남자가 자기가 대신 맞아준 겨 .',
#  '<gs> 그래서 아니 나는 티브이에서 보는 걸로 만족하지 그기에 가서 여자들처럼 있잖아',
#  '<kw> 못생기면 어뜨게 어태 하냐고 애한테',
#  '<jj> 나는 무서워서 못 걸으크라 . 겅 새벽에는 .',
#  '<kw> 니 맛도 내 맛도 없는 닝닝한 무치미에다',
#  '<gs> 나는 꼭 밥 묵어야 된다 소리는 안 했다 .',
#  '<gs> 이제 이름님처럼 저도 뭐 주변 지인들 근황 쫌 확인하기 위해서 이제',
#  '<gs> 그냥 엄마는 당연히 딸들은 잘 산다 생각하시는 거 같애요 웃음 쫌',
#  '<gs> 이렇게 트레이닝을 받고 쫌 훈련을 받느냐에 따라서',
#  '<jj> 우리가 손님을 초대하는 거네 이거는',
#  '<jj> 아니면 집에 완전 가난행으네 진짜 찢어지게 가난하거나',
#  '<gs> 사실 저는 좀 좋은 면만 봤어요 그까 시각 장애인이나 아니면',
#  '<gs> 거기를 짤라 가주고 이케 빵 위에다가 식빵 위에다가 딸기쨈을 발라',
#  '<jd> 그런 게 나는 쫌 볼 때 쫌 불편하더라고 .',
#  '<cc> 뭐 진짜 따른 여행도 잘 못 가겠고 간신히 간신히 시간을 내서',
#  '<jj> 농협 갓인디 아 이체된 거 맞고 연체료 육십 육원 붙은 거 맞댄 .',
#  '<cc> 그런 것들을 쫌 많이 구체화시키고 미래 준비에 대한 그런 것들',
#  '<jd> 그래서 아무도 안 먹는다 한다고 안 먹고 냉장고에 다 고대로 있었는데',
#  '<jj> 애들도 지네 알아 지네 착한거',
#  '<jj> 그 요가해서 그렇게 저 활력있게 넘치는 거꽈 ?',
#  '<cc> 나두 계절에 대해서 이렇게 오래 얘기 하다 보니께 진짜 재밌는 거 같어 .',
#  '<gs> 한번 스파링을 쫌 해 봤으면은',
#  '<jj> 할망 아파신디 할망 저기 헐 생각 안 해그냉 고라부런 웃음',
#  '<gs> 그걸 시키는 걸 한 번도 본 적 없어 그니까 우리가 마지막이었거든 그거 시키고 보는 거를',
#  '<gs> 니는 어때 ? 웃음',
#  '<jj> 밭듸 글랜 허민 강 당구에만 아즈멍 비만 와부러시민 좋켄 허멍',
#  '<jd> 우리가 마련이 돼 있고 여윳돈이 쫌 생기면 그때 조금씩 넣어도 되지 않을까',
#  '<cc> 고집 땜에 약간 스트레스를 쪼끔 받은 적이 쫌 많은 것 같습니다 .',
#  '<cc> 이름아주머니가 엄마한테 그게 한 간헐적 단식이 원래 한 삼 일 인가 오 일 정도 하는 건데 그거는 쫌 아 일주일 정도 하는 거 같애 .',
#  '<gs> 나중에 걔가 막 옆에 와 가지고 막 왈왈 카니까 이름한 방에 그냥 와',
#  '<jd> 와 나는 니가 진짜 랩을 엄청나게 좋아한다는 게 느껴지는데',
#  '<jj> 빨래도 건조됭 나오고',
#  '<jd> 봉다리에다가 화장품 다 넣가지고 밖으로 던지고',
#  '<gs> 어른이 되고 나서도 보면은 이케',
#  '<jd> 그래서 인제 요즘 이제 내 바람이 바램이 있다면',
#  '<cc> 긍까 틀에 서로 어 억압 받지 않고 그런 규칙 같은 것도 세우지 않고 안 해도',
#  '<gs> 이 그때 작년 봄에 끝났다 아이가 이거',
#  '<cc> 대학교를 컴퓨터공학과를 가는 바람에 아빠가 쫌 거금을 들여서 그때 사팔육 컴퓨터를 언니한테 사줬어 .',
#  '<gs> 니도 내랑 운동을 따로따로 꾸준히 다니면 만나서 같이 그 운동을 할 수 있잖아 .',
#  '<kw> 오늘 또 온 거 이름 가 나가서 아주 두 번 다시 허튼 맘 못 먹게 악살을 멕이구 들어왔어 .',
#  '<cc> 그니까 내가 처음에 오빠를 다시 만난다고 했을 때 오빠한테 오빠가 너 아 내가 오빠한테 얘길 했지 .',
#  '<cc> 옮기고 옮기고 옮겨지다 보니까 이제 자연재해로 이제 퍼지니께 이제',
#  '<jj> 삼만 구천 원 이면 거의 뷔페 값이다 . 이',
#  '<jj> 조금씩은 다 해야 되난',
#  '<jj> 아니 공항은 진짜 일찍 간 .',
#  '<jj> 왜냐하면 땅이 한 만평 조금 넘는데 거기에 한 거의 한 칠천평 이상이 짤랑 들어갈꺼거든 .',
#  '<kw> 그른 놈이 자야 사진도 컴퓨터에 잔떡 넣어놓고 그랬다는 거 아닌가 .',
#  '<gs> 그니까 그 아버지가 그른 이야기를 하는데',
#  '<cc> 어 그런 거에 엄마가 쪼꼼 음 막 빠지면서',
#  '<gs> 이 집중하다 보니까 쫌 정신이 피폐해지더라구요 그래서 피파도 그렇고 배그도 그렇고',
#  '<gs> 저는 남들이 들으면 쫌 웃긴데 원피스 보면서 되게',
#  '<cc> 근데 진짜 변화가 되고 싶으면 감당해야지 리스크를 어떻게 리스크 없이 뭐 대가 없이 뭔가를 얻을려 그래 ?',
#  '<gs> 옛날에 쫌 예쁜 차였는데 요새',
#  '<cc> 그러고 바다는 이제 가면은 쫌 이제 느낌이 쫌 달러 .',
#  '<gs> 뭐 군대 근무하실 때 쫌 특별하게 기억에 나는 에피소드라던지',
#  '<cc> 그래서 자동차를 빨리 수리해야지 고객층을 유지할 수 있었다고 하드라고',
#  '<jj> 멀어지는 거 닮아 .',
#  '<gs> 어 이게 뭐야 이러면서 이러니까 그니까 그때가 어 이게',
#  '<gs> 서로 막 이케 이케 했는데 이제는 어머니께서 이렇게 저를 컨트롤해주시는 것 같아요 .',
#  '<gs> 이것도 제테크라고 할 수 있나 ?',
#  '<jd> 너무 쫌 이런 것들은 막 뭐 얼굴을 손대는 거는',
#  '<kw> 이 사이로 살그머이 보이는 혀끝 .',
#  '<jj> 일요일날 숙제도 꼬박 꼬박 행 가려고 해 .',
#  '<jj> 돈우미서 태어난양 칠 남매의 맏딸로 태어난 엄마 아빠는',
#  '<jj> 꽃청 해가지고 그 뭐지 걔네 어디 갔었지 ?',
#  '<jd> 은근 강릉이나 막 이런 쪽이 본전통이 있더라고 아니',
#  '<jj> 걔네한테만 배랭이가 막 버랭이들이 보글 보글해 .',
#  '<kw> 물속에 빠뜨렸는데도 쭉지 않고 상구 살아 있어 .',
#  '<gs> 내 어릴 때 막 듣는 거라던가 그런 거 쫌 많이 듣게 되던데',
#  '<kw> 정말 모든 안 되는 거 같아 .',
#  '<jj> 그니까 그 name 선생님 등급 인',
#  '<kw> 어찌 된 판국인지 전예 모르겠다 .',
#  '<kw> 야 니 핸드폰 고쳐왔거든 내 핸드폰 내놔 .',
#  '<kw> 아무것도 몰라도 난 무조근 형수님 편이예요 .',
#  '<jj> 우리 형부는 사돈들 만나난',
#  '<gs> 그런 그거 뭐라고 해야 되나 그런 거를 선물 겉은 것도 사가 오고 막 이러면은',
#  '<jd> 그럼 말 안 해야제 우리는 믿고 말한건디 .',
#  '<cc> 쫌 애가 크니까 괜찮아지는 거야 근데 삼 학년 때 그 내가 이렇게 부르면은',
#  '<jd> 그 슬픈 영화를 잘 못 보는디 그 와중에',
#  '<cc> 취약계총 잘 걸리는 사람들부터 백신 놔줘야 된다라는 거여 .',
#  '<cc> 그리구 발가락두 시리구요 .',
#  '<jj> 그럼 같이 가가지고 사잰 ?',
#  '<jj> 인생이 막 초반에 안 풀려서 이상한 남자영 결혼행해',
#  '<jj> 그리고 또 우리 어멍은 나이 들엉 음식을',
#  '<cc> 그리고 인턴 오블리비언 뭐 약간 그렇게 한 대 여섯까지가 있는디',
#  '<jj> 그난 거기에 그냥 히히히 내불잰',
#  '<gs> 아 엄청 떴다 다들 그니까',
#  '<jd> 글면은 정 사장님이 그리울 수가 있을 거야 .',
#  '<jd> 봤는디',
#  '<gs> 그렇게 지도 가려우니까 얼마나 또 그렇겠노 ?',
#  '<cc> 굉장히 말이 많았던 직원이었구먼유 그래서 그 직원이',
#  '<jd> 원래는 포켓몬이 게임으로 먼저 나와 부렀고',
#  '<gs> 회사에서 쫌 아는 부부 아니었나 약간 쫌 소문난 컾',
#  '<jj> 술 먹고 일어난 일들이 몇 개 있긴 이서 . 그거 한 번 들어보젠 ?',
#  '<jj> 치마가 이시면 했주 .',
#  '<jj> 그런데 괜찮아 세련되게 잘하더라 나랑 나랑 좀 겹치는 게 많긴 핸',
#  '<cc> 글쎄 옷을 옷을 쫌 여러 가지 사긴 했는데',
#  '<gs> 그니까 언제나 잘될 수도 없고 언제나 못 될 수도 없고 그렇기 때문에',
#  '<cc> 그 분위기 따라서 어느 날 이제 첫 명절이었을 거여 .',
#  '<jj> 계단으로 영 해여그네 이제 그 물을 들렁이네 욕심을 부려그네 그',
#  '<jj> 헐 이름왔언 ?',
#  '<gs> 인상 깊게 봤던 올림픽 경기가 있다 쫌 이런 거 있으십니까 ?',
#  '<jj> 기술 배왕 뭐해지믄 양장점이라도 하나 촐리민',
#  '<gs> 그 사진 찍어서 있었는데 새 거 맨날 들어오데',
#  '<jj> 그래도이 스마트폰 쓰다가 피쳐폰 절대 못쓸걸 ?',
#  '<jd> 나는 나도 로봇을 쫌 더 사용할 것 같애 .',
#  '<jj> 근데 다 사는 수준을 알고 하니까 다 이해하고 뭐 하지만 고등학교 때는 뭐 자기네 집으로 데려가지도 않해 .',
#  '<gs> 근데 그게 진짜 국물이 거의 없고 그냥 건더기랑 쫌 죽 느낌인 거예요 .',
#  '<cc> 그게 트라우마 있는 거여 그게 콤플렉스여 .',
#  '<kw> 그러니 사는 게 재미다리라곤 하나도 .',
#  '<gs> 뭔가 보는 입장으로썬 괜찮긴 한데 약간 갑수목장처럼 그런 사건이 터지니까 뭐랄까 쫌',
#  '<jj> 그 동카름엔 어떵 잘 사름들 잘 사는 사람들만 이신건고라 .',
#  '<cc> 쪼만했을 때 더고 변화가 있었나 그때',
#  '<jj> 겐 거의 이제 글로 해서 걸어서 이제 다녔고',
#  '<jd> 아니겠다 아 이 사람이랑 나 몬해 먹겄다 웃음 이러거나 쫌 이러먼 또 크게 리스크가 없을 때 갈라설 수도 있고',
#  '<cc> 너무 서슴없이 막 이릏게 막',
#  '<cc> 근데 그니까 왜냐면 나는 지금 현실에 너무 찌들어 있고',
#  '<jj> 대박 너네 좋다 이 .',
#  '<jd> 내가 벌써 진로가 정해진다는 것도 무섭구 공부를 쫌 더 해서',
#  '<cc> 어 따로 그 오층에서 생활을 해서 쫌 편했거든요 .',
#  '<gs> 나는 일본 홋카이도 한 번쯤 가 보고 싶었는데 내 중학교 때 친구',
#  '<gs> 그렇지만은 인자 유튜브를 통해서 김호중 노래는 제가 쫌 듣고 있습니다 왜냐면은',
#  '<gs> 그거 잘못했으면 아칼리 궁에 연계됐으면 걍 죽었지 .',
#  '<cc> 자고 났다가 또 먹는 거여 이렇게 일 키로 밑으로 따운시켜 놨다가 그때는 쪼끔 더 뭐를 먹는 거를',
#  '<cc> 그래 집 관리를 참 철저하게 잘 하드라고 그래서 우리는 그래도 지대가 쫌 이 응',
#  '<gs> 니는 제일 싫어하는 계절이 뭐야 ?',
#  '<cc> 쫌 푹신푹신한 쌔거 완전 바뀐 걸로 줘가지고',
#  '<jj> 손님들 넘어강 자빠져 가불민',
#  '<cc> 살짝 팔은 거예요 인제 그릏게 인제 남편한테 인제 얘기를 해가지구',
#  '<gs> 지금 현 뭔가 현재에 이케 나에 대해서 쫌',
#  '<kw> 야 이그 안 놔 ?',
#  '<jj> 이름 개빡가지고 맞아 맞아 언니들하고 말해가지구 그때랑 상황이 조금 바꿔긴해',
#  '<gs> 미끌미끌해서 잘 흘러가거든 그서 병뚜껑 축구도 되게 많이 했는데',
#  '<gs> 그냥 쫌 많이 먹었다 싶으면 작게 먹고',
#  '<kw> 그런거야 증말 그른 거야 ?',
#  '<jj> 뭐 단호하게 거절한 적은 없는 거 닮은디 .',
#  '<gs> 졸업하다 보면 이제 휴대폰 쓸 일도 쫌 많아지기도 할 거고',
#  '<jd> 같이 눈화장을 찐하게 해 가지고 펄있게 해가지구',
#  '<gs> 케이리그도 인제 쫌 자주 봐야겠다 생각을 했어 .',
#  '<kw> 옷 안 갈아 입으문 아문일도 못하잖아 너 .',
#  '<jj> 겅허믄 큰일 날 일이라 게난',
#  '<cc> 이 쫌 옷을 쫌 관심이 생기고 쫌 자주 입고 하다 보니까 대충 혼방율을 보면은 어떤 느낌인지를 쫌',
#  '<cc> 어떻게 나 혼자 가냐 거기 타지를 아무도 안 가냐고 같이 가기로 했으면서 다 어떻게 배신 때리냐고 그서 진짜 서운했단 말야 .',
#  '<gs> 그게 쫄아요 제가 그래서 전 쫄지 않을라해요 .',
#  '<gs> 그서 막 장기로 하고 밥 아낄라면 아 돈 아낄라면',
#  '<cc> 모든 영화를 난 다 재밌게 보는 편이여 갖고 뭐 다 그냥 뭐 볼만하드라고 .',
#  '<jj> 옥수수 있잖아 예',
#  '<jj> 그런 대우를 안 받아 보니깐 몰란 .',
#  '<jj> 그거 핑계로 나도 강',
#  '<jj> 아쉬운다 빨리 허라이 .',
#  '<kw> 그 비밀은 첫째로 당신 자신을 신뢰하는 것이며 이기 제일 중요한 것입니다 .',
#  '<gs> 그 공부 좀 더 할라 해갖고 어디 다른 데에가 인제 취직 다른 데에 인자 그 공무원 시험 볼라고',
#  '<jd> 이제 아버지가 엄마가 많이 아프셔가꼬',
#  '<jj> 너 잘할꺼 닮아 .',
#  '<gs> 오 그래서 이제 꽃도 보고 그기에 항상 이제 견주들이 강아지들을 항상 데리고 오거든 .',
#  '<jj> 야 이거 겁나 맛인 .',
#  '<kw> 내가 보기엔 에레 주벤 사램들 그른 마옴 이용해서',
#  '<jd> 예의라고 인제 그때 배울 수 있게 되었거든 그래서 나도',
#  '<cc> 괜찮다 싫 안 별로 안 좋다 뭐 이런 얘기 단 지금까지도 한 번도 안 해봤어 지네들이 선택한 거니까',
#  '<jj> 게난 호르몬이 확실하네',
#  '<cc> 나는 김태년 김태년이라는 사람을 증말루 이해할 수 없는 사람이여',
#  '<jd> 너무 긍께 처음 평상시에 왜 이렇게 살 찌까',
#  '<jd> 수면부족이 가장 컸었던 거 같여 잠이 안 오니까 긍까',
#  '<gs> 원놈의 예전에 원나블이라 했다 아이가 .',
#  '<cc> 쫌 고급스럽게 꾸민다구 그때는 머리를 짤라가주구 다 웨이브들을 이케 했나 몰라 .',
#  '<kw> 딴 수가 없으니 너는 그들을 만나서 정말로 즐길 수 있을 거야 .',
#  '<jd> 그렇 그런디 그 밥도 맨날 맛있는 거 사 주고 소고기 사 줄 때도 있고',
#  '<kw> 자 어뜬 게 걸릴지 기대되는데요 .',
#  '<jd> 근데 내 차를 운전도 못하고 니가 택시 불러줘 갖고 타고 왔다갔다 했잖아 .',
#  '<jj> 물 좔 좔 흐른 거 핸',
#  '<cc> 나한테 뭐 누가 쫌 뚝뚝하게 생겼다고는 할지언정 난 이게 수다도 좀 떨구',
#  '<jj> 밭을 갈고 일을 모치난',
#  '<jd> 쫌 스트레스를 너무 잘 받아 가지고',
#  '<gs> 근데 진돗개치고는 좀 큰편이어가지고 다른 니가 혹시 보거나 하면은 좀 놀랬을 수도 있어 .',
#  '<jj> 아이구 게메이',
#  '<jd> 다중 뭐 다중이 근까 다중',
#  '<jd> 먼저 제일 먼저 하고싶은 얘기는 우리 인제 딸 이름',
#  '<jj> 거 막 토당 오고정한디 이 사람이 막 요라 해영 가노난',
#  '<gs> 그냥 두뇌를 써야 되는 것들이 썪여 있어서',
#  '<jj> 영 안 앉앙 막 말곧거든 말 하거든',
#  '<gs> 그 할아버지가 큰 삼촌을 억수로 싫어했고',
#  '<jj> 십 년 전에부터 색소폰도 하고 하난이',
#  '<kw> 개가주 어렸을때 꿈이 뭐냐고 물어보면 아롱사태 써는 사람이 꿈이라고 했었어요 .',
#  '<gs> 나 걍 너가 그냥 몸을 만들고 그런 그니까 너가 지금 운동을 하는 목적이 뭐야 뭐',
#  '<gs> 쉬는 시간이 딱 이케 있는데 우리도 그러면 아 그럼 너네도 그 직원 이모야들 쉴 때 니네도 쉬라 이러면서 캤는데',
#  '<gs> 그니까 니 웃음 그거 취소하는 데도 오만상',
#  '<kw> 공사는 인재 막 착수했을 따름이다 .',
#  '<jj> 근데 진짜 깨끗해젼 .',
#  '<cc> 참기름 살짝 둘러서 김가루 해서 비벼 비벼먹어 까 약간',
#  '<gs> 파 어슷썰기 해서 인자 고거 파를 살짝 해가',
#  '<cc> 그걸 보면서도 이케 잘 안 읽게 돼 내가 시작이 참 어려워',
#  '<gs> 일본 가서도 영어 내 일본 가서는 진짜 말 한마디도 안했는데 웃음',
#  '<cc> 거기 이제 방공호라고 해서 호를 파잖여 산에',
#  '<cc> 노얄싸롱 있을 때 그것도 좋았었는데 지금으로 말 하믄',
#  '<jd> 정말 우리가 모달 게 뭐가 있어 이 나이 먹어가지고',
#  '<jj> 수원 화성에 갔언',
#  '<cc> 그래 가주고 그때 엄마한테 혼나긴 했었는데',
#  '<jj> 이제 구젱이 받으러 오면은 구젱이 받으러 왕으네 이디 왕 무시거',
#  '<jj> 백이십명쯤 갈까 했는데 백이십명이 아니고 거진 백사십명쯤 온 거 닮아 .',
#  '<jj> 밤이고 거 장시햄잰 한 신호 게난양 그 사람이 미깡 낭',
#  '<jj> 나 배민 브이아이피랜 .',
#  '<gs> 하다가 안 할라 카니까 뭐 쫌 시원 섭 쫌 섭섭하이 그렇네 .',
#  '<jd> 너가 한번 뛰어 봐라 해가지고 한번 뛰어봤는데 그때 일 등 한 거야 해가지고 내가 그때',
#  '<jd> 공포는 드릅게 보기 싫드라 인제는',
#  '<gs> 낙후되었다고 평가하는 거 보이깐 참 마음이 안타깝네 .',
#  '<gs> 어 업무를 하는 데 있어서 좀 수월하지 않을까 생각을 하고 있그든 그래서 니도 토목 공학 토목 공학과니까',
#  '<gs> 치매 같은 것도 걸려갖고 만났을 때는 전달도 못해주고',
#  '<jj> 에듀 에듀 뭐랜 말해냐만은 말하는지는 모르겠지만',
#  '<cc> 그때 기억 고등학교 때 가봤던 기억이 쫌 많이 났었고',
#  '<kw> 역추적한 결과 장물 취득과정에 대한 증거는 몇 가젱이 정도 확보된 상태입니다 .',
#  '<cc> 막 이케 몇 번 연락했었거든 .',
#  '<jj> 무근성 이신드레 있는 곳에 그레 보믄 집들이 오망조망헌 집들이 셔 .',
#  '<cc> 하여튼 묘한 거지 그니까 쪼끔 닮 닮으며',
#  '<jd> 지금 생각해 본께 그렇게 좋았던 알바가 없는 거 같혀 .',
#  '<gs> 그랬지 세븐 쓸 때 항 그때 니 기억날랑가 모르겠는데',
#  '<jj> 아니 써본적이 써신가 ? 하니까',
#  '<jd> 자기가 갔는데 인사도 안 하고 그냥 이르케',
#  '<cc> 장기가 불편하면 체해두 등 아픈 거 알지 ?',
#  '<cc> 그런데 막상 또 그 이후처럼 그니까 그 예전처럼 무한도전을',
#  '<cc> 그런데 여기에다가 신청을 해서 엘 이런거다 해도 이것보다 훨씬 들 나와 씨엠비 쓰는 것보다',
#  '<jj> 나 해주랜핸거 해달라고 하는거 다 해줜',
#  '<cc> 그냥 친구가 화를 내는 것도 솔직히 뭐 내가 서운하게 했거나 그런 게 있으니까 쫌',
#  '<gs> 그래서 의사 선생님이 저는 간 큰 여자예요 카면서 수술할 거면은 수술 안 해요 그러면서',
#  '<kw> 뭘 봐 자석아 .',
#  '<gs> 쪼금 아무래도 많이 깝깝하더라구요 그래서',
#  '<jj> 너 지금 씨씨티비 봠서 ? 제주도 ?',
#  '<gs> 아 있잖아 내가 이주 있었다고 했잖아 그니까 할 일이 없는 거야',
#  '<jj> 그 반이고 이 어는 물고기고 이 피는 껍데기라 겡 뭐 닮아 ?',
#  '<jj> 게난 그 사람들도',
#  '<gs> 우리 밭에 그거 인자 느그 외할머니 집에는 밭이 이리 쳤는데',
#  '<jj> 야 너네 내년 일 학기 교류 수학 진짜 생각 인 ?',
#  '<kw> 오놀 갑자키 이름어머이가 보자는 거야 .',
#  '<jj> 자장면먹엄시냐 ? 뭐 뭐 먹엄샤 ?',
#  '<jd> 쫌 상황에 따라',
#  '<kw> 베르고 벨러서 벼르고 별러서 한 일이 요거 밖에 안되나 ?',
#  '<cc> 음 이제 쪼금 그릏게 빨리빨리 실천이 안 되는데요 .',
#  '<jd> 오로지 집중하고 무슨 자리가 있으면 항시 데꼬 나가고 그랬냐',
#  '<jj> 사람들 나에 관심을 둘 수 있는 그런 그정도 좋아하는 거 담 .',
#  '<jd> 걍 한 방에다 모아 놓은 그런 그래서 엄청 넓고 먹을 것도 엄청 많아서',
#  '<jj> 있다고 하는 것 같긴 하던데',
#  '<jj> 어머니는 이 나한테 가면 막 뭐라고 하는디',
#  '<jj> 그래도 고 다리 후들거릴 거 닮아 .',
#  '<gs> 막 밤에 자는데 기침 쪼끔만 나도 코로나 아니가라는 생각도 들고 그런 생각이 쫌 더 무섭게 하는 거 같애요 사람을',
#  '<jj> 지금 동창들이 더 와랑와랑 해실건디',
#  '<jj> 나는 아들 불렀주게 아들들 이리저리 오랜행 . 오라고 해서 .',
#  '<kw> 삐걱거리는 소리는 낼 미치게하고 있어 .',
#  '<gs> 장난으로 쫌 티격태격하는 편인데',
#  '<gs> 돈 돈 돈 내는 돈밖에 모른다 뭐 돈 때문에 안 된다 뭐 이런',
#  '<jd> 상호명러버 란께 ?',
#  '<cc> 머리 가서 드라이 딱 해논게 부럽디야 .',
#  '<gs> 아 맞다 카고',
#  '<jd> 일헐 때 십팔만 원짜리 했는데 그 그 꼴이었단께',
#  '<jd> 바꾸면서 자기 개성대로 쫌 쫌 이케',
#  '<cc> 막 이런 거 남자들끼리 가면 이런 거 하면서 쫌 재밌는데',
#  '<gs> 그거 이렇게 혓바닥에 이렇게 발라 가지고 진하게 나오잖아요 아고 그럼 클난다 니 병 걸린다 이렇게 하니까',
#  '<gs> 쫌 더듬잖아 그 그 그 말할 때에',
#  '<jd> 뭐 이런 거 온라인 강의로 합격한 사람 많으니까 걱정 안 해도 될 거 같여 .',
#  '<gs> 스팅어라던가 그런 식으로 쪼 그 말하셨던 차들보다는 쪼금 짝은 차들로',
#  '<jj> 아니 존나 다니는데이 맘에 드는데가 어서',
#  '<cc> 뭐 어떤 그런 인제 어 이케 오케스트라가 있는',
#  '<kw> 나랑 아랑 아빠랑 그렇게 행복하게 가정을 꾸려 가는 거',
#  '<jj> 아 거 문제다게',
#  '<kw> 너 자꼬 이름가지고 쓸데없는 소리기 하려거든 오지마 .',
#  '<jj> 허멍 막',
#  '<kw> 내가 이름 이 앞에서 이름애미 얘기하므 신세 한탄 할까 봐 그래서 ?',
#  '<cc> 그래서 솔직히 뭐 이름 없거나 뭐 쫌 중저가보다는 그래도 가격이 쎈데',
#  '<jj> 초등학교 때 좋아하는 사람들도 많았지 안 ?',
#  '<jd> 거기서 길 읽고 나서 더 이상 하기가 싫더라고 그래가꼬',
#  '<jd> 뭐 맨날 집에서 인제 음식도 그냥 가까운 데 나가서 먹는 게 아니라 되게 시켜먹는 게 쫌 많아졌어요',
#  '<gs> 너는 만약에 그런 시대가 오면 니가 어떻게 활동할 것 같애 ?',
#  '<jd> 하이브도 있고 조석 작가 이제 조의 영역이라는 웹툰도 있고 마음의 소리도 있는디',
#  '<jj> 추석도 친척들도 사촌까지만 모이긴 했는데 이 다 모이난이 할 말도 많고 이',
#  '<cc> 커피숍 가서 이케 먹고 하는 거가 훨씬 맛있거든 기분상으로도 그렇고']

# %%
# # special token >> jj: 4, jd: 5, gs: 6 , cc: 7 , kw: 8 
# print(dec_tokenizer.encode('<jj><jd><gs><cs><kw>'))

reg = {4 : '제주도', 5 : '전라도', 6 :'경상도',7:'충청도', 8:'강원도'}

for i in range(4,9) :
    print(f'{reg[i]} 사투리 :')    
    translate(enc_corpus_test[i] ,transformer, i, enc_tokenizer, dec_tokenizer)
    print()
# Out:
# 제주도 사투리 :
# Input: theyribs are not recommended to go on a diet when they see it around them
# Predicted translation: 그 사람들이 막 돌아다니는 거 추천 안 해줘가지고이
#
# 전라도 사투리 :
# Input: i think its a little bit like that right now
# Predicted translation: 쫌 그런 거 같애 .
#
# 경상도 사투리 :
# Input: yes he was like this with his name
# Predicted translation: 어 그 이름님은 이케
#
# 충청도 사투리 :
# Input: but our ceos name is so serious
# Predicted translation: 근데 우리 세 우리 세멘이 너무 심각한 거야 .
#
# 강원도 사투리 :
# Input: since its a comic id like to tell you tom jerry and dooly a baby dinosaur as a representative
# Predicted translation: 만화니까는 아시아 대표로 대표로 대표로 해 가주구

# %% [markdown]
# # Step 5. 평가

# %%
print(enc_corpus_test[0])
print(dec_corpus_test[0])
# Out:
# you have to wake up and eat on time and clean up but its so neat
# <cc> 일어나서 제시간에 밥을 먹어야 되구 청소를 해야 되는데 워낙 깔끔은 허셔 아주

# %%
dec_tokenizer.encode_as_ids(dec_corpus_test[0])
enc_tokenizer.encode_as_ids(enc_corpus_test[0])
# Out:
# [27, 104, 30, 1476, 187, 40, 188, 82, 159, 40, 895, 187, 73, 107, 43, 2927]

# %%
translate(enc_corpus_test[0], transformer, 4, enc_tokenizer, dec_tokenizer)
# Out:
# Input: you have to wake up and eat on time and clean up but its so neat
# Predicted translation: 일어나야 되고 이
# '일어나야 되고 이'

# %%
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.bleu_score import SmoothingFunction

def eval_bleu_single(model, reg, src_sentence, tgt_sentence, enc_tokenizer, dec_tokenizer, verbose=True):
    src_tokens = enc_tokenizer.encode_as_ids(src_sentence)
    tgt_tokens = dec_tokenizer.encode_as_ids(tgt_sentence)

    if (len(src_tokens) > 50): return None
    if (len(tgt_tokens) > 50): return None

    reference = tgt_sentence.split()
    candidate = translate(src_sentence, model, reg, enc_tokenizer, dec_tokenizer).split()

    score = sentence_bleu([reference], candidate,
                          smoothing_function=SmoothingFunction().method1)

    if verbose:
        print("Source Sentence: ", src_sentence)
        print("Model Prediction: ", candidate)
        print("Real: ", reference)
        print("Score: %lf\n" % score)
        
    return score

# %%
# single test
test_idx = 100
reg = 4

eval_bleu_single(transformer, 
                 reg,
                 enc_corpus_test[test_idx], 
                 dec_corpus_test[test_idx], 
                 enc_tokenizer, 
                 dec_tokenizer, 
                 verbose=True)
# Out:
# Input: the actors were actually a little bit bad and the set and the whole
# Predicted translation: 그 배우들이 사실 좀 안좋아하고 전체를
# Source Sentence:  the actors were actually a little bit bad and the set and the whole
# Model Prediction:  ['그', '배우들이', '사실', '좀', '안좋아하고', '전체를']
# Real:  ['<gs>', '어', '그', '배우들도', '난', '사실', '쫌', '별로였고', '그', '세트장이나', '전체적인', '그런']
# Score: 0.017860
# 0.01786024416690236

# %%
def eval_bleu(model, reg, src_sentences, tgt_sentence, enc_tokenizer, dec_tokenizer, verbose=True):
    total_score = 0.0
    sample_size = len(src_sentences)
    
    for idx in tqdm(range(sample_size)):
        score = eval_bleu_single(model, reg, src_sentences[idx], tgt_sentence[idx], enc_tokenizer, dec_tokenizer, verbose)
        if not score: continue
        
        total_score += score
    
    print("Num of Sample:", sample_size)
    print("Total Score:", total_score / sample_size*100)

# %%
eval_bleu(transformer, reg, enc_corpus_test[:70], dec_corpus_test[:70], enc_tokenizer, dec_tokenizer, verbose=False)
# Out:
#   0%|          | 0/70 [00:00<?, ?it/s]
# Input: you have to wake up and eat on time and clean up but its so neat
# Predicted translation: 일어나야 되고 이
# Input: hey he is the person who left the dry but he is the lawyers office who is smiling on the site
# Predicted translation: 야 그 사람은 그 말로 왼쪽으로 남은 사람인데 웃음
# Input: i the nami sings like this and she has a short hair
# Predicted translation: 나 나영이가 영 불르는데 그 언니가
# Input: so if youre stressed out and do this
# Predicted translation: 거난이 스트레스 받앙 영 허믄
# Input: theyribs are not recommended to go on a diet when they see it around them
# Predicted translation: 그 사람들이 막 돌아다니는 거 추천 안 해줘가지고이
# Input: i think its a little bit like that right now
# Predicted translation: 약간 그런 거 닮아 지금 약간
# Input: yes he was like this with his name
# Predicted translation: 응 이름 이랑 영
# Input: but our ceos name is so serious
# Predicted translation: 그런데 우리 세멘은이 너무 심각한 거
# Input: since its a comic id like to tell you tom jerry and dooly a baby dinosaur as a representative
# Predicted translation: 만화난게 .
# Input: so ill eat until im drunk but anyway its only for me
# Predicted translation: 그래서 내가 먹을꺼는 취할게 근데 어쨌든 나밖에 안 먹긴 한데
# Input: get the old age lets go lets go
# Predicted translation: 나이 들어가가 게
# Input: there were three of us
# Predicted translation: 우리 세 명이서
# Input: so i liked a lot of friends who were a little bit long and mother seedlings
# Predicted translation: 그래서 나는 쫌 오래된 친구들을 많이 좋아핸 .
# Input: ita is a name and i have to go to my sister
# Predicted translation: 이름 는 이고 언니한테 가야되는디
# Input: how can we go abroad if we go there because we said we would go abroad
# Predicted translation: 어떻게 하면 외국으로 갈 수 있냐 ? 외국에 가켄 하난
# Input: i wonder if you like this kind of performance a little bit
# Predicted translation: 이런 성향이 좋으신지 궁금하다 .
# Input: our title name is like that to me
# Predicted translation: 우리 이름 이는 저 저
# Input: imly call the school because im abusive so im going to do this so i wont come from next time
# Predicted translation: 나 학비라고 해서 학교라고 하니까 내가 이 다음에 이 안 오거든
# Input: the taste is really good
# Predicted translation: 맛은 진짜 맛인
# Input: i think he quit in the year of ten
# Predicted translation: 그 사람 일 년 동안 그만두는 거 닮아
# Input: before that it went up once a year
# Predicted translation: 그 전에 일 년에 한 번씩 올라간
# Input: lets eat for about two days focusing on a small amount of rice and inje vegetables
# Predicted translation: 우리 밥 한 이틀 정도 먹을 거 밥도 양에 집중해주고 야채도
# Input: but the rules are simple too
# Predicted translation: 근데 규칙은 너무 간단하게
# Input: everything is doing like this now its completely well
# Predicted translation: 다 영 하는 거 다 이제 완전 잘 되네
# Input: do you want to ruin my hair then
# Predicted translation: 너 머리 러치잰 ?
# Input: do germs crawl like this
# Predicted translation: 생강도 게
# Input: so replace it at the right time
# Predicted translation: 거난이 그 때 교체해줘
# Input: it doesnt suit me so
# Predicted translation: 나 안 어울리니까
# Input: some working women suffer from habitual miscarriage
# Predicted translation: 어떤 여자의 생명을 겪는 습관에서 고생하는 아이도 있주
# Input: so in korea really all over the world
# Predicted translation: 거난 우리 한국에서는 진짜 다 세계적으로
# Input: i know he was in his early and mid s but he must have lived like that in changwon so he wasnt even a drama writer
# Predicted translation: 게 그 사람 그 사람의 삼십 초반에 그 사람인데 그 창원에서 그렇게 살았을 거 아니 ?
# Input: and if i become a little dead alone i remember again
# Predicted translation: 그리고 내가 만약에 내가 쫌 죽은 상태가 되민 또 기억을
# Input: i dont know all the details in detail
# Predicted translation: 자세한 세세한 내용은 다 몰르쿠다
# Input: when i was young my parents said they didnt want to go to my mother
# Predicted translation: 어릴 때 막 친정 어멍네가 막 가젠허난
# Input: no there are a lot of small children and pretty children but its particularly
# Predicted translation: 아니 작은 아이들은 작은 아이들은 하영 이쁜데 이 특히나
# Input: so its not just about blocking it from being fixed
# Predicted translation: 그래서 그냥 정해진거로만 막아주는 게 아니
# Input: oh i didnt know
# Predicted translation: 아 몰란 .
# Input: so if theres a more seoul concert im going to hang out in seoul
# Predicted translation: 그래서 서울에 더 많으면 서울 콘서트도 놀러 가고
# Input: its better to have a pet in a house with a little yard
# Predicted translation: 약간 마당에 있는 반려동물 있는 게 낫주게
# Input: no stocks are done these days or anything
# Predicted translation: 아니 주식을 요즘엔 다 해여
# Input: its times hot with gel so theres no air conditioner and no fan at home
# Predicted translation: 생이라 젤로 더워 . 그래서 에어컨도 없고 집에서도 팬더 팬더 팬도 없고
# Input: youre thinking about something so you can do it later
# Predicted translation: 뭔가 고민하는 거 있네 나중에 할 수 있는 거
# Input: after growing up i traveled a lot with my boyfriend but thats what the two go around
# Predicted translation: 커 크고 나서 이제 남자친구랑 많이 놀고 나신디 그 두 둘이
# Input: recognize you well is there a philosopher who is good at seogwipo
# Predicted translation: 잘 알아봐 너 서귀포에 잘 서귀포 잘한 아이는 이신거
# Input: then my dad at my house
# Predicted translation: 우리 아방은 우리 집에 아방
# Input: its a pity in a way and i think its a selfemployed profit and i just dont know
# Predicted translation: 어떻게 보면 안타깝고 자가용인거 닮아 . 그냥 모르는 거 닮아 .
# Input: isnt there a time when youre really puzzled
# Predicted translation: 진짜 진짜 사투리로 하는 때가 있지 않애 ?
# Input: ithe was built by the year but now it changed oh i think it changed to beginner and intermediate since last year
# Predicted translation: 일 년쯤 지났는데 지금은이 바뀌어 아 일 년 후에 갈아타고 연초 간격을 해버린거 닮아
# Input: it does worth doing
# Predicted translation: 할 만 하주게
# Input: oh my the hair dye is strong
# Predicted translation: 아이고 염색 염색이 강으네
# Input: well the insurance company sold everything and fed them to me really bars long time ago
# Predicted translation: 뭐 그 보험회사 다 팔고 다 멕이고 진짜 오래전에
# Input: should i not post the sashtag to just look at the people around me
# Predicted translation: 주소는 안 올리카 ? 그냥 구경만 하카 ?
# Input: since youve been working in a bank for a long time how neatly would you like to serve customers or manage your finances
# Predicted translation: 은행에서 일만 하당 보난예 그 손님이예 얼마나 정돈을 하느냐
# Input: its a dry pig that just soaks it and its splashing out
# Predicted translation: 그냥 그 흙으로 그냥 담가그네 막  ⁇ 아
# Input: you use a lot of filters in the photo album like an album have you used that filter before
# Predicted translation: 사진처럼 많이 쓰잖아예
# Input: and among your diet diets
# Predicted translation: 그리고 너네 식단 중에는이
# Input: usually there are not many places like this so its early in the morning so its a tunnel
# Predicted translation: 보통 이렇게 많진 않게 영하난 아침 일찍이
# Input: did you sign up
# Predicted translation: 싸인을 해신가
# Input: i thought i could last a long time
# Predicted translation: 나 한참을 오래 갈 수 있을까 해신디
# Input: then you just have to not make physical contact
# Predicted translation: 게믄 그냥 몸에 안 맞게 해야되여
# Input: i dont think theres any advertisement that really doesnt do it
# Predicted translation: 진짜 광고를 안 하는 광고가 없는거 닮아
# Input: oh my is this like this for exercise
# Predicted translation: 아이고 운동은 이 운동은
# Input: i dont see you burying it at least well im a daughter who has two different things so im not sure about my mother
# Predicted translation:  ⁇  안보여도  ⁇ 게 . 두개는 딸인데 . 다른 딸이난 .
# Input: lets go lets go
# Predicted translation: 가게 가게
# Input: ohay right why did you learn programming
# Predicted translation: 아 기 ? 아 왜 프로그램을 배웠지 ?
# Input: and i tried that today i gave it to the nurse the flavor of the chips the injeon and the injeolmi
# Predicted translation: 그리고 나 오늘도 그거 먹어봐신디 그 조리조리 그 조미료 맛을
# Input: ill know only when i grow it up but so is it guilty
# Predicted translation: 나 알쿠다 크면만 알쿠다만은예 ? 죄 ?
# Input: but our title name overslept so they always said that they should go to the academy and take it out so its late on the ledger
# Predicted translation: 근데 우리 이름 이 과 과제를 해 가지고 맨날 학원을 다녀야 된댄 .
# Input: there are a lot of accidents like that
# Predicted translation: 그런 사고들이 많이 나부난
# Input: there is a major announcement the manager doesnt even connect i think i called the reporter in person
# Predicted translation: 연결자회도 있네 연결자도 안 하고 인 내가 보는 사람한테 전화 온 거 닮아
# Num of Sample: 70
# Total Score: 3.030076464932344

# %%
# # Bleu example
# from datasets import load_metric

# bleu = load_metric("bleu")
# predictions = [["I", "have", "thirty", "six", "years"]] 
# references = [
#     [["I", "am", "thirty", "six", "years", "old"], ["I", "am", "thirty", "six"]]
# ]
# bleu.compute(predictions=predictions, references=references)

# # Bleu example
# from datasets import load_metric

# bleu = load_metric("bleu")
# #bleu = load_metric('sacrebleu')

# reference = [kor_corpus_test.split()]
# predictions = [translate(eng_corpus_test, transformer, en_tokenizer, ko_tokenizer).split()]

# bleu.compute(predictions=predictions, references=reference)

# %%
# import matplotlib as mpl
# import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'retina'
 
# import matplotlib.font_manager as fm

# fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
# font = fm.FontProperties(fname=fontpath, size=9)
# plt.rc('font', family='NanumBarunGothic') 
# # mpl.font_manager._rebuild()

# %%
# 매 Epoch 마다 제시된 예문에 대한 번역 생성시각화
# for example in examples:
#     translate(example, transformer, en_tokenizer, ko_tokenizer, plot_attention=True)
