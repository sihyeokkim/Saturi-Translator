# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Step-1.-데이터-다운로드" data-toc-modified-id="Step-1.-데이터-다운로드-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Step 1. 데이터 다운로드</a></span></li><li><span><a href="#Step-2.-데이터-정제-및-토큰화" data-toc-modified-id="Step-2.-데이터-정제-및-토큰화-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Step 2. 데이터 정제 및 토큰화</a></span></li><li><span><a href="#Step-3.-모델설계" data-toc-modified-id="Step-3.-모델설계-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Step 3. 모델설계</a></span><ul class="toc-item"><li><span><a href="#Positional-Encoding" data-toc-modified-id="Positional-Encoding-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Positional Encoding</a></span></li><li><span><a href="#Multi-Head-Attention" data-toc-modified-id="Multi-Head-Attention-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Multi-Head Attention</a></span></li><li><span><a href="#Position-wise-Feed-Forward-Network" data-toc-modified-id="Position-wise-Feed-Forward-Network-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Position-wise Feed-Forward Network</a></span></li><li><span><a href="#Encoder-레이어-구현하기" data-toc-modified-id="Encoder-레이어-구현하기-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Encoder 레이어 구현하기</a></span></li><li><span><a href="#Decoder-레이어-구현하기" data-toc-modified-id="Decoder-레이어-구현하기-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Decoder 레이어 구현하기</a></span></li><li><span><a href="#Encoder와-Decoder-클래스를-정의" data-toc-modified-id="Encoder와-Decoder-클래스를-정의-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Encoder와 Decoder 클래스를 정의</a></span></li><li><span><a href="#Transformer-완성하기" data-toc-modified-id="Transformer-완성하기-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Transformer 완성하기</a></span></li><li><span><a href="#Mask" data-toc-modified-id="Mask-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Mask</a></span></li></ul></li><li><span><a href="#Step-4.-훈련하기" data-toc-modified-id="Step-4.-훈련하기-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Step 4. 훈련하기</a></span><ul class="toc-item"><li><span><a href="#Learning-Rate-Scheduler를-선언하고,-이를-포함하는-Adam-Optimizer를-선언" data-toc-modified-id="Learning-Rate-Scheduler를-선언하고,-이를-포함하는-Adam-Optimizer를-선언-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Learning Rate Scheduler를 선언하고, 이를 포함하는 Adam Optimizer를 선언</a></span></li><li><span><a href="#Loss-함수를-정의" data-toc-modified-id="Loss-함수를-정의-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Loss 함수를 정의</a></span></li><li><span><a href="#train_step-함수를-정의" data-toc-modified-id="train_step-함수를-정의-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>train_step 함수를 정의</a></span></li><li><span><a href="#Attention-시각화-함수" data-toc-modified-id="Attention-시각화-함수-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Attention 시각화 함수</a></span></li><li><span><a href="#번역생성함수" data-toc-modified-id="번역생성함수-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>번역생성함수</a></span></li><li><span><a href="#학습" data-toc-modified-id="학습-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>학습</a></span></li></ul></li><li><span><a href="#Step-5.-평가" data-toc-modified-id="Step-5.-평가-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Step 5. 평가</a></span></li></ul></div>

# %%
# np.__version__
# tf.__version__
# !pip install -U numpy
# !pip3 list

# %%
import tensorflow as tf
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

import matplotlib as mpl
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt

import time
import re
import os
import io


# from tqdm import tqdm_notebook 
from tqdm.notebook import tqdm 
import random

import sentencepiece as spm
from konlpy.tag import Mecab

print(tf.__version__)
print(np.__version__)
# Out:
# 2.6.0
# 1.21.4

# %% [markdown]
# # Step 1. 데이터 다운로드

# %%
# train data load
data_dir = os.getenv('HOME')+'/aiffel/aiffelthon/data'
data_train_path = data_dir+"/train_v_final_0310.csv"
data_test_path = data_dir+"/test_v_final_0310.csv"
full_data = pd.read_csv(data_train_path)
full_data_test = pd.read_csv(data_test_path)

# %%
full_data
# Out:
#         reg topic                                                eng  \
# 0        jd    역사                 I've changed my mind a little bit.
# 1        jd    가족    You know what? Foreigners still get used to it.
# 2        jd    건강  All of a sudden, I think I've ripped off my ap...
# 3        jd   스타일  I have a lot of ideas about getting older in a...
# 4        jd   먹거리        It's a little bit of a tastey, but still...
# ...      ..   ...                                                ...
# 1229206  kw    정치  Five hours and the vote's over. That's why I c...
# 1229207  kw    법률  It smells like piss. That's what I'm doing. If...
# 1229208  kw    법률  I'm going to put her in court. Who is it? They...
# 1229209  kw    법률  Oh, my God. Detective Joe, if that's the case,...
# 1229210  kw    법률  You want to finish cleaning the house before t...
#
#                                                       dial
# 0                                           생각이 쪼금씩 바뀌드라고
# 1                                 웜마 알겄는가 애국인들이 그또 달 적응하고
# 2                              아으 갑자기 에전에 맹장 뜯은 게잉 생각난디야.
# 3                   보먼은 좀 품위 있게 나이 들어가야 되겠단 싱각을 참 마이 해요잉.
# 4                             약깐 좀 약깐 맛이가 쪼까 머시기 카긴 한디 그또
# ...                                                    ...
# 1229206  다섯시간만 지나믄 투패가 끝나.  개가주 몬 가서 하튼 지 중국놈들은 어뜬 기 사실...
# 1229207  오즘 내금새 난다고.  그레 하구 앉은 자리데이. 요게가  만일에 그이 삼십 오십으...
# 1229208  그이 년아를 법정에 세울 겁니다.  느그?  지네 자석 굶기면서 옳은 소라리 카는 ...
# 1229209  이그 촌니나.  조 헹사님 그믄 저한데 기횔  여게가 바빨리 길인데  애미한테 인사...
# 1229210  쌔 줸 들어오기 앞전에 집구석키 소제 끝내자는 거겠지.  저래 난릴 칠까 왜서 저럴...
#
# [1229211 rows x 4 columns]

# %%
#for test
full_data = full_data.sample(frac=1).reset_index(drop=True)
full_data = full_data[:10000]
full_data
# Out:
#      reg  topic                                                eng  \
# 0     gs     군대       And we have a lot of seniors in Gyeongsangdo
# 1     jd   반려동물                             Its around 900 or 1000
# 2     gs  회사/학교         Rather I was a little bit from high school
# 3     kw     경제  The first thing you need to learn to do is to ...
# 4     cc     쇼핑                        So you didnt open the door.
# ...   ..    ...                                                ...
# 9995  kw     가족  Well, do you want me to give you a little more...
# 9996  kw     영화                          He saw her mother-in-law.
# 9997  kw     성격  The biggest mistake is trying to be kind beyon...
# 9998  cc    드라마  As it is revealed from the beginning something...
# 9999  kw    드라마        You can't even open your eyes. What's okay?
#
#                                                    dial
# 0                         그러꼬 즈그느 은근히 경상도 선임들이 쫌 많아가주꼬
# 1                                     좀 아홉 시 열 시쯤 들 간게
# 2                                 내느 오히려 고등학교 때를 쫌 계기로
# 3                             저깔질하는 법은 츰에 지대로 배우콰야 한다.
# 4                                        긍까 문을 알은 열었지.
# ...                                                 ...
# 9995  갬 만도보다 사골을 쫌 고아드릴까요?  증말 닐 행복하게 헤 나래비 수 잊을 나래비...
# 9996                                      시어멍이 숭을 보더라.
# 9997                   채고 크다한 실수는 넝력 이상으루 친절하려 노력하는 그니
# 9998                        처음부통 이케 탁 밝혀지면서 인자 뭔가가 이렇게
# 9999                                   눈두 못뜨민서 뭐이 괜찮아?
#
# [10000 rows x 4 columns]

# %%
full_data_test
# Out:
#      reg  topic                                                eng  \
# 0     jd     쇼핑  There's one person over there who's going to b...
# 1     jd  방송/연예  Or they do things like taking money instead bu...
# 2     jd     가족  So its systematically organized even if its no...
# 3     jd     영화  When you go on a cruise why do you rest once i...
# 4     jd     성격  Now everyone knows each other like this but he...
# ...   ..    ...                                                ...
# 1495  kw     문학  Oh go toward Seoksu youre the same as me Would...
# 1496  kw  회사/학교  You did what you wanted with your own money. Y...
# 1497  kw  연애/결혼  Don't you want to know where your wife's gone?...
# 1498  kw     가족  I'm going to lend you money. I don't want to d...
# 1499  kw  연애/결혼  I don't think he trusts you yet. Stay still. A...
#
#                                                    dial
# 0        쩌그 헌 사람은 나이 인자 륙십 세신가 된닥 근게 고칠만 하제 그는 나이가 있응께
# 1     아니믄 대신 돈을 받어 준다거나 이른 껄 한디 인자  뭣하러 여리 마잉 포장을 헐라...
# 2     긍게 허벌 꺠끗하진 않아도 나름 체계적으로 정리가 되야 있어.  난테 마 용돈을 하...
# 3                  크루즈 여행을 가나 보믄 언니야 뭣하러 중간에 헌 번씩 쉬자네.
# 4     인자 다들 니 명이서는 서로 이르케 맨 알고잉 있으야 가 성격을 근디 가한테는 직접...
# ...                                                 ...
# 1495                    가 석수 쪽으루 가요 지랑 같으시네 오눌같이 가실래요?
# 1496  재기 돈으루 하구 싶은 대루 하셨는데 예다 저렇다 이애기할 수완 웂는 일이겠죠.  ...
# 1497  즈 여편내가 없어졌는데 워데 갔나 궁금하지두 않나?  내 증말 장하라우 엄마?  추...
# 1498  낸 돈같은 게 빌려주구 받구 그른 게 싫어.  니 오놀 한가해?  심자랑이 늘어지지...
# 1499  니를 상구 신뢰하지 않는 모냥이니까  잠자쿠 있사.  그래구 이기 지굼 탈수가 된거...
#
# [1500 rows x 4 columns]

# %%
#for test
full_data_test = full_data_test.sample(frac=1).reset_index(drop=True)
full_data_test = full_data_test[:500]
full_data_test
# Out:
#     reg     topic                                                eng  \
# 0    jj  자동차/오토바이  So I jumped into my car and took it right away...
# 1    jj        역사  Its the same in the back and the front is lost...
# 2    gs       SNS  Im planning to release it Isnt there anything ...
# 3    jj      반려동물  There can be a difference in this language I'm...
# 4    jj        가족  I don't know if I'm gonna sit down and eat, an...
# ..   ..       ...                                                ...
# 495  jd        쇼핑  Yeagago I asked where I was and I said I was a...
# 496  cc      콤플렉스  Lets talk and play like this Lets play with th...
# 497  jd        계절        And I'm doing this, but it hurts like hell.
# 498  kw        음악  It's hard to decide on my own. Now theres noth...
# 499  jd       먹거리  I don't like burgers in the morning, but I thi...
#
#                                                   dial
# 0    그래서이 나 차이 걍이 뛰어가가지고 걍이 고짝 빼진  달리는 디 부애가 너무이 나는...
# 1                                   뒷티 허고 앞이가 똑같아부런 요
# 2       발매할 계획이대이 겉은 꺼 올라온대이 아가 뭐~ 고런 꺼 겉은 꺼 챙겨보꼬 있거덩
# 3    요 언어적인게 차이가 날이 수 있는거지게  오늘이 겅해도 집이 성님 계속이 이실 거...
# 4    무신거 시비 걸엉 허진 안하니까 앉앙 먹엉 과자도이?  막이 잘도 된마씸. 울리 옆...
# ..                                                 ...
# 495  가꼬 나가 어디냐 긍께 나가 거즘 맨 왔다야 헜더니 지가 지끔 마틍께 필요헌 거이 ...
# 496  이케 말 걸어주구 검거지 놀자 놀자 오늘 뭐~ 핵교 끝나구 내랑 피씨방 가자구 애덜...
# 497                끄꼬 이르케 허고 있단 말이여 근디 요게 모가지가 흑부 아프네
# 498  나 생각만으로는 결정하기 어룹다.  지굼은 뭐러 그른 달구새끼 집쩍 잡는 것두 없지...
# 499  아칙에 햄버거는 별로긴 한디 넨 야식에 햄버거 괜찮한 거이 같애잉 아칙에 햄버거는 ...
#
# [500 rows x 4 columns]

# %%
# full_data=pd.concat([full_data, full_data_test], axis=0)

# %%
full_data.info() #full_data: 1065918 full_data_test: 500
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   reg     10000 non-null  object
#  1   topic   10000 non-null  object
#  2   eng     10000 non-null  object
#  3   dial    10000 non-null  object
# dtypes: object(4)
# memory usage: 312.6+ KB

# %%
full_data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   reg     500 non-null    object
#  1   topic   500 non-null    object
#  2   eng     500 non-null    object
#  3   dial    500 non-null    object
# dtypes: object(4)
# memory usage: 15.8+ KB

# %%
full_data.isnull().sum()
# Out:
# reg      0
# topic    0
# eng      0
# dial     0
# dtype: int64

# %%
full_data_test.isnull().sum()
# Out:
# reg      0
# topic    0
# eng      0
# dial     0
# dtype: int64

# %%
def del_null_dupl(data):
    data=data.dropna(axis=0)
    data=data[~data.duplicated(subset=['reg','topic','eng','dial'], keep= 'first')]
    data=data.reset_index(drop=True)# index reset하기 - 기존 index 제거 O
    return data

# %%
full_data=del_null_dupl(full_data) # ['text', 'dial', 'reg', 'eng'])
full_data_test=del_null_dupl(full_data_test) # ['text', 'dial', 'reg', 'eng'])

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   reg     10000 non-null  object
#  1   topic   10000 non-null  object
#  2   eng     10000 non-null  object
#  3   dial    10000 non-null  object
# dtypes: object(4)
# memory usage: 312.6+ KB

# %%
full_data['eng_length'] = full_data['eng'].apply(lambda x : len(str(x).split()))
full_data['dial_length'] = full_data['dial'].apply(lambda x : len(str(x).split()))
full_data['eng_c_length'] = full_data['eng'].apply(lambda x : len(str(x)))
full_data['dial_c_length'] = full_data['dial'].apply(lambda x : len(str(x)))

# %%
regs = ['jj', 'jd', 'gs', 'cc', 'kw']

for reg in regs:
    count = full_data['dial'][full_data['reg']==reg].count()
    print(f'Dial_{reg} :', count)
# Out:
# Dial_jj : 2130
# Dial_jd : 1919
# Dial_gs : 1200
# Dial_cc : 1171
# Dial_kw : 3580

# %%
full_data.groupby(full_data['reg'])['eng_length'].mean()
# Out:
# reg
# cc    54.229718
# gs    42.663333
# jd    45.908286
# jj    31.937559
# kw    30.865363
# Name: eng_length, dtype: float64

# %%
full_data.groupby(full_data['reg'])['dial_length'].mean()
# Out:
# reg
# cc    41.768574
# gs    32.968333
# jd    34.186034
# jj    22.130516
# kw    21.626816
# Name: dial_length, dtype: float64

# %%
# eng_data = full_data[['eng', 'eng_length']]
# eng_data

# %%
# dial_data = full_data[['reg', 'dial', 'dial_length']]
# dial_data

# %%
full_data["reg_eng"] = "<" + full_data["reg"] +"> "+full_data["eng"]
full_data["reg_eng"]
# Out:
# 0       <gs> And we have a lot of seniors in Gyeongsangdo
# 1                             <jd> Its around 900 or 1000
# 2         <gs> Rather I was a little bit from high school
# 3       <kw> The first thing you need to learn to do i...
# 4                        <cc> So you didnt open the door.
#                               ...
# 9995    <kw> Well, do you want me to give you a little...
# 9996                       <kw> He saw her mother-in-law.
# 9997    <kw> The biggest mistake is trying to be kind ...
# 9998    <cc> As it is revealed from the beginning some...
# 9999     <kw> You can't even open your eyes. What's okay?
# Name: reg_eng, Length: 10000, dtype: object

# %%
full_data_test["reg_eng"] = "<" + full_data_test["reg"] +"> "+full_data_test["eng"]
full_data_test["reg_eng"]
# Out:
# 0      <jj> So I jumped into my car and took it right...
# 1      <jj> Its the same in the back and the front is...
# 2      <gs> Im planning to release it Isnt there anyt...
# 3      <jj> There can be a difference in this languag...
# 4      <jj> I don't know if I'm gonna sit down and ea...
#                              ...
# 495    <jd> Yeagago I asked where I was and I said I ...
# 496    <cc> Lets talk and play like this Lets play wi...
# 497     <jd> And I'm doing this, but it hurts like hell.
# 498    <kw> It's hard to decide on my own. Now theres...
# 499    <jd> I don't like burgers in the morning, but ...
# Name: reg_eng, Length: 500, dtype: object

# %%
full_data
# Out:
#      reg  topic                                                eng  \
# 0     gs     군대       And we have a lot of seniors in Gyeongsangdo
# 1     jd   반려동물                             Its around 900 or 1000
# 2     gs  회사/학교         Rather I was a little bit from high school
# 3     kw     경제  The first thing you need to learn to do is to ...
# 4     cc     쇼핑                        So you didnt open the door.
# ...   ..    ...                                                ...
# 9995  kw     가족  Well, do you want me to give you a little more...
# 9996  kw     영화                          He saw her mother-in-law.
# 9997  kw     성격  The biggest mistake is trying to be kind beyon...
# 9998  cc    드라마  As it is revealed from the beginning something...
# 9999  kw    드라마        You can't even open your eyes. What's okay?
#
#                                                    dial  eng_length  \
# 0                         그러꼬 즈그느 은근히 경상도 선임들이 쫌 많아가주꼬            9
# 1                                     좀 아홉 시 열 시쯤 들 간게            5
# 2                                 내느 오히려 고등학교 때를 쫌 계기로            9
# 3                             저깔질하는 법은 츰에 지대로 배우콰야 한다.           15
# 4                                        긍까 문을 알은 열었지.            6
# ...                                                 ...         ...
# 9995  갬 만도보다 사골을 쫌 고아드릴까요?  증말 닐 행복하게 헤 나래비 수 잊을 나래비...          62
# 9996                                      시어멍이 숭을 보더라.            4
# 9997                   채고 크다한 실수는 넝력 이상으루 친절하려 노력하는 그니           11
# 9998                        처음부통 이케 탁 밝혀지면서 인자 뭔가가 이렇게           12
# 9999                                   눈두 못뜨민서 뭐이 괜찮아?            8
#
#       dial_length  eng_c_length  dial_c_length  \
# 0               7            44             29
# 1               7            22             17
# 2               6            42             21
# 3               6            75             25
# 4               4            27             14
# ...           ...           ...            ...
# 9995           39           301            157
# 9996            3            25             13
# 9997            8            61             32
# 9998            7            68             27
# 9999            4            43             16
#
#                                                 reg_eng
# 0     <gs> And we have a lot of seniors in Gyeongsangdo
# 1                           <jd> Its around 900 or 1000
# 2       <gs> Rather I was a little bit from high school
# 3     <kw> The first thing you need to learn to do i...
# 4                      <cc> So you didnt open the door.
# ...                                                 ...
# 9995  <kw> Well, do you want me to give you a little...
# 9996                     <kw> He saw her mother-in-law.
# 9997  <kw> The biggest mistake is trying to be kind ...
# 9998  <cc> As it is revealed from the beginning some...
# 9999   <kw> You can't even open your eyes. What's okay?
#
# [10000 rows x 9 columns]

# %%
full_data_test
# Out:
#     reg     topic                                                eng  \
# 0    jj  자동차/오토바이  So I jumped into my car and took it right away...
# 1    jj        역사  Its the same in the back and the front is lost...
# 2    gs       SNS  Im planning to release it Isnt there anything ...
# 3    jj      반려동물  There can be a difference in this language I'm...
# 4    jj        가족  I don't know if I'm gonna sit down and eat, an...
# ..   ..       ...                                                ...
# 495  jd        쇼핑  Yeagago I asked where I was and I said I was a...
# 496  cc      콤플렉스  Lets talk and play like this Lets play with th...
# 497  jd        계절        And I'm doing this, but it hurts like hell.
# 498  kw        음악  It's hard to decide on my own. Now theres noth...
# 499  jd       먹거리  I don't like burgers in the morning, but I thi...
#
#                                                   dial  \
# 0    그래서이 나 차이 걍이 뛰어가가지고 걍이 고짝 빼진  달리는 디 부애가 너무이 나는...
# 1                                   뒷티 허고 앞이가 똑같아부런 요
# 2       발매할 계획이대이 겉은 꺼 올라온대이 아가 뭐~ 고런 꺼 겉은 꺼 챙겨보꼬 있거덩
# 3    요 언어적인게 차이가 날이 수 있는거지게  오늘이 겅해도 집이 성님 계속이 이실 거...
# 4    무신거 시비 걸엉 허진 안하니까 앉앙 먹엉 과자도이?  막이 잘도 된마씸. 울리 옆...
# ..                                                 ...
# 495  가꼬 나가 어디냐 긍께 나가 거즘 맨 왔다야 헜더니 지가 지끔 마틍께 필요헌 거이 ...
# 496  이케 말 걸어주구 검거지 놀자 놀자 오늘 뭐~ 핵교 끝나구 내랑 피씨방 가자구 애덜...
# 497                끄꼬 이르케 허고 있단 말이여 근디 요게 모가지가 흑부 아프네
# 498  나 생각만으로는 결정하기 어룹다.  지굼은 뭐러 그른 달구새끼 집쩍 잡는 것두 없지...
# 499  아칙에 햄버거는 별로긴 한디 넨 야식에 햄버거 괜찮한 거이 같애잉 아칙에 햄버거는 ...
#
#                                                reg_eng
# 0    <jj> So I jumped into my car and took it right...
# 1    <jj> Its the same in the back and the front is...
# 2    <gs> Im planning to release it Isnt there anyt...
# 3    <jj> There can be a difference in this languag...
# 4    <jj> I don't know if I'm gonna sit down and ea...
# ..                                                 ...
# 495  <jd> Yeagago I asked where I was and I said I ...
# 496  <cc> Lets talk and play like this Lets play wi...
# 497   <jd> And I'm doing this, but it hurts like hell.
# 498  <kw> It's hard to decide on my own. Now theres...
# 499  <jd> I don't like burgers in the morning, but ...
#
# [500 rows x 5 columns]

# %%
type(full_data['dial'][0])
# Out:
# str

# %%
# # 1. 모든 입력을 소문자로 변환합니다.
# # 2. 알파벳, 문장부호, 한글만 남기고 모두 제거합니다.
# # 3. 문장부호 양옆에 공백을 추가합니다.
# # 4. 문장 앞뒤의 불필요한 공백을 제거합니다.

def preprocess_sentence(sentence):

    length = len(sentence)
    match = re.search(r'(.+)\1{3,}', sentence) 
    if match or length == 0:
        return None

    sentence = sentence.lower()
    sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
    sentence = re.sub(r'[" "]+', " ", sentence)
    sentence = re.sub(r"[^a-zA-Z?.!<>가-힣ㄱ-ㅎㅏ-ㅣ]+", " ", sentence)
    sentence = sentence.strip()

    return sentence

# %%
# encoder corpus
enc_corpus = full_data['reg_eng'].apply(lambda x : preprocess_sentence(x)).sort_index()

# %%
# encoder test corpus
enc_corpus_test = full_data_test['reg_eng'].apply(lambda x : preprocess_sentence(x)).sort_index()

# %%
# 지역별 평가를 위해 분리
# 지역별 encoder test corpus 
enc_corpus_test_jj = full_data_test['reg_eng'][full_data_test['reg']=='jj'].apply(lambda x : preprocess_sentence(x)).sort_index()
enc_corpus_test_jd = full_data_test['reg_eng'][full_data_test['reg']=='jd'].apply(lambda x : preprocess_sentence(x)).sort_index()
enc_corpus_test_gs = full_data_test['reg_eng'][full_data_test['reg']=='gs'].apply(lambda x : preprocess_sentence(x)).sort_index()
enc_corpus_test_cc = full_data_test['reg_eng'][full_data_test['reg']=='cc'].apply(lambda x : preprocess_sentence(x)).sort_index()
enc_corpus_test_kw = full_data_test['reg_eng'][full_data_test['reg']=='kw'].apply(lambda x : preprocess_sentence(x)).sort_index()

# %%
# decoder corpus
dec_corpus = full_data['dial'].apply(lambda x : preprocess_sentence(x)).sort_index()

# %%
# decoder corpus test
dec_corpus_test = full_data_test['dial'].apply(lambda x : preprocess_sentence(x)).sort_index()

# %%
# 지역별 평가를 위해 분리
# 지역별 decoder test corpus 
dec_corpus_test_jj = full_data_test['dial'][full_data_test['reg']=='jj'].apply(lambda x : preprocess_sentence(x)).sort_index()
dec_corpus_test_jd = full_data_test['dial'][full_data_test['reg']=='jd'].apply(lambda x : preprocess_sentence(x)).sort_index()
dec_corpus_test_gs = full_data_test['dial'][full_data_test['reg']=='gs'].apply(lambda x : preprocess_sentence(x)).sort_index()
dec_corpus_test_cc = full_data_test['dial'][full_data_test['reg']=='cc'].apply(lambda x : preprocess_sentence(x)).sort_index()
dec_corpus_test_kw = full_data_test['dial'][full_data_test['reg']=='kw'].apply(lambda x : preprocess_sentence(x)).sort_index()

# %%
enc_corpus_test_jj
# Out:
# 0      <jj> so i jumped into my car and took it right...
# 1      <jj> its the same in the back and the front is...
# 3      <jj> there can be a difference in this languag...
# 4      <jj> i don t know if i m gonna sit down and ea...
# 14     <jj> its okay if its good there was something ...
#                              ...
# 472    <jj> so the tangerines have just fallen if you...
# 474           <jj> should i wear a beret not this time ?
# 488    <jj> apython its a taxi when everyone comes ou...
# 492    <jj> don t just put it together and throw it a...
# 494    <jj> but since i cant just wear things like th...
# Name: reg_eng, Length: 103, dtype: object

# %%
dec_corpus_test_jj
# Out:
# 0                                                   None
# 1                                      뒷티 허고 앞이가 똑같아부런 요
# 3                                                   None
# 4      무신거 시비 걸엉 허진 안하니까 앉앙 먹엉 과자도이 ? 막이 잘도 된마씸 . 울리 ...
# 14     좋으면이 되수다예 오해 받주게 않으젠 한 꺼도 있고이 거 경헌디 가볼 디가 무신거 ...
#                              ...
# 472    그난 미깡이 막이 털어젼 영허민 어떵행 털어젼마씸 하믄 인제 물어봐마씸 . 거 땡땡...
# 474                         베레모 썽 하카 ? 아님 요번엔 이거이 썽 허카 ?
# 488    아파튼 다이 나왐서야 택시난 길가애란 사롬덜도 엇고 어우 겡 암튼 요 아이 못 먹어...
# 492    걍 모다들엉 불지 말앙 가이드라인 안에서이 놀 수 있주게 해줘사야 하는디 걍 요 버...
# 494              경한디 너무이 경헌 거만 입힐 수 어시난 인제 가당 무신거 아디다스 .
# Name: dial, Length: 103, dtype: object

# %%
# enc_corpus 통계

min_len = 999
max_len = 0
sum_len = 0


for sen in enc_corpus:
    length = len(str(sen))
    if min_len > length: min_len = length
    if max_len < length: max_len = length
    sum_len += length

print("문장의 최단 길이:", min_len)
print("문장의 최장 길이:", max_len)
print("문장의 평균 길이:", sum_len // len(enc_corpus))

sentence_length = np.zeros((max_len), dtype=int)

#총 max_len의 배열을 만든 후, raw 문장을 돌면서 각 문장별 길이를 sentence_length의 len(sen) 인덱스마다  계속 더해가면서 counting
for sen in enc_corpus:
    sentence_length[len(str(sen))-1] += 1

plt.bar(range(max_len), sentence_length, width=1.0)
plt.title("Sentence Length Distribution")
plt.show()
# Out:
# 문장의 최단 길이: 4
# 문장의 최장 길이: 3881
# 문장의 평균 길이: 193

# %%
dec_corpus_test
# Out:
# 0                                                   None
# 1                                      뒷티 허고 앞이가 똑같아부런 요
# 2           발매할 계획이대이 겉은 꺼 올라온대이 아가 뭐 고런 꺼 겉은 꺼 챙겨보꼬 있거덩
# 3                                                   None
# 4      무신거 시비 걸엉 허진 안하니까 앉앙 먹엉 과자도이 ? 막이 잘도 된마씸 . 울리 ...
#                              ...
# 495    가꼬 나가 어디냐 긍께 나가 거즘 맨 왔다야 헜더니 지가 지끔 마틍께 필요헌 거이 ...
# 496    이케 말 걸어주구 검거지 놀자 놀자 오늘 뭐 핵교 끝나구 내랑 피씨방 가자구 애덜이...
# 497                   끄꼬 이르케 허고 있단 말이여 근디 요게 모가지가 흑부 아프네
# 498    나 생각만으로는 결정하기 어룹다 . 지굼은 뭐러 그른 달구새끼 집쩍 잡는 것두 없지...
# 499    아칙에 햄버거는 별로긴 한디 넨 야식에 햄버거 괜찮한 거이 같애잉 아칙에 햄버거는 ...
# Name: dial, Length: 500, dtype: object

# %%
# dec_corpus 통계

min_len = 999
max_len = 0
sum_len = 0


for sen in dec_corpus:
    length = len(str(sen))
    if min_len > length: min_len = length
    if max_len < length: max_len = length
    sum_len += length

print("문장의 최단 길이:", min_len)
print("문장의 최장 길이:", max_len)
print("문장의 평균 길이:", sum_len // len(dec_corpus))

sentence_length = np.zeros((max_len), dtype=int)

#총 max_len의 배열을 만든 후, raw 문장을 돌면서 각 문장별 길이를 sentence_length의 len(sen) 인덱스마다  계속 더해가면서 counting
for sen in dec_corpus:
    sentence_length[len(str(sen))-1] += 1

plt.bar(range(max_len), sentence_length, width=1.0)
plt.title("Sentence Length Distribution")
plt.show()
# Out:
# 문장의 최단 길이: 2
# 문장의 최장 길이: 2128
# 문장의 평균 길이: 99

# %%
len(enc_corpus)
# Out:
# 10000

# %%
len(dec_corpus)
# Out:
# 10000

# %%
# #훈련 및 테스트셋 분리
# enc_corpus=enc_corpus[:-100]
# enc_corpus_test = enc_corpus[-100:]
# dec_corpus=dec_corpus[:-100]
# dec_corpus_test = dec_corpus[-100:]

# %%
# print(enc_corpus.shape)
# print(enc_corpus_test.shape)
# print(dec_corpus.shape)
# print(dec_corpus_test.shape)

# %% [markdown]
# # Step 2. 데이터 정제 및 토큰화

# %%
# Train 데이터 정제 및 토큰화
def clean_corpus(enc_corpus, dec_corpus):

    assert len(enc_corpus) == len(dec_corpus) # enc_corpus, dec_corpus가 같은 갯수라는 것을 검증받기 위해 적용

    cleaned_corpus = list(set(zip(enc_corpus, dec_corpus)))  # 중복된 데이터 제거
    
    return cleaned_corpus

cleaned_corpus = clean_corpus(enc_corpus, dec_corpus)
len(cleaned_corpus)
# Out:
# 10000

# %%
cleaned_corpus
# Out:
# [('<kw> why are you here ex wife ?', '근디 왜서 요 전처가 . 아따 혹예'),
#  ('<cc> i m trying to take the lead . i m still healthy enough .',
#   '앞장설라 그려 아직두 내 충분히 건강하다구'),
#  ('<kw> i don t have any air .', '아문 풍취두 음싸 .'),
#  ('<jj> even if youre going to sell it again', '되팔잰해도'),
#  ('<jd> you don t have to look at me like that . you don t have to look at me like that . you don t have to look at me like that .',
#   '굳이 마잉 너무 눈치 마잉 그렇고 볼라고 하도 않고잉 그른 내잉 일날 하믄서'),
#  ('<gs> they go to their house and exchange useless gifts',
#   '즈그 지베이 가가 가주꼬 씨잘데기없느 선물 교환하는데 근꼬'),
#  ('<cc> ita is unless it hurts ive been doing it for years',
#   '아프지만 않으믄 된다 나가 나가 멫 년 전부통 그니까는 내는'),
#  ('<gs> im more practical than designing', '지느 쫌 더 디자인 이른 거보대이 실용적'),
#  ('<jd> i hid not living for a long time but ive been having a hard time and living a lot .',
#   '지가 벌로 오래에 살아온 거는 아닌디 쩌 모 고생 억수로 드럽게 마이 허고 살아왔어요잉 .'),
#  ('<gs> who knows how you can be cursed at there too and honestly you can be cursed at there . as a person who has been using it for a long time i dont think i like this function a little bit . you don t care what i do you rip each other s throats like this . but what is it how many is it it was hard to see a little bit because of that i floated all the spools . if you lose fat youll get weak weight .',
#  ('<jj> i dant adjust to the lag', '시차적응이 안되가지고'),
#  ('<cc> its really sad like its saying sad to the person who is going to part .',
#   '이별하는 사람으 맞춰서 슬프라구 허는 말인 거처럼 진자 슬픈 겨 .'),
#  ('<kw> chariots were crowded .', '전차는 지법 혼잡했어 .'),
#  ('<jj> that way let me stay silent', '그추룩 해그네 저 묵허게 해그네 허라'),
#  ('<cc> there s not a lot like that between the two of them .',
#   '얘네 둘이 혀 형제간끼리는 그른 기 벨로 음써 응 그른 기 벨로 없드라구 근디'),
#  ('<jd> so after more than ten years of marriage after fifteen years of marriage',
#   '긍게 결혼 요잉 시 년 넘게 헌 요잉 시 년 요잉 시 아따 주년 넘어졌다며'),
#  ('<kw> you re throwing up on me ?', '시방 즈 말에 토다는 것이다요 ?'),
#  ('<kw> i have to come with you . i didn t come with you . what happened to you ?',
#   '승규이가 매치루 와야 되는디 매치루 아이 왔으니 나가 뭐이 일이 있어가 왔는지'),
#  ('<gs> i was a little scared when i was grumbling when i was sleeping i was afraid that i would fall out when i slept and lose it',
#   '대께 땐 낄려니께 쫌 무섭더라고예 대께 땐 빠질꼬 봐래이 빠져가 분실될꼬 봐래이 무서워가'),
#  ('<jd> you have to put importance on homosexuals so',
#   '그른 동성애자 그른 거이 중시해야 되고잉 중시 긍까'),
#  ('<jd> ever since i was a little girl', '어렸을 때부터 이르케 좀 난'),
#  ('<cc> its too hot in summer so i dont want to go outside and if i go outside i have limited clothes to take off . i feel like i do . its not obscured by japan anymore so the sea itself is open i dont prefer it that much . i think it s cool and i ve got a lot of air conditioning on and i don t think it s easy to move around . im glad that i grew up now but i think i had a hard time when i was young .',
#   '여름에는 너머 더워 가주구 밲이 나가기가 싫구 밲이 당가면은 옷을 벗는 데도 한정적이잖아 . 그른 느낌이 드는 꺼 같여 . 인자 일본 겉은 디이 가려져 있제 않혀 가주구 쫌 널 넓게 탁 트인단 말이여 바다 자체가 그르케 선호하는 편은 아니구유 . 아무래두 시원하구 에어컨도 마이 켜두구 하니께 워디 밲이 돌아다니기도 쉽지 않구 그서 지끔 커가지구 그나마 다행을루 인자 지끔은 쫌 괜찮드라구 근디 어렸을 땐 검거지 겁나 고생했지 .'),
#  ('<gs> the machine is boiling it with curls by pressing a button like this these days',
#   '기계가 요줌 이케 버튼 눌러 가주구 뽀글이 있다이가 뽀글이 고걸로 끓이느 긴데'),
#  ('<jj> i cant walk after leg surgery', '가달 수술 행 걷주게 못 행 해보난'),
#  ('<jj> i think i would have ground beans and beets too .',
#   '콩이영 비트도 갈곡 해실꺼여 .'),
#  ('<kw> how long has it been ?', '아유 못써 수짱 두둑하게 생각하노 인자 얼매 됐어 ?'),
#  ('<kw> i m not trying to stop you .', '나 느 몽사 말릴 생가 없어 .'),
#  ('<jd> i saw that it was shortened to five minutes there are suspicions about whether its a really perfect truth or not i think i was shocked like this . that s good for you . that s good for you guys . theres that charm when you look at him and theres that charm when you look at him oh yeah at first but . . .',
#  ('<jd> i told you i only told you and started talking like this',
#   '나가 니한테만 말짝 헌다 이럼서 이르케 말을 시작을 하자녀 그랑꼬'),
#  ('<gs> who doesnt do it next to you', '누가 옆에 사람도 해주지마느 그느'),
#  ('<jj> lets buy fruits and go in and lets go to us now .',
#   '호꼼 과일 상 들어가자는 식으로이 해가지고 인제 우리신디 이젠이 갔단 오자 .'),
#  ('<gs> its only in busan .', '부산에마 있었느 점이드라고예 .'),
#  ('<jj> oh my what should i do ?', '어머 어떻게 해 ?'),
#  ('<kw> your arm s so tight that it s falling off your kid s arm .',
#   '팔이 아따 아의 팔을 아쭈 툭 떨어지게 땡기잖소'),
#  ('<cc> so when you wear this it goes well together',
#   '긍까 게 유 쫌 입어주구 핬을 띠 어울리구 하믄은'),
#  ('<gs> there s got to be some hard stuff right ?', '쫌 빡센 부분도 있겠죠 ?'),
#  ('<jd> and when i think about it i m not exactly the kind of person who wears a lot of perfume so it hurts my head .',
#   '생각혀 봉게 난 그닥 이케잉 향수를 마이 쓰는 싸람이 아니었거든 향수 쓰믄 머리가 아프드라고'),
#  ('<jj> i think it suits soybean paste rather than salt or soy sauce',
#   '다른거 무신거 소금이나 간장보다는 된장이요 호꼼 어울리는거 닮더라고이'),
#  ('<kw> i don t know what to do with you yet .', '상구 닐 우떻게 할지 판단이 아이 서 .'),
#  ('<gs> she they escorted from the back and the women stood in the middle',
#   '어 앞에 뒤에서 인지를 호위를 카꼬 여자들은 인대이 중간에 스꼬'),
#  ('<jj> we married a little late but my older child is',
#   '울리 울리 거 울리 거 장게 호솔 느지막이 해신디 울리 흘근 아이도양'),
#  ('<kw> my dads car has parking on the rear side',
#   '주차를 후면 주차두 읊어 가주구 울 아부지 차가'),
#  ('<jj> that s cute . isn t that self involved ? if the house is here for my mom and dad i m just gonna keep coming back and forth and then i m gonna . . . it should have been raining . geji is so there are many sayings to guess its similar yes theres that one the bag youve been using since you were a baby is yours because youre kidding me baking it like this oh i breathed after i said hap the cat thought he was muscling himself ? youh have to feed them but when its lunchtime for children we know her we talk the most and thats when we talk the most its better if its like a daejeong',
#   '귀여운게 거 지 생업이 있주게 안허꽈 ? 집이가 이디 우리엄마 아방 사는 집이믄 계속이 막이 뒤척뒤척 해부난 비 와나야 되여 조지는 거고이 게난 맞히라는 소리가 많은디 비슷하쥬 어 그런거가 이서 애기 때부터게 써당 가방이 형아 써당 거 지가 쓰난 장난헌댄 영 굽어그네 막이 영영햄시난 아게 허라 부난 숨 쉬니까는 고냉이가 합 지신디 하악질을 허는 중 아이 거 ? 어게 거 딱 밥을 딱 멕여야 왜냐민 근디 아이돌 점심시간 된 보믄 우리도게 성님 아네 젤 말 허영 허고 아맹해도 거 때가이 대정 곹으민 아사리 나은디'),
#  ('<kw> everyone i care about is leaving me .',
#   '내 특벨히 생각하는 사램들은 마카 내를 떠나거든요 .'),
#  ('<jd> poor ? why are people tangled at first when we met with lee hyorirang and lee sangsoon so i went to seoul and was there but we re over million now so i m trying to figure out if i m going to have to lower my equilibrium . what if you re a man and you re a man ? ive been selected more than a hundred times and now im not married and i get scolded by my father a lot',
#   '짠해요 ? 그 인냐 그 이효리랑 이상순이랑 이르케 맨날 띠 첨에 싸람들이 엉 오메 뭣하러 긍게 난 인자 공부한다고 서울 가가지고 인자 서울 가 있었고잉 근디 지끔 삼억 넘는다 긍께 평수를 쫌 더 쭐여야 대나 어찌나 고민 중이야 . 혹씨 남자도 겹쳐 블면 어떡하냐 ? 빽 분 넘게 선 봐보고 인자 결혼을 안 한닥 아부지한테 혼도 마이 나고잉'),
#  ('<cc> oh health is so precious', '아 역시 건강이 참 게 소중하다는 긋을'),
#  ('<jd> so its really good to do it when its cold and when its hot',
#   '근까 긍게 이거이 추울 땐 춥고 더울 땐 더웁고 허는 거이 개 조요운 건디'),
#  ('<gs> are you interested in that ?', '니느 혹시 고런 부분에 대해서느 뭐 관심 있나 ?'),
#  ('<jj> a day of personal opinion .', '개인의견 하멍 한 날이'),
#  ('<kw> what am i doing ? open it up .', '내 뭐하나 빠빠빨리 열어 .'),
#  ('<kw> just pretend to do it without sincerity . she hasn t kissed me yet not even on her cheek . all right let s go . how d you get along ? you re living in the same neighborhood again ? i ll do it later . you want me to build you a hospital day care ? i thought you d buy some for three stars . don t make me trash with a few bucks .',
#   '성의움씨 하죠 하는척만 . 쟈 여적지 뽀뽀 한번을 아이 해주잖아요 뺨에두 이란 제길 위치가 파악 됐 돼싸 어푸 가요 어푸 . 상간 쫌 돈독해졌니 ? 또 거튼 동니 살게 됐네요 ? 내 냉중에 . 내 벵원이라두 지어줘 탁아소 ? 아부님이 벨 셋이면 워느 정돈 사타구 게 같아서 . 이깐 쐬푼 메 푼으로 나까정 씨레모이 맨들지 말고 .'),
#  ('<gs> since there is no string there is a string and its a little big so i was bothered to buy it because i was pushed back',
#   '그 끈이 없은 꺼니께 요거느 끈도 있고이 쫌 크니께 산다꼬 굳이 내 카다가 내 밀리가 귀찮아갖꼬'),
#  ('<cc> let s go home . we didn t eat dinner . we just went home .',
#   '집이나 가자 혀 가주구 저녁 알은 묵구 그냥 집 갔잖아유 .'),
#  ('<cc> i wope you can follow me as well if i try this and that little by little . i went on a trip to rest and i didnt like to go around like this after seeing this and that teams so other teams in their league you guys will probably be surprised when they go to a drama oh anyway is it because there are a lot of miscarriages on the roadside its too noisy because there arent many cars and there are many motorcycles what are you going to do or not this is how you do it',
#   '이것저것 쪼금씩 응 다양히 쫌 먹어보는 꺼 니도 쫌 따라줬으면 좋겄어 . 쉬러 여앵을 갔는디 검거지 이것 보러 저것 보러 이케 부랴부랴 검거지 이케 댕기는 기 쪼꼼 싫어서 팀 긍까 지 리그이 있는 따른 팀이 있는 따른 느들 아마 드라마 가믄 깜작 놀랠 꺼다 오 하튼 간 오도바이가 많아가지구 겅가 그 도로변은 너머 시끄럽긴 혀 차는 벨로 읎구 오토바이가 많어 가주구 이런거나 머 헐 겨 말 겨 유 쩡도 핸다 하'),
#   '벵원 댕겨오는 시융이라두 쳐야 임신 얘길 알 게 아이나 ?'),
#  ('<kw> i m sure we re going to start a business .', '성업할 기 틀림없어 .'),
#  ('<jd> he should go to his seeds and cut down the tree .',
#   '고놈은 나무를 씨 친정 가가지고 비어 불어야것다 .'),
#  ('<jd> perhaps because of that harry boche cant do it and something is now',
#   '아마 그른 꺼 때매 해리 보슈는 안되고 또잉 무언가가 이자'),
#  ('<jj> how did you take it out ?', '어떻게 행 빼여 ? 게'),
#  ('<jd> now if the years go by', '이자 세월이 흘러 가 버리믄'),
#  ('<jd> depending on what i eat the health of my body depends on it .',
#   '나가 어뜬 걸 먹느냐에 따라서 내잉 몸의 건강도 모 거따가 에 으해서 좌우되기도 허고'),
#  ('<jj> yeah you should thank your grandchildren for that .',
#   '맞아 . 손지보민 손지 봥 고맙댄을 해사주 .'),
#  ('<kw> you ll see later . it s an honor . while i m at work i m gonna have to pay attention to my every move . what s the point of knowing ? oh my mom s still doing great because grandmothers are walking the most important thing . why are you playing with her ?',
# ...
#   '그기 글런데 함 알잖아예 랑 동물 병원 돈 겁나 씨께 받꼬 왈가왈부 칼 필요도 없은 기꼬 강아지를 키우느 그느 언제든둥 우리가잉 생각해가지꼬 쪼깨 더 커야 되는데 쫌 내 바라느 그 뭐 키가 핸 백육십사 정도가 걍 이쁜 꺼 겉그등 힐 신어도 이쁜 꺼 겉꼬 데 내느 아 점막 점막이 막 띵띵 달아 붓 사람들 거진 없드래이 거진 없으니께네 뭐 춥은데 뭐 꼬 사람들 꼬 뭐 앉아 있을 일또 엄꼬 내나 그래이 함 해보대이 . 마 걍 온천지를 이케 난리를 피워놨더라구예 . 그라면은 뭐 친구들 중에느 강아지를 키우느 사람 없나 그래 만내가 놀아도 좋을 꺼 같은데 ? 저래 저래 카꼬 있노 싶을 때가 있드라꼬 아이 그래이 내나 품에 알았느 삼십 분 안키갖꼬 콧바람 식식 내불민시 그라면은 혹시 키울 생각 있나 ?'),
#  ('<kw> i saved some money with your mom and yes rags',
#   '내 니 어머이랑 잉 넝매로 돈으 쫌 모톼'),
#  ('<cc> i think we should understand the other persons mind and give him a new idea . well it s a little expensive but i bought it for won which was said to be on sale . yes i liked it . so i think we re going to have a lot of gifts now that we re going to give them to girls or we re going to give them to family . this year i was at home without going anywhere on chuseok due to covid . well theres something in mind thats just holding one by one . i think it would be good so i have some time to give me',
#   '쌔 생각 상대방의 마음도 쫌 이해하구 쥐여 되것구나 이른 생각을 들어 . 뭐 쫌 비싼 건디 세일했다구 핸 오십만 완 주구유 사 주드라고유 그려 게 좋았구 그서 아무래두 선물을 마이 인자 지지배들헌티 주던지 아니믄 가족헌티 주던지 허기 땜이 올해는 코로나로 인해서 추석이 아무데도 가덜 않구 집이 있읐잖아 . 머 게 마음속이 게 그양 하나썩 품구 있는 꺼 있잖아 . 좋을 꺼 겉은 생각을 들으 그서 그리구 냉거지 나보러 주어진 시간들을 쫌'),
#  ('<jj> in the past there was nothing like that so did you use pesticides',
#   '옛날엔게 요 경헌 게 쩌런 거 어시난 농약을 해시냐'),
#  ('<kw> let s do the rest tomorrow . i don t have much trouble with that . why do you have a towel on your head ? i just moved in . who did you fight with and you got a bruise in your face ? he appeased the two men who were fighting and reconciled them . i haven t helped anything in the past . i ve been looking at you and i don t look at you . which companys tv is from ? that kimbab must have been hurt . yeah but i didn t mean to lie because i haven t been married for three months . what are you doing ? it s two o clock tomorrow afternoon isn t it ? i don t think it s a little bad about that part because the whole thing is swearing together . so you can imagine you re going to be the boss later ? the two attack each other with all their might . the battle has not been resolved . she s getting close to you and you re gonna have to give her a break . i don t even have time to think about my future . would you really do that for me ? let s go get some rabbits . it s a holiday so there s too many lines . it s a long desk . that ship went out to sea yesterday . should i have it dismissed ? his face is bloodless and yellow .',
#   '나문지는 올제 하자 . 그이 일레 관해서는 벨루 지장 없어 . 대그빡에 씻개을 왜서 뒈쓰니 ? 얼매 앞전에 이새 왔습니다 . 누그랑 싸웠길래 얼구리에 싱검가 생겼나요 ? 싸우고 있슬 두 인두꺼비을 달룡어 화해시켰다 . 그이 동세 아문 것두 도와준 기 읊어 니들 볼라니 멘목이 없구나 . 댁에 티브이는 워느 해사 제품이죠 ? 그이 짐밥은 상했을 거 같아 . 그렇긴 헤 하지마 악의가 있슬 거짓뿔은 아니었어 결혼하기까지 안주 삼 개월이나 남았잖아 . 지굼 머이하고 있아요 ? 올제 오후 두시까지 맞지 ? 전체가 매치루 요그 먹으이까 그이 부분에 대해선 증말 좀 아이 존 게 같애 . 그래가주 니는 니가 냉중에 사장이 되사 있슬 길 상상하라우 본다고 ? 쌍방이 전력을 다하여 서루 공격하다 . 싸운 감정이 상그두 풀리지 않고 있다 . 여동상이 옆에서 자꼬 깝짝거리는데 함 혼을 내줘야지 . 지 미래를 위하라우 고민하는 시간조차 아꽈요 . 내를 위하라우 증말 그닷하게 해주겠어요 ? 울 퇴껭이 밥주러 가자 . 명절이니까 가질두 있어야죠 . 그이 책상은 지럭지가 길사 . 그이 배는 어재 바다로 나갔어 . 해치워 뿌까 ? 얼구리이 핏기가 음꼬 노르께하다 ? .'),
#  ('<kw> grandma doesn t like chinese food . you feel it don t you ?',
#   '할머이 중국움석 안좋아하잖아 느끼하다구 그치 ?'),
#  ('<jj> is it okay ?', '되쿠가 ?'),
#  ('<jj> i just said that when i didn t read white bread and let it go .',
#   '백빵 아이 읽고이 걍 냅둔다고 허멍 막이 겅 말했언 .'),
#  ('<jj> oh i told you yesterday that i went to a red house in sinjeju .',
#   '아게 나맨 어짓께 신제주 벌겅헌 정시집 갔댄 했네 .'),
#  ('<kw> the grown ups think they re getting married .', '으런들은 겨론하는 껄로 알구 계셔서'),
#  ('<kw> when s your flight time ?', '쇠꼽새 탑승 시간은 언제입니까 ?'),
#  ('<kw> looks like summer s here .', '더와 비는 기 여름이 왔나 보다 .'),
#  ('<kw> i m just saying let s see .', '이기 보자보자 하이까 .'),
#  ('<kw> okay dad .', '아랐싸요 아바이'),
#  ('<cc> if you ask him to pay for this when all life becomes like this he has to make some time to spare',
#   '머 삶이 다 게 디는 껄 이골 어떡하느냐구 벌라구 하믄은 머 벌어서 어는 쩡도 여유가 생겨야지'),
#  ('<cc> i m just gonna go check on him .',
#   '그라갖구 인자 아 그냥 지 볼게유 이러믄서 인자 보러 갔지 .'),
#  ('<jj> if there is nothing i can say i would be like that so even in that situation',
#   '나이 내세울 수 이신 뭔가가 없다민 나라도 경할꺼 닮은 거라 나이 거 사정이라도 겐'),
#  ('<jd> i want to live a life where i find happiness even in a little trivial thing',
#   '좀 사소한 거에서도 행복을 뒤지시로 싸는 삶을 살고잉 싶은디'),
#  ('<jj> so i just took out one for dp .', '겅행 걍 디피용 하나 썩 빼놓네 . 나옵서'),
#  ('<cc> i think its okay and theres the center director here so he doesnt leave the department until he leaves .',
#   '괜잖은 꺼 같은디 그리구 요기 센터장님이 계셔 긍까 대빵 유 부서이 유 분이 퇴근할 때까정 다 퇴근 알은 혀 .'),
#  ('<jd> so that s when um . . .', '긍게 그땐 음'),
#  ('<gs> yeah anyway lets think about dyeing a little more .',
#   '그래이 무튼 염색은 쪼깨 더 고민을 해보느 걸로 하대이 .'),
#  ('<kw> where are you talking about the answer .', '지굼 어데서 만 대답질이야 확 .'),
#  ('<gs> in the end in the case of complex you may think that your heart is at stake this is also a complex personality now if you just directly read it at that age it will become a big mountain can i ask you what it is so what made you decorate it i haven t been to any other sports and i have a house near the river . what should i do ? is it his own fashion like your friend im among my friends wee are getting along well and were still very close anyway it was like that but i only gained belly fat then the hard stories that people s feelings are a little bit more likely to do that there are some things that i have to do so about that',
#   '결국에느 컴플렉스 겉은 경우에느 인대이 내나 본인의 맘이 걸려있는거라꼬 인대이 생각할수도 있지만은 요고도 도 인대이 예 성격이 쫌 콤플렉스인데 인대이 꼬 나이대에서 걍 직독 직해를 해뿜 컨 산이라느 되 이름이 된대이 부리니께 쫌 약깐 어뜬 건지를 물어봐도 되노 꾸미께 됐느 계기가 뭐꼬 걍 다른 운동은 알았느 가봤꼬 도 집이 강변 근처에 있어가 예 어트께 캐야 되는데 ? 그 없대이 때만의 지를 때만의 그른 어뜬 패션인가 니 친구맨치로 내도 내나 이기 중에 그 인대이 서로 대께 풀꼬 인대이 쫌 지끔도 짐 겁나 친하께 지내는데 하이튼 그랬었었는데 뱃살마 쪄서 그때도 그 사람의 감정이 쫌 마이 그렇겠대이 카느 글렀느 얘기들은 이케 뭐 캐야 되가 카느 일들이 쫌 있디 보이꼬 그기에 대해서'),
#  ('<jj> what did you guys like the most on that trip ?',
#   '닌 너넨 거 여행이 중에서 무시것이 젤 좋안 ?'),
#  ('<gs> its a bit interesting but', '쫌 신기하긴 하구마'),
#  ('<kw> my mother s french .', '울 어마이가 프랑스인이세요 .'),
#  ('<kw> get us out of here .', '가다 즈네 내려줘요 .'),
#  ('<kw> what s the matter with you ?', '왜서 자꼬 그러우'),
#  ('<gs> so you guys cant go should we meet the date next month ?',
#   '그서 너거들은 몬 가겠대이 다음 달에 날짜를 함 맞춰볼꼬 ?'),
#  ('<gs> i was supposed to take how long this takes but now its a bit at the same company',
#   '아 이기 얼매나 오래 걸리느 꺼꼬 카꼬 캐샀는데 인대이 겉은 회사에 쪼깨'),
#  ('<jd> dieting is not that easy but your will is too low',
#   '다이어트가 헌다는 거이 그렇고 쉬운 거이 아닌디 본 으지가 하도 떨어지드라고'),
#  ('<jj> yeah well he s just a kid now .', '어 너무이 인제 받앙만 이 아이라부난'),
#  ('<kw> just because you re willing to leave the marriage matter to han . can you think about it again master ? i don t have enough money to live up to my death . this is your first time here isn t it ? i m not what you think i am . how selfish of a human being i am . in the meantime i ve been drinking your skull . yes sir . have a cup of tea . paying you what you ate didn t make any sense . he gave me quite a bit of it . it s freezing . what are you doing ?',
#   '오갈단지 겨론 문젠 한군한테 맡기겠다는 생각이시기 때미에 허락하신 거야 . 대련님 다신 핸 벌 생각하실 수 없으십니까 ? 낸 뒈질 망쿰 애써두 갖을 수 웂는 사램인데 이딴 데 츰 삔침 거죠 ? 내 나가 생각하는 그른 대단한 사램 아냐 . 내란 인가이 얼매나 이기적인 놈인지 . 그간 아이씨 사골을 하두 뺏아 마셨더니 야 성님 타 핸 따가리 하세요 . 먹든 게 주시므는 쐬푼 내라는 껀 말이나 아이 돼지 . 꽤똥 마이 줬대나 봐 . 으이구 춥대이 . 싱야 뭐해 ?'),
#  ('<jj> wipe your feet', '발 닦는디'),
#  ('<kw> she s grown up with kids and she s a big family .',
#   '그이 가아지가 인재 커가 아들이 생게 대가족이 되었잖소 .'),
#  ('<jj> but i liked it there .', '겅해도 거기선 입맛 잘도 맞았다이 .'),
#  ('<jd> he doesn t think it s this apartment but no he s right about this apartment and he s got the same name again .',
#   '요잉 아파트가 아잉 거이 같뎌 근디 아니여 요잉 아빠트 맞어 그랬드니 요잉 아빠트 똑같은 이름이 또잉 있다는 거여 .'),
#  ('<kw> i think that s what they do in a movie .',
#   '어뜬 영화에서 보이까 마카 그래 카는 게 같던데 .'),
#  ('<gs> why do you only think of something angry when you think of it when you were in school because youre at a cafe',
#   '랑 학창 시절 생각하믄 랑 고로 화나느 일마 생각나는지를 몰르겠는데 카페 카니께'),
#  ('<cc> if there are so many things that you want to do such as pasting or retrieving blogs or chatting with friends',
#   '붙여늫기나 불러오기나 머 블로그 보거나 친구하구 채팅하거나 요런게 다 혀구 싶을 쩡도로 많으믄'),
#  ('<cc> theres a road from donghaksa temple to nonsan theres a straight road there thats so leisurely its because hes coming late . my grandchildren carried everything around the house so i took him to the hospital and then he paid me for that .',
#   '논산 동학사에서 논산 간 길 있잖여 고기가 쪼꼼 한가하드라구 쭉 직진 슨 도로가 돼있구 간 늦게 오니께 그러네 . 그 울 손자들이 집 식구마다 다 가주구 댕기니께 나뽀구 지가 병원이 데꼬 갔드냐 그라고서는 샤크존 값만 줬댜 .'),
#  ('<cc> but my friend at that time said ill pay for it so lets just go but my friend at the time',
#   '근디 인자 끄때 친구가유 아 나가 돈 내줄 테니께 그냥 가자 근디 당시 친구가유'),
#  ('<cc> its changing but theres not enough power to check this politics .',
#   '변하는디 유 정치의 견제 세력이 지끔 부족해서 그랴 .'),
#  ('<jd> he s dead so all of a sudden i can t accept this .',
#   '디졌어 그까 나가 갑자기 요잉 상황을 모 받아들이는 거야 .'),
#  ('<jd> so its almost', '긍게 거즘'),
#  ('<gs> well it s back to me . it s falling apart and she s down to a dozen .',
#   '그래가주구 다시 있다이가 인지를 팍 떨어져가지꼬 갸가 십 불대까증 떨어졌단 말이라 .'),
#   '잔치 해먹젠허난 핑계에 무신거 벚꽃놀이 구경허고 막이 게난 장사하는 덴 좋을 게 닮아마씨 거디 소곱에 통드리 버려상 가사주 . 아게 괌 거디 그디도 시방 가믄 딱 좋을 땐디 아이 거디 원 높으니깐 빨리 피여 막이 어디여 어디여 막이 돌아댕기지 말앙 엄마추룩 어찌됐던 포르투갈도 다이 바당 근접해 있고이 스페인도 바닥 근접해 이신디 가도이 바당은 제주도가 짱 다이 뵈리는 게 닮아 . 만반의 준비는 됑 인 찬 겁난 튼튼하곡 막이 겅한디 위로부떠 요 상 일본도 한번 더이 가카 요코하마 ? 나는이 상하이에 가실 때이 다이 겅해연 사람덜 다이 바닥에도 앉앙있고 의자에도 앉앙있고 아게 니 잘도 제다 요 모을 영 행 들어강 아고 끝나부렀지양 ? 죙일 걸언 양 울리 동네는예 첨에 강 무신 영 시상이 이신고 했주마씨 . 다이 돌앙 땡기질 못해도 거 어느거 만납서주 그디만 봥 왔겠지 일본에서이 사불어 오난 비싸게 파네 . 오 학년정도 되시큰게 . 잘도 테레비에서 배리는 요 원두막 닮은 디 있네 게민 난이 당연히 삼십오일오일을 추가 받는 건게 나 손에 돈이 들렴져 이시난 트랜스젠더 무대에서 춤추던 성님이 나 손에 돈이 이시난 무대위러레 올라오랜 호꼼 영하당 보난 요 나이가이 들어가지는 게 닮다는 샘토막이 들맨 .'),
#  ('<jd> that s right . that s what it is .', '긍게 맞어잉 그른 부분이 있어 .'),
#  ('<jj> i know what im saying', '게난 나 말이게'),
#  ('<jd> i work here for a dish parttime job and i dont know if the plate is me or myself',
#   '여그서 설거지 알바를 하간디 나가 접시인지 접시가 나인지 모를 정도로잉 오고'),
#  ...]

# %%
# <PAD> : 0 / <BOS> : 1 / <EOS> : 2 / <UNK> : 3
# <jj> : 4 / <jd> : 5 / <gs> : 6 / <cc> : 7 / <kw> : 8

# Sentencepiece를 활용하여 학습한 tokenizer를 생성
def generate_tokenizer(corpus, vocab_size, lang="en", pad_id=0, bos_id=1, eos_id=2, unk_id=3):

    temp_file = os.getenv('HOME') + f'/aiffel/aiffelthon/corpus_{lang}_r0.txt'     # corpus를 받아 txt파일로 저장
    
    with open(temp_file, 'w') as f:
        for row in corpus:
            f.write(str(row) + '\n')
    
    # Sentencepiece를 이용해 
    spm.SentencePieceTrainer.Train(
        f'--input={temp_file} --model_type=bpe --pad_id={pad_id} --bos_id={bos_id} --eos_id={eos_id} \
        --unk_id={unk_id} --model_prefix=spm{lang}_test_r0 --vocab_size={vocab_size} \
        --user_defined_symbols=<jj>,<jd>,<gs>,<cc>,<kw> --remove_extra_whitespaces=false'   # model_r0
    )
    tokenizer = spm.SentencePieceProcessor()
    tokenizer.Load(f'spm{lang}_test_r0.model') # model_r0

    return tokenizer

# %%
SRC_VOCAB_SIZE = TGT_VOCAB_SIZE = 4009

enc_corpus = []
dec_corpus = []

for pair in cleaned_corpus:
    e, d = pair[0], pair[1]
    # enc, dec 분리
    enc_corpus.append(e)
    dec_corpus.append(d)

#     enc_corpus.append(preprocess_sentence(e))
#     dec_corpus.append(preprocess_sentence(d))

enc_tokenizer = generate_tokenizer(enc_corpus, SRC_VOCAB_SIZE, "enc")
dec_tokenizer = generate_tokenizer(dec_corpus, TGT_VOCAB_SIZE, "dec")
dec_tokenizer.set_encode_extra_options("bos:eos")
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=/aiffel/aiffel/aiffelthon/corpus_enc_r0.txt --model_type=bpe --pad_id=0 --bos_id=1 --eos_id=2         --unk_id=3 --model_prefix=spmenc_test_r0 --vocab_size=4009         --user_defined_symbols=<jj>,<jd>,<gs>,<cc>,<kw> --remove_extra_whitespaces=false
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /aiffel/aiffel/aiffelthon/corpus_enc_r0.txt
#   input_format:
#   model_prefix: spmenc_test_r0
#   model_type: BPE
#   vocab_size: 4009
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: <jj>
#   user_defined_symbols: <jd>
#   user_defined_symbols: <gs>
#   user_defined_symbols: <cc>
#   user_defined_symbols: <kw>
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 3
#   bos_id: 1
#   eos_id: 2
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 0
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(329) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(178) LOG(INFO) Loading corpus: /aiffel/aiffel/aiffelthon/corpus_enc_r0.txt
# trainer_interface.cc(385) LOG(INFO) Loaded all 10000 sentences
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <jj>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <jd>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <gs>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <cc>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <kw>
# trainer_interface.cc(405) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(466) LOG(INFO) all chars count=1914376
# trainer_interface.cc(477) LOG(INFO) Done: 99.9744% characters are covered.
# trainer_interface.cc(487) LOG(INFO) Alphabet size=28
# trainer_interface.cc(488) LOG(INFO) Final character coverage=0.999744
# trainer_interface.cc(520) LOG(INFO) Done! preprocessed 10000 sentences.
# trainer_interface.cc(526) LOG(INFO) Tokenizing input sentences with whitespace: 10000
# trainer_interface.cc(537) LOG(INFO) Done! 11822
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=59401 min_freq=1
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=15710 size=20 all=951 active=922 piece=on
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=7109 size=40 all=1627 active=1598 piece=ll
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4964 size=60 all=2369 active=2340 piece=as
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3406 size=80 all=2857 active=2828 piece=▁was
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2727 size=100 all=3400 active=3371 piece=▁its
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=2632 min_freq=81
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2115 size=120 all=3893 active=1494 piece=au
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1703 size=140 all=4411 active=2012 piece=▁not
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1454 size=160 all=4806 active=2407 piece=ion
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1217 size=180 all=5259 active=2860 piece=▁up
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1009 size=200 all=5501 active=3102 piece=ven
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1001 min_freq=88
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=911 size=220 all=5905 active=1377 piece=▁fr
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=806 size=240 all=6264 active=1736 piece=▁too
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=696 size=260 all=6734 active=2206 piece=▁went
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=621 size=280 all=7039 active=2511 piece=▁sp
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=529 size=300 all=7369 active=2841 piece=ess
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=529 min_freq=79
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=502 size=320 all=7545 active=1147 piece=ide
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=470 size=340 all=7783 active=1385 piece=▁yeah
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=430 size=360 all=7992 active=1594 piece=▁kid
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=403 size=380 all=8195 active=1797 piece=▁friend
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=377 size=400 all=8438 active=2040 piece=▁diff
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=376 min_freq=70
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=343 size=420 all=8663 active=1224 piece=▁big
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=314 size=440 all=8888 active=1449 piece=▁also
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=297 size=460 all=9139 active=1700 piece=▁talking
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=274 size=480 all=9386 active=1947 piece=▁brother
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=253 size=500 all=9613 active=2174 piece=▁use
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=252 min_freq=61
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=10 size=3780 all=19005 active=1167 piece=▁tied
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=10 size=3800 all=18999 active=1161 piece=▁lover
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=10 min_freq=7
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=10 size=3820 all=18998 active=999 piece=▁allerg
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=10 size=3840 all=19005 active=1006 piece=▁regist
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=10 size=3860 all=19003 active=1004 piece=▁farming
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=10 size=3880 all=18991 active=992 piece=▁homework
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=10 size=3900 all=18983 active=984 piece=▁permission
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=10 min_freq=6
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=9 size=3920 all=19021 active=1039 piece=sat
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=9 size=3940 all=19069 active=1087 piece=jeon
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=9 size=3960 all=19110 active=1128 piece=allow
# trainer_interface.cc(615) LOG(INFO) Saving model: spmenc_test_r0.model
# trainer_interface.cc(626) LOG(INFO) Saving vocabs: spmenc_test_r0.vocab
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=/aiffel/aiffel/aiffelthon/corpus_dec_r0.txt --model_type=bpe --pad_id=0 --bos_id=1 --eos_id=2         --unk_id=3 --model_prefix=spmdec_test_r0 --vocab_size=4009         --user_defined_symbols=<jj>,<jd>,<gs>,<cc>,<kw> --remove_extra_whitespaces=false
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /aiffel/aiffel/aiffelthon/corpus_dec_r0.txt
#   input_format:
#   model_prefix: spmdec_test_r0
#   model_type: BPE
#   vocab_size: 4009
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: <jj>
#   user_defined_symbols: <jd>
#   user_defined_symbols: <gs>
#   user_defined_symbols: <cc>
#   user_defined_symbols: <kw>
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 3
#   bos_id: 1
#   eos_id: 2
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 0
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(329) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(178) LOG(INFO) Loading corpus: /aiffel/aiffel/aiffelthon/corpus_dec_r0.txt
# trainer_interface.cc(356) LOG(WARNING) Found too long line (4518 > 4192).
# trainer_interface.cc(358) LOG(WARNING) Too long lines are skipped in the training.
# trainer_interface.cc(359) LOG(WARNING) The maximum length can be changed with --max_sentence_length=<size> flag.
# trainer_interface.cc(385) LOG(INFO) Loaded all 9968 sentences
# trainer_interface.cc(391) LOG(INFO) Skipped 32 too long sentences.
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <jj>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <jd>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <gs>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <cc>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <kw>
# trainer_interface.cc(405) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(466) LOG(INFO) all chars count=949011
# trainer_interface.cc(477) LOG(INFO) Done: 99.9501% characters are covered.
# trainer_interface.cc(487) LOG(INFO) Alphabet size=1519
# trainer_interface.cc(488) LOG(INFO) Final character coverage=0.999501
# trainer_interface.cc(520) LOG(INFO) Done! preprocessed 9968 sentences.
# trainer_interface.cc(526) LOG(INFO) Tokenizing input sentences with whitespace: 9968
# trainer_interface.cc(537) LOG(INFO) Done! 70621
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=13761 min_freq=43
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2299 size=20 all=45929 active=4697 piece=▁기
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1467 size=40 all=47758 active=6526 piece=▁같
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1130 size=60 all=49700 active=8468 piece=▁이케
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=893 size=80 all=51033 active=9801 piece=▁경
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=748 size=100 all=52371 active=11139 piece=▁약
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=737 min_freq=34
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=612 size=120 all=53529 active=3747 piece=▁무신
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=536 size=140 all=54728 active=4946 piece=▁재
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=501 size=160 all=55500 active=5718 piece=요잉
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=467 size=180 all=56673 active=6891 piece=▁봐
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=443 size=200 all=57994 active=8212 piece=▁겁나
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=439 min_freq=29
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=405 size=220 all=59119 active=4018 piece=지를
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=31 size=2380 all=96099 active=5451 piece=시기
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=31 size=2400 all=96355 active=5707 piece=▁대부
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=31 min_freq=10
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=31 size=2420 all=96490 active=4951 piece=▁축구
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=30 size=2440 all=96597 active=5058 piece=▁똘
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=30 size=2460 all=96877 active=5338 piece=▁거기
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=30 size=2480 all=97029 active=5490 piece=▁인사
# trainer_interface.cc(615) LOG(INFO) Saving model: spmdec_test_r0.model
# trainer_interface.cc(626) LOG(INFO) Saving vocabs: spmdec_test_r0.vocab
# True

# %%
enc_corpus
# Out:
# ['<kw> why are you here ex wife ?',
#  '<cc> i m trying to take the lead . i m still healthy enough .',
#  '<kw> i don t have any air .',
#  '<jj> even if youre going to sell it again',
#  '<jd> you don t have to look at me like that . you don t have to look at me like that . you don t have to look at me like that .',
#  '<gs> they go to their house and exchange useless gifts',
#  '<cc> ita is unless it hurts ive been doing it for years',
#  '<gs> im more practical than designing',
#  '<jd> i hid not living for a long time but ive been having a hard time and living a lot .',
#  '<gs> who knows how you can be cursed at there too and honestly you can be cursed at there . as a person who has been using it for a long time i dont think i like this function a little bit . you don t care what i do you rip each other s throats like this . but what is it how many is it it was hard to see a little bit because of that i floated all the spools . if you lose fat youll get weak weight .',
#  '<gs> i changed myself to a constitution that doesnt gain weight',
#  '<jj> its true that the land wasnt built because my fatherinlaw built it what youre doing is bring one more underpants from home yes im not good at taking pictures but ill go she s a nice girl . hey if you want that sweet potato over there bring me his potatoes . then i called him now because he said i would so so when did he set me up on the day is the average score of yuxpoint you can have beer . she s a scary bitch too . hurry up and go over the wall and put it on pizza two hundred sixty on the level if you come and do it youll come to my house and put it on i ll be there in the morning and take it . im going to eat with him or her i couldnt eat it i went out right away ? i ve seen it . now that i m born yes with five things real kid i m surprised . uh then a baby that is more than six months old and newborn on top this month old here we re moving them out of the way . i ve been listening to youtube videos . and i made a signboard and now they were so my brother was jealous and angry but ive never been late ill give you money on the day its over . just the siasons brotherinlaw dafters this root yes its like low onions i hit my calf with my moms fly sweets at that time . you said your shoes were here . uh is she tall ? i saved money and bought pomegranate i bought oil . you got more happiness how many times happiness is it why are you making our grade ? anyway i remember eating the one that i cooked in the term back then my back has been hurting since a long time ago yeah you can express it to others or you can do it . so this is also but it takes me too long to get to the banquet hall . i went to the village to bathe my mother . three of them cried on the curtain behind the curtain . thats really true but now that youre a little old the tone has gone down a little bit what should i do with the siamo junior oh when i got a blizzard i was going to take the csat on the day of the csat for my youngest brother how can you endure it because youre really amazing even if you hear such a ridiculous sound i go to find someone who lives in outside houses my mom in my lower house is one year older than me . i m talking about the sun and i m thinking about it and i m thinking i told you too late . then what do you do ? he said it was her mom and she was shocked thats amazing thats how it works i know so i m gonna go downstairs and i m gonna put them in a room .',
#  '<cc> then are you living alone on the internet',
#  '<jd> he s invested a lot in real estate huh ?',
#  '<jd> pursue something like that and something sustainable',
#  '<jd> no not at all .',
#  '<jd> it s not funny so watch tv less .',
#  '<jd> and in summer im just going out to play . in that spring blue birdshoots are green and light green rather than green i mean that kind of thing went up a little bit so i actually didn t eat . no it was fun i think i started liking camellia flowers a little from then on . i ve never been to the summer sun again in late autumn . i hid not even go on vacation in the summer and i havent been there anywhere . so when you re too tired and you re going to winter you re going to remember that when you were in elementary school your arm was too hard . ithe was so good that i didnt hate anything sprouts are just so i enjoy it again so i am so how do you get around ? but people are still out there',
#  '<gs> customers come like a man who throws a slight cold wave or a woman who screams',
#  '<kw> where have you been ?',
#  '<jd> but it s good to cut down on ms . bob from the beginning . donty if i turn my eyes over and eat them . pinkeroot said it was weird . he couldn t eat it . i m going to college . good luck . yeah . it s really gross for boys to evaluate their bodies and see things like that . i quit yoga saying i don t need this anymore . you don t eat instant you exercise but you have to eat less . i m not gonna leave it alone but when i m on your diet after a while i don t eat much more . so i cant do it because im on the road amitabha it smells bad and what are you eating i gave my daughter a nose cut in the midst of her sickness',
#  '<kw> anyway i said we should work together under very good conditions .',
#  '<cc> my mother is going to her inlaws this time so i cant get older',
#  '<jj> and the one that made that last time is enzymes',
#  '<jd> its very scary to hear what you say',
#  '<jj> but if youre not qualified how can you put it up',
#  '<jj> but in my eyes the vaccine is the answer .',
#  '<jd> that s right .',
#  '<kw> it s a lot to miss . the shade of that tree fell on the grass . i can answer that question . are you okay ? wake up . what s your hobby ? how s it going ? i don t feel safe standing there .',
#  '<jj> i dant adjust to the lag',
#  '<cc> its really sad like its saying sad to the person who is going to part .',
#  '<kw> chariots were crowded .',
#  '<jj> that way let me stay silent',
#  '<cc> there s not a lot like that between the two of them .',
#  '<jd> so after more than ten years of marriage after fifteen years of marriage',
#  '<kw> you re throwing up on me ?',
#  '<kw> i have to come with you . i didn t come with you . what happened to you ?',
#  '<gs> i was a little scared when i was grumbling when i was sleeping i was afraid that i would fall out when i slept and lose it',
#  '<jd> you have to put importance on homosexuals so',
#  '<jd> ever since i was a little girl',
#  '<cc> its too hot in summer so i dont want to go outside and if i go outside i have limited clothes to take off . i feel like i do . its not obscured by japan anymore so the sea itself is open i dont prefer it that much . i think it s cool and i ve got a lot of air conditioning on and i don t think it s easy to move around . im glad that i grew up now but i think i had a hard time when i was young .',
#  '<gs> the machine is boiling it with curls by pressing a button like this these days',
#  '<jj> i cant walk after leg surgery',
#  '<jj> i think i would have ground beans and beets too .',
#  '<kw> how long has it been ?',
#  '<kw> i m not trying to stop you .',
#  '<jd> i saw that it was shortened to five minutes there are suspicions about whether its a really perfect truth or not i think i was shocked like this . that s good for you . that s good for you guys . theres that charm when you look at him and theres that charm when you look at him oh yeah at first but . . .',
#  '<jj> and then back in the day but its going to be tomorrow again and the vicious cycle keeps repeating do you want to have it ? i eat it completely hard we re not coming in here with orange . i woke up eating two meals . you got up early in the morning working and went to the field with all your kids and everything you had to eat . i think i m eating too much . i should study this but let alone study why does he keep going back and forth ? then the previous days feast will be held at the village hall anyway ? how did you come from the east was it driven by car ?',
#  '<kw> is a whole garlic better or a ground garlic better ?',
#  '<kw> if it s hard will you hold all the women in the world ?',
#  '<gs> i thought i could do stocks because there was no interest rate on this bank so i didnt do much',
#  '<kw> i can t even cry as much as i want . we need to rebuild our sales strategy . you can t get involved . you remember that arrogance even though you remember it . then i ll read it to you . i can t even look around at everything you ve been talking about . the show s gonna stop for a while with the commercials . i can t stop it . do you know how delicious it is to put a chicken sweet potato in a chicken dorit ? no it s just a weird phone call . it s time for you to finish your exam . i m glad you re here .',
#  '<kw> didn t you get the manuscript ?',
#  '<kw> are you drunk again ? i don t have one . you re having a hard time with me aren t you ? you stay here for a second . but what is this ? you re gonna make money if you get one or two of your kids out of here aren t you ? its strange that i dont get a bone disease because ive been holding it in so many years . yeah we need to get a room quick . let him get married first . im so proud of you . i m just a sally man . find a nice guy . here you are .',
#  '<kw> it s time ?',
#  '<kw> kim s fourth daughter is so pretty .',
#  '<jj> i m feeling it . isn t dew wearing board glasses ? im so tired of it i just want to grow johnna and get a perm it hurt a lot really yesre saying this yes are you crazy ? i think you can just buy it ?',
#  '<jj> because i dyed my hair dark brown once',
#  '<jj> i had to go when i had a little applause .',
#  '<kw> if you go that way you won t fight again .',
#  '<gs> you have a way again you do it to you i think its comfortable anyway . i dont know who i didnt see because it closed quickly no one thinks about it but only about himself so yes you gave birth to two daughters and a son i don t know what to say . you know it s what i call it . it s what it s called . it s what it s supposed to be . it s what it s supposed to be . it s what it s supposed to be . it s what it s called . it s what it s called . if you look like this separately ill be the first one to me and there s a little bit of confidence everywhere . uh huh . uh huh . i dont feel it much so i dont think its wrong . i had that feeling and then i went through an emvithia test and then i got this enttyjay . i heard that the relationship with humans is getting narrower but he has a little talent and is a timid gwanjong',
#  '<cc> first of all because i stand for a long time my toes hurt my calf hurt and my knees hurt',
#  '<jd> i told you i only told you and started talking like this',
#  '<gs> who doesnt do it next to you',
#  '<jj> lets buy fruits and go in and lets go to us now .',
#  '<gs> its only in busan .',
#  '<jj> oh my what should i do ?',
#  '<kw> your arm s so tight that it s falling off your kid s arm .',
#  '<cc> so when you wear this it goes well together',
#  '<gs> there s got to be some hard stuff right ?',
#  '<jd> and when i think about it i m not exactly the kind of person who wears a lot of perfume so it hurts my head .',
#  '<jj> i think it suits soybean paste rather than salt or soy sauce',
#  '<kw> i don t know what to do with you yet .',
#  '<gs> she they escorted from the back and the women stood in the middle',
#  '<jj> we married a little late but my older child is',
#  '<kw> my dads car has parking on the rear side',
#  '<jj> that s cute . isn t that self involved ? if the house is here for my mom and dad i m just gonna keep coming back and forth and then i m gonna . . . it should have been raining . geji is so there are many sayings to guess its similar yes theres that one the bag youve been using since you were a baby is yours because youre kidding me baking it like this oh i breathed after i said hap the cat thought he was muscling himself ? youh have to feed them but when its lunchtime for children we know her we talk the most and thats when we talk the most its better if its like a daejeong',
#  '<kw> everyone i care about is leaving me .',
#  '<cc> yeah well it s got a little low frequency ribs on it and it s been used to warm it up and then it s been eaten . at any rate i bought eight pieces of it and i sold them for two hundred pieces of it on the internet for about two and a half dollars . so i told you to make it why did you make it . oh i originally ordered sneakers for couples but my size was returned because my feet were big i want to buy a reversible fleece that can be worn on both sides it was a dye that you could rinse after giving about to minutes of time . its red and green by color these days its christmas so i dont just use it as an interior . such apps are easy to search and view and there are a lot of discount coupons for them whenever i use that there are a lot of size misses so most of them say i think i always wore pants only right now im wearing training suits but i dont know where its now the small one wasnt sold but it wasnt sold so its there ? a little bit if you have to choose between quality and price which one do you want to choose ?',
#  '<jj> the children of the family with many brothers are very straightforward',
#  '<jj> back in our day when we used to put kimchi s blanket on us when we used to be peppered oh i couldnt tell you to give me won even if my house is rich look at that cow . once i ve got to figure this out i ve got to figure it out . theres namwon mongsaeng theres no one theres only daejeong mongsaeng . its different its different they sell candies over there too i need to buy you a really good meat but i cant meet you seven days seven seven twenty seven thirty three days seven four twenty eight your siabah havent worked at all i don t know what you re talking about . i think the antiintract life has disappeared back then . oh my i heard you how fun did you think it was . everyone knows it . yes so even if i would persecute him i wanted to live in my house answered that there was a store afterwards and i made so much money from the dock i don t know . now i m running away . there were a lot so there were morning and afternoon mireuksa temple is also very important in literary history . but theres a branch office over there theres a person who goes to see the land',
#  '<gs> its okay now but take care of yourself .',
#  '<jj> but when i saw you writing there it didnt come out as much as before',
#  '<cc> im getting married now and after that ive been especially a little',
#  '<jj> i think its all gone as it grew up .',
#  '<kw> so as he passed by the structure',
#  '<gs> its a little similar',
#  '<kw> i don t regret living that way .',
#  '<jd> i thont think its a diet but the reason is',
#  '<kw> i followed him a little . so i went to dessert and i ate a lot of cake and bread . when the bell rings get up . i thought about it and you thought about the japanese girl . there s a seminar for sales executives . i don t want you to play the game and i want you to play the useless sport . there s something that s so interesting about this place and there s something that says it s different from our country . scientists working in other fields . why does your chest hurt so much ? unfortunately the reality is very different . well i haven t had a drink out there anymore . this sea of shipping is a little bit different from this sea of ice .',
#  '<jj> it does worth doing',
#  '<kw> sit down on your chair .',
#  '<kw> it s hard to chew .',
#  '<kw> get some rest at work .',
#  '<kw> the creativity and planning doesn t come from the desk .',
#  '<kw> we re going to add some barley rice to make some barley rice .',
#  '<jd> poor ? why are people tangled at first when we met with lee hyorirang and lee sangsoon so i went to seoul and was there but we re over million now so i m trying to figure out if i m going to have to lower my equilibrium . what if you re a man and you re a man ? ive been selected more than a hundred times and now im not married and i get scolded by my father a lot',
#  '<cc> oh health is so precious',
#  '<jd> so its really good to do it when its cold and when its hot',
#  '<gs> are you interested in that ?',
#  '<jj> a day of personal opinion .',
#  '<kw> what am i doing ? open it up .',
#  '<kw> just pretend to do it without sincerity . she hasn t kissed me yet not even on her cheek . all right let s go . how d you get along ? you re living in the same neighborhood again ? i ll do it later . you want me to build you a hospital day care ? i thought you d buy some for three stars . don t make me trash with a few bucks .',
#  '<gs> since there is no string there is a string and its a little big so i was bothered to buy it because i was pushed back',
#  '<cc> let s go home . we didn t eat dinner . we just went home .',
#  '<kw> a year old top of the art genius girl in korea .',
#  '<cc> and i run around when i work out but its uncomfortable if my phone keeps moving in my pocket',
#  '<kw> he s stubborn . that s why i m so tall . it s like i want to see your picture over there and meet you . that s the best person i ve ever seen . i told you it was a bad idea . our heroes in the fabulous high school . i m gonna eat it now .',
#  '<kw> it s nothing ?',
#  '<gs> then the carp bread will be a little more chewy so these days',
#  '<jd> theres a lot of fun things to cook hamuk camping and theres a good one .',
#  '<jj> its not going to be a misdemeaning .',
#  '<gs> dont study what is the reason you study ?',
#  '<jd> but i m gonna kill you . i m gonna kill you .',
#  '<kw> thats right cheekoo . that s what they say when a woman says she s getting married she wants to run away isn t it ? and it really hurts . what kind of help is there ? i asked him to help me with everything he could . come on come on come on come on . you don t know that yet . i don t know if there s anything else but you have to go quickly because of the move . if that s what the world knows why don t you try to hide it like that ? you don t know why you went to work for a while . but you re eating too much aren t you ? he s going for a walk . mother when are you going to say hi to my house ?',
#  '<jd> its a little bit its a little bit',
#  '<jj> why didnt you finish it so why did you come so fast i m sure it s been a month or so . oh i have to take out my wisdom teeth but its good that its somehow over is that why you came up here today ? because he inspects them all out how delicious it was because i told you everything i was going to ask but i thought they knew how to cover the furrows . when you go to college you can go to your own office . professors are also like that thats right but jd said its a little more than that .',
#  '<jj> they don t have a lot of products but it s actually too hard to lose the principal to mr . emir . i told you i kept getting exhausted after my internship . when i was just about six or seven years old no even when you apply moisturizing cream like that dont move in the sea im going crazy about the sea and guarding the sea honey yes i havent been to my motherinlaws house in a while first of all if youre the same age or someone shes slower than me what did you do ? oh but i have a girlfriend next to me i think it s a really good webtoon these days . there was nothing to do with computers and games and football games . but i don t think something would have hit you . now my nose turns red after drinking like that',
#  '<kw> i don t know what she didn t tell me or what i was missing .',
#  '<kw> they called me this morning .',
#  '<kw> i think he noticed something .',
#  '<kw> do you think that value only exists at this point ? the pebble beach is a minute s walk . santa ana strong winds are expected to return this week . you said women don t understand they feel ? the twins take actions that are consistent with everything they do together . and there are parents representatives in the counseling room so go to glue and buy it and apologize . i don t know how many times i m or years old . what if i m drunk all day ? it didn t happen when you and your friends were together . there was always a pizza truck here . who s okay ? the restaurant was a mess and i couldn t even taste the food .',
#  '<jd> i always go to school with him so i thought he was really close .',
#  '<cc> it is already completed so i want to recommend a little bit',
#  '<jd> so given the stockage and the shareholders',
#  '<kw> don t you think she ll talk about the pregnancy if she goes to the hospital ?',
#  '<kw> i m sure we re going to start a business .',
#  '<jd> he should go to his seeds and cut down the tree .',
#  '<jd> perhaps because of that harry boche cant do it and something is now',
#  '<jj> how did you take it out ?',
#  '<jd> now if the years go by',
#  '<jd> depending on what i eat the health of my body depends on it .',
#  '<jj> yeah you should thank your grandchildren for that .',
#  '<kw> you ll see later . it s an honor . while i m at work i m gonna have to pay attention to my every move . what s the point of knowing ? oh my mom s still doing great because grandmothers are walking the most important thing . why are you playing with her ?',
how can i not see you when your mother s admitted ? im tired now so stop taking care of me . i think it fits my personality . it s been over two hours . my back . my back . you can t come ? where d you go ? you re not going to move on . uh his face is shining . it s shining . you heard me . did we come back to sing ? honey follow me . i don t think you d be comfortable with that . hurry up and grow up in their rooms . don t be so confident huh ? i m always moody . i m good . he was trying to put a wedge between us . yeah well you know the painting . i don t know . don t freak out . i m not studying and i m watching t . o . right ? she went shopping .',
#  '<jd> im a little worried about falls broken bones or concussions',
#  '<kw> i ve been talking so hard about what s going to happen to me .',
#  '<jd> can you introduce me next time you have a good job ?',
#  '<jj> oh my god you did a good job .',
#  '<jd> and i ve seen tiarah s video on his relationship search .',
#  '<kw> what did you like about it ?',
#  '<cc> if it doesnt get along just talk around and turn the topic around .',
#  '<cc> im going to starve today',
#  '<cc> its a picture of sugarshu garun when we were a little younger since its a japanese animation',
#  '<jd> well what i was using now is an air system phone where my husband s been using it for a couple of years .',
#  '<gs> so i sometimes post on instagram what i want to show off or travel for selfsatisfaction',
#  '<gs> even if its as much as you do to your parents',
#  '<kw> the kind of criticism was clearer than the rest .',
#  '<cc> no no because lee sungmi is doing cancer surgery and breast cancer surgery',
#  '<kw> you d be happy to play racquet . thank you wouldn t you ?',
#  '<jj> what it is',
#  '<jd> then you should take your parentsinlaw first and then you generally go back and come back and get along well',
#  '<gs> its a little old before with a horizontal bachelor',
#  '<kw> what s wrong with you ?',
#  '<kw> it s just last year or so and now i ve got a match .',
#  '<kw> oh you didnt wear makeup what do you mean .',
#  '<cc> i don t want to see her because at some point she s like a family .',
#  '<cc> i d like you to do a little bit of that and my country has expanded so much about that music .',
#  '<cc> refrain from walking around the outside',
#  '<jd> but evil follows and line line indian johnson goes',
# ...
#  '<jj> don t worry about anything just make money that s what i did .',
#  '<kw> that s probably a generation gap .',
#  '<kw> i m the only one who loses .',
#  '<kw> that s why customers are so popular .',
#  '<jd> imas so atrophied that i prefer a maker even if i buy one well tell me a color with the product number behind it and then two seats at the end . but if you leave it alone i think youll wear it again so i cant throw it away you re going to have to look at the shopping the greed the greed . i m more interested in shopping . i dont like women wearing leather so im going to make them neat what was it but it was black and this pattern this colorful suit is one of the best items to re enhancing the atmosphere . theres nothing urgent . i failed a few times but the standard for buying pants is spandex so what i usually go to is where to go and when i walk around the internet',
#  '<cc> so i made it for him and he likes it .',
#  '<jd> the golden ratio of the pieces is to show these perspectives .',
#  '<kw> he s not polite and he s a total stranger to no one s eyes .',
#  '<jd> i like cell phones a lot but the best thing i like is honestly a camera rather than a cell phone .',
#  '<jj> what if jeju island hits this stage too ?',
#  '<gs> i didnt think about why my parents were annoyed by me with this .',
#  '<jj> it doesn t say anything about that .',
#  '<jj> what kind of family do you not acknowledge it',
#  '<gs> but this hair is also like this person so he looks good on him',
#  '<jd> i bought you a drink first when i was drinking my mom came and said why did you want to buy me first as i got close now i felt that this was your own expression of affection so i didnt make any misunderstandings but when i was in elementary school how can parents not represent the class with only a few representatives in a grade because thats what the scholarship decides at that university i had just made a phone call on my teacher s day . i don t know how to use it . when you look at the thriller you can see if youre the culprit for example when youre chasing the main character i want to go to the architecture department because im going to write a comprehensive one . i was really good with ordinary friends and of course i learned a race or some other shoot . what do you mean by sticks or whips anyway you told me to lift the hawk and teach it i was going to study as a counselor but its late .',
#  '<kw> you re tired and you re asleep .',
#  '<kw> this is the only allowance .',
#  '<jd> when things like this come out he seems to be acting honestly to fit his face . would you like me to introduce you to a film you ve been impressed with ? i don t even know what you saw in the movie theater this morning . shall we share it ? and what was that in the middle of an elder s service ? and there are many kinds of movies again now',
#  '<kw> let s do the rest tomorrow . i don t have much trouble with that . why do you have a towel on your head ? i just moved in . who did you fight with and you got a bruise in your face ? he appeased the two men who were fighting and reconciled them . i haven t helped anything in the past . i ve been looking at you and i don t look at you . which companys tv is from ? that kimbab must have been hurt . yeah but i didn t mean to lie because i haven t been married for three months . what are you doing ? it s two o clock tomorrow afternoon isn t it ? i don t think it s a little bad about that part because the whole thing is swearing together . so you can imagine you re going to be the boss later ? the two attack each other with all their might . the battle has not been resolved . she s getting close to you and you re gonna have to give her a break . i don t even have time to think about my future . would you really do that for me ? let s go get some rabbits . it s a holiday so there s too many lines . it s a long desk . that ship went out to sea yesterday . should i have it dismissed ? his face is bloodless and yellow .',
#  '<kw> grandma doesn t like chinese food . you feel it don t you ?',
#  '<jj> is it okay ?',
#  '<jj> i just said that when i didn t read white bread and let it go .',
#  '<jj> oh i told you yesterday that i went to a red house in sinjeju .',
#  '<kw> the grown ups think they re getting married .',
#  '<kw> when s your flight time ?',
#  '<kw> looks like summer s here .',
#  '<kw> i m just saying let s see .',
#  '<kw> okay dad .',
#  '<cc> if you ask him to pay for this when all life becomes like this he has to make some time to spare',
#  '<cc> i m just gonna go check on him .',
#  '<jj> if there is nothing i can say i would be like that so even in that situation',
#  '<jd> i want to live a life where i find happiness even in a little trivial thing',
#  '<jj> so i just took out one for dp .',
#  '<cc> i think its okay and theres the center director here so he doesnt leave the department until he leaves .',
#  '<jd> so that s when um . . .',
#  '<gs> yeah anyway lets think about dyeing a little more .',
#  '<kw> where are you talking about the answer .',
#  '<gs> in the end in the case of complex you may think that your heart is at stake this is also a complex personality now if you just directly read it at that age it will become a big mountain can i ask you what it is so what made you decorate it i haven t been to any other sports and i have a house near the river . what should i do ? is it his own fashion like your friend im among my friends wee are getting along well and were still very close anyway it was like that but i only gained belly fat then the hard stories that people s feelings are a little bit more likely to do that there are some things that i have to do so about that',
#  '<jj> what did you guys like the most on that trip ?',
#  '<gs> its a bit interesting but',
#  '<kw> my mother s french .',
#  '<kw> get us out of here .',
#  '<kw> what s the matter with you ?',
#  '<gs> so you guys cant go should we meet the date next month ?',
#  '<gs> i was supposed to take how long this takes but now its a bit at the same company',
#  '<jd> dieting is not that easy but your will is too low',
#  '<jj> yeah well he s just a kid now .',
#  '<kw> just because you re willing to leave the marriage matter to han . can you think about it again master ? i don t have enough money to live up to my death . this is your first time here isn t it ? i m not what you think i am . how selfish of a human being i am . in the meantime i ve been drinking your skull . yes sir . have a cup of tea . paying you what you ate didn t make any sense . he gave me quite a bit of it . it s freezing . what are you doing ?',
#  '<jj> wipe your feet',
#  '<kw> she s grown up with kids and she s a big family .',
#  '<jj> but i liked it there .',
#  '<jd> he doesn t think it s this apartment but no he s right about this apartment and he s got the same name again .',
#  '<kw> i think that s what they do in a movie .',
#  '<gs> why do you only think of something angry when you think of it when you were in school because youre at a cafe',
#  '<cc> if there are so many things that you want to do such as pasting or retrieving blogs or chatting with friends',
#  '<cc> theres a road from donghaksa temple to nonsan theres a straight road there thats so leisurely its because hes coming late . my grandchildren carried everything around the house so i took him to the hospital and then he paid me for that .',
#  '<cc> but my friend at that time said ill pay for it so lets just go but my friend at the time',
#  '<cc> its changing but theres not enough power to check this politics .',
#  '<jd> he s dead so all of a sudden i can t accept this .',
#  '<jd> so its almost',
#  '<gs> well it s back to me . it s falling apart and she s down to a dozen .',
#  '<kw> everyone s got a year old relationship now but don t you go to school these days ?',
#  '<kw> they say there s a bottle of bottle in the air .',
#  '<kw> you have to be good with your presentation .',
#  '<jd> i think its good to see little by little when theres nothing to do for a while well you told me you didn t see a little esp which is actually what i ve seen a lot of esp movies . theres an app called what player its a bit fun so i remember a little bit of the difference between fat and speciality that i felt in my body at the time . oh my that feeling is not forgotten then .',
#  '<kw> i ve met you two or three times and your family s already talking about it .',
#  '<jd> i don t know if it s gonna happen but it s not gonna happen .',
#  '<jd> i cant do it ill lend you the daycare center license again .',
#  '<kw> yes but barely .',
#  '<kw> i m gonna work hard for it again .',
#  '<jd> honestly the picture came out a little well enough for others to admit it',
#  '<jd> and i just kept doing that and after a couple of weeks my friends said',
#  '<jd> uh im a little nervous about this many dreams i told you i m putting it on a practical basis now so what s your dream after that ? i don t know what i m going to do . i m going to do it later . so i put my feet in and talked to him and my father he really wanted to do this a lot . so i d like to have another job .',
#  '<jj> since youre going to have a party you know watching the cherry blossom . it s a lot . so it would be good for business you have to throw it away in the container there . oh guam there is the perfect time to go there no its so high there so spread it out quickly don t just walk around like your mother . at any rate portugal is close to the sea spain is close to the sea but the sea is very strong . i think i see it all . im fully prepared to car its frightening and strong yokohama ? i did it all when i went to shanghai everybody was sitting on the floor everybody was in the chair . oh yeah its very fast lets do it this is how we get into the village . you re done with that aren t you ? i balanced myself yes my neighborhood is i was wondering what kind of world there was . even if you cant go around everyone you must have only seen it there it s expensive to buy from japan . he s probably in fifth grade . theres a place like a lower bean cabin that you see in tereby then im of course getting an extra days oil my hands are money so my sister who was dancing on the transgender stage has money in my hands so come up to the stage i thek its like im getting older .',
#  '<jd> that s right . that s what it is .',
#  '<jj> i know what im saying',
#  '<jd> i work here for a dish parttime job and i dont know if the plate is me or myself',
#  ...]

# %%
dec_corpus
# Out:
# ['근디 왜서 요 전처가 . 아따 혹예',
#  '앞장설라 그려 아직두 내 충분히 건강하다구',
#  '아문 풍취두 음싸 .',
#  '되팔잰해도',
#  '아 겐 게 저디 무신거 쩌번에 거 멩군 거는이 효소가',
#  '요게 뭐 말만 들으면은 겁나 무서분디',
#  '근디 부적격하면은 그거를이 인제이 올려가지고 어떻게이',
#  '근디 나이 뽈 때분 백신이 답이다게 .',
#  '글지 모병제로 바뀌만',
#  '어 마이 아쉬워요 . 때에 그이 낭 그느리이 졌어 . 그이 질문에는 대답할 수 있사 . 괜찮으냐 정신줄 차려라 . 그 뭐 취미가 뭐 질래 되나 ? 지 비스가이 가지고 있슬 기 불안하다 .',
#  '시차적응이 안되가지고',
#  '이별하는 사람으 맞춰서 슬프라구 허는 말인 거처럼 진자 슬픈 겨 .',
#  '전차는 지법 혼잡했어 .',
#  '그추룩 해그네 저 묵허게 해그네 허라',
#  '얘네 둘이 혀 형제간끼리는 그른 기 벨로 음써 응 그른 기 벨로 없드라구 근디',
#  '긍게 결혼 요잉 시 년 넘게 헌 요잉 시 년 요잉 시 아따 주년 넘어졌다며',
#  '시방 즈 말에 토다는 것이다요 ?',
#  '승규이가 매치루 와야 되는디 매치루 아이 왔으니 나가 뭐이 일이 있어가 왔는지',
#  '대께 땐 낄려니께 쫌 무섭더라고예 대께 땐 빠질꼬 봐래이 빠져가 분실될꼬 봐래이 무서워가',
#  '그른 동성애자 그른 거이 중시해야 되고잉 중시 긍까',
#  '어렸을 때부터 이르케 좀 난',
#  '여름에는 너머 더워 가주구 밲이 나가기가 싫구 밲이 당가면은 옷을 벗는 데도 한정적이잖아 . 그른 느낌이 드는 꺼 같여 . 인자 일본 겉은 디이 가려져 있제 않혀 가주구 쫌 널 넓게 탁 트인단 말이여 바다 자체가 그르케 선호하는 편은 아니구유 . 아무래두 시원하구 에어컨도 마이 켜두구 하니께 워디 밲이 돌아다니기도 쉽지 않구 그서 지끔 커가지구 그나마 다행을루 인자 지끔은 쫌 괜찮드라구 근디 어렸을 땐 검거지 겁나 고생했지 .',
#  '기계가 요줌 이케 버튼 눌러 가주구 뽀글이 있다이가 뽀글이 고걸로 끓이느 긴데',
#  '가달 수술 행 걷주게 못 행 해보난',
#  '콩이영 비트도 갈곡 해실꺼여 .',
#  '아유 못써 수짱 두둑하게 생각하노 인자 얼매 됐어 ?',
#  '나 느 몽사 말릴 생가 없어 .',
#  '아따 분으로 쭐여서 허는 거이 내도 봤그는 근디 인제 그거이 개 완벼간 진실일지 그른 거에 대한 으혹도 있고이 어 이케잉 쇼킹했었던 거이 같구요잉 . 니기가 잘해브렀네 니기가 잘했네 . 자놈 보믄 쩌 매력이 있고이 자놈 보믄 자 매력이 있고이 마잉 사람마다 아따 처음엔 그렜제 근디',
#  '거 때이 옛날신디 보믄 근디 또이 낼 됨신게 거 악순환이 계속이 반복이 되부는 거 가지크냐 ? 완전하드하게 먹는디 아유게 거디 막이 좋은게 우린이 미깡 들어오는디 혼저 놈들 두어 끼 먹을 때이 일어난마씨 일행 아침 새벽에가 으까 거 자식들이랑 서방 매 매 거 다이 해뒹 밭듸 갔수게 너무이 먹는 게 닮 나맨 이거이 공비 두레기얜 영 해신디 공부는 커녕 걍이 거 사람도이 무사 영 자꼬 왔다갔다 햄신디사 게민 아시날 잔치 어짜피 마을회관에서 헐 게 아니 ? 동방은 어떵 완 ? 차이 탕 완 ?',
#  '나 이딴 닐 생길까 보그라 그래 아가리가 닳도록 얘기했건만 .',
#  '담에 하먼 조요운 직장 있으믄 함 소개시켜 줄텨 ?',
#  '아이고게 속았수다 .',
#  '카시로 그 연관 검색에 티아라 고 영상이 브러갓고 봤는디',
#  '니는 어뜬 점이 좋았었나 ?',
#  '알은 맞으믄 그양 앵간히 말을 돌려 가주구 주제를 돌려버리지 .',
#  '내는 오늘도 굶을라구',
#  '어 쫌 어렸을 띠 울 검거지 슈가슈가룬이나 이른 꺼 본 그른 그림체잖아 아무래두 일본 애니메이션이다 보니께 어',
#  '음 지가 사용하든 꺼를 인제 공기계 폰으로 해가꼬 남편이 헌 일날 요잉 년 정도 쫌 사용을 허고',
#  '긍꼬 자기만족으로 내 머 여행 갔대이 왔거나 자랑하꼬 싶은 고런 거마 가끔 인스타에 올린대이',
#  '내나 만큼이라도 부모님한테 쫌',
#  '비난의 종류는 선 부분보다 명확했어 .',
#  '아이 고거 아이 지가 이성미가 암 수술인가 뭐하구 유방암 수술이구 혀구 해니께',
#  '니는 라섹 해가지고 좋갰대야 고맙지 ?',
#  '어떤거냐민',
#  '금 또잉 인자 시부모님을 먼지 모시고 가자네 글면은 대체로 갔다 와가지고 사이가 안 좋아지는 것이여 왜냐믄',
#  '엔날에 인대이 쫌 오래된 긴데 호랭총각이랑',
#  '좋잖우 어니는 또 왜 ?',
#  '재작년인가 인재 냥이를 데꼬 왔사',
#  '어우 화장을 안했구나 우짼지 .',
#  '승질을 내블구 알은 보겠다 이래두 어는 시점이 가믄 머 가족이기도 혀구 해니께',
#  '고거를 이케 쫌 해줬음 좋겄어유 그리구 우리나라도 또 구 음악이 대한 것도 마이 넓어져서',
#  '뭐 외부를 쫌 돌아뎅기는 일은 쪼굼 자제하구',
#  '그려도 악도 따라가고 선 선 인디안 존슨이 간 디도',
#  '좀 안 조요운 영향을 받은 거이 같애서 건 좀 안타까운 거이 같아라 허지만 인제',
#  '할머이들 뭐 어무이들 뭐 마카',
#  '울 평상시에 강주 암 데나 가가지고 걍 묵은 국밥보다 맛이가 없드라 하두 맛탱가리 가 한나도 읎어 가꼬',
#  '왜서 암사나맨치 치마폭으 감싸구 뱅뱅 도우냐구 허게',
#  '아부님 아부지가 으제 타 박은 분한테 수리비 도라고 즌화 하셨어요 ?',
#  '긍까 적어도 질러 노는 내 성격이 그른 거여 질러 놔구 그냥 주급 나가 알으믄 삼천 선이었던 꺼 같애 . 구 땅이 땅에다가 나가 인자 거따 인자 게 머 그양 그른 생각을 들었었던 그지 그잉께 내 말은 또 잘 들으 아부지가 엣날에는 엄마가 뭐라꺼 하믄은 검거지 소리또 질르구 검거지 그랬는디 뭐 그른 껄 손재주가 필요한 그른 것들을 쫌 마이 찾았어유 .',
#  '행 영 딱 봐신디 막이 사람덜 막이',
#  '사진은이 언제랑 찍주만은 아 근디 겨울에는이 야외가이',
#  '벨로 알은 달다 그양 구움과자 이른 종류면은 딸기라떼나 초코라떼 이케 먹는 꺼 같여 . 양지 끓으 가주구 거따 동치미 구 국물하구 가미혀 갖고서로 그릏게 육수 허는 사람들두 있드라구 양념을 이케 혀구 구 우이 고구마 소스를 올리구 구 우이 괴기 올리구 검거지 이케 허는 건디 잉 그릏게 그른 식으루 그서 괴가라면다 좋아해유 캐 고기엔 쐬주 핸 잔 그려 가주구 쫌 빨갛게 돼가꼬 잘 알은 베기구 구워지면 먹겠는디 구 진자 게 기가 맥혀 . 고거 얘기가 탓할거 엄시 지 취향이 맞게 설탕 쫌 들 늫면 댜 알은 그텨 ? ? 긍까 아이 이케 다 준는 데도 있구려 반죽만 준 데도 있어 . 술 시켜 가주구 구 술 묵구 그라구 인자 스키야키 나오먼은 일대일로 해가꼬 이케 그양 보르면은 구 깻잎은 근디 내도 구 황도 겉은 껀 뭐헌티 먹는지 모르겄어 그서 내도',
#  '지굼이라두 처레미 가겠다고 그럴까 ?',
#  '긍까 그릏게 기장 짜꾸 엇 엇갈리더라구 오믄은 머',
#  '젤 용량을 마이 차지하느 기 은행 앱이래이 . 뭐 서른 종목이 고로 동시에 떨어지나 ? 뭐 짐 알아보꼬 있긴 하구마 혹시 니느 아 노 그래가주구 걍 걍 구경도 카민시 천천히 그라대이 그래이 만약에 심는다머 구동 구동 글 가자꼬',
#  '쫌 머 사람이 순진한 꺼 같어 근디 머 연예인은 머 그릏게 보이는 이미지 다 믿으믄 안되겠지만',
#  '어무이 . 아따 글지 마고 빠빠빨리 줘 . 매지 왔나 ? 달구라지몽댕이부터 뽀솨버려야지 뭐 . 이케 팡 이케 해가지고 바람으로 닫거나 이딴 게 있제 근까 나두 그른 게 얘기하기두 싫은데 떨다 뿐이래요 ?',
#  '저울기나 비오는 날은 발이 시렵지 .',
#  '그랬드니 고 요잉 아까침에 있자녀 손톱 한나 짜르면 어짜피 댓 개 맨 짜르게 된닥',
#  '아따 마잉 아야 여기보다 쌈짐막한 디 없을랑가 여기보다 쌈짐막한 디 없을랑가 마잉 겁 겁나 검색을 마잉 하지 .',
#  '아게 기 ? 난이 구젱이',
#  '겡 음 무신거 치킨도 호솔 한 군데만 먹어나신디',
#  '단장 사램들 불러 . 대전꺼정 갈라먼 마이 막힐텐데 . 왜서 무신 닐 인데요 ? 그래니까네 오라바이두 그래라 응 ? 왜서 엉겨 붙지 않겠다 싶으이까 섭해서 작업 건 건가 ? 중환자가 한고비를 개와 넘겼다 .',
#  '젊을 띠 그까 그릏게 될 땐 젊을 띠 마이 그른 껄 마이 느꼈는디',
#  '근디 인자 김필의 따른 곡을 들으믄 너머 고음 일 띠 야가 이케 갈라지는 특유이 목소리잖아 .',
#  '맨 맞어 .',
#  '안드로이드도 먼가 상용화 될려면 긍까 만들 내 혼저 실험실에서 똑딱똑딱 만들면은',
#  '기지예 울리 아예 두린 때이 세면은 아니였고예',
#  '또 게스트하우스도 머 핸 일 박 잘 댜 있는디 잘라면 또 핸 십 만 언저리 인자 해줘여 되는디 고거',
#  '오진율도 많댄 하잖아 .',
#  '만약이 고때는 코로나가 없어질 꺼 아녀 그랬음 좋겠다는 생각을 들구',
#  '즈 딴애란 요 부정적인 단어네 . 호솔 멀 멀 꺼 닮은디 . 가이 얜 있네 . 나는이 다이 봐줜 . 아게 잘도 가이 찡찡 너넨 손님 아이 줄언',
#  '고다음에 또 또 넘어가이까 또 인재 츤 오백원 요 돈천원 매치루 사는 사램이 해야 하니까니',
#  '그려 역시 사람은 마이 믿으믄 안 되야 어느 정도만 믿고잉 어느 정도만 해줘야 돼 .',
#  '근디 알앙 봐나난이 잘도 동백이 아게 모슬포에서 잘도 못 봐나신가',
#  '내 바꾼다구데 왜서 그래 .',
#  '주말에이 보낼거아니 ? 평일에 보내젠 ?',
#  '이근 당시이 가져온 거요 ?',
#  '툴렁 넘어가부런 아이고게',
#  '냉동실에 고간 있죠 .',
#  '그녀는 흥분하여 뜻두 알 수 웂는 말을 엉겁절에 지껄였어 .',
#  '쪼깨 그도 쫌 편안한 마음으로 어 에전에 연애하셨던 것들 쫌 떠올리민시 볼 수 있었느 내용이 아이래이 싶어갖꼬',
#  '올라와라 상가 머 먹구 가라 .',
#  '고급지게 쫌 먼가 쪼꼼 근디 젤네일은 제거하기가 대간해서 이케 쫌 그른 것덜 땜이 약깐 쫌 주 약깐 스 횟수가 쫌 줄어들게 되기는 했는디 마스크만 해니께 꽃 단장하는 곳도 귀찮드라구 인저는 진자 디게 뭐라꺼 허지 구 앞머리 한나로 이미지가 너머 틀리 보이드라구 긍까 학실히 엄마는 욕구가 쌓여서 기분이 나쁘믄 검거지 갑자키 검거지 화려하게 반지를 검거지 낀다던가 어짜피 머 흰머리 쪼꼼 있어도 괜찮아유 . 왜냐믄 학기 중에는 우리가 실습 해야되는디 실습 요리를 헐 띠 네일아트를 혀구 있으믄은 감점이 되니께 증말 긍까 근디 가는 집이 가믄 머리를 가발을 퍽 해가꼬 찝어 떤져 잉게 팔십멫 키로가 거진 나왔는디 칠십 아 근디 미쳤지 고거 어트게 내는 애를 그 따른 껀 다 캐도 문신은 몬 해게 햐 . 그서 지금까정 썼 싼 싼 제품을 썼었어 지끔은 인자 살짝 쫌 무리해가지구 십만 원짜리 사가꼬 쓰구 있긴 한디',
#  '어 겁나 애착이 있다기 보다는 검거지 따른 팀들헌티 검거지 애착이 그릏게 알은 가유 .',
#  '긍까 달달한 지는 다시는 애견을 알은 키우겠다구 맘 먹었는디',
#  '쩨일 존 건 쫌 건강한 재료로 만들어진 곳들이 증말 좋긴 하구나 .',
#  '온몸으로 느낄 수 있어가주고 내는 역부러',
#  '성 원시인들은 말야 여시 사양을 어태 핸지 알아 ?',
#  '건 그냥 낭구에서 따면은 된 거지 .',
 난 약 먹어야제 약 묵고 다이어트 혀야 되야 따른 방법은 없닥 생각한다 . 저녁도 좀 일찍허니 묵고 최대한잉 일고 시 이후에는 안 먹은다 생각허고 야식을 금지시킨다 요게 쩰 나가 실험을 혀 본께 쩰 효과가 있드라고 줄로도 허고 그러드만 가꼬 고 뒤로는 거서 모 하겠드라고 . 그러고 작년에 다씨 함 또잉 이자 헌 것이여 옆에가 지인이 고 으지가 야개서 중간에 꺼 불고 인자 안 헐 때도야 있고이 솔찌기 맨 끝까지 해도야 헌 시 키로 뺐드라 고 언닌 운동도 같이로 한디 . 이자 걍 그른 말이제 나가 모 낚시가 허벌 가고잉 싶다야 그른 말은 아니야 . 어딘가 먼가 좀 빠졌재 빠지기는 글지 않아 . 글제 긍께잉 . 긍게 난 빼고이 다이어트를 마이 안 해보고 또잉 어뜬 약을 복용한 적이 읎어서 좀 치매 입고 마잉 그렇고 댕기고 싶제 않어 항시 헌 말이야 있으야 지는 지 몸에 만족을 한디 지 나름대로의 고 가게를 하믄서 체인점을 낼라고 인자 카만히 있기 모 헌께 머라고 한나 깔짝깔짝 혀 봐보고 또잉 헬스장 갔다 왔응께는 일본이고 그다음에가 인자 묵은 거이 그담에 운동 이래야 운동은 마지막 이래야',
#  '겐 글쓴이가 놀랑 보난 방충망에 어떵 여자가 놋이 놋이 짓눌린 차 웃고 있었댄 걍 하영 걍 놈이 집이 가주게 할망한틴 무시것이 이신게 . 설제기 크댄 가슴을 오뚜기 캠프를 나냥데레 간 예 어멍은 영 미덥지 안허여수다 . 호꼼 호솔 맑게 해야되는거 아니 ? 알도 하도 큰큰해그네 굵어수다 호꼼 영 식데레 . 요 나무꾼이 참말러레 착헌 사람이우다 . 거 집이가 이층이연 시골죙이는 인제 또이 딴 이야기도 한번 생각행 시작하맨 보카마씨 . 겅행그넹 매 결혼을 결혼 ?',
#  '만제보는데 돈드나 ? 만지지두 못하게해 ! . 바우 주벤에 사는 괴기가 있다 . 어는 내를 갑재기 팍 죽구 말았어 . 아매두 봄이 되먼 양석이 모자라겠구나 . 지들꺼는 아꿉고 남어 꺼는 아이 아깝나 ? 웃는 얼구리에 춤을 뱉지 말거라 . 꼿을 가꽈 팔기까지의 과정을 혹예 아시나요 ? 컴퓨터는 어타 사는 기 쩨일 좋아 ? 개개이 계산하도록 하죠 . 그근 나두 마탕가지니까 오해마세요 . 이바 담버텀은 패션쇼 갈 질 굽이 낮은 껄로 신으려고 . 이러이 환자에게는 인제 손으 쓸 방도가 없어 .',
#  '땅을 파 놨거든요 ?',
#  '그 마잉 궁합이하고 명당 뭐 그른 영화들도 나왔었어잉 ?',
#  '저깔질하는 법은 츰에 지대로 배우콰야 한다 .',
#  '쫌 쫌 쫌 얍쓸해진거 깥은 느낌이 든다야',
#  '아까 거 나맨 예 당하젠 한디 거 소나이도 겅 허지 않애샤',
#  '재채기를 크게도 햄져',
#  '내 언급한 바 있든 그이 취약한 그룹은 특벨한 보완점과 관심 사항이 논다 .',
#  '효과가 아에 없고잉 애만 개고생 시키고 이래블면 안 되지 .',
� 빠지게 노력 봉사한 댓간데 . 고내이 갔으이까 요상간 주택에서 핸다펀두 아이 받아 . 내리가 있사 동세가 울산 내리가 있슬 동안은 아븐님 내 모시면 되제 뭐 . 아바이 요 사램 코피나게 일해요 . 알았어 . 가가주 마카 이애기하라우 준다니까 . 그기 첫째야 좋아가주구 하는기 . 그른 일이 있었다면 내인데 야길 했어야지 . 즈어머이 욕하면서두 지두 또 그렇게 . 으젠 우동이 그래 먹구 싶었다 하드이 ? 어띃게 어띃게 젖을 비레 가주구 돌아오는데 태어나 츰으로 빙 땡큐 어태 마카 만지나 진뗑이 극정했었는데 고등핵교 질 핸드볼 주전으로 뛴 저 있사 . 쐬푼 빽 불에두 사램 죽인다는 거 . 기래두 죽지는 않고 어데 있나 부네 . 느 내 개뼉따구라 개가주 기부이 나쁘나 ? 어부 먹자 . 갬 동료로써 부택 하꾸마 내 컨디션 아이 좋아가주구 머엉이 매치루 갈래 ? 요 예자 지 예자 슨 봐가주고 조근 맞는 예자 찾는 껀 신문두 볼겸 가껌 가요 . 그이 간나 누그야 ? 벵원에 칭구 있댔잖아요 . 여적지 이상한데 ? 느 생각만 하구 근디 나가 몰르는 게 있어 . 생각보다 마이 아이 걸렸네 . 오놀 스믈 일굽살 이에요 . 입양시설 그른건 알아봐서 뭐할려구 ? 이케 쫌 올라가는 기 방지된다 하드라고 느 없음 내 혼재 진지 해야 돼 . 개가주 내 다써 시에 인나서 밥으 하구 여서 시 되먼 집서 떠나야 돼 .',
#  '학창 시절에 낸 장창 문제로 일으켰어 . 학업엔 전예 신겡을 아이 썼지 .',
# ...
#  '물론 구 사제관도 주구유 해가꼬 머 구 사제복이냐 인자',
#  '강냉이가 구가 막히잖아 .',
#  '이녁 의견에 찬성하고 습지 만두 .',
#  '그서 기분을 쫌 좋께 캐 주꼬 싶어갖꼬',
#  '감저',
#  '지느 첨 들었을 땐 디께 쫌 전형적인 인대이',
#  '마트에서 사가꼬 와가꼬 뎁히기만 허믄 대는 거이 있잖아 .',
#  '지 녀나는 도대처 왜서 자주 삐지냐 ?',
#  '애호박 도라지 더덕 등을 말려놓고 깻잎 부각 풋고추 부각 감자녹말 등을 저장 음식으로 만들었댜 .',
#  '어머이가 어태 돈으 마이 벌어 ?',
#  '약을 떡 끊꼬 이라니께 인대이',
#  '고무님이 좋아하시겠네요 .',
#  '하르바이께 빨라당 오시라고 여쭈어라 .',
#  '쫌 생각해보니께 지느 걍 현실적인 꺼 같애예 .',
#  '일본 말고느 유럽을 쫌 마이 다녀왔었는데',
#  '될 수 있으믄은 쫌 산책 주말 겉은 경우에는 워떤 시간대를 정해서',
#  '근까 집접 가가지고 싸는 으미가 없이 자세히 살펴보지도 모다고 걍 대강 이르케 집고',
#  '기본적인 겟들이 헌 달에 내잉 친구 본께 헌 십만 원은 기본으로 들어가드만 마잉 간식이며 혀 가꼬 근디',
#  '채고 크다한 실수는 넝력 이상으루 친절하려 노력하는 그니',
#  '저가 쫌 어 친구들이 알은 귀찮게 헐 수 있게 먼가 여앵 가기 쩐이',
#  '영 곧는거',
#  '아게 점북 행 해줘사야 되켜 .',
#  '그러꼬 니 어데가 샀는지를 링크 쫌 보내주래이 .',
#  '그택 혼재 마 마이 아풍 사램이래요 .',
#  '게니까 양',
#  '차를 이르케 지끔은 인대이 차를 알았느 태아 보내는데',
#  '에스유브이가 쫌 차체가 넓으니께',
#  '온쥉일 서서 일하게 .',
#  '하느님과 요 수도회를 위해 살켜 영 허라 부난 종신서원을이라는 거 해마씨',
#  '난이 고게 잘도 중요하덴 생각햄주게 .',
#  '어데루 가요 내 간 짝은 이짝인데 뭐해요 ?',
#  '고 밥을 밥을 묵고 인자 계산을 하믄서',
#  '나가 아까침에 말했자녀 부동산하고 주식은 거즘 차이가 없닥 하간디',
#  '쫌 마이 알았느 좋노 상황이 예전보대이 대구 그 신천지를 사건 때보다느',
#  '왜냐믄 아들 묵느 사료가 다가 아이꼬',
#  '으이 도두 동세 .',
#  '그이 카세트는 질이 뻐꾸기눈물 떨어졌다 .',
#  '고등학교고 중학교고 대학꼬지라도 다 시깁써게',
#  '아따 마 쥐똥 아이 한다는 껀 느머 심하잖아 .',
#  '마옴에 병두 치로됐나봐 . 벨일 없사 . 기래두 빨라당 쐬푼 알아봐야지 . 머이 어째 ? 이거는 단순히 몰르는 기 아이라 근까 근디 우타하와 ?',
#  '아이고게 울리 거 누겐 강이네 시 명이예 있네 쇠 한 마리 그디서 잡아네 이젠이 십이 월에 거 막이 축제 닮은 꺼도 하네 . 고딩 때이 해산물 거 어디가난 예 아이고게 막이 보도 울리 비쌍 못 먹는 해산물들 아니라 ? 화려해부니까 화려해부난 나맨 서귀포 소장데레 이실때 다해가지고 오 만납서주 몇 나완 근디 거 안봔 시베리아 한 열차 극과 극 허라 부난 잘못행 북한 사람덜 역시 어게 중 상 때이 어게 왔언 . 무신 나옵서 밉성발랑 죽어지쿠나 이노무 서방도 원예 동맥경화 수술하단이 경해 죽언 . 고게 무사 꿀인지 잘도 몰란 .',
#  '부 이케 쓰노 놔 가주꼬 이케 버스 안에서 보꼬 외우꼬',
#  '너무이 오랜만이 놀안 울리 어멍 하도 예뻤주게 시방 나 모습에서 살 빠진 나옵서 겅하난 요 놈이 코로나가 땜에 영 난린디 영 중이 가달 닮은 게 잡아먹어 되크녠 야생동물을 . 매누리들은 지쳠주마씸게 해보난 학교를 아이 댕기젠들 허는디 아직 학원 알아봐 줍서 한번 알아봐그넹 할망이 밖거리에 남동기만 불렁어내 가이만 매 차려주고 닮으고 싶지 않안 . 니 겅 그건가 계좌번호가 거 맞다게 디자인을 다이 잘라부렀댄 대표가 요 어마어마한 내통을 안햄시냐 어떻게 헐 말고게 긍까는 저디 마라도 짜장면이 또이 우도로는',
#  '난이 경 해집네다 난이 드렁청하게 요 등급 올라가던디 겁나 야이 히어뜩허게 바빴던 모양이라 . 시 번째 말재아씨가 왓 주연 아니라는 말 듣자마자이 수박 들렁 유유히 조연스럽게 가더랜 . 아이 근디 택배가 기랜 지가 해사 헐 할당량을 채워야 시간에 상게 어시',
#  '그이 사나',
#  '아 뭐 겁나 오래에 헐 지를 알았드만은 상영시간 헌 헌 시간 반 쫌 넘었제 헌 두 시간 됐나 ?',
#  '걍 와지는 게 닮',
#  '다른 사람들은 저랑 헤어지믄 먼저 연락이 오꼬',
#  '뭐러 핸 기 있어고 상구두 점슴두 마카 내 차렸구만 .',
#  '승 죽어 ?',
#  '여꽝 전체를 빌려야 되난 빌리는 돈도 하영 들렁 해서만은',
#  '탁 . 울리 탁구 얘기 해난 게 호솔 골아봐',
#  '엉댕이가 들썩 거리지는 않는다고 혀야 대나 약깐 그른 느낌이 있는 거이 같애 .',
#  '그 기프티콘에 가격만큼을 빼줘서 나가 쪼까 더',
#  '키스하는 껀 어뜬 기분이야 ?',
#  '그이 압력이 얼매나 대단하라우 .',
#  '어 리먼 사탠가 거 때두 그때도 겪었었구 어트게 보믄 지끔두 어트게 보믄 금융 위기일 수도 있으 게 삼 차',
#  '저게 아부님이 먼전 선약 허신 게 같으이까 그래 해라 .',
#  '접데 울 아따 구해준 게 감사해요 .',
#  '함 몸에서 분리되었던 영혼은 순결하라우 .',
#  '긍까 변비 겉은 곳도 실은 소소한 거잖어 우리가 놓치는 거지 . 그래두 이케 뱃살이 마이 없으니께 핏은 쫌 있으 랑 그랴 . 생명이 그까 질병 땜이 생명이 위험했던 쩍은 없었던 꺼 같아유 . 오빠가 전을 잘 몬 먹어서인지 아니믄 알은 익은 껄 먹어가꼬 그랜지 갑자키 엄마가 인나 보라구 허는 겨 밤이 왜냐먼은 약이 갱장히 비싸 . 올 봄이 인자 재건축을 혀 가주고서는 부처님을 모시더라구 니나 해니께 그릏게 삼 개월 동안 꾸준히 먹지 우덜은 먹다 말어 . 그려 고모부가 또 그릏게 있느냐구 몽댕이 들구 그랬드냐 그릏대 . 쩌번이 나가 위 땜이 요즘이 꼐속 병원을 거여 되는디 바뻐서 갈 시간이 읎는 거여 먼가 습관 식습관도 먼가 쫌 굶어서 빼면은 먼가 먹으먼은 알은 된단 그른 생각을 허기 땜이 머 그른 것까정 긍까 따져여 된다구 하드라구 영양제 보충할 띠 그른 꺼 앵간히 보여 되는디 테레비를 또 마이 보나 비네 ?',
#  '아이가이고 큰일났져 큰일났져 선생님께 골아야지 골아야지',
#  '히야한테 신세 아이 질래 .',
#  '근디 고게 꼬치 육 종이랑 팔 종이 나오는 메뉴가 이서 .',
#  '왜냐민 잘도 어려웠언 날 포함행 몬딱',
#  '웜마 쉰다매 ?',
#  '좀 더 객관적이지 않으까 인제 뭐 이른 이야기도 하구요잉 .',
#  '어 . 나맨 겁나 매날 매날 배리는 거 복희라고 인 ?',
#  '기언이 얘가 생겨버렸다 뭐 이른 식으로 이케잉 찐 전개가 돼가지고 아 좀',
#  '울 누우가 결혼식날 뻥 차버린 불쌍한 성',
#  '아게 나맨 어짓께 신제주 벌겅헌 정시집 갔댄 했네 .',
#  '으런들은 겨론하는 껄로 알구 계셔서',
#  '쇠꼽새 탑승 시간은 언제입니까 ?',
#  '더와 비는 기 여름이 왔나 보다 .',
#  '이기 보자보자 하이까 .',
#  '아랐싸요 아바이',
#  '머 삶이 다 게 디는 껄 이골 어떡하느냐구 벌라구 하믄은 머 벌어서 어는 쩡도 여유가 생겨야지',
#  '그라갖구 인자 아 그냥 지 볼게유 이러믄서 인자 보러 갔지 .',
#  '나이 내세울 수 이신 뭔가가 없다민 나라도 경할꺼 닮은 거라 나이 거 사정이라도 겐',
#  '좀 사소한 거에서도 행복을 뒤지시로 싸는 삶을 살고잉 싶은디',
#  '겅행 걍 디피용 하나 썩 빼놓네 . 나옵서',
#  '괜잖은 꺼 같은디 그리구 요기 센터장님이 계셔 긍까 대빵 유 부서이 유 분이 퇴근할 때까정 다 퇴근 알은 혀 .',
#  '긍게 그땐 음',
#  '그래이 무튼 염색은 쪼깨 더 고민을 해보느 걸로 하대이 .',
#  '지굼 어데서 만 대답질이야 확 .',
#  '결국에느 컴플렉스 겉은 경우에느 인대이 내나 본인의 맘이 걸려있는거라꼬 인대이 생각할수도 있지만은 요고도 도 인대이 예 성격이 쫌 콤플렉스인데 인대이 꼬 나이대에서 걍 직독 직해를 해뿜 컨 산이라느 되 이름이 된대이 부리니께 쫌 약깐 어뜬 건지를 물어봐도 되노 꾸미께 됐느 계기가 뭐꼬 걍 다른 운동은 알았느 가봤꼬 도 집이 강변 근처에 있어가 예 어트께 캐야 되는데 ? 그 없대이 때만의 지를 때만의 그른 어뜬 패션인가 니 친구맨치로 내도 내나 이기 중에 그 인대이 서로 대께 풀꼬 인대이 쫌 지끔도 짐 겁나 친하께 지내는데 하이튼 그랬었었는데 뱃살마 쪄서 그때도 그 사람의 감정이 쫌 마이 그렇겠대이 카느 글렀느 얘기들은 이케 뭐 캐야 되가 카느 일들이 쫌 있디 보이꼬 그기에 대해서',
#  '닌 너넨 거 여행이 중에서 무시것이 젤 좋안 ?',
#  '쫌 신기하긴 하구마',
#  '울 어마이가 프랑스인이세요 .',
#  '가다 즈네 내려줘요 .',
#  '왜서 자꼬 그러우',
#  '그서 너거들은 몬 가겠대이 다음 달에 날짜를 함 맞춰볼꼬 ?',
#  '아 이기 얼매나 오래 걸리느 꺼꼬 카꼬 캐샀는데 인대이 겉은 회사에 쪼깨',
#  '다이어트가 헌다는 거이 그렇고 쉬운 거이 아닌디 본 으지가 하도 떨어지드라고',
#  '어 너무이 인제 받앙만 이 아이라부난',
#  '오갈단지 겨론 문젠 한군한테 맡기겠다는 생각이시기 때미에 허락하신 거야 . 대련님 다신 핸 벌 생각하실 수 없으십니까 ? 낸 뒈질 망쿰 애써두 갖을 수 웂는 사램인데 이딴 데 츰 삔침 거죠 ? 내 나가 생각하는 그른 대단한 사램 아냐 . 내란 인가이 얼매나 이기적인 놈인지 . 그간 아이씨 사골을 하두 뺏아 마셨더니 야 성님 타 핸 따가리 하세요 . 먹든 게 주시므는 쐬푼 내라는 껀 말이나 아이 돼지 . 꽤똥 마이 줬대나 봐 . 으이구 춥대이 . 싱야 뭐해 ?',
#  '발 닦는디',
#  '그이 가아지가 인재 커가 아들이 생게 대가족이 되었잖소 .',
#  '겅해도 거기선 입맛 잘도 맞았다이 .',
#  '요잉 아파트가 아잉 거이 같뎌 근디 아니여 요잉 아빠트 맞어 그랬드니 요잉 아빠트 똑같은 이름이 또잉 있다는 거여 .',
#  '어뜬 영화에서 보이까 마카 그래 카는 게 같던데 .',
#  '랑 학창 시절 생각하믄 랑 고로 화나느 일마 생각나는지를 몰르겠는데 카페 카니께',
#  '붙여늫기나 불러오기나 머 블로그 보거나 친구하구 채팅하거나 요런게 다 혀구 싶을 쩡도로 많으믄',
#  '논산 동학사에서 논산 간 길 있잖여 고기가 쪼꼼 한가하드라구 쭉 직진 슨 도로가 돼있구 간 늦게 오니께 그러네 . 그 울 손자들이 집 식구마다 다 가주구 댕기니께 나뽀구 지가 병원이 데꼬 갔드냐 그라고서는 샤크존 값만 줬댜 .',
#  '근디 인자 끄때 친구가유 아 나가 돈 내줄 테니께 그냥 가자 근디 당시 친구가유',
#  '변하는디 유 정치의 견제 세력이 지끔 부족해서 그랴 .',
#  '디졌어 그까 나가 갑자기 요잉 상황을 모 받아들이는 거야 .',
#  '긍게 거즘',
#  '그래가주구 다시 있다이가 인지를 팍 떨어져가지꼬 갸가 십 불대까증 떨어졌단 말이라 .',
#  '남들은 시무살에 카는 이은애를 이제사 허구 근데 요중간은 통 강의 아이 나가니 ?',
#  '공다지로 간병인 하내기 생겼다치고',
#  '오라바이 프리젠이션 준비 잘해야 돼 .',
#  '뭐 잠깜 헐 일날 없을 띠 쪼끔씩 보기느 조요운 거이 같아라 요게 스토리가 음 네가 난테 약깐 에스에프를 안 본다고 그러는디 요게 실은 내도 에스에프 영화잉 마이 봤그는 내도 마션도 봤고잉 지가 그걸 왓쳐 플레이어라는 어플 있거덜랑요잉 그거이 좀 재밌드라구요잉 마이 긍께 좀 이르케 지방과 그 특별시의 차이를 지가 고때 몸으로 느꼈던 기억이 납니다 . 오미 고때 고 삔또가 잊혀지지 안은 겨 .',
#  '내 왜서 선봐서 두 쎄 벌 만났는데 집안끼리 하머 야기 마카 오가고',
#  '어찐가 몰라도잉 요잉 때깔이 안나더만',
#  '허담은 또잉 고 어린이집 자격증도 빌려줘 .',
#  '마 하지마 간신히 .',
#  '그거를 위해서 또 쎄빠지게 불나게 알 거구',
#  '솔찌기 다른 싸람들도 인정할 만치 사진이 좀 달 나왔잖여 긍께',
#  '고 뒤로 마잉 꼐속 그렇고 허다가 헌 멫 일이 주 지나놓고 블어가지고 인자 친구들도이',
#  '웜마 이른 꿈이 마은 게잉 모 쫌 불안하기도 하믄서 좀 그걸 인제 현실적으로 인제 놨다고이 했자녀 긍께 고 뒤로 꾼 꿈이 뭐여 ? 학력이 안되서 난중에 이자 그래가꼬 발 눟고 이자 얘기 하 허고 있는디 울 아부지가 이케잉 활동하는 걸 개 마이 이케잉 허고 싶여 하시드라고 긍께 긍께 난 또잉 따른 직업을 또잉 가꼬 싶으긴 한디',
#  '잔치 해먹젠허난 핑계에 무신거 벚꽃놀이 구경허고 막이 게난 장사하는 덴 좋을 게 닮아마씨 거디 소곱에 통드리 버려상 가사주 . 아게 괌 거디 그디도 시방 가믄 딱 좋을 땐디 아이 거디 원 높으니깐 빨리 피여 막이 어디여 어디여 막이 돌아댕기지 말앙 엄마추룩 어찌됐던 포르투갈도 다이 바당 근접해 있고이 스페인도 바닥 근접해 이신디 가도이 바당은 제주도가 짱 다이 뵈리는 게 닮아 . 만반의 준비는 됑 인 찬 겁난 튼튼하곡 막이 겅한디 위로부떠 요 상 일본도 한번 더이 가카 요코하마 ? 나는이 상하이에 가실 때이 다이 겅해연 사람덜 다이 바닥에도 앉앙있고 의자에도 앉앙있고 아게 니 잘도 제다 요 모을 영 행 들어강 아고 끝나부렀지양 ? 죙일 걸언 양 울리 동네는예 첨에 강 무신 영 시상이 이신고 했주마씨 . 다이 돌앙 땡기질 못해도 거 어느거 만납서주 그디만 봥 왔겠지 일본에서이 사불어 오난 비싸게 파네 . 오 학년정도 되시큰게 . 잘도 테레비에서 배리는 요 원두막 닮은 디 있네 게민 난이 당연히 삼십오일오일을 추가 받는 건게 나 손에 돈이 들렴져 이시난 트랜스젠더 무대에서 춤추던 성님이 나 손에 돈이 이시난 무대위러레 올라오랜 호꼼 영하당 보난 요 나이가이 들어가지는 게 닮다는 샘토막이 들맨 .',
#  '긍게 맞어잉 그른 부분이 있어 .',
#  '게난 나 말이게',
#  '여그서 설거지 알바를 하간디 나가 접시인지 접시가 나인지 모를 정도로잉 오고',
#  ...]

# %%
len(enc_corpus)
# Out:
# 10000

# %%
len(dec_corpus)
# Out:
# 10000

# %%
print(enc_tokenizer.EncodeAsPieces(enc_corpus[200]))
# Out:
# ['▁', '<gs>', '▁i', '▁mean', '▁he', '▁s', '▁right', '▁so', '▁i', '▁don', '▁t', '▁have', '▁anything', '▁to', '▁say', '▁.']

# %%
print(dec_tokenizer.EncodeAsPieces(dec_corpus[200]))
# Out:
# ['<s>', '▁지느', '▁야가', '▁근꼬', '▁맞', '느', '▁말', '▁하니께네', '▁지가', '▁칼', '▁말이', '▁없은', '▁거', '예', '에', '▁그서', '</s>']

# %%
print(enc_tokenizer.EncodeAsIds(enc_corpus[900]))
# Out:
# [3981, 8, 10, 22, 19, 357, 217, 219, 1106, 3988, 16]

# %%
print(dec_tokenizer.EncodeAsIds(dec_corpus[900]))
# Out:
# [1, 81, 2204, 26, 2541, 369, 2524, 2835, 9, 2]

# %%
# 토크나이저를 활용해 토큰의 길이가 >5 이상인 데이터를 선별하여 src_corpus 와 tgt_corpus 를 각각 구축하고, 텐서 enc_train 과 dec_train 으로 변환
src_corpus = [] #영어
tgt_corpus = [] #사투리

assert len(enc_corpus) == len(dec_corpus)

# 토큰의 길이가 xxx 이하인 문장만 남깁니다. 
for idx in tqdm(range(len(enc_corpus))):
    src = enc_tokenizer.EncodeAsIds(str(enc_corpus[idx]))
    tgt = dec_tokenizer.EncodeAsIds(str(dec_corpus[idx]))
    
    if len(src) >= 5 : 
        src_corpus.append(src)
        tgt_corpus.append(tgt)

# 패딩처리를 완료하여 학습용 데이터를 완성합니다. 
enc_train = tf.keras.preprocessing.sequence.pad_sequences(src_corpus, padding='post')
dec_train = tf.keras.preprocessing.sequence.pad_sequences(tgt_corpus, padding='post')
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
# # 훈련 데이터와 검증 데이터로 분리하기
# enc_train, enc_val, dec_train, dec_val = train_test_split(enc_data, dec_data, test_size=0.05)

# %%
# enc, dec 의 seq_length는 달라도 상관없음.
print(enc_train.shape)
print(dec_train.shape)
# print(enc_val.shape)
# print(dec_val.shape)
# Out:
# (9953, 918)
# (9953, 1070)

# %%
dec_tokenizer.encode('<jd>')
# Out:
# [1, 2490, 5, 2]

# %% [markdown]
# # Step 3. 모델설계

# %% [markdown]
# ## Positional Encoding

# %%
# pos - 단어가 위치한 Time-step(각각의 토큰의 위치정보값이며 정수값을 의미)
# d_model - 모델의 Embedding 차원 수
# i - Encoding차원의 index

def positional_encoding(pos, d_model):
    def cal_angle(position, i):
        return position / np.power(10000, int(i)/d_model)  # np.power(a,b) > a^b(제곱)
    
    def get_posi_angle_vec(position):
        return [cal_angle(position, i) for i in range(d_model)]
    
    sinusoid_table = np.array([get_posi_angle_vec(pos_i) for pos_i in range(pos)])
    
    # 배열의 짝수 인덱스(2i)에는 사인 함수 적용
    sinusoid_table[:, 0::2] = np.sin(sinusoid_table[:, 0::2])
    # 배열의 홀수 인덱스(2i+1)에는 코사인 함수 적용
    sinusoid_table[:, 1::2] = np.cos(sinusoid_table[:, 1::2])
    
    return sinusoid_table

# %% [markdown]
# ## Multi-Head Attention

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model
        
        self.depth = d_model // self.num_heads
        
        self.W_q = tf.keras.layers.Dense(d_model)  # Linear Layer
        self.W_k = tf.keras.layers.Dense(d_model)
        self.W_v = tf.keras.layers.Dense(d_model)
        
        self.linear = tf.keras.layers.Dense(d_model)
        
    def scaled_dot_product_attention(self, Q, K, V, mask):
        d_k = tf.cast(K.shape[-1], tf.float32)
        
        # Scaled QK 값 구하기
        QK = tf.matmul(Q, K, transpose_b=True)
        scaled_qk = QK / tf.math.sqrt(d_k)
        
        if mask is not None:
            scaled_qk += (mask * -1e9)
        
        # 1. Attention Weights 값 구하기 -> attentions
        attentions = tf.nn.softmax(scaled_qk, axis=-1)
        # 2. Attention 값을 V에 곱하기 -> out
        out = tf.matmul(attentions, V)
        return out, attentions
    
    def split_heads(self, x):
        """
        Embedding된 입력을 head의 수로 분할하는 함수
        
        x: [ batch x length x emb ]
        return: [ batch x length x heads x self.depth ]
        """
        bsz = x.shape[0]
        split_x = tf.reshape(x, (bsz, -1, self.num_heads, self.depth))
        split_x = tf.transpose(split_x, perm=[0, 2, 1, 3])
        return split_x
    
    def combine_heads(self, x):
        """
        분할된 Embedding을 하나로 결합하는 함수
        
        x: [ batch x length x heads x self.depth ]
        return: [ batch x length x emb ]
        """
        bsz = x.shape[0]
        combined_x = tf.transpose(x, perm=[0, 2, 1, 3])
        combined_x = tf.reshape(combined_x, (bsz, -1, self.d_model))
        return combined_x
    
    def call(self, Q, K, V, mask):
        """
        Step 1: Linear_in(Q, K, V) -> WQ, WK, WV
        Step 2: Split Heads(WQ, WK, WV) -> WQ_split, WK_split, WV_split
        Step 3: Scaled Dot Product Attention(WQ_split, WK_split, WV_split)
                 -> out, attention_weights
        Step 4: Combine Heads(out) -> out
        Step 5: Linear_out(out) -> out
        """
        WQ = self.W_q(Q)
        WK = self.W_k(K)
        WV = self.W_v(V)
        
        WQ_splits = self.split_heads(WQ)
        WK_splits = self.split_heads(WK)
        WV_splits = self.split_heads(WV)
        
        out, attention_weights = self.scaled_dot_product_attention(
            WQ_splits, WK_splits, WV_splits, mask
        )
        
        out = self.combine_heads(out)
        out = self.linear(out)
        
        return out, attention_weights

# %% [markdown]
# ## Position-wise Feed-Forward Network

# %%
class PoswiseFeedForwardNet(tf.keras.layers.Layer):
    def __init__(self, d_model, d_ff):
        super(PoswiseFeedForwardNet, self).__init__()
        self.w_1 = tf.keras.layers.Dense(d_ff, activation='relu')
        self.w_2 = tf.keras.layers.Dense(d_model)

    def call(self, x):
        out = self.w_1(x)
        out = self.w_2(out)
            
        return out

print("슝=3")
# Out:
# 슝=3

# %% [markdown]
# ## Encoder 레이어 구현하기

# %%
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, n_heads, d_ff, dropout):
        super(EncoderLayer, self).__init__()
        self.enc_self_attn = MultiHeadAttention(d_model, n_heads)
        self.ffn = PoswiseFeedForwardNet(d_model, d_ff)
        
        self.norm_1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.norm_2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        
        self.do = tf.keras.layers.Dropout(dropout)
        
    def call(self, x, mask):
        # Multi-Head Attention
        residual = x
        out = self.norm_1(x)
        out, enc_attn = self.enc_self_attn(out, out, out, mask)
        out = self.do(out)
        out += residual*1 
        
        # Position-Wise Feed Forward Network
        residual = out
        out = self.norm_2(out)
        out = self.ffn(out)
        out = self.do(out)
        out += residual*1 
        
        return out, enc_attn

# %% [markdown]
# ## Decoder 레이어 구현하기

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(DecoderLayer, self).__init__()

        self.dec_self_attn = MultiHeadAttention(d_model, num_heads)
        self.enc_dec_attn = MultiHeadAttention(d_model, num_heads)

        self.ffn = PoswiseFeedForwardNet(d_model, d_ff)

        self.norm_1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.norm_2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.norm_3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.do = tf.keras.layers.Dropout(dropout)
        
    def call(self, x, enc_out, causality_mask, padding_mask):
        # Masked Multi-Head Attention
        residual = x
        out = self.norm_1(x)
        #out, dec_attn = self.dec_self_attn(out, out, out, causality_mask)
        out, dec_attn = self.dec_self_attn(out, out, out, padding_mask)
        out = self.do(out)
        out += residual
        
        # Multi-Head Attention
        residual = out
        out = self.norm_2(out)
        #out, dec_enc_attn = self.enc_dec_attn(out, enc_out, enc_out, padding_mask)
        out, dec_enc_attn = self.enc_dec_attn(out, enc_out, enc_out, causality_mask)
        out = self.do(out)
        out += residual

        # Position-Wise Feed Forward Network
        residual = out
        out = self.norm_3(out)
        out = self.ffn(out)
        out = self.do(out)
        out += residual

        return out, dec_attn, dec_enc_attn

# %% [markdown]
# ## Encoder와 Decoder 클래스를 정의
# EncodeLayer 와 DecoderLayer 를 모두 정의했으니 이를 조립하는 것은 어렵지 않겠죠? 이를 이용해 Encoder와 Decoder 클래스를 정의합니다.

# %%
class Encoder(tf.keras.Model):
    def __init__(self, n_layers, d_model, n_heads, d_ff, dropout):
        super(Encoder, self).__init__()
        self.n_layers = n_layers
        self.enc_layers = [EncoderLayer(d_model, n_heads, d_ff, dropout) for _ in range(n_layers)]
        self.do = tf.keras.layers.Dropout(dropout)
        
    def call(self, x, mask):
        out = x
        enc_attns = list()
        for i in range(self.n_layers):
            out, enc_attn = self.enc_layers[i](out, mask)
            enc_attns.append(enc_attn)
            
        return out, enc_attns

# %%
class Decoder(tf.keras.Model):
    def __init__(self, n_layers, d_model, n_heads, d_ff, dropout):
        super(Decoder, self).__init__()
        self.n_layers = n_layers
        self.dec_layers = [DecoderLayer(d_model, n_heads, d_ff, dropout) for _ in range(n_layers)]
        
    def call(self, x, enc_out, causality_mask, padding_mask):
        out = x
        dec_attns = list()
        dec_enc_attns = list()
        for i in range(self.n_layers):
            out, dec_attn, dec_enc_attn = self.dec_layers[i](out, enc_out, causality_mask, padding_mask)
            dec_attns.append(dec_attn)
            dec_enc_attns.append(dec_enc_attn)
        
        return out, dec_attns, dec_enc_attns

# %% [markdown]
# ## Transformer 완성하기

# %%
class Transformer(tf.keras.Model):
    def __init__(self, n_layers, d_model, n_heads, d_ff, src_vocab_size, tgt_vocab_size,
                 pos_len, dropout=0.2, shared=True):
        super(Transformer, self).__init__()
        self.d_model = tf.cast(d_model, tf.float32)
        
        # 1. Embedding Layer 정의
        self.enc_emb = tf.keras.layers.Embedding(src_vocab_size, d_model)
        self.dec_emb = tf.keras.layers.Embedding(tgt_vocab_size, d_model)
        
        # 2. Positional Encoding 정의
        self.pos_encoding = positional_encoding(pos_len, d_model)
        # 6. Dropout 정의
        self.do = tf.keras.layers.Dropout(dropout)
        
        # 3. Encoder / Decoder 정의
        self.encoder = Encoder(n_layers, d_model, n_heads, d_ff, dropout)
        self.decoder = Decoder(n_layers, d_model, n_heads, d_ff, dropout)
        
        # 4. Output Linear 정의
        self.fc = tf.keras.layers.Dense(tgt_vocab_size)
        
        # 5. Shared Weights
        self.shared = shared
        
        if shared:
            self.fc.set_weights(tf.transpose(self.dec_emb.weights))
        
        
    def embedding(self, emb, x):
        """
        입력된 정수 배열을 Embedding + Pos Encoding
        + Shared일 경우 Scaling 작업 포함

        x: [ batch x length ]
        return: [ batch x length x emb ]
        """
        seq_len = x.shape[1]
        out = emb(x)
        
        if self.shared:
            out *= tf.math.sqrt(self.d_model)
        
        out += self.pos_encoding[np.newaxis, ...][:, :seq_len, :]
        out = self.do(out)
        
        return out
    
    def call(self, enc_in, dec_in, enc_mask, causality_mask, dec_mask):
        # Step 1: Embedding(enc_in, dec_in) -> enc_in, dec_in
        enc_in = self.embedding(self.enc_emb, enc_in)
        dec_in = self.embedding(self.dec_emb, dec_in)
        
        # Step 2: Encoder(enc_in, enc_mask) -> enc_out, enc_attns
        enc_out, enc_attns = self.encoder(enc_in, enc_mask)

        # Step 3: Decoder(dec_in, enc_out, mask) -> dec_out, dec_attns, dec_enc_attns
        dec_out, dec_attns, dec_enc_attns = self.decoder(dec_in, enc_out, causality_mask, dec_mask)
        
        # Step 4: Out Linear(dec_out) -> logits
        logits = self.fc(dec_out)
        
        return logits, enc_attns, dec_attns, dec_enc_attns

# %% [markdown]
# ## Mask

# %%
# Attention을 할 때에 <PAD> 토큰에도 Attention을 주는 것을 방지해 주는 역할
def generate_padding_mask(seq):
    seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
    return seq[:, tf.newaxis, tf.newaxis, :]

def generate_causality_mask(src_len, tgt_len):
    mask = 1 - np.cumsum(np.eye(src_len, tgt_len), 0)
    return tf.cast(mask, tf.float32)

def generate_masks(src, tgt):
    enc_mask = generate_padding_mask(src)
    dec_mask = generate_padding_mask(tgt)

    dec_enc_causality_mask = generate_causality_mask(tgt.shape[1], src.shape[1])
    dec_enc_mask = tf.maximum(enc_mask, dec_enc_causality_mask)

    dec_causality_mask = generate_causality_mask(tgt.shape[1], tgt.shape[1])
    dec_mask = tf.maximum(dec_mask, dec_causality_mask)

    return enc_mask, dec_enc_mask, dec_mask

# %% [markdown]
# # Step 4. 훈련하기

# %%
transformer = Transformer(
    n_layers=2,
    d_model=512,
    n_heads=8,
    d_ff=2048,
    src_vocab_size=SRC_VOCAB_SIZE,
    tgt_vocab_size=TGT_VOCAB_SIZE,
    pos_len=200,
    dropout=0.2,
    shared=True
)

# %% [markdown]
# ##  Learning Rate Scheduler를 선언하고, 이를 포함하는 Adam Optimizer를 선언

# %%
class LearningRateScheduler(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(LearningRateScheduler, self).__init__()
        self.d_model = d_model
        self.warmup_steps = warmup_steps
    
    def __call__(self, step):
        arg1 = step ** -0.5
        arg2 = step * (self.warmup_steps ** -1.5)
        
        return (self.d_model ** -0.5) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = LearningRateScheduler(512)
optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

# %% [markdown]
# ## Loss 함수를 정의

# %%
# Loss 함수 정의
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    # Masking 되지 않은 입력의 개수로 Scaling하는 과정
    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

# %% [markdown]
# ## train_step 함수를 정의

# %%
@tf.function()
def train_step(src, tgt, model, optimizer):
    gold = tgt[:, 1:]
        
    enc_mask, dec_enc_mask, dec_mask = generate_masks(src, tgt)

    # 계산된 loss에 tf.GradientTape()를 적용해 학습을 진행합니다.
    with tf.GradientTape() as tape:
        predictions, enc_attns, dec_attns, dec_enc_attns = model(src, tgt, enc_mask, dec_enc_mask, dec_mask)
        loss = loss_function(gold, predictions[:, :-1])

    # 최종적으로 optimizer.apply_gradients()가 사용됩니다. 
    gradients = tape.gradient(loss, model.trainable_variables)    
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    
    return loss, enc_attns, dec_attns, dec_enc_attns

# %%
directory = os.getenv('HOME') + '/aiffel/aiffelthon/'

# %%
# print(os.getcwd())
# os.listdir(directory)

# %%
ckpt = tf.train.Checkpoint(step = tf.Variable(1), optimizer = optimizer , transformer = transformer)
manager = tf.train.CheckpointManager(ckpt, directory +'tf_ckpts_gd12_test_r0',max_to_keep=3)

# %% [markdown]
# ## Attention 시각화 함수

# %%
# Attention 시각화 함수
def visualize_attention(src, tgt, enc_attns, dec_attns, dec_enc_attns):
    def draw(data, ax, x="auto", y="auto"):
        import seaborn
        seaborn.heatmap(data, 
                        square=True,
                        vmin=0.0, vmax=1.0, 
                        cbar=False, ax=ax,
                        xticklabels=x,
                        yticklabels=y)
        
    for layer in range(0, 2, 1):
        fig, axs = plt.subplots(1, 4, figsize=(20, 10))
        print("Encoder Layer", layer + 1)
        for h in range(4):
            draw(enc_attns[layer][0, h, :len(src), :len(src)], axs[h], src, src)
        plt.show()
        
    for layer in range(0, 2, 1):
        fig, axs = plt.subplots(1, 4, figsize=(20, 10))
        print("Decoder Self Layer", layer+1)
        for h in range(4):
            draw(dec_attns[layer][0, h, :len(tgt), :len(tgt)], axs[h], tgt, tgt)
        plt.show()

        print("Decoder Src Layer", layer+1)
        fig, axs = plt.subplots(1, 4, figsize=(20, 10))
        for h in range(4):
            draw(dec_enc_attns[layer][0, h, :len(tgt), :len(src)], axs[h], src, tgt)
        plt.show()

# %% [markdown]
# ## 번역생성함수

# %%
# 번역 생성 함수
def evaluate(sentence, model, reg, src_tokenizer, tgt_tokenizer):
    sentence = preprocess_sentence(sentence)
    pieces = src_tokenizer.encode_as_pieces(sentence)
    tokens = src_tokenizer.encode_as_ids(sentence)

    _input = tf.keras.preprocessing.sequence.pad_sequences([tokens], maxlen=enc_train.shape[-1], padding='post')

    ids = []

    #     output = tf.expand_dims([tgt_tokenizer.bos_id()], 0)    
    # jj > 4, jd > 5, gs > 6 , cc > 7 , kw > 8
    output = tf.expand_dims([tgt_tokenizer.bos_id(), reg], 0) # reg포함
    for i in range(dec_train.shape[-1]):
        enc_padding_mask, combined_mask, dec_padding_mask = generate_masks(_input, output)
        

        predictions, enc_attns, dec_attns, dec_enc_attns = model(_input, output, enc_padding_mask, combined_mask, dec_padding_mask)
        
        predicted_id = tf.argmax(tf.math.softmax(predictions, axis=-1)[0, -1]).numpy().item()
        if tgt_tokenizer.eos_id() == predicted_id:
            result = tgt_tokenizer.decode_ids(ids)
            return pieces, result, enc_attns, dec_attns, dec_enc_attns

        ids.append(predicted_id)
        output = tf.concat([output, tf.expand_dims([predicted_id], 0)], axis=-1)
    result = tgt_tokenizer.decode_ids(ids)
    return pieces, result, enc_attns, dec_attns, dec_enc_attns

# %%
# 번역 생성 및 Attention 시각화 결합
def translate(sentence, model, reg, src_tokenizer, tgt_tokenizer, plot_attention=False):
    pieces, result, enc_attns, dec_attns, dec_enc_attns = evaluate(sentence, model, reg, src_tokenizer, tgt_tokenizer)
    
    print('Input: %s' % (sentence))
    print('Predicted translation: {}'.format(result))

    if plot_attention:
        visualize_attention(pieces, result.split(), enc_attns, dec_attns, dec_enc_attns)
  
    return result

# %%
examples = [
    "How was your day? I was the best.",
    "Take your time, please.",
    "I’m about to leave. Please hold for a moment.",
    "Have you heard of it?"
]

# %% [markdown]
# ## 학습

# %%
# 학습
EPOCHS = 1
BATCH_SIZE = 64

def train_and_checkpoint(transformer, manager, EPOCHS):
    ckpt.restore(manager.latest_checkpoint)
    if manager.latest_checkpoint:
        print("Restored from {}".format(manager.latest_checkpoint))
    
    else:
        print("Initializing from scratch.")


    for epoch in range(EPOCHS):
        total_loss = 0

        idx_list = list(range(0, enc_train.shape[0], BATCH_SIZE))
        random.shuffle(idx_list)
        t = tqdm(idx_list)

        for (batch, idx) in enumerate(t):
            batch_loss, enc_attns, dec_attns, dec_enc_attns = train_step(enc_train[idx:idx+BATCH_SIZE],
                                                                         dec_train[idx:idx+BATCH_SIZE],
                                                                         transformer,
                                                                         optimizer)

            total_loss += batch_loss

            t.set_description_str('Epoch %2d' % (epoch + 1))
            t.set_postfix_str('Loss %.4f' % (total_loss.numpy() / (batch + 1)))
      
      
#         # 매 Epoch 마다 제시된 예문에 대한 번역 생성
#         for reg in [4,5,6,7,8]:
#             translate('I’m about to leave. Please hold for a moment', transformer, reg, enc_tokenizer, dec_tokenizer)
            


        save_path = manager.save()
        print("Saved checkpoint for step {}: {}".format(int(ckpt.step), save_path))

# %%
train_and_checkpoint(transformer, manager, EPOCHS)
# Out:
# Initializing from scratch.
#   0%|          | 0/156 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipykernel_31/3069671801.py in <module>
# ----> 1 train_and_checkpoint(transformer, manager, EPOCHS)
#
# /tmp/ipykernel_31/2787506568.py in train_and_checkpoint(transformer, manager, EPOCHS)
#      20
#      21         for (batch, idx) in enumerate(t):
# ---> 22             batch_loss, enc_attns, dec_attns, dec_enc_attns = train_step(enc_train[idx:idx+BATCH_SIZE],
#      23                                                                          dec_train[idx:idx+BATCH_SIZE],
#      24                                                                          transformer,
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     931       # This is the first call of __call__, so we have to initialize.
#     932       initializers = []
# --> 933       self._initialize(args, kwds, add_initializers_to=initializers)
#     934     finally:
#     935       # At this point we know that the initialization is complete (or less
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     757     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     758     self._concrete_stateful_fn = (
# --> 759         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     760             *args, **kwds))
#     761
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3064       args, kwargs = None, None
#    3065     with self._lock:
# -> 3066       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3067     return graph_function
#    3068
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3461
#    3462           self._function_cache.missed.add(call_context_key)
# -> 3463           graph_function = self._create_graph_function(args, kwargs)
#    3464           self._function_cache.primary[cache_key] = graph_function
#    3465
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3296     arg_names = base_arg_names + missing_arg_names
#    3297     graph_function = ConcreteFunction(
# -> 3298         func_graph_module.func_graph_from_py_func(
#    3299             self._name,
#    3300             self._python_function,
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1005         _, original_func = tf_decorator.unwrap(python_func)
#    1006
# -> 1007       func_outputs = python_func(*func_args, **func_kwargs)
#    1008
#    1009       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     666         # the function a weak reference to itself to avoid a reference cycle.
#     667         with OptionalXlaContext(compile_with_xla):
# --> 668           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     669         return out
#     670
#
# /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     992           except Exception as e:  # pylint:disable=broad-except
#     993             if hasattr(e, "ag_error_metadata"):
# --> 994               raise e.ag_error_metadata.to_exception(e)
#     995             else:
#     996               raise
#
# NotImplementedError: in user code:
#
#     /tmp/ipykernel_31/1101096343.py:9 train_step  *
#         predictions, enc_attns, dec_attns, dec_enc_attns = model(src, tgt, enc_mask, dec_enc_mask, dec_mask)
#     /tmp/ipykernel_31/3348831578.py:51 call  *
#         enc_in = self.embedding(self.enc_emb, enc_in)
#     /tmp/ipykernel_31/3348831578.py:44 embedding  *
#         out += self.pos_encoding[np.newaxis, ...][:, :seq_len, :]
#     /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:1378 binary_op_wrapper
#         out = r_op(x)
#     /opt/conda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:867 __array__
#         raise NotImplementedError(
#
#     NotImplementedError: Cannot convert a symbolic Tensor (transformer/mul:0) to a numpy array. This error may indicate that you're trying to pass a Tensor to a NumPy call, which is not supported

# %%
print(type(enc_corpus_test))
print(type(dec_corpus_test))
print(type(enc_corpus_test_jj))
print(type(dec_corpus_test_jj))

# %%
# jj > 4, jd > 5, gs > 6 , cc > 7 , kw > 8

reg = {4 : '제주도', 5 : '전라도', 6 :'경상도',7:'충청도', 8:'강원도'}

for i in range(4,9) :
    print(f'{reg[i]} 사투리 :')    
    translate('what are you doing?',transformer, i, enc_tokenizer, dec_tokenizer)
    print()

# %%
# jj > 4, jd > 5, gs > 6 , cc > 7 , kw > 8

reg = {4 : '제주도', 5 : '전라도', 6 :'경상도',7:'충청도', 8:'강원도'}

for i in range(4,9) :
    print(f'{reg[i]} 사투리 :')    
    translate(enc_corpus_test[2],transformer, i, enc_tokenizer, dec_tokenizer)
    print()

# %% [markdown]
# # Step 5. 평가

# %%
enc_corpus_test

# %%
dec_corpus_test

# %%
dec_tokenizer.encode_as_ids(dec_corpus_test_jj.iloc[0])

# %%
enc_tokenizer.encode_as_ids(enc_corpus_test_jj.iloc[0])

# %%
enc_corpus_test_jj.reset_index(drop=True)

# %%
dec_corpus_test_jj.reset_index(drop=True)

# %%
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.bleu_score import SmoothingFunction

def eval_bleu_single(model, reg, src_sentence, tgt_sentence, enc_tokenizer, dec_tokenizer, verbose=True):
    src_tokens = enc_tokenizer.encode_as_ids(src_sentence)
    tgt_tokens = dec_tokenizer.encode_as_ids(tgt_sentence)

    if (len(src_tokens) > 100): return None
    if (len(tgt_tokens) > 100): return None

    reference = tgt_sentence.split()
    candidate = translate(src_sentence, model, reg, enc_tokenizer, dec_tokenizer).split()

    score = sentence_bleu([reference], candidate,
                          smoothing_function=SmoothingFunction().method1)

    if verbose:
        print("Source Sentence: ", src_sentence)
        print("Model Prediction: ", candidate)
        print("Real: ", reference)
        print("Score: %lf\n" % score*100)
        
    return score

# %%
# single test (제주도사투리)
test_idx = 70

eval_bleu_single(transformer, 
                 4,
                 enc_corpus_test_jj.iloc[test_idx], 
                 dec_corpus_test_jj.iloc[test_idx], 
                 enc_tokenizer, 
                 dec_tokenizer, 
                 verbose=True)

# %%
def eval_bleu(model, reg, src_sentences, tgt_sentence, enc_tokenizer, dec_tokenizer, verbose=True):
    total_score = 0.0
    sample_size = len(src_sentences)
    
    for idx in tqdm(range(sample_size)):
        score = eval_bleu_single(model, reg, src_sentences.iloc[idx], tgt_sentence.iloc[idx], enc_tokenizer, dec_tokenizer, verbose)
        if not score: continue
        
        total_score += score
    
    print("Num of Sample:", sample_size)
    print("Total Score:", (total_score / sample_size)*100)

# %%
enc_corpus_test_jj.isnull()

# %%
# Null data 제거

enc_corpus_test_jd=enc_corpus_test_jd.dropna(axis=0)
enc_corpus_test_gs=enc_corpus_test_gs.dropna(axis=0)
enc_corpus_test_cc=enc_corpus_test_cc.dropna(axis=0)
enc_corpus_test_kw=enc_corpus_test_kw.dropna(axis=0)

dec_corpus_test_jj=dec_corpus_test_jj.dropna(axis=0)
dec_corpus_test_jd=dec_corpus_test_jd.dropna(axis=0)
dec_corpus_test_gs=dec_corpus_test_gs.dropna(axis=0)
dec_corpus_test_cc=dec_corpus_test_cc.dropna(axis=0)
dec_corpus_test_kw=dec_corpus_test_kw.dropna(axis=0)

# %%
# reg = {4 : '제주도'}
eval_bleu(transformer, 4, enc_corpus_test_jj.iloc[:], dec_corpus_test_jj.iloc[:], enc_tokenizer, dec_tokenizer, verbose=False)

# %%
# reg = {5 : '전라도'}
eval_bleu(transformer, 5, enc_corpus_test_jd.iloc[:], dec_corpus_test_jd.iloc[:], enc_tokenizer, dec_tokenizer, verbose=False)

# %%
#reg = {6 :'경상도'}
eval_bleu(transformer, 6, enc_corpus_test_gs.iloc[:], dec_corpus_test_gs.iloc[:], enc_tokenizer, dec_tokenizer, verbose=False)

# %%
#reg = {7:'충청도'}
eval_bleu(transformer, 7, enc_corpus_test_cc.iloc[:], dec_corpus_test_cc.iloc[:], enc_tokenizer, dec_tokenizer, verbose=False)

# %%
#reg = {8:'강원도'}
eval_bleu(transformer, 8, enc_corpus_test_kw.iloc[:], dec_corpus_test_kw.iloc[:], enc_tokenizer, dec_tokenizer, verbose=False)

# %%
# # Bleu example
# from datasets import load_metric

# bleu = load_metric("bleu")
# predictions = [["I", "have", "thirty", "six", "years"]] 
# references = [
#     [["I", "am", "thirty", "six", "years", "old"], ["I", "am", "thirty", "six"]]
# ]
# bleu.compute(predictions=predictions, references=references)

# # Bleu example
# from datasets import load_metric

# bleu = load_metric("bleu")
# #bleu = load_metric('sacrebleu')

# reference = enc_corpus_test
# predictions = translate(enc_corpus_test, reg, transformer, enc_tokenizer, dec_tokenizer)

# bleu.compute(predictions=predictions, references=reference)

# %%
# import matplotlib as mpl
# import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'retina'
 
# import matplotlib.font_manager as fm

# fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
# font = fm.FontProperties(fname=fontpath, size=9)
# plt.rc('font', family='NanumBarunGothic') 
# # mpl.font_manager._rebuild()

# %%
# 매 Epoch 마다 제시된 예문에 대한 번역 생성시각화
# for example in examples:
#     translate(example, transformer, en_tokenizer, ko_tokenizer, plot_attention=True)
