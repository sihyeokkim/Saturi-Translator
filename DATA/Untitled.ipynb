# %%
import os

# %%
directory = os.getenv('HOME') + '/aiffel/aiffelthon/reg_1'

# %%
os.listdir(directory)
# Out:
# ['DZJD21002058.json',
#  'DZJD20000236.txt',
#  'DZJD20001739.json',
#  'DZES20000586.json',
#  'DZHF20000451.txt',
#  'DZJD20001746.txt',
#  'DZES21001818.txt',
#  'DZHF20002302.json',
#  'DZJD21002032.txt',
#  'DZJD21002045.json',
#  'DZES20000043.json',
#  'DZJD20001692.json',
#  'DZJD21001989.txt',
#  'DZJD20001023.json',
#  'DZJD21002073.json',
#  'DZJD20001198.json',
#  'DZES21001491.txt',
#  'DZHF20002188.txt',
#  'DZHF20001286.txt',
#  'DZJD20000889.txt',
#  'DZES20000231.json',
#  'DZJD20001301.txt',
#  'DZES20000716.txt',
#  'DZHF20002195.txt',
#  'DZHF20002075.json',
#  'DZHF20002877.txt',
#  'DZHF20001651.txt',
#  'DZHF20000782.txt',
#  'DZHF20002682.txt',
#  'DZJD20001096.json',
#  'DZHF20000357.json',
#  'DZJD20001666.txt',
#  'DZJD20001355.json',
#  'DZHF20000037.json',
#  'DZHF20001270.json',
#  'DZJD20001338.json',
#  'DZES21001519.json',
#  'DZES20000344.txt',
#  'DZHF20000267.txt',
#  'DZHF20002325.txt',
#  'DZES20001440.json',
#  'DZHF20001093.json',
# ...

# %%
import json
with open(directory +'/DZJD21002058.json') as f :
    raw= json.load(f)

# %%
raw
# Out:
# {'id': 'DZJD21002058',
#  'metadata': {'title': 'DZJD21002058',
#   'creator': '솔트룩스',
#   'distributor': '솔트룩스',
#   'year': '2021',
#   'category': '제주방언 > 사적 대화 > 일상 대화',
#   'annotation_level': ['원시'],
#   'sampling': '본문 전체',
#   'author': '개인 발화자',
#   'publisher': '개인 발화 녹음',
#   'date': '20210107',
#   'topic': '꿈(목표)'},
#  'speaker': [{'id': '1',
#    'name': 'null',
#    'age': '30대',
#    'sex': '여성',
#    'occupation': '전문가 및 관련 종사자',
#    'birthplace': '제주',
#    'principal_residence': '제주',
#    'current_residence': '서울',
#    'education': '대졸'},
#   {'id': '2',
#    'name': 'null',
#    'age': '30대',
#    'sex': '여성',
#    'occupation': '무직/취업준비생',
#    'birthplace': '제주',
#    'principal_residence': '제주',
#    'current_residence': '제주',
#    'education': '대졸'}],
#  'setting': {'relation': '기타'},
#  'utterance': [{'id': 'DZJD21002058.1.1.1',
#    'start': 0,
#    'end': 11.07,
#    'speaker_id': '1',
# ...

# %%
with open(directory +'/DZES20000297.txt') as f :
    raw = f.read().splitlines()

# %%
raw
# Out:
# ['3: 이천이십 년 십이 월 이십 일',
#  '3: @이름1',
#  '2: @이름2',
#  '1: @이름3',
#  '3: 자택에서 녹음 시작합니다 야 야',
#  '3: @이름2 @이름2이 왜 너 전화번호가 없지?',
#  '3: 야',
#  '1: 그니까 나 저 전화번호 (인)/(있어)',
#  '2: 너 언제 (바꿘?)/(바꿨어?)',
#  '1: 내가 저장 안 했나봐',
#  '3: 아 진짜 야 근데 너무한거 아니냐?',
#  '2: 너가 말 안 했나보지 뭐 @웃음 음',
#  '1: 개소리야 @웃음',
#  '2: 야 먼지 먹었어',
#  '3: 먼지 먹었어 괜찮아',
#  '2: 괜찮다고?',
#  '3: 어 괜찮아',
#  '1: 본지가 언젠데',
#  '2: 음',
#  '3: @이름4 지금 잭잭이 (인)/(있어)',
#  '2: 내가 데꼬 왔어',
#  '3: 음 잭잭이 보',
#  '1: 고양이',
#  '3: 보여줘?',
#  '1: 응 보여줘',
#  '2: 너무 귀여워',
#  '3: 잭잭이 지금 (이)/(#이) @이름5이한테 낯가리고 있어가지고 (이)/(#이)',
#  '3: 일로 잘 안 오는데 @웃음 귀여워 잭잭이',
#  '1: (()) 잭잭이 원래 낯 가려?',
#  '3: 어 그 사람을 별로 안 좋아해',
#  '3: 우리 말고는 사람을 별로 안 좋아해',
#  '2: 댕댕이를 (좋아한댄)/(좋아한대)',
#  '3: 어',
#  '1: 사람말고 댕댕이를 좋아하는구나',
#  '3: 음',
#  '1: 개될래 개가될래',
#  '3: 개들에 개가 된다고?',
#  '2: 주륵 @웃음',
#  '3: 스 그 너 바베시아 알아?',
#  '1: 몰라 그게 뭐야?',
#  '3: 그 강아지 좀 가까이 해야겠다 강아지',
#  '1: 어',
#  '3: 그 뭐지 가 진드기 감염병인데',
#  '1: 응.',
#  '3: 그 바베시아라는 균이 진드기 입에 기생해서 살아?',
#  '1: 응.',
# ...
