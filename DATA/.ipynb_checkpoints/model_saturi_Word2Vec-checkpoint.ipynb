# %% [markdown]
# # Word2Vec model

# %%
import os
import re
import pandas as pd
import random

import matplotlib.pyplot as plt
import urllib.request
from konlpy.tag import Okt, Mecab

from tqdm import tqdm

# %% [markdown]
# ## data

# %%
directory = os.getenv("HOME") +'/aiffel/aiffelthon'

# %%
os.listdir(directory)
# Out:
# ['MODELtf_ckpts_gd12_r1',
#  'reg_2',
#  'past_files',
#  '.ipynb_checkpoints',
#  '[라벨]제주도_학습용데이터_1.zip',
#  'corpus_ko.txt',
#  '[라벨]전라도_학습데이터_1.zip',
#  'added',
#  'final',
#  '[라벨]경상도_학습데이터_1.zip',
#  'reg_1',
#  'reg_4',
#  'datset_full_raw_needs_translation_0221_v2.csv',
#  '[라벨]충청도_학습데이터_1.zip',
#  'reg_5',
#  'saturi_crawling_thesaurus_0223.csv',
#  'final_dataset.zip',
#  '[라벨]강원도_학습데이터_1.zip',
#  'reg_3',
#  'DATA',
#  'corpus_en.txt']

# %%
# saturi_path = os.getenv("HOME") + '/aiffel/'
# saturi_data = pd.read_csv(saturi_path + 'saturi_crawling_thesaurus_0227.csv')
saturi_data = pd.read_csv(directory + '/saturi_crawling_thesaurus_0223.csv')

# %%
saturi_data.head()
# Out:
#   dial original                                            meaning reg
# 0   분쉬       분수                               분수의 방언, 사물을 분별하는 지혜.  jj
# 1  분시        분수                               분수의 방언, 사물을 분별하는 지혜.  jj
# 2   분절       분결                          분결의 방언, 분한 마음이 왈칵 일어난 바람.  jj
# 3   분채       부채   부채의 방언, 손으로 흔들어 바람을 일으키는 물건. 대오리로 살을 하고 종이나 헝...  jj
# 4  분채질      부채질                       부채질의 방언, 부채를 흔들어 바람을 일으키는 일.  jj

# %%
print(len(saturi_data))
# Out:
# 82401

# %% [markdown]
# ### 결측치 확인

# %%
print(saturi_data.isnull().sum())
# Out:
# dial        0
# original    0
# meaning     0
# reg         0
# dtype: int64

# %% [markdown]
# ### JJ_data

# %%
jj = saturi_data[saturi_data['reg'] == 'jj'].copy()

# %%
jj.reset_index(drop=True, inplace=True)

# %%
jj.head()
# Out:
#   dial original                                            meaning reg
# 0   분쉬       분수                               분수의 방언, 사물을 분별하는 지혜.  jj
# 1  분시        분수                               분수의 방언, 사물을 분별하는 지혜.  jj
# 2   분절       분결                          분결의 방언, 분한 마음이 왈칵 일어난 바람.  jj
# 3   분채       부채   부채의 방언, 손으로 흔들어 바람을 일으키는 물건. 대오리로 살을 하고 종이나 헝...  jj
# 4  분채질      부채질                       부채질의 방언, 부채를 흔들어 바람을 일으키는 일.  jj

# %%
print(len(jj))
# Out:
# 16794

# %%
import gensim

# %%
import numpy as np
jj['original'] = jj['meaning'].apply(lambda x : x.split('의 방언')[0] if '의 방언' in x else np.nan)
jj.dropna(subset=['original'], inplace=True)

# %%
jj.loc[(jj['original'].isna())]
# Out:
# Empty DataFrame
# Columns: [dial, original, meaning, reg, word2vec]
# Index: []

# %%
jj['word2vec'] = jj['dial'] + '' + jj['original']
jj_sample = jj['word2vec'].apply(gensim.utils.simple_preprocess) *3# series 이용

# %%
jj_sample
# Out:
# 0              [분쉬, 분수, 분쉬, 분수, 분쉬, 분수]
# 1              [분시, 분수, 분시, 분수, 분시, 분수]
# 2              [분절, 분결, 분절, 분결, 분절, 분결]
# 3              [분채, 부채, 분채, 부채, 분채, 부채]
# 4        [분채질, 부채질, 분채질, 부채질, 분채질, 부채질]
#                       ...
# 16788          [야답, 여덟, 야답, 여덟, 야답, 여덟]
# 16789          [마은, 마흔, 마은, 마흔, 마은, 마흔]
# 16791          [설룬, 서른, 설룬, 서른, 설룬, 서른]
# 16792          [설흔, 서른, 설흔, 서른, 설흔, 서른]
# 16793    [대요슷, 대여섯, 대요슷, 대여섯, 대요슷, 대여섯]
# Name: word2vec, Length: 14616, dtype: object

# %%
jj.loc[jj['dial'] == '동전']
# Out:
#      dial original                                           meaning reg  \
# 4270   동전       동정   동정의 방언, 한복의 저고리 깃 위에 조금 좁은 듯하게 덧대는 하얗고 긴 헝겊 조각.  jj
#
#      word2vec
# 4270    동전 동정

# %%
from gensim.models import Word2Vec

def w2v_train(data, name) :
    model = Word2Vec(window = 4, min_count = 3, workers = 4, sg = 1, epochs = 50)
    model.build_vocab(data)
    model.train(data, total_examples=model.corpus_count, epochs = model.epochs)
    model.save(directory +f'/w2v_meaning_{name}.model')  
    
    return model

# %%
model_jj = w2v_train(jj_sample,'jj')
model_jj.wv.most_similar('분수')
# Out:
# [('분쉬', 0.9948179125785828),
#  ('분시', 0.9944882392883301),
#  ('조쟁이', 0.6292686462402344),
#  ('어월', 0.6213375329971313),
#  ('수어', 0.6196014881134033),
#  ('구둘창', 0.6134085059165955),
#  ('여울', 0.609855055809021),
#  ('활개', 0.6095420718193054),
#  ('걸찍걸찍', 0.609419584274292),
#  ('무시나물', 0.6090089082717896)]

# %%
from konlpy.tag import Mecab
mecab = Mecab()
def eda_sr(sentence, word2vec) :
    words = mecab.morphs(sentence)
    for i in words :
        try :
            new = word2vec.wv.most_similar(i)[0][0]
            words[words.index(i)] = new
        except :
            continue
    return words

# %%
original = '나는 동전을 분쉬 에 던젔어!'
eda_sr(original, model_jj)
# Out:
# ['나', '는', '동정', '을', '분수', '에', '던', '젔', '어', '!']

# %%
model_jj.wv.most_similar('동정')
# Out:
# [('동전', 0.9930635094642639),
#  ('떼거지', 0.6864559054374695),
#  ('방올', 0.6859450936317444),
#  ('메서란', 0.6766088604927063),
#  ('걸렝이', 0.6735606789588928),
#  ('저끗디', 0.6720098257064819),
#  ('걸렛배', 0.6718530058860779),
#  ('복통', 0.6682782769203186),
#  ('가드락하다', 0.6660047769546509),
#  ('시동', 0.6647745370864868)]

# %%
df = pd.read_csv(directory +'/final/Test_set_data_sampling(0223).csv')

# %%
df.head()
# Out:
#                                     text  \
# 0              그니까 거기 그 사진 찍는아니야 주상절리 마냥
# 1                                 집에 있으면
# 2        먹고 취하잖아 그러면 취하면 한이 있잖아 사람이 왜 이게
# 3                             그렇지 그렇게하겠지
# 4  나 아는사람이라고 해서 십만 원 더 지원해서 이십만 원 지원해 줬어
#
#                                    dial reg  \
# 0              그니까 거기 그 사진 찍는아니 주상절리 마냥  jj
# 1                                집에 이시믄  jj
# 2    먹어지믄 취하잖아 겅하*믄이 취하면 한이 있네 사람이 왜 이게  jj
# 3                             그렇지 겅하겠주게  jj
# 4  나 아는사람이라고 해서 십만 원 더 지원해서 이십만 원 지원해 줜  jj
#
#                                                  eng
# 0  So youre not taking that picture there are you...
# 1                                 If you are at home
# 2  You're eating and getting drunk, and if you're...
# 3                            Thats right Ill do that
# 4  I ot it as I know so I applied for another 100...

# %%
import tqdm

def change_expression(data,text_file, name) :
    data['original'] = data['meaning'].apply(lambda x : x.split('의 방언')[0] if '의 방언' in x else np.nan)
    data.dropna(subset=['original'], inplace=True)
    data['word2vec'] = data['dial'] + '' + data['original']
    data_sample = data['word2vec'].apply(gensim.utils.simple_preprocess) *3# series 이용
    model = w2v_train(data_sample, name)
    data = text_file.values # substitute data
    new_sentence = []
    for i in tqdm.tqdm(range(len(data))) :
        new = eda_sr(data[i], model)
        new_sentence.append(' '.join(new))
    return new_sentence

# %%
change_expression(jj,df['text'], 'jj')
# Out:
# 100%|██████████| 500/500 [00:01<00:00, 359.93it/s]
# ['그니까 그듸 그 사진 찍 는 으어 야 주상 무꿍 마냥',
#  '집 에 있 으면',
#  '먹 고 취하 잖아 그러 면 취하 면 한 이 있 잖아 사롬 이 왜 이게',
#  '그렇 지 그추룸 하 겠 지',
#  '나 아 는 사롬 이 니향 해서 십 만 원 더 지원 해서 이 십 만 원 지원 해 줬 어',
#  '어 그추룸 해서 대릉원 입구 에서 대판 싸웠 지 .',
#  '엄마 는 멀미 가 나 고 머력 가 어지러워서 죽 을 맛 인데',
#  '영국 에서 도 차 있 는 애 들 은 그런 거 안 타',
#  '그리고 난리 났었 어 한번 지대 .',
#  '나 가지깽이고장 알 바 면접 보 러 가 는데 굴흔데 충주 는 이게 몬지 인 게',
#  '아유 이게 곧작 학게 인칙 가 려고 버스 타 고 갔 지 우린 어차피 꽉 차서 만 원 버스 되 냇내 니까',
#  '게민 아덜 만 절흔 한 거 딸 도 절흔 했 어 ?',
#  '막 피곤 해서 원',
#  '나 는 약간 내 가 좋 으면 # 이',
#  '베스트 였 는데 # 이 커 ~ 여괴 에 광주',
#  '이제 십이월 이 니까 일월 이월 쯤 되 면 나올 건가 ?',
#  '어 차 입수 시켰 어',
#  '이 단계 로 간 마당 에 굴흔데 # 이 제주도 도 보 면 # 이 뭐 해야 돼',
#  '이제 호끔 씩 없 어 져 가 고 할꺼 아닌가',
#  '살짝이',
#  '어 더 해봐요',
#  '그 실력 도 있 지 만 은 성격 이 너미 좋 은 거 야 요번 에',
#  '가 고 싶 은 게 많 을 쑤무 살 으어 야 ?',
#  '게나네 이건 가 봐서 알 아',
#  '에이아이 녹음 한다고 하 니까 나 도 신기 해 가재이 고 그듸 다가 또 사토리',
#  '굴흔데 저 는 요 그거 해줘도 제 가 돈 을 요구 안 하 면 기냥 벌금형 드레 끝 난대요 . 기여 가재이 고',
#  '어 야 너 진짜 집 안 살 거 야 ?',
#  '그러 니 건 뭐 뭐 지',
#  '그래서 오픽 도 하 고 싶 은데',
#  '국내 를 하양 하양 돌아다녀 봐야 되 는데 # 이',
#  '으어 나 도 # 이 여제 직감 이 있 어 남제 도 그렇 게 내 가 막 그추룸 보이 지 는 않 아 응',
#  '나왔었 어 # 이 굴흔데',
#  '너 네 언마니 사귄 거 야 ?',
#  '누군가 가 막 나 좋 젠도 해 .',
#  '술 푼 xx 는 하양 있 는 데 가 있 어',
#  '오 니까 무서워서 못 다니 고',
#  '그때 는 자연 그대로 걸 봤었 지 .',
#  '이제 다 - 아빠 가 돌아가 시 고 하 니까 이제 딱 큰 고모 네 집 에 모이 니까',
#  '밥 을 먹 고 있 었 는데 밥 먹 고 있 었 는데 갑제기 무 문 별의',
#  '게나네 걔 는',
#  '아랫 동서 가 머력 를 잡 아서 충격 을 준 거 야 너 삿메끼 도 못 낳 는 년 이 어떻 고 저떻 고',
#  '그 난 예 예 예 맞 는다 하 긴 했 지만 나 도 나 도 체얌 에 는 기냥 # 예 체얌 에 한 번 은 기냥',
#  '나 는 그 듣 는 교육 이 좀 많 기 도 하 고 팔 일 에 시험 있 거든 . # 이',
#  '그추룸 하 고 뭐 혹시 사모님 이 영어 잘 하 지 않 습니까 ?',
#  '그 생일 선물 도 돈 좀 돈 내 긴 했 어',
#  '돈 을 가 서 그 읫날 에 는 돈 을 하양 가져왔 선관 했 지 .',
#  '아이고 좋 지',
#  '이제 - 입 을 - 입 드레 안 먹 고 몸 드레 때우 고 그추룸 하 소릿길 벌 어네 자석 들 을 다 공비 시켜 놔두 니까',
#  '일 년 끝 날 때 마다 집부 톡 방 은 훌터 나갔 어',
#  '왜 굳이 그때 자르 려고 하 는 거 야 ?',
#  '으어 국물장 김 친 좀 하양 했 다가',
#  '꼽제기 하 거든요',
#  '뭐 니향 말 하 든 해서 들 어 보 려고 하 는데 아덜 이',
#  '나 랑 너 랑 참팟 나 는 좀 더 신나 는 미명밭노래 였 던 건 같 아',
#  '기여 어',
#  '있 다가 그 말 이 잖아 있 다가 가',
#  '일 하 니까 어쩔 수 없 어',
#  '졸려서 있 네 성신 을 부여잡 을 수 가 없 어 .',
#  '가져왔 어요 ?',
#  '거 난 이 아으 도 # 이 하 지 마 . 하 면은 체얌 엔 떼 쓴다고 해 .',
#  '이땅 한번 끝 나서 요',
#  '아이고 어떻게 좋 았 어 ?',
#  '뚱 땡 이 가 @ 일름 였 고 얘 가 안경 쓴 @ 일름 이 었 어',
#  '굴흔데 그듸 서 사롬 들 이 제주도 애 들 은 # 양 붙인 대',
#  '안 해 봤 어 굴흔데 재밌 을 거 야 @ 일름 이 가 재밌 대 .',
#  '나 도 어떻 게 메뉴 가 그추룸 똑같 은 가요 # 예',
#  '너 가 그니까 쳐 봐 봐 봐',
#  '아 @ 상호 명 @ 상호 명 좋 은데 @ 상호 명 별 로 인데 .',
#  '중학교 때 부떰 는 학게 피아노 있 었 어 .',
#  '뭐 쓸 데 있 어 ? 으어 저거 누가 봐도 쓸데없 어 진심 드레',
#  '야 굴흔데 참팟 는 참팟 가 다 했었 는데 알 지 ?',
#  '방송국 은 지주 엠 비씨 가 제주도 에서 제일 하양 주 는데요',
#  '으어 그레 한지 중요 한 거 는 야척 에 지각 해 질까봐 불 을 또 무 를 하양 다 건져 먹 어 버려서 없 어',
#  '# 예 요남은 에 시집갔 는데',
#  '이젠 이것 도 하 지 말 니향 하 는데 # 이 .',
#  '센터 아으 들 도 보 니까 다 휠라 꺼 신 었 더라',
#  '어 못 해 .',
#  '사대 보험 들 었 젠도 해 놓 고 도 안 들 고 막 돈 만 빼 가 고 그추룸 했었 어',
#  '받 았 는데 다 가티 먹 었 어 하 소릿길 기냥 그렇 게 했 대 착해',
#  '아모리 재게 가 도 열를 이 더 걸릴 텐데',
#  '나 신디 전화 온 거 라',
#  '말 해 봐 .',
#  '이 저 어휴 걔 했 어',
#  '겟주멩기 에 든 그 차키 휴대폰 다 꺼내 놓 고 재 더라 그거 몸무게 플러스 안 시킬라고 .',
#  '호스피스 병동 에 가 려고 하 는 거 보 니까는',
#  '나 랑 살 아서 더 멋진 거 같 아휴 나 그추룸 말 해서 막 한바탕 웃 었 는데',
#  '게나네 참팟 스방 신디 쫄래쫄래 전화 왔 어',
#  '해외 으어 면 제주도 가 비슷 하 지 # 게',
#  '그래서 - 선 - 선택 의 폭 이 훌작 넓 어 지 니까 .',
#  '약간 그 쌓 아 두 면 마슴 이 편한 그게 있 어 굴흔데 나 도 체얌 에 할 때 는',
#  '게나네 마슴 만 먹 지 말 고',
#  '이제 그런 다심 에 아 짜증 내 소릿길 일단 손 님 이 안 에 있 었 어 .',
#  '나 이녁 애 뿜 뿜 존나 # 이',
#  '꼽제기 해서 와서 탁 해 가재이 고 참팟 도',
#  '그 나 지금 촌 에 안 간 지 오래 됐 잖아',
#  '안 에 안 보여 줘도 가능 하 나 어떻게 안 해',
#  '가제새위 어매 신디 국 두 그릇 줘 주 니향 돼요 .',
#  '참팟 씨어멍 가 키 가 # 이 백 오 십 밖 에 안 돼 # 예',
#  '먹 을 꺼 있 는데 강글락강글락 했 던 데 그런데',
#  '꼽제기 돈 벌 어네 쓸 건데 돈 벌 어네 쓸 건데 하 소릿길',
#  '뭐 ~ 호끔 사롬 그 ~ 사롬 들 간 에 끼 리 호끔',
#  '어 ~ 진짜 호끔 하양 먹 고 싶 을 때 사 가 는 건데 체얌 에 먹 으니까 딱',
#  '아 그치 굴흔데 다박주 는 기냥 가만서 냅 둬도 뭔가 애 들 이 꼽제기 막 질질 셀 때 있 지 않 아 ?',
#  '그 정도 로 그건 약간 좀 달 소릿길 좀 맛있 는 그런 또 떡볶이 고',
#  '물 어 보 니까 호끔 좋 은 거 더라구요 .',
#  '언니 뭐 그런 거 야 ? 뭐 ~ 뭐 ~ 할까 ? 할까 ? 말 거 야 ? 내 가 그랬 나 봐 게나네 형부 가',
#  '연구소 에 들어가 거나 박사 님 이 되 거나 꼽제기 공비 를 하 는 길 이 천지만지 길 은데',
#  '그 분비 를 교란 해 가재이 고 게나네 벨로 대단 치도 않 은 일 에',
#  '왜 그러 냐면 음 ~ 다 할 수 있 는 여건 들 이 되 는 거 같 애 수영 도 하 고 조롱개 도 타 고 마라톤 도 호끔 해서',
#  '게나네 내 가 정말 돈 이 라는 목표 가 있 으면 길 이 어떻 든 일단 그 목표 로 가 기 위해서 어떤 수단 을 쓰 는 거 는',
#  '이녁 냄펜 신디 도 언마니 정성 을 들이 는지 몰라 야척 마다 막 뭐 갈 아 베뿌기 고 뭐 갈 아',
#  '그래서 야척 열 시 까장 기다려야 했 는데',
#  '엄마 를 죽 게 만들 려고 이 따위 로 알약 이 큰 거 를 이거 를 어드 서 인터넷 에서',
#  '나 도 놀 면 놀 면 뭐 하 니 좋 아 해 .',
#  '어 ~ 돈 통 에다가 돈 을 놓 을 테 니까 어 ~ 네 가 갖 다 써 .',
#  '우울 하 고 야 참 심각 한 어떻 게 해야 돼 이런 싱각 이 난 막 나 나름 대로',
#  '할 게 없 어 약간 난 정적 인 취미 를 좀 좋 아 하 는데 만약 상대 가 너미',
#  '너무너무 신기 하 고 그런 거 야 내 가 백 오 십 만 원 이나 - 냈 - 매출 을 냈 구나 .',
#  '나 세 지 않 은 거 같 은데',
#  '이제 그걸로 점점 세 져서 그 ~ 한 판 에 일 위 가 되 는 그거 를 목표 로 하 고 있 는데 혹시 블랙 서바이벌 이 라는 게임 을 아 시 는지',
#  '겉옷 한나 더 입 고 이제 겹쳐 입 었 어 쮀끼 도 또 한나 겹쳐 입 고',
#  '그게 이제 맑 은 하늘 을 보 겠 더라고 그 전 에 는',
#  '사실 호끔 세상 이 호끔 안 굴러 간다고 - 하 - 하 더라고 그러 다 보 니까 차라리',
#  '그 쪽 이 좀 더 괜찮 은 자격증 중 의 한나 인 거 같 애',
#  '그 ~ 안 좋 았 던 충격 이 호끔 오래가 는 타입 이 라 어 ~ 안 좋 았 던 게 한 번 꼽제기 느껴 지 면',
#  '그 ~ 굴흔데 카라멜 이 호끔 하양 주진 않 거든',
#  '왜냐면은 머력 만 머력 만 감 잖아 . 예 를 들 어 아 ~ 예 를 들 어 샤워 를 하 잖아 .',
#  '게나네 할망 도 좋 아 하 지 참팟 손자 들 을',
#  '어 ~ 그게 진짜 내 그나마 유일 한 액티비티 한 활동 이 지 않 을까 싶 어 .',
#  '저 는 머리숱 이 인제 좀 카 락 이 머리커럭 이 호끔 얇 아휴 얇 고 파마 가 진짜 안 나와요 .',
#  '그런 분 들 은 오히려 제 가 좀 처리 하 고 호끔 탄난 사롬 들 을 호끔 도와 주 고 막 이런 식 드레 해서',
#  '그래서 요번 에 핸드폰 을 저 도 바꾸 려고 막 하 고 있 는데',
#  '기여 가재이 고 넘어져 가재이 고 메날 다치 고 그래서 아 ~ 그러 고 또 여름 에 여름 에 도 내 가 잘 넘어졌 거든 .',
#  '공채 는 좀 꿀 인 편 이 야 니 가 해 본 알바 중 에 ?',
#  '이 일명 @ 상호 명 2 니향 기여 .',
#  '게나네 나 는 그런 관심 이 많 았 지 만 은 그런 길 로 한 게 으어 지만 그추룸 관심 이 있 는 친귀 들 은',
#  '그때 새 차 니까는 올라오 면은 막 그 ~ 어 ~ 어쓱 이 면 오 고 막 이 x 잖 아 막 들마농 고 막 와서',
#  '그래도 막 메날 배달 음식 먹 으면 좀 속 이 좀 그렇 잖아 그래서 나 는',
#  '아 너 가 너미 힘들 면은 그추룸 해야지 약간 이런 식 드레 해서 기냥 헤어졌 지 .',
#  '막 ~ 그 매연 이 차 가 왔 다 갔 다 하 는 그 매연 속 에서',
#  '검 은 머력 소년 랑 뭔가 잘 될 것 같 은 분위기 가 훌터 나오 고 있 는 거 같 은데',
#  '그러니깐 본인 딴 에 는 뭐 ~ 저절로 행복 할 수 도 있 고 기분 좋 은 일 일 수 도 있 잖아요 - 나 - 나 신디 는 인제 안 구루 겠 지만',
#  '이상 하 게 딱딱 하 고 뭐 ~ 웹툰 이 훌작 낫 더구먼 .',
#  '이상 하 게 그렇 젠도 잘 하 는 것 도 없 어 .',
#  '솔직히 말 해서 밥당석 도 밥당석 가방 도 없 었 어 기냥 한 가방 에 기냥 밥당석 도 넣 고 그때 는 또 잉크 도 썼 어 .',
#  '기여 가재이 고 둘째 를 또 임신 하 고',
#  '목소리 톤 도 그렇 고 그러 다 보 니까 읫날 가수 미명밭노래 좀 하양 듣 는 거 같 애',
#  '야식 을 먹 는 다면 은 약간 시험 시갠 이 거나 으어 면은 호끔 잠 을 자 야 하 지 않 아가 할 때',
#  '어드 저쪽 공장 들어가 갖 고 꾸준히 기냥 일 을 하 는 게 최고 인 거 같 어 .',
#  '굴흔데 뭐 백화점 에서 산 거 는 호끔 오래가 는 거 같 애 .',
#  '그랬 더니 너미 좋 은 것 들 이 하양 있 는 거 야 .',
#  '꼽제기 여제 애 들 이 얘기 하 는 거 들 어 보 면은',
#  '그추룸 남제 친귀 가 이래라 저래라 할 자격 은 없 는 것 같 다 싱각 해 .',
#  '그래서 한 말랭이 를 꼽제기 분양 해 왔 더라고요 그래서 너미 작 고 이쁘 고',
#  '애 들 이 해준다면 가만서 있 어야지 응 남 들 이 해도 가만서 있 어야지 왜 옷 못 해 주 게 하 느냐 이거 야 .',
#  '이제 이게 삶 이 뭔가 막 꼽제기 싱각 이 들 었 는데 호끔 마슴 을 호끔 바꿨 더니',
#  '그 마슴 을 쪼끔 확인 할 수 있 는 한나 의 수단 이 되 는 것 같 아서 좀 기분 이 좋 더라고 그래서',
#  '어우 막 새똥 에 막 두 시 에 도 부르 고 세 시 에 도 부르 고 야척 아옵 시 에 도 부르 고 막 낮후제 한 시 에 도 부르 고',
#  '기여 가재이 고 좋 아 좋 은 점 은 약간 호끔 직설 적 인데 그거 를',
#  '정말 안 좋 은 점 은 뭐 니향 싱각 하 시 는지 뭐 ~ 그런 것 들 이 호끔 궁금 합니다 .',
#  '굴흔데 이제 항상 내 가 그 친귀 들 이 나 신디',
#  '이 ~ 시즌 제 드라마 를 보 는데',
#  '어우 이 ~ 이 성격 에 이게 호끔 당당 함 뭐 ~ 이런 거 호끔 자신감',
#  '게나네 그런 거 지 이제 외국 영화 에 그 ~ 조커 얘기 해서 그런 건데',
#  '꼽제기 완전히 끊 어 낸 상태 였 거든 .',
#  '입 이 강하 니까 그 밥그릇 이 딱 맞 는 거 야 그래서 나 그 밥그릇 좀 사 야 되 겠 어 .',
#  '막 참팟 가 꼽제기 게훽 도 세우 고 언마니 좋 아휴',
#  '내 가 호끔 더 마슴 의 정리 가 필요 했 젠도 싱각 을 해서',
#  '게나네 기여 갖 고 좀 철저히 고증 돼 가재이 고 그렇 게 했 음 좋 겠 는데',
#  '비 공개 계정 드레 바꾸 고 호끔 필요 한 정우 가 있 어네',
#  '그래서 여름 에 는 보통 대비 을 신 지 않 잖아 그래서',
#  '그런 것 이 자꼬 스트레스 쌓이 는 거 야 그런 것 이 탄난 거 에 쓰 쓰 쌓이 는 것 이 으어 라',
#  '이제 까장 부미 님 이 준 용돈 을 내 가 거수루 줘야 한다 싱각 이 들 어네 이런 알바 를 하 는 거 야 .',
#  '해 가재이 고 시갠 이 호끔 오래 걸렸 던 거 같 고 그래서 결국 이벤트 까장 는 안 돈 으어 더라도 호끔 비슷 하 게 는 했 던 거 같 애요 혹시',
#  '호끔 시계 를 으어 하양 모으 지 는 못하 고 있 고 그래도 몇 개 호끔 이르 케',
#  '쪼끔 어려운 부분 이 호끔 있 어요 그래서',
#  '꼽제기 감정 기복 도 덜 하 고 좀 꼽제기 말투 도 덜하 고 왜 경상도 말투 는 막 강 하 게 막 말 하 잖아 .',
#  '그리고 물 을 따뜻 한 물 을 한 잔 마셔 .',
#  '그런데 그 당시 에 는 요양원 이 없 었 고 요양 빙원 도 그추룸 없 었 어 .',
#  '애니메이션 이 아닌 거 야 그래서 저듸',
#  '호끔 베꼍 드레 잘 표출 해서 좀 세계 화 시킬 수 있 는',
#  '그래서 그거 하 는데 저 는 쪼끔 매콤 한 거 좋 아 한다고 가싸 말씀 드렸 다시피 쪼끔 매운 걸 좋 아 해 가재이 구',
#  '그러면은 서로 갈라지 는 거 요 찢어지 는 거 야 친귀 간 에 도',
#  '그러니깐 아무래두 뭐 ~ 사롬 대하 는 거 이런 것 도 호끔 하양 좀 배우 고',
#  '그런 거 에 퍼찍 이녁 자존 감 을 높이 는',
#  '그러 소릿길 호끔 꼽제기 핸드폰 좀 작동 좀 알려 달 니향 그분 이 그러 시 더라고요 .',
#  '고쩌 깁스 하 고 이녁 할 거 응 ~ 고쩌 운 재활 운동 하 러 갔 젠도',
#  '그래서 친정 에서 도 어 ~ 그추룸 하 면 안 된다는 거 야 이녁 는 아 ~ 말 도 안 된다는 소리 해 내 가 그추룸 하 면',
#  '얇 은 목걸이 를 했 는데 도 천지만지 뭔가 나 를 호끔 옥죄이 는 거 같 고',
#  '하 소릿길 불키 고 서로 콩주름 좀 약간 익 는 듯 하 면 뒤적거려 그러 면은',
#  '게민 일 호차 를 하 소릿길 뭐 시기 와 질투 를 호끔 받 으셨다고 했 는데',
#  '몇 초 인지 더 중요 하 기 따문 에 내 세트 수 와 어쓱 이제 보 고 이제 고짝 고쩌 내 거 에 집중 을 해야 되 지 내 자세 를 보 고',
#  '그 쪽 보상 을 좀 하양 받 았',
#  '이제 그때 미명밭노래 를 진짜 하양 찾 아서 들 었 는데 그때 는 이제 싸이월드',
#  '아쉽 젠도 도 볼 수 있 는데 좋 은 점 이 한나 가 있 는 게 .',
#  '여주 가 이지아 인가 그 사롬 이 거든 그 사롬 발견 한 거 야',
#  '부미 를 원망 하 소릿길 현재 사훼 에 대한 분노 를 가재이 게 되 는 거 야 그래서 살 아가 하 기 따문 에 잠시',
#  '그래서 뭔가 막 술 을 먹 는데 호끔 아쉽 다는 식 드레 막 훌터 얘기 하 는 거 야 안쥐 가 너미 아쉽 다 뭐 한다 뭐 한다 머식 는 거 야 .',
#  '그 ~ 그 ~ 그건 가 아닌가 모르 겠 는데 그런 종류 꼽제기 패스 츄 리야 일종 이',
#  '좀 이땅 보 니까',
#  '재게 죽 고 싶 구먼 .',
#  '기억 을 잃 어 냇내 다 .',
#  '대화 는 절흔 준비 에 대한 말 보단 아덜 딸 자오 하 는 게 분위기 도 띄우 고 좋 은 것 같 아휴 .',
#  '그런 같잖 은 일 을 가재이 고 말다툼 을 하 니 ?',
#  '어매 장 보 러 가 셨 어 .',
#  '이 사롬 저 사롬 드나들 면 좋 지 않 아휴 .',
#  '어떨 땐 키 가 큰 사롬 이 나타나 기 도 하 고 또 어떨 땐',
#  '만디 도 수 도 없이 했 구 음식 좀 했 어 ?',
#  '그러 구 보 니까 넌 참 벨멩 극 과 극 이 다 .',
#  '이왕이면 입 어 보 지 .',
#  '결국 이런 말 할 거 소릿길 왜 데이트 하 재요 ?',
#  '읫날 에 그 멋 짐 이 하양 줄 었 어 예놈 에 살 따문 에',
#  '곤밥 이 든 보리밥 이 든 무쉐 솥 에 넣 어라 .',
#  '이젠 그추룸 공통 된 이왁 가 없 고요 .',
#  '개고 돼 지 고 만딱 포유 동물 이 지 .',
#  '참팟 집 에 오 는 거 하양 망설이 고 용기 가 필요 했잖아요 .',
#  '부루 로 겉절이 해 먹 어도 맛있 더라 .',
#  '나 는 난 그런 거 못 해 머식 소릿길 참팟 엄마 는',
#  '좁 은 엄마 배 속 에서 두 년석 이 있 는데 이녁 들 도 오직 갑갑 하 겠 냐 ?',
#  '굴흔데 이 년석 이 어드 서 시치미 떼 ?',
#  '가겟방 아저씨 가 참팟 아빠 절친 이 거든 .',
#  '오널 눈 온다구 하 더니 .',
#  '호명정구 가 옆 에서 볶아치 다 아주',
#  '지금 뭐 하 고 있 는 거 예요 ?',
#  '이 사롬 과 는 한반치 승부 를 벌였 다는 것 자치버렝이 만 드레 도 만족 스럽 다 .',
#  '입힐 니향 또 서 케 스린 건 입 에다 지근지근 지근지근 깨문 다 이제 @ 웃음차제기',
#  '큰일 났 다 큰일 났 다 하 소릿길 했 는데 어 ~ 뭐 ~ 그런 거 는 안 하 시 더라고',
#  '시내 나갈 필요 도 정말 없 겠 구나 싶 더라니까 .',
#  '스굼푸 없이 는 얻 는 것 도 없 어 .',
#  '네 그럼 언니 가 과외 하 는 집 도 여괴 ?',
#  '그럼 선배 들 혼 낸 게 다 싱각 해서 역불 그런 거 에요 ?',
#  '그 ~ 하르버지 가 혼자 뭐 ~ 꼽제기 못 다니 니까는',
#  '대수로운 엑쉬 는 으어 다 .',
#  '미련 한 사롬 이 마른 땅 에서 삼통 을 판다 .',
#  '걔 가 꼽제기 안 하 고 막 머식 면은 그 그 지지 배 그러 는데 성신 차리 고 하 니향',
#  '회장 님 없 어도 난 언매 든지 살 수 있 어요 .',
#  '나 잡상인 으어 고 이 회사 @ 일름 상무 만나 러 왔 어요 .',
#  '굴흔데 너 는 그럼 완전 기냥 발라당 뒤집 어 진 거 는 없 어 ?',
#  '@ 일름 2 오빠 두 옆 에서 호끔 씩 도와 주 겠 다 .',
#  '@ 일름 5 가 뭐 라 그러 면 어떡 해 ?',
#  '날씨 가 추워 지 고 있 어 .',
#  '그런 거 없 어요',
#  '기여 아직 도 창업 을 구상 중 인가 ?',
#  '상무 님 지금 외출 중 이 신데요 .',
#  '방 안 에서 종일 나 만 기다리 고 내 일름 만 부르 고',
#  '혼자 서 는 도저히 할 수 없 어 .',
#  '그래도 그 안 에서 발전 이 라든지 장점 된 부분 은 있 젠도 는 싱각 은 들 어 가재이 고',
#  '공 하양 들어가 는 걸 했 어요 ?',
#  '그 길 은 화살 추룩 훌터 쭉 뻗 어 있 어 .',
#  '그런데 그런 자유 니향 하 는 거 는 .',
#  '@ 일름 2 밧파니 @ 일름 언마니 행복 하 게 지내 는지',
#  '네 가 죄송 할 게 뭐 있 어 ?',
#  '대체 왜 집 에 안 가 고 붙 어 있 는데 ?',
#  '@ 일름 2 야 할망 가 잘못 했 다 .',
#  '활발 하 게 활동 하 고 있 다 .',
#  '손가락 이 라도 잘렸 어 ?',
#  '야 야 재게 돈 이나 내놔라 .',
#  '그래도 참팟 작 은 아방 가 서월 에 큰 회사 에 들어갔 는데 운 이 좋 았 다 .',
#  '그 향 이 염쉐 탕 밧파니 보신탕 이 하양 강하 젠도 하 더라고',
#  '이상 하 게 들리 겠 지만 난 아직 도 통금 시갠 이 있 어 이젠 가 야 해 .',
#  '그래요 나종 에 또 통화 해요 .',
#  '제 힘 만 드레 는 역부족 이 예요 .',
#  '아매 다심 주 에 완 공식 할 수 있 을 것 같 은데',
#  '그 난리 를 겪 게 했 는데 상치 를 안 줘 ?',
#  '어매 뭐 래니 ?',
#  '왜 소린 질러 하 기 싫 음 말 지 라면 삶 아 먹 으면 되 잖아 .',
#  '영어 도 못 하 소릿길 하꼼하민 잘난 척 은',
#  '오널 꼽제기 가족 회의 를 하 는 이유 는',
#  '게나네 머식 이것 도 저것 도 참 꼽제기 애매 한 그런 상황 이 에요 그리고 이제 그 ~ 역류 성 식도염 도',
#  '자꼬 까불 어 따라와 내 가 찾 아 줄게 .',
#  '쪼끔 톡 쏘 고 강한 향 을 좋아하 는데',
#  '어네 가 보 세요 .',
#  '삼 십 년 을 이녁 손 드레 키웠 으면 고릴라 삿메끼 도 정들 었 겠 다 ?',
#  '그럼 - 저거 - 저듸 있 는 이런 거 전부 공짜 로 먹 는 거 예요 ?',
#  '비꼬 지 마 .',
#  '그래서 나 는 걔 네 랑 너미 친해 갖 고 난 대학교 친귀 인 줄 알 았 지 .',
#  '@ 일름 3 이 가 좀 걱정 돼서 그래요 .',
#  '원칙 주의자 니 ?',
#  '지구 중심 의 지층 들 이 이동 하 고 있 기 땜 에 훌터 지진 이 불가피 해 지 고 있 다 .',
#  '정말 속상해서 절흔 도 거듭 .',
#  '안 해도 되 는 일 나 따문 에 해 준 것 도 알 겠 고',
#  '아유 너미 늦 었 다 .',
#  '누가 삼 일 도 안 된 커튼 을 빨 아휴 그것 도 이 밤 에',
#  '오널 하늘 이 다르 디 ?',
#  '언마니 심장 이 오그라든 줄 알 아휴 ?',
#  '안 됐 지만 돈 가진 것 이 없 습니다 .',
#  '가싸 는 분명 비 가 내렸 는데 지금 은 눈 이 내리 고 있 어요 .',
#  '가끔 주세 를 부릴 땐 제 삼 의 인격 이 나타나 고',
#  '제 가 혹시 어드 로 가 야 휴대폰 을 받 을 수 있 을까요 ?',
#  '@ 이름씨 가 어떤 재쥐 를 피워 서 라도 두 사롬 갈라 놨으면 그런 마슴 이 었 어 .',
#  '새아가 여괴 와서 앉 어 봐 .',
#  '전 개인 적 드레 결혼식 같 은 그런 형식 적 인 게 벨로 중요 하 지 않 젠도 싱각 하 거든요 .',
#  '쉬 긴 쉬 었 는데 이게 제작 일정 이 있 고 짜여진 스케줄 대로 만딱 만딱',
#  '하루하루 가 불안 해서 미치 겠 어요 .',
#  '그게 미신 소리 여 ?',
#  '갓세 연 이 으어 예요 .',
#  '내 가 때 가 필요 하 다구 했 다니까 아범 깐깐 한 성격 에 이럴까 저럴까 복 잡 하 게 싱각 할 거 아냐',
#  '눈치 어떠 시 니 ?',
#  '맛있 는 케잌 은 금방 다 팔렸 네 ?',
#  '이따 따뜻 한 거 먹 어 .',
#  '그럼 또 고것 도 그 제 가 막 악보 볼 줄 알 가니 그것 도 그거 하 면은',
#  '게나네 애 가 기냥 알 아서 진짜 한다고 하 거나 그러 면 안 들어가 는데',
#  '일단 은 저 는 호끔 - 아 - 아팠 던 건강 이 니향 하 니까 그러 는데',
#  '나 는 그추룸 싱각 하 는데 그런데 또',
#  '시름초 를 끊 으려면 은',
#  '아 ~ 엄청 컸 던 기억 이 나 는데 그때 어렸 을 때 여 가재이 고',
#  '게나네 한마디 로 호끔 눈치 있 게 그렇지만 서로 가티 협력 할 부분 은 협력 하 고',
#  '작 은 입저 들 만 사용 하 는 거 기 따문 에',
#  '가슬 옷 은 - 우 - 어떻 게 올히 는 어떻 게 - 저 - 저듸',
#  '이제 씻 는 것 만 나종 에 하 죽장 기여 갖 고 일찌겡이 요슷 시 호끔 넘 어 갖 고 주인장 신디 전화 를 해서 죄송 한지 물 이 안 나온다고 화장실 물 을 못 내린다고 그랬 더니',
#  '이 태조 는 요답 번 째 이짜 망좆 아덜 인 의안대군 의 요팡석 을 왕세자 로 삼 았 는데',
#  '그 마슴 에 흡족 할 수 는 없 겠 지 그런데 이제 뭐',
#  '잘도 챙겨 보 고 제 영국 이피 엘 어 ~',
#  '팔 십 이 넘 었 는데',
#  '그렇 지 그렇 지 기여 갖 고 그거 는 인제 검진 뭐 ~ 드라마 가 끝 날 때 쯤 에 야 모돈 게 다 밝혀 지 소릿길 드라마 가 끝나 지 .',
#  '그추룸 걸 어 다니 다가 수영 선쉬 돼 .',
#  '내 가 나이 먹 어 보 니까 눈 온 게 벨로 안 좋 더라고 .',
#  '그런 좀 더 신경 을 쓰 다 보 면 아멘해도 주가 가 지다리 고 내리 고 하나하나 그런 거 에 호끔',
#  '어 ~ 몬처 본인 의 소득 과 지출 에 대해서 정확히 알 아가 해 .',
#  '굴흔데 이제 게임 좋 아 하 고 이런 거 공비 에 는 대렵 관심 이 덜하 고 막 이런 다 하 니까',
#  '게나네 맞 는 사롬 이 있 고 안 맞 는 사롬 이 있 대 굴흔데 나 는 벨로 그런 게 없 었 거든 .',
#  '꼽제기 하양 꼽제기 얘기 를 하 는데 그런 거 따문 에 하양 다투 고 그랬 지 체얌 에 는',
#  '또 듣 는 것 도 있 었 지만 호끔 그러 한 부분 에 있 어네 호끔 개선 했 으면 하 는 뭐 ~ 그런 싱각 이 들 기 도 하 거든 ?',
#  '호끔 청력 도 좀 걱정 이 되 더라구 기여 가주 구',
#  '저듸 라인 이 호끔 있 는 거 같 더라고',
#  '그런데 그것 이',
#  '굴흔데 좀 교수 님 나 는 담당 교수 님 이 되게 젊 으신 분 이 거든 .',
#  '막 후추 귀엽 다는 소리 도 하양 듣 고 그래서 기분 이 좋 았 는데',
#  '거 참팟 알 바 너 구할 때 나 신디 말 해 나 도 호끔 알아보 게',
#  '약간 걱정 이 되 긴 하 는데 그래서 저 는 머력 가 호끔',
#  '아니면 기냥 내 가 덜 먹 어네 빠진 건더기 모르 겠 는데',
#  '그분 들 만나 려면 두 시갠 을 그듸 서 총 세 네 시갠 을 그듸 서 있 선관 되 는데',
#  '식귀 들 이 정말 긴장 그 김끼 맛 을 좋 아 한나 봐',
#  '그래서 그걸 계기 로 해 갖 고 부동산 사놓 고 주식 이 이제 굴흔데 오만 원 그때 를',
#  '그러 지 인제 애 들 이 쪼끔',
#  '그런데 내 나이 가 내 나이 인지라 지금 은 건축 기사 가 되 는 것 도 힘들 고 막상 과거 로 가 는 것 도 힘드 니까',
#  '또 그때 만 의 감성 들 이 있 더라고',
#  '게나네 네 고왕 광희 재미있 연게',
#  '나영석 피디 가 어떻게 그추룸 재밌 는 게임 들 을 다 만들 어 내 는지 나 는 너미 신기 해 .',
#  '나 랑 참 참말로 비슷 한 점 이 많 아 .',
#  '순천 에서 @ 상호 명 라는 데 가 있 어 그런데 그듸 는',
#  '게나네 나 는 이제 미쳐 버려 .',
#  '게나네 스타일 이 라는 게',
#  '게나네 참팟 는 그때 읫날 에 어려서 뭔 물 을 사 먹 어 막 그랬 을 때 부떰 걔 네 는 물 을 사 먹 었잖 아 그만큼 물 사정 이 안 좋 젠도 그듸 는',
#  '그래서 뭐 ~ 기냥 단발 이 으어 라 그듸 그 상태 에서 호끔 파마 를 하 던가',
#  '밤 아옵 시 넘 으면 아시예 사롬 이 없 어',
#  '그래서 이제 그 놈 을 해 가재이 고',
#  '그래도 좀 몇 명 꼽제기 배출 을 해요 .',
#  '탄난 과 로 가 고 싶 어 너 는 잘 맞 아 ?',
#  '이게 시장 같 은 데 서 나 마트 같 은 데 서 사면 물훼 가 회도 적 고 그렇 잖아 .',
#  '그리고 이제 그추룸 다 담 아 보 려고 .',
#  '확실히 그거 먹 고 양지 이 팽팽 해진 가 ?',
#  '난 이 미명밭노래 가 내 십 팔 번 곡 이 야 .',
#  '그렇 지 좀 기여',
#  '어떻게 올라왔 데 걔 는 ?',
#  '게민 원처',
#  '저 사롬 어떠 냐 네 가 만나 보 니까 호끔 괜찮 냐 그랬 더니 야 너 신디 아깝 다 야 놓치 지 말 아라 .',
#  '그 싱각 을 호끔 하양 드 는 시기 가 되 다 보 니까',
#  '비교 를 안 해 본 거 같 아 .',
#  '쉐집 에 가 면 .',
#  '쓰 는 거 같 아 성분 도 호끔 좋 은 성분 을 쓸려고 하양 찾아보 기 도 하 고',
#  '그거 를 빠지 지 않 고 다운 받 아 가재이 고 보 든가 막 그런 식 드레 하 게 되 는 것 같 아휴',
#  '옷 을 주 고 구두 도 줘 으어 다 .',
#  '상가 행성 이 꼽제기 됐 거든',
#  '그런데 그듸 서 상방 상방 미명밭노래 를',
#  '친귀 들 지금 시너 명 그듸 다녔 는데 애 들 이 너미 좋 아 한대요 . 기여 가재이 고',
#  '노래방 에서 는 좀 뭐 라 해야 데 지 좀 그 체얌 에 막 발라드 타임 이 있 고',
#  '아모리 맛있 어도 호끔 가티 호끔 매치 가 돼야지 먹 잖아 ?',
#  '소저 네 소저 야 . @ 웃음차제기',
#  '장그르헤 엔가 아이폰 막 나온다고 했 을 때 예약 구매 해 가재이 고 막 사롬 들 이 택배 배송 을 받 았 다는데',
#  '나 같 으면 참팟 엄마 꼴 안 보 지 그런데 방금 이왁 했 듯이 절흔 유자 된 것 이 선택 의 여지 가 없 었 고',
#  '그러니까는 좋 았 지 어쓱 씩 만 일 해도 뭐 꽤 짭짤 했 어 한 달 에 뭐 한 삼 십 만 원 정도 들어오 니까 .',
#  '애기 들 은 기냥 보람 어떻게 게나네 애기 들 조차 사실 느네 들 도 벨로 안 좋 아 하 거든요',
#  '어 ~ 그러 다 이제 저 는 군대 갔 을 때 호끔 특이 했 던 제 경험 은',
#  '약물 중독 과 알코올 의존 증 같 은 무서운 중독 에 쉽 게 노출 된다고 해 .',
#  '아 누군지 알 겠 다 .',
#  '내 가 훌터 그 ~ 얘기 를 하 다 보 니까 말 이야 좀 싱각 이 든 게 있 는데',
#  '게나네 하를 종일 말 도 안 통하 는 애 들 하고 꼽제기 얘기 하 고 있 다가',
#  '그게 그게 이녁 들 이 남제 들 이 나 는 내 가 그랬 거든 봉토지 에다 일름 을 써 줘라',
#  '감정 이 메말랐 어 언니 왜 그럴까 감정 을 되살려 주 세요 .',
#  '그럼 봐 봐 옆 인데 전화 할 거 으어 에요 .',
#  '어 ~ 너 나이 가 이제 몇 인데 어 ~ 언매 든지 할 수 있 다 .',
#  '호끔 뛰 고 싶 은데',
#  '지금 이번 달 에 보 니향 나 신디 냉기 이 왔 는데 기냥 안 볼 싱각 이 거든 지금 이게 다 몇 학년 까장 하 는 건더기 잘 모르 겠 고',
#  '그러면은 체얌 에 는 호끔 들 어 줘',
#  '연하 게 루주 정 루즈 정도 바당 면 될 거 같 애요 굴흔데 막 어 ~',
#  '나 도 내 가 어째 그런가 모르 겠 어 .',
#  '나 는 친정 에서 게나네 참팟 아방 는 기냥 내 삿메끼 내 삿메끼 벌벌벌 하 소릿길 그추룸 자랐 는데',
#  '굴흔데 참팟 같 은 정우 에 는 그추룸 다 상당히 다 안 해 냇내 잖아 .',
#  '굴흔데 귤 을 팔 러 갔 는데 그런 데 보통 인수인계 를 안 해 주 니까 단기 아르바이트 는',
#  '뭐 ~ 주말 에 하간 사롬 모여서 - 게임 하 - 게임 하 는 게 이제 는 호끔 힘든 상황 이 니까',
#  '재미있 다 하 더라 ?',
#  '어 설 것 아 그듸 이제 그만두 고 비자 가 나왔 으니까 노래방 에서 아르바이트 를 했 거든 ?',
#  '굴흔데 밖 에서 꼽제기 - 걷 - 걷 는 거 꼽제기 그듸 에서 꼽제기 뛴 거 하고 또 틀린가 봐 .',
#  '게나네 훌터 그 정보 를 얻 기 위해서 오 더라고 .',
#  '그러고 이제 그 꺼풀 는 물 팔 팔 끓인 그럼 딱 대침 은',
#  '네 그렇 죠 한 번 형성 된 성격 은',
#  '아 그랬 다 네 시갠 해 기여 가재이 고 어 이 가 없 어네 네이버 에 쳐 봤 다 혹시 ?',
#  '@ 상호 명가 기냥 - 미니 - 미니 백 팔 십 구 인데',
#  '사롬 이 나이 가 한나 라도 더 들어가 면',
#  '엘에이 치 는 그런 꼽제기 뭐 라 해야 되 지 주택 금융 공사 랑 엘 에 이치 의 호끔 큰 차이점 은',
#  '이제 초보 티 를 막 벗 은 상태 여 가재이 고 약간 중고 로 호끔 가볍 게 살 거 랑근에',
#  '이제 좀 즐겨 보 려고 하 니까',
#  '너 도 탄수화물 안 먹 는 게 제일 중요 하 젠도 싱각 하 지 않 냐 ?',
#  '아 ~ 저 초등 학게 때 인가 그 ~ 이근호 선쉬 가 되게 호끔 핫 했 을 때',
#  '안 그래도 요새 얘 가 왜 음식 을 해 달 라는 소리 를 안 하 지 안 그래도 궁금 했 고 만',
#  '누나 가싸 말 했 던 그 ~ 회색 회색 츄리닝 티 있 지 않 아 ? @ 웃음차제기',
#  '그 사실 을 그대로 보여 주 는 과거 도 그렇 고 - 내 - 내 가 호끔 마슴 이 되게 불편 했 던 건',
#  '이녁 연 있 을 때 엄마 가 간섭 해 가 못 가 게 했잖아 .',
#  '게나네 이게 마슴 에 드 는 선물 찾 기 가 이게 싱각 바레다 어렵 다 .',
#  '아 ~ 으어 다 롯데마트',
#  '그때 는 사롬 이 호끔 내 가 나 호끔 게으르 다 ?',
#  '호끔 표준 을 세워야 될 거 같 다 .',
#  '이녁 는 인제 동료 가 기냥 그 ~ 이제 뭐 ~ 밥 한 그릇 먹 으라 그러 니까',
#  '요새 는 인터넷 에 보 면은',
#  '너 는 군대 에서 뭐 ~ 아 는 사롬 만난 거 없 어 ?',
#  '호끔 올라가 볼까 한 시갠 정도 하 면 이제 다 되 는 짧 은 코스 가 있 어네',
#  '꼽제기 디엠비 켜 서 본 방송 챙겨 보 고 그랬었 거든요 .',
#  '굴흔데 유독 유튜브 에 그게 진짜 조회 수 가 하양 나오 더라 .',
#  '보통 밀양 은 그 ~ 얼음골 사롬 들 이 호끔 하양 얼음 골 들 어 봤 죠 ?',
#  '굴흔데 단발 을 하 하 니향 하 는 사롬 이 너 밖에 없 고 탄난 애 들 다 막',
#  '이게 세련 되게 꼽제기 호끔 하 려니까',
#  '벨로 그추룸 존경 할 뭐 ~ 정치인 이 든지 뭐 ~ 문학 적 이 든지 이런 정 뭐 ~ 존경 할 사롬 이 벨로 없 는 거 같 애 예전 바레다 는 .',
#  '그러 다 보 니까 호끔 편하 게 있 을 때 가 많 은데 굴흔데 확실히 상담 을 하 고 이럴 때 호끔 느꼈 던 거 는',
#  '왜 그추룸 시갠 이 안 가 는지 약간 진짜 궁뎅이 가 들락들락 걸리 고 약간 일어서 고 싶 고 호끔 그랬 어 .',
#  '좀 이제 는 읫날 에 는 안 그랬 는데 지금 은 호끔',
#  '뭔가 돈 도 호끔 비쌌 을 거 같 은데 기냥 오만 원 받 고 땡 쳤 니 ?',
#  '뭐 ~ 한 이 십 만 그 ~ 명품 뭐 ~ 까진 으어 더라도 그 ~ 호끔 중 저급',
#  '그리고 요거 랑 호끔 성제 만화 가 죠 용비 불패 란 만화 가 있 는데',
#  '볼 이 좁 아 가재이 고 저 랑 잘 안 맞 연게',
#  '맞 아 맞 아 그리고 첫 번 째 로 좋 은 게 나 신디 돈 부담 이 없 어 @ 웃음차제기',
#  '아 ~ 그래서 스트레스 를 은근히 받 더라고요 그런데 이 ~ 탁구 나 뭐 ~',
#  '기냥 차 가재이 고 롯데 는 백화점 이 너미 복잡 해서 차 쟁이 가 너미 힘드 니까',
#  '굴흔데 그게 맞 는 사롬 이 있 고 또 안 - 아 - 아닌 사롬 도 있 는 가 바레다 성격 상 xx',
#  '게임 하 러 내 친귀 들 이 올 정도 로 씨 디 가 엄청 많 았 거든 참팟 집 에 그리고 사춘 형 님 이 또',
#  '성격 이 뭐 ~ 꼽제기 딱 부러지 고 이런 성격 이 절대 안 되 는 거 야 그게',
#  '사실 이게 약간 변두리 다 보 니까 그때 당시 에 는 그런 개념 이 저 도 인제 공비 를 호끔 더 하양 했 선관 되 는데',
#  '신랑 이 호끔 뭐 른 뭔 소리 를 하 더라도 쪼끔 챙겨 줄려고 노력 을 노력 을 하 지 .',
#  '탄난 한 생명 을 책임진다는 게',
#  '싱각 바레다 호끔 더',
#  '너 는 막 아유 아빠 운전 을 잘 해서 네 가 면했 다 이영 나 는 꼽제기 는 싱각 안 하 거든 .',
#  '본인 을 호끔 과소평가 하 는 게 있 어 .',
#  '성선 님 은 혹시 그 지역 에 한 번 가 보 신 적 있 는지 호끔 궁금 해요 .',
#  '게나네 그추룸 는 다 하 는 거 다 .',
#  '또 부산 에 는 또 그 ~ 가로수 들 이 또 벚꽃 드레 쫙 되 어 있 는 데 가 있 고',
#  '그런데 봐 봐 고등학교 그래도 - 고 - - 고 - 고등학교 삼 학년 이',
#  '남제 애 가 나 보 고',
#  '뭐 지 그 영화 관 있 고 꼽제기 하 니까 사롬 들 - 오 - 오 는 가 봐 ?',
#  '동승 은 애기 니까 뭐 ~ 집 에 없 고 봐 주 는 분 집 에 있 고 게나네 나 혼자 집 에서 그 ~ 깨진 오카리나 를 엉엉 울 소릿길 하나하나 집 어 갖 고 테이프 로 다 붙였 다 .',
#  '막 특별 한 막 새로 서로 챙겨 주 고 싶 고 뭐 이런 감정 도 없 고 기냥',
#  '그래서 안 봤 지 너 는 뭐 ~ 그런 걸로 뭐 ~ 한 번 배우 거나 한 적 없 나',
#  '나 는 내 지냥 는 무신론자 니향 싱각 하 는데 또 탄난 사롬 이 볼 땐 어떻 게 비춰 지 는지 는 모르 겠 지만',
#  '호끔 모델 을 살 수 있 는 돈 인데 내 가 이걸 또 바꿔서 해야 되 나 이런 고민 에 요새 호끔',
#  '그 ~ 항상 하 는 말 이 뭐 ~ 오빠 만 뭐 ~ 하 고 오빠 만 하 고 하 는데 중형차',
#  '@ 일름 이제 반갑 젠도 막 쫓 아 오 는 거 라 쫓 아 오 니까 걔 는 이제',
#  '어제 바레다 는 그 제 가 더 심했 다 .',
#  '뭐 ~ 학생 들 도 배우 - 지 - 진짜 하양 하 지 않 아 지망생 도 많 고',
#  '그런 집 이 잖아요 요줌 아파트 추룩 이런 형태 가 으어 고 신발 을 신 고 내려 내려가 서 정지 이 있 는 그런 집 이 었 는데 그 ~ 정지 이',
#  '이게 애 들 신디 도 그런 말 되게 하양 하 는데 네 가 지금 이거 할 거 니 저거 할 거 니 했 을 때',
#  '으어 기냥 뭐 ~ 구두 가 그듸 서 - 거 - 그듸 지 뭐 가 다르 지 꼽제기 했 는데',
#  '그게 꼽제기 벼락부자 한 번 에 부제 가 될 수 는 없 젠도 하 더라고요 그게 돈 을 모으 는 거 는',
#  '갑제기 엄청 이렇 게',
#  '어 ~ 된다 라는 그런 게 있 으면 호끔 그런 걸 호끔 팁 을 얻 어네',
#  '그 뒤 론 좀 운동 하 니까 하양 나아지 데 굴흔데 이제 목 은 아직 까장 도 가끔 아프 더라',
#  '그러 다 보 니까 확실 하 게 그 튼튼 하 게 그 올릴 수 있 는 디즈니 아니면은 호끔',
#  '그래서 펀드 매니저 를 안 쓰 는구먼 .',
#  '되게 하간 가재이 있 으신 데 그러 면 가장 기억 에 남 는 영화 는 혹시 어떻게 될까요 ?',
#  '새로 부른다 니 장르 를 말 하 는 거 니 으어 면 뭐 ~ 어떤 거 말 하 는 건데 ?',
#  '기여 가재이 고 나 는 되게 내 가',
#  '뭐 ~ 요리사 라든 꼽제기 쪼금 어 ~ 뭐 ~ 잘 하 시 는 요영 호끔 자신 있 있 으신 요영 가 있 으신지 호끔 궁금 합니다 .',
#  '이 ~ 요줌 세상 에 형사 관련 된 이런 일 들 이 많 은데 그래서 아 ~ 호끔',
#  '게나네 내 나이 바레다 훌작 인칙 돌아가 셨 기 따문 에 그 ~ 모델 이 없 어 가재이 고',
#  '기여 마음속 드레 인제 그추룸 기도 하 소릿길 내 가 길 을 다니 잖아 너 는 어떻게 다녀 다니 소릿길 보 면은',
#  '인제 미명밭노래 를 켜 고',
#  '어색 하 게 느껴 지 는 거 야 으어 약간 정확 하 게 말 하 면 기이 하 게 느껴졌 어 .',
#  '어 ~ 하 소릿길 엄마 너미 아프 다 하 니까 원처 이뻐 질려 면 그 정도 는 참 아가 된다 하 소릿길 미인 이 뭐 ~ 쉽 게 되 는 줄 아 나 그러 소릿길 네 가 털 많 은 거 스트레스 받 았 으니까',
#  '마슴 을 먹 고 있 습니다 사실 은 마슴 은 먹 고 있 고 또 그추룸 살 아가',
#  '이제 유행 밧파니 스타일 에 맞춰서 몇 개 몇 개 를 사 서 딱 하 는 그추룸 돼야 호끔',
#  '그 ~ 성당 단체 에서 아시예 규제 를 해서 안 가 는데 기독교 나 이제 호끔 호끔 탄난 종교 들 같 은 정우 에 는 이런 걸 규제 를 안 하 고 훌터 훌터 가 다 보 니까',
#  '확실히 클래식 콘서트 는 잘 안 가 게 되 는 게 호끔',
#  '독무릅 이 호끔 아팠 던 게 하양 좋 아 지 는 게 느껴 지 더라고요 그리고',
#  '그거 하고 비슷 한 거 같 네 보 니까 지금 진행 이 - 시 - 시대 가 바뀌 소릿길 그추룸 된 거 같 네 .',
#  '지금 은 아멘해도 힘들 다기 바레다 는 번거로운 것 들 이 호끔 많 은 거 같 은데',
#  '아니면 호끔 저 는 개인 적 드레 로망 같 은 게 있 었 기 따문 에 가 고 싶 었 지만',
#  '된다 하 다가 이제 뭐 ~ 그것 따문 에 뭐 ~ 한 달 비자 도 쓰 지 도 못하 고 기냥 끝날까',
#  '요줌 은 호끔 추우 니까 파스텔 색깔 호끔 차분 한 파스텔 색깔 의 니트 입 고',
#  '게나네 펜 트 하우스 그것 도',
#  '좀 그 타임 루프 잘 쓰 면은 좋 다 그게 그 그런 거 같 애요 저 도 꼽제기 아 꼽제기 상상 을 해서 그 다심 에 와 닿 고 이게 이해 가 돼서 막 매끄럽 게 되 면은 뭐 ~',
#  '크 게 저 도 안 신 신경 안 쓰 고 하 기 땜 에 얘 가 이녁 가 알 아 살 아 니향 이왁 를 하양 하 거든요 .',
#  '어 ~ 제 가 그 ~ 올히 시적 을 할려고 했 는 거 는 어 ~ 쉼터 입니다 쉼터',
#  '기지게 큰 고모 신디 전화 하 니까',
#  '지금 고쩌 웬폴 로 갔 는 거 같 더라고',
#  '이 ~ 호끔 어렵 더라구요 .',
#  '야 참팟 황 이 있 지 않 니 참팟 황 이 이제 저을 이 잖아 기여 가재이 고 이제',
#  '나 기분 이 좋 아 지 는 거 같 아 .',
#  '뭐 ~ 두 분 쓰 시 는 게 없 어네 뭐 ~ 온정 적 인 건더기 살 잘 얘기 를 안 하 시 더라고요 그래서 걱정 이 좀 되 긴 합니다 요줌 에 중 장년층 은 호끔 어떠신가요 ?',
#  '잘 치 거나 꼽제기 했 을 때 다 기냥 꼽제기 손 한 번 씩 다',
#  '으어 잘 안 맞 지 넌',
#  '진짜 너미 이거 호끔 호끔 미안 하 기 도 하 고 탄난 사롬 들 신디',
#  '바퀴벌레 가 방역 을 해도 기 어 나와 가재이 고 이제 는 쪼끔 마슴 이 호끔 나아지 긴 했 는데 체얌 에 정말 저 집 에 갈 때 무서워 가재이 고 가방 에']

# %%
model_jj.wv.most_similar('마누라')
# Out:
# [('큰한집', 0.9982072710990906),
#  ('호명정구', 0.9980982542037964),
#  ('호명', 0.9979606866836548),
#  ('항긋', 0.99786776304245),
#  ('항것', 0.9973326921463013),
#  ('한굿', 0.9973018765449524),
#  ('마마', 0.9951244592666626),
#  ('큰마누라', 0.9920323491096497),
#  ('큰각시', 0.9857249855995178),
#  ('멍코젱이', 0.6812736988067627)]

# %% [markdown]
# ### KW_data

# %%
kw = saturi_data[saturi_data['reg'] == 'kw']

# %%
kw.reset_index(drop=True, inplace=True)

# %%
kw.head()
# Out:
#    dial original                                            meaning reg
# 0    분멩       분명                                 분명의 방언, 틀림없이 확실하게.  kw
# 1    분벨       분별                     분별의 방언, 서로 다른 일이나 사물을 구별하여 가름.  kw
# 2    분사       분수                               분수의 방언, 사물을 분별하는 지혜.  kw
# 3  분사머리       분수                               분수의 방언, 사물을 분별하는 지혜.  kw
# 4    분초       부추   부추의 방언, 백합과의 여러해살이풀. 봄에 땅속의 작은 비늘줄기로부터 길이 30c...  kw

# %%
print(len(kw))
# Out:
# 14805

# %% [markdown]
# ### GS_data

# %%
gs = saturi_data[saturi_data['reg'] == 'gs']

# %%
gs.reset_index(drop=True, inplace=True)

# %%
gs.head()
# Out:
#      dial original                               meaning reg
# 0    분래하다     분란하다                분란하다의 방언, 어수선하고 소란스럽다.  gs
# 1    분산하다     부산하다   부산하다의 방언, 급하게 서두르거나 시끄럽게 떠들어 어수선하다.  gs
# 2   불구룸하다    불그름하다                     불그름하다의 방언, 조금 붉다.  gs
# 3   불구리하다    불그레하다                 불그레하다의 방언, 엷게 불그스름하다.  gs
# 4  불구무리하다   볼그무레하다             볼그무레하다의 방언, 아주 엷게 볼그스름하다.  gs

# %%
print(len(gs))
# Out:
# 25106

# %% [markdown]
# ### CC_data

# %%
cc = saturi_data[saturi_data['reg'] == 'cc']

# %%
cc.reset_index(drop=True, inplace=True)

# %%
cc.head()
# Out:
#    dial original                                            meaning reg
# 0   분우기      분위기                           분위기의 방언, 지구를 둘러싸고 있는 기체.  cc
# 1   불막대     부지깽이   부지깽이의 방언, 아궁이 따위에 불을 땔 때에, 불을 헤치거나 끌어내거나 거두어 ...  cc
# 2  불막대기     부지깽이   부지깽이의 방언, 아궁이 따위에 불을 땔 때에, 불을 헤치거나 끌어내거나 거두어 ...  cc
# 3  불쇠바닥       불혀                불혀의 방언, 날름거리며 타오르는 불길을 비유적으로 이르는 말.  cc
# 4   불여수      불여우       불여우의 방언, 몹시 변덕스럽고 못된, 꾀가 많은 여자를 비유적으로 이르는 말.  cc

# %%
print(len(cc))
# Out:
# 5856

# %% [markdown]
# ### JD_data

# %%
jd = saturi_data[saturi_data['reg'] == 'jd']

# %%
jd.reset_index(drop=True, inplace=True)

# %%
jd.head()
# Out:
#    dial original                                            meaning reg
# 0   분대질      분탕질                       분탕질의 방언, 집안의 재물을 다 없애 버리는 짓.  jd
# 1    분투       부티   부티의 방언, 베를 짤 때, 베틀의 말코 두 끝에 끈을 매어 허리에 두르는 넓은 ...  jd
# 2    분튀       부티   부티의 방언, 베를 짤 때, 베틀의 말코 두 끝에 끈을 매어 허리에 두르는 넓은 ...  jd
# 3   붇두둥      불두덩                   불두덩의 방언, 남녀의 생식기 언저리에 있는 불룩한 부분.  jd
# 4  불강생이     불강아지                            불강아지의 방언, 몸이 바싹 여윈 강아지.  jd

# %%
print(len(jd))
# Out:
# 17653

# %% [markdown]
# ## Word2Vec_jj

# %%
test = list(jj['word2vec'].values)

# %%
tset = []
for i in test:
    i = i.split()
    tset.append(i)

# %%
tset
# Out:
# [['분쉬', '분수', '분쉬', '분수', '분쉬', '분수'],
#  ['분시', '분수', '분시', '분수', '분시', '분수'],
#  ['분절', '분결', '분절', '분결', '분절', '분결'],
#  ['분채', '부채', '분채', '부채', '분채', '부채'],
#  ['분채질', '부채질', '분채질', '부채질', '분채질', '부채질'],
#  ['사둔칩', '사돈집', '사둔칩', '사돈집', '사둔칩', '사돈집'],
#  ['분짐', '분김', '분짐', '분김', '분짐', '분김'],
#  ['분짓', '분깃', '분짓', '분깃', '분짓', '분깃'],
#  ['하르버지', '할아버지', '하르버지', '할아버지', '하르버지', '할아버지'],
#  ['불', '벌', '불', '벌', '불', '벌'],
#  ['불갈래', '부삽', '불갈래', '부삽', '불갈래', '부삽'],
#  ['불갑', '성냥', '불갑', '성냥', '불갑', '성냥'],
#  ['불게미', '불똥', '불게미', '불똥', '불게미', '불똥'],
#  ['불게예미', '불똥', '불게예미', '불똥', '불게예미', '불똥'],
#  ['불곽', '성냥갑', '불곽', '성냥갑', '불곽', '성냥갑'],
#  ['불궤수웨', '불쏘시개', '불궤수웨', '불쏘시개', '불궤수웨', '불쏘시개'],
#  ['불그네', '고무래', '불그네', '고무래', '불그네', '고무래'],
#  ['불근네', '불고무래', '불근네', '불고무래', '불근네', '불고무래'],
#  ['불근데', '불고무래', '불근데', '불고무래', '불근데', '불고무래'],
#  ['불글레기', '거품', '불글레기', '거품', '불글레기', '거품'],
#  ['불깍', '성냥', '불깍', '성냥', '불깍', '성냥'],
#  ['불깍지', '등잔', '불깍지', '등잔', '불깍지', '등잔'],
#  ['불껑', '재', '불껑', '재', '불껑', '재'],
#  ['불끌럭지', '불꾸러미', '불끌럭지', '불꾸러미', '불끌럭지', '불꾸러미'],
#  ['불끌레기', '불꾸러미', '불끌레기', '불꾸러미', '불끌레기', '불꾸러미'],
#  ['불닥새기', '불알', '불닥새기', '불알', '불닥새기', '불알'],
#  ['불닥세기', '불알', '불닥세기', '불알', '불닥세기', '불알'],
#  ['불도', '산신', '불도', '산신', '불도', '산신'],
#  ['불땡이', '부지깽이', '불땡이', '부지깽이', '불땡이', '부지깽이'],
#  ['불란지', '개똥벌레', '불란지', '개똥벌레', '불란지', '개똥벌레'],
#  ['불미질', '대장일', '불미질', '대장일', '불미질', '대장일'],
#  ['불망골', '불똥', '불망골', '불똥', '불망골', '불똥'],
#  ['불망구리', '불똥', '불망구리', '불똥', '불망구리', '불똥'],
#  ['불망텡이', '불알망태', '불망텡이', '불알망태', '불망텡이', '불알망태'],
#  ['불매대장', '대장장이', '불매대장', '대장장이', '불매대장', '대장장이'],
#  ['불매질', '대장일', '불매질', '대장일', '불매질', '대장일'],
#  ['불미', '풀무', '불미', '풀무', '불미', '풀무'],
#  ['불미간', '대장간', '불미간', '대장간', '불미간', '대장간'],
#  ['하르비', '할아버지', '하르비', '할아버지', '하르비', '할아버지'],
#  ['불미대장', '대장장이', '불미대장', '대장장이', '불미대장', '대장장이'],
#  ['불미와찌', '대장장이', '불미와찌', '대장장이', '불미와찌', '대장장이'],
#  ['불미왕', '대장간', '불미왕', '대장간', '불미왕', '대장간'],
#  ['불미쟁이', '대장장이', '불미쟁이', '대장장이', '불미쟁이', '대장장이'],
#  ['불미칩', '대장간', '불미칩', '대장간', '불미칩', '대장간'],
#  ['불밋간', '대장간', '불밋간', '대장간', '불밋간', '대장간'],
#  ['불방둥이', '불장난', '불방둥이', '불장난', '불방둥이', '불장난'],
#  ['불벳', '불볕', '불벳', '불볕', '불벳', '불볕'],
#  ['불벹', '불볕', '불벹', '불볕', '불벹', '불볕'],
#  ['불삽', '부삽', '불삽', '부삽', '불삽', '부삽'],
#  ['불소슬게', '불쏘시개', '불소슬게', '불쏘시개', '불소슬게', '불쏘시개'],
#  ['불소시개', '불쏘시개', '불소시개', '불쏘시개', '불소시개', '불쏘시개'],
#  ['불수세', '불쏘시개', '불수세', '불쏘시개', '불수세', '불쏘시개'],
#  ['불순', '부손', '불순', '부손', '불순', '부손'],
#  ['불숟가락', '부순', '불숟가락', '부순', '불숟가락', '부순'],
#  ['불숟구락', '부손', '불숟구락', '부손', '불숟구락', '부손'],
#  ['불쏘스개', '불쏘시개', '불쏘스개', '불쏘시개', '불쏘스개', '불쏘시개'],
#  ['불쏘슬개', '불쏘시개', '불쏘슬개', '불쏘시개', '불쏘슬개', '불쏘시개'],
#  ['불아대', '불알망태', '불아대', '불알망태', '불아대', '불알망태'],
#  ['불어귀', '아궁이', '불어귀', '아궁이', '불어귀', '아궁이'],
#  ['불이떵이', '부지깽이', '불이떵이', '부지깽이', '불이떵이', '부지깽이'],
#  ['불잉겅', '불잉걸', '불잉겅', '불잉걸', '불잉겅', '불잉걸'],
#  ['불잉겡이', '불잉걸', '불잉겡이', '불잉걸', '불잉겡이', '불잉걸'],
#  ['불자붐', '부젓가락', '불자붐', '부젓가락', '불자붐', '부젓가락'],
#  ['불접개', '부젓가락', '불접개', '부젓가락', '불접개', '부젓가락'],
#  ['불접시', '등잔', '불접시', '등잔', '불접시', '등잔'],
#  ['불제', '부젓가락', '불제', '부젓가락', '불제', '부젓가락'],
#  ['불짐', '불김', '불짐', '불김', '불짐', '불김'],
#  ['불집개', '부젓가락', '불집개', '부젓가락', '불집개', '부젓가락'],
#  ['불찍', '부싯깃', '불찍', '부싯깃', '불찍', '부싯깃'],
#  ['불퉤미', '불똥', '불퉤미', '불똥', '불퉤미', '불똥'],
#  ['불차디', '불알망태', '불차디', '불알망태', '불차디', '불알망태'],
#  ['불차지', '불알망태', '불차지', '불알망태', '불차지', '불알망태'],
#  ['불채', '산마루', '불채', '산마루', '불채', '산마루'],
#  ['불체기', '땅꽈리', '불체기', '땅꽈리', '불체기', '땅꽈리'],
#  ['불테미', '불똥', '불테미', '불똥', '불테미', '불똥'],
#  ['불한듸', '개똥벌레', '불한듸', '개똥벌레', '불한듸', '개똥벌레'],
#  ['불한디', '반딧불이', '불한디', '반딧불이', '불한디', '반딧불이'],
#  ['불한지', '개똥벌레', '불한지', '개똥벌레', '불한지', '개똥벌레'],
#  ['불화리', '불화로', '불화리', '불화로', '불화리', '불화로'],
#  ['불환디', '반딧불이', '불환디', '반딧불이', '불환디', '반딧불이'],
#  ['불희', '뿌리', '불희', '뿌리', '불희', '뿌리'],
#  ['붉가시낭', '붉가시나무', '붉가시낭', '붉가시나무', '붉가시낭', '붉가시나무'],
#  ['붉낭', '붉가시나무', '붉낭', '붉가시나무', '붉낭', '붉가시나무'],
#  ['붉은게염지', '불개미', '붉은게염지', '불개미', '붉은게염지', '불개미'],
#  ['붕붕이', '게걸쟁이', '붕붕이', '게걸쟁이', '붕붕이', '게걸쟁이'],
#  ['붉은알', '노른자', '붉은알', '노른자', '붉은알', '노른자'],
#  ['붉은헤돋이', '아침놀', '붉은헤돋이', '아침놀', '붉은헤돋이', '아침놀'],
#  ['붉은헤지기', '저녁노을', '붉은헤지기', '저녁노을', '붉은헤지기', '저녁노을'],
#  ['붓도갑', '붓두껍', '붓도갑', '붓두껍', '붓도갑', '붓두껍'],
#  ['붓두께', '붓두껍', '붓두께', '붓두껍', '붓두께', '붓두껍'],
#  ['붕알', '불알', '붕알', '불알', '붕알', '불알'],
#  ['붕애눈', '거적눈', '붕애눈', '거적눈', '붕애눈', '거적눈'],
#  ['붕에바지', '솜바지', '붕에바지', '솜바지', '붕에바지', '솜바지'],
#  ['붕장이', '붕장어', '붕장이', '붕장어', '붕장이', '붕장어'],
#  ['붕젱이', '뱀장어', '붕젱이', '뱀장어', '붕젱이', '뱀장어'],
#  ['붕채', '부채', '붕채', '부채', '붕채', '부채'],
#  ['비낌', '삐침', '비낌', '삐침', '비낌', '삐침'],
#  ['비', '북', '비', '북', '비', '북'],
#  ['빗꾸렝이', '빚꾸러기', '빗꾸렝이', '빚꾸러기', '빗꾸렝이', '빚꾸러기'],
#  ['비근다리', '두툽상어', '비근다리', '두툽상어', '비근다리', '두툽상어'],
#  ['비근더리', '복상어', '비근더리', '복상어', '비근더리', '복상어'],
#  ['비금다리', '수염상어', '비금다리', '수염상어', '비금다리', '수염상어'],
#  ['비께', '두툽상어', '비께', '두툽상어', '비께', '두툽상어'],
#  ['비껭이', '두툽상어', '비껭이', '두툽상어', '비껭이', '두툽상어'],
#  ['비끄렝이', '비탈', '비끄렝이', '비탈', '비끄렝이', '비탈'],
#  ['비끄림', '부끄럼', '비끄림', '부끄럼', '비끄림', '부끄럼'],
#  ['비녓대', '비녀', '비녓대', '비녀', '비녓대', '비녀'],
#  ['비놈', '비름', '비놈', '비름', '비놈', '비름'],
#  ['비눔', '비름', '비눔', '비름', '비눔', '비름'],
#  ['비늠', '비름', '비늠', '비름', '비늠', '비름'],
#  ['비닫이', '북바늘', '비닫이', '북바늘', '비닫이', '북바늘'],
#  ['비대죽', '수수', '비대죽', '수수', '비대죽', '수수'],
#  ['비대축', '수수', '비대축', '수수', '비대축', '수수'],
#  ['비돔', '비듬', '비돔', '비듬', '비돔', '비듬'],
#  ['비둠', '비듬', '비둠', '비듬', '비둠', '비듬'],
#  ['비들귀', '비둘기', '비들귀', '비둘기', '비들귀', '비둘기'],
#  ['빗첩', '빗접', '빗첩', '빗접', '빗첩', '빗접'],
#  ['비떼깃질', '비탈길', '비떼깃질', '비탈길', '비떼깃질', '비탈길'],
#  ['비렁내', '비린내', '비렁내', '비린내', '비렁내', '비린내'],
#  ['하쌀', '조금', '하쌀', '조금', '하쌀', '조금'],
#  ['비로', '비료', '비로', '비료', '비로', '비료'],
#  ['비루도', '벨벳', '비루도', '벨벳', '비루도', '벨벳'],
#  ['비리', '옴', '비리', '옴', '비리', '옴'],
#  ['비리쟁이', '옴쟁이', '비리쟁이', '옴쟁이', '비리쟁이', '옴쟁이'],
#  ['비빔깍신', '딴총박이', '비빔깍신', '딴총박이', '비빔깍신', '딴총박이'],
#  ['비바리', '처녀', '비바리', '처녀', '비바리', '처녀'],
#  ['비받이', '쓰레받기', '비받이', '쓰레받기', '비받이', '쓰레받기'],
#  ['비시', '켜', '비시', '켜', '비시', '켜'],
#  ['비아기', '병아리', '비아기', '병아리', '비아기', '병아리'],
#  ['비아리', '병아리', '비아리', '병아리', '비아리', '병아리'],
#  ['비알', '귀얄', '비알', '귀얄', '비알', '귀얄'],
#  ['빌은딸', '움딸', '빌은딸', '움딸', '빌은딸', '움딸'],
#  ['비크레깃질', '비탈길', '비크레깃질', '비탈길', '비크레깃질', '비탈길'],
#  ['비애기', '병아리', '비애기', '병아리', '비애기', '병아리'],
#  ['비야기', '병아리', '비야기', '병아리', '비야기', '병아리'],
#  ['비얄', '귀얄', '비얄', '귀얄', '비얄', '귀얄'],
#  ['비얭기', '비행기', '비얭기', '비행기', '비얭기', '비행기'],
#  ['비에기', '병아리', '비에기', '병아리', '비에기', '병아리'],
#  ['송징', '송진', '송징', '송진', '송징', '송진'],
#  ['비염', '뱀', '비염', '뱀', '비염', '뱀'],
#  ['비영게', '비행기', '비영게', '비행기', '비영게', '비행기'],
#  ['비영기', '비행기', '비영기', '비행기', '비영기', '비행기'],
#  ['비옝기', '비행기', '비옝기', '비행기', '비옝기', '비행기'],
#  ['비우제', '기우제', '비우제', '기우제', '비우제', '기우제'],
#  ['비자낭', '비자나무', '비자낭', '비자나무', '비자낭', '비자나무'],
#  ['비저기', '비지', '비저기', '비지', '비저기', '비지'],
#  ['비제기', '비지', '비제기', '비지', '비제기', '비지'],
#  ['비제기국', '비짓국', '비제기국', '비짓국', '비제기국', '비짓국'],
#  ['비제기떡', '비지떡', '비제기떡', '비지떡', '비제기떡', '비지떡'],
#  ['비제깃국', '비짓국', '비제깃국', '비짓국', '비제깃국', '비짓국'],
#  ['비주기', '비쭈기나무', '비주기', '비쭈기나무', '비주기', '비쭈기나무'],
#  ['비주기낭', '비쭈기나무', '비주기낭', '비쭈기나무', '비주기낭', '비쭈기나무'],
#  ['비죽낭', '비쭈기나무', '비죽낭', '비쭈기나무', '비죽낭', '비쭈기나무'],
#  ['비죽새', '박새', '비죽새', '박새', '비죽새', '박새'],
#  ['비죽생이', '종다리', '비죽생이', '종다리', '비죽생이', '종다리'],
#  ['비죽쟁이', '종다리', '비죽쟁이', '종다리', '비죽쟁이', '종다리'],
#  ['비지낭', '비자나무', '비지낭', '비자나무', '비지낭', '비자나무'],
#  ['빈찍', '번쩍', '빈찍', '번쩍', '빈찍', '번쩍'],
#  ['빈채', '공차', '빈채', '공차', '빈채', '공차'],
#  ['비쭉새', '종다리', '비쭉새', '종다리', '비쭉새', '종다리'],
#  ['비차락', '빗자루', '비차락', '빗자루', '비차락', '빗자루'],
#  ['비처럼', '부끄럼', '비처럼', '부끄럼', '비처럼', '부끄럼'],
#  ['비치락', '비', '비치락', '비', '비치락', '비'],
#  ['비치럼', '부끄럼', '비치럼', '부끄럼', '비치럼', '부끄럼'],
#  ['빈내', '비녀', '빈내', '비녀', '빈내', '비녀'],
#  ['비크레기', '비탈', '비크레기', '비탈', '비크레기', '비탈'],
#  ['비크렝이', '비탈', '비크렝이', '비탈', '비크렝이', '비탈'],
#  ['비크렝잇질', '비탈길', '비크렝잇질', '비탈길', '비크렝잇질', '비탈길'],
#  ['비킴', '삐침', '비킴', '삐침', '비킴', '삐침'],
#  ['빈네', '아욱메풀', '빈네', '아욱메풀', '빈네', '아욱메풀'],
#  ['화벵', '화병', '화벵', '화병', '화벵', '화병'],
#  ['빅데기', '비탈', '빅데기', '비탈', '빅데기', '비탈'],
#  ['빅데깃질', '비탈길', '빅데깃질', '비탈길', '빅데깃질', '비탈길'],
#  ['빈데', '아욱메풀', '빈데', '아욱메풀', '빈데', '아욱메풀'],
#  ['빈데쿨', '아욱메풀', '빈데쿨', '아욱메풀', '빈데쿨', '아욱메풀'],
#  ['빈독낭', '천선과나무', '빈독낭', '천선과나무', '빈독낭', '천선과나무'],
#  ['빈몸', '맨몸', '빈몸', '맨몸', '빈몸', '맨몸'],
#  ['빈물', '맹물', '빈물', '맹물', '빈물', '맹물'],
#  ['빈복다리', '복처리', '빈복다리', '복처리', '빈복다리', '복처리'],
#  ['펄룽이', '왕눈이', '펄룽이', '왕눈이', '펄룽이', '왕눈이'],
#  ['빨레', '빨래', '빨레', '빨래', '빨레', '빨래'],
#  ['어림성', '어렴성', '어림성', '어렴성', '어림성', '어렴성'],
#  ['뻔데기', '번데기', '뻔데기', '번데기', '뻔데기', '번데기'],
#  ['사뒈', '사삿되', '사뒈', '사삿되', '사뒈', '사삿되'],
#  ['뻭', '비역', '뻭', '비역', '뻭', '비역'],
#  ['뽈래', '빨래', '뽈래', '빨래', '뽈래', '빨래'],
#  ['뽈치', '빨부리', '뽈치', '빨부리', '뽈치', '빨부리'],
#  ['뽐', '뼘', '뽐', '뼘', '뽐', '뼘'],
#  ['뽕돌', '봉돌', '뽕돌', '봉돌', '뽕돌', '봉돌'],
#  ['뽕남여름', '오디', '뽕남여름', '오디', '뽕남여름', '오디'],
#  ['뽕낭', '뽕나무', '뽕낭', '뽕나무', '뽕낭', '뽕나무'],
#  ['뽕낭여름', '오디', '뽕낭여름', '오디', '뽕낭여름', '오디'],
#  ['뽕낭요름', '오디', '뽕낭요름', '오디', '뽕낭요름', '오디'],
#  ['뽕낭잣', '뽕자지', '뽕낭잣', '뽕자지', '뽕낭잣', '뽕자지'],
#  ['뿌글레기', '거품', '뿌글레기', '거품', '뿌글레기', '거품'],
#  ['하를저녁', '하룻저녁', '하를저녁', '하룻저녁', '하를저녁', '하룻저녁'],
#  ['뿌렝이', '뿌리', '뿌렝이', '뿌리', '뿌렝이', '뿌리'],
#  ['톱상의', '톱상어', '톱상의', '톱상어', '톱상의', '톱상어'],
#  ['뿔리', '뿌리', '뿔리', '뿌리', '뿔리', '뿌리'],
#  ['뿔새위', '가재', '뿔새위', '가재', '뿔새위', '가재'],
#  ['뿡기', '미끼', '뿡기', '미끼', '뿡기', '미끼'],
#  ['할이', '할인', '할이', '할인', '할이', '할인'],
#  ['삐야망데기', '뺨따귀', '삐야망데기', '뺨따귀', '삐야망데기', '뺨따귀'],
#  ['삐죽새', '종다리', '삐죽새', '종다리', '삐죽새', '종다리'],
#  ['삥이', '삘기', '삥이', '삘기', '삥이', '삘기'],
#  ['삥이마농', '파', '삥이마농', '파', '삥이마농', '파'],
#  ['사곰파리', '사금파리', '사곰파리', '사금파리', '사곰파리', '사금파리'],
#  ['사궤맞춤', '사개맞춤', '사궤맞춤', '사개맞춤', '사궤맞춤', '사개맞춤'],
#  ['사그랭이', '사그랑이', '사그랭이', '사그랑이', '사그랭이', '사그랑이'],
#  ['사그렝이', '사그랑이', '사그렝이', '사그랑이', '사그렝이', '사그랑이'],
#  ['사금바치', '사금파리', '사금바치', '사금파리', '사금바치', '사금파리'],
#  ['사나을', '사나흘', '사나을', '사나흘', '사나을', '사나흘'],
#  ['사기패', '사금파리', '사기패', '사금파리', '사기패', '사금파리'],
#  ['사기펭', '사기병', '사기펭', '사기병', '사기펭', '사기병'],
#  ['사나', '사나이', '사나', '사나이', '사나', '사나이'],
#  ['사념살이', '살림살이', '사념살이', '살림살이', '사념살이', '살림살이'],
#  ['사나의', '사나이', '사나의', '사나이', '사나의', '사나이'],
#  ['사나의놈', '사내아이', '사나의놈', '사내아이', '사나의놈', '사내아이'],
#  ['사나의사돈', '바깥사돈', '사나의사돈', '바깥사돈', '사나의사돈', '바깥사돈'],
#  ['사나의상제', '바깥상제', '사나의상제', '바깥상제', '사나의상제', '바깥상제'],
#  ['사녕', '사냥', '사녕', '사냥', '사녕', '사냥'],
#  ['사농', '사냥', '사농', '사냥', '사농', '사냥'],
#  ['사농개', '사냥개', '사농개', '사냥개', '사농개', '사냥개'],
#  ['사농꾼', '사냥꾼', '사농꾼', '사냥꾼', '사농꾼', '사냥꾼'],
#  ['사농바치', '사냥꾼', '사농바치', '사냥꾼', '사농바치', '사냥꾼'],
#  ['흐렝이', '골답', '흐렝이', '골답', '흐렝이', '골답'],
#  ['사농쟁이', '사냥꾼', '사농쟁이', '사냥꾼', '사농쟁이', '사냥꾼'],
#  ['사농캐', '사냥개', '사농캐', '사냥개', '사농캐', '사냥개'],
#  ['사다기낭', '생달나무', '사다기낭', '생달나무', '사다기낭', '생달나무'],
#  ['사당낭', '생달나무', '사당낭', '생달나무', '사당낭', '생달나무'],
#  ['사당대죽', '사탕수수', '사당대죽', '사탕수수', '사당대죽', '사탕수수'],
#  ['사들개', '진펄', '사들개', '진펄', '사들개', '진펄'],
#  ['사랑간', '사랑방', '사랑간', '사랑방', '사랑간', '사랑방'],
#  ['사레', '대야', '사레', '대야', '사레', '대야'],
#  ['사레기', '싸라기', '사레기', '싸라기', '사레기', '싸라기'],
#  ['터럭겡이', '털게', '터럭겡이', '털게', '터럭겡이', '털게'],
#  ['사르리', '근처', '사르리', '근처', '사르리', '근처'],
#  ['사름', '사람', '사름', '사람', '사름', '사람'],
#  ['사름수질', '인절미', '사름수질', '인절미', '사름수질', '인절미'],
#  ['터럭긍이', '털게', '터럭긍이', '털게', '터럭긍이', '털게'],
#  ['사막', '사마귀', '사막', '사마귀', '사막', '사마귀'],
#  ['사망', '행운', '사망', '행운', '사망', '행운'],
#  ['사미', '소매', '사미', '소매', '사미', '소매'],
#  ['사방', '화통', '사방', '화통', '사방', '화통'],
#  ['사분', '비누', '사분', '비누', '사분', '비누'],
#  ['사뽁', '사폭', '사뽁', '사폭', '사뽁', '사폭'],
#  ['사상벌', '말벌', '사상벌', '말벌', '사상벌', '말벌'],
#  ['사셍', '사생', '사셍', '사생', '사셍', '사생'],
#  ['사시', '근방', '사시', '근방', '사시', '근방'],
#  ['사올쪽', '상앗대', '사올쪽', '상앗대', '사올쪽', '상앗대'],
#  ['사어', '상어', '사어', '상어', '사어', '상어'],
#  ['사오기', '벚나무', '사오기', '벚나무', '사오기', '벚나무'],
#  ['사올대', '상앗대', '사올대', '상앗대', '사올대', '상앗대'],
#  ['사옹대', '상앗대', '사옹대', '상앗대', '사옹대', '상앗대'],
#  ['사우', '새우', '사우', '새우', '사우', '새우'],
#  ['속대왓', '쑥대밭', '속대왓', '쑥대밭', '속대왓', '쑥대밭'],
#  ['사우짝', '상앗대', '사우짝', '상앗대', '사우짝', '상앗대'],
#  ['사울대', '상앗대', '사울대', '상앗대', '사울대', '상앗대'],
#  ['사위', '새우', '사위', '새우', '사위', '새우'],
#  ['사을', '사흘', '사을', '사흘', '사을', '사흘'],
#  ['사을날', '사흗날', '사을날', '사흗날', '사을날', '사흗날'],
#  ['사을대', '상앗대', '사을대', '상앗대', '사을대', '상앗대'],
#  ['사을메', '사흘메', '사을메', '사흘메', '사을메', '사흘메'],
#  ['사쥐', '사주', '사쥐', '사주', '사쥐', '사주'],
#  ['숙피쟁이', '무두장이', '숙피쟁이', '무두장이', '숙피쟁이', '무두장이'],
#  ['사철낭', '사철나무', '사철낭', '사철나무', '사철낭', '사철나무'],
#  ['사춘', '사촌', '사춘', '사촌', '사춘', '사촌'],
#  ['산데미', '산더미', '산데미', '산더미', '산데미', '산더미'],
#  ['사탕가르', '설탕', '사탕가르', '설탕', '사탕가르', '설탕'],
#  ['사탕가를', '설탕', '사탕가를', '설탕', '사탕가를', '설탕'],
#  ['테견', '퇴김', '테견', '퇴김', '테견', '퇴김'],
#  ['사탕대죽', '사탕수수', '사탕대죽', '사탕수수', '사탕대죽', '사탕수수'],
#  ['사토리', '사투리', '사토리', '사투리', '사토리', '사투리'],
#  ['사퉤', '사퇴', '사퉤', '사퇴', '사퉤', '사퇴'],
#  ['사팔뚜기', '사팔뜨기', '사팔뚜기', '사팔뜨기', '사팔뚜기', '사팔뜨기'],
#  ['터우리', '뗏목', '터우리', '뗏목', '터우리', '뗏목'],
#  ['터우베', '뗏목', '터우베', '뗏목', '터우베', '뗏목'],
#  ['사훼', '사회', '사훼', '사회', '사훼', '사회'],
#  ['사흘날', '사흗날', '사흘날', '사흗날', '사흘날', '사흗날'],
#  ['터위', '떼', '터위', '떼', '터위', '떼'],
#  ['삭각', '삿갓', '삭각', '삿갓', '삭각', '삿갓'],
#  ['터윗낭', '뗏목', '터윗낭', '뗏목', '터윗낭', '뗏목'],
#  ['삭달남', '삭정이', '삭달남', '삭정이', '삭달남', '삭정이'],
#  ['터이베', '뗏목', '터이베', '뗏목', '터이베', '뗏목'],
#  ['삭일', '삯일', '삭일', '삯일', '삭일', '삯일'],
#  ['산', '뫼', '산', '뫼', '산', '뫼'],
#  ['산기벵', '오줌소태', '산기벵', '오줌소태', '산기벵', '오줌소태'],
#  ['파쉐', '바소', '파쉐', '바소', '파쉐', '바소'],
#  ['산강', '서리', '산강', '서리', '산강', '서리'],
#  ['파쉬', '바소', '파쉬', '바소', '파쉬', '바소'],
#  ['산고고리', '산꼭대기', '산고고리', '산꼭대기', '산고고리', '산꼭대기'],
#  ['산굼부리', '화구', '산굼부리', '화구', '산굼부리', '화구'],
#  ['산기장', '오줌소태', '산기장', '오줌소태', '산기장', '오줌소태'],
#  ['산깃벵', '오줌소태', '산깃벵', '오줌소태', '산깃벵', '오줌소태'],
#  ['산꼬지', '산꼭대기', '산꼬지', '산꼭대기', '산꼬지', '산꼭대기'],
#  ['산마르테기', '산마루터기', '산마르테기', '산마루터기', '산마르테기', '산마루터기'],
#  ['가마귀지장', '솔새', '가마귀지장', '솔새', '가마귀지장', '솔새'],
#  ['산달뤼', '진달래', '산달뤼', '진달래', '산달뤼', '진달래'],
#  ['산담', '사성', '산담', '사성', '산담', '사성'],
#  ['산뎅이', '산더미', '산뎅이', '산더미', '산뎅이', '산더미'],
#  ['산도세기', '산돼지', '산도세기', '산돼지', '산도세기', '산돼지'],
#  ['산돌', '산돼지', '산돌', '산돼지', '산돌', '산돼지'],
#  ['산돗', '산돼지', '산돗', '산돼지', '산돗', '산돼지'],
#  ['산돝', '산돼지', '산돝', '산돼지', '산돝', '산돼지'],
#  ['산돼아지', '산돼지', '산돼아지', '산돼지', '산돼아지', '산돼지'],
#  ['산뒈야지', '산돼지', '산뒈야지', '산돼지', '산뒈야지', '산돼지'],
#  ['산뒤', '산도', '산뒤', '산도', '산뒤', '산도'],
#  ['산뒤말축', '방아깨비', '산뒤말축', '방아깨비', '산뒤말축', '방아깨비'],
#  ['산뒤사촌', '방동사니', '산뒤사촌', '방동사니', '산뒤사촌', '방동사니'],
#  ['산뒤삼춘', '방동사니', '산뒤삼춘', '방동사니', '산뒤삼춘', '방동사니'],
#  ['산뒤쌀', '밭벼쌀', '산뒤쌀', '밭벼쌀', '산뒤쌀', '밭벼쌀'],
#  ['산뒤왓', '밭벼밭', '산뒤왓', '밭벼밭', '산뒤왓', '밭벼밭'],
#  ['산뒤제와니', '방동사니', '산뒤제와니', '방동사니', '산뒤제와니', '방동사니'],
#  ['산등성말이리', '산등성마루', '산등성말이리', '산등성마루', '산등성말이리', '산등성마루'],
#  ['산디', '산도', '산디', '산도', '산디', '산도'],
#  ['산지레', '선키', '산지레', '선키', '산지레', '선키'],
#  ['산마르', '산마루', '산마르', '산마루', '산마르', '산마루'],
#  ['산마르겡이', '산마루터기', '산마르겡이', '산마루터기', '산마르겡이', '산마루터기'],
#  ['산지물', '산수', '산지물', '산수', '산지물', '산수'],
#  ['산마를', '산마루', '산마를', '산마루', '산마를', '산마루'],
#  ['산말렝이', '산마루', '산말렝이', '산마루', '산말렝이', '산마루'],
#  ['산말로', '산마루', '산말로', '산마루', '산말로', '산마루'],
#  ['산말이리', '산마루', '산말이리', '산마루', '산말이리', '산마루'],
#  ['산멀뤼', '산머루', '산멀뤼', '산머루', '산멀뤼', '산머루'],
#  ['산멀리', '머루', '산멀리', '머루', '산멀리', '머루'],
#  ['산메자낭', '산매자나무', '산메자낭', '산매자나무', '산메자낭', '산매자나무'],
#  ['산멕', '모이주머니', '산멕', '모이주머니', '산멕', '모이주머니'],
#  ['산목솜', '산목숨', '산목솜', '산목숨', '산목솜', '산목숨'],
#  ['태', '때', '태', '때', '태', '때'],
#  ['산물', '귤', '산물', '귤', '산물', '귤'],
#  ['산발', '산기슭', '산발', '산기슭', '산발', '산기슭'],
#  ['산보', '소풍', '산보', '소풍', '산보', '소풍'],
#  ['태뒤', '태두', '태뒤', '태두', '태뒤', '태두'],
#  ['산봉데기', '산꼭대기', '산봉데기', '산꼭대기', '산봉데기', '산꼭대기'],
#  ['산봉오지', '산봉우리', '산봉오지', '산봉우리', '산봉오지', '산봉우리'],
#  ['산부새', '산바람', '산부새', '산바람', '산부새', '산바람'],
#  ['산비돌기', '산비둘기', '산비돌기', '산비둘기', '산비돌기', '산비둘기'],
#  ['산뽕낭', '산뽕나무', '산뽕낭', '산뽕나무', '산뽕낭', '산뽕나무'],
#  ['산송', '소나무', '산송', '소나무', '산송', '소나무'],
#  ['산역사', '산역', '산역사', '산역', '산역사', '산역'],
#  ['산승', '더덕', '산승', '더덕', '산승', '더덕'],
#  ['산역서', '산역', '산역서', '산역', '산역서', '산역'],
#  ['산역시', '산역', '산역시', '산역', '산역시', '산역'],
#  ['산자리', '묏자리', '산자리', '묏자리', '산자리', '묏자리'],
#  ['산쟁이', '사냥꾼', '산쟁이', '사냥꾼', '산쟁이', '사냥꾼'],
#  ['산전발라기', '방아깨비', '산전발라기', '방아깨비', '산전발라기', '방아깨비'],
#  ['산전발락', '방아깨비', '산전발락', '방아깨비', '산전발락', '방아깨비'],
#  ['산전볼락', '방아깨비', '산전볼락', '방아깨비', '산전볼락', '방아깨비'],
#  ['탑', '조각', '탑', '조각', '탑', '조각'],
#  ['탕구', '두레우물', '탕구', '두레우물', '탕구', '두레우물'],
#  ['탕근', '탕건', '탕근', '탕건', '탕근', '탕건'],
#  ['탕수', '잡채', '탕수', '잡채', '탕수', '잡채'],
#  ['탕쥐', '탱자', '탕쥐', '탱자', '탕쥐', '탱자'],
#  ['탕쥐낭', '탱자나무', '탕쥐낭', '탱자나무', '탕쥐낭', '탱자나무'],
#  ['탕지', '탱자', '탕지', '탱자', '탕지', '탱자'],
#  ['탕지낭', '탱자나무', '탕지낭', '탱자나무', '탕지낭', '탱자나무'],
#  ['태경', '퇴김', '태경', '퇴김', '태경', '퇴김'],
#  ['태상배기', '대성마', '태상배기', '대성마', '태상배기', '대성마'],
#  ['태양', '차양', '태양', '차양', '태양', '차양'],
#  ['태왈', '설피', '태왈', '설피', '태왈', '설피'],
#  ['태작', '타작', '태작', '타작', '태작', '타작'],
#  ['판수', '바소', '판수', '바소', '판수', '바소'],
#  ['탱기', '탱자', '탱기', '탱자', '탱기', '탱자'],
#  ['탱기낭', '탱자나무', '탱기낭', '탱자나무', '탱기낭', '탱자나무'],
#  ['터는병', '학질', '터는병', '학질', '터는병', '학질'],
#  ['터는빙', '말라리아', '터는빙', '말라리아', '터는빙', '말라리아'],
#  ['터러귓벵', '학질', '터러귓벵', '학질', '터러귓벵', '학질'],
#  ['터러귓병', '학질', '터러귓병', '학질', '터러귓병', '학질'],
#  ['터러기', '학질', '터러기', '학질', '터러기', '학질'],
#  ['판쉐', '바소', '판쉐', '바소', '판쉐', '바소'],
#  ['판쉬', '바소', '판쉬', '바소', '판쉬', '바소'],
#  ['터배', '떼배', '터배', '떼배', '터배', '떼배'],
#  ['판쒜', '바소', '판쒜', '바소', '판쒜', '바소'],
#  ['터투아리', '말더듬이', '터투아리', '말더듬이', '터투아리', '말더듬이'],
#  ['터투와리', '말더듬이', '터투와리', '말더듬이', '터투와리', '말더듬이'],
#  ['턱가리', '턱살', '턱가리', '턱살', '턱가리', '턱살'],
#  ['턱고마지', '턱', '턱고마지', '턱', '턱고마지', '턱'],
#  ['턱받에', '턱받이', '턱받에', '턱받이', '턱받에', '턱받이'],
#  ['턱사리', '턱주가리', '턱사리', '턱주가리', '턱사리', '턱주가리'],
#  ['턱시염', '턱수염', '턱시염', '턱수염', '턱시염', '턱수염'],
#  ['턱쉬염', '턱수염', '턱쉬염', '턱수염', '턱쉬염', '턱수염'],
#  ['턱싯은것', '턱찌꺼기', '턱싯은것', '턱찌꺼기', '턱싯은것', '턱찌꺼기'],
#  ['털북세기', '털보', '털북세기', '털보', '털북세기', '털보'],
#  ['털깅이', '털게', '털깅이', '털게', '털깅이', '털게'],
#  ['털러귀', '말라리아', '털러귀', '말라리아', '털러귀', '말라리아'],
#  ['털멩이', '털메기', '털멩이', '털메기', '털멩이', '털메기'],
#  ['털벌립', '털벙거지', '털벌립', '털벙거지', '털벌립', '털벙거지'],
#  ['털벙것', '털벙거지', '털벙것', '털벙거지', '털벙것', '털벙거지'],
#  ['털부리', '텁석부리', '털부리', '텁석부리', '털부리', '텁석부리'],
#  ['털북새기', '털벙거지', '털북새기', '털벙거지', '털북새기', '털벙거지'],
#  ['털세', '텃세', '털세', '텃세', '털세', '텃세'],
#  ['털채', '먼지떨이', '털채', '먼지떨이', '털채', '먼지떨이'],
#  ['텃삭', '텃세', '텃삭', '텃세', '텃삭', '텃세'],
#  ['텅에', '둥우리', '텅에', '둥우리', '텅에', '둥우리'],
#  ['테', '떼', '테', '떼', '테', '떼'],
#  ['테거리', '떼거리', '테거리', '떼거리', '테거리', '떼거리'],
#  ['테밧', '잔디밭', '테밧', '잔디밭', '테밧', '잔디밭'],
#  ['테배', '떼배', '테배', '떼배', '테배', '떼배'],
#  ['테악', '테왁', '테악', '테왁', '테악', '테왁'],
#  ['테역', '잔디', '테역', '잔디', '테역', '잔디'],
#  ['테역단풍', '금잔디', '테역단풍', '금잔디', '테역단풍', '금잔디'],
#  ['테역밧', '잔디밭', '테역밧', '잔디밭', '테역밧', '잔디밭'],
#  ['테역벙뎅이', '뗏장', '테역벙뎅이', '뗏장', '테역벙뎅이', '뗏장'],
#  ['테우', '떼', '테우', '떼', '테우', '떼'],
#  ['테우리', '뗏목', '테우리', '뗏목', '테우리', '뗏목'],
#  ['테위', '떼', '테위', '떼', '테위', '떼'],
#  ['테윗낭', '뗏목', '테윗낭', '뗏목', '테윗낭', '뗏목'],
#  ['텟낭', '뗏목', '텟낭', '뗏목', '텟낭', '뗏목'],
#  ['텟도독', '떼도둑', '텟도독', '떼도둑', '텟도독', '떼도둑'],
#  ['텟벙뎅이', '뗏장', '텟벙뎅이', '뗏장', '텟벙뎅이', '뗏장'],
#  ['텟벙에', '뗏장', '텟벙에', '뗏장', '텟벙에', '뗏장'],
#  ['텡자낭', '탱자나무', '텡자낭', '탱자나무', '텡자낭', '탱자나무'],
#  ['텡지여름', '탱자', '텡지여름', '탱자', '텡지여름', '탱자'],
#  ['토갱이', '밭뙈기', '토갱이', '밭뙈기', '토갱이', '밭뙈기'],
#  ['토께띠', '토끼띠', '토께띠', '토끼띠', '토께띠', '토끼띠'],
#  ['토꼐해', '토끼해', '토꼐해', '토끼해', '토꼐해', '토끼해'],
#  ['토다진사름', '갈가위', '토다진사름', '갈가위', '토다진사름', '갈가위'],
#  ['토란', '도라지', '토란', '도라지', '토란', '도라지'],
#  ['토러기', '학질', '토러기', '학질', '토러기', '학질'],
#  ['토막낭', '토막나무', '토막낭', '토막나무', '토막낭', '토막나무'],
#  ['토불미', '손풀무', '토불미', '손풀무', '토불미', '손풀무'],
#  ['자근테', '이야기꾼', '자근테', '이야기꾼', '자근테', '이야기꾼'],
#  ['자글', '자귀풀', '자글', '자귀풀', '자글', '자귀풀'],
#  ['톨레', '자새', '톨레', '자새', '톨레', '자새'],
#  ['톱가로', '톱밥', '톱가로', '톱밥', '톱가로', '톱밥'],
#  ['톱가르', '톱밥', '톱가르', '톱밥', '톱가르', '톱밥'],
#  ['톱가를', '톱밥', '톱가를', '톱밥', '톱가를', '톱밥'],
#  ['톱갈리', '톱밥', '톱갈리', '톱밥', '톱갈리', '톱밥'],
#  ['톳헤치', '토끼띠', '톳헤치', '토끼띠', '톳헤치', '토끼띠'],
#  ['통', '소', '통', '소', '통', '소'],
#  ['통대', '설대', '통대', '설대', '통대', '설대'],
#  ['통대왈', '대접', '통대왈', '대접', '통대왈', '대접'],
#  ['통머리', '대통머리', '통머리', '대통머리', '통머리', '대통머리'],
#  ['통모개', '대통목', '통모개', '대통목', '통모개', '대통목'],
#  ['통모개기', '대통목', '통모개기', '대통목', '통모개기', '대통목'],
#  ['통부체', '돌부처', '통부체', '돌부처', '통부체', '돌부처'],
#  ['통사발', '사발', '통사발', '사발', '통사발', '사발'],
#  ['통삼', '배쌈', '통삼', '배쌈', '통삼', '배쌈'],
#  ['통새', '뒷간', '통새', '뒷간', '통새', '뒷간'],
#  ['통쉐', '자물쇠', '통쉐', '자물쇠', '통쉐', '자물쇠'],
#  ['통얼레', '얼레', '통얼레', '얼레', '통얼레', '얼레'],
#  ['통잔', '담배통', '통잔', '담배통', '통잔', '담배통'],
#  ['통진', '댓진', '통진', '댓진', '통진', '댓진'],
#  ['통치메', '통치마', '통치메', '통치마', '통치메', '통치마'],
#  ['장희', '큰비', '장희', '큰비', '장희', '큰비'],
#  ['자글락쉬', '이야기꾼', '자글락쉬', '이야기꾼', '자글락쉬', '이야기꾼'],
#  ['투바리', '뚝배기', '투바리', '뚝배기', '투바리', '뚝배기'],
#  ['투죽', '투족', '투죽', '투족', '투죽', '투족'],
#  ['퉤비', '퇴비', '퉤비', '퇴비', '퉤비', '퇴비'],
#  ['퉁쒜', '자물쇠', '퉁쒜', '자물쇠', '퉁쒜', '자물쇠'],
#  ['개모믈', '며느리배꼽', '개모믈', '며느리배꼽', '개모믈', '며느리배꼽'],
#  ['퉤', '토', '퉤', '토', '퉤', '토'],
#  ['퉤기', '외', '퉤기', '외', '퉤기', '외'],
#  ['퉤꼐', '토끼', '퉤꼐', '토끼', '퉤꼐', '토끼'],
#  ['퉤끼', '토끼', '퉤끼', '토끼', '퉤끼', '토끼'],
#  ['퉤역', '잔디', '퉤역', '잔디', '퉤역', '잔디'],
#  ['퉷도리', '툇도리', '퉷도리', '툇도리', '퉷도리', '툇도리'],
#  ['퉷마리', '툇마루', '퉷마리', '툇마루', '퉷마리', '툇마루'],
#  ['퉷지둥', '툇기둥', '퉷지둥', '툇기둥', '퉷지둥', '툇기둥'],
#  ['퉷짓', '툇기둥', '퉷짓', '툇기둥', '퉷짓', '툇기둥'],
#  ['튀자리', '초석', '튀자리', '초석', '튀자리', '초석'],
#  ['트멍', '틈', '트멍', '틈', '트멍', '틈'],
#  ['트멍이', '틈', '트멍이', '틈', '트멍이', '틈'],
#  ['튼봉사', '청맹과니', '튼봉사', '청맹과니', '튼봉사', '청맹과니'],
#  ['튼봉사', '눈뜬장님', '튼봉사', '눈뜬장님', '튼봉사', '눈뜬장님'],
#  ['튼쉐경', '청맹과니', '튼쉐경', '청맹과니', '튼쉐경', '청맹과니'],
#  ['튼장님', '눈뜬장님', '튼장님', '눈뜬장님', '튼장님', '눈뜬장님'],
#  ['틀국쉬', '틀국수', '틀국쉬', '틀국수', '틀국쉬', '틀국수'],
#  ['틈', '뜸', '틈', '뜸', '틈', '뜸'],
#  ['티', '가시', '티', '가시', '티', '가시'],
#  ['팃물', '뜨물', '팃물', '뜨물', '팃물', '뜨물'],
#  ['파궤', '파괴', '파궤', '파괴', '파궤', '파괴'],
#  ['파기', '파괴', '파기', '파괴', '파기', '파괴'],
#  ['파니', '뙈기', '파니', '뙈기', '파니', '뙈기'],
#  ['파니밭', '뙈기밭', '파니밭', '뙈기밭', '파니밭', '뙈기밭'],
#  ['잔소낭밭', '잔솔밭', '잔소낭밭', '잔솔밭', '잔소낭밭', '잔솔밭'],
#  ['파레', '파래', '파레', '파래', '파레', '파래'],
#  ['파리도독', '파리잡이거미', '파리도독', '파리잡이거미', '파리도독', '파리잡이거미'],
#  ['파리똥', '주근깨', '파리똥', '주근깨', '파리똥', '주근깨'],
#  ['파리목젱이', '파리잡이거미', '파리목젱이', '파리잡이거미', '파리목젱이', '파리잡이거미'],
#  ['파리찜', '주근깨', '파리찜', '주근깨', '파리찜', '주근깨'],
#  ['파리춤', '주근깨', '파리춤', '주근깨', '파리춤', '주근깨'],
#  ['파리침', '주근깨', '파리침', '주근깨', '파리침', '주근깨'],
#  ['파종저', '팟종', '파종저', '팟종', '파종저', '팟종'],
#  ['팍', '팥', '팍', '팥', '팍', '팥'],
#  ['판고집다리', '고집쟁이', '판고집다리', '고집쟁이', '판고집다리', '고집쟁이'],
#  ['팔', '삼', '팔', '삼', '팔', '삼'],
#  ['팔각낭', '붓순나무', '팔각낭', '붓순나무', '팔각낭', '붓순나무'],
#  ['팔고비', '팔꿈치', '팔고비', '팔꿈치', '팔고비', '팔꿈치'],
#  ['팔기', '포기', '팔기', '포기', '팔기', '포기'],
#  ['팔곱지', '팔꿈치', '팔곱지', '팔꿈치', '팔곱지', '팔꿈치'],
#  ['팔굽지', '팔꿈치', '팔굽지', '팔꿈치', '팔굽지', '팔꿈치'],
#  ['팔똑', '팔뚝', '팔똑', '팔뚝', '팔똑', '팔뚝'],
#  ['팔닷', '팔때기', '팔닷', '팔때기', '팔닷', '팔때기'],
#  ['팔둑거리', '팔찌', '팔둑거리', '팔찌', '팔둑거리', '팔찌'],
#  ['팔똥', '팔짱', '팔똥', '팔짱', '팔똥', '팔짱'],
#  ['팔따시', '팔때기', '팔따시', '팔때기', '팔따시', '팔때기'],
#  ['팔씨롬', '팔씨름', '팔씨롬', '팔씨름', '팔씨롬', '팔씨름'],
#  ['팔쥐거리', '팔찌', '팔쥐거리', '팔찌', '팔쥐거리', '팔찌'],
#  ['팔짤레기', '곰배팔이', '팔짤레기', '곰배팔이', '팔짤레기', '곰배팔이'],
#  ['팔찜', '팔짱', '팔찜', '팔짱', '팔찜', '팔짱'],
#  ['팔풍이', '허풍선이', '팔풍이', '허풍선이', '팔풍이', '허풍선이'],
#  ['팟감', '고욤', '팟감', '고욤', '팟감', '고욤'],
#  ['팟감낭', '고욤나무', '팟감낭', '고욤나무', '팟감낭', '고욤나무'],
#  ['팟버렝이', '팥망아지', '팟버렝이', '팥망아지', '팟버렝이', '팥망아지'],
#  ['팟볼레', '보리수', '팟볼레', '보리수', '팟볼레', '보리수'],
#  ['팟빈뎅이', '마른버짐', '팟빈뎅이', '마른버짐', '팟빈뎅이', '마른버짐'],
#  ['팟쉬', '팥소', '팟쉬', '팥소', '팟쉬', '팥소'],
#  ['팟잎', '팥잎', '팟잎', '팥잎', '팟잎', '팥잎'],
#  ['팟자리', '털매미', '팟자리', '털매미', '팟자리', '털매미'],
#  ['팟재', '털매미', '팟재', '털매미', '팟재', '털매미'],
#  ['팟재열', '털매미', '팟재열', '털매미', '팟재열', '털매미'],
#  ['팟재일', '털매미', '팟재일', '털매미', '팟재일', '털매미'],
#  ['팟재일', '애매미', '팟재일', '애매미', '팟재일', '애매미'],
#  ['팟잴', '털매미', '팟잴', '털매미', '팟잴', '털매미'],
#  ['팟죽', '팥죽', '팟죽', '팥죽', '팟죽', '팥죽'],
#  ['팟터는벵', '말라리아', '팟터는벵', '말라리아', '팟터는벵', '말라리아'],
#  ['팟터는병', '학질', '팟터는병', '학질', '팟터는병', '학질'],
#  ['팟터는빙', '말라리아', '팟터는빙', '말라리아', '팟터는빙', '말라리아'],
#  ['팟푸께', '땅꽈리', '팟푸께', '땅꽈리', '팟푸께', '땅꽈리'],
#  ['팡', '자리', '팡', '자리', '팡', '자리'],
#  ['패마농', '파', '패마농', '파', '패마농', '파'],
#  ['팻도독', '떼도둑', '팻도독', '떼도둑', '팻도독', '떼도둑'],
#  ['퍼때기', '보자기', '퍼때기', '보자기', '퍼때기', '보자기'],
#  ['펀개', '번개', '펀개', '번개', '펀개', '번개'],
#  ['펀께', '번개', '펀께', '번개', '펀께', '번개'],
#  ['펄눙멸', '눈퉁멸', '펄눙멸', '눈퉁멸', '펄눙멸', '눈퉁멸'],
#  ['펄바다', '개펄', '펄바다', '개펄', '펄바다', '개펄'],
#  ['페', '표', '페', '표', '페', '표'],
#  ['페마농', '파', '페마농', '파', '페마농', '파'],
#  ['페렝이', '밀짚모자', '페렝이', '밀짚모자', '페렝이', '밀짚모자'],
#  ['페리', '패랭이', '페리', '패랭이', '페리', '패랭이'],
#  ['페적', '표적', '페적', '표적', '페적', '표적'],
#  ['페지', '표지', '페지', '표지', '페지', '표지'],
#  ['페채기', '질경이', '페채기', '질경이', '페채기', '질경이'],
#  ['펜씨롬', '편씨름', '펜씨롬', '편씨름', '펜씨롬', '편씨름'],
#  ['펜씨름', '편씨름', '펜씨름', '편씨름', '펜씨름', '편씨름'],
#  ['펜안', '편안', '펜안', '편안', '펜안', '편안'],
#  ['펜지', '편지', '펜지', '편지', '펜지', '편지'],
#  ['펜틀', '편틀', '펜틀', '편틀', '펜틀', '편틀'],
#  ['펭', '병', '펭', '병', '펭', '병'],
#  ['펭겟낭', '탕개목', '펭겟낭', '탕개목', '펭겟낭', '탕개목'],
#  ['펭고대', '평고대', '펭고대', '평고대', '펭고대', '평고대'],
#  ['펭고디', '평고대', '펭고디', '평고대', '펭고디', '평고대'],
#  ['펭기', '팽이', '펭기', '팽이', '펭기', '팽이'],
#  ['펭년', '평년', '펭년', '평년', '펭년', '평년'],
#  ['펭도로기', '팽이', '펭도로기', '팽이', '펭도로기', '팽이'],
#  ['펭승', '평생', '펭승', '평생', '펭승', '평생'],
#  ['펭반', '평반', '펭반', '평반', '펭반', '평반'],
#  ['펭장', '평장', '펭장', '평장', '펭장', '평장'],
#  ['펭풍', '병풍', '펭풍', '병풍', '펭풍', '병풍'],
#  ['포알귀클', '아랫중방', '포알귀클', '아랫중방', '포알귀클', '아랫중방'],
#  ['포알귀틀', '아랫중방', '포알귀틀', '아랫중방', '포알귀틀', '아랫중방'],
#  ['포', '너울', '포', '너울', '포', '너울'],
#  ['포대기', '보자기', '포대기', '보자기', '포대기', '보자기'],
#  ['포대깃짐', '봇짐', '포대깃짐', '봇짐', '포대깃짐', '봇짐'],
#  ['포따리', '보따리', '포따리', '보따리', '포따리', '보따리'],
#  ['포리똥', '주근깨', '포리똥', '주근깨', '포리똥', '주근깨'],
#  ['포신', '앙갚음', '포신', '앙갚음', '포신', '앙갚음'],
#  ['포리침', '주근깨', '포리침', '주근깨', '포리침', '주근깨'],
#  ['포마시', '앙갚음', '포마시', '앙갚음', '포마시', '앙갚음'],
#  ['포시', '앙갚음', '포시', '앙갚음', '포시', '앙갚음'],
#  ['포제기', '보자기', '포제기', '보자기', '포제기', '보자기'],
#  ['폭', '팽', '폭', '팽', '폭', '팽'],
#  ['폭낭', '팽나무', '폭낭', '팽나무', '폭낭', '팽나무'],
#  ['폭낭구', '팽나무', '폭낭구', '팽나무', '폭낭구', '팽나무'],
#  ['폭도둑놈', '살쐐기', '폭도둑놈', '살쐐기', '폭도둑놈', '살쐐기'],
#  ['폰사둔', '겹사돈', '폰사둔', '겹사돈', '폰사둔', '겹사돈'],
#  ['자우락', '천일사초', '자우락', '천일사초', '자우락', '천일사초'],
#  ['폴고비', '팔꿈치', '폴고비', '팔꿈치', '폴고비', '팔꿈치'],
#  ['폴굽지', '팔꿈치', '폴굽지', '팔꿈치', '폴굽지', '팔꿈치'],
#  ['폴따시', '팔때기', '폴따시', '팔때기', '폴따시', '팔때기'],
#  ['폴둑거리', '팔찌', '폴둑거리', '팔찌', '폴둑거리', '팔찌'],
#  ['폴찜', '팔짱', '폴찜', '팔짱', '폴찜', '팔짱'],
#  ['폴쥐거리', '팔찌', '폴쥐거리', '팔찌', '폴쥐거리', '팔찌'],
#  ['폴쫄레기', '곰배팔이', '폴쫄레기', '곰배팔이', '폴쫄레기', '곰배팔이'],
#  ['폿버렝이', '팥망아지', '폿버렝이', '팥망아지', '폿버렝이', '팥망아지'],
#  ['폿볼레', '보리수', '폿볼레', '보리수', '폿볼레', '보리수'],
#  ['폿지방', '아랫중방', '폿지방', '아랫중방', '폿지방', '아랫중방'],
#  ['폿짐', '봇짐', '폿짐', '봇짐', '폿짐', '봇짐'],
#  ['폿짐장사', '봇짐장사', '폿짐장사', '봇짐장사', '폿짐장사', '봇짐장사'],
#  ['폿짐장시', '봇짐장사', '폿짐장시', '봇짐장사', '폿짐장시', '봇짐장사'],
#  ['폿터는벵', '학질', '폿터는벵', '학질', '폿터는벵', '학질'],
#  ['푸게기', '땅꽈리', '푸게기', '땅꽈리', '푸게기', '땅꽈리'],
#  ['푸기', '포기', '푸기', '포기', '푸기', '포기'],
#  ['푸께', '텡쇠', '푸께', '텡쇠', '푸께', '텡쇠'],
#  ['푸께기', '땅꽈리', '푸께기', '땅꽈리', '푸께기', '땅꽈리'],
#  ['푸레죽', '풀떼기', '푸레죽', '풀떼기', '푸레죽', '풀떼기'],
#  ['푸는체', '키', '푸는체', '키', '푸는체', '키'],
#  ['푸다시', '푸닥거리', '푸다시', '푸닥거리', '푸다시', '푸닥거리'],
#  ['푸답', '푸새', '푸답', '푸새', '푸답', '푸새'],
#  ['푸답마깨', '다듬잇방망이', '푸답마깨', '다듬잇방망이', '푸답마깨', '다듬잇방망이'],
#  ['푸대', '부대', '푸대', '부대', '푸대', '부대'],
#  ['푸돋잇마', '봄장마', '푸돋잇마', '봄장마', '푸돋잇마', '봄장마'],
#  ['푸마시', '앙갚음', '푸마시', '앙갚음', '푸마시', '앙갚음'],
#  ['푸섬키', '푸성귀', '푸섬키', '푸성귀', '푸섬키', '푸성귀'],
#  ['푸성거리', '푸성귀', '푸성거리', '푸성귀', '푸성거리', '푸성귀'],
#  ['푸성키', '푸성귀', '푸성키', '푸성귀', '푸성키', '푸성귀'],
#  ['푸솜', '부풀', '푸솜', '부풀', '푸솜', '부풀'],
#  ['푸숨', '부풀', '푸숨', '부풀', '푸숨', '부풀'],
#  ['푸습새', '푸성귀', '푸습새', '푸성귀', '푸습새', '푸성귀'],
#  ['푸심', '부풀', '푸심', '부풀', '푸심', '부풀'],
#  ['푸짜리', '잠자리', '푸짜리', '잠자리', '푸짜리', '잠자리'],
#  ['푸채', '부채', '푸채', '부채', '푸채', '부채'],
#  ['푼채', '부채', '푼채', '부채', '푼채', '부채'],
#  ['푼채질', '부채질', '푼채질', '부채질', '푼채질', '부채질'],
#  ['푼챗살', '부챗살', '푼챗살', '부챗살', '푼챗살', '부챗살'],
#  ['풀고치', '풋고추', '풀고치', '풋고추', '풀고치', '풋고추'],
#  ['푼철귀', '꽈리', '푼철귀', '꽈리', '푼철귀', '꽈리'],
#  ['푼체', '부채', '푼체', '부채', '푼체', '부채'],
#  ['푼체꽝', '견갑골', '푼체꽝', '견갑골', '푼체꽝', '견갑골'],
#  ['푼쳘귀', '꽈리', '푼쳘귀', '꽈리', '푼쳘귀', '꽈리'],
#  ['풀가개비', '청개구리', '풀가개비', '청개구리', '풀가개비', '청개구리'],
#  ['풀가게비', '청개구리', '풀가게비', '청개구리', '풀가게비', '청개구리'],
#  ['풀가레', '풀매', '풀가레', '풀매', '풀가레', '풀매'],
#  ['풀갈개비', '청개구리', '풀갈개비', '청개구리', '풀갈개비', '청개구리'],
#  ['풀갈게비', '청개구리', '풀갈게비', '청개구리', '풀갈게비', '청개구리'],
#  ['풀감', '풋감', '풀감', '풋감', '풀감', '풋감'],
#  ['풀떼죽', '갱죽', '풀떼죽', '갱죽', '풀떼죽', '갱죽'],
#  ['풀밧', '풀밭', '풀밧', '풀밭', '풀밧', '풀밭'],
#  ['풀솔', '풀비', '풀솔', '풀비', '풀솔', '풀비'],
#  ['풀왓', '풀밭', '풀왓', '풀밭', '풀왓', '풀밭'],
#  ['풀처귀', '땅꽈리', '풀처귀', '땅꽈리', '풀처귀', '땅꽈리'],
#  ['풀철귀', '땅꽈리', '풀철귀', '땅꽈리', '풀철귀', '땅꽈리'],
#  ['풀체기', '땅꽈리', '풀체기', '땅꽈리', '풀체기', '땅꽈리'],
#  ['풀콩생이쿨', '가는잎향유', '풀콩생이쿨', '가는잎향유', '풀콩생이쿨', '가는잎향유'],
#  ['품', '삯', '품', '삯', '품', '삯'],
#  ['품갑', '품값', '품갑', '품값', '품갑', '품값'],
#  ['품질', '까붐질', '품질', '까붐질', '품질', '까붐질'],
#  ['풋', '팥', '풋', '팥', '풋', '팥'],
#  ['풍개', '키', '풍개', '키', '풍개', '키'],
#  ['풍갱이', '키', '풍갱이', '키', '풍갱이', '키'],
#  ['풍뎅이', '쭉정이', '풍뎅이', '쭉정이', '풍뎅이', '쭉정이'],
#  ['풍둥이', '풍뎅이', '풍둥이', '풍뎅이', '풍둥이', '풍뎅이'],
#  ['풍례', '풍류', '풍례', '풍류', '풍례', '풍류'],
#  ['풍채', '차양', '풍채', '차양', '풍채', '차양'],
#  ['풍채눈', '거적눈', '풍채눈', '거적눈', '풍채눈', '거적눈'],
#  ['풍채바지', '풍차바지', '풍채바지', '풍차바지', '풍채바지', '풍차바지'],
#  ['풍체', '차양', '풍체', '차양', '풍체', '차양'],
#  ['풍체눈', '거적눈', '풍체눈', '거적눈', '풍체눈', '거적눈'],
#  ['피만자', '피마자', '피만자', '피마자', '피만자', '피마자'],
#  ['피만주', '피마자', '피만주', '피마자', '피만주', '피마자'],
#  ['피만쥐', '피마자', '피만쥐', '피마자', '피만쥐', '피마자'],
#  ['피만지', '피마자', '피만지', '피마자', '피만지', '피마자'],
#  ['피파', '비파', '피파', '비파', '피파', '비파'],
#  ['피풍낭', '사스래나무', '피풍낭', '사스래나무', '피풍낭', '사스래나무'],
#  ['피얄', '귀얄', '피얄', '귀얄', '피얄', '귀얄'],
#  ['피쟁이', '백장', '피쟁이', '백장', '피쟁이', '백장'],
#  ['피창', '순대', '피창', '순대', '피창', '순대'],
#  ['피청', '무쇠', '피청', '무쇠', '피청', '무쇠'],
#  ['핏내', '피비린내', '핏내', '피비린내', '핏내', '피비린내'],
#  ['하기새', '두루미', '하기새', '두루미', '하기새', '두루미'],
#  ['하각', '성냥', '하각', '성냥', '하각', '성냥'],
#  ['하간듸', '여기저기', '하간듸', '여기저기', '하간듸', '여기저기'],
#  ['하계량', '제량', '하계량', '제량', '하계량', '제량'],
#  ['하꼼', '조금', '하꼼', '조금', '하꼼', '조금'],
#  ['하깡이', '재채기', '하깡이', '재채기', '하깡이', '재채기'],
#  ['하깽이', '재채기', '하깽이', '재채기', '하깽이', '재채기'],
#  ['하꼬만', '조금', '하꼬만', '조금', '하꼬만', '조금'],
#  ['하늘쉐', '투구풍뎅이', '하늘쉐', '투구풍뎅이', '하늘쉐', '투구풍뎅이'],
#  ['하늘강생이', '땅강아지', '하늘강생이', '땅강아지', '하늘강생이', '땅강아지'],
#  ['하늘생이', '종다리', '하늘생이', '종다리', '하늘생이', '종다리'],
#  ['하늘레기', '하눌타리', '하늘레기', '하눌타리', '하늘레기', '하눌타리'],
#  ['하막', '무당개구리', '하막', '무당개구리', '하막', '무당개구리'],
#  ['하늘에기', '하눌타리', '하늘에기', '하눌타리', '하늘에기', '하눌타리'],
#  ['하늘웨기', '하눌타리', '하늘웨기', '하눌타리', '하늘웨기', '하눌타리'],
#  ['하늘푸께', '땅꽈리', '하늘푸께', '땅꽈리', '하늘푸께', '땅꽈리'],
#  ['하늬보롬', '하늬바람', '하늬보롬', '하늬바람', '하늬보롬', '하늬바람'],
#  ['하늬보름', '하늬바람', '하늬보름', '하늬바람', '하늬보름', '하늬바람'],
#  ['하니바름', '하늬바람', '하니바름', '하늬바람', '하니바름', '하늬바람'],
#  ['하라바님', '할아버님', '하라바님', '할아버님', '하라바님', '할아버님'],
#  ['하루방', '할아버지', '하루방', '할아버지', '하루방', '할아버지'],
#  ['하르바님', '할아버님', '하르바님', '할아버님', '하르바님', '할아버님'],
#  ['하르바지', '할아버지', '하르바지', '할아버지', '하르바지', '할아버지'],
#  ['하르방', '할아버지', '하르방', '할아버지', '하르방', '할아버지'],
#  ['하르비고장', '할미꽃', '하르비고장', '할미꽃', '하르비고장', '할미꽃'],
#  ['하르비꽃', '할미꽃', '하르비꽃', '할미꽃', '하르비꽃', '할미꽃'],
#  ['하르살이', '하루살이', '하르살이', '하루살이', '하르살이', '하루살이'],
#  ['하를', '하루', '하를', '하루', '하를', '하루'],
#  ['하를날', '하루', '하를날', '하루', '하를날', '하루'],
#  ['하를밤', '하룻밤', '하를밤', '하룻밤', '하를밤', '하룻밤'],
#  ['하릇밤', '하룻밤', '하릇밤', '하룻밤', '하릇밤', '하룻밤'],
#  ['하릇저낙', '하룻저녁', '하릇저낙', '하룻저녁', '하릇저낙', '하룻저녁'],
#  ['하릇저녁', '하룻저녁', '하릇저녁', '하룻저녁', '하릇저녁', '하룻저녁'],
#  ['하리방', '할아버지', '하리방', '할아버지', '하리방', '할아버지'],
#  ['하리비', '할아버지', '하리비', '할아버지', '하리비', '할아버지'],
#  ['하리비고장', '할미꽃', '하리비고장', '할미꽃', '하리비고장', '할미꽃'],
#  ['하베', '하복', '하베', '하복', '하베', '하복'],
#  ['하썰', '조금', '하썰', '조금', '하썰', '조금'],
#  ['하옴', '하품', '하옴', '하품', '하옴', '하품'],
#  ['하우염', '하품', '하우염', '하품', '하우염', '하품'],
#  ['하움', '하품', '하움', '하품', '하움', '하품'],
#  ['하위여', '하품', '하위여', '하품', '하위여', '하품'],
#  ['하위염', '하품', '하위염', '하품', '하위염', '하품'],
#  ['하위욤', '하품', '하위욤', '하품', '하위욤', '하품'],
#  ['하위용', '하품', '하위용', '하품', '하위용', '하품'],
#  ['하조기', '하현', '하조기', '하현', '하조기', '하현'],
#  ['학', '흙', '학', '흙', '학', '흙'],
#  ['학게', '학교', '학게', '학교', '학게', '학교'],
#  ['학설', '조금', '학설', '조금', '학설', '조금'],
#  ['학답', '확답', '학답', '확답', '학답', '확답'],
#  ['학동산', '흙더미', '학동산', '흙더미', '학동산', '흙더미'],
#  ['학사니뻬', '무릎뼈', '학사니뻬', '무릎뼈', '학사니뻬', '무릎뼈'],
#  ['학산꽝', '종지뼈', '학산꽝', '종지뼈', '학산꽝', '종지뼈'],
#  ['한가리', '한고비', '한가리', '한고비', '한가리', '한고비'],
#  ['학설뻬', '무릎뼈', '학설뻬', '무릎뼈', '학설뻬', '무릎뼈'],
#  ['학손', '흙손', '학손', '흙손', '학손', '흙손'],
#  ['학슬뻬', '무릎뼈', '학슬뻬', '무릎뼈', '학슬뻬', '무릎뼈'],
#  ['한가운디', '한가운데', '한가운디', '한가운데', '한가운디', '한가운데'],
#  ['한간', '대청', '한간', '대청', '한간', '대청'],
#  ['한갑잔체', '환갑잔치', '한갑잔체', '환갑잔치', '한갑잔체', '환갑잔치'],
#  ['한고리', '한고비', '한고리', '한고비', '한고리', '한고비'],
#  ['한굿', '마마', '한굿', '마마', '한굿', '마마'],
#  ['한긋그르', '마맛자국', '한긋그르', '마맛자국', '한긋그르', '마맛자국'],
#  ['한나', '하나', '한나', '하나', '한나', '하나'],
#  ['한디', '반딧불이', '한디', '반딧불이', '한디', '반딧불이'],
#  ['한반치', '한복판', '한반치', '한복판', '한반치', '한복판'],
#  ['한불', '애벌', '한불', '애벌', '한불', '애벌'],
#  ['한줴기', '조금', '한줴기', '조금', '한줴기', '조금'],
#  ['한소치', '청새치', '한소치', '청새치', '한소치', '청새치'],
#  ['한손', '외손', '한손', '외손', '한손', '외손'],
#  ['한솔치', '청새치', '한솔치', '청새치', '한솔치', '청새치'],
#  ['한쓱', '한속', '한쓱', '한속', '한쓱', '한속'],
#  ['한요름', '한여름', '한요름', '한여름', '한요름', '한여름'],
#  ['한조기', '조금', '한조기', '조금', '한조기', '조금'],
#  ['한집', '주인', '한집', '주인', '한집', '주인'],
#  ['한집그르', '마맛자국', '한집그르', '마맛자국', '한집그르', '마맛자국'],
#  ['한쪼', '한턱', '한쪼', '한턱', '한쪼', '한턱'],
#  ['한착손', '외손', '한착손', '외손', '한착손', '외손'],
#  ['한탈낭', '산딸기', '한탈낭', '산딸기', '한탈낭', '산딸기'],
#  ['한판', '한복판', '한판', '한복판', '한판', '한복판'],
#  ['한펜', '한편', '한펜', '한편', '한펜', '한편'],
#  ['할락산', '한라산', '할락산', '한라산', '할락산', '한라산'],
#  ['할마니', '할머니', '할마니', '할머니', '할마니', '할머니'],
#  ['할망', '할머니', '할망', '할머니', '할망', '할머니'],
#  ['할아바지', '할아버지', '할아바지', '할아버지', '할아바지', '할아버지'],
#  ['함박꼿', '병풀', '함박꼿', '병풀', '함박꼿', '병풀'],
#  ['함박쿨', '병풀', '함박쿨', '병풀', '함박쿨', '병풀'],
#  ['함박풀', '병풀', '함박풀', '병풀', '함박풀', '병풀'],
#  ['함부레기', '거품', '함부레기', '거품', '함부레기', '거품'],
#  ['함불레기', '거품', '함불레기', '거품', '함불레기', '거품'],
#  ['합순낭', '합다리나무', '합순낭', '합다리나무', '합순낭', '합다리나무'],
#  ['합체', '고운체', '합체', '고운체', '합체', '고운체'],
#  ['핫아방', '핫아비', '핫아방', '핫아비', '핫아방', '핫아비'],
#  ['핫어멍', '핫어미', '핫어멍', '핫어미', '핫어멍', '핫어미'],
#  ['핫질', '핫길', '핫질', '핫길', '핫질', '핫길'],
#  ['항', '독', '항', '독', '항', '독'],
#  ['항것', '마마', '항것', '마마', '항것', '마마'],
#  ['항고지', '무지개', '항고지', '무지개', '항고지', '무지개'],
#  ['항긋', '마마', '항긋', '마마', '항긋', '마마'],
#  ['항긋그르', '마맛자국', '항긋그르', '마맛자국', '항긋그르', '마맛자국'],
#  ['항노', '항라', '항노', '항라', '항노', '항라'],
#  ['항뚜껑이', '장독소래기', '항뚜껑이', '장독소래기', '항뚜껑이', '장독소래기'],
#  ['항뚜께', '장독소래기', '항뚜께', '장독소래기', '항뚜께', '장독소래기'],
#  ['항정', '죽대', '항정', '죽대', '항정', '죽대'],
#  ['해갓', '햇무리', '해갓', '햇무리', '해갓', '햇무리'],
#  ['해래비꽃', '딱지꽃', '해래비꽃', '딱지꽃', '해래비꽃', '딱지꽃'],
#  ['해발래기', '해바라기', '해발래기', '해바라기', '해발래기', '해바라기'],
#  ['해벤', '해변', '해벤', '해변', '해벤', '해변'],
#  ['해섬', '해삼', '해섬', '해삼', '해섬', '해삼'],
#  ['해질가리', '해거름', '해질가리', '해거름', '해질가리', '해거름'],
#  ['해질고리', '해거름', '해질고리', '해거름', '해질고리', '해거름'],
#  ['해천', '해전', '해천', '해전', '해천', '해전'],
#  ['해한', '해전', '해한', '해전', '해한', '해전'],
#  ['햇갓', '햇무리', '햇갓', '햇무리', '햇갓', '햇무리'],
#  ['햇빝', '햇볕', '햇빝', '햇볕', '햇빝', '햇볕'],
#  ['햇아이', '어린아이', '햇아이', '어린아이', '햇아이', '어린아이'],
#  ['행견', '행전', '행견', '행전', '행견', '행전'],
#  ['행경', '행전', '행경', '행전', '행경', '행전'],
#  ['행기', '놋그릇', '행기', '놋그릇', '행기', '놋그릇'],
#  ['곤침떡', '쌀떡', '곤침떡', '쌀떡', '곤침떡', '쌀떡'],
#  ['허깃징', '허기증', '허깃징', '허기증', '허깃징', '허기증'],
#  ['허깨', '허깨비', '허깨', '허깨비', '허깨', '허깨비'],
#  ['허껑이', '재채기', '허껑이', '재채기', '허껑이', '재채기'],
#  ['허께', '허깨비', '허께', '허깨비', '허께', '허깨비'],
#  ['허리안개', '부티', '허리안개', '부티', '허리안개', '부티'],
#  ['허리티', '허리띠', '허리티', '허리띠', '허리티', '허리띠'],
#  ['허멩이', '허수아비', '허멩이', '허수아비', '허멩이', '허수아비'],
#  ['자매', '암말', '자매', '암말', '자매', '암말'],
#  ['허우대기', '허우대', '허우대기', '허우대', '허우대기', '허우대'],
#  ['허주', '헛소문', '허주', '헛소문', '허주', '헛소문'],
#  ['허쥐', '헛소문', '허쥐', '헛소문', '허쥐', '헛소문'],
#  ['허풍젱이', '허풍선이', '허풍젱이', '허풍선이', '허풍젱이', '허풍선이'],
#  ['허풍다리', '허풍선이', '허풍다리', '허풍선이', '허풍다리', '허풍선이'],
#  ['허풍쉬', '허풍선이', '허풍쉬', '허풍선이', '허풍쉬', '허풍선이'],
#  ['헉쉬', '용치놀래기', '헉쉬', '용치놀래기', '헉쉬', '용치놀래기'],
#  ['헌물체', '헌것', '헌물체', '헌것', '헌물체', '헌것'],
#  ['헌달매기', '헌털뱅이', '헌달매기', '헌털뱅이', '헌달매기', '헌털뱅이'],
#  ['헌당', '넝마', '헌당', '넝마', '헌당', '넝마'],
#  ['헌털마기', '헌털뱅이', '헌털마기', '헌털뱅이', '헌털마기', '헌털뱅이'],
#  ['헌벅', '헝겊', '헌벅', '헝겊', '헌벅', '헝겊'],
#  ['헌벅눈', '함박눈', '헌벅눈', '함박눈', '헌벅눈', '함박눈'],
#  ['헌털매기', '헌털뱅이', '헌털매기', '헌털뱅이', '헌털매기', '헌털뱅이'],
#  ['헤지기붉음', '저녁노을', '헤지기붉음', '저녁노을', '헤지기붉음', '저녁노을'],
#  ['헌탈마기', '헌털뱅이', '헌탈마기', '헌털뱅이', '헌탈마기', '헌털뱅이'],
#  ['험벅', '헝겊', '험벅', '헝겊', '험벅', '헝겊'],
#  ['험벅눈', '함박눈', '험벅눈', '함박눈', '험벅눈', '함박눈'],
#  ['헙개미', '기울', '헙개미', '기울', '헙개미', '기울'],
#  ['헙데', '기울', '헙데', '기울', '헙데', '기울'],
#  ['헙짐', '헛헛증', '헙짐', '헛헛증', '헙짐', '헛헛증'],
#  ['헙헙징', '헛헛증', '헙헙징', '헛헛증', '헙헙징', '헛헛증'],
#  ['헛갱이', '재채기', '헛갱이', '재채기', '헛갱이', '재채기'],
#  ['헛녁', '헛일', '헛녁', '헛일', '헛녁', '헛일'],
#  ['헛말', '잠꼬대', '헛말', '잠꼬대', '헛말', '잠꼬대'],
#  ['헛짐', '헛헛증', '헛짐', '헛헛증', '헛짐', '헛헛증'],
#  ['헤갓', '햇무리', '헤갓', '햇무리', '헤갓', '햇무리'],
#  ['헤낮', '낮', '헤낮', '낮', '헤낮', '낮'],
#  ['헤답', '회답', '헤답', '회답', '헤답', '회답'],
#  ['헤돋이붉음', '아침노을', '헤돋이붉음', '아침노을', '헤돋이붉음', '아침노을'],
#  ['헤바레기', '먼산바라기', '헤바레기', '먼산바라기', '헤바레기', '먼산바라기'],
#  ['헤왕낮', '한낮', '헤왕낮', '한낮', '헤왕낮', '한낮'],
#  ['헤찬', '해전', '헤찬', '해전', '헤찬', '해전'],
#  ['헤천', '해전', '헤천', '해전', '헤천', '해전'],
#  ['헤치', '띠', '헤치', '띠', '헤치', '띠'],
#  ['흰잉어', '은잉어', '흰잉어', '은잉어', '흰잉어', '은잉어'],
#  ['헤한', '해전', '헤한', '해전', '헤한', '해전'],
#  ['헨실머리', '행실머리', '헨실머리', '행실머리', '헨실머리', '행실머리'],
#  ['헷소리', '잠꼬대', '헷소리', '잠꼬대', '헷소리', '잠꼬대'],
#  ['헷송아기', '애송아지', '헷송아기', '애송아지', '헷송아기', '애송아지'],
#  ['헹경', '행전', '헹경', '행전', '헹경', '행전'],
#  ['헹기', '놋그릇', '헹기', '놋그릇', '헹기', '놋그릇'],
#  ['호강이', '옹당이', '호강이', '옹당이', '호강이', '옹당이'],
#  ['호겡이', '옹당이', '호겡이', '옹당이', '호겡이', '옹당이'],
#  ['호끔', '조금', '호끔', '조금', '호끔', '조금'],
#  ['호달매', '호마', '호달매', '호마', '호달매', '호마'],
#  ['호량', '호령', '호량', '호령', '호량', '호령'],
#  ['호루거리', '하루거리', '호루거리', '하루거리', '호루거리', '하루거리'],
#  ['호명', '마마', '호명', '마마', '호명', '마마'],
#  ['호명정구', '마마', '호명정구', '마마', '호명정구', '마마'],
#  ['호미', '낫', '호미', '낫', '호미', '낫'],
#  ['호미공젱이', '호미걸이', '호미공젱이', '호미걸이', '호미공젱이', '호미걸이'],
#  ['호미열공젱이', '호미걸이', '호미열공젱이', '호미걸이', '호미열공젱이', '호미걸이'],
#  ['호박말랭이', '호박고지', '호박말랭이', '호박고지', '호박말랭이', '호박고지'],
#  ['호사와치', '호사바치', '호사와치', '호사바치', '호사와치', '호사바치'],
#  ['호상옷', '수의', '호상옷', '수의', '호상옷', '수의'],
#  ['호시', '사치', '호시', '사치', '호시', '사치'],
#  ['호어', '홍어', '호어', '홍어', '호어', '홍어'],
#  ['호통', '온통', '호통', '온통', '호통', '온통'],
#  ['혹', '확', '혹', '확', '혹', '확'],
#  ['화빙', '화병', '화빙', '화병', '화빙', '화병'],
#  ['혹밥장난', '소꿉장난', '혹밥장난', '소꿉장난', '혹밥장난', '소꿉장난'],
#  ['작은태', '작다리', '작은태', '작다리', '작은태', '작다리'],
#  ['혼백상지', '혼백상자', '혼백상지', '혼백상자', '혼백상지', '혼백상자'],
#  ['혼삿가음', '혼숫감', '혼삿가음', '혼숫감', '혼삿가음', '혼숫감'],
#  ['혼숫가슴', '혼숫감', '혼숫가슴', '혼숫감', '혼숫가슴', '혼숫감'],
#  ['혼숫가음', '혼숫감', '혼숫가음', '혼숫감', '혼숫가음', '혼숫감'],
#  ['혼적', '혼', '혼적', '혼', '혼적', '혼'],
#  ['혼정', '혼령', '혼정', '혼령', '혼정', '혼령'],
#  ['혼지', '혼동', '혼지', '혼동', '혼지', '혼동'],
#  ['환태', '황태', '환태', '황태', '환태', '황태'],
#  ['홀메기', '손목', '홀메기', '손목', '홀메기', '손목'],
#  ['홀목', '손목', '홀목', '손목', '홀목', '손목'],
#  ['홀아방', '홀아비', '홀아방', '홀아비', '홀아방', '홀아비'],
#  ['활', '활개', '활', '활개', '활', '활개'],
#  ['홀어멍', '홀어미', '홀어멍', '홀어미', '홀어멍', '홀어미'],
#  ['홀채이', '올챙이', '홀채이', '올챙이', '홀채이', '올챙이'],
#  ['홈자갈', '홈', '홈자갈', '홈', '홈자갈', '홈'],
#  ['홀태기', '벼훑이', '홀태기', '벼훑이', '홀태기', '벼훑이'],
#  ['홈챙이', '옹당이', '홈챙이', '옹당이', '홈챙이', '옹당이'],
#  ['홈미레', '개탕', '홈미레', '개탕', '홈미레', '개탕'],
#  ['홈밀이', '홈대패', '홈밀이', '홈대패', '홈밀이', '홈대패'],
#  ['홈박눈', '함박눈', '홈박눈', '함박눈', '홈박눈', '함박눈'],
#  ['황지넹이', '왕지네', '황지넹이', '왕지네', '황지넹이', '왕지네'],
#  ['황고지', '무지개', '황고지', '무지개', '황고지', '무지개'],
#  ['홍실감', '홍시', '홍실감', '홍시', '홍실감', '홍시'],
#  ['홍압', '홍합', '홍압', '홍합', '홍압', '홍합'],
#  ['홍에', '홍어', '홍에', '홍어', '홍에', '홍어'],
#  ['황칠낭', '황칠나무', '황칠낭', '황칠나무', '황칠낭', '황칠나무'],
#  ['홍질대', '홍두깨', '홍질대', '홍두깨', '홍질대', '홍두깨'],
#  ['홍짓대', '홍두깨', '홍짓대', '홍두깨', '홍짓대', '홍두깨'],
#  ['홍탱이', '홈', '홍탱이', '홈', '홍탱이', '홈'],
#  ['홑두루막', '홑두루마기', '홑두루막', '홑두루마기', '홑두루막', '홑두루마기'],
#  ['홑창', '홑청', '홑창', '홑청', '홑창', '홑청'],
#  ['화룡선', '화륜선', '화룡선', '화륜선', '화룡선', '화륜선'],
#  ['화토', '화투', '화토', '화투', '화토', '화투'],
#  ['확독', '돌확', '확독', '돌확', '확독', '돌확'],
#  ['환두상의', '환도상어', '환두상의', '환도상어', '환두상의', '환도상어'],
#  ['환재', '환자', '환재', '환자', '환재', '환자'],
#  ['활지거리', '활갯짓', '활지거리', '활갯짓', '활지거리', '활갯짓'],
#  ['활질', '활갯짓', '활질', '활갯짓', '활질', '활갯짓'],
#  ['홧짐', '홧김', '홧짐', '홧김', '홧짐', '홧김'],
#  ['황', '항아리', '황', '항아리', '황', '항아리'],
#  ['황개오리', '노랑가오리', '황개오리', '노랑가오리', '황개오리', '노랑가오리'],
#  ['황게', '황계', '황게', '황계', '황게', '황계'],
#  ['황구지', '무지개', '황구지', '무지개', '황구지', '무지개'],
#  ['황기', '도끼', '황기', '도끼', '황기', '도끼'],
#  ['황로', '항라', '황로', '항라', '황로', '항라'],
#  ['황벡비낭', '황벽나무', '황벡비낭', '황벽나무', '황벡비낭', '황벽나무'],
#  ['황벡피낭', '황벽나무', '황벡피낭', '황벽나무', '황벡피낭', '황벽나무'],
#  ['황솔', '황송', '황솔', '황송', '황솔', '황송'],
#  ['황솔치', '청새치', '황솔치', '청새치', '황솔치', '청새치'],
#  ['황쉐', '황소', '황쉐', '황소', '황쉐', '황소'],
#  ['황애이리', '황매퉁이', '황애이리', '황매퉁이', '황애이리', '황매퉁이'],
#  ['황주넹이', '왕지네', '황주넹이', '왕지네', '황주넹이', '왕지네'],
#  ['홰', '화', '홰', '화', '홰', '화'],
#  ['홰똥', '활개똥', '홰똥', '활개똥', '홰똥', '활개똥'],
#  ['횃대쉬', '키다리', '횃대쉬', '키다리', '횃대쉬', '키다리'],
#  ['횃짐', '홧김', '횃짐', '홧김', '횃짐', '홧김'],
#  ['회', '당혜', '회', '당혜', '회', '당혜'],
#  ['후각', '뒷다리', '후각', '뒷다리', '후각', '뒷다리'],
#  ['후끗', '뒤끝', '후끗', '뒤끝', '후끗', '뒤끝'],
#  ['후루걸이', '말라리아', '후루걸이', '말라리아', '후루걸이', '말라리아'],
#  ['후루마기', '두루마기', '후루마기', '두루마기', '후루마기', '두루마기'],
#  ['후르매기', '두루마기', '후르매기', '두루마기', '후르매기', '두루마기'],
#  ['후리막', '두루마기', '후리막', '두루마기', '후리막', '두루마기'],
#  ['후리매', '두루마기', '후리매', '두루마기', '후리매', '두루마기'],
#  ['후리메', '두루마기', '후리메', '두루마기', '후리메', '두루마기'],
#  ['후리아들', '후레아들', '후리아들', '후레아들', '후리아들', '후레아들'],
#  ['후림', '멸치들망', '후림', '멸치들망', '후림', '멸치들망'],
#  ['후림대', '후림', '후림대', '후림', '후림대', '후림'],
#  ['후림질', '후리질', '후림질', '후리질', '후림질', '후리질'],
#  ['후릿구물', '멸치들망', '후릿구물', '멸치들망', '후릿구물', '멸치들망'],
#  ['후박낭', '후박나무', '후박낭', '후박나무', '후박낭', '후박나무'],
#  ['후보롬', '후보름', '후보롬', '후보름', '후보롬', '후보름'],
#  ['훍은모살', '왕모래', '훍은모살', '왕모래', '훍은모살', '왕모래'],
#  ['훍은몰레', '왕모래', '훍은몰레', '왕모래', '훍은몰레', '왕모래'],
#  ['훍은체', '왕겨', '훍은체', '왕겨', '훍은체', '왕겨'],
#  ['훗공론', '뒷공론', '훗공론', '뒷공론', '훗공론', '뒷공론'],
#  ['훗말', '뒷말', '훗말', '뒷말', '훗말', '뒷말'],
#  ['훗소리', '뒷말', '훗소리', '뒷말', '훗소리', '뒷말'],
#  ['잠진탕근', '게알탕건', '잠진탕근', '게알탕건', '잠진탕근', '게알탕건'],
#  ['훼', '홰', '훼', '홰', '훼', '홰'],
#  ['훼미', '호미', '훼미', '호미', '훼미', '호미'],
#  ['훼초리', '회초리', '훼초리', '회초리', '훼초리', '회초리'],
#  ['훼추리', '회초리', '훼추리', '회초리', '훼추리', '회초리'],
#  ['휏데쉬', '키다리', '휏데쉬', '키다리', '휏데쉬', '키다리'],
#  ['흐렁', '수렁', '흐렁', '수렁', '흐렁', '수렁'],
#  ['흐렁논', '수렁논', '흐렁논', '수렁논', '흐렁논', '수렁논'],
#  ['흐렁답', '수렁논', '흐렁답', '수렁논', '흐렁답', '수렁논'],
#  ['흐린감저', '밤고구마', '흐린감저', '밤고구마', '흐린감저', '밤고구마'],
#  ['흐린조', '차조', '흐린조', '차조', '흐린조', '차조'],
#  ['흐린조팝', '차조밥', '흐린조팝', '차조밥', '흐린조팝', '차조밥'],
#  ['흐린좁쌀', '차좁쌀', '흐린좁쌀', '차좁쌀', '흐린좁쌀', '차좁쌀'],
#  ['흑', '흙', '흑', '흙', '흑', '흙'],
#  ['흑돔', '감성돔', '흑돔', '감성돔', '흑돔', '감성돔'],
#  ['흑물탕', '흙탕물', '흑물탕', '흙탕물', '흑물탕', '흙탕물'],
#  ['흑밥', '소꿉질', '흑밥', '소꿉질', '흑밥', '소꿉질'],
#  ['흑밥장난', '소꿉장난', '흑밥장난', '소꿉장난', '흑밥장난', '소꿉장난'],
#  ['흑벡', '흙벽', '흑벡', '흙벽', '흑벡', '흙벽'],
#  ['흑소왕이', '조뱅이', '흑소왕이', '조뱅이', '흑소왕이', '조뱅이'],
#  ['흑손', '흙손', '흑손', '흙손', '흑손', '흙손'],
#  ['흑일', '흙일', '흑일', '흙일', '흑일', '흙일'],
#  ['흑질', '흙질', '흑질', '흙질', '흑질', '흙질'],
#  ['자뀌', '쳇발', '자뀌', '쳇발', '자뀌', '쳇발'],
#  ['흑탕물', '흙탕물', '흑탕물', '흙탕물', '흑탕물', '흙탕물'],
#  ['흘', '허물', '흘', '허물', '흘', '허물'],
#  ['흘레', '얼레', '흘레', '얼레', '흘레', '얼레'],
#  ['자냥', '절약', '자냥', '절약', '자냥', '절약'],
#  ['흘테', '훑이', '흘테', '훑이', '흘테', '훑이'],
#  ['흘테기', '훑이', '흘테기', '훑이', '흘테기', '훑이'],
#  ['흙밥', '소꿉질', '흙밥', '소꿉질', '흙밥', '소꿉질'],
#  ['흙밥장난', '소꿉장난', '흙밥장난', '소꿉장난', '흙밥장난', '소꿉장난'],
#  ['흥성바치', '흥정바치', '흥성바치', '흥정바치', '흥성바치', '흥정바치'],
#  ['쉐고기적', '산적', '쉐고기적', '산적', '쉐고기적', '산적'],
#  ['흰공자', '흰자위', '흰공자', '흰자위', '흰공자', '흰자위'],
#  ['흰동자', '흰자위', '흰동자', '흰자위', '흰동자', '흰자위'],
#  ['히는데', '수영장', '히는데', '수영장', '히는데', '수영장'],
#  ['히린조', '차조', '히린조', '차조', '히린조', '차조'],
#  ['힌공자', '흰자위', '힌공자', '흰자위', '힌공자', '흰자위'],
#  ['힌알', '흰자위', '힌알', '흰자위', '힌알', '흰자위'],
#  ['힌조기', '보구치', '힌조기', '보구치', '힌조기', '보구치'],
#  ['힘', '헤엄', '힘', '헤엄', '힘', '헤엄'],
#  ['자밤낭', '모밀잣밤나무', '자밤낭', '모밀잣밤나무', '자밤낭', '모밀잣밤나무'],
#  ['작산돈', '큰돈', '작산돈', '큰돈', '작산돈', '큰돈'],
#  ['자갈밧', '자갈땅', '자갈밧', '자갈땅', '자갈밧', '자갈땅'],
#  ['자갈왓', '자갈밭', '자갈왓', '자갈밭', '자갈왓', '자갈밭'],
#  ['자갈코', '재갈멈치', '자갈코', '재갈멈치', '자갈코', '재갈멈치'],
#  ['자갓', '곁', '자갓', '곁', '자갓', '곁'],
#  ['자곰테기', '자개미', '자곰테기', '자개미', '자곰테기', '자개미'],
#  ['자골', '차풀', '자골', '차풀', '자골', '차풀'],
#  ['자구남', '자귀나무', '자구남', '자귀나무', '자구남', '자귀나무'],
#  ['자구낭', '자귀나무', '자구낭', '자귀나무', '자구낭', '자귀나무'],
#  ['자굴', '재갈', '자굴', '재갈', '자굴', '재갈'],
#  ['자굴낭', '자귀나무', '자굴낭', '자귀나무', '자굴낭', '자귀나무'],
#  ['자귀낭', '자귀나무', '자귀낭', '자귀나무', '자귀낭', '자귀나무'],
#  ['자금채', '작대기', '자금채', '작대기', '자금채', '작대기'],
#  ['자금체', '작대기', '자금체', '작대기', '자금체', '작대기'],
#  ['자금타는낭', '백일홍', '자금타는낭', '백일홍', '자금타는낭', '백일홍'],
#  ['자금태기', '자개미', '자금태기', '자개미', '자금태기', '자개미'],
#  ['자금테기', '자개미', '자금테기', '자개미', '자금테기', '자개미'],
#  ['자금텡이', '자개미', '자금텡이', '자개미', '자금텡이', '자개미'],
#  ['자기예기', '자개미', '자기예기', '자개미', '자기예기', '자개미'],
#  ['자기예미', '자개미', '자기예미', '자개미', '자기예미', '자개미'],
#  ['자껭이', '겨드랑이', '자껭이', '겨드랑이', '자껭이', '겨드랑이'],
#  ['자는무르레', '물레', '자는무르레', '물레', '자는무르레', '물레'],
#  ['자돔', '자리돔', '자돔', '자리돔', '자돔', '자리돔'],
#  ['자드랑이', '겨드랑이', '자드랑이', '겨드랑이', '자드랑이', '겨드랑이'],
#  ['자라펭', '편병', '자라펭', '편병', '자라펭', '편병'],
#  ['자락', '자루', '자락', '자루', '자락', '자루'],
#  ['자래', '꼬시래기', '자래', '꼬시래기', '자래', '꼬시래기'],
#  ['자럭', '자루', '자럭', '자루', '자럭', '자루'],
#  ['자레', '자라', '자레', '자라', '자레', '자라'],
#  ['가리', '갈비', '가리', '갈비', '가리', '갈비'],
#  ['자록', '자루', '자록', '자루', '자록', '자루'],
#  ['자룩', '자루', '자룩', '자루', '자룩', '자루'],
#  ['자류말', '자류마', '자류말', '자류마', '자류말', '자류마'],
#  ['자류매', '자류마', '자류매', '자류마', '자류매', '자류마'],
#  ['자른부출', '막이', '자른부출', '막이', '자른부출', '막이'],
#  ['자른중이', '잠방이', '자른중이', '잠방이', '자른중이', '잠방이'],
#  ['자름보말', '각시고둥', '자름보말', '각시고둥', '자름보말', '각시고둥'],
#  ...]

# %%
from gensim.models import Word2Vec

model_jj = Word2Vec(sentences = tset, vector_size = 100,dd window = 3, min_count = 3, workers = 4, sg = 1, epochs = 100)
# sg값 1일 경우 skip-gram, 0일 경우 CBOW
# skip-gram : 해당 단어를 통해 주변단어를 dd
# CBOW : 주변 단어를 통해 해당 단어를 dd

# %%
model_jj.wv.similarity('부채', '분채')
# Out:
# 0.99645764

# %%
print(model_jj.wv.most_similar("시름없다"))
# Out:
# [('시름엇다', 0.9964210987091064), ('시름읏다', 0.996354877948761), ('시름읎다', 0.9959554076194763), ('행실머리', 0.6141220927238464), ('물퀴신', 0.5997700691223145), ('헨실머리', 0.5978392362594604), ('물쿠신', 0.5977985262870789), ('물귀신', 0.5854921340942383), ('어느제', 0.5790910720825195), ('어는제', 0.5770575404167175)]

# %%
jj[:50]
# Out:
#     dial original                                            meaning reg  \
# 0     분쉬       분수                               분수의 방언, 사물을 분별하는 지혜.  jj
# 1     분시       분수                               분수의 방언, 사물을 분별하는 지혜.  jj
# 2     분절       분결                          분결의 방언, 분한 마음이 왈칵 일어난 바람.  jj
# 3     분채       부채   부채의 방언, 손으로 흔들어 바람을 일으키는 물건. 대오리로 살을 하고 종이나 헝...  jj
# 4    분채질      부채질                       부채질의 방언, 부채를 흔들어 바람을 일으키는 일.  jj
# 5    사둔칩      사돈집                              사돈집의 방언, 서로 사돈이 되는 집.  jj
# 6     분짐       분김                          분김의 방언, 분한 마음이 왈칵 일어난 바람.  jj
# 7     분짓       분깃                     분깃의 방언, 유산을 한 몫 나누어 줌. 또는 그 몫.  jj
# 8   하르버지     할아버지                     할아버지의 방언, 부모의 아버지를 이르거나 부르는 말.  jj
# 9      불        벌                               벌의 방언, 넓고 평평하게 생긴 땅.  jj
# 10   불갈래       부삽   부삽의 방언, 아궁이나 화로의 재를 치거나, 숯불이나 불을 담아 옮기는 데 쓰는 ...  jj
# 11    불갑       성냥   성냥의 방언, 마찰에 의하여 불을 일으키는 물건. 작은 나뭇개비의 한쪽 끝에 황 ...  jj
# 12   불게미       불똥                    불똥의 방언, 심지의 끝이 다 타서 엉기어 붙은 찌꺼기.  jj
# 13  불게예미       불똥                    불똥의 방언, 심지의 끝이 다 타서 엉기어 붙은 찌꺼기.  jj
# 14    불곽      성냥갑   성냥갑의 방언, 성냥개비를 넣는 갑. 측면에 유리 가루, 규사, 규조토 따위가 발...  jj
# 15  불궤수웨     불쏘시개   불쏘시개의 방언, 불을 때거나 피울 적에 불이 쉽게 옮겨붙게 하기 위하여 먼저 태...  jj
# 16   불그네      고무래   고무래의 방언, 곡식을 그러모으고 펴거나, 밭의 흙을 고르거나 아궁이의 재를 긁어...  jj
# 17   불근네     불고무래   불고무래의 방언, 아궁이의 불을 밀어 넣거나 한데 모아 당기어 밖으로 내는 데 쓰...  jj
# 18   불근데     불고무래   불고무래의 방언, 아궁이의 불을 밀어 넣거나 한데 모아 당기어 밖으로 내는 데 쓰...  jj
# 19  불글레기       거품              거품의 방언, 액체가 기체를 머금고 부풀어서 생긴, 속이 빈 방울.  jj
# 20    불깍       성냥   성냥의 방언, 마찰에 의하여 불을 일으키는 물건. 작은 나뭇개비의 한쪽 끝에 황 ...  jj
# 21   불깍지       등잔                    등잔의 방언, 기름을 담아 등불을 켜는 데에 쓰는 그릇.  jj
# 22    불껑        재                         재의 방언, 불에 타고 남는 가루 모양의 물질.  jj
# 23  불끌럭지     불꾸러미             불꾸러미의 방언, 불씨를 옮기기 위하여 짚 뭉치 따위에 옮겨붙인 불.  jj
# 24  불끌레기     불꾸러미             불꾸러미의 방언, 불씨를 옮기기 위하여 짚 뭉치 따위에 옮겨붙인 불.  jj
# 25  불닥새기       불알                           불알의 방언, 고환을 일상적으로 이르는 말.  jj
# 26  불닥세기       불알      불알의 방언 제주 지역에서는 불세기로도 적는다., 고환을 일상적으로 이르는 말.  jj
# 27    불도       산신                             산신의 방언, 산을 지키고 다스리는 신.  jj
# 28   불땡이     부지깽이   부지깽이의 방언, 아궁이 따위에 불을 땔 때에, 불을 헤치거나 끌어내거나 거두어 ...  jj
# 29   불란지     개똥벌레   개똥벌레의 방언, 반딧불잇과의 딱정벌레. 몸의 길이는 1.2~1.8cm이며, 검은...  jj
# 30   불미질      대장일           대장일의 방언, 수공업적인 방법으로 쇠를 달구어 연장 따위를 만드는 일.  jj
# 31   불망골       불똥                    불똥의 방언, 심지의 끝이 다 타서 엉기어 붙은 찌꺼기.  jj
# 32  불망구리       불똥                    불똥의 방언, 심지의 끝이 다 타서 엉기어 붙은 찌꺼기.  jj
# 33  불망텡이     불알망태                           불알망태의 방언, 음낭을 속되게 이르는 말.  jj
# 34  불매대장     대장장이         대장장이의 방언, 쇠를 달구어 연장 따위를 만드는 일을 직업으로 하는 사람.  jj
# 35   불매질      대장일           대장일의 방언, 수공업적인 방법으로 쇠를 달구어 연장 따위를 만드는 일.  jj
# 36    불미       풀무   풀무의 방언, 불을 피울 때에 바람을 일으키는 기구. 골풀무와 손풀무 두 가지가 있다.  jj
# 37   불미간      대장간                      대장간의 방언, 쇠를 달구어 온갖 연장을 만드는 곳.  jj
# 38   하르비     할아버지                     할아버지의 방언, 부모의 아버지를 이르거나 부르는 말.  jj
# 39  불미대장     대장장이         대장장이의 방언, 쇠를 달구어 연장 따위를 만드는 일을 직업으로 하는 사람.  jj
# 40  불미와찌     대장장이         대장장이의 방언, 쇠를 달구어 연장 따위를 만드는 일을 직업으로 하는 사람.  jj
# 41   불미왕      대장간                      대장간의 방언, 쇠를 달구어 온갖 연장을 만드는 곳.  jj
# 42  불미쟁이     대장장이         대장장이의 방언, 쇠를 달구어 연장 따위를 만드는 일을 직업으로 하는 사람.  jj
# 43   불미칩      대장간                      대장간의 방언, 쇠를 달구어 온갖 연장을 만드는 곳.  jj
# 44   불밋간      대장간                      대장간의 방언, 쇠를 달구어 온갖 연장을 만드는 곳.  jj
# 45  불방둥이      불장난                             불장난의 방언, 불을 가지고 노는 장난.  jj
# 46    불벳       불볕                            불볕의 방언, 몹시 뜨겁게 내리쬐는 햇볕.  jj
# 47    불벹       불볕                            불볕의 방언, 몹시 뜨겁게 내리쬐는 햇볕.  jj
# 48    불삽       부삽   부삽의 방언, 아궁이나 화로의 재를 치거나, 숯불이나 불을 담아 옮기는 데 쓰는 ...  jj
# 49  불소슬게     불쏘시개   불쏘시개의 방언, 불을 때거나 피울 적에 불이 쉽게 옮겨붙게 하기 위하여 먼저 태...  jj
#
#                           word2vec
# 0               분쉬 분수 분쉬 분수 분쉬 분수
# 1               분시 분수 분시 분수 분시 분수
# 2               분절 분결 분절 분결 분절 분결
# 3               분채 부채 분채 부채 분채 부채
# 4         분채질 부채질 분채질 부채질 분채질 부채질
# 5         사둔칩 사돈집 사둔칩 사돈집 사둔칩 사돈집
# 6               분짐 분김 분짐 분김 분짐 분김
# 7               분짓 분깃 분짓 분깃 분짓 분깃
# 8   하르버지 할아버지 하르버지 할아버지 하르버지 할아버지
# 9                     불 벌 불 벌 불 벌
# 10           불갈래 부삽 불갈래 부삽 불갈래 부삽
# 11              불갑 성냥 불갑 성냥 불갑 성냥
# 12           불게미 불똥 불게미 불똥 불게미 불똥
# 13        불게예미 불똥 불게예미 불똥 불게예미 불똥
# 14           불곽 성냥갑 불곽 성냥갑 불곽 성냥갑
# 15  불궤수웨 불쏘시개 불궤수웨 불쏘시개 불궤수웨 불쏘시개
# 16        불그네 고무래 불그네 고무래 불그네 고무래
# 17     불근네 불고무래 불근네 불고무래 불근네 불고무래
# 18     불근데 불고무래 불근데 불고무래 불근데 불고무래
# 19        불글레기 거품 불글레기 거품 불글레기 거품
# 20              불깍 성냥 불깍 성냥 불깍 성냥
# 21           불깍지 등잔 불깍지 등잔 불깍지 등잔
# 22                 불껑 재 불껑 재 불껑 재
# 23  불끌럭지 불꾸러미 불끌럭지 불꾸러미 불끌럭지 불꾸러미
# 24  불끌레기 불꾸러미 불끌레기 불꾸러미 불끌레기 불꾸러미
# 25        불닥새기 불알 불닥새기 불알 불닥새기 불알
# 26        불닥세기 불알 불닥세기 불알 불닥세기 불알
# 27              불도 산신 불도 산신 불도 산신
# 28     불땡이 부지깽이 불땡이 부지깽이 불땡이 부지깽이
# 29     불란지 개똥벌레 불란지 개똥벌레 불란지 개똥벌레
# 30        불미질 대장일 불미질 대장일 불미질 대장일
# 31           불망골 불똥 불망골 불똥 불망골 불똥
# 32        불망구리 불똥 불망구리 불똥 불망구리 불똥
# 33  불망텡이 불알망태 불망텡이 불알망태 불망텡이 불알망태
# 34  불매대장 대장장이 불매대장 대장장이 불매대장 대장장이
# 35        불매질 대장일 불매질 대장일 불매질 대장일
# 36              불미 풀무 불미 풀무 불미 풀무
# 37        불미간 대장간 불미간 대장간 불미간 대장간
# 38     하르비 할아버지 하르비 할아버지 하르비 할아버지
# 39  불미대장 대장장이 불미대장 대장장이 불미대장 대장장이
# 40  불미와찌 대장장이 불미와찌 대장장이 불미와찌 대장장이
# 41        불미왕 대장간 불미왕 대장간 불미왕 대장간
# 42  불미쟁이 대장장이 불미쟁이 대장장이 불미쟁이 대장장이
# 43        불미칩 대장간 불미칩 대장간 불미칩 대장간
# 44        불밋간 대장간 불밋간 대장간 불밋간 대장간
# 45     불방둥이 불장난 불방둥이 불장난 불방둥이 불장난
# 46              불벳 불볕 불벳 불볕 불벳 불볕
# 47              불벹 불볕 불벹 불볕 불벹 불볕
# 48              불삽 부삽 불삽 부삽 불삽 부삽
# 49  불소슬게 불쏘시개 불소슬게 불쏘시개 불소슬게 불쏘시개

# %%
model_jj.wv.vectors.shape
# Out:
# (21152, 100)

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ### Lexical Substitution 구현하기(표준어 -> 사투리)

# %%
def lexical_sub(sentence, word2vec):
    res = ""
    sentence = sentence.values
    tt = []
    for i in sentence:
        i = i.split()
        tt.append(i)

    try:
        _from = random.choice(tt)
        _to = word2vec.wv.most_similar(_from)[0][0]
        
    except:   # 단어장에 없는 단어
        return None

    for tok in tt:
        if tok is _from:
            res += _to + " "
        else:
            res += str(tok) + " "

    return res
