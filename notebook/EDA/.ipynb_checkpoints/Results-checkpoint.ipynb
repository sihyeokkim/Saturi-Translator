# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob

# %%
path = os.getenv('HOME') + '/aiffel/DATA'

# %%
files = glob.glob(path + '/*needs_merge_327.csv')

# %%
files
# Out:
# ['/home/seuyon0101/aiffel/DATA/test_results_msp8000_final_needs_merge_327.csv',
#  '/home/seuyon0101/aiffel/DATA/test_results_cmsp8000_final_needs_merge_327.csv',
#  '/home/seuyon0101/aiffel/DATA/test_results_spm8000_final_needs_merge_327.csv']

# %%
results = ['msp','cmsp','spm']

# %%
df = pd.read_csv(files[0],usecols=['Unnamed: 0','reg','topic','eng','dial','bleu','pred'], index_col = 'Unnamed: 0')
df.rename(columns={'bleu':'bleu_msp','pred' : 'pred_msp'}, inplace=True)

for file, res in zip(files[1:], results[1:]) :
    temp_ = pd.read_csv(file, usecols=['Unnamed: 0','reg','topic','eng','dial','bleu','pred'], index_col = 'Unnamed: 0')
    temp_.rename(columns={'bleu':f'bleu_{res}','pred' : f'pred_{res}'},inplace=True)
    df = pd.merge(df, temp_.iloc[:,[-1,-2]], right_index=True, left_index=True)
reorder_col = ['reg','topic','eng','dial','pred_spm','pred_msp','pred_cmsp','bleu_spm','bleu_msp','bleu_cmsp']
df = df[reorder_col].copy()

# %%
df['tok_len'] = df['eng'].apply(lambda x : len(x.split()))
conditions = [
    (df['tok_len'] <= 5),
    (df['tok_len'] > 5) & (df['tok_len'] <= 10),
    (df['tok_len'] > 10) & (df['tok_len'] <= 15),
    (df['tok_len'] > 15) & (df['tok_len'] <= 20),
    (df['tok_len'] > 20) & (df['tok_len'] <= 25),
    (df['tok_len'] > 25)
    ]
values = [1, 2, 3, 4,5,6]

# %%
df['tok_cat'] = np.select(conditions, values)

# %% [markdown]
# ### overall score
# > __bleu\_*max__ _는 epoch 5번까지 돌리고, 긴 시퀀스를 데이터에서 제외하고 돌린 결과임_

# %%
bleus=['bleu_spm','bleu_msp','bleu_cmsp']
df[bleus].agg(['mean']).style.background_gradient(cmap='Blues', vmin=0, vmax=15)
# Out:
# <style type="text/css">
# #T_e8052_row0_col0 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_e8052_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e8052_row0_col2 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e8052">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8052_level0_col0" class="col_heading level0 col0" >bleu_spm</th>
#       <th id="T_e8052_level0_col1" class="col_heading level0 col1" >bleu_msp</th>
#       <th id="T_e8052_level0_col2" class="col_heading level0 col2" >bleu_cmsp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8052_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_e8052_row0_col0" class="data row0 col0" >14.060324</td>
#       <td id="T_e8052_row0_col1" class="data row0 col1" >15.096059</td>
#       <td id="T_e8052_row0_col2" class="data row0 col2" >14.276615</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### by region

# %%
df.groupby('reg')[bleus].mean().style.background_gradient(cmap='Blues', vmin=0, vmax=20)
# Out:
# <style type="text/css">
# #T_ef48d_row0_col0 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_ef48d_row0_col1 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_ef48d_row0_col2 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_ef48d_row1_col0 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_ef48d_row1_col1 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_ef48d_row1_col2 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_ef48d_row2_col0 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_ef48d_row2_col1 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_ef48d_row2_col2 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_ef48d_row3_col0 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_ef48d_row3_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ef48d_row3_col2 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_ef48d_row4_col0 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_ef48d_row4_col1 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_ef48d_row4_col2 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ef48d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef48d_level0_col0" class="col_heading level0 col0" >bleu_spm</th>
#       <th id="T_ef48d_level0_col1" class="col_heading level0 col1" >bleu_msp</th>
#       <th id="T_ef48d_level0_col2" class="col_heading level0 col2" >bleu_cmsp</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >reg</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef48d_level0_row0" class="row_heading level0 row0" >cc</th>
#       <td id="T_ef48d_row0_col0" class="data row0 col0" >10.823839</td>
#       <td id="T_ef48d_row0_col1" class="data row0 col1" >10.521975</td>
#       <td id="T_ef48d_row0_col2" class="data row0 col2" >10.989728</td>
#     </tr>
#     <tr>
#       <th id="T_ef48d_level0_row1" class="row_heading level0 row1" >gs</th>
#       <td id="T_ef48d_row1_col0" class="data row1 col0" >17.369254</td>
#       <td id="T_ef48d_row1_col1" class="data row1 col1" >15.775978</td>
#       <td id="T_ef48d_row1_col2" class="data row1 col2" >19.696434</td>
#     </tr>
#     <tr>
#       <th id="T_ef48d_level0_row2" class="row_heading level0 row2" >jd</th>
#       <td id="T_ef48d_row2_col0" class="data row2 col0" >10.442326</td>
#       <td id="T_ef48d_row2_col1" class="data row2 col1" >11.920957</td>
#       <td id="T_ef48d_row2_col2" class="data row2 col2" >13.424255</td>
#     </tr>
#     <tr>
#       <th id="T_ef48d_level0_row3" class="row_heading level0 row3" >jj</th>
#       <td id="T_ef48d_row3_col0" class="data row3 col0" >18.520314</td>
#       <td id="T_ef48d_row3_col1" class="data row3 col1" >20.342869</td>
#       <td id="T_ef48d_row3_col2" class="data row3 col2" >14.475589</td>
#     </tr>
#     <tr>
#       <th id="T_ef48d_level0_row4" class="row_heading level0 row4" >kw</th>
#       <td id="T_ef48d_row4_col0" class="data row4 col0" >13.145886</td>
#       <td id="T_ef48d_row4_col1" class="data row4 col1" >16.918515</td>
#       <td id="T_ef48d_row4_col2" class="data row4 col2" >12.797071</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### by tok_len

# %%
df.groupby('tok_cat')[bleus].mean().style.background_gradient(cmap='Blues', vmin=0, vmax=15)
# Out:
# <style type="text/css">
# #T_1bb57_row0_col0, #T_1bb57_row0_col1, #T_1bb57_row0_col2, #T_1bb57_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_1bb57_row1_col0 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_1bb57_row1_col2 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_1bb57_row2_col0 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_1bb57_row2_col1 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_1bb57_row2_col2 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_1bb57_row3_col0 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_1bb57_row3_col1, #T_1bb57_row4_col0 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_1bb57_row3_col2 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_1bb57_row4_col1 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_1bb57_row4_col2 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_1bb57_row5_col0 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_1bb57_row5_col1 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_1bb57_row5_col2 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1bb57">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bb57_level0_col0" class="col_heading level0 col0" >bleu_spm</th>
#       <th id="T_1bb57_level0_col1" class="col_heading level0 col1" >bleu_msp</th>
#       <th id="T_1bb57_level0_col2" class="col_heading level0 col2" >bleu_cmsp</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tok_cat</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bb57_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_1bb57_row0_col0" class="data row0 col0" >25.041029</td>
#       <td id="T_1bb57_row0_col1" class="data row0 col1" >28.499103</td>
#       <td id="T_1bb57_row0_col2" class="data row0 col2" >19.814600</td>
#     </tr>
#     <tr>
#       <th id="T_1bb57_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_1bb57_row1_col0" class="data row1 col0" >14.149254</td>
#       <td id="T_1bb57_row1_col1" class="data row1 col1" >14.987535</td>
#       <td id="T_1bb57_row1_col2" class="data row1 col2" >14.508934</td>
#     </tr>
#     <tr>
#       <th id="T_1bb57_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_1bb57_row2_col0" class="data row2 col0" >11.859820</td>
#       <td id="T_1bb57_row2_col1" class="data row2 col1" >12.998134</td>
#       <td id="T_1bb57_row2_col2" class="data row2 col2" >13.728172</td>
#     </tr>
#     <tr>
#       <th id="T_1bb57_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_1bb57_row3_col0" class="data row3 col0" >9.696765</td>
#       <td id="T_1bb57_row3_col1" class="data row3 col1" >9.801594</td>
#       <td id="T_1bb57_row3_col2" class="data row3 col2" >11.278902</td>
#     </tr>
#     <tr>
#       <th id="T_1bb57_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_1bb57_row4_col0" class="data row4 col0" >9.785995</td>
#       <td id="T_1bb57_row4_col1" class="data row4 col1" >10.318615</td>
#       <td id="T_1bb57_row4_col2" class="data row4 col2" >11.652167</td>
#     </tr>
#     <tr>
#       <th id="T_1bb57_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_1bb57_row5_col0" class="data row5 col0" >12.339038</td>
#       <td id="T_1bb57_row5_col1" class="data row5 col1" >9.769318</td>
#       <td id="T_1bb57_row5_col2" class="data row5 col2" >11.129502</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### by reg & tok len

# %%
df.groupby(['reg','tok_cat'])[bleus].mean().style.background_gradient(cmap='Blues', vmin=0, vmax=15)
# Out:
# <style type="text/css">
# #T_5f4e8_row0_col0, #T_5f4e8_row6_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_5f4e8_row0_col1 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_5f4e8_row0_col2 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_5f4e8_row1_col0, #T_5f4e8_row1_col2, #T_5f4e8_row11_col0, #T_5f4e8_row13_col1, #T_5f4e8_row20_col2 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_5f4e8_row1_col1, #T_5f4e8_row22_col2 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_5f4e8_row2_col0 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_5f4e8_row2_col1 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_5f4e8_row2_col2 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_5f4e8_row3_col0 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_5f4e8_row3_col1, #T_5f4e8_row18_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_5f4e8_row3_col2 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_5f4e8_row4_col0, #T_5f4e8_row4_col1, #T_5f4e8_row4_col2, #T_5f4e8_row5_col0, #T_5f4e8_row5_col1, #T_5f4e8_row5_col2, #T_5f4e8_row6_col2, #T_5f4e8_row8_col2, #T_5f4e8_row9_col0, #T_5f4e8_row9_col2, #T_5f4e8_row11_col2, #T_5f4e8_row15_col0, #T_5f4e8_row15_col1, #T_5f4e8_row15_col2, #T_5f4e8_row16_col1, #T_5f4e8_row17_col0, #T_5f4e8_row19_col0, #T_5f4e8_row19_col1, #T_5f4e8_row19_col2, #T_5f4e8_row20_col1, #T_5f4e8_row21_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5f4e8_row6_col1 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_5f4e8_row7_col0 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_5f4e8_row7_col1 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_5f4e8_row7_col2 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_5f4e8_row8_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_5f4e8_row8_col1 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_5f4e8_row9_col1 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_5f4e8_row10_col0, #T_5f4e8_row10_col1, #T_5f4e8_row10_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5f4e8_row11_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_5f4e8_row12_col0 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_5f4e8_row12_col1 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_5f4e8_row12_col2 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_5f4e8_row13_col0 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_5f4e8_row13_col2 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_5f4e8_row14_col0 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_5f4e8_row14_col1, #T_5f4e8_row18_col1 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_5f4e8_row14_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_5f4e8_row16_col0 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_5f4e8_row16_col2 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_5f4e8_row17_col1 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_5f4e8_row17_col2 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_5f4e8_row18_col2 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_5f4e8_row20_col0 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_5f4e8_row21_col0 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_5f4e8_row21_col2 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_5f4e8_row22_col0 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_5f4e8_row22_col1 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5f4e8">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f4e8_level0_col0" class="col_heading level0 col0" >bleu_spm</th>
#       <th id="T_5f4e8_level0_col1" class="col_heading level0 col1" >bleu_msp</th>
#       <th id="T_5f4e8_level0_col2" class="col_heading level0 col2" >bleu_cmsp</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >reg</th>
#       <th class="index_name level1" >tok_cat</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f4e8_level0_row0" class="row_heading level0 row0" rowspan="4">cc</th>
#       <th id="T_5f4e8_level1_row0" class="row_heading level1 row0" >2</th>
#       <td id="T_5f4e8_row0_col0" class="data row0 col0" >14.845077</td>
#       <td id="T_5f4e8_row0_col1" class="data row0 col1" >10.022184</td>
#       <td id="T_5f4e8_row0_col2" class="data row0 col2" >11.477947</td>
#     </tr>
#     <tr>
#       <th id="T_5f4e8_level1_row1" class="row_heading level1 row1" >3</th>
#       <td id="T_5f4e8_row1_col0" class="data row1 col0" >11.123156</td>
#       <td id="T_5f4e8_row1_col1" class="data row1 col1" >12.573577</td>
#       <td id="T_5f4e8_row1_col2" class="data row1 col2" >11.113325</td>
#     </tr>
#     <tr>
#       <th id="T_5f4e8_level1_row2" class="row_heading level1 row2" >4</th>
#       <td id="T_5f4e8_row2_col0" class="data row2 col0" >8.637001</td>
#       <td id="T_5f4e8_row2_col1" class="data row2 col1" >9.152653</td>
#       <td id="T_5f4e8_row2_col2" class="data row2 col2" >10.911225</td>
#     </tr>
#     <tr>
#       <th id="T_5f4e8_level1_row3" class="row_heading level1 row3" >5</th>
#       <td id="T_5f4e8_row3_col0" class="data row3 col0" >7.403626</td>
#       <td id="T_5f4e8_row3_col1" class="data row3 col1" >9.976888</td>
#       <td id="T_5f4e8_row3_col2" class="data row3 col2" >9.383943</td>
#     </tr>
#     <tr>
#       <th id="T_5f4e8_level0_row4" class="row_heading level0 row4" rowspan="6">gs</th>
#       <th id="T_5f4e8_level1_row4" class="row_heading level1 row4" >1</th>
#       <td id="T_5f4e8_row4_col0" class="data row4 col0" >70.710678</td>
#       <td id="T_5f4e8_row4_col1" class="data row4 col1" >84.089642</td>
#       <td id="T_5f4e8_row4_col2" class="data row4 col2" >70.710678</td>
#     </tr>
#     <tr>
#       <th id="T_5f4e8_level1_row5" class="row_heading level1 row5" >2</th>
#       <td id="T_5f4e8_row5_col0" class="data row5 col0" >18.630669</td>
#       <td id="T_5f4e8_row5_col1" class="data row5 col1" >17.657288</td>
#       <td id="T_5f4e8_row5_col2" class="data row5 col2" >20.323334</td>
#     </tr>
#     <tr>
#       <th id="T_5f4e8_level1_row6" class="row_heading level1 row6" >3</th>
#       <td id="T_5f4e8_row6_col0" class="data row6 col0" >14.847347</td>
#       <td id="T_5f4e8_row6_col1" class="data row6 col1" >9.919701</td>
#       <td id="T_5f4e8_row6_col2" class="data row6 col2" >19.314745</td>
#     </tr>
#     <tr>
#       <th id="T_5f4e8_level1_row7" class="row_heading level1 row7" >4</th>
#       <td id="T_5f4e8_row7_col0" class="data row7 col0" >9.244730</td>
#       <td id="T_5f4e8_row7_col1" class="data row7 col1" >8.914331</td>
#       <td id="T_5f4e8_row7_col2" class="data row7 col2" >11.860072</td>
#     </tr>
#     <tr>
#       <th id="T_5f4e8_level1_row8" class="row_heading level1 row8" >5</th>
#       <td id="T_5f4e8_row8_col0" class="data row8 col0" >14.550732</td>
#       <td id="T_5f4e8_row8_col1" class="data row8 col1" >11.002068</td>
#       <td id="T_5f4e8_row8_col2" class="data row8 col2" >16.188614</td>
#     </tr>
#     <tr>
#       <th id="T_5f4e8_level1_row9" class="row_heading level1 row9" >6</th>
#       <td id="T_5f4e8_row9_col0" class="data row9 col0" >18.110801</td>
#       <td id="T_5f4e8_row9_col1" class="data row9 col1" >9.730661</td>
#       <td id="T_5f4e8_row9_col2" class="data row9 col2" >15.229307</td>
#     </tr>
#     <tr>
#       <th id="T_5f4e8_level0_row10" class="row_heading level0 row10" rowspan="5">jd</th>
#       <th id="T_5f4e8_level1_row10" class="row_heading level1 row10" >1</th>
#       <td id="T_5f4e8_row10_col0" class="data row10 col0" >0.000000</td>
#       <td id="T_5f4e8_row10_col1" class="data row10 col1" >0.000000</td>
#       <td id="T_5f4e8_row10_col2" class="data row10 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5f4e8_level1_row11" class="row_heading level1 row11" >2</th>
#       <td id="T_5f4e8_row11_col0" class="data row11 col0" >11.080699</td>
#       <td id="T_5f4e8_row11_col1" class="data row11 col1" >14.591673</td>
#       <td id="T_5f4e8_row11_col2" class="data row11 col

# %% [markdown]
# ### by topic

# %%
df.groupby('topic')[bleus].mean().style.background_gradient(cmap='Blues', vmin=0, vmax=30)
# Out:
# <style type="text/css">
# #T_49b5d_row0_col0, #T_49b5d_row4_col0 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_49b5d_row0_col1, #T_49b5d_row13_col1 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_49b5d_row0_col2, #T_49b5d_row21_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_49b5d_row1_col0, #T_49b5d_row22_col2, #T_49b5d_row25_col0 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_49b5d_row1_col1, #T_49b5d_row33_col0 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_49b5d_row1_col2, #T_49b5d_row34_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_49b5d_row2_col0, #T_49b5d_row32_col2 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_49b5d_row2_col1, #T_49b5d_row29_col1 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_49b5d_row2_col2 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_49b5d_row3_col0, #T_49b5d_row3_col1 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_49b5d_row3_col2, #T_49b5d_row8_col0, #T_49b5d_row8_col1, #T_49b5d_row8_col2, #T_49b5d_row12_col0, #T_49b5d_row12_col1, #T_49b5d_row12_col2, #T_49b5d_row16_col0, #T_49b5d_row16_col1, #T_49b5d_row16_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_49b5d_row4_col1 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_49b5d_row4_col2 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_49b5d_row5_col0, #T_49b5d_row33_col1, #T_49b5d_row33_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_49b5d_row5_col1, #T_49b5d_row20_col2 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_49b5d_row5_col2 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_49b5d_row6_col0, #T_49b5d_row26_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_49b5d_row6_col1 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_49b5d_row6_col2, #T_49b5d_row27_col1, #T_49b5d_row29_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_49b5d_row7_col0, #T_49b5d_row15_col2 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_49b5d_row7_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_49b5d_row7_col2 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_49b5d_row9_col0 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_49b5d_row9_col1 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_49b5d_row9_col2, #T_49b5d_row15_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_49b5d_row10_col0 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_49b5d_row10_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_49b5d_row10_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_49b5d_row11_col0 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_49b5d_row11_col1 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_49b5d_row11_col2 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_49b5d_row13_col0, #T_49b5d_row14_col2, #T_49b5d_row21_col0 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_49b5d_row13_col2 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_49b5d_row14_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_49b5d_row14_col1 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_49b5d_row15_col0 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_49b5d_row17_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_49b5d_row17_col1 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_49b5d_row17_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_49b5d_row18_col0 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_49b5d_row18_col1, #T_49b5d_row18_col2, #T_49b5d_row28_col0, #T_49b5d_row28_col1, #T_49b5d_row28_col2, #T_49b5d_row30_col0, #T_49b5d_row30_col1, #T_49b5d_row31_col1, #T_49b5d_row31_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_49b5d_row19_col0 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_49b5d_row19_col1 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_49b5d_row19_col2, #T_49b5d_row26_col1 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_49b5d_row20_col0, #T_49b5d_row22_col0, #T_49b5d_row22_col1, #T_49b5d_row31_col0 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_49b5d_row20_col1 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_49b5d_row21_col2 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_49b5d_row23_col0 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_49b5d_row23_col1 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_49b5d_row23_col2 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_49b5d_row24_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_49b5d_row24_col1 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_49b5d_row24_col2 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_49b5d_row25_col1 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_49b5d_row25_col2 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_49b5d_row26_col2 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_49b5d_row27_col0 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_49b5d_row27_col2 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_49b5d_row29_col0 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_49b5d_row30_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_49b5d_row32_col0 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_49b5d_row32_col1 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_49b5d_row34_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_49b5d_row34_col1 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# </style>
# <table id="T_49b5d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49b5d_level0_col0" class="col_heading level0 col0" >bleu_spm</th>
#       <th id="T_49b5d_level0_col1" class="col_heading level0 col1" >bleu_msp</th>
#       <th id="T_49b5d_level0_col2" class="col_heading level0 col2" >bleu_cmsp</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49b5d_level0_row0" class="row_heading level0 row0" >가족</th>
#       <td id="T_49b5d_row0_col0" class="data row0 col0" >13.536697</td>
#       <td id="T_49b5d_row0_col1" class="data row0 col1" >15.529030</td>
#       <td id="T_49b5d_row0_col2" class="data row0 col2" >13.684335</td>
#     </tr>
#     <tr>
#       <th id="T_49b5d_level0_row1" class="row_heading level0 row1" >건강</th>
#       <td id="T_49b5d_row1_col0" class="data row1 col0" >12.102183</td>
#       <td id="T_49b5d_row1_col1" class="data row1 col1" >11.629497</td>
#       <td id="T_49b5d_row1_col2" class="data row1 col2" >8.377936</td>
#     </tr>
#     <tr>
#       <th id="T_49b5d_level0_row2" class="row_heading level0 row2" >게임</th>
#       <td id="T_49b5d_row2_col0" class="data row2 col0" >11.296500</td>
#       <td id="T_49b5d_row2_col1" class="data row2 col1" >9.407481</td>
#       <td id="T_49b5d_row2_col2" class="data row2 col2" >12.739882</td>
#     </tr>
#     <tr>
#       <th id="T_49b5d_level0_row3" class="row_heading level0 row3" >경제</th>
#       <td id="T_49b5d_row3_col0" class="data row3 col0" >24.925979</td>
#       <td id="T_49b5d_row3_col1" class="data row3 col1" >24.880469</td>
#       <td id="T_49b5d_row3_col2" class="data row3 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_49b5d_level0_row4" class="row_heading level0 row4" >계절</th>
#       <td id="T_49b5d_row4_col0" class="data row4 col0" >13.502928</td>
#       <td id="T_49b5d_row4_col1" class="data row4 col1" >5.427963</td>
#       <td id="T_49b5d_row4_col2" class="data row4 col2" >18.532822</td>
#     </tr>
#     <tr>
#       <th id="T_49b5d_level0_row5" class="row_heading level0 row5" >군대</th>
#       <td id="T_49b5d_row5_col0" class="data row5 col0" >8.595871</td>
#       <td id="T_49b5d_row5_col1" class="data row5 col1" >14.234617</td>
#       <td id="T_49b5d_row5_col2" class="data row5 col2" >16.960703</td>
#     </tr>
#     <tr>
#       <th id="T_49b5d_level0_row6" class="row_heading level0 row6" >꿈(목표)</th>
#       <td id="T_49b5d_row6_col0" class="data row6 col0" >15.445222</td>
#       <td id="T_

# %% [markdown]
# ### by reg & topic

# %%
df.loc[df.reg =='cc'].groupby(['topic'])[bleus].mean().style.background_gradient(cmap='Blues', vmin=0, vmax=30)
# Out:
# <style type="text/css">
# #T_b4c14_row0_col0 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_b4c14_row0_col1, #T_b4c14_row1_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_b4c14_row0_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_b4c14_row1_col0 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_b4c14_row1_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_b4c14_row2_col0, #T_b4c14_row2_col1, #T_b4c14_row13_col1 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_b4c14_row2_col2, #T_b4c14_row12_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_b4c14_row3_col0 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_b4c14_row3_col1 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_b4c14_row3_col2, #T_b4c14_row7_col1, #T_b4c14_row7_col2, #T_b4c14_row11_col2 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_b4c14_row4_col0 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_b4c14_row4_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_b4c14_row4_col2 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_b4c14_row5_col0, #T_b4c14_row5_col1, #T_b4c14_row5_col2, #T_b4c14_row8_col2, #T_b4c14_row20_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b4c14_row6_col0 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_b4c14_row6_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_b4c14_row6_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_b4c14_row7_col0 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_b4c14_row8_col0, #T_b4c14_row8_col1, #T_b4c14_row20_col1 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_b4c14_row9_col0, #T_b4c14_row17_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_b4c14_row9_col1 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_b4c14_row9_col2, #T_b4c14_row15_col2 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_b4c14_row10_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_b4c14_row10_col1 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_b4c14_row10_col2 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_b4c14_row11_col0, #T_b4c14_row11_col1, #T_b4c14_row18_col1 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_b4c14_row12_col0 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_b4c14_row12_col2 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_b4c14_row13_col0 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_b4c14_row13_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_b4c14_row14_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_b4c14_row14_col1 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_b4c14_row14_col2 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_b4c14_row15_col0 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_b4c14_row15_col1 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_b4c14_row16_col0 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_b4c14_row16_col1 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_b4c14_row16_col2 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_b4c14_row17_col0 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_b4c14_row17_col1 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_b4c14_row18_col0, #T_b4c14_row18_col2 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_b4c14_row19_col0 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_b4c14_row19_col1, #T_b4c14_row19_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_b4c14_row20_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# </style>
# <table id="T_b4c14">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4c14_level0_col0" class="col_heading level0 col0" >bleu_spm</th>
#       <th id="T_b4c14_level0_col1" class="col_heading level0 col1" >bleu_msp</th>
#       <th id="T_b4c14_level0_col2" class="col_heading level0 col2" >bleu_cmsp</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4c14_level0_row0" class="row_heading level0 row0" >가족</th>
#       <td id="T_b4c14_row0_col0" class="data row0 col0" >10.278340</td>
#       <td id="T_b4c14_row0_col1" class="data row0 col1" >7.830277</td>
#       <td id="T_b4c14_row0_col2" class="data row0 col2" >8.255532</td>
#     </tr>
#     <tr>
#       <th id="T_b4c14_level0_row1" class="row_heading level0 row1" >게임</th>
#       <td id="T_b4c14_row1_col0" class="data row1 col0" >8.042268</td>
#       <td id="T_b4c14_row1_col1" class="data row1 col1" >7.812895</td>
#       <td id="T_b4c14_row1_col2" class="data row1 col2" >9.291150</td>
#     </tr>
#     <tr>
#       <th id="T_b4c14_level0_row2" class="row_heading level0 row2" >계절</th>
#       <td id="T_b4c14_row2_col0" class="data row2 col0" >10.855926</td>
#       <td id="T_b4c14_row2_col1" class="data row2 col1" >10.855926</td>
#       <td id="T_b4c14_row2_col2" class="data row2 col2" >12.185174</td>
#     </tr>
#     <tr>
#       <th id="T_b4c14_level0_row3" class="row_heading level0 row3" >군대</th>
#       <td id="T_b4c14_row3_col0" class="data row3 col0" >10.569769</td>
#       <td id="T_b4c14_row3_col1" class="data row3 col1" >12.605968</td>
#       <td id="T_b4c14_row3_col2" class="data row3 col2" >13.910598</td>
#     </tr>
#     <tr>
#       <th id="T_b4c14_level0_row4" class="row_heading level0 row4" >날씨</th>
#       <td id="T_b4c14_row4_col0" class="data row4 col0" >6.454972</td>
#       <td id="T_b4c14_row4_col1" class="data row4 col1" >14.620347</td>
#       <td id="T_b4c14_row4_col2" class="data row4 col2" >14.167552</td>
#     </tr>
#     <tr>
#       <th id="T_b4c14_level0_row5" class="row_heading level0 row5" >드라마</th>
#       <td id="T_b4c14_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_b4c14_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_b4c14_row5_col2" class="data row5 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b4c14_level0_row6" class="row_heading level0 row6" >만화</th>
#       <td id="T_b4c14_row6_col0" class="data row6 col0" >6.787683</td>
#       <td id="T_b4c14_row6_col1" class="data row6 col1" >4.175854</td>
#       <td id="T_b4c14_row6_col2" class="data row6 col2" >5.625356</td>
#     </tr>
#     <tr>
#       <th id="T_b4c14_level0_row7" class="row_heading level0 row7" >먹거리</th>
#       <td id="T_b4c14_row7_col0" class="data row7 col0" >21.649101</td>
#       <td id="T_b4c14_row7_col1" class="data row7 col1" >13.832544</td>
#       <td id="T_b4c14_row7_col2" class="data row7 col2" >13.832544</td>
#     </tr>
#     <tr>
#       <th id="T_b4c14_level0_row8" class="row_heading level0 row8" >선물</th>
#       <td id="T_b4c14_row8_col0" class="data row8 col0" >5.427963</td>
#       <td id="T_b4c14_row8_col1" class="data row8 col1" >5.408030</td>
#       <td id="T_b4c14_row8_col2" class="data row8 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b4c14_level0_row9" class="row_heading level0 row9" >스타일</th>
#       <td id="T_b4c14_row9_col0" class="data row9 col0" >7.638390</td>
#       <td id="T_b4c14_row9_col1" class="data row9 col1" >8.862507</td>
#       <td id="T_b4c14_row9_col2" class="data row9 col2" >12.533477</td>
#     </tr>
#     <tr>
#       <th id="T_b4c14_level0_row10" class="row_heading level0 row10" >스포츠/레저</th>
#       <td id="T_b4c14_row10_col0" class="data row10 col0" >10.957784</td>
#       <td id="T_b4c14_row10_col1" class="data row10 col1" >13.726281</td>
#       <td id="T_b4c14_row10_col2" class="data row10 col2" >16.853999</td>
#     </tr>
#     <tr>
#       <th id="T_b4c14_level0_row11" class="row_heading level0 row11" >아르바이트</th>
#       <td id="T_b4c14_row11_col0" class="data row11 col0" >19.304870</td>
#       <td id="T_b4c14_row11_col1" class="data row11 col1" >19.304870</td>
#       <td id="T_b4c14_row11_col2" class="data row11 col2" >13.888095</td>
#     </tr>
#     <tr>
#       <th id="T_b4c14_level0_row12" class="row_heading level0 row12" >여행지(국내/해외)</th>
#       <td id="T_b4c14_row12_col0" class="data row12 col0" >19.902627</td>
#       <td

# %%
df.loc[:,['sat_eval1','acc_eval1','sat_eval2','acc_eval2','sat_eval3','acc_eval4']] = np.nan
export_df =df.loc[:,['eng','pred_spm','sat_eval1','acc_eval1','pred_msp','sat_eval2','acc_eval2','pred_cmsp','sat_eval3','acc_eval4']]

# %%
export_df.head()
# Out:
#                                                       eng  \
# 39379                <jd> That's why my friend had a cat.
# 53200                              <jd> What's a startup?
# 74542   <jd> But it's oil because it doesn't work for ...
# 723370          <jd> I wink Ill study a little like this.
# 75397   <jd> So I just wanted to apologize and get goo...
#
#                                             pred_spm  sat_eval1  acc_eval1  \
# 39379                        내 친구가 내 고양이가 왜 이케 키웠었어.        NaN        NaN
# 53200                                     스타트업 뭐시기냐?        NaN        NaN
# 74542   근디 그게 소화를 잘 못 쓰게 하는 게 기름은 내가 봤을 때는 기름을 잘 소요한        NaN        NaN
# 723370                   쫌 이케 공부도 쫌 공부도 쫌 하고 이런 편입니다        NaN        NaN
# 75397    너무 그냥 아이 사이가 잘 돼 가꼬 성적도 좋아지고잉 너도 이제 같은 거 해.        NaN        NaN
#
#                                      pred_msp  sat_eval2  acc_eval2  \
# 39379                   긍께 우리 친구가 고양이를 키워 봤제.        NaN        NaN
# 53200                                 시업이 뭐냐?        NaN        NaN
# 74542       기름에다 조화가 되는 게 아니라잉 조 소화가 잘 되는 거야.        NaN        NaN
# 723370                   아이병원이나 이런 거 쫌 공부를 잘하        NaN        NaN
# 75397   긍께 그냥 그냥 사학과 성적도 좋고 이제 같은 것도 이제 같은 것도        NaN        NaN
#
#                                       pred_cmsp  sat_eval3  acc_eval4
# 39379                    왜 그냐면 내 친구가 고양이를 키우더마.        NaN        NaN
# 53200                                 스타트업 뭐시냐?        NaN        NaN
# 74542      근디 내가 일허는 게 몸에 안 좋응께 소화가 되는다는 거야 소화가        NaN        NaN
# 723370                     좋은 시디야 같은 거를 쫌 공부를 했        NaN        NaN
# 75397   그냥 긍께 그냥 좋은 성적을 받고 좋은 성적을 받고 싶었고 이제 다시금        NaN        NaN

# %%
# !python3 -m pip install openpyxl
# Out:
# /bin/bash: /home/seuyon0101/anaconda3/envs/saturi/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Collecting openpyxl
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Collecting et-xmlfile
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2

# %%
export_df.to_excel('saturi_evaluation_0328.xlsx')
