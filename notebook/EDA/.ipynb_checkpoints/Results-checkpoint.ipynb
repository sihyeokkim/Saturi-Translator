# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob
import re

# %%
path = os.getenv('HOME') + '/aiffel/DATA'

# %%
os.getenv("HOME") + '/aiffel/aiffelthon/evaluation_test'
# Out:
# '/aiffel/aiffel/aiffelthon/evaluation_test'

# %%
path = os.getenv("HOME") + '/aiffel/aiffelthon/evaluation_test'
path
# Out:
# '/aiffel/aiffel/aiffelthon/evaluation_test'

# %%
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'saturi_evaluation_330_1600vs_SA.xlsx',
#  'test_results_msp8000_final_needs_merge_327.csv',
#  'test_results_spm8000_final_needs_merge_327.csv',
#  'test_results_cmsp8000_final_needs_merge_327.csv',
#  'test_results_spm16000_final_needs_merge_329.csv',
#  'saturi_evaluation_330_1600vs_Jongin.xlsx',
#  'test_results_msp16000_final_needs_merge_329.csv',
#  'saturi_evaluation_330_1600vs_SD.xlsx',
#  'test_results_cmsp16000_final_needs_merge_329.csv',
#  'saturi_evaluation_330_1600vs hyowon.xlsx']

# %%
files = glob.glob(path + '/*needs_merge_327.csv')
files1 = glob.glob(path + '/*needs_merge_329.csv')

# %%
files = files + files1

# %%
files
# Out:
# ['/aiffel/aiffel/aiffelthon/evaluation_test/test_results_msp8000_final_needs_merge_327.csv',
#  '/aiffel/aiffel/aiffelthon/evaluation_test/test_results_spm8000_final_needs_merge_327.csv',
#  '/aiffel/aiffel/aiffelthon/evaluation_test/test_results_cmsp8000_final_needs_merge_327.csv',
#  '/aiffel/aiffel/aiffelthon/evaluation_test/test_results_spm16000_final_needs_merge_329.csv',
#  '/aiffel/aiffel/aiffelthon/evaluation_test/test_results_msp16000_final_needs_merge_329.csv',
#  '/aiffel/aiffel/aiffelthon/evaluation_test/test_results_cmsp16000_final_needs_merge_329.csv']

# %%
# Out:
# 'msp8000'

# %%
df = pd.read_csv(files[0],usecols=['Unnamed: 0','reg','topic','eng','dial','bleu','pred'], index_col = 'Unnamed: 0')
res = re.search(r'(?<=_results_)(.*)(?=\_final.*)',files[0]).group()
df.rename(columns={'bleu':'bleu_msp8000','pred' : 'pred_msp8000'}, inplace=True)

for file in files[1:] :
    res = re.search(r'(?<=_results_)(.*)(?=\_final.*)',file).group()
    temp_ = pd.read_csv(file, usecols=['Unnamed: 0','reg','topic','eng','dial','bleu','pred'], index_col = 'Unnamed: 0')
    temp_.rename(columns={'bleu':f'bleu_{res}','pred' : f'pred_{res}'},inplace=True)
    df = pd.merge(df, temp_.iloc[:,[-1,-2]], right_index=True, left_index=True)
# reorder_col = ['reg','topic','eng','dial','pred_spm','pred_msp','pred_cmsp','bleu_spm','bleu_msp','bleu_cmsp']
# df = df[reorder_col].copy()

# %%
df.loc[:,['sat_eval1', 'acc_eval1','sat_eval2','acc_eval2','sat_eval3', 'acc_eval4']] = np.nan

# %%
eval_col_q=['reg', 'eng', 'pred_spm','sat_eval1', 'acc_eval1', 'pred_msp', 'sat_eval2','acc_eval2','pred_cmsp','sat_eval3', 'acc_eval4']

# %%
df[eval_col_q].to_excel("saturi_evaluation_330_1600vs.xlsx")

# %%
df['tok_len'] = df['eng'].apply(lambda x : len(x.split()))
conditions = [
    (df['tok_len'] <= 5),
    (df['tok_len'] > 5) & (df['tok_len'] <= 10),
    (df['tok_len'] > 10) & (df['tok_len'] <= 15),
    (df['tok_len'] > 15) & (df['tok_len'] <= 20),
    (df['tok_len'] > 20) & (df['tok_len'] <= 25),
    (df['tok_len'] > 25)
    ]
values = [1, 2, 3, 4,5,6]

# %%
df['tok_cat'] = np.select(conditions, values)

# %% [markdown]
# ### overall score
# > __bleu\_*max__ _는 epoch 5번까지 돌리고, 긴 시퀀스를 데이터에서 제외하고 돌린 결과임_

# %%
# Out:
# Index(['bleu_msp8000', 'bleu_spm8000', 'bleu_cmsp8000', 'bleu_spm16000',
#        'bleu_msp16000', 'bleu_cmsp16000'],
#       dtype='object')

# %%
bleus=['bleu_spm8000','bleu_msp8000', 'bleu_cmsp8000', 'bleu_spm16000','bleu_msp16000', 'bleu_cmsp16000']
bleus8000=['bleu_spm8000','bleu_msp8000', 'bleu_cmsp8000']
bleus1600=['bleu_spm16000','bleu_msp16000', 'bleu_cmsp16000']
preds=df.columns[df.columns.str.contains('pred')]
df[bleus].agg(['mean']).style.background_gradient(cmap='Blues', vmin=14, vmax=17)
# Out:
# <style type="text/css">
# #T_8eec6_row0_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_8eec6_row0_col1 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_8eec6_row0_col2 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_8eec6_row0_col3 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_8eec6_row0_col4 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_8eec6_row0_col5 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# </style>
# <table id="T_8eec6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >bleu_spm8000</th>
#       <th class="col_heading level0 col1" >bleu_msp8000</th>
#       <th class="col_heading level0 col2" >bleu_cmsp8000</th>
#       <th class="col_heading level0 col3" >bleu_spm16000</th>
#       <th class="col_heading level0 col4" >bleu_msp16000</th>
#       <th class="col_heading level0 col5" >bleu_cmsp16000</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8eec6_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_8eec6_row0_col0" class="data row0 col0" >14.060324</td>
#       <td id="T_8eec6_row0_col1" class="data row0 col1" >15.096059</td>
#       <td id="T_8eec6_row0_col2" class="data row0 col2" >14.276615</td>
#       <td id="T_8eec6_row0_col3" class="data row0 col3" >15.453427</td>
#       <td id="T_8eec6_row0_col4" class="data row0 col4" >16.194445</td>
#       <td id="T_8eec6_row0_col5" class="data row0 col5" >15.273744</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### by region

# %%
df.groupby('reg')[bleus].mean().style.background_gradient(cmap='Blues', vmin=10, vmax=20)
# Out:
# <style type="text/css">
# #T_08452_row0_col0 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_08452_row0_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_08452_row0_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_08452_row0_col3 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_08452_row0_col4 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_08452_row0_col5 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_08452_row1_col0 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_08452_row1_col1 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_08452_row1_col2 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_08452_row1_col3 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_08452_row1_col4 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_08452_row1_col5 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_08452_row2_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_08452_row2_col1 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_08452_row2_col2 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_08452_row2_col3 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_08452_row2_col4 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_08452_row2_col5 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_08452_row3_col0 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_08452_row3_col1, #T_08452_row4_col3, #T_08452_row4_col4, #T_08452_row4_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_08452_row3_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_08452_row3_col3 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_08452_row3_col4 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_08452_row3_col5 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_08452_row4_col0 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_08452_row4_col1 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_08452_row4_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# </style>
# <table id="T_08452_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >bleu_spm8000</th>
#       <th class="col_heading level0 col1" >bleu_msp8000</th>
#       <th class="col_heading level0 col2" >bleu_cmsp8000</th>
#       <th class="col_heading level0 col3" >bleu_spm16000</th>
#       <th class="col_heading level0 col4" >bleu_msp16000</th>
#       <th class="col_heading level0 col5" >bleu_cmsp16000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >reg</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08452_level0_row0" class="row_heading level0 row0" >cc</th>
#       <td id="T_08452_row0_col0" class="data row0 col0" >10.823839</td>
#       <td id="T_08452_row0_col1" class="data row0 col1" >10.521975</td>
#       <td id="T_08452_row0_col2" class="data row0 col2" >10.989728</td>
#       <td id="T_08452_row0_col3" class="data row0 col3" >10.240520</td>
#       <td id="T_08452_row0_col4" class="data row0 col4" >10.103434</td>
#       <td id="T_08452_row0_col5" class="data row0 col5" >11.109375</td>
#     </tr>
#     <tr>
#       <th id="T_08452_level0_row1" class="row_heading level0 row1" >gs</th>
#       <td id="T_08452_row1_col0" class="data row1 col0" >17.369254</td>
#       <td id="T_08452_row1_col1" class="data row1 col1" >15.775978</td>
#       <td id="T_08452_row1_col2" class="data row1 col2" >19.696434</td>
#       <td id="T_08452_row1_col3" class="data row1 col3" >17.255555</td>
#       <td id="T_08452_row1_col4" class="data row1 col4" >17.647626</td>
#       <td id="T_08452_row1_col5" class="data row1 col5" >16.665131</td>
#     </tr>
#     <tr>
#       <th id="T_08452_level0_row2" class="row_heading level0 row2" >jd</th>
#       <td id="T_08452_row2_col0" class="data row2 col0" >10.442326</td>
#       <td id="T_08452_row2_col1" class="data row2 col1" >11.920957</td>
#       <td id="T_08452_row2_col2" class="data row2 col2" >13.424255</td>
#       <td id="T_08452_row2_col3" class="data row2 col3" >12.530576</td>
#       <td id="T_08452_row2_col4" class="data row2 col4" >14.186832</td>
#       <td id="T_08452_row2_col5" class="data row2 col5" >12.066039</td>
#     </tr>
#     <tr>
#       <th id="T_08452_level0_row3" class="row_heading level0 row3" >jj</th>
#       <td id="T_08452_row3_col0" class="data row3 col0" >18.520314</td>
#       <td id="T_08452_row3_col1" class="data row3 col1" >20.342869</td>
#       <td id="T_08452_row3_col2" class="data row3 col2" >14.475589</td>
#       <td id="T_08452_row3_col3" class="data row3 col3" >15.934394</td>
#       <td id="T_08452_row3_col4" class="data row3 col4" >17.412999</td>
#       <td id="T_08452_row3_col5" class="data row3 col5" >14.762976</td>
#     </tr>
#     <tr>
#       <th id="T_08452_level0_row4" class="row_heading level0 row4" >kw</th>
#       <td id="T_08452_row4_col0" class="data row4 col0" >13.145886</td>
#       <td id="T_08452_row4_col1" class="data row4 col1" >16.918515</td>
#       <td id="T_08452_row4_col2" class="data row4 col2" >12.797071</td>
#       <td id="T_08452_row4_col3" class="data row4 col3" >21.306091</td>
#       <td id="T_08452_row4_col4" class="data row4 col4" >21.621334</td>
#       <td id="T_08452_row4_col5" class="data row4 col5" >21.765199</td>
#     </tr>
#   </tbody>
# </table>

# %%
import seaborn
regs = df.reg.unique()
fig = plt.figure(figsize = (10,10))
for i, reg in enumerate(regs) :
    plt.subplot(3,2,i+1)
    for k,col in enumerate(bleus8000) :
        ax =seaborn.histplot(df,x=col,label=col, color=seaborn.color_palette('pastel')[k])
    plt.xlabel(reg)
    plt.legend()
plt.tight_layout()
plt.show()

# %%
import seaborn
regs = df.reg.unique()
fig = plt.figure(figsize = (10,10))
for i, reg in enumerate(regs) :
    plt.subplot(3,2,i+1)
    for k,col in enumerate(bleus1600) :
        ax =seaborn.histplot(df,x=col,label=col, color=seaborn.color_palette('pastel')[k])
    plt.xlabel(reg)
    plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### by tok_len

# %%
df.groupby('tok_cat')[bleus].mean().style.background_gradient(cmap='Blues', vmin=0, vmax=30)
# Out:
# <style type="text/css">
# #T_52b0f_row0_col0 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_52b0f_row0_col1 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_52b0f_row0_col2 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_52b0f_row0_col3 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_52b0f_row0_col4 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_52b0f_row0_col5 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_52b0f_row1_col0, #T_52b0f_row2_col5 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_52b0f_row1_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_52b0f_row1_col2 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_52b0f_row1_col3 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_52b0f_row1_col4 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_52b0f_row1_col5 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_52b0f_row2_col0 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_52b0f_row2_col1 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_52b0f_row2_col2 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_52b0f_row2_col3, #T_52b0f_row5_col4 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_52b0f_row2_col4 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_52b0f_row3_col0 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_52b0f_row3_col1, #T_52b0f_row4_col0, #T_52b0f_row5_col1 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_52b0f_row3_col2 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_52b0f_row3_col3 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_52b0f_row3_col4 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_52b0f_row3_col5 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_52b0f_row4_col1 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_52b0f_row4_col2 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_52b0f_row4_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_52b0f_row4_col4, #T_52b0f_row5_col2 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_52b0f_row4_col5 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_52b0f_row5_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_52b0f_row5_col3 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_52b0f_row5_col5 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# </style>
# <table id="T_52b0f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >bleu_spm8000</th>
#       <th class="col_heading level0 col1" >bleu_msp8000</th>
#       <th class="col_heading level0 col2" >bleu_cmsp8000</th>
#       <th class="col_heading level0 col3" >bleu_spm16000</th>
#       <th class="col_heading level0 col4" >bleu_msp16000</th>
#       <th class="col_heading level0 col5" >bleu_cmsp16000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tok_cat</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52b0f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_52b0f_row0_col0" class="data row0 col0" >25.041029</td>
#       <td id="T_52b0f_row0_col1" class="data row0 col1" >28.499103</td>
#       <td id="T_52b0f_row0_col2" class="data row0 col2" >19.814600</td>
#       <td id="T_52b0f_row0_col3" class="data row0 col3" >26.752194</td>
#       <td id="T_52b0f_row0_col4" class="data row0 col4" >29.275493</td>
#       <td id="T_52b0f_row0_col5" class="data row0 col5" >24.699729</td>
#     </tr>
#     <tr>
#       <th id="T_52b0f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_52b0f_row1_col0" class="data row1 col0" >14.149254</td>
#       <td id="T_52b0f_row1_col1" class="data row1 col1" >14.987535</td>
#       <td id="T_52b0f_row1_col2" class="data row1 col2" >14.508934</td>
#       <td id="T_52b0f_row1_col3" class="data row1 col3" >17.498521</td>
#       <td id="T_52b0f_row1_col4" class="data row1 col4" >16.012577</td>
#       <td id="T_52b0f_row1_col5" class="data row1 col5" >15.612656</td>
#     </tr>
#     <tr>
#       <th id="T_52b0f_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_52b0f_row2_col0" class="data row2 col0" >11.859820</td>
#       <td id="T_52b0f_row2_col1" class="data row2 col1" >12.998134</td>
#       <td id="T_52b0f_row2_col2" class="data row2 col2" >13.728172</td>
#       <td id="T_52b0f_row2_col3" class="data row2 col3" >10.552030</td>
#       <td id="T_52b0f_row2_col4" class="data row2 col4" >14.388566</td>
#       <td id="T_52b0f_row2_col5" class="data row2 col5" >14.167507</td>
#     </tr>
#     <tr>
#       <th id="T_52b0f_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_52b0f_row3_col0" class="data row3 col0" >9.696765</td>
#       <td id="T_52b0f_row3_col1" class="data row3 col1" >9.801594</td>
#       <td id="T_52b0f_row3_col2" class="data row3 col2" >11.278902</td>
#       <td id="T_52b0f_row3_col3" class="data row3 col3" >10.128978</td>
#       <td id="T_52b0f_row3_col4" class="data row3 col4" >11.012911</td>
#       <td id="T_52b0f_row3_col5" class="data row3 col5" >10.812521</td>
#     </tr>
#     <tr>
#       <th id="T_52b0f_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_52b0f_row4_col0" class="data row4 col0" >9.785995</td>
#       <td id="T_52b0f_row4_col1" class="data row4 col1" >10.318615</td>
#       <td id="T_52b0f_row4_col2" class="data row4 col2" >11.652167</td>
#       <td id="T_52b0f_row4_col3" class="data row4 col3" >10.018692</td>
#       <td id="T_52b0f_row4_col4" class="data row4 col4" >11.040642</td>
#       <td id="T_52b0f_row4_col5" class="data row4 col5" >8.934661</td>
#     </tr>
#     <tr>
#       <th id="T_52b0f_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_52b0f_row5_col0" class="data row5 col0" >12.339038</td>
#       <td id="T_52b0f_row5_col1" class="data row5 col1" >9.769318</td>
#       <td id="T_52b0f_row5_col2" class="data row5 col2" >11.129502</td>
#       <td id="T_52b0f_row5_col3" class="data row5 col3" >9.082663</td>
#       <td id="T_52b0f_row5_col4" class="data row5 col4" >10.654051</td>
#       <td id="T_52b0f_row5_col5" class="data row5 col5" >8.862213</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### by reg & tok len

# %%
df.groupby(['reg','tok_cat'])[bleus].mean().style.background_gradient(cmap='Blues', vmin=0, vmax=15)
# Out:
# <style type="text/css">
# #T_c921f_row0_col0, #T_c921f_row6_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_c921f_row0_col1, #T_c921f_row0_col4 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_c921f_row0_col2, #T_c921f_row8_col3 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_c921f_row0_col3, #T_c921f_row3_col1, #T_c921f_row18_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_c921f_row0_col5 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_c921f_row1_col0, #T_c921f_row1_col2, #T_c921f_row11_col0, #T_c921f_row13_col1, #T_c921f_row20_col2 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_c921f_row1_col1, #T_c921f_row22_col2 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_c921f_row1_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_c921f_row1_col4 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_c921f_row1_col5, #T_c921f_row17_col2 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_c921f_row2_col0 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_c921f_row2_col1 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_c921f_row2_col2 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_c921f_row2_col3, #T_c921f_row14_col1, #T_c921f_row18_col1 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_c921f_row2_col4, #T_c921f_row7_col2 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_c921f_row2_col5 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_c921f_row3_col0 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_c921f_row3_col2 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_c921f_row3_col3, #T_c921f_row3_col5, #T_c921f_row13_col4 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_c921f_row3_col4 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_c921f_row4_col0, #T_c921f_row4_col1, #T_c921f_row4_col2, #T_c921f_row4_col3, #T_c921f_row4_col4, #T_c921f_row4_col5, #T_c921f_row5_col0, #T_c921f_row5_col1, #T_c921f_row5_col2, #T_c921f_row5_col3, #T_c921f_row5_col4, #T_c921f_row5_col5, #T_c921f_row6_col2, #T_c921f_row8_col2, #T_c921f_row9_col0, #T_c921f_row9_col2, #T_c921f_row11_col2, #T_c921f_row11_col3, #T_c921f_row11_col4, #T_c921f_row12_col4, #T_c921f_row15_col0, #T_c921f_row15_col1, #T_c921f_row15_col2, #T_c921f_row15_col3, #T_c921f_row15_col4, #T_c921f_row15_col5, #T_c921f_row16_col1, #T_c921f_row16_col3, #T_c921f_row16_col4, #T_c921f_row17_col0, #T_c921f_row19_col0, #T_c921f_row19_col1, #T_c921f_row19_col2, #T_c921f_row19_col3, #T_c921f_row19_col4, #T_c921f_row19_col5, #T_c921f_row20_col1, #T_c921f_row20_col3, #T_c921f_row20_col4, #T_c921f_row20_col5, #T_c921f_row21_col1, #T_c921f_row21_col4, #T_c921f_row21_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c921f_row6_col1 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_c921f_row6_col3 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_c921f_row6_col4, #T_c921f_row13_col5 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_c921f_row6_col5, #T_c921f_row8_col4, #T_c921f_row11_col5 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_c921f_row7_col0 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_c921f_row7_col1, #T_c921f_row18_col5 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_c921f_row7_col3 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_c921f_row7_col4, #T_c921f_row9_col3, #T_c921f_row17_col5 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_c921f_row7_col5 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_c921f_row8_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_c921f_row8_col1 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_c921f_row8_col5 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_c921f_row9_col1 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_c921f_row9_col4, #T_c921f_row13_col2 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_c921f_row9_col5, #T_c921f_row13_col3 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_c921f_row10_col0, #T_c921f_row10_col1, #T_c921f_row10_col2, #T_c921f_row10_col3, #T_c921f_row10_col4, #T_c921f_row10_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c921f_row11_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_c921f_row12_col0 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_c921f_row12_col1 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_c921f_row12_col2 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_c921f_row12_col3 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_c921f_row12_col5 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_c921f_row13_col0, #T_c921f_row22_col5 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_c921f_row14_col0, #T_c921f_row14_col3 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_c921f_row14_col2, #T_c921f_row14_col5 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_c921f_row14_col4, #T_c921f_row21_col2 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_c921f_row16_col0, #T_c921f_row21_col3 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_c921f_row16_col2, #T_c921f_row22_col3 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_c921f_row16_col5 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_c921f_row17_col1 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_c921f_row17_col3 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_c921f_row17_col4 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_c921f_row18_col2, #T_c921f_row18_col3, #T_c921f_row22_col4 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_c921f_row18_col4 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_c921f_row20_col0 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_c921f_row21_col0 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_c921f_row22_col0 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_c921f_row22_col1 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c921f_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >bleu_spm8000</th>
#       <th class="col_heading level0 col1" >bleu_msp8000</th>
#       <th class="col_heading level0 col2" >bleu_cmsp8000</th>
#       <th class="col_heading level0 col3" >bleu_spm16000</th>
#       <th class="col_heading level0 col4" >bleu_msp16000</th>
#       <th class="col_heading level0 col5" >bleu_cmsp16000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >reg</th>
#       <th class="index_name level1" >tok_cat</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c921f_level0_row0" class="row_heading level0 row0" rowspan="4">cc</th>
#       <th id="T_c921f_level1_row0" class="row_heading level1 row0" >2</th>
#       <td id="T_c921f_row0_col0" class="data row0 col0" >14.845077</td>
#       <td id="T_c921f_row0_col1" class="data row0 col1" >10.022184</td>
#       <td id="T_c921f_row0_col2" class="data row0 col2" >11.477947</td>
#       <td id="T_c921f_row0_col3" class="data row0 col3" >9.981694</td>
#       <td id="T_c921f_row0_col4" class="data row0 col4" >10.025348</td>
#       <td id="T_c921f_row0_col5" class="data row0 col5" >11.198516</td>
#     </tr>
#     <tr>
#       <th id="T_c921f_level1_row1" class="row_heading level1 row1" >3</th>
#       <td id="T_c921f_row1_col0" class="data row1 col0" >11.123156</td>
#       <td id="T_c921f_row1_col1" class="data row1 col1" >12.573577</td>
#       <td id="T_c921f_row1_col2" class="data row1 col2" >11.113325</td>
#       <td id="T_c921f_row1_col3" class="data row1 col3" >11.143185</td>
#       <td id="T_c921f_row1_col4" class="data row1 col4" >8.304468</td>
#       <td id="T_c921f_row1_col5" class="data row1 col5" >11.760296</td>
#     </tr>
#     <tr>
#       <th id="T_c921f_level1_row2" class="row_heading level1 row2" >4</th>
#       <td id="T_c921f_row2_col0" class="data row2 col0" >8.637001</

# %% [markdown]
# ### by topic

# %%
df.groupby('topic')[bleus].mean().style.background_gradient(cmap='Blues', vmin=0, vmax=30)
# Out:
# <style type="text/css">
# #T_6bf2a_row0_col0, #T_6bf2a_row4_col0, #T_6bf2a_row7_col3, #T_6bf2a_row20_col3 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_6bf2a_row0_col1, #T_6bf2a_row13_col1 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_6bf2a_row0_col2, #T_6bf2a_row21_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_6bf2a_row0_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_6bf2a_row0_col4, #T_6bf2a_row5_col2 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_6bf2a_row0_col5, #T_6bf2a_row23_col2 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_6bf2a_row1_col0, #T_6bf2a_row22_col2, #T_6bf2a_row25_col0, #T_6bf2a_row25_col5 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_6bf2a_row1_col1, #T_6bf2a_row33_col0 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_6bf2a_row1_col2, #T_6bf2a_row34_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_6bf2a_row1_col3, #T_6bf2a_row17_col2, #T_6bf2a_row17_col3 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_6bf2a_row1_col4, #T_6bf2a_row9_col3 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_6bf2a_row1_col5 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_6bf2a_row2_col0, #T_6bf2a_row32_col2 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_6bf2a_row2_col1, #T_6bf2a_row2_col3, #T_6bf2a_row29_col1 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_6bf2a_row2_col2, #T_6bf2a_row17_col5 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_6bf2a_row2_col4, #T_6bf2a_row6_col3, #T_6bf2a_row33_col5 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_6bf2a_row2_col5 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_6bf2a_row3_col0, #T_6bf2a_row3_col1, #T_6bf2a_row3_col3, #T_6bf2a_row3_col4, #T_6bf2a_row3_col5, #T_6bf2a_row19_col3 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_6bf2a_row3_col2, #T_6bf2a_row8_col0, #T_6bf2a_row8_col1, #T_6bf2a_row8_col2, #T_6bf2a_row8_col3, #T_6bf2a_row8_col4, #T_6bf2a_row12_col0, #T_6bf2a_row12_col1, #T_6bf2a_row12_col2, #T_6bf2a_row12_col3, #T_6bf2a_row12_col4, #T_6bf2a_row12_col5, #T_6bf2a_row16_col0, #T_6bf2a_row16_col1, #T_6bf2a_row16_col2, #T_6bf2a_row16_col4, #T_6bf2a_row22_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6bf2a_row4_col1 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_6bf2a_row4_col2 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_6bf2a_row4_col3 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_6bf2a_row4_col4, #T_6bf2a_row11_col1 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_6bf2a_row4_col5 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_6bf2a_row5_col0, #T_6bf2a_row33_col1, #T_6bf2a_row33_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_6bf2a_row5_col1, #T_6bf2a_row11_col4, #T_6bf2a_row20_col2 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_6bf2a_row5_col3 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_6bf2a_row5_col4, #T_6bf2a_row19_col2, #T_6bf2a_row26_col1, #T_6bf2a_row26_col4 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_6bf2a_row5_col5 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_6bf2a_row6_col0, #T_6bf2a_row13_col3, #T_6bf2a_row26_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_6bf2a_row6_col1, #T_6bf2a_row24_col3 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_6bf2a_row6_col2, #T_6bf2a_row27_col1, #T_6bf2a_row27_col3, #T_6bf2a_row29_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_6bf2a_row6_col4 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_6bf2a_row6_col5, #T_6bf2a_row17_col1 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_6bf2a_row7_col0, #T_6bf2a_row15_col2 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_6bf2a_row7_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_6bf2a_row7_col2 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_6bf2a_row7_col4, #T_6bf2a_row10_col5, #T_6bf2a_row29_col0 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_6bf2a_row7_col5 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_6bf2a_row8_col5 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_6bf2a_row9_col0 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_6bf2a_row9_col1 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_6bf2a_row9_col2, #T_6bf2a_row15_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_6bf2a_row9_col4 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_6bf2a_row9_col5, #T_6bf2a_row22_col5 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_6bf2a_row10_col0, #T_6bf2a_row34_col3 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_6bf2a_row10_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_6bf2a_row10_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_6bf2a_row10_col3 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_6bf2a_row10_col4 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_6bf2a_row11_col0 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_6bf2a_row11_col2 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_6bf2a_row11_col3 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_6bf2a_row11_col5 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_6bf2a_row13_col0, #T_6bf2a_row14_col2, #T_6bf2a_row21_col0 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_6bf2a_row13_col2 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_6bf2a_row13_col4 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_6bf2a_row13_col5 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_6bf2a_row14_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_6bf2a_row14_col1 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_6bf2a_row14_col3, #T_6bf2a_row14_col5 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_6bf2a_row14_col4 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_6bf2a_row15_col0, #T_6bf2a_row29_col3, #T_6bf2a_row34_col5 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_6bf2a_row15_col3 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_6bf2a_row15_col4 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_6bf2a_row15_col5 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_6bf2a_row16_col3 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_6bf2a_row16_col5, #T_6bf2a_row26_col3, #T_6bf2a_row26_col5 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_6bf2a_row17_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_6bf2a_row17_col4 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_6bf2a_row18_col0 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_6bf2a_row18_col1, #T_6bf2a_row18_col2, #T_6bf2a_row18_col3, #T_6bf2a_row18_col5, #T_6bf2a_row28_col0, #T_6bf2a_row28_col1, #T_6bf2a_row28_col2, #T_6bf2a_row28_col3, #T_6bf2a_row28_col4, #T_6bf2a_row28_col5, #T_6bf2a_row30_col0, #T_6bf2a_row30_col1, #T_6bf2a_row30_col3, #T_6bf2a_row30_col4, #T_6bf2a_row31_col1, #T_6bf2a_row31_col2, #T_6bf2a_row31_col3, #T_6bf2a_row31_col4, #T_6bf2a_row31_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6bf2a_row18_col4 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_6bf2a_row19_col0, #T_6bf2a_row29_col4 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_6bf2a_row19_col1, #T_6bf2a_row32_col3 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_6bf2a_row19_col4 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_6bf2a_row19_col5 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_6bf2a_row20_col0, #T_6bf2a_row21_col5, #T_6bf2a_row22_col0, #T_6bf2a_row22_col1, #T_6bf2a_row31_col0 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_6bf2a_row20_col1 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_6bf2a_row20_col4, #T_6bf2a_row34_col1 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_6bf2a_row20_col5 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_6bf2a_row21_col2 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_6bf2a_row21_col3 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_6bf2a_row21_col4 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_6bf2a_row22_col3 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_6bf

# %% [markdown]
# ### by reg & topic

# %%
df.loc[df.reg =='cc'].groupby(['topic'])[bleus].mean().style.background_gradient(cmap='Blues', vmin=0, vmax=30)
# Out:
# <style type="text/css">
# #T_d73df_row0_col0 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_d73df_row0_col1, #T_d73df_row1_col1, #T_d73df_row19_col4 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_d73df_row0_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_d73df_row0_col3, #T_d73df_row2_col0, #T_d73df_row2_col1, #T_d73df_row5_col4, #T_d73df_row13_col1 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_d73df_row0_col4, #T_d73df_row13_col2, #T_d73df_row13_col3 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_d73df_row0_col5 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_d73df_row1_col0 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_d73df_row1_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_d73df_row1_col3 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_d73df_row1_col4 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_d73df_row1_col5, #T_d73df_row2_col3, #T_d73df_row5_col0, #T_d73df_row5_col1, #T_d73df_row5_col2, #T_d73df_row7_col3, #T_d73df_row8_col2, #T_d73df_row11_col4, #T_d73df_row13_col4, #T_d73df_row13_col5, #T_d73df_row18_col4, #T_d73df_row20_col0, #T_d73df_row20_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d73df_row2_col2, #T_d73df_row5_col5, #T_d73df_row12_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_d73df_row2_col4, #T_d73df_row9_col5, #T_d73df_row19_col0 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_d73df_row2_col5, #T_d73df_row11_col3 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_d73df_row3_col0 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_d73df_row3_col1, #T_d73df_row3_col3, #T_d73df_row15_col4 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_d73df_row3_col2, #T_d73df_row5_col3, #T_d73df_row7_col1, #T_d73df_row7_col2, #T_d73df_row11_col2, #T_d73df_row14_col3, #T_d73df_row14_col5, #T_d73df_row18_col3 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_d73df_row3_col4, #T_d73df_row19_col3 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_d73df_row3_col5, #T_d73df_row7_col4, #T_d73df_row14_col1, #T_d73df_row14_col4 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_d73df_row4_col0, #T_d73df_row8_col3 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_d73df_row4_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_d73df_row4_col2 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_d73df_row4_col3, #T_d73df_row8_col4, #T_d73df_row10_col5 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_d73df_row4_col4, #T_d73df_row6_col5, #T_d73df_row17_col0 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_d73df_row4_col5, #T_d73df_row15_col3 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_d73df_row6_col0 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_d73df_row6_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_d73df_row6_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_d73df_row6_col3 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_d73df_row6_col4 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_d73df_row7_col0 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_d73df_row7_col5 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_d73df_row8_col0, #T_d73df_row8_col1, #T_d73df_row20_col1 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_d73df_row8_col5, #T_d73df_row15_col1 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_d73df_row9_col0, #T_d73df_row17_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_d73df_row9_col1 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_d73df_row9_col2, #T_d73df_row9_col3, #T_d73df_row15_col2 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_d73df_row9_col4 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_d73df_row10_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_d73df_row10_col1 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_d73df_row10_col2 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_d73df_row10_col3, #T_d73df_row10_col4 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_d73df_row11_col0, #T_d73df_row11_col1, #T_d73df_row18_col1 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_d73df_row11_col5 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_d73df_row12_col0 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_d73df_row12_col2 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_d73df_row12_col3 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_d73df_row12_col4 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_d73df_row12_col5 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_d73df_row13_col0 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_d73df_row14_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_d73df_row14_col2 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_d73df_row15_col0, #T_d73df_row17_col4 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_d73df_row15_col5, #T_d73df_row18_col5 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_d73df_row16_col0 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_d73df_row16_col1 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_d73df_row16_col2 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_d73df_row16_col3 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_d73df_row16_col4 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_d73df_row16_col5 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_d73df_row17_col1 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_d73df_row17_col3 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_d73df_row17_col5 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_d73df_row18_col0, #T_d73df_row18_col2 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_d73df_row19_col1, #T_d73df_row19_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_d73df_row19_col5 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_d73df_row20_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_d73df_row20_col4 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_d73df_row20_col5 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# </style>
# <table id="T_d73df_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >bleu_spm8000</th>
#       <th class="col_heading level0 col1" >bleu_msp8000</th>
#       <th class="col_heading level0 col2" >bleu_cmsp8000</th>
#       <th class="col_heading level0 col3" >bleu_spm16000</th>
#       <th class="col_heading level0 col4" >bleu_msp16000</th>
#       <th class="col_heading level0 col5" >bleu_cmsp16000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d73df_level0_row0" class="row_heading level0 row0" >가족</th>
#       <td id="T_d73df_row0_col0" class="data row0 col0" >10.278340</td>
#       <td id="T_d73df_row0_col1" class="data row0 col1" >7.830277</td>
#       <td id="T_d73df_row0_col2" class="data row0 col2" >8.255532</td>
#       <td id="T_d73df_row0_col3" class="data row0 col3" >10.864892</td>
#       <td id="T_d73df_row0_col4" class="data row0 col4" >9.136248</td>
#       <td id="T_d73df_row0_col5" class="data row0 col5" >6.804838</td>
#     </tr>
#     <tr>
#       <th id="T_d73df_level0_row1" class="row_heading level0 row1" >게임</th>
#       <td id="T_d73df_row1_col0" class="data row1 col0" >8.042268</td>
#       <td id="T_d73df_row1_col1" class="data row1 col1" >7.812895</td>
#       <td id="T_d73df_row1_col2" class="data row1 col2" >9.291150</td>
#       <td id="T_d73df_row1_col3" class="data row1 col3" >7.433762</td>
#       <td id="T_d73df_row1_col4" class="data row1 col4" >8.201060</td>
#       <td id="T_d73df_row1_col5" class="data row1 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d73df_level0_row2" class="row_heading level0 row2" >계절</

# %%
df.loc[:,['sat_eval1','acc_eval1','sat_eval2','acc_eval2','sat_eval3','acc_eval4']] = np.nan
export_df =df.loc[:,['eng','pred_spm','sat_eval1','acc_eval1','pred_msp','sat_eval2','acc_eval2','pred_cmsp','sat_eval3','acc_eval4']]

# %%
# export_df.head()

# %%
eval_files = os.listdir(path + '/evaluation')

# %%
df_ev = pd.read_excel(path + '/evaluation/' + eval_files[0], index_col = 'Unnamed: 0')

# %%
for i,file in enumerate(eval_files[1:]) :
    i +=1
    use_cols=['Unnamed: 0','sat_eval1', 'acc_eval1','sat_eval2','acc_eval2','sat_eval3', 'acc_eval4']
    df_ev_temp = pd.read_excel(path + '/evaluation/' + file, usecols = use_cols, index_col = 'Unnamed: 0')
    df_ev_temp.rename(columns = {'sat_eval1': f'sat_eval1_{i}', 'acc_eval1':f'acc_eval1_{i}', 'sat_eval2': f'sat_eval2_{i}', 'acc_eval2':f'acc_eval2_{i}','sat_eval3': f'sat_eval3_{i}', 'acc_eval4':f'acc_eval3_{i}'},inplace=True)
    df_ev = pd.merge(df_ev, df_ev_temp, right_index =True, left_index=True)

# %%
df_ev.columns
# Out:
# Index(['eng', 'pred_spm', 'sat_eval1', 'acc_eval1', 'pred_msp', 'sat_eval2',
#        'acc_eval2', 'pred_cmsp', 'sat_eval3', 'acc_eval4', 'sat_eval1_1',
#        'acc_eval1_1', 'sat_eval2_1', 'acc_eval2_1', 'sat_eval3_1',
#        'acc_eval3_1', 'sat_eval1_2', 'acc_eval1_2', 'sat_eval2_2',
#        'acc_eval2_2', 'sat_eval3_2', 'acc_eval3_2', 'sat_eval1_3',
#        'acc_eval1_3', 'sat_eval2_3', 'acc_eval2_3', 'sat_eval3_3',
#        'acc_eval3_3', 'sat_eval1_4', 'acc_eval1_4', 'sat_eval2_4',
#        'acc_eval2_4', 'sat_eval3_4', 'acc_eval3_4'],
#       dtype='object')

# %%
new_col_order =['eng', 
'pred_spm', 'sat_eval1', 'sat_eval1_1','sat_eval1_2','sat_eval1_3','sat_eval1_4', 
            'acc_eval1', 'acc_eval1_1','acc_eval1_2','acc_eval1_3','acc_eval1_4',
'pred_msp', 'sat_eval2', 'sat_eval2_1','sat_eval2_2','sat_eval2_3','sat_eval2_4', 
            'acc_eval2', 'acc_eval2_1','acc_eval2_2','acc_eval2_3','acc_eval2_4',
'pred_cmsp','sat_eval3', 'sat_eval3_1','sat_eval3_2','sat_eval3_3','sat_eval3_4',  
            'acc_eval4', 'acc_eval3_1','acc_eval3_2','acc_eval3_3','acc_eval3_4']

# %%
df_ev['spm_sat_mean'] = df_ev[['sat_eval1', 'sat_eval1_1','sat_eval1_2','sat_eval1_3','sat_eval1_4']].mean(axis=1)
df_ev['spm_acc_mean'] = df_ev[['acc_eval1', 'acc_eval1_1','acc_eval1_2','acc_eval1_3','acc_eval1_4']].mean(axis=1)
df_ev['msp_sat_mean'] = df_ev[['sat_eval2', 'sat_eval2_1','sat_eval2_2','sat_eval2_3','sat_eval2_4']].mean(axis=1)
df_ev['msp_acc_mean'] = df_ev[['acc_eval2', 'acc_eval2_1','acc_eval2_2','acc_eval2_3','acc_eval2_4']].mean(axis=1)
df_ev['cmsp_sat_mean'] = df_ev[['sat_eval3', 'sat_eval3_1','sat_eval3_2','sat_eval3_3','sat_eval3_4']].mean(axis=1)
df_ev['cmsp_acc_mean'] = df_ev[['acc_eval4', 'acc_eval3_1','acc_eval3_2','acc_eval3_3','acc_eval3_4']].mean(axis=1)

# %%
final_reorder = ['pred_spm',
'spm_sat_mean','spm_acc_mean',
'pred_msp',
'msp_sat_mean','msp_acc_mean',
'pred_cmsp',
'cmsp_sat_mean','cmsp_acc_mean',]

final_reorder_only_values = [
'spm_sat_mean','spm_acc_mean',
'msp_sat_mean','msp_acc_mean',
'cmsp_sat_mean','cmsp_acc_mean',]

# %%
final_df = pd.merge(df, df_ev[final_reorder_only_values], right_index=True, left_index=True)

# %%
final_df.columns
# Out:
# Index(['reg', 'topic', 'eng', 'dial', 'pred_spm', 'pred_msp', 'pred_cmsp',
#        'bleu_spm', 'bleu_msp', 'bleu_cmsp', 'tok_len', 'tok_cat', 'sat_eval1',
#        'acc_eval1', 'sat_eval2', 'acc_eval2', 'sat_eval3', 'acc_eval4',
#        'spm_sat_mean', 'spm_acc_mean', 'msp_sat_mean', 'msp_acc_mean',
#        'cmsp_sat_mean', 'cmsp_acc_mean'],
#       dtype='object')

# %%
tokenizers = ['spm','msp','cmsp']
eval_1 = final_df.loc[:,[f'bleu_{tokenizers[0]}',f'{tokenizers[0]}_sat_mean', f'{tokenizers[0]}_acc_mean']].agg('mean').to_frame().transpose().rename(index={0:tokenizers[0]},columns={f'bleu_{tokenizers[0]}':'bleu',f'{tokenizers[0]}_sat_mean':'sat_qual_mean',f'{tokenizers[0]}_acc_mean':'acc_qual_mean'})
for tokenizer in tokenizers[1:] :
    temp = final_df.loc[:,[f'bleu_{tokenizer}',f'{tokenizer}_sat_mean', f'{tokenizer}_acc_mean']].agg('mean').to_frame().transpose().rename(index={0:tokenizer},columns={f'bleu_{tokenizer}':'bleu',f'{tokenizer}_sat_mean':'sat_qual_mean',f'{tokenizer}_acc_mean':'acc_qual_mean'})
    eval_1 = pd.concat([eval_1,temp],axis=0)

# %%
eval_1
# Out:
#            bleu  sat_qual_mean  acc_qual_mean
# spm   14.060324         3.1120         3.0040
# msp   15.096059         3.0096         2.9232
# cmsp  14.276615         3.1792         3.1360

# %%
qual = ['spm_sat_mean', 'msp_sat_mean', 'cmsp_sat_mean','spm_acc_mean','msp_acc_mean',
        'cmsp_acc_mean']
final_df.groupby('reg')[qual].mean().style.background_gradient(cmap='Blues', vmin=2.5, vmax=4)
# Out:
# <style type="text/css">
# #T_588f2_row0_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_588f2_row0_col1 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_588f2_row0_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_588f2_row0_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_588f2_row0_col4, #T_588f2_row4_col0 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_588f2_row0_col5 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_588f2_row1_col0 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_588f2_row1_col1 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_588f2_row1_col2 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_588f2_row1_col3 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_588f2_row1_col4, #T_588f2_row3_col1 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_588f2_row1_col5 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_588f2_row2_col0, #T_588f2_row4_col4 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_588f2_row2_col1 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_588f2_row2_col2, #T_588f2_row2_col5 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_588f2_row2_col3 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_588f2_row2_col4 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_588f2_row3_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_588f2_row3_col2 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_588f2_row3_col3 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_588f2_row3_col4 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_588f2_row3_col5 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_588f2_row4_col1 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_588f2_row4_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_588f2_row4_col3 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_588f2_row4_col5 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# </style>
# <table id="T_588f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_588f2_level0_col0" class="col_heading level0 col0" >spm_sat_mean</th>
#       <th id="T_588f2_level0_col1" class="col_heading level0 col1" >msp_sat_mean</th>
#       <th id="T_588f2_level0_col2" class="col_heading level0 col2" >cmsp_sat_mean</th>
#       <th id="T_588f2_level0_col3" class="col_heading level0 col3" >spm_acc_mean</th>
#       <th id="T_588f2_level0_col4" class="col_heading level0 col4" >msp_acc_mean</th>
#       <th id="T_588f2_level0_col5" class="col_heading level0 col5" >cmsp_acc_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >reg</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_588f2_level0_row0" class="row_heading level0 row0" >cc</th>
#       <td id="T_588f2_row0_col0" class="data row0 col0" >3.128000</td>
#       <td id="T_588f2_row0_col1" class="data row0 col1" >3.024000</td>
#       <td id="T_588f2_row0_col2" class="data row0 col2" >3.200000</td>
#       <td id="T_588f2_row0_col3" class="data row0 col3" >2.976000</td>
#       <td id="T_588f2_row0_col4" class="data row0 col4" >2.944000</td>
#       <td id="T_588f2_row0_col5" class="data row0 col5" >3.272000</td>
#     </tr>
#     <tr>
#       <th id="T_588f2_level0_row1" class="row_heading level0 row1" >gs</th>
#       <td id="T_588f2_row1_col0" class="data row1 col0" >3.352000</td>
#       <td id="T_588f2_row1_col1" class="data row1 col1" >3.168000</td>
#       <td id="T_588f2_row1_col2" class="data row1 col2" >3.472000</td>
#       <td id="T_588f2_row1_col3" class="data row1 col3" >3.292000</td>
#       <td id="T_588f2_row1_col4" class="data row1 col4" >3.088000</td>
#       <td id="T_588f2_row1_col5" class="data row1 col5" >3.464000</td>
#     </tr>
#     <tr>
#       <th id="T_588f2_level0_row2" class="row_heading level0 row2" >jd</th>
#       <td id="T_588f2_row2_col0" class="data row2 col0" >3.016000</td>
#       <td id="T_588f2_row2_col1" class="data row2 col1" >2.712000</td>
#       <td id="T_588f2_row2_col2" class="data row2 col2" >3.144000</td>
#       <td id="T_588f2_row2_col3" class="data row2 col3" >2.904000</td>
#       <td id="T_588f2_row2_col4" class="data row2 col4" >2.616000</td>
#       <td id="T_588f2_row2_col5" class="data row2 col5" >3.144000</td>
#     </tr>
#     <tr>
#       <th id="T_588f2_level0_row3" class="row_heading level0 row3" >jj</th>
#       <td id="T_588f2_row3_col0" class="data row3 col0" >3.120000</td>
#       <td id="T_588f2_row3_col1" class="data row3 col1" >3.088000</td>
#       <td id="T_588f2_row3_col2" class="data row3 col2" >3.080000</td>
#       <td id="T_588f2_row3_col3" class="data row3 col3" >2.912000</td>
#       <td id="T_588f2_row3_col4" class="data row3 col4" >2.952000</td>
#       <td id="T_588f2_row3_col5" class="data row3 col5" >3.032000</td>
#     </tr>
#     <tr>
#       <th id="T_588f2_level0_row4" class="row_heading level0 row4" >kw</th>
#       <td id="T_588f2_row4_col0" class="data row4 col0" >2.944000</td>
#       <td id="T_588f2_row4_col1" class="data row4 col1" >3.056000</td>
#       <td id="T_588f2_row4_col2" class="data row4 col2" >3.000000</td>
#       <td id="T_588f2_row4_col3" class="data row4 col3" >2.936000</td>
#       <td id="T_588f2_row4_col4" class="data row4 col4" >3.016000</td>
#       <td id="T_588f2_row4_col5" class="data row4 col5" >2.768000</td>
#     </tr>
#   </tbody>
# </table>

# %%
final_df.groupby('reg')[bleus].mean().style.background_gradient(cmap='Blues', vmin=0, vmax=20)
# Out:
# <style type="text/css">
# #T_e7fac_row0_col0 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_e7fac_row0_col1 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_e7fac_row0_col2 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_e7fac_row1_col0 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_e7fac_row1_col1 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_e7fac_row1_col2 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_e7fac_row2_col0 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_e7fac_row2_col1 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_e7fac_row2_col2 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_e7fac_row3_col0 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_e7fac_row3_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e7fac_row3_col2 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_e7fac_row4_col0 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_e7fac_row4_col1 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_e7fac_row4_col2 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e7fac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7fac_level0_col0" class="col_heading level0 col0" >bleu_spm</th>
#       <th id="T_e7fac_level0_col1" class="col_heading level0 col1" >bleu_msp</th>
#       <th id="T_e7fac_level0_col2" class="col_heading level0 col2" >bleu_cmsp</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >reg</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7fac_level0_row0" class="row_heading level0 row0" >cc</th>
#       <td id="T_e7fac_row0_col0" class="data row0 col0" >10.823839</td>
#       <td id="T_e7fac_row0_col1" class="data row0 col1" >10.521975</td>
#       <td id="T_e7fac_row0_col2" class="data row0 col2" >10.989728</td>
#     </tr>
#     <tr>
#       <th id="T_e7fac_level0_row1" class="row_heading level0 row1" >gs</th>
#       <td id="T_e7fac_row1_col0" class="data row1 col0" >17.369254</td>
#       <td id="T_e7fac_row1_col1" class="data row1 col1" >15.775978</td>
#       <td id="T_e7fac_row1_col2" class="data row1 col2" >19.696434</td>
#     </tr>
#     <tr>
#       <th id="T_e7fac_level0_row2" class="row_heading level0 row2" >jd</th>
#       <td id="T_e7fac_row2_col0" class="data row2 col0" >10.442326</td>
#       <td id="T_e7fac_row2_col1" class="data row2 col1" >11.920957</td>
#       <td id="T_e7fac_row2_col2" class="data row2 col2" >13.424255</td>
#     </tr>
#     <tr>
#       <th id="T_e7fac_level0_row3" class="row_heading level0 row3" >jj</th>
#       <td id="T_e7fac_row3_col0" class="data row3 col0" >18.520314</td>
#       <td id="T_e7fac_row3_col1" class="data row3 col1" >20.342869</td>
#       <td id="T_e7fac_row3_col2" class="data row3 col2" >14.475589</td>
#     </tr>
#     <tr>
#       <th id="T_e7fac_level0_row4" class="row_heading level0 row4" >kw</th>
#       <td id="T_e7fac_row4_col0" class="data row4 col0" >13.145886</td>
#       <td id="T_e7fac_row4_col1" class="data row4 col1" >16.918515</td>
#       <td id="T_e7fac_row4_col2" class="data row4 col2" >12.797071</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.columns.str.contains('pred')
# Out:
# array([False, False, False, False,  True,  True,  True, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
final_df.loc[(final_df.bleu_spm > final_df.bleu_cmsp),['eng','pred_spm','bleu_spm','pred_msp','bleu_msp','pred_cmsp','bleu_cmsp']]
# Out:
#                                                         eng  \
# 230919.0  <jd> These days when it comes to historical dr...
# 8596.0    <jd> By about ten o'clock or eleven o'clock, y...
# 6353.0    <jd> Well, if you look at people who are very ...
# 772660.0  <jd> There are so many restrictions on the par...
# 4190.0    <jd> Or you don't let go of what you like to d...
# 906848.0           <jj> Will it be dying without that salt?
# 259192.0                 <jj> Oh, I'm gonna run some tests.
# 808387.0                              <jj> Then in the past
# 254952.0           <jj> I'm just saying, "What's going on?"
# 204242.0                            <jj> It was really good
# 684233.0    <jj> I solicited you to buy it before you leave
# 868585.0                  <jj> But please wear a mask well.
# 162561.0  <jj> I think it's gonna be fun. I'm gonna take...
# 776452.0  <jj> Isnt it Japanese words that means Is it j...
# 156607.0           <jj> And now you're just drinking water.
# 710991.0  <jj> Its a lot of money after tax two hundred ...
# 266189.0                   <jj> He's so thin. He's so thin.
# 162936.0            <jj> I raised all the babies, and here.
# 790141.0  <cc> And then you have to get a customer at th...
# 113633.0                    <cc> I think it'll be more fun.
# 781989.0  <cc> He doesnt say that he doesnt have to do i...
# 896135.0                    <cc> In b but I dont like meat.
# 616604.0  <cc> But even though I woke up my husband was ...
# 765685.0  <cc> I saw that it took a little longer to fin...
# 97945.0          <cc> I think everyone has a good mind, so.
# 719816.0  <cc> If you break your back you dont know wher...
# 855826.0  <cc> So the commander in the Navy dispatches b...
# 650865.0  <gs> So if companies made different announceme...
# 937736.0  <gs> So the perpetrator you said what you woul...
# 772807.0  <gs> So I dont like it but there are many case...
# 798567.0                  <gs> He likes eating a little bit
# 115361.0  <gs> Anyway, I think I went to our school twic...
# 847421.0     <gs> What do you mean by that design is unique
# 945227.0  <gs> I think so because he isnt even a helper ...
# 122353.0  <gs> It's been a little bit of a struggle, but...
# 869009.0  <gs> My back was weak and I had surgery and tr...
# 532498.0                               <kw> I'm not eating.
# 884077.0             <kw> I honestly dont believe it today.
# 297199.0           <kw> I like the hair of the prosthetist.
# 324339.0  <kw> I tried to eat the chicken, but now I'm t...
# 514347.0                               <kw> Have I changed?
# 332420.0  <kw> To be honest, I got a present from the Pr...
# 781989.0                             이케 안 해도 된다구 안 하는데유   8.558153
# 896135.0                          고기는 아이오 고기는 근데 괴기는 별로  13.832544
# 616604.0                   데 남편이 데지만 남편이 깨서도 그냥 누워 있는 거   0.000000
# 765685.0        한 편 한 편을 한 번씩 찾다가 반찬을 찾으라구 쫌 더 시간이 가더라고  11.858108
# 97945.0                              다 좋은 맘이 있는 거 같애 긍까   9.120159
# 719816.0        허리를  ⁇ 으면은 밑이 가서 설거지할 때도 몰르구 하튼 간이 너무 좋   8.255532
# 855826.0           긍까 그 해군 분비시전은 근데 전형 파전은 그냥 파워 워타워 그냥   5.625356
# 650865.0                 회사가 다른 기업들은 그런 거를 쫌 알께 됐다꼬 카면은   9.757125
# 937736.0                   그꼬 가해자느 니느 뭐 하겠노 근꼬 수사까증 수사가  12.862535
# 772807.0     너무 싫어하는데 혼대이 선택할 수 있느 경우가 많은 거야 그서 쫌 그래 갖꼬  15.229307
# 798567.0                                  쫌 먹느 걸 좋아해가주꼬  29.588031
# 115361.0      하튼 우리 두 번이나 중학교 때도 우리 아즈망이 한 번씩 학교 갔던 거 같  13.856598
# 847421.0                               그 디자인마 해도 무슨 말이노   0.000000
# 945227.0                 그 사람은 그래 생각하는데 내한텐 내 인생에 일생이라도  13.183577
# 122353.0                   쫌 고생을 많이 캤는데 좀  ⁇ 께 말하꼬 싶은데.  10.855926
# 869009.0                        허리도 아프꼬 수술도 쫌 하꼬 처신도 있었  10.404965
# 532498.0                                     밥을 먹지 않는 근   0.000000
# 884077.0                                 오날에는 솔직하니 믿지 않   0.000000
# 297199.0                             미디어 시력을 좋아한 간직한 모십   0.000000
# 324339.0         치킨을 먹는 것을 좋아하지만 이제 치킨을 먹는 양육을 타는 거이 아니   9.789106
# 514347.0                                     그~ 아이엔에프피가   0.000000
# 332420.0                          어제 소직히 회장님한테 당장 대대장한테  16.106527
# 884006.0                             역부러 그래 말을 하는 거야 니?  19.205613
# 307751.0             야 저 할머이 야 니 그 할머이 야 다 한통한 거야 이 집에.   9.952568
# 594960.0               그 많은 사램들을 위해서 죽어가는 일에두 아문 생각으롤 해   0.000000
# 297204.0                                    그 말은 하기가 그렇   0.000000

# %%
final_df.loc[(final_df.spm_sat_mean > final_df.cmsp_sat_mean),['eng','pred_spm','bleu_spm','pred_msp','bleu_msp','pred_cmsp','bleu_cmsp']]
# Out:
#                                                         eng  \
# 53200.0                              <jd> What's a startup?
# 723370.0          <jd> I wink Ill study a little like this.
# 8596.0    <jd> By about ten o'clock or eleven o'clock, y...
# 286387.0                                 <jd> Itas selected
# 6353.0    <jd> Well, if you look at people who are very ...
# 16040.0              <jd> I wish I could get back together.
# 772660.0  <jd> There are so many restrictions on the par...
# 897956.0  <jd> I went there Hoian but I cant remember it...
# 22092.0   <jd> I'm going. I'm scared. I need to hear som...
# 41305.0   <jd> I've got it in the early 200 millionth ce...
# 66707.0   <jd> And now I'm going home and I don't have a...
# 906848.0           <jj> Will it be dying without that salt?
# 922232.0     <jj> Isnt it so fun to watch things like this?
# 248793.0  <jj> He's down. He's got street lights. He's g...
# 204242.0                            <jj> It was really good
# 684233.0    <jj> I solicited you to buy it before you leave
# 868585.0                  <jj> But please wear a mask well.
# 158604.0                    <jj> So you're gonna let it go?
# 776452.0  <jj> Isnt it Japanese words that means Is it j...
# 156607.0           <jj> And now you're just drinking water.
# 177256.0                                   <jj> That's off.
# 710991.0  <jj> Its a lot of money after tax two hundred ...
# 266189.0                   <jj> He's so thin. He's so thin.
# 134642.0                          <jj> Are you alone, then?
# 862775.0  <cc> I think I screamed a lot of cash especial...
# 98835.0   <cc> And now, in the summer, you're going to g...
# 795084.0  <cc> Ill have to find out a little bit today W...
# 113633.0                    <cc> I think it'll be more fun.
# 768126.0  <cc> What I heard from our seniors was that th...
# 921090.0  <cc> Ifou you bought a lot of cute babies and ...
# 616604.0  <cc> But even though I woke up my husband was ...
# 765685.0  <cc> I saw that it took a little longer to fin...
# 644413.0  <cc> When you look at Tereby or something like...
# 719816.0  <cc> If you break your back you dont know wher...
# 684916.0  <gs> So all the clothes are a little bit coord...
# 679063.0  <gs> So how long does the US government print ...
# 847421.0     <gs> What do you mean by that design is unique
# 945227.0  <gs> I think so because he isnt even a helper ...
# 803148.0  <gs> Isnt it time to give a little gift to peo...
# 869009.0  <gs> My back was weak and I had surgery and tr...
# 868799.0  <gs> What should I do after I put green onion ...
# 532498.0                               <kw> I'm not eating.
# 884077.0             <kw> I honestly dont believe it today.
# 551581.0   <kw> You're still in the game today, aren't you?
# 324339.0  <kw> I tried to eat the chicken, but now I'm t...
# 514347.0                               <kw> Have I changed?
# 517303.0  <kw> I'm scratching my suit because my back's ...
# 332420.0  <kw> To be honest, I got a present from the Pr...
# 406028.0          <kw> That's why I have to give up on you.
# 185484.0  <kw> The recommended daily intake of vitamin s...
# 307751.0  <kw> Hey, Grandma, there's all that's left ove...
# 580318.0        <kw> That's why you've been running for me?
# 594960.0  <kw> Do you have any idea how many people die ...
# 297204.0                            <kw> Even you say that.
#
#                                                    pred_spm   bleu_spm  \
# 53200.0                                          스타트업 뭐시기냐?   0.000000
# 723370.0                        쫌 이케 공부도 쫌 공부도 쫌 하고 이런 편입니다  12.185174
# 8596.0                        시계 열 시 요법이나 열한 시나 깨는 깨소 이런 거.  13.843886
# 286387.0                                              뽑혀가지고   0.000000
# 6353.0                  아주 잘 빨아 가는 디 보면 우리 동서들 진짜 똑같애브러 언니.   8.201060
# 16040.0                                  아이쇼핑도 다시 하면 좋을 텐디.   0.000000
# 772660.0                     지원을 받칠 수 있는 이런 제한 제한이 너무 많아 가꾸  15.352598
# 897956.0                     그~ 호주로 갔는디 지나놓고 지낸 뒤에 생각나제 모다네   9.757125
# 22092.0                   갈망 이드끼도 되게 뭔가 뭔가 뭔가 뭔가 듣기 시작이 필요혀   0.000000
# 41305.0                            아이 아이 조기 백구십구 세기를 초반에 땄다   0.000000
# 66707.0                 집이서 인제 아이모 집에 가는 것도 좋아하고잉 아이모트도 있고.  10.855926
# 906848.0                                       소금 안 깨고 죽으켜?  19.672556
# 922232.0                                 이런 거 보멍 너무 재미져가지고?  23.263473
# 679063.0         정부에서 돈을 얼매나 마이 주는데 데뷔하꼬 카면은 또 얼마짜리를 사   0.000000
# 847421.0                          그~ 뭐래이 하노 그 디자인이 특이한  10.845758
# 945227.0                내 인생이 그니께 내 인생에 있느 사람이서도 도움이 안  13.664845
# 803148.0               주위 사람들한테 쫌 선물 줄 때가 아인가 이런 생각도 들   9.822848
# 869009.0                   허리가 약하꼬 막 애가 막 이르케 막 이르케 수술  11.490720
# 868799.0     아이 아이 아이 아이 아이 아이 아이 아이 아이 아이 아이 아이 아이 아이   0.000000
# 532498.0                                    먹지 않은 밥 먹지   0.000000
# 884077.0                                오늘에는 소직히 안 믿어.  30.789214
# 551581.0                         오놀두 게임에서는 되레 다시 겡기 안하  19.304870
# 324339.0                닭 먹을려고 했지만 지굼은 버스 타는 것두 맛있어래이.  12.185174
# 514347.0                                    아이언맨이 바뀌었나   0.000000
# 517303.0                            허리깽이가 뒤통새이를 뒤죽박죽으이   0.000000
# 332420.0                   으제 대통령 선물 받은 거 대통령 슨상님 솔직히요  16.515822
# 406028.0                         그른 사램이라두 니가 준 게 나으가 왜   0.000000
# 185484.0                  비타민씨의 할루 섭취 권장량은 어른의 경우에 있사.  40.564972
# 307751.0                     할어머 저느마 다 두고 다 남은 거야 이집아.  14.490696
# 580318.0                              니가 날 뛰다가 왜 날 뛰냐?  16.149931
# 594960.0                          스트레스로 사램 죽을지 얼매나 많은데  15.681966
# 297204.0                                    그른 말까지 해라.  24.880469
#
#                                               pred_cmsp  bleu_cmsp
# 53200.0                                       스타트업 뭐시냐?   0.000000
# 723370.0                           좋은 시디야 같은 거를 쫌 공부를 했  19.205613
# 8596.0                한 열 시 정도에 한 열 시 정도 되면 한 시점 열 시 되면  10.694730
# 286387.0                                      선택을 해 가지고   0.000000
# 6353.0    진짜 애기들이 애기를 닮아갖고 먹는 애기들이 똑같은 거 보믄은 나도 우리 언니가.   8.182478
# 16040.0                              아이 돌아오게 되면 좋게 좋게 좋   0.000000
# 772660.0                           부품에 브러갓고 제약이 너무 많애갖고  10.796528
# 897956.0                  가서 가봤는디 사년이 지나놓고 나서 기억이 안 나는디  19.660764
# 22092.0                 가는 거 좋은 거는 에이아이가 너무 무서워가지고 가는 거   0.000000
# 41305.0                                초기 초에서 초기에서 구했어.   0.000000
# 66707.0                 그러고 이제 집에 가서 이제 아이쇼핑이랑 이런 부분이 없  15.420263
# 906848.0                            그 소금 안 찍엉 죽어질 거 아니?  18.277761
# 922232.0                         이런 거 보는 거 너무 재미 없지 아네?  53.077122
# 248793.0              그 사람 거리를 거리 두고 길바닥을 해 부난 이 그 불을 펴   0.000000
# 204242.0                                          잘도 좋안   0.000000
# 684233.0                                두고보게 사켄 한게 아니라예   0.000000
# 868585.0                                      게 잘 끼랜. 게  14.209029
# 158604.0                                        갱 재워주나?  34.787006
# 776452.0                      그 말이 이 말이 이 말이 그냥 육지 말이주게  12.185174
# 156607.0                             이제 너가 너가 그냥 물 먹는 거   0.000000
# 177256.0                                       그 저 이파리.   0.000000
# 710991.0                         이백 구십 이도 넘고 한 번 타고 이 돈  12.185174
# 266189.0                            야이가 워낙 얇게  ⁇ . 게난 이   0.000000
# 134642.0                                       너 혼자? 그럼  30.326533
# 862775.0                  캐시를 많이 사 주구 싶은 맨 처음엔 캐시미어로 많이   9.291150
# 98835.0                     여름이 이제 여름이 가서 해붓가로 갈 거 아니여.  12.185174
# 795084.0                오늘은 쫌 적합하게 찾아봐야지 적합한 적합한 적이 요즘이  13.888095
# 113633.0                              더 재밌게 생각허는 게 재밌어.  22.957488
# 768126.0       우리 선배들이 어땠드라 그때 그때 적에는 고지서부를 하구 있었는디 갑자키  13.910598
# 921090.0         애기덜 많이 사서 봤는디 이런 거 먹는 거를 좋아한다구 하시드라구요?   9.705947
# 616604.0                   데 남편이 데지만 남편이 깨서도 그냥 누워 있는 거   0.000000
# 765685.0        한 편 한 편을 한 번씩 찾다가 반찬을 찾으라구 쫌 더 시간이 가더라고  11.858108
# 644413.0           테레비나 이런 거 보면 커플링이나 커플들이 같이 빨간 옷을 입게?  12.533477
# 719816.0        허리를  ⁇ 으면은 밑이 가서 설거지할 때도 몰르구 하튼 간이 너무 좋   8.255532
# 684916.0                        그서 옷이 전부 대이 쫌 조율이 많이 되꼬  14.575161
# 679063.0             인턴지를 인턴지를 인대이 얼매나 돈을 주는지를 대신 샀느 거느   7.812895
# 847421.0                               그 디자인마 해도 무슨 말이노   0.000000
# 945227.0                 그 사람은 그래 생각하는데 내한텐 내 인생에 일생이라도  13.183577
# 803148.0                     주변 사람들한테도 쫌 선물을 할 때가 되지를 않  19.660764
# 869009.0                        허리도 아프꼬 수술도 쫌 하꼬 처신도 있었  10.404965
# 868799.0                            파랑색 파랑 그담에 뭐 해야 되노?  25.276008
# 532498.0                                     밥을 먹지 않는 근   0.000000
# 884077.0                                 오날에는 솔직하니 믿지 않   0.000000
# 551581.0                              상구두 시합에서 오놀은 끝났어?  24.028114
# 324339.0         치킨을 먹는 것을 좋아하지만 이제 치킨을 먹는 양육을 타는 거이 아니   9.789106
# 514347.0                                     그~ 아이엔에프피가   0.000000
# 517303.0                        등을 뒤집어서 내 등골을 긁은 것을 긁었다   0.000000
# 332420.0                          어제 소직히 회장님한테 당장 대대장한테  16.106527
# 406028.0                         그 이에게 왜 퍽데기를 해야 되는 것이냐   0.000000
# 185484.0                  비타민씨의 실비를 섭취하는 것은 어른의 경우에 밀집돼  12.136306
# 307751.0             야 저 할머이 야 니 그 할머이 야 다 한통한 거야 이 집에.   9.952568
# 580318.0                          그 왜사 내가 니한테  ⁇ 이고 있었어   0.000000
# 594960.0               그 많은 사램들을 위해서 죽어가는 일에두 아문 생각으롤 해   0.000000
# 297204.0                                    그 말은 하기가 그렇   0.000000

# %%
# export_df.to_excel('saturi_evaluation_0328.xlsx')

# %%
import seaborn as sns
fig = plt.figure()
ax = sns.scatterplot(data = eval_1, x='acc_qual_mean',y='sat_qual_mean', size='bleu',sizes=(20,200),legend=True)
for i in range(len(eval_1)) :
    t = 1
    if i == 2 :
        t *= -1
    ax.text(eval_1['acc_qual_mean'][i]+0.005 *t ,eval_1['sat_qual_mean'][i] +0.009*t , eval_1.index[i])
