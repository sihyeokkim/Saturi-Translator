# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os
import glob
import shutil

# %%
file_path = os.getenv('HOME') + '/aiffel/aiffelthon/'
# os.mkdir(file_path + '/spm')

# %%
df = pd.read_csv(file_path + '/final/Train_set_data.csv')

# %%
from konlpy.tag import Mecab
mecab = Mecab()

# %%
import sentencepiece as spm
def generate_tokenizer(corpus, vocab_size, lang="en", pad_id=0, bos_id=1, eos_id=2, unk_id=3):

    temp_file = os.getenv('HOME') + f'/aiffel/aiffelthon/spm/corpus_{lang}.txt'     # corpus를 받아 txt파일로 저장
    
    with open(temp_file, 'w') as f:
        for row in corpus:
            f.write(str(row) + '\n')
    
    # Sentencepiece를 이용해 
    spm.SentencePieceTrainer.Train(
        f'--input={temp_file} --model_type=bpe --pad_id={pad_id} --bos_id={bos_id} --eos_id={eos_id} \
        --unk_id={unk_id} --model_prefix=spm_{lang}_r1 --vocab_size={vocab_size} \
        --user_defined_symbols=<jj>,<jd>,<gs>,<cc>,<kw>,@이름,@상호 --remove_extra_whitespaces=false'   # model_r1
    )
    
    tokenizer = spm.SentencePieceProcessor()
    tokenizer.Load(f'spm_{lang}_r1.model') # model_r1

    return tokenizer

# %%
regs = ['kw','jj','cc','gs','jd']

# %%
spm_corpus = df.loc[df['reg'] == regs[0]].sample(frac=1).copy()[:100000]

for reg in regs[1:] :
    temp_corpus = df.loc[df['reg'] == reg].copy()[:100000]
    spm_corpus = pd.concat([spm_corpus,temp_corpus],axis=0)
len(spm_corpus)
# Out:
# 500000

# %%
train_corpus = spm_corpus['dial'].values
train_corpus[:5]
# Out:
# array(['오후가 되자 싸락눈은 목화솜처럼 부드러운 박석눈으로 변했다.',
#        '그래도 병원에도 안 가 보고 그~ 돈 벌러 댕기느라고', '뭐 얻어처묵을끼 있다꼬 여 오노?',
#        '내가 그 친구한테 철썩 같이 약속을 했어요.글구 솔직히 상품 본부장이 그 정도 인사권도 못 갖나?',
#        '아이고매 어엽다.'], dtype=object)

# %%
# tokenizer = generate_tokenizer(train_corpus, 8011, 'dial')
tokenizer = spm.SentencePieceProcessor()
tokenizer.Load('spm_dial_r1.model')
# Out:
# True

# %%
df['text'][:10].apply(tokenizer.encode_as_pieces)
# Out:
# 0                               [▁생각이, ▁쪼금씩, ▁바뀌, 더라고]
# 1         [▁어, ▁알, 겠, 는가, ▁외국, 인들이, ▁그래도, ▁잘, ▁적응, 하고]
# 2    [▁아, 으, ▁갑자기, ▁예전에, ▁맹, 장, ▁뜯, 은, ▁게, ▁생각, 난다, .]
# 3    [▁보면은, ▁조금, ▁품, 위, ▁있게, ▁나이, ▁들어가, 야, ▁되겠, 단, ...
# 4      [▁약간, ▁조금, ▁약간, ▁맛이, ▁쪼끔, ▁거시기, ▁하긴, ▁한데, ▁그래도]
# 5    [▁다른, ▁데, ▁뭐, ~, ▁수영, ▁카페, ▁같은, ▁데, ▁가, ▁보면은, ...
# 6    [▁그거를, ▁이렇게, ▁깨, 달, 으면서, ▁제가, ▁좋아하는, ▁맛집, 이, ▁...
# 7         [▁근데, ▁쪘, 다가, ▁또, ▁빠졌, 다가, ▁또, ▁쪘, 다가, ▁이렇게]
# 8    [▁놀, 이, ▁있냐, ▁이게, ▁플, 레이, 냐, ▁꿈이, 냐, ▁틀리, 잖아, ...
# 9            [▁모든, ▁종류, 의, ▁기록, 을, ▁, 깼, 다고, ▁하더라고, .]
# Name: text, dtype: object

# %%
mecab_corpus = []
for i in spm_corpus['dial'].values :
    mecab_corpus.append(' '.join(mecab.morphs(i)))
mecab_corpus[:5]
# Out:
# ['오후 가 되 자 싸락눈 은 목화솜 처럼 부드러운 박석 눈 으로 변했 다 .',
#  '그래도 병원 에 도 안 가 보 고 그 ~ 돈 벌 러 댕기 느라고',
#  '뭐 얻 어 처묵 을 끼 있 다꼬 여 오노 ?',
#  '내 가 그 친구 한테 철썩 같이 약속 을 했 어요 . 글구 솔직히 상품 본부 장 이 그 정도 인사 권 도 못 갖 나 ?',
#  '아이고매 어 엽 다 .']

# %%
msp_tokenizer = generate_tokenizer(mecab_corpus, 8011, 'msp')

# %%
df.loc[df['reg']== reg, ['dial']].values[:5]
# Out:
# array([['생각이 쪼금씩 바뀌드라고'],
#        ['어 알겄는가 외국인들이 그래도 잘 적응하고'],
#        ['아으 갑자기 예전에 맹장 뜯은 게 생각난디야.'],
#        ['보면은 쫌 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.'],
#        ['약간 쫌 약간 맛이 쪼끔 거시기 하긴 한데 그래도']], dtype=object)

# %%
#bpe 8000 기준
for reg in regs :
    print(reg)    
    for k in df.loc[df['reg']== reg, ['dial']].values[:5] :
        print('spm: ',tokenizer.encode_as_pieces(k[0]))
        print('msp: ',msp_tokenizer.encode_as_pieces(k[0]))
        print()
# Out:
# kw
# spm:  ['▁그런', '▁걸', '▁보면', '▁농', '부', '▁얼굴', '은', '▁함', '박', '삐', '다구', '가', '▁되는', '거지', '.']
# msp:  ['▁그런', '▁걸', '▁보', '면', '▁농', '부', '▁얼굴', '은', '▁함', '박', '삐', '다구', '가', '▁되', '는', '거지', '.']
#
# spm:  ['▁홀', '에서는', '▁내', '금새', '▁피', '우', '지', '▁마', '.']
# msp:  ['▁홀', '에', '서', '는', '▁내금새', '▁피우', '지', '▁마', '.']
#
# spm:  ['▁너', '▁그거', '▁무슨', '▁소', '래기', '냐', '?']
# msp:  ['▁너', '▁그거', '▁무슨', '▁소래기', '냐', '?']
#
# spm:  ['▁국민', '들은', '▁과연', '▁어뜬', '▁선택', '을', '▁할', '▁것', '인지', '▁귀', '추', '가', '▁주', '목', '되고', '▁있습니다', '.']
# msp:  ['▁국민', '들', '은', '▁과연', '▁어뜬', '▁선택', '을', '▁할', '▁것', '인', '지', '▁귀', '추', '가', '▁주', '목', '되', '고', '▁있', '습', '니다', '.']
#
# spm:  ['▁얼구리', '라도', '▁안', '▁내', '밀', '면', '▁후', '환', '이', '▁두', '렵', '거든', '.']
# msp:  ['▁얼구', '리', '라도', '▁안', '▁내', '밀', '면', '▁후', '환', '이', '▁두', '렵', '거든', '.']
#
# jj
# spm:  ['▁부', '애', '나', '도', '▁막', '▁좋은', '▁말로', '만', '▁해야', '▁되고', '▁막', '▁타', '일', '러', '야', '▁되고']
# msp:  ['▁부', '애', '나', '도', '▁막', '▁좋', '은', '▁말', '로', '만', '▁해야', '▁되', '고', '▁막', '▁타', '일', '러', '야', '▁되', '고']
#
# spm:  ['▁나는', '▁최대한', '▁안', '▁살려고', '▁집에', '▁있는', '▁거', '▁다', '▁가져', '▁간', '?']
# msp:  ['▁나', '는', '▁최대한', '▁안', '▁살', '려고', '▁집', '에', '▁있', '는', '▁거', '▁다', '▁가져', '▁간', '?']
#
# spm:  ['▁큰', '엉', '▁간', '▁인디', '언']
# msp:  ['▁큰', '엉', '▁간', '▁인디', '언']
#
# spm:  ['▁좀', '▁홍보', '를', '▁좀', '▁잘해', '▁가지고', '▁또', '▁그것도', '▁조금', '▁조금', '▁더', '▁다양하게', '이']
# msp:  ['▁좀', '▁홍보', '를', '▁좀', '▁잘', '해', '▁가지', '고', '▁또', '▁그것', '도', '▁조금', '▁조금', '▁더', '▁다양', '하', '게', '이']
#
# spm:  ['▁그', '▁강', '으네', '▁이제', '▁한', '복', '도', '▁입고', '▁해', '▁가지고']
# msp:  ['▁그', '▁강', '으네', '▁이제', '▁한복', '도', '▁입', '고', '▁해', '▁가지', '고']
#
# cc
# spm:  ['▁근데', '▁긍까', '▁너는', '▁조심', '스럽', '지', '▁많이', '▁조심', '성이', '▁많지', '.']
# msp:  ['▁근데', '▁긍까', '▁너', '는', '▁조심', '스럽', '지', '▁많이', '▁조심', '성', '이', '▁많', '지', '.']
#
# spm:  ['▁비타민', '▁먹', '▁말고', '▁쫌', '▁관심', '▁갖고', '▁있는', '▁뭐', '~', '▁다른', '▁보조', '제', '▁있는지', '▁궁금', '해', '.']
# msp:  ['▁비타민', '▁먹', '▁말', '고', '▁쫌', '▁관심', '▁갖', '고', '▁있', '는', '▁뭐', '~', '▁다른', '▁보조제', '▁있', '는', '지', '▁궁금', '해', '.']
#
# spm:  ['▁나', '▁자랑', '할려고', '▁내', '▁허영', '심', '에', '▁뭐', '~', '▁그렇게', '▁주는', '▁것도', '▁아니고', '▁정말', '▁그냥']
# msp:  ['▁나', '▁자랑', '할', '려고', '▁내', '▁허영', '심', '에', '▁뭐', '~', '▁그렇게', '▁주', '는', '▁것', '도', '▁아니', '고', '▁정말', '▁그냥']
#
# spm:  ['▁어', '~', '▁지금', '▁현재', '▁당장', '으로', '서는', '▁전기', '▁차가', '▁쫌', '▁불편', '하고', '▁문제가', '▁없', '진', '▁않지만']
# msp:  ['▁어', '~', '▁지금', '▁현재', '▁당장', '으', '로', '서', '는', '▁전기', '▁차가', '▁쫌', '▁불편', '하', '고', '▁문제', '가', '▁없', '진', '▁않', '지만']
#
# spm:  ['▁지', '▁저', '~', '▁뭐야', '▁취업', '▁나갔', '다고', '요', '▁', '@이름', '아빠', '가', '▁거', '금', '▁주고', '▁그래두']
# msp:  ['▁지', '▁저', '~', '▁뭐', '야', '▁취업', '▁나갔', '다고', '요', '▁', '@이름', '아', '빠', '가', '▁거', '금', '▁주고', '▁그래두']
#
# gs
# spm:  ['▁해서', '▁이르케', '▁큰', '▁위', '기가', '▁', '닥', '쳤', '을', '▁때']
# msp:  ['▁해서', '▁이르케', '▁큰', '▁위기', '가', '▁닥', '쳤', '을', '▁때']
#
# spm:  ['▁근데', '▁이제', '▁사회', '▁나오니까', '▁오히려', '▁더', '▁추', '위를', '▁마이', '▁타', '게', '▁되더라고요', '▁이제는']
# msp:  ['▁근데', '▁이제', '▁사회', '▁나오', '니까', '▁오히려', '▁더', '▁추위', '를', '▁마이', '▁타', '게', '▁되', '더', '라고', '요', '▁이제', '는']
#
# spm:  ['▁몸을', '▁갖다가', '▁지가', '▁인제', '▁지', '▁편', '할', '▁대로', '▁살다가', '▁보니까', '▁지금']
# msp:  ['▁몸', '을', '▁갖', '다가', '▁지가', '▁인제', '▁지', '▁편할', '▁대로', '▁살', '다가', '▁보', '니까', '▁지금']
#
# spm:  ['▁근데', '▁니는', '▁거기', '▁단', '골', '은', '▁없었', '겠', '▁그렇게', '▁막', '▁자주', '▁오는', '▁사람은', '▁없었', '겠다', '.']
# msp:  ['▁근데', '▁니', '는', '▁거기', '▁단', '골', '은', '▁없', '었', '겠', '▁그렇게', '▁막', '▁자주', '▁오', '는', '▁사람', '은', '▁없', '었', '겠다', '.']
#
# spm:  ['▁이제', '▁델', '루', '나', '도', '▁쫌', '▁재밌게', '▁봤', '었고']
# msp:  ['▁이제', '▁델', '루', '나', '도', '▁쫌', '▁재밌', '게', '▁봤었', '고']
#
# jd
# spm:  ['▁생각이', '▁쪼금씩', '▁바뀌', '드라고']
# msp:  ['▁생각', '이', '▁쪼금', '씩', '▁바뀌', '드', '라고']
#
# spm:  ['▁어', '▁알', '겄', '는가', '▁외국', '인들이', '▁그래도', '▁잘', '▁적응', '하고']
# msp:  ['▁어', '▁알', '겄', '는', '가', '▁외국인', '들이', '▁그래도', '▁잘', '▁적응', '하', '고']
#
# spm:  ['▁아', '으', '▁갑자기', '▁예전에', '▁맹', '장', '▁뜯', '은', '▁게', '▁생각난', '디야', '.']
# msp:  ['▁아', '으', '▁갑자기', '▁예전', '에', '▁맹', '장', '▁뜯', '은', '▁게', '▁생각난', '디', '야', '.']
#
# spm:  ['▁보면은', '▁쫌', '▁품', '위', '▁있게', '▁나이', '▁들어가', '야', '▁되겠', '단', '▁생각을', '▁참', '▁많이', '▁해요', '.']
# msp:  ['▁보', '면은', '▁쫌', '▁품', '위', '▁있', '게', '▁나이', '▁들어가', '야', '▁되', '겠', '단', '▁생각', '을', '▁참', '▁많이', '▁해요', '.']
#
# spm:  ['▁약간', '▁쫌', '▁약간', '▁맛이', '▁쪼끔', '▁거시기', '▁하긴', '▁한데', '▁그래도']
# msp:  ['▁약간', '▁쫌', '▁약간', '▁맛', '이', '▁쪼끔', '▁거시기', '▁하긴', '▁한데', '▁그래도']

# %%
from wordcloud import WordCloud
import matplotlib as mpl
import matplotlib.font_manager as fm
from collections import Counter

# %%
plt.figure(figsize= (20,20))

for i, reg in enumerate(regs) :
    counter = Counter()
    for k in spm_corpus.loc[spm_corpus['reg'] == reg,'dial'].values :
        counter.update(''.join(msp_tokenizer.encode_as_pieces(k)).replace('▁',' '))
    
    print(reg)
    print(counter.most_common(30),end='\n\n')

    # font path http://corazzon.github.io/matplotlib_font_setting
    font_list = [(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
    font_list[0][1]
    wc = WordCloud(font_path= font_list[0][1], background_color='white',max_font_size=60)
    
    
    cloud = wc.generate_from_frequencies(counter)
    
    plt.subplot(3,2,i+1)
    plt.ylabel(reg)
    plt.imshow(cloud)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)

plt.suptitle('지역별 most-common 워드클라우드',  font ='NanumGothic')
plt.tight_layout()
plt.show()
# Out:
# kw
# [(' ', 601192), ('이', 73220), ('.', 63904), ('가', 37654), ('어', 35221), ('는', 33070), ('그', 32218), ('아', 31190), ('지', 30409), ('다', 28588), ('고', 28542), ('하', 26393), ('요', 24103), ('?', 23458), ('나', 22242), ('에', 20485), ('니', 19078), ('서', 18731), ('거', 17201), ('게', 17051), ('도', 16723), ('기', 15723), ('을', 14943), ('데', 14600), ('사', 14595), ('리', 14242), ('라', 13962), ('야', 13729), ('구', 13682), ('은', 13621)]
#
# jj
# [(' ', 643938), ('이', 70099), ('그', 41861), ('아', 36420), ('가', 34110), ('거', 31678), ('고', 31087), ('는', 28755), ('어', 26286), ('도', 24941), ('게', 24937), ('하', 24918), ('나', 24229), ('지', 23519), ('.', 23371), ('다', 20967), ('에', 19554), ('해', 16887), ('니', 16835), ('서', 16798), ('기', 16137), ('난', 15123), ('?', 14634), ('라', 14323), ('리', 13759), ('디', 13247), ('은', 12787), ('사', 12619), ('들', 12112), ('안', 11600)]
#
# cc
# [(' ', 1059857), ('이', 111644), ('그', 97470), ('는', 77692), ('고', 71686), ('가', 65219), ('하', 44376), ('어', 43768), ('서', 42319), ('게', 41413), ('거', 40119), ('아', 39156), ('지', 37859), ('다', 35595), ('도', 35434), ('에', 34245), ('나', 34024), ('쫌', 31546), ('을', 29219), ('.', 28855), ('니', 28821), ('은', 27701), ('데', 26380), ('기', 26352), ('라', 25513), ('~', 25501), ('까', 24988), ('면', 24793), ('있', 22773), ('들', 22068)]
#
# gs
# [(' ', 988250), ('이', 105059), ('그', 80555), ('는', 70368), ('고', 70305), ('가', 64030), ('쫌', 42157), ('하', 41049), ('아', 39664), ('거', 39642), ('다', 39249), ('지', 37240), ('~', 36816), ('서', 33801), ('도', 33600), ('니', 33124), ('어', 33071), ('게', 32245), ('에', 31944), ('나', 31935), ('데', 29037), ('은', 25941), ('면', 25418), ('을', 22963), ('라', 22871), ('있', 22687), ('기', 22412), ('요', 20473), ('뭐', 20109), ('제', 20066)]
#
# jd
# [(' ', 895960), ('이', 89717), ('그', 79075), ('고', 67764), ('는', 61119), ('가', 58778), ('하', 36713), ('어', 36133), ('아', 35708), ('지', 35141), ('도', 32166), ('다', 31663), ('거', 31173), ('나', 30624), ('게', 30105), ('.', 28657), ('서', 28433), ('에', 27378), ('니', 25316), ('을', 22538), ('은', 22351), ('라', 22304), ('기', 22151), ('제', 21805), ('데', 21483), ('면', 20435), ('까', 19431), ('쫌', 19226), ('들', 18689), ('인', 18225)]

# %%
from nltk import ngrams
import seaborn as sns

fig = plt.figure(figsize=(15,30))

for i, reg in enumerate(regs) :
    
    frequency_pos = Counter()
    
    for k in spm_corpus.loc[spm_corpus['reg'] == reg, 'dial'] :
        tokenized = ''.join(msp_tokenizer.encode_as_pieces(k)).replace('▁',' ').split()
        token_words = ngrams(tokenized,1)
        frequency_pos.update(token_words)

    df_pos = pd.DataFrame(frequency_pos.most_common(20))

    # Barplot that shows the top most common
    
    plt.subplot(5,1,i+1)
    sns.set(font_scale = 1.5, style = 'whitegrid', font ='NanumGothic')
    sns_pos_1 = sns.barplot(x = df_pos[1], y = df_pos[0], color = 'steelblue')

    # Setting axes labels
    sns_pos_1.set(xlabel = 'Occurrence', ylabel = 'Unigrams', title = f'Top 20 Unigrams : {reg}')
#     plt.xticks(fontsize=16)
#     plt.yticks(fontsize=16)

    
plt.tight_layout()
plt.show()

# %%
from nltk import ngrams
import seaborn as sns

fig = plt.figure(figsize=(15,30))

for i, reg in enumerate(regs) :
    
    frequency_pos = Counter()
    
    for k in spm_corpus.loc[spm_corpus['reg'] == reg, 'dial'] :
        tokenized = ''.join(msp_tokenizer.encode_as_pieces(k)).replace('▁',' ').split()
        token_words = ngrams(tokenized,2)
        frequency_pos.update(token_words)

    df_pos = pd.DataFrame(frequency_pos.most_common(20))

    # Barplot that shows the top most common
    
    plt.subplot(5,1,i+1)
    sns.set(font_scale = 1.5, style = 'whitegrid', font ='NanumGothic')
    sns_pos_1 = sns.barplot(x = df_pos[1], y = df_pos[0], color = 'steelblue')

    # Setting axes labels
    sns_pos_1.set(xlabel = 'Occurrence', ylabel = 'Bigrams', title = f'Top 20 Bigrams : {reg}')
#     plt.xticks(fontsize=16)
#     plt.yticks(fontsize=16)

    
plt.tight_layout()
plt.show()

# %%
#trigram
fig = plt.figure(figsize=(15,30))

for i, reg in enumerate(regs) :
    
    frequency_pos = Counter()
    
    for k in spm_corpus.loc[spm_corpus['reg'] == reg, 'dial'] :
        tokenized = ''.join(msp_tokenizer.encode_as_pieces(k)).replace('▁',' ').split()
        token_words = ngrams(tokenized,3)
        frequency_pos.update(token_words)

    df_pos = pd.DataFrame(frequency_pos.most_common(20))

    # Barplot that shows the top most common
    
    plt.subplot(5,1,i+1)
    sns.set(font_scale = 1.5, style = 'whitegrid', font ='NanumGothic')
    sns_pos_1 = sns.barplot(x = df_pos[1], y = df_pos[0], color = 'steelblue')

    # Setting axes labels
    sns_pos_1.set(xlabel = 'Occurrence', ylabel = 'Trigrams', title = f'Top 20 Trigrams : {reg}')
#     plt.xticks(fontsize=16)
#     plt.yticks(fontsize=16)

    
plt.tight_layout()
plt.show()
